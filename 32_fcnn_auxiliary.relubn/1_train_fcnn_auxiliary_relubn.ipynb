# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']
X_pids = _d['pids']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
print X.dtype
print Y.dtype
# Out:
# (3906, 128, 128)
# (3906, 128, 128)
# float32
# float32

# %%
if False:
    # Split patients in train/test
    train_pids, test_pids = train_test_split(np.unique(X_pids), test_size=0.2)
    print train_pids
    print test_pids
    
    train_indices = np.flatnonzero(np.in1d(X_pids, train_pids))
    test_indices = np.flatnonzero(np.in1d(X_pids, test_pids))
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]
else:
    nsamples = X.shape[0]

    #train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.2)
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]

# %%
import skimage.transform as sktransf

def rand_float(rng):
    return rng[0] + np.random.random() * (rng[1] - rng[0])

def generate_image(X_img, Y_img, angle_range=None, zoom_range=None, shear_range=None, horiz_shift_range=None,
                   vert_shift_range=None):
    """
    Randomly shift an image by resizing and then random croping
    the resized image
    """
    if angle_range is None:
        angle_range = (-5, 5)
    if zoom_range is None:
        zoom_range = (0.8, 1.2)
    if shear_range is None:
        shear_range = (-5, 5) # shear angle in degrees
    if horiz_shift_range is None:
        horiz_shift_range = (-5, 5)
    if vert_shift_range is None:
        vert_shift_range = (-5, 5)
    inshape = X_img.shape
    
    X2 = X_img.copy()
    Y2 = Y_img.copy()
    
    # -- random rotation
    angle = np.deg2rad(rand_float(angle_range))
    zoom = rand_float(zoom_range)
    shear = np.deg2rad(rand_float(shear_range))
    horiz_shift = rand_float(horiz_shift_range)
    vert_shift = rand_float(vert_shift_range)
    
    tform = sktransf.AffineTransform(
        scale=(zoom, zoom),
        rotation=angle,
        shear=shear,
        translation=(horiz_shift, vert_shift)
    )
    X2 = sktransf.warp(X2, tform, order=5, mode='edge')
    Y2 = sktransf.warp(Y2, tform, order=1)

    # gaussian noise
    #noise_scale = rand_float((0, 0.1))
    #X2 += np.random.normal(scale=noise_scale, size=X2.shape)
    Y2 = Y2 > 0.5
    return X2[None,:,:].astype(np.float32), Y2[None,:,:].astype(np.float32)

X_train_augmented = []
Y_train_augmented = []
for i in range(X_train.shape[0]):
    if i % 10 == 0:
        print '\r%d / %d' % (i, X_train.shape[0]),
        sys.stdout.flush()
    X_train_augmented.append(X_train[i])
    Y_train_augmented.append(Y_train[i])
    for j in range(2):
        X2, Y2 = generate_image(X_train[i].squeeze(), Y_train[i].squeeze())
        X_train_augmented.append(X2)
        Y_train_augmented.append(Y2)
# Out:
# 3120 / 3124

# %%
X_train = np.array(X_train_augmented, dtype=np.float32)
Y_train = np.array(Y_train_augmented, dtype=np.float32)

Y_train_binary = np.sum(np.sum(Y_train.squeeze(), axis=2), axis=1) > 0
Y_train_binary = Y_train_binary.astype(np.float32)
Y_train_binary = Y_train_binary[:,None]

# %%
print X_train.shape
print Y_train.shape
print X_test.shape
print X_train.min(), X_train.max()
# Out:
# (9372, 1, 128, 128)
# (9372, 1, 128, 128)
# (782, 1, 128, 128)
# 0.0 1.0

# %%
import cv2
def _resize(Y, outshape):
    return cv2.resize(Y.squeeze(), outshape, interpolation=cv2.INTER_AREA)[None, :, :]
Y_train_88 = np.array([_resize(img, (8, 8)) for img in Y_train])
Y_test_88 = np.array([_resize(img, (8, 8)) for img in Y_test])
Y_train_44 = np.array([_resize(img, (4, 4)) for img in Y_train])
Y_test_44 = np.array([_resize(img, (4, 4)) for img in Y_test])

# %%
with_bp = np.flatnonzero(np.sum(np.sum(np.sum(Y_train, axis=1), axis=1), axis=1))

# %%
for bpi in range(11, 14):
    i = with_bp[bpi]
    pl.figure(figsize=(16, 4))
    pl.subplot(141)
    pl.imshow(X_train[i].squeeze())
    pl.subplot(142)
    pl.imshow(Y_train[i].squeeze())
    pl.subplot(143)
    pl.imshow(Y_train_88[i].squeeze(), interpolation='nearest')
    pl.colorbar()
    pl.subplot(144)
    pl.imshow(Y_train_44[i].squeeze(), interpolation='nearest')
    pl.colorbar()

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float32'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense
from keras.layers import LeakyReLU, BatchNormalization
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
import keras.backend as K
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
# https://www.kaggle.com/c/ultrasound-nerve-segmentation/forums/t/21358/0-57-deep-learning-keras-tutorial
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def dice_coef_batchwise(y_true, y_pred):
    y_true_f = K.batch_flatten(y_true)
    y_pred_f = K.batch_flatten(y_pred)
    intersection = 2. * K.sum(y_true_f * y_pred_f, axis=1, keepdims=True) + smooth
    union = K.sum(y_true_f, axis=1, keepdims=True) + \
            K.sum(y_pred_f, axis=1, keepdims=True) + \
            smooth
    return K.mean(intersection / union)

def dice_coef_loss_batchwise(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %% [markdown]
# http://torch.ch/blog/2015/07/30/cifar.html

# %%
input_img = x = Input(shape=input_shape, name='input_img')
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(input_img)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
pool1 = BatchNormalization(name='pool1', axis=1)(x)

x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
pool2 = BatchNormalization(name='pool2', axis=1)(x)

x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
pool3 = BatchNormalization(name='pool3', axis=1)(x)

x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
pool4 = BatchNormalization(name='pool4', axis=1)(x)

x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
pool5 = BatchNormalization(name='pool5', axis=1)(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(pool5)
x = Dense(32, activation='relu')(x)
x = Dense(16, activation='relu')(x)
x = Dropout(0.25)(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# turn pool5 into a classification map
outmap5 = Convolution2D(1, 3, 3, border_mode='same', activation='sigmoid', name='outmap5')(pool5)

x = UpSampling2D((2, 2))(outmap5)
x = merge([x, pool4], mode='concat', concat_axis=1)
x = Dropout(0.25)(x)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
outmap4 = Convolution2D(1, 3, 3, border_mode='same', activation='sigmoid', name='outmap4')(x)
x = UpSampling2D((2, 2))(x)

# upsample the classif map
x = merge([x, pool3], mode='concat', concat_axis=1)
x = Dropout(0.25)(x)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(pool3)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Dropout(0.25)(x)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Dropout(0.25)(x)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = UpSampling2D((2, 2))(x)

x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(x)
outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outmap4, outmap5, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
metrics={'outbin': 'accuracy'}
model.compile(optimizer='adam', loss='binary_crossentropy',
              loss_weights=[1., 0.2, 0.05, 0.01], metrics=metrics)

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)    (None, 16, 128, 128)160         input_img[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)    (None, 16, 128, 128)2320        convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_1 (MaxPooling2D)      (None, 16, 64, 64)  0           convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)    (None, 16, 64, 64)  2320        maxpooling2d_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)    (None, 16, 64, 64)  2320        convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_2 (MaxPooling2D)      (None, 16, 32, 32)  0           convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)    (None, 16, 32, 32)  2320        maxpooling2d_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_6 (Convolution2D)    (None, 16, 32, 32)  2320        convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_3 (MaxPooling2D)      (None, 16, 16, 16)  0           convolution2d_6[0][0]
# ____________________________________________________________________________________________________
# pool3 (BatchNormalization)         (None, 16, 16, 16)  32          maxpooling2d_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_13 (Convolution2D)   (None, 16, 16, 16)  2320        pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_14 (Convolution2D)   (None, 16, 16, 16)  2320        convolution2d_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_7 (Convolution2D)    (None, 16, 16, 16)  2320        maxpooling2d_3[0][0]
# ____________________________________________________________________________________________________
# pool2 (BatchNormalization)         (None, 16, 32, 32)  32          maxpooling2d_2[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_3 (UpSampling2D)      (None, 16, 32, 32)  0           convolution2d_14[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8 (Convolution2D)    (None, 16, 16, 16)  2320        convolution2d_7[0][0]
# ____________________________________________________________________________________________________
# merge_3 (Merge)                    (None, 32, 32, 32)  0           upsampling2d_3[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)                (None, 32, 32, 32)  0           merge_3[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_4 (MaxPooling2D)      (None, 16, 8, 8)    0           convolution2d_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_15 (Convolution2D)   (None, 16, 32, 32)  4624        dropout_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_9 (Convolution2D)    (None, 16, 8, 8)    2320        maxpooling2d_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_10 (Convolution2D)   (None, 16, 8, 8)    2320        convolution2d_9[0][0]
# ____________________________________________________________________________________________________
# convolution2d_16 (Convolution2D)   (None, 16, 32, 32)  2320        convolution2d_15[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_5 (MaxPooling2D)      (None, 16, 4, 4)    0           convolution2d_10[0][0]
# ____________________________________________________________________________________________________
# pool1 (BatchNormalization)         (None, 16, 64, 64)  32          maxpooling2d_1[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_4 (UpSampling2D)      (None, 16, 64, 64)  0           convolution2d_16[0][0]
# ____________________________________________________________________________________________________
# merge_4 (Merge)                    (None, 32, 64, 64)  0           upsampling2d_4[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# pool5 (BatchNormalization)         (None, 16, 4, 4)    32          maxpooling2d_5[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)                (None, 32, 64, 64)  0           merge_4[0][0]
# ____________________________________________________________________________________________________
# outmap5 (Convolution2D)            (None, 1, 4, 4)     145         pool5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_17 (Convolution2D)   (None, 16, 64, 64)  4624        dropout_5[0][0]
# ____________________________________________________________________________________________________
# pool4 (BatchNormalization)         (None, 16, 8, 8)    32          maxpooling2d_4[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_1 (UpSampling2D)      (None, 1, 8, 8)     0           outmap5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_18 (Convolution2D)   (None, 16, 64, 64)  2320        convolution2d_17[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)                (None, 256)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# merge_1 (Merge)                    (None, 17, 8, 8)    0           upsampling2d_1[0][0]
#                                                                    pool4[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                    (None, 32)          8224        flatten_1[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)                (None, 17, 8, 8)    0           merge_1[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_5 (UpSampling2D)      (None, 16, 128, 128)0           convolution2d_18[0][0]
# ____________________________________________________________________________________________________
# convolution2d_11 (Convolution2D)   (None, 16, 8, 8)    2464        dropout_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_19 (Convolution2D)   (None, 8, 128, 128) 1160        upsampling2d_5[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                    (None, 16)          528         dense_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_12 (Convolution2D)   (None, 16, 8, 8)    2320        convolution2d_11[0][0]
# ____________________________________________________________________________________________________
# convolution2d_20 (Convolution2D)   (None, 8, 128, 128) 584         convolution2d_19[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)                (None, 16)          0           dense_2[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          dropout_1[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 73          convolution2d_20[0][0]
# ____________________________________________________________________________________________________
# outmap4 (Convolution2D)            (None, 1, 8, 8)     145         convolution2d_12[0][0]
# ====================================================================================================
# Total params: 55388
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {
            'outmap': Y_train,
            'outmap4' : Y_train_88,
            'outmap5' : Y_train_44,
            'outbin': Y_train_binary
        },
        batch_size=64,
        validation_data=(X_test, {
                'outmap': Y_test,
                'outmap4' : Y_test_88,
                'outmap5' : Y_test_44,
                'outbin': Y_test_binary
        }),
        nb_epoch=60,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    
    pl.figure()
    pl.plot(history.history['outmap_loss'], label='train loss')
    pl.plot(history.history['val_outmap_loss'], c='g', label='val loss')
    pl.legend()

    pl.figure()
    pl.plot(history.history['outbin_acc'], label='train acc')
    pl.plot(history.history['val_outbin_acc'], c='g', label='val acc')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
                custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.01])
    
    print_summary(model.layers)
# Out:
# Train on 9372 samples, validate on 782 samples
# Epoch 1/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0951 - outmap_loss: 0.0665 - outmap4_loss: 0.0797 - outmap5_loss: 0.1273 - outbin_loss: 0.6325 - outbin_acc: 0.6401Epoch 00000: val_loss improved from inf to 0.07950, saving model to weights.hdf5
# 9372/9372 [==============================] - 61s - loss: 0.0950 - outmap_loss: 0.0664 - outmap4_loss: 0.0796 - outmap5_loss: 0.1270 - outbin_loss: 0.6328 - outbin_acc: 0.6396 - val_loss: 0.0795 - val_outmap_loss: 0.0610 - val_outmap4_loss: 0.0451 - val_outmap5_loss: 0.0582 - val_outbin_loss: 0.6542 - val_outbin_acc: 0.6151
# Epoch 2/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0470 - outmap_loss: 0.0308 - outmap4_loss: 0.0409 - outmap5_loss: 0.0552 - outbin_loss: 0.5259 - outbin_acc: 0.7375Epoch 00001: val_loss improved from 0.07950 to 0.04334, saving model to weights.hdf5
# 9372/9372 [==============================] - 62s - loss: 0.0470 - outmap_loss: 0.0308 - outmap4_loss: 0.0409 - outmap5_loss: 0.0552 - outbin_loss: 0.5260 - outbin_acc: 0.7375 - val_loss: 0.0433 - val_outmap_loss: 0.0265 - val_outmap4_loss: 0.0423 - val_outmap5_loss: 0.0478 - val_outbin_loss: 0.5977 - val_outbin_acc: 0.6790
# Epoch 3/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0403 - outmap_loss: 0.0265 - outmap4_loss: 0.0343 - outmap5_loss: 0.0468 - outbin_loss: 0.4613 - outbin_acc: 0.7856Epoch 00002: val_loss did not improve
# 9372/9372 [==============================] - 63s - loss: 0.0403 - outmap_loss: 0.0265 - outmap4_loss: 0.0343 - outmap5_loss: 0.0468 - outbin_loss: 0.4610 - outbin_acc: 0.7857 - val_loss: 0.0436 - val_outmap_loss: 0.0311 - val_outmap4_loss: 0.0300 - val_outmap5_loss: 0.0454 - val_outbin_loss: 0.4228 - val_outbin_acc: 0.8146
# Epoch 4/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0363 - outmap_loss: 0.0233 - outmap4_loss: 0.0325 - outmap5_loss: 0.0428 - outbin_loss: 0.4300 - outbin_acc: 0.8054Epoch 00003: val_loss did not improve
# 9372/9372 [==============================] - 63s - loss: 0.0362 - outmap_loss: 0.0233 - outmap4_loss: 0.0324 - outmap5_loss: 0.0427 - outbin_loss: 0.4295 - outbin_acc: 0.8057 - val_loss: 0.0517 - val_outmap_loss: 0.0372 - val_outmap4_loss: 0.0311 - val_outmap5_loss: 0.0403 - val_outbin_loss: 0.6188 - val_outbin_acc: 0.7468
# Epoch 5/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0344 - outmap_loss: 0.0220 - outmap4_loss: 0.0315 - outmap5_loss: 0.0412 - outbin_loss: 0.4078 - outbin_acc: 0.8235Epoch 00004: val_loss improved from 0.04334 to 0.03268, saving model to weights.hdf5
# 9372/9372 [==============================] - 63s - loss: 0.0344 - outmap_loss: 0.0220 - outmap4_loss: 0.0315 - outmap5_loss: 0.0412 - outbin_loss: 0.4079 - outbin_acc: 0.8235 - val_loss: 0.0327 - val_outmap_loss: 0.0208 - val_outmap4_loss: 0.0291 - val_outmap5_loss: 0.0387 - val_outbin_loss: 0.4083 - val_outbin_acc: 0.8235
# Epoch 6/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0332 - outmap_loss: 0.0211 - outmap4_loss: 0.0308 - outmap5_loss: 0.0406 - outbin_loss: 0.3843 - outbin_acc: 0.8363Epoch 00005: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0332 - outmap_loss: 0.0211 - outmap4_loss: 0.0308 - outmap5_loss: 0.0406 - outbin_loss: 0.3839 - outbin_acc: 0.8363 - val_loss: 0.0547 - val_outmap_loss: 0.0339 - val_outmap4_loss: 0.0414 - val_outmap5_loss: 0.0443 - val_outbin_loss: 1.0351 - val_outbin_acc: 0.5294
# Epoch 7/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0319 - outmap_loss: 0.0203 - outmap4_loss: 0.0300 - outmap5_loss: 0.0393 - outbin_loss: 0.3663 - outbin_acc: 0.8417Epoch 00006: val_loss did not improve
# 9372/9372 [==============================] - 63s - loss: 0.0319 - outmap_loss: 0.0203 - outmap4_loss: 0.0300 - outmap5_loss: 0.0393 - outbin_loss: 0.3666 - outbin_acc: 0.8417 - val_loss: 0.0334 - val_outmap_loss: 0.0209 - val_outmap4_loss: 0.0334 - val_outmap5_loss: 0.0376 - val_outbin_loss: 0.3865 - val_outbin_acc: 0.8389
# Epoch 8/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0312 - outmap_loss: 0.0198 - outmap4_loss: 0.0297 - outmap5_loss: 0.0390 - outbin_loss: 0.3528 - outbin_acc: 0.8515Epoch 00007: val_loss improved from 0.03268 to 0.03182, saving model to weights.hdf5
# 9372/9372 [==============================] - 63s - loss: 0.0311 - outmap_loss: 0.0197 - outmap4_loss: 0.0297 - outmap5_loss: 0.0390 - outbin_loss: 0.3526 - outbin_acc: 0.8516 - val_loss: 0.0318 - val_outmap_loss: 0.0205 - val_outmap4_loss: 0.0290 - val_outmap5_loss: 0.0379 - val_outbin_loss: 0.3609 - val_outbin_acc: 0.8312
# Epoch 9/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0299 - outmap_loss: 0.0190 - outmap4_loss: 0.0290 - outmap5_loss: 0.0383 - outbin_loss: 0.3265 - outbin_acc: 0.8659Epoch 00008: val_loss did not improve
# 9372/9372 [==============================] - 63s - loss: 0.0300 - outmap_loss: 0.0190 - outmap4_loss: 0.0290 - outmap5_loss: 0.0383 - outbin_loss: 0.3266 - outbin_acc: 0.8659 - val_loss: 0.0319 - val_outmap_loss: 0.0211 - val_outmap4_loss: 0.0271 - val_outmap5_loss: 0.0367 - val_outbin_loss: 0.3582 - val_outbin_acc: 0.8414
# Epoch 10/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0294 - outmap_loss: 0.0186 - outmap4_loss: 0.0285 - outmap5_loss: 0.0381 - outbin_loss: 0.3178 - outbin_acc: 0.8696Epoch 00009: val_loss improved from 0.03182 to 0.03097, saving model to weights.hdf5
# 9372/9372 [==============================] - 63s - loss: 0.0294 - outmap_loss: 0.0186 - outmap4_loss: 0.0285 - outmap5_loss: 0.0380 - outbin_loss: 0.3173 - outbin_acc: 0.8699 - val_loss: 0.0310 - val_outmap_loss: 0.0198 - val_outmap4_loss: 0.0279 - val_outmap5_loss: 0.0369 - val_outbin_loss: 0.3779 - val_outbin_acc: 0.8402
# Epoch 11/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0289 - outmap_loss: 0.0182 - outmap4_loss: 0.0282 - outmap5_loss: 0.0379 - outbin_loss: 0.3106 - outbin_acc: 0.8745Epoch 00010: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0289 - outmap_loss: 0.0182 - outmap4_loss: 0.0282 - outmap5_loss: 0.0379 - outbin_loss: 0.3108 - outbin_acc: 0.8743 - val_loss: 0.0339 - val_outmap_loss: 0.0220 - val_outmap4_loss: 0.0301 - val_outmap5_loss: 0.0390 - val_outbin_loss: 0.3942 - val_outbin_acc: 0.8363
# Epoch 12/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0286 - outmap_loss: 0.0180 - outmap4_loss: 0.0280 - outmap5_loss: 0.0382 - outbin_loss: 0.3091 - outbin_acc: 0.8736Epoch 00011: val_loss did not improve
# 9372/9372 [==============================] - 62s - loss: 0.0286 - outmap_loss: 0.0180 - outmap4_loss: 0.0281 - outmap5_loss: 0.0382 - outbin_loss: 0.3092 - outbin_acc: 0.8736 - val_loss: 0.0334 - val_outmap_loss: 0.0199 - val_outmap4_loss: 0.0278 - val_outmap5_loss: 0.0389 - val_outbin_loss: 0.5935 - val_outbin_acc: 0.7903
# Epoch 13/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0280 - outmap_loss: 0.0176 - outmap4_loss: 0.0276 - outmap5_loss: 0.0379 - outbin_loss: 0.2985 - outbin_acc: 0.8805Epoch 00012: val_loss improved from 0.03097 to 0.03000, saving model to weights.hdf5
# 9372/9372 [==============================] - 65s - loss: 0.0280 - outmap_loss: 0.0176 - outmap4_loss: 0.0276 - outmap5_loss: 0.0378 - outbin_loss: 0.2984 - outbin_acc: 0.8804 - val_loss: 0.0300 - val_outmap_loss: 0.0192 - val_outmap4_loss: 0.0268 - val_outmap5_loss: 0.0366 - val_outbin_loss: 0.3601 - val_outbin_acc: 0.8670
# Epoch 14/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0276 - outmap_loss: 0.0174 - outmap4_loss: 0.0275 - outmap5_loss: 0.0376 - outbin_loss: 0.2832 - outbin_acc: 0.8850Epoch 00013: val_loss improved from 0.03000 to 0.02956, saving model to weights.hdf5
# 9372/9372 [==============================] - 62s - loss: 0.0275 - outmap_loss: 0.0173 - outmap4_loss: 0.0275 - outmap5_loss: 0.0375 - outbin_loss: 0.2831 - outbin_acc: 0.8851 - val_loss: 0.0296 - val_outmap_loss: 0.0191 - val_outmap4_loss: 0.0267 - val_outmap5_loss: 0.0360 - val_outbin_loss: 0.3341 - val_outbin_acc: 0.8657
# Epoch 15/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0272 - outmap_loss: 0.0171 - outmap4_loss: 0.0273 - outmap5_loss: 0.0374 - outbin_loss: 0.2753 - outbin_acc: 0.8942Epoch 00014: val_loss did not improve
# 9372/9372 [==============================] - 62s - loss: 0.0272 - outmap_loss: 0.0171 - outmap4_loss: 0.0273 - outmap5_loss: 0.0374 - outbin_loss: 0.2752 - outbin_acc: 0.8943 - val_loss: 0.0301 - val_outmap_loss: 0.0187 - val_outmap4_loss: 0.0292 - val_outmap5_loss: 0.0388 - val_outbin_loss: 0.3594 - val_outbin_acc: 0.8619
# Epoch 16/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0265 - outmap_loss: 0.0166 - outmap4_loss: 0.0269 - outmap5_loss: 0.0372 - outbin_loss: 0.2679 - outbin_acc: 0.8979Epoch 00015: val_loss did not improve
# 9372/9372 [==============================] - 62s - loss: 0.0265 - outmap_loss: 0.0166 - outmap4_loss: 0.0269 - outmap5_loss: 0.0372 - outbin_loss: 0.2684 - outbin_acc: 0.8979 - val_loss: 0.0484 - val_outmap_loss: 0.0232 - val_outmap4_loss: 0.0367 - val_outmap5_loss: 0.0778 - val_outbin_loss: 1.3956 - val_outbin_acc: 0.5038
# Epoch 17/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0261 - outmap_loss: 0.0163 - outmap4_loss: 0.0266 - outmap5_loss: 0.0371 - outbin_loss: 0.2637 - outbin_acc: 0.8952Epoch 00016: val_loss did not improve
# 9372/9372 [==============================] - 62s - loss: 0.0261 - outmap_loss: 0.0163 - outmap4_loss: 0.0266 - outmap5_loss: 0.0371 - outbin_loss: 0.2637 - outbin_acc: 0.8952 - val_loss: 0.0315 - val_outmap_loss: 0.0199 - val_outmap4_loss: 0.0289 - val_outmap5_loss: 0.0390 - val_outbin_loss: 0.3822 - val_outbin_acc: 0.8593
# Epoch 18/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0255 - outmap_loss: 0.0159 - outmap4_loss: 0.0264 - outmap5_loss: 0.0368 - outbin_loss: 0.2446 - outbin_acc: 0.9054Epoch 00017: val_loss did not improve
# 9372/9372 [==============================] - 62s - loss: 0.0255 - outmap_loss: 0.0160 - outmap4_loss: 0.0264 - outmap5_loss: 0.0368 - outbin_loss: 0.2447 - outbin_acc: 0.9052 - val_loss: 0.0307 - val_outmap_loss: 0.0197 - val_outmap4_loss: 0.0264 - val_outmap5_loss: 0.0355 - val_outbin_loss: 0.3912 - val_outbin_acc: 0.8555
# Epoch 19/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0251 - outmap_loss: 0.0156 - outmap4_loss: 0.0262 - outmap5_loss: 0.0364 - outbin_loss: 0.2400 - outbin_acc: 0.9051Epoch 00018: val_loss did not improve
# 9372/9372 [==============================] - 62s - loss: 0.0251 - outmap_loss: 0.0157 - outmap4_loss: 0.0262 - outmap5_loss: 0.0364 - outbin_loss: 0.2400 - outbin_acc: 0.9050 - val_loss: 0.0326 - val_outmap_loss: 0.0197 - val_outmap4_loss: 0.0288 - val_outmap5_loss: 0.0378 - val_outbin_loss: 0.5300 - val_outbin_acc: 0.8338
# Epoch 20/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0245 - outmap_loss: 0.0152 - outmap4_loss: 0.0259 - outmap5_loss: 0.0362 - outbin_loss: 0.2292 - outbin_acc: 0.9114Epoch 00019: val_loss did not improve
# 9372/9372 [==============================] - 62s - loss: 0.0245 - outmap_loss: 0.0152 - outmap4_loss: 0.0259 - outmap5_loss: 0.0362 - outbin_loss: 0.2295 - outbin_acc: 0.9112 - val_loss: 0.0325 - val_outmap_loss: 0.0213 - val_outmap4_loss: 0.0272 - val_outmap5_loss: 0.0373 - val_outbin_loss: 0.3935 - val_outbin_acc: 0.8670
# Epoch 21/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0241 - outmap_loss: 0.0149 - outmap4_loss: 0.0257 - outmap5_loss: 0.0362 - outbin_loss: 0.2182 - outbin_acc: 0.9112Epoch 00020: val_loss did not improve
# 9372/9372 [==============================] - 62s - loss: 0.0241 - outmap_loss: 0.0149 - outmap4_loss: 0.0257 - outmap5_loss: 0.0362 - outbin_loss: 0.2182 - outbin_acc: 0.9110 - val_loss: 0.0313 - val_outmap_loss: 0.0196 - val_outmap4_loss: 0.0269 - val_outmap5_loss: 0.0361 - val_outbin_loss: 0.4474 - val_outbin_acc: 0.8440
# Epoch 22/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0238 - outmap_loss: 0.0147 - outmap4_loss: 0.0256 - outmap5_loss: 0.0362 - outbin_loss: 0.2124 - outbin_acc: 0.9178Epoch 00021: val_loss did not improve
# 9372/9372 [==============================] - 62s - loss: 0.0238 - outmap_loss: 0.0147 - outmap4_loss: 0.0256 - outmap5_loss: 0.0362 - outbin_loss: 0.2123 - outbin_acc: 0.9178 - val_loss: 0.0317 - val_outmap_loss: 0.0210 - val_outmap4_loss: 0.0265 - val_outmap5_loss: 0.0363 - val_outbin_loss: 0.3579 - val_outbin_acc: 0.8708
# Epoch 23/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0237 - outmap_loss: 0.0148 - outmap4_loss: 0.0255 - outmap5_loss: 0.0361 - outbin_loss: 0.2060 - outbin_acc: 0.9185Epoch 00022: val_loss did not improve
# 9372/9372 [==============================] - 62s - loss: 0.0237 - outmap_loss: 0.0148 - outmap4_loss: 0.0255 - outmap5_loss: 0.0361 - outbin_loss: 0.2060 - outbin_acc: 0.9185 - val_loss: 0.0412 - val_outmap_loss: 0.0261 - val_outmap4_loss: 0.0323 - val_outmap5_loss: 0.0379 - val_outbin_loss: 0.6817 - val_outbin_acc: 0.8299
# Epoch 24/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0234 - outmap_loss: 0.0145 - outmap4_loss: 0.0253 - outmap5_loss: 0.0361 - outbin_loss: 0.2001 - outbin_acc: 0.9195Epoch 00023: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0234 - outmap_loss: 0.0145 - outmap4_loss: 0.0253 - outmap5_loss: 0.0361 - outbin_loss: 0.2002 - outbin_acc: 0.9194 - val_loss: 0.0303 - val_outmap_loss: 0.0195 - val_outmap4_loss: 0.0260 - val_outmap5_loss: 0.0355 - val_outbin_loss: 0.3783 - val_outbin_acc: 0.8645
# Epoch 25/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0226 - outmap_loss: 0.0139 - outmap4_loss: 0.0249 - outmap5_loss: 0.0356 - outbin_loss: 0.1911 - outbin_acc: 0.9247Epoch 00024: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0226 - outmap_loss: 0.0139 - outmap4_loss: 0.0249 - outmap5_loss: 0.0356 - outbin_loss: 0.1908 - outbin_acc: 0.9248 - val_loss: 0.0355 - val_outmap_loss: 0.0232 - val_outmap4_loss: 0.0269 - val_outmap5_loss: 0.0359 - val_outbin_loss: 0.5105 - val_outbin_acc: 0.8568
# Epoch 26/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0226 - outmap_loss: 0.0139 - outmap4_loss: 0.0250 - outmap5_loss: 0.0361 - outbin_loss: 0.1871 - outbin_acc: 0.9290Epoch 00025: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0226 - outmap_loss: 0.0139 - outmap4_loss: 0.0250 - outmap5_loss: 0.0361 - outbin_loss: 0.1869 - outbin_acc: 0.9290 - val_loss: 0.0331 - val_outmap_loss: 0.0210 - val_outmap4_loss: 0.0281 - val_outmap5_loss: 0.0365 - val_outbin_loss: 0.4667 - val_outbin_acc: 0.8453
# Epoch 27/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0220 - outmap_loss: 0.0135 - outmap4_loss: 0.0248 - outmap5_loss: 0.0355 - outbin_loss: 0.1730 - outbin_acc: 0.9316Epoch 00026: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0220 - outmap_loss: 0.0135 - outmap4_loss: 0.0248 - outmap5_loss: 0.0355 - outbin_loss: 0.1731 - outbin_acc: 0.9315 - val_loss: 0.0347 - val_outmap_loss: 0.0208 - val_outmap4_loss: 0.0302 - val_outmap5_loss: 0.0377 - val_outbin_loss: 0.5937 - val_outbin_acc: 0.8376
# Epoch 28/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0219 - outmap_loss: 0.0135 - outmap4_loss: 0.0247 - outmap5_loss: 0.0357 - outbin_loss: 0.1705 - outbin_acc: 0.9323Epoch 00027: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0219 - outmap_loss: 0.0135 - outmap4_loss: 0.0247 - outmap5_loss: 0.0357 - outbin_loss: 0.1702 - outbin_acc: 0.9324 - val_loss: 0.0344 - val_outmap_loss: 0.0229 - val_outmap4_loss: 0.0270 - val_outmap5_loss: 0.0352 - val_outbin_loss: 0.4263 - val_outbin_acc: 0.8772
# Epoch 29/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0211 - outmap_loss: 0.0130 - outmap4_loss: 0.0243 - outmap5_loss: 0.0352 - outbin_loss: 0.1543 - outbin_acc: 0.9403Epoch 00028: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0211 - outmap_loss: 0.0130 - outmap4_loss: 0.0243 - outmap5_loss: 0.0353 - outbin_loss: 0.1540 - outbin_acc: 0.9404 - val_loss: 0.0390 - val_outmap_loss: 0.0240 - val_outmap4_loss: 0.0308 - val_outmap5_loss: 0.0514 - val_outbin_loss: 0.6319 - val_outbin_acc: 0.8133
# Epoch 30/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0210 - outmap_loss: 0.0129 - outmap4_loss: 0.0242 - outmap5_loss: 0.0354 - outbin_loss: 0.1513 - outbin_acc: 0.9401Epoch 00029: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0210 - outmap_loss: 0.0129 - outmap4_loss: 0.0242 - outmap5_loss: 0.0354 - outbin_loss: 0.1516 - outbin_acc: 0.9398 - val_loss: 0.0317 - val_outmap_loss: 0.0205 - val_outmap4_loss: 0.0262 - val_outmap5_loss: 0.0355 - val_outbin_loss: 0.4196 - val_outbin_acc: 0.8798
# Epoch 31/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0211 - outmap_loss: 0.0130 - outmap4_loss: 0.0242 - outmap5_loss: 0.0353 - outbin_loss: 0.1481 - outbin_acc: 0.9445Epoch 00030: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0211 - outmap_loss: 0.0130 - outmap4_loss: 0.0242 - outmap5_loss: 0.0353 - outbin_loss: 0.1480 - outbin_acc: 0.9445 - val_loss: 0.0400 - val_outmap_loss: 0.0263 - val_outmap4_loss: 0.0297 - val_outmap5_loss: 0.0358 - val_outbin_loss: 0.5936 - val_outbin_acc: 0.8645
# Epoch 32/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0206 - outmap_loss: 0.0126 - outmap4_loss: 0.0239 - outmap5_loss: 0.0352 - outbin_loss: 0.1370 - outbin_acc: 0.9478Epoch 00031: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0206 - outmap_loss: 0.0127 - outmap4_loss: 0.0240 - outmap5_loss: 0.0352 - outbin_loss: 0.1373 - outbin_acc: 0.9476 - val_loss: 0.0341 - val_outmap_loss: 0.0218 - val_outmap4_loss: 0.0276 - val_outmap5_loss: 0.0358 - val_outbin_loss: 0.5009 - val_outbin_acc: 0.8427
# Epoch 33/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0201 - outmap_loss: 0.0123 - outmap4_loss: 0.0239 - outmap5_loss: 0.0351 - outbin_loss: 0.1242 - outbin_acc: 0.9513Epoch 00032: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0201 - outmap_loss: 0.0123 - outmap4_loss: 0.0239 - outmap5_loss: 0.0351 - outbin_loss: 0.1243 - outbin_acc: 0.9512 - val_loss: 0.0347 - val_outmap_loss: 0.0226 - val_outmap4_loss: 0.0265 - val_outmap5_loss: 0.0355 - val_outbin_loss: 0.4957 - val_outbin_acc: 0.8555
# Epoch 34/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0197 - outmap_loss: 0.0121 - outmap4_loss: 0.0234 - outmap5_loss: 0.0350 - outbin_loss: 0.1192 - outbin_acc: 0.9542Epoch 00033: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0197 - outmap_loss: 0.0121 - outmap4_loss: 0.0234 - outmap5_loss: 0.0350 - outbin_loss: 0.1191 - outbin_acc: 0.9543 - val_loss: 0.0348 - val_outmap_loss: 0.0224 - val_outmap4_loss: 0.0275 - val_outmap5_loss: 0.0364 - val_outbin_loss: 0.5098 - val_outbin_acc: 0.8581
# Epoch 35/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0196 - outmap_loss: 0.0121 - outmap4_loss: 0.0234 - outmap5_loss: 0.0348 - outbin_loss: 0.1130 - outbin_acc: 0.9564Epoch 00034: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0196 - outmap_loss: 0.0121 - outmap4_loss: 0.0234 - outmap5_loss: 0.0348 - outbin_loss: 0.1133 - outbin_acc: 0.9564 - val_loss: 0.0382 - val_outmap_loss: 0.0235 - val_outmap4_loss: 0.0296 - val_outmap5_loss: 0.0362 - val_outbin_loss: 0.6999 - val_outbin_acc: 0.8581
# Epoch 36/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0193 - outmap_loss: 0.0119 - outmap4_loss: 0.0233 - outmap5_loss: 0.0348 - outbin_loss: 0.1061 - outbin_acc: 0.9598Epoch 00035: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0193 - outmap_loss: 0.0119 - outmap4_loss: 0.0233 - outmap5_loss: 0.0348 - outbin_loss: 0.1059 - outbin_acc: 0.9599 - val_loss: 0.0377 - val_outmap_loss: 0.0239 - val_outmap4_loss: 0.0292 - val_outmap5_loss: 0.0381 - val_outbin_loss: 0.6111 - val_outbin_acc: 0.8645
# Epoch 37/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0192 - outmap_loss: 0.0117 - outmap4_loss: 0.0233 - outmap5_loss: 0.0349 - outbin_loss: 0.1116 - outbin_acc: 0.9589Epoch 00036: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0192 - outmap_loss: 0.0117 - outmap4_loss: 0.0233 - outmap5_loss: 0.0349 - outbin_loss: 0.1120 - outbin_acc: 0.9588 - val_loss: 0.0418 - val_outmap_loss: 0.0243 - val_outmap4_loss: 0.0301 - val_outmap5_loss: 0.0433 - val_outbin_loss: 0.9318 - val_outbin_acc: 0.7404
# Epoch 38/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0188 - outmap_loss: 0.0114 - outmap4_loss: 0.0231 - outmap5_loss: 0.0346 - outbin_loss: 0.0982 - outbin_acc: 0.9636Epoch 00037: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0187 - outmap_loss: 0.0114 - outmap4_loss: 0.0231 - outmap5_loss: 0.0346 - outbin_loss: 0.0981 - outbin_acc: 0.9636 - val_loss: 0.0374 - val_outmap_loss: 0.0232 - val_outmap4_loss: 0.0282 - val_outmap5_loss: 0.0365 - val_outbin_loss: 0.6701 - val_outbin_acc: 0.8632
# Epoch 39/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0183 - outmap_loss: 0.0113 - outmap4_loss: 0.0227 - outmap5_loss: 0.0346 - outbin_loss: 0.0786 - outbin_acc: 0.9697Epoch 00038: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0183 - outmap_loss: 0.0113 - outmap4_loss: 0.0227 - outmap5_loss: 0.0346 - outbin_loss: 0.0788 - outbin_acc: 0.9696 - val_loss: 0.0391 - val_outmap_loss: 0.0217 - val_outmap4_loss: 0.0302 - val_outmap5_loss: 0.0374 - val_outbin_loss: 0.9511 - val_outbin_acc: 0.8491
# Epoch 40/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0186 - outmap_loss: 0.0114 - outmap4_loss: 0.0230 - outmap5_loss: 0.0345 - outbin_loss: 0.0886 - outbin_acc: 0.9648Epoch 00039: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0186 - outmap_loss: 0.0114 - outmap4_loss: 0.0230 - outmap5_loss: 0.0346 - outbin_loss: 0.0885 - outbin_acc: 0.9649 - val_loss: 0.0432 - val_outmap_loss: 0.0254 - val_outmap4_loss: 0.0297 - val_outmap5_loss: 0.0424 - val_outbin_loss: 0.9703 - val_outbin_acc: 0.8325
# Epoch 41/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0183 - outmap_loss: 0.0112 - outmap4_loss: 0.0228 - outmap5_loss: 0.0345 - outbin_loss: 0.0804 - outbin_acc: 0.9714Epoch 00040: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0183 - outmap_loss: 0.0112 - outmap4_loss: 0.0229 - outmap5_loss: 0.0346 - outbin_loss: 0.0804 - outbin_acc: 0.9715 - val_loss: 0.0392 - val_outmap_loss: 0.0251 - val_outmap4_loss: 0.0279 - val_outmap5_loss: 0.0389 - val_outbin_loss: 0.6621 - val_outbin_acc: 0.8645
# Epoch 42/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0182 - outmap_loss: 0.0112 - outmap4_loss: 0.0227 - outmap5_loss: 0.0345 - outbin_loss: 0.0815 - outbin_acc: 0.9696Epoch 00041: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0182 - outmap_loss: 0.0112 - outmap4_loss: 0.0226 - outmap5_loss: 0.0344 - outbin_loss: 0.0814 - outbin_acc: 0.9697 - val_loss: 0.0367 - val_outmap_loss: 0.0225 - val_outmap4_loss: 0.0272 - val_outmap5_loss: 0.0361 - val_outbin_loss: 0.6995 - val_outbin_acc: 0.8568
# Epoch 43/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0183 - outmap_loss: 0.0112 - outmap4_loss: 0.0227 - outmap5_loss: 0.0343 - outbin_loss: 0.0861 - outbin_acc: 0.9668Epoch 00042: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0183 - outmap_loss: 0.0112 - outmap4_loss: 0.0227 - outmap5_loss: 0.0343 - outbin_loss: 0.0861 - outbin_acc: 0.9668 - val_loss: 0.0370 - val_outmap_loss: 0.0236 - val_outmap4_loss: 0.0270 - val_outmap5_loss: 0.0359 - val_outbin_loss: 0.6233 - val_outbin_acc: 0.8338
# Epoch 44/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0177 - outmap_loss: 0.0108 - outmap4_loss: 0.0225 - outmap5_loss: 0.0342 - outbin_loss: 0.0669 - outbin_acc: 0.9770Epoch 00043: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0177 - outmap_loss: 0.0108 - outmap4_loss: 0.0225 - outmap5_loss: 0.0342 - outbin_loss: 0.0669 - outbin_acc: 0.9770 - val_loss: 0.0378 - val_outmap_loss: 0.0235 - val_outmap4_loss: 0.0271 - val_outmap5_loss: 0.0360 - val_outbin_loss: 0.7057 - val_outbin_acc: 0.8632
# Epoch 45/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0174 - outmap_loss: 0.0107 - outmap4_loss: 0.0223 - outmap5_loss: 0.0341 - outbin_loss: 0.0592 - outbin_acc: 0.9785Epoch 00044: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0174 - outmap_loss: 0.0107 - outmap4_loss: 0.0223 - outmap5_loss: 0.0341 - outbin_loss: 0.0592 - outbin_acc: 0.9784 - val_loss: 0.0431 - val_outmap_loss: 0.0244 - val_outmap4_loss: 0.0312 - val_outmap5_loss: 0.0378 - val_outbin_loss: 1.0504 - val_outbin_acc: 0.8619
# Epoch 46/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0172 - outmap_loss: 0.0105 - outmap4_loss: 0.0220 - outmap5_loss: 0.0340 - outbin_loss: 0.0551 - outbin_acc: 0.9792Epoch 00045: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0172 - outmap_loss: 0.0105 - outmap4_loss: 0.0220 - outmap5_loss: 0.0340 - outbin_loss: 0.0551 - outbin_acc: 0.9792 - val_loss: 0.0421 - val_outmap_loss: 0.0249 - val_outmap4_loss: 0.0312 - val_outmap5_loss: 0.0363 - val_outbin_loss: 0.9118 - val_outbin_acc: 0.8670
# Epoch 47/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0172 - outmap_loss: 0.0105 - outmap4_loss: 0.0221 - outmap5_loss: 0.0338 - outbin_loss: 0.0576 - outbin_acc: 0.9786Epoch 00046: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0172 - outmap_loss: 0.0105 - outmap4_loss: 0.0221 - outmap5_loss: 0.0338 - outbin_loss: 0.0578 - outbin_acc: 0.9786 - val_loss: 0.0420 - val_outmap_loss: 0.0253 - val_outmap4_loss: 0.0309 - val_outmap5_loss: 0.0379 - val_outbin_loss: 0.8647 - val_outbin_acc: 0.8670
# Epoch 48/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0170 - outmap_loss: 0.0103 - outmap4_loss: 0.0220 - outmap5_loss: 0.0339 - outbin_loss: 0.0589 - outbin_acc: 0.9787Epoch 00047: val_loss did not improve
# 9372/9372 [==============================] - 65s - loss: 0.0170 - outmap_loss: 0.0103 - outmap4_loss: 0.0220 - outmap5_loss: 0.0339 - outbin_loss: 0.0590 - outbin_acc: 0.9787 - val_loss: 0.0401 - val_outmap_loss: 0.0246 - val_outmap4_loss: 0.0281 - val_outmap5_loss: 0.0385 - val_outbin_loss: 0.7867 - val_outbin_acc: 0.8325
# Epoch 49/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0171 - outmap_loss: 0.0104 - outmap4_loss: 0.0220 - outmap5_loss: 0.0338 - outbin_loss: 0.0581 - outbin_acc: 0.9795Epoch 00048: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0171 - outmap_loss: 0.0104 - outmap4_loss: 0.0220 - outmap5_loss: 0.0338 - outbin_loss: 0.0579 - outbin_acc: 0.9795 - val_loss: 0.0421 - val_outmap_loss: 0.0260 - val_outmap4_loss: 0.0290 - val_outmap5_loss: 0.0358 - val_outbin_loss: 0.8530 - val_outbin_acc: 0.8798
# Epoch 50/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0172 - outmap_loss: 0.0105 - outmap4_loss: 0.0221 - outmap5_loss: 0.0340 - outbin_loss: 0.0609 - outbin_acc: 0.9770Epoch 00049: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0172 - outmap_loss: 0.0105 - outmap4_loss: 0.0221 - outmap5_loss: 0.0340 - outbin_loss: 0.0608 - outbin_acc: 0.9770 - val_loss: 0.0427 - val_outmap_loss: 0.0264 - val_outmap4_loss: 0.0313 - val_outmap5_loss: 0.0369 - val_outbin_loss: 0.8175 - val_outbin_acc: 0.8683
# Epoch 51/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0166 - outmap_loss: 0.0102 - outmap4_loss: 0.0217 - outmap5_loss: 0.0337 - outbin_loss: 0.0402 - outbin_acc: 0.9864Epoch 00050: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0166 - outmap_loss: 0.0102 - outmap4_loss: 0.0217 - outmap5_loss: 0.0337 - outbin_loss: 0.0406 - outbin_acc: 0.9863 - val_loss: 0.0439 - val_outmap_loss: 0.0239 - val_outmap4_loss: 0.0333 - val_outmap5_loss: 0.0386 - val_outbin_loss: 1.1453 - val_outbin_acc: 0.8657
# Epoch 52/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0167 - outmap_loss: 0.0101 - outmap4_loss: 0.0217 - outmap5_loss: 0.0336 - outbin_loss: 0.0506 - outbin_acc: 0.9812Epoch 00051: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0167 - outmap_loss: 0.0101 - outmap4_loss: 0.0217 - outmap5_loss: 0.0337 - outbin_loss: 0.0505 - outbin_acc: 0.9812 - val_loss: 0.0416 - val_outmap_loss: 0.0252 - val_outmap4_loss: 0.0289 - val_outmap5_loss: 0.0358 - val_outbin_loss: 0.8785 - val_outbin_acc: 0.8593
# Epoch 53/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0160 - outmap_loss: 0.0097 - outmap4_loss: 0.0214 - outmap5_loss: 0.0334 - outbin_loss: 0.0405 - outbin_acc: 0.9844Epoch 00052: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0160 - outmap_loss: 0.0097 - outmap4_loss: 0.0214 - outmap5_loss: 0.0334 - outbin_loss: 0.0406 - outbin_acc: 0.9842 - val_loss: 0.0412 - val_outmap_loss: 0.0254 - val_outmap4_loss: 0.0279 - val_outmap5_loss: 0.0356 - val_outbin_loss: 0.8386 - val_outbin_acc: 0.8491
# Epoch 54/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0161 - outmap_loss: 0.0097 - outmap4_loss: 0.0215 - outmap5_loss: 0.0334 - outbin_loss: 0.0346 - outbin_acc: 0.9885Epoch 00053: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0161 - outmap_loss: 0.0097 - outmap4_loss: 0.0215 - outmap5_loss: 0.0334 - outbin_loss: 0.0346 - outbin_acc: 0.9886 - val_loss: 0.0481 - val_outmap_loss: 0.0294 - val_outmap4_loss: 0.0303 - val_outmap5_loss: 0.0363 - val_outbin_loss: 1.0813 - val_outbin_acc: 0.8632
# Epoch 55/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0160 - outmap_loss: 0.0096 - outmap4_loss: 0.0214 - outmap5_loss: 0.0335 - outbin_loss: 0.0388 - outbin_acc: 0.9857Epoch 00054: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0160 - outmap_loss: 0.0096 - outmap4_loss: 0.0214 - outmap5_loss: 0.0335 - outbin_loss: 0.0395 - outbin_acc: 0.9855 - val_loss: 0.0429 - val_outmap_loss: 0.0259 - val_outmap4_loss: 0.0282 - val_outmap5_loss: 0.0363 - val_outbin_loss: 0.9524 - val_outbin_acc: 0.8414
# Epoch 56/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0161 - outmap_loss: 0.0098 - outmap4_loss: 0.0215 - outmap5_loss: 0.0334 - outbin_loss: 0.0362 - outbin_acc: 0.9879Epoch 00055: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0161 - outmap_loss: 0.0098 - outmap4_loss: 0.0215 - outmap5_loss: 0.0334 - outbin_loss: 0.0364 - outbin_acc: 0.9878 - val_loss: 0.0440 - val_outmap_loss: 0.0269 - val_outmap4_loss: 0.0285 - val_outmap5_loss: 0.0358 - val_outbin_loss: 0.9552 - val_outbin_acc: 0.8760
# Epoch 57/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0161 - outmap_loss: 0.0097 - outmap4_loss: 0.0215 - outmap5_loss: 0.0335 - outbin_loss: 0.0442 - outbin_acc: 0.9829Epoch 00056: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0161 - outmap_loss: 0.0097 - outmap4_loss: 0.0215 - outmap5_loss: 0.0335 - outbin_loss: 0.0442 - outbin_acc: 0.9829 - val_loss: 0.0458 - val_outmap_loss: 0.0273 - val_outmap4_loss: 0.0315 - val_outmap5_loss: 0.0367 - val_outbin_loss: 1.0352 - val_outbin_acc: 0.8734
# Epoch 58/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0156 - outmap_loss: 0.0095 - outmap4_loss: 0.0210 - outmap5_loss: 0.0331 - outbin_loss: 0.0298 - outbin_acc: 0.9884Epoch 00057: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0157 - outmap_loss: 0.0095 - outmap4_loss: 0.0210 - outmap5_loss: 0.0332 - outbin_loss: 0.0299 - outbin_acc: 0.9884 - val_loss: 0.0485 - val_outmap_loss: 0.0267 - val_outmap4_loss: 0.0301 - val_outmap5_loss: 0.0417 - val_outbin_loss: 1.3783 - val_outbin_acc: 0.7916
# Epoch 59/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0160 - outmap_loss: 0.0096 - outmap4_loss: 0.0214 - outmap5_loss: 0.0335 - outbin_loss: 0.0414 - outbin_acc: 0.9858Epoch 00058: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0160 - outmap_loss: 0.0096 - outmap4_loss: 0.0215 - outmap5_loss: 0.0336 - outbin_loss: 0.0422 - outbin_acc: 0.9856 - val_loss: 0.0464 - val_outmap_loss: 0.0282 - val_outmap4_loss: 0.0293 - val_outmap5_loss: 0.0366 - val_outbin_loss: 1.0435 - val_outbin_acc: 0.8645
# Epoch 60/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0157 - outmap_loss: 0.0096 - outmap4_loss: 0.0211 - outmap5_loss: 0.0332 - outbin_loss: 0.0278 - outbin_acc: 0.9909Epoch 00059: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0157 - outmap_loss: 0.0095 - outmap4_loss: 0.0211 - outmap5_loss: 0.0331 - outbin_loss: 0.0281 - outbin_acc: 0.9907 - val_loss: 0.0443 - val_outmap_loss: 0.0262 - val_outmap4_loss: 0.0281 - val_outmap5_loss: 0.0355 - val_outbin_loss: 1.0646 - val_outbin_acc: 0.8517

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture_final.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights_final.hdf5'))

# %%
def compute_scores_map(X, Y):
    Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X)
    
    map_threshs = np.linspace(0, 1, num=21)
    bin_threshs = np.linspace(0, 1, num=21)
    
    scores = np.zeros((len(map_threshs), len(bin_threshs)))
    for i in range(len(map_threshs)):
        for j in range(len(bin_threshs)):
            _Y_pred = Y_pred > map_threshs[i]
            
            for k in range(_Y_pred.shape[0]):
                # Clear prediction where we detect to little pixels
                if np.sum(_Y_pred[k]) < 150 or Y_pred_binary[k] < bin_threshs[j]:
                    _Y_pred[k,:] = 0
            
            scores[i, j] = utils.average_dice_coefficient(_Y_pred, Y)
    
    pl.imshow(scores, interpolation='nearest')
    pl.yticks(np.arange(len(map_threshs)) + 0.5, ['%.2f' % v for v in map_threshs])
    pl.xticks(np.arange(len(bin_threshs)) + 0.5, ['%.2f' % v for v in bin_threshs], rotation=90)
    pl.ylabel('map thresh')
    pl.xlabel('bin thresh')
    pl.colorbar()
    
    best_i, best_j = np.unravel_index(np.argmax(scores.ravel()), scores.shape)
    best_map_thresh = map_threshs[best_i]
    best_bin_thresh = bin_threshs[best_j]
    return best_map_thresh, best_bin_thresh

map_thresh, bin_thresh = compute_scores_map(X_test, Y_test)
print 'Best map_thresh=%f, bin_thresh=%f' % (map_thresh, bin_thresh)
# Out:
# Best map_thresh=0.400000, bin_thresh=0.850000

# %%
#map_thresh = 0.5
#bin_thresh = 0.7

# %%
def predict(X, map_thresh, bin_thresh):
    Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > map_thresh
    for i in range(Y_pred.shape[0]):
        if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < bin_thresh:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test, map_thresh, bin_thresh)
Y_full_pred, Y_full_pred_proba, Y_full_pred_binary = predict(X_full, map_thresh, bin_thresh)

print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "avg test set score : ", utils.average_dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
print "avg full set score : ", utils.average_dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.679346533981
# avg test set score :  0.821299803649
# full set score :  0.695166499388
# avg full set score :  0.808646145475

# %%
_ = pl.hist(Y_pred_binary)

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[40:45]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise. Note the +0.5 is pretty critical since our input is in [0,1],
    # NOT [-1,1]
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(30):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        #print grads_value.max()
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, pred44, pred88, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 15
img, pred_map = dream_output(Y_full[i])
pl.figure(figsize=(12, 4))
pl.subplot(141)
pl.imshow(X_full[i].squeeze(), cmap=cm.gray)
pl.subplot(142)
pl.imshow(Y_full[i].squeeze())
pl.subplot(143)
pl.imshow(img, cmap=cm.gray)
pl.subplot(144)
pl.imshow(pred_map.squeeze())

# %%
def dream_layer_filter(layer_name, filter_index):

    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(4):
        pl.subplot(1, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
if True:
    import cv2
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(50,50))
    
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    test_fnames = _d['test_fnames']
    # bin_thresh
    Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:],
                                                  map_thresh, bin_thresh)
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
        #imre = cv2.morphologyEx(imre, cv2.MORPH_CLOSE, kernel)
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
        
        if i % 10 == 0:
            print '\r%d / %d' % (i, len(test_fnames)),
            sys.stdout.flush()
# Out:
# 5500 / 5508

# %% [markdown]
# ## Stats on predicted masks

# %%
# on Y_full
nbp_pixels = np.sum(np.sum(np.sum(Y_full, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
pl.xlim((0, 1200))
# Out:
# (0, 1200)

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
pl.xlim((0, 1200))
# Out:
# (0, 1200)
