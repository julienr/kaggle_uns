# %% [markdown]
# ## FCNN with a boolean output indicating the likelihood of the image containing nerve

# %% [markdown]
# Trying to improve on the model that gave use 0.65

# %%
import sys
sys.path.append('../notebooks')
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):

# %%
_d = np.load('../../data_128_train.npz')
X = _d['X']
Y = _d['Y']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
print X.shape
print Y.shape
# Out:
# (5635, 128, 128)
# (5635, 128, 128)

# %%
nsamples = X.shape[0]

train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
#train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.25)
X_train = X[train_indices][:,None,:,:]
Y_train_binary = Y_binary[train_indices][:,None]
Y_train = Y[train_indices][:,None,:,:]
X_test = X[test_indices][:,None,:,:]
Y_test_binary = Y_binary[test_indices][:,None]
Y_test = Y[test_indices][:,None,:,:]

# %%
print X_train.shape
print Y_train.shape
print Y_train_binary.shape
print X_train.min(), X_train.max()

print X_test.shape
# Out:
# (5071, 1, 128, 128)
# (5071, 1, 128, 128)
# (5071, 1)
# 0.0 1.0
# (564, 1, 128, 128)

# %%
#pl.imshow(X_train[0].squeeze())
pl.imshow(Y_train[0].squeeze())
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float16'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, GaussianNoise, ZeroPadding2D
from keras.layers import BatchNormalization
from keras.layers import LeakyReLU, PReLU
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
nf = 16

input_img = Input(shape=input_shape)
x = ZeroPadding2D((1, 1))(input_img)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool1 = x = Dropout(0.25, name='pool1')(x)

x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool2 = x = Dropout(0.25, name='pool2')(x)

x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool3 = x = Dropout(0.25, name='pool3')(x)

# -- binary presence part
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool4 = x = Dropout(0.1, name='pool4')(x)

x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool5 = x = Dropout(0.1, name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(x)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# -- location map upsampling

seg5 = ZeroPadding2D((1, 1))(pool5)
seg5 = Convolution2D(1, 3, 3)(seg5)
seg5 = LeakyReLU(name='seg5')(seg5)

x = Reshape((1, 4, 4), name='outbinmap')(RepeatVector(16)(outbin))
x = merge([seg5, x], mode='mul')
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(1, 3, 3)(x)
x = UpSampling2D((2, 2))(x)


seg4 = ZeroPadding2D((1, 1))(pool4)
seg4 = Convolution2D(1, 3, 3)(seg4)
seg4 = LeakyReLU(name='seg4')(seg4)

x = merge([x, seg4], mode='concat', concat_axis=1)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(1, 3, 3)(x)
x = LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)

seg3 = ZeroPadding2D((1, 1))(pool3)
seg3 = Convolution2D(1, 3, 3)(seg3)
seg3 = LeakyReLU(name='seg3')(seg3)

x = merge([x, seg3], mode='concat', concat_axis=1)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(1, 3, 3)(x)
x = LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)


seg2 = ZeroPadding2D((1, 1))(pool2)
seg2 = Convolution2D(1, 3, 3)(seg2)
seg2 = LeakyReLU(name='seg2')(seg2)

x = merge([x, seg2], mode='concat', concat_axis=1)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(1, 3, 3)(x)
x = LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)


seg1 = ZeroPadding2D((1, 1))(pool1)
seg1 = Convolution2D(1, 3, 3)(seg1)
seg1 = LeakyReLU(name='seg1')(seg1)

x = merge([x, seg1], mode='concat', concat_axis=1)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(1, 3, 3)(x)
x = LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)

# Flatten across filters
#x = Convolution2D(1, 3, 3, border_mode='same')(x)
#x = LeakyReLU()(x)

outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
optimizer='adam'
#optimizer=sgd
#optimizer=rmsprop

model.compile(optimizer=optimizer, loss='binary_crossentropy',
              loss_weights=[1., 0.01], metrics=['accuracy'])

# %%
print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)               (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# zeropadding2d_1 (ZeroPadding2D)    (None, 1, 130, 130) 0           input_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)    (None, 16, 128, 128)160         zeropadding2d_1[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_1 (LeakyReLU)            (None, 16, 128, 128)0           convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_2 (ZeroPadding2D)    (None, 16, 130, 130)0           leakyrelu_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)    (None, 16, 128, 128)2320        zeropadding2d_2[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_2 (LeakyReLU)            (None, 16, 128, 128)0           convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_1 (MaxPooling2D)      (None, 16, 64, 64)  0           leakyrelu_2[0][0]
# ____________________________________________________________________________________________________
# pool1 (Dropout)                    (None, 16, 64, 64)  0           maxpooling2d_1[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_3 (ZeroPadding2D)    (None, 16, 66, 66)  0           pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)    (None, 16, 64, 64)  2320        zeropadding2d_3[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_3 (LeakyReLU)            (None, 16, 64, 64)  0           convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_4 (ZeroPadding2D)    (None, 16, 66, 66)  0           leakyrelu_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)    (None, 16, 64, 64)  2320        zeropadding2d_4[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_4 (LeakyReLU)            (None, 16, 64, 64)  0           convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_2 (MaxPooling2D)      (None, 16, 32, 32)  0           leakyrelu_4[0][0]
# ____________________________________________________________________________________________________
# pool2 (Dropout)                    (None, 16, 32, 32)  0           maxpooling2d_2[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_5 (ZeroPadding2D)    (None, 16, 34, 34)  0           pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)    (None, 16, 32, 32)  2320        zeropadding2d_5[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_5 (LeakyReLU)            (None, 16, 32, 32)  0           convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_6 (ZeroPadding2D)    (None, 16, 34, 34)  0           leakyrelu_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_6 (Convolution2D)    (None, 16, 32, 32)  2320        zeropadding2d_6[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_6 (LeakyReLU)            (None, 16, 32, 32)  0           convolution2d_6[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_3 (MaxPooling2D)      (None, 16, 16, 16)  0           leakyrelu_6[0][0]
# ____________________________________________________________________________________________________
# pool3 (Dropout)                    (None, 16, 16, 16)  0           maxpooling2d_3[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_7 (ZeroPadding2D)    (None, 16, 18, 18)  0           pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_7 (Convolution2D)    (None, 16, 16, 16)  2320        zeropadding2d_7[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_7 (LeakyReLU)            (None, 16, 16, 16)  0           convolution2d_7[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_8 (ZeroPadding2D)    (None, 16, 18, 18)  0           leakyrelu_7[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8 (Convolution2D)    (None, 16, 16, 16)  2320        zeropadding2d_8[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_8 (LeakyReLU)            (None, 16, 16, 16)  0           convolution2d_8[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_4 (MaxPooling2D)      (None, 16, 8, 8)    0           leakyrelu_8[0][0]
# ____________________________________________________________________________________________________
# pool4 (Dropout)                    (None, 16, 8, 8)    0           maxpooling2d_4[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_9 (ZeroPadding2D)    (None, 16, 10, 10)  0           pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_9 (Convolution2D)    (None, 16, 8, 8)    2320        zeropadding2d_9[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_9 (LeakyReLU)            (None, 16, 8, 8)    0           convolution2d_9[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_5 (MaxPooling2D)      (None, 16, 4, 4)    0           leakyrelu_9[0][0]
# ____________________________________________________________________________________________________
# pool5 (Dropout)                    (None, 16, 4, 4)    0           maxpooling2d_5[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)                (None, 256)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                    (None, 32)          8224        flatten_1[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_10 (LeakyReLU)           (None, 32)          0           dense_1[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                    (None, 16)          528         leakyrelu_10[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_11 (LeakyReLU)           (None, 16)          0           dense_2[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_11[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_10 (ZeroPadding2D)   (None, 16, 6, 6)    0           pool5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_10 (Convolution2D)   (None, 1, 4, 4)     145         zeropadding2d_10[0][0]
# ____________________________________________________________________________________________________
# repeatvector_1 (RepeatVector)      (None, 16, 1)       0           outbin[0][0]
# ____________________________________________________________________________________________________
# outbinmap (Reshape)                (None, 1, 4, 4)     0           repeatvector_1[0][0]
# ____________________________________________________________________________________________________
# seg5 (LeakyReLU)                   (None, 1, 4, 4)     0           convolution2d_10[0][0]
# ____________________________________________________________________________________________________
# merge_1 (Merge)                    (None, 1, 4, 4)     0           seg5[0][0]
#                                                                    outbinmap[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_11 (ZeroPadding2D)   (None, 1, 6, 6)     0           merge_1[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_12 (ZeroPadding2D)   (None, 16, 10, 10)  0           pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_11 (Convolution2D)   (None, 1, 4, 4)     10          zeropadding2d_11[0][0]
# ____________________________________________________________________________________________________
# convolution2d_12 (Convolution2D)   (None, 1, 8, 8)     145         zeropadding2d_12[0][0]
# ____________________________________________________________________________________________________
# seg4 (LeakyReLU)                   (None, 1, 8, 8)     0           convolution2d_12[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_1 (UpSampling2D)      (None, 1, 8, 8)     0           convolution2d_11[0][0]
# ____________________________________________________________________________________________________
# merge_2 (Merge)                    (None, 2, 8, 8)     0           upsampling2d_1[0][0]
#                                                                    seg4[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_13 (ZeroPadding2D)   (None, 2, 10, 10)   0           merge_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_13 (Convolution2D)   (None, 1, 8, 8)     19          zeropadding2d_13[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_14 (ZeroPadding2D)   (None, 16, 18, 18)  0           pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_14 (Convolution2D)   (None, 1, 16, 16)   145         zeropadding2d_14[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_12 (LeakyReLU)           (None, 1, 8, 8)     0           convolution2d_13[0][0]
# ____________________________________________________________________________________________________
# seg3 (LeakyReLU)                   (None, 1, 16, 16)   0           convolution2d_14[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_2 (UpSampling2D)      (None, 1, 16, 16)   0           leakyrelu_12[0][0]
# ____________________________________________________________________________________________________
# merge_3 (Merge)                    (None, 2, 16, 16)   0           upsampling2d_2[0][0]
#                                                                    seg3[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_15 (ZeroPadding2D)   (None, 2, 18, 18)   0           merge_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_15 (Convolution2D)   (None, 1, 16, 16)   19          zeropadding2d_15[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_16 (ZeroPadding2D)   (None, 16, 34, 34)  0           pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_16 (Convolution2D)   (None, 1, 32, 32)   145         zeropadding2d_16[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_13 (LeakyReLU)           (None, 1, 16, 16)   0           convolution2d_15[0][0]
# ____________________________________________________________________________________________________
# seg2 (LeakyReLU)                   (None, 1, 32, 32)   0           convolution2d_16[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_3 (UpSampling2D)      (None, 1, 32, 32)   0           leakyrelu_13[0][0]
# ____________________________________________________________________________________________________
# merge_4 (Merge)                    (None, 2, 32, 32)   0           upsampling2d_3[0][0]
#                                                                    seg2[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_17 (ZeroPadding2D)   (None, 2, 34, 34)   0           merge_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_17 (Convolution2D)   (None, 1, 32, 32)   19          zeropadding2d_17[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_18 (ZeroPadding2D)   (None, 16, 66, 66)  0           pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_18 (Convolution2D)   (None, 1, 64, 64)   145         zeropadding2d_18[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_14 (LeakyReLU)           (None, 1, 32, 32)   0           convolution2d_17[0][0]
# ____________________________________________________________________________________________________
# seg1 (LeakyReLU)                   (None, 1, 64, 64)   0           convolution2d_18[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_4 (UpSampling2D)      (None, 1, 64, 64)   0           leakyrelu_14[0][0]
# ____________________________________________________________________________________________________
# merge_5 (Merge)                    (None, 2, 64, 64)   0           upsampling2d_4[0][0]
#                                                                    seg1[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_19 (ZeroPadding2D)   (None, 2, 66, 66)   0           merge_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_19 (Convolution2D)   (None, 1, 64, 64)   19          zeropadding2d_19[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_15 (LeakyReLU)           (None, 1, 64, 64)   0           convolution2d_19[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_5 (UpSampling2D)      (None, 1, 128, 128) 0           leakyrelu_15[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 10          upsampling2d_5[0][0]
# ====================================================================================================
# Total params: 28310
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {'outmap': Y_train, 'outbin': Y_train_binary},
        batch_size=64,
        validation_data=(X_test, {'outmap': Y_test, 'outbin': Y_test_binary}),
        nb_epoch=60,# 40 + 10 + 10 + 5 + 5
        verbose=2,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    pl.plot(history.history['loss'], label='train loss')
    pl.plot(history.history['val_loss'], c='g', label='val loss')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(open(os.path.join(model_dir, 'architecture.json')).read())
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adagrad', loss='mse')
# Out:
# Train on 5071 samples, validate on 564 samples
# Epoch 1/60
# Epoch 00000: val_loss improved from inf to 0.11184, saving model to weights.hdf5
# 37s - loss: 0.1651 - outmap_loss: 0.1581 - outbin_loss: 0.7020 - outmap_acc: 0.7776 - outbin_acc: 0.5772 - val_loss: 0.1118 - val_outmap_loss: 0.1049 - val_outbin_loss: 0.6908 - val_outmap_acc: 0.8460 - val_outbin_acc: 0.5177
# Epoch 2/60
# Epoch 00001: val_loss improved from 0.11184 to 0.08436, saving model to weights.hdf5
# 36s - loss: 0.0939 - outmap_loss: 0.0869 - outbin_loss: 0.7044 - outmap_acc: 0.7974 - outbin_acc: 0.5669 - val_loss: 0.0844 - val_outmap_loss: 0.0776 - val_outbin_loss: 0.6731 - val_outmap_acc: 0.8230 - val_outbin_acc: 0.5887
# Epoch 3/60
# Epoch 00002: val_loss improved from 0.08436 to 0.06663, saving model to weights.hdf5
# 36s - loss: 0.0697 - outmap_loss: 0.0629 - outbin_loss: 0.6725 - outmap_acc: 0.7206 - outbin_acc: 0.5896 - val_loss: 0.0666 - val_outmap_loss: 0.0599 - val_outbin_loss: 0.6691 - val_outmap_acc: 0.6026 - val_outbin_acc: 0.5957
# Epoch 4/60
# Epoch 00003: val_loss improved from 0.06663 to 0.05383, saving model to weights.hdf5
# 37s - loss: 0.0572 - outmap_loss: 0.0505 - outbin_loss: 0.6683 - outmap_acc: 0.5179 - outbin_acc: 0.5926 - val_loss: 0.0538 - val_outmap_loss: 0.0472 - val_outbin_loss: 0.6645 - val_outmap_acc: 0.3548 - val_outbin_acc: 0.6046
# Epoch 5/60
# Epoch 00004: val_loss improved from 0.05383 to 0.05056, saving model to weights.hdf5
# 36s - loss: 0.0522 - outmap_loss: 0.0456 - outbin_loss: 0.6628 - outmap_acc: 0.4250 - outbin_acc: 0.6007 - val_loss: 0.0506 - val_outmap_loss: 0.0439 - val_outbin_loss: 0.6668 - val_outmap_acc: 0.2270 - val_outbin_acc: 0.6011
# Epoch 6/60
# Epoch 00005: val_loss improved from 0.05056 to 0.04920, saving model to weights.hdf5
# 39s - loss: 0.0286 - outmap_loss: 0.0244 - outbin_loss: 0.4218 - outmap_acc: 0.2297 - outbin_acc: 0.8050 - val_loss: 0.0296 - val_outmap_loss: 0.0249 - val_outbin_loss: 0.4646 - val_outmap_acc: 0.2710 - val_outbin_acc: 0.7784
# Epoch 57/60
# Epoch 00056: val_loss improved from 0.02905 to 0.02902, saving model to weights.hdf5
# 38s - loss: 0.0285 - outmap_loss: 0.0243 - outbin_loss: 0.4194 - outmap_acc: 0.2757 - outbin_acc: 0.8062 - val_loss: 0.0290 - val_outmap_loss: 0.0244 - val_outbin_loss: 0.4617 - val_outmap_acc: 0.2605 - val_outbin_acc: 0.7695
# Epoch 58/60
# Epoch 00057: val_loss did not improve
# 24s - loss: 0.0282 - outmap_loss: 0.0240 - outbin_loss: 0.4202 - outmap_acc: 0.2248 - outbin_acc: 0.8095 - val_loss: 0.0294 - val_outmap_loss: 0.0247 - val_outbin_loss: 0.4687 - val_outmap_acc: 0.1748 - val_outbin_acc: 0.7695
# Epoch 59/60
# Epoch 00058: val_loss improved from 0.02902 to 0.02874, saving model to weights.hdf5
# 18s - loss: 0.0281 - outmap_loss: 0.0240 - outbin_loss: 0.4145 - outmap_acc: 0.2737 - outbin_acc: 0.8099 - val_loss: 0.0287 - val_outmap_loss: 0.0243 - val_outbin_loss: 0.4426 - val_outmap_acc: 0.2325 - val_outbin_acc: 0.7872
# Epoch 60/60
# Epoch 00059: val_loss did not improve
# 18s - loss: 0.0279 - outmap_loss: 0.0238 - outbin_loss: 0.4122 - outmap_acc: 0.2572 - outbin_acc: 0.8060 - val_loss: 0.0317 - val_outmap_loss: 0.0270 - val_outbin_loss: 0.4671 - val_outmap_acc: 0.3102 - val_outbin_acc: 0.7801

# %%
if False:
    model_dir = '../models/fcnn_128_multiout'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights.h5'))

# %%
import skimage.measure as measure

def predict(X):
    Y_pred, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > 0.3
    for i in range(Y_pred.shape[0]):
        # Clear prediction where we detect to little pixels
        # Figure it out by
        # pl.hist(np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1))
        if np.sum(Y_pred[i]) < 0 or Y_pred_binary[i] < 0.0:
            Y_pred[i,:] = 0
            
        avg_zone_proba = np.mean(Y_pred_proba[i][Y_pred[i] == 1])
        if avg_zone_proba < 0.0:
            Y_pred[i,:] = 0
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test)
print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
# Out:
# test set score :  0.586795355994
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[-450:-445]:
#for i in lowest[215:220]:
for i in lowest[10:15]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    
    #blob_proba = np.mean(Y_pred_proba[i][Y_pred[i] == 1])
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Visualize filters
#
# See http://blog.keras.io/how-convolutional-neural-networks-see-the-world.html

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

layer_name = 'pool5'
filter_index = 0

# build a loss function that maximizes the activation
# of the nth filter of the layer considered
layer_output = layer_dict[layer_name].output
loss = K.mean(layer_output[:, filter_index, :, :])

# compute the gradient of the input picture wrt this loss
grads = K.gradients(loss, input_img)[0]

# normalization trick: we normalize the gradient
grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

# this function returns the loss and grads given the input picture
iterate = K.function([K.learning_phase(), input_img], [loss, grads])

# we start from a gray image with some noise
input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
input_img_data = input_img_data.astype(np.float32)

orig_img = input_img_data.copy()

# run gradient ascent for 20 steps
step = 0.1
for i in range(20):
    # 0 is to disable training_phase
    loss_value, grads_value = iterate([0, input_img_data])
    input_img_data += grads_value * step
    
img = input_img_data[0].squeeze()
#img = deprocess_image(img)

pl.figure(figsize=(12, 5))
pl.subplot(121)
pl.imshow(orig_img.squeeze())
pl.subplot(122)
pl.imshow(img)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
_d = np.load('../../data_128_test.npz')
X_submit = _d['X']
test_fnames = _d['test_fnames']
Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:])

# %%
#pl.imshow(Y_pred_proba[50].squeeze())

# %%
OUTDIR='../../preds'
if os.path.exists(OUTDIR):
    shutil.rmtree(OUTDIR)
utils.mkdir_p(OUTDIR)

for i in range(Y_pred.shape[0]):
    imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
    basename = os.path.splitext(test_fnames[i])[0]
    cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
