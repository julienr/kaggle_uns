# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']
X_pids = _d['pids']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
print X.dtype
print Y.dtype
# Out:
# (3906, 128, 128)
# (3906, 128, 128)
# float32
# float32

# %%
if False:
    # Split patients in train/test
    train_pids, test_pids = train_test_split(np.unique(X_pids), test_size=0.1)
    print train_pids
    print test_pids
    
    train_indices = np.flatnonzero(np.in1d(X_pids, train_pids))
    test_indices = np.flatnonzero(np.in1d(X_pids, test_pids))
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]
else:
    nsamples = X.shape[0]

    #train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]

# %%
import skimage.transform as sktransf

def rand_float(rng):
    return rng[0] + np.random.random() * (rng[1] - rng[0])

def generate_image(X_img, Y_img, angle_range=None, zoom_range=None, shear_range=None, horiz_shift_range=None,
                   vert_shift_range=None):
    """
    Randomly shift an image by resizing and then random croping
    the resized image
    """
    if angle_range is None:
        angle_range = (-5, 5)
    if zoom_range is None:
        zoom_range = (0.8, 1.2)
    if shear_range is None:
        shear_range = (-5, 5) # shear angle in degrees
    if horiz_shift_range is None:
        horiz_shift_range = (-5, 5)
    if vert_shift_range is None:
        vert_shift_range = (-5, 5)
    inshape = X_img.shape
    
    X2 = X_img.copy()
    Y2 = Y_img.copy()
    
    # -- random rotation
    angle = np.deg2rad(rand_float(angle_range))
    zoom = rand_float(zoom_range)
    shear = np.deg2rad(rand_float(shear_range))
    horiz_shift = rand_float(horiz_shift_range)
    vert_shift = rand_float(vert_shift_range)
    
    tform = sktransf.AffineTransform(
        scale=(zoom, zoom),
        rotation=angle,
        shear=shear,
        translation=(horiz_shift, vert_shift)
    )
    X2 = sktransf.warp(X2, tform, order=5, mode='edge')
    Y2 = sktransf.warp(Y2, tform, order=1)

    # gaussian noise
    #noise_scale = rand_float((0, 0.1))
    #X2 += np.random.normal(scale=noise_scale, size=X2.shape)
    Y2 = Y2 > 0.5
    return X2[None,:,:].astype(np.float32), Y2[None,:,:].astype(np.float32)

X_train_augmented = []
Y_train_augmented = []
for i in range(X_train.shape[0]):
    if i % 10 == 0:
        print '\r%d / %d' % (i, X_train.shape[0]),
        sys.stdout.flush()
    X_train_augmented.append(X_train[i])
    Y_train_augmented.append(Y_train[i])
    for j in range(2):
        X2, Y2 = generate_image(X_train[i].squeeze(), Y_train[i].squeeze())
        X_train_augmented.append(X2)
        Y_train_augmented.append(Y2)
# Out:
# 3510 / 3515

# %%
X_train = np.array(X_train_augmented, dtype=np.float32)
Y_train = np.array(Y_train_augmented, dtype=np.float32)

Y_train_binary = np.sum(np.sum(Y_train.squeeze(), axis=2), axis=1) > 0
Y_train_binary = Y_train_binary.astype(np.float32)
Y_train_binary = Y_train_binary[:,None]

# %%
print X_train.shape
print Y_train.shape
print X_test.shape
print X_train.min(), X_train.max()
# Out:
# (10545, 1, 128, 128)
# (10545, 1, 128, 128)
# (391, 1, 128, 128)
# 0.0 1.0

# %%
import cv2
def _resize(Y, outshape):
    return cv2.resize(Y.squeeze(), outshape, interpolation=cv2.INTER_AREA)[None, :, :]
Y_train_88 = np.array([_resize(img, (8, 8)) for img in Y_train])
Y_test_88 = np.array([_resize(img, (8, 8)) for img in Y_test])
Y_train_44 = np.array([_resize(img, (4, 4)) for img in Y_train])
Y_test_44 = np.array([_resize(img, (4, 4)) for img in Y_test])

# %%
with_bp = np.flatnonzero(np.sum(np.sum(np.sum(Y_train, axis=1), axis=1), axis=1))

# %%
for bpi in range(11, 14):
    i = with_bp[bpi]
    pl.figure(figsize=(16, 4))
    pl.subplot(141)
    pl.imshow(X_train[i].squeeze())
    pl.subplot(142)
    pl.imshow(Y_train[i].squeeze())
    pl.subplot(143)
    pl.imshow(Y_train_88[i].squeeze(), interpolation='nearest')
    pl.colorbar()
    pl.subplot(144)
    pl.imshow(Y_train_44[i].squeeze(), interpolation='nearest')
    pl.colorbar()

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float32'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense
from keras.layers import LeakyReLU, BatchNormalization
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
import keras.backend as K
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
from keras.layers import Layer, InputSpec
import keras.initializations
import keras.backend as K

class Maxout2D(Layer):
    def __init__(self, output_dim, cardinality, init='glorot_uniform', **kwargs):
        super(Maxout2D, self).__init__(**kwargs)
        # the k of the maxout paper
        self.cardinality = cardinality
        # the m of the maxout paper
        self.output_dim = output_dim
        self.init = keras.initializations.get(init)
    
    def build(self, input_shape):
        self.input_dim = input_shape[1]
        self.input_spec = [InputSpec(dtype=K.floatx(),
                                     shape=(None, input_shape[1], input_shape[2], input_shape[3]))]
        self.W = self.init((self.input_dim, self.output_dim, self.cardinality),
                           name='{}_W'.format(self.name))
        self.b = K.zeros((self.output_dim, self.cardinality))
        self.trainable_weights = [self.W, self.b]
              
    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        # flatten the spatial dimensions
        flat_x = K.reshape(x, (-1, input_shape[1], input_shape[2] * input_shape[3]))
        output = K.dot(
            K.permute_dimensions(flat_x, (0, 2, 1)),
            K.permute_dimensions(self.W, (1, 0, 2))
        )
        output += K.reshape(self.b, (1, 1, self.output_dim, self.cardinality))
        output = K.max(output, axis=3)
        output = output.transpose(0, 2, 1)
        output = K.reshape(output, (-1, self.output_dim, input_shape[2], input_shape[3]))
        return output
    
    def get_output_shape_for(self, input_shape):
        return (input_shape[0], self.output_dim, input_shape[2], input_shape[3])
    
    def get_config(self):
        config = {
            'output_dim': self.output_dim,
            'cardinality': self.cardinality
        }
        base_config = super(Maxout2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
input_img = x = Input(shape=input_shape, name='input_img')
x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(input_img)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool1 = x = MaxPooling2D((2, 2), name='pool1')(x)

x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool2 = x = MaxPooling2D((2, 2), name='pool2')(x)

x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool3 = x = MaxPooling2D((2, 2), name='pool3')(x)

# -- binary presence part
x = Dropout(0.25)(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

x = Dropout(0.25)(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(pool5)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# turn pool4 and 5 into classification map
outmap4 = Convolution2D(1, 3, 3, border_mode='same', activation='sigmoid', name='outmap4')(pool4)

outmap5 = Convolution2D(1, 3, 3, border_mode='same', activation='sigmoid', name='outmap5')(pool5)

# upsample the classif map
x = merge([
        UpSampling2D((2, 2))(outmap4),
        UpSampling2D((4, 4))(outmap5),
        pool3
    ], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
x = UpSampling2D((2, 2))(x)

x = Dropout(0.25)(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outmap4, outmap5, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
metrics={'outbin': 'accuracy'}
model.compile(optimizer='adam', loss='binary_crossentropy',
              loss_weights=[1., 0.2, 0.05, 0.01], metrics=metrics)

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)    (None, 32, 128, 128)320         input_img[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)    (None, 16, 128, 128)4624        convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# maxout2d_1 (Maxout2D)              (None, 16, 128, 128)544         convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)               (None, 16, 64, 64)  0           maxout2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)                (None, 16, 64, 64)  0           pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)    (None, 32, 64, 64)  4640        dropout_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)    (None, 16, 64, 64)  4624        convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# maxout2d_2 (Maxout2D)              (None, 16, 64, 64)  544         convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)               (None, 16, 32, 32)  0           maxout2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)                (None, 16, 32, 32)  0           pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)    (None, 32, 32, 32)  4640        dropout_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_6 (Convolution2D)    (None, 16, 32, 32)  4624        convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# maxout2d_3 (Maxout2D)              (None, 16, 32, 32)  544         convolution2d_6[0][0]
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)               (None, 16, 16, 16)  0           maxout2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)                (None, 16, 16, 16)  0           pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_7 (Convolution2D)    (None, 16, 16, 16)  2320        dropout_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8 (Convolution2D)    (None, 16, 16, 16)  2320        convolution2d_7[0][0]
# ____________________________________________________________________________________________________
# maxout2d_4 (Maxout2D)              (None, 16, 16, 16)  544         convolution2d_8[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)               (None, 16, 8, 8)    0           maxout2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)                (None, 16, 8, 8)    0           pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_9 (Convolution2D)    (None, 16, 8, 8)    2320        dropout_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_10 (Convolution2D)   (None, 16, 8, 8)    2320        convolution2d_9[0][0]
# ____________________________________________________________________________________________________
# maxout2d_5 (Maxout2D)              (None, 16, 8, 8)    544         convolution2d_10[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)               (None, 16, 4, 4)    0           maxout2d_5[0][0]
# ____________________________________________________________________________________________________
# outmap4 (Convolution2D)            (None, 1, 8, 8)     145         pool4[0][0]
# ____________________________________________________________________________________________________
# outmap5 (Convolution2D)            (None, 1, 4, 4)     145         pool5[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_1 (UpSampling2D)      (None, 1, 16, 16)   0           outmap4[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_2 (UpSampling2D)      (None, 1, 16, 16)   0           outmap5[0][0]
# ____________________________________________________________________________________________________
# merge_1 (Merge)                    (None, 18, 16, 16)  0           upsampling2d_1[0][0]
#                                                                    upsampling2d_2[0][0]
#                                                                    pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_11 (Convolution2D)   (None, 16, 16, 16)  2608        merge_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_12 (Convolution2D)   (None, 16, 16, 16)  2320        convolution2d_11[0][0]
# ____________________________________________________________________________________________________
# maxout2d_6 (Maxout2D)              (None, 16, 16, 16)  544         convolution2d_12[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_3 (UpSampling2D)      (None, 16, 32, 32)  0           maxout2d_6[0][0]
# ____________________________________________________________________________________________________
# merge_2 (Merge)                    (None, 32, 32, 32)  0           upsampling2d_3[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_13 (Convolution2D)   (None, 16, 32, 32)  4624        merge_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_14 (Convolution2D)   (None, 16, 32, 32)  2320        convolution2d_13[0][0]
# ____________________________________________________________________________________________________
# maxout2d_7 (Maxout2D)              (None, 16, 32, 32)  544         convolution2d_14[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_4 (UpSampling2D)      (None, 16, 64, 64)  0           maxout2d_7[0][0]
# ____________________________________________________________________________________________________
# merge_3 (Merge)                    (None, 32, 64, 64)  0           upsampling2d_4[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_15 (Convolution2D)   (None, 16, 64, 64)  4624        merge_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_16 (Convolution2D)   (None, 16, 64, 64)  2320        convolution2d_15[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)                (None, 256)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# maxout2d_8 (Maxout2D)              (None, 16, 64, 64)  544         convolution2d_16[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                    (None, 32)          8224        flatten_1[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_5 (UpSampling2D)      (None, 16, 128, 128)0           maxout2d_8[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)                (None, 16, 128, 128)0           upsampling2d_5[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_1 (LeakyReLU)            (None, 32)          0           dense_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_17 (Convolution2D)   (None, 8, 128, 128) 1160        dropout_6[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                    (None, 16)          528         leakyrelu_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_18 (Convolution2D)   (None, 8, 128, 128) 584         convolution2d_17[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_2 (LeakyReLU)            (None, 16)          0           dense_2[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_2[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 73          convolution2d_18[0][0]
# ====================================================================================================
# Total params: 66796
# ____________________________________________________________________________________________________

# %%
from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

from keras.utils.visualize_util import plot
plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {
            'outmap': Y_train,
            'outmap4' : Y_train_88,
            'outmap5' : Y_train_44,
            'outbin': Y_train_binary
        },
        batch_size=64,
        validation_data=(X_test, {
                'outmap': Y_test,
                'outmap4' : Y_test_88,
                'outmap5' : Y_test_44,
                'outbin': Y_test_binary
        }),
        nb_epoch=60,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    
    pl.figure()
    pl.plot(history.history['outmap_loss'], label='train loss')
    pl.plot(history.history['val_outmap_loss'], c='g', label='val loss')
    pl.legend()

    pl.figure()
    pl.plot(history.history['outbin_acc'], label='train acc')
    pl.plot(history.history['val_outbin_acc'], c='g', label='val acc')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
                custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.01])
    
    print_summary(model.layers)
# Out:
# Train on 10545 samples, validate on 391 samples
# Epoch 1/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1451 - outmap_loss: 0.1170 - outmap4_loss: 0.0787 - outmap5_loss: 0.0879 - outbin_loss: 0.7996 - outbin_acc: 0.5830Epoch 00000: val_loss improved from inf to 0.12864, saving model to weights.hdf5
# 10545/10545 [==============================] - 127s - loss: 0.1447 - outmap_loss: 0.1166 - outmap4_loss: 0.0786 - outmap5_loss: 0.0878 - outbin_loss: 0.7991 - outbin_acc: 0.5829 - val_loss: 0.1286 - val_outmap_loss: 0.0902 - val_outmap4_loss: 0.1120 - val_outmap5_loss: 0.1866 - val_outbin_loss: 0.6663 - val_outbin_acc: 0.6368
# Epoch 2/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0594 - outmap_loss: 0.0396 - outmap4_loss: 0.0506 - outmap5_loss: 0.0658 - outbin_loss: 0.6331 - outbin_acc: 0.6441Epoch 00001: val_loss improved from 0.12864 to 0.06622, saving model to weights.hdf5
# 10545/10545 [==============================] - 127s - loss: 0.0594 - outmap_loss: 0.0396 - outmap4_loss: 0.0506 - outmap5_loss: 0.0657 - outbin_loss: 0.6333 - outbin_acc: 0.6436 - val_loss: 0.0662 - val_outmap_loss: 0.0409 - val_outmap4_loss: 0.0736 - val_outmap5_loss: 0.0983 - val_outbin_loss: 0.5685 - val_outbin_acc: 0.6931
# Epoch 3/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0501 - outmap_loss: 0.0331 - outmap4_loss: 0.0420 - outmap5_loss: 0.0563 - outbin_loss: 0.5740 - outbin_acc: 0.7018Epoch 00002: val_loss did not improve
# 10545/10545 [==============================] - 128s - loss: 0.0501 - outmap_loss: 0.0331 - outmap4_loss: 0.0420 - outmap5_loss: 0.0563 - outbin_loss: 0.5742 - outbin_acc: 0.7014 - val_loss: 0.0704 - val_outmap_loss: 0.0487 - val_outmap4_loss: 0.0634 - val_outmap5_loss: 0.0706 - val_outbin_loss: 0.5423 - val_outbin_acc: 0.7519
# Epoch 4/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0453 - outmap_loss: 0.0299 - outmap4_loss: 0.0382 - outmap5_loss: 0.0508 - outbin_loss: 0.5221 - outbin_acc: 0.7459Epoch 00003: val_loss improved from 0.06622 to 0.04194, saving model to weights.hdf5
# 10545/10545 [==============================] - 128s - loss: 0.0452 - outmap_loss: 0.0298 - outmap4_loss: 0.0382 - outmap5_loss: 0.0508 - outbin_loss: 0.5215 - outbin_acc: 0.7459 - val_loss: 0.0419 - val_outmap_loss: 0.0266 - val_outmap4_loss: 0.0396 - val_outmap5_loss: 0.0590 - val_outbin_loss: 0.4442 - val_outbin_acc: 0.7980
# Epoch 5/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0420 - outmap_loss: 0.0275 - outmap4_loss: 0.0363 - outmap5_loss: 0.0475 - outbin_loss: 0.4954 - outbin_acc: 0.7651Epoch 00004: val_loss improved from 0.04194 to 0.04093, saving model to weights.hdf5
# 10545/10545 [==============================] - 128s - loss: 0.0420 - outmap_loss: 0.0274 - outmap4_loss: 0.0362 - outmap5_loss: 0.0476 - outbin_loss: 0.4954 - outbin_acc: 0.7652 - val_loss: 0.0409 - val_outmap_loss: 0.0254 - val_outmap4_loss: 0.0420 - val_outmap5_loss: 0.0567 - val_outbin_loss: 0.4283 - val_outbin_acc: 0.8261
# Epoch 6/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0400 - outmap_loss: 0.0260 - outmap4_loss: 0.0350 - outmap5_loss: 0.0459 - outbin_loss: 0.4682 - outbin_acc: 0.7799Epoch 00005: val_loss improved from 0.04093 to 0.03865, saving model to weights.hdf5
# 10545/10545 [==============================] - 128s - loss: 0.0400 - outmap_loss: 0.0260 - outmap4_loss: 0.0350 - outmap5_loss: 0.0459 - outbin_loss: 0.4680 - outbin_acc: 0.7800 - val_loss: 0.0387 - val_outmap_loss: 0.0246 - val_outmap4_loss: 0.0377 - val_outmap5_loss: 0.0513 - val_outbin_loss: 0.3954 - val_outbin_acc: 0.8491
# Epoch 7/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0387 - outmap_loss: 0.0250 - outmap4_loss: 0.0341 - outmap5_loss: 0.0454 - outbin_loss: 0.4557 - outbin_acc: 0.7857Epoch 00006: val_loss did not improve
# 10545/10545 [==============================] - 128s - loss: 0.0387 - outmap_loss: 0.0250 - outmap4_loss: 0.0342 - outmap5_loss: 0.0454 - outbin_loss: 0.4559 - outbin_acc: 0.7854 - val_loss: 0.0390 - val_outmap_loss: 0.0246 - val_outmap4_loss: 0.0392 - val_outmap5_loss: 0.0476 - val_outbin_loss: 0.4207 - val_outbin_acc: 0.8184
# Epoch 8/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0386 - outmap_loss: 0.0251 - outmap4_loss: 0.0340 - outmap5_loss: 0.0452 - outbin_loss: 0.4494 - outbin_acc: 0.7914Epoch 00007: val_loss improved from 0.03865 to 0.03661, saving model to weights.hdf5
# 10545/10545 [==============================] - 128s - loss: 0.0386 - outmap_loss: 0.0251 - outmap4_loss: 0.0340 - outmap5_loss: 0.0451 - outbin_loss: 0.4493 - outbin_acc: 0.7915 - val_loss: 0.0366 - val_outmap_loss: 0.0241 - val_outmap4_loss: 0.0327 - val_outmap5_loss: 0.0471 - val_outbin_loss: 0.3651 - val_outbin_acc: 0.8440
# Epoch 9/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0369 - outmap_loss: 0.0238 - outmap4_loss: 0.0330 - outmap5_loss: 0.0442 - outbin_loss: 0.4283 - outbin_acc: 0.8067Epoch 00008: val_loss improved from 0.03661 to 0.03491, saving model to weights.hdf5
# 10545/10545 [==============================] - 128s - loss: 0.0369 - outmap_loss: 0.0238 - outmap4_loss: 0.0331 - outmap5_loss: 0.0442 - outbin_loss: 0.4288 - outbin_acc: 0.8069 - val_loss: 0.0349 - val_outmap_loss: 0.0224 - val_outmap4_loss: 0.0332 - val_outmap5_loss: 0.0476 - val_outbin_loss: 0.3495 - val_outbin_acc: 0.8619
# Epoch 10/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0361 - outmap_loss: 0.0232 - outmap4_loss: 0.0327 - outmap5_loss: 0.0437 - outbin_loss: 0.4187 - outbin_acc: 0.8134Epoch 00009: val_loss did not improve
# 10545/10545 [==============================] - 132s - loss: 0.0361 - outmap_loss: 0.0232 - outmap4_loss: 0.0327 - outmap5_loss: 0.0437 - outbin_loss: 0.4187 - outbin_acc: 0.8130 - val_loss: 0.0355 - val_outmap_loss: 0.0233 - val_outmap4_loss: 0.0324 - val_outmap5_loss: 0.0453 - val_outbin_loss: 0.3431 - val_outbin_acc: 0.8568
# Epoch 11/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0357 - outmap_loss: 0.0228 - outmap4_loss: 0.0325 - outmap5_loss: 0.0432 - outbin_loss: 0.4235 - outbin_acc: 0.8095Epoch 00010: val_loss improved from 0.03491 to 0.03345, saving model to weights.hdf5
# 10545/10545 [==============================] - 133s - loss: 0.0357 - outmap_loss: 0.0228 - outmap4_loss: 0.0325 - outmap5_loss: 0.0431 - outbin_loss: 0.4233 - outbin_acc: 0.8094 - val_loss: 0.0335 - val_outmap_loss: 0.0213 - val_outmap4_loss: 0.0327 - val_outmap5_loss: 0.0423 - val_outbin_loss: 0.3452 - val_outbin_acc: 0.8542
# Epoch 12/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0346 - outmap_loss: 0.0220 - outmap4_loss: 0.0320 - outmap5_loss: 0.0433 - outbin_loss: 0.4020 - outbin_acc: 0.8206Epoch 00011: val_loss improved from 0.03345 to 0.03195, saving model to weights.hdf5
# 10545/10545 [==============================] - 133s - loss: 0.0346 - outmap_loss: 0.0220 - outmap4_loss: 0.0320 - outmap5_loss: 0.0433 - outbin_loss: 0.4030 - outbin_acc: 0.8202 - val_loss: 0.0320 - val_outmap_loss: 0.0207 - val_outmap4_loss: 0.0297 - val_outmap5_loss: 0.0427 - val_outbin_loss: 0.3177 - val_outbin_acc: 0.8593
# Epoch 13/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0341 - outmap_loss: 0.0217 - outmap4_loss: 0.0318 - outmap5_loss: 0.0425 - outbin_loss: 0.3945 - outbin_acc: 0.8250Epoch 00012: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0341 - outmap_loss: 0.0216 - outmap4_loss: 0.0318 - outmap5_loss: 0.0424 - outbin_loss: 0.3942 - outbin_acc: 0.8251 - val_loss: 0.0322 - val_outmap_loss: 0.0204 - val_outmap4_loss: 0.0308 - val_outmap5_loss: 0.0443 - val_outbin_loss: 0.3465 - val_outbin_acc: 0.8721
# Epoch 14/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0335 - outmap_loss: 0.0212 - outmap4_loss: 0.0316 - outmap5_loss: 0.0426 - outbin_loss: 0.3831 - outbin_acc: 0.8276Epoch 00013: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0335 - outmap_loss: 0.0213 - outmap4_loss: 0.0316 - outmap5_loss: 0.0426 - outbin_loss: 0.3829 - outbin_acc: 0.8277 - val_loss: 0.0320 - val_outmap_loss: 0.0206 - val_outmap4_loss: 0.0300 - val_outmap5_loss: 0.0397 - val_outbin_loss: 0.3352 - val_outbin_acc: 0.8619
# Epoch 15/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0327 - outmap_loss: 0.0206 - outmap4_loss: 0.0312 - outmap5_loss: 0.0416 - outbin_loss: 0.3745 - outbin_acc: 0.8370Epoch 00014: val_loss improved from 0.03195 to 0.03122, saving model to weights.hdf5
# 10545/10545 [==============================] - 133s - loss: 0.0327 - outmap_loss: 0.0206 - outmap4_loss: 0.0311 - outmap5_loss: 0.0416 - outbin_loss: 0.3747 - outbin_acc: 0.8370 - val_loss: 0.0312 - val_outmap_loss: 0.0198 - val_outmap4_loss: 0.0300 - val_outmap5_loss: 0.0417 - val_outbin_loss: 0.3301 - val_outbin_acc: 0.8517
# Epoch 16/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0326 - outmap_loss: 0.0206 - outmap4_loss: 0.0311 - outmap5_loss: 0.0419 - outbin_loss: 0.3657 - outbin_acc: 0.8439Epoch 00015: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0326 - outmap_loss: 0.0206 - outmap4_loss: 0.0311 - outmap5_loss: 0.0419 - outbin_loss: 0.3653 - outbin_acc: 0.8442 - val_loss: 0.0323 - val_outmap_loss: 0.0210 - val_outmap4_loss: 0.0300 - val_outmap5_loss: 0.0396 - val_outbin_loss: 0.3281 - val_outbin_acc: 0.8696
# Epoch 17/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0323 - outmap_loss: 0.0204 - outmap4_loss: 0.0308 - outmap5_loss: 0.0419 - outbin_loss: 0.3632 - outbin_acc: 0.8417Epoch 00016: val_loss improved from 0.03122 to 0.03097, saving model to weights.hdf5
# 10545/10545 [==============================] - 133s - loss: 0.0323 - outmap_loss: 0.0204 - outmap4_loss: 0.0308 - outmap5_loss: 0.0418 - outbin_loss: 0.3633 - outbin_acc: 0.8418 - val_loss: 0.0310 - val_outmap_loss: 0.0196 - val_outmap4_loss: 0.0293 - val_outmap5_loss: 0.0399 - val_outbin_loss: 0.3526 - val_outbin_acc: 0.8491
# Epoch 18/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0319 - outmap_loss: 0.0200 - outmap4_loss: 0.0306 - outmap5_loss: 0.0420 - outbin_loss: 0.3663 - outbin_acc: 0.8415Epoch 00017: val_loss improved from 0.03097 to 0.03036, saving model to weights.hdf5
# 10545/10545 [==============================] - 131s - loss: 0.0320 - outmap_loss: 0.0201 - outmap4_loss: 0.0307 - outmap5_loss: 0.0421 - outbin_loss: 0.3660 - outbin_acc: 0.8417 - val_loss: 0.0304 - val_outmap_loss: 0.0194 - val_outmap4_loss: 0.0286 - val_outmap5_loss: 0.0403 - val_outbin_loss: 0.3206 - val_outbin_acc: 0.8593
# Epoch 19/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0314 - outmap_loss: 0.0197 - outmap4_loss: 0.0303 - outmap5_loss: 0.0415 - outbin_loss: 0.3568 - outbin_acc: 0.8449Epoch 00018: val_loss improved from 0.03036 to 0.03036, saving model to weights.hdf5
# 10545/10545 [==============================] - 128s - loss: 0.0314 - outmap_loss: 0.0197 - outmap4_loss: 0.0303 - outmap5_loss: 0.0416 - outbin_loss: 0.3567 - outbin_acc: 0.8450 - val_loss: 0.0304 - val_outmap_loss: 0.0194 - val_outmap4_loss: 0.0288 - val_outmap5_loss: 0.0379 - val_outbin_loss: 0.3254 - val_outbin_acc: 0.8670
# Epoch 20/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0308 - outmap_loss: 0.0193 - outmap4_loss: 0.0301 - outmap5_loss: 0.0407 - outbin_loss: 0.3460 - outbin_acc: 0.8518Epoch 00019: val_loss did not improve
# 10545/10545 [==============================] - 128s - loss: 0.0308 - outmap_loss: 0.0193 - outmap4_loss: 0.0301 - outmap5_loss: 0.0406 - outbin_loss: 0.3458 - outbin_acc: 0.8517 - val_loss: 0.0305 - val_outmap_loss: 0.0195 - val_outmap4_loss: 0.0293 - val_outmap5_loss: 0.0400 - val_outbin_loss: 0.3079 - val_outbin_acc: 0.8696
# Epoch 21/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0306 - outmap_loss: 0.0191 - outmap4_loss: 0.0299 - outmap5_loss: 0.0406 - outbin_loss: 0.3418 - outbin_acc: 0.8528Epoch 00020: val_loss did not improve
# 10545/10545 [==============================] - 128s - loss: 0.0306 - outmap_loss: 0.0191 - outmap4_loss: 0.0299 - outmap5_loss: 0.0407 - outbin_loss: 0.3415 - outbin_acc: 0.8530 - val_loss: 0.0320 - val_outmap_loss: 0.0209 - val_outmap4_loss: 0.0292 - val_outmap5_loss: 0.0432 - val_outbin_loss: 0.3072 - val_outbin_acc: 0.8875
# Epoch 22/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0305 - outmap_loss: 0.0191 - outmap4_loss: 0.0300 - outmap5_loss: 0.0407 - outbin_loss: 0.3382 - outbin_acc: 0.8558Epoch 00021: val_loss improved from 0.03036 to 0.02928, saving model to weights.hdf5
# 10545/10545 [==============================] - 128s - loss: 0.0306 - outmap_loss: 0.0191 - outmap4_loss: 0.0300 - outmap5_loss: 0.0407 - outbin_loss: 0.3380 - outbin_acc: 0.8559 - val_loss: 0.0293 - val_outmap_loss: 0.0183 - val_outmap4_loss: 0.0293 - val_outmap5_loss: 0.0378 - val_outbin_loss: 0.3214 - val_outbin_acc: 0.8645
# Epoch 23/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0301 - outmap_loss: 0.0188 - outmap4_loss: 0.0296 - outmap5_loss: 0.0406 - outbin_loss: 0.3316 - outbin_acc: 0.8554Epoch 00022: val_loss did not improve
# 10545/10545 [==============================] - 131s - loss: 0.0301 - outmap_loss: 0.0188 - outmap4_loss: 0.0296 - outmap5_loss: 0.0406 - outbin_loss: 0.3315 - outbin_acc: 0.8554 - val_loss: 0.0306 - val_outmap_loss: 0.0199 - val_outmap4_loss: 0.0282 - val_outmap5_loss: 0.0379 - val_outbin_loss: 0.3162 - val_outbin_acc: 0.8670
# Epoch 24/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0298 - outmap_loss: 0.0186 - outmap4_loss: 0.0294 - outmap5_loss: 0.0406 - outbin_loss: 0.3296 - outbin_acc: 0.8580Epoch 00023: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0298 - outmap_loss: 0.0186 - outmap4_loss: 0.0295 - outmap5_loss: 0.0406 - outbin_loss: 0.3293 - outbin_acc: 0.8581 - val_loss: 0.0299 - val_outmap_loss: 0.0191 - val_outmap4_loss: 0.0285 - val_outmap5_loss: 0.0418 - val_outbin_loss: 0.3075 - val_outbin_acc: 0.8747
# Epoch 25/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0299 - outmap_loss: 0.0187 - outmap4_loss: 0.0294 - outmap5_loss: 0.0404 - outbin_loss: 0.3286 - outbin_acc: 0.8583Epoch 00024: val_loss improved from 0.02928 to 0.02925, saving model to weights.hdf5
# 10545/10545 [==============================] - 133s - loss: 0.0299 - outmap_loss: 0.0187 - outmap4_loss: 0.0294 - outmap5_loss: 0.0404 - outbin_loss: 0.3280 - outbin_acc: 0.8585 - val_loss: 0.0292 - val_outmap_loss: 0.0186 - val_outmap4_loss: 0.0279 - val_outmap5_loss: 0.0385 - val_outbin_loss: 0.3160 - val_outbin_acc: 0.8824
# Epoch 26/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0293 - outmap_loss: 0.0183 - outmap4_loss: 0.0292 - outmap5_loss: 0.0400 - outbin_loss: 0.3196 - outbin_acc: 0.8671Epoch 00025: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0293 - outmap_loss: 0.0183 - outmap4_loss: 0.0293 - outmap5_loss: 0.0400 - outbin_loss: 0.3198 - outbin_acc: 0.8669 - val_loss: 0.0302 - val_outmap_loss: 0.0193 - val_outmap4_loss: 0.0286 - val_outmap5_loss: 0.0387 - val_outbin_loss: 0.3313 - val_outbin_acc: 0.8824
# Epoch 27/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0291 - outmap_loss: 0.0181 - outmap4_loss: 0.0290 - outmap5_loss: 0.0400 - outbin_loss: 0.3169 - outbin_acc: 0.8661Epoch 00026: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0291 - outmap_loss: 0.0181 - outmap4_loss: 0.0290 - outmap5_loss: 0.0400 - outbin_loss: 0.3167 - outbin_acc: 0.8662 - val_loss: 0.0293 - val_outmap_loss: 0.0187 - val_outmap4_loss: 0.0275 - val_outmap5_loss: 0.0368 - val_outbin_loss: 0.3215 - val_outbin_acc: 0.8875
# Epoch 28/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0289 - outmap_loss: 0.0180 - outmap4_loss: 0.0289 - outmap5_loss: 0.0397 - outbin_loss: 0.3123 - outbin_acc: 0.8729Epoch 00027: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0289 - outmap_loss: 0.0180 - outmap4_loss: 0.0289 - outmap5_loss: 0.0397 - outbin_loss: 0.3124 - outbin_acc: 0.8730 - val_loss: 0.0303 - val_outmap_loss: 0.0196 - val_outmap4_loss: 0.0275 - val_outmap5_loss: 0.0408 - val_outbin_loss: 0.3150 - val_outbin_acc: 0.8747
# Epoch 29/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0289 - outmap_loss: 0.0179 - outmap4_loss: 0.0288 - outmap5_loss: 0.0400 - outbin_loss: 0.3179 - outbin_acc: 0.8650Epoch 00028: val_loss improved from 0.02925 to 0.02918, saving model to weights.hdf5
# 10545/10545 [==============================] - 132s - loss: 0.0288 - outmap_loss: 0.0179 - outmap4_loss: 0.0288 - outmap5_loss: 0.0399 - outbin_loss: 0.3173 - outbin_acc: 0.8653 - val_loss: 0.0292 - val_outmap_loss: 0.0188 - val_outmap4_loss: 0.0276 - val_outmap5_loss: 0.0374 - val_outbin_loss: 0.3000 - val_outbin_acc: 0.8849
# Epoch 30/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0287 - outmap_loss: 0.0178 - outmap4_loss: 0.0290 - outmap5_loss: 0.0398 - outbin_loss: 0.3133 - outbin_acc: 0.8675Epoch 00029: val_loss did not improve
# 10545/10545 [==============================] - 128s - loss: 0.0287 - outmap_loss: 0.0178 - outmap4_loss: 0.0289 - outmap5_loss: 0.0398 - outbin_loss: 0.3135 - outbin_acc: 0.8673 - val_loss: 0.0303 - val_outmap_loss: 0.0196 - val_outmap4_loss: 0.0279 - val_outmap5_loss: 0.0385 - val_outbin_loss: 0.3200 - val_outbin_acc: 0.8798
# Epoch 31/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0285 - outmap_loss: 0.0176 - outmap4_loss: 0.0288 - outmap5_loss: 0.0398 - outbin_loss: 0.3063 - outbin_acc: 0.8712Epoch 00030: val_loss did not improve
# 10545/10545 [==============================] - 128s - loss: 0.0284 - outmap_loss: 0.0176 - outmap4_loss: 0.0288 - outmap5_loss: 0.0397 - outbin_loss: 0.3059 - outbin_acc: 0.8715 - val_loss: 0.0304 - val_outmap_loss: 0.0199 - val_outmap4_loss: 0.0273 - val_outmap5_loss: 0.0398 - val_outbin_loss: 0.3088 - val_outbin_acc: 0.8849
# Epoch 32/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0284 - outmap_loss: 0.0176 - outmap4_loss: 0.0286 - outmap5_loss: 0.0398 - outbin_loss: 0.3080 - outbin_acc: 0.8698Epoch 00031: val_loss did not improve
# 10545/10545 [==============================] - 128s - loss: 0.0284 - outmap_loss: 0.0176 - outmap4_loss: 0.0286 - outmap5_loss: 0.0398 - outbin_loss: 0.3077 - outbin_acc: 0.8700 - val_loss: 0.0301 - val_outmap_loss: 0.0193 - val_outmap4_loss: 0.0280 - val_outmap5_loss: 0.0372 - val_outbin_loss: 0.3279 - val_outbin_acc: 0.8747
# Epoch 33/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0280 - outmap_loss: 0.0173 - outmap4_loss: 0.0284 - outmap5_loss: 0.0395 - outbin_loss: 0.3034 - outbin_acc: 0.8693Epoch 00032: val_loss improved from 0.02918 to 0.02860, saving model to weights.hdf5
# 10545/10545 [==============================] - 128s - loss: 0.0280 - outmap_loss: 0.0173 - outmap4_loss: 0.0284 - outmap5_loss: 0.0395 - outbin_loss: 0.3038 - outbin_acc: 0.8692 - val_loss: 0.0286 - val_outmap_loss: 0.0183 - val_outmap4_loss: 0.0272 - val_outmap5_loss: 0.0365 - val_outbin_loss: 0.3048 - val_outbin_acc: 0.8900
# Epoch 34/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0277 - outmap_loss: 0.0171 - outmap4_loss: 0.0283 - outmap5_loss: 0.0393 - outbin_loss: 0.2986 - outbin_acc: 0.8736Epoch 00033: val_loss did not improve
# 10545/10545 [==============================] - 130s - loss: 0.0277 - outmap_loss: 0.0171 - outmap4_loss: 0.0283 - outmap5_loss: 0.0393 - outbin_loss: 0.2982 - outbin_acc: 0.8736 - val_loss: 0.0308 - val_outmap_loss: 0.0202 - val_outmap4_loss: 0.0281 - val_outmap5_loss: 0.0391 - val_outbin_loss: 0.3061 - val_outbin_acc: 0.8951
# Epoch 35/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0274 - outmap_loss: 0.0169 - outmap4_loss: 0.0283 - outmap5_loss: 0.0388 - outbin_loss: 0.2917 - outbin_acc: 0.8780Epoch 00034: val_loss improved from 0.02860 to 0.02837, saving model to weights.hdf5
# 10545/10545 [==============================] - 133s - loss: 0.0274 - outmap_loss: 0.0169 - outmap4_loss: 0.0283 - outmap5_loss: 0.0388 - outbin_loss: 0.2918 - outbin_acc: 0.8779 - val_loss: 0.0284 - val_outmap_loss: 0.0178 - val_outmap4_loss: 0.0278 - val_outmap5_loss: 0.0370 - val_outbin_loss: 0.3121 - val_outbin_acc: 0.8900
# Epoch 36/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0274 - outmap_loss: 0.0168 - outmap4_loss: 0.0283 - outmap5_loss: 0.0392 - outbin_loss: 0.2929 - outbin_acc: 0.8773Epoch 00035: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0274 - outmap_loss: 0.0168 - outmap4_loss: 0.0283 - outmap5_loss: 0.0392 - outbin_loss: 0.2939 - outbin_acc: 0.8770 - val_loss: 0.0284 - val_outmap_loss: 0.0181 - val_outmap4_loss: 0.0273 - val_outmap5_loss: 0.0370 - val_outbin_loss: 0.3026 - val_outbin_acc: 0.8977
# Epoch 37/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0274 - outmap_loss: 0.0169 - outmap4_loss: 0.0282 - outmap5_loss: 0.0391 - outbin_loss: 0.2914 - outbin_acc: 0.8765Epoch 00036: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0274 - outmap_loss: 0.0169 - outmap4_loss: 0.0282 - outmap5_loss: 0.0390 - outbin_loss: 0.2908 - outbin_acc: 0.8768 - val_loss: 0.0296 - val_outmap_loss: 0.0188 - val_outmap4_loss: 0.0282 - val_outmap5_loss: 0.0377 - val_outbin_loss: 0.3281 - val_outbin_acc: 0.8824
# Epoch 38/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0269 - outmap_loss: 0.0165 - outmap4_loss: 0.0280 - outmap5_loss: 0.0387 - outbin_loss: 0.2864 - outbin_acc: 0.8829Epoch 00037: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0269 - outmap_loss: 0.0165 - outmap4_loss: 0.0279 - outmap5_loss: 0.0387 - outbin_loss: 0.2863 - outbin_acc: 0.8829 - val_loss: 0.0295 - val_outmap_loss: 0.0189 - val_outmap4_loss: 0.0275 - val_outmap5_loss: 0.0393 - val_outbin_loss: 0.3195 - val_outbin_acc: 0.8824
# Epoch 39/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0267 - outmap_loss: 0.0164 - outmap4_loss: 0.0279 - outmap5_loss: 0.0387 - outbin_loss: 0.2847 - outbin_acc: 0.8835Epoch 00038: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0267 - outmap_loss: 0.0164 - outmap4_loss: 0.0279 - outmap5_loss: 0.0387 - outbin_loss: 0.2850 - outbin_acc: 0.8835 - val_loss: 0.0299 - val_outmap_loss: 0.0188 - val_outmap4_loss: 0.0284 - val_outmap5_loss: 0.0378 - val_outbin_loss: 0.3500 - val_outbin_acc: 0.8670
# Epoch 40/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0268 - outmap_loss: 0.0164 - outmap4_loss: 0.0279 - outmap5_loss: 0.0387 - outbin_loss: 0.2854 - outbin_acc: 0.8803Epoch 00039: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0267 - outmap_loss: 0.0164 - outmap4_loss: 0.0279 - outmap5_loss: 0.0387 - outbin_loss: 0.2850 - outbin_acc: 0.8806 - val_loss: 0.0294 - val_outmap_loss: 0.0187 - val_outmap4_loss: 0.0281 - val_outmap5_loss: 0.0363 - val_outbin_loss: 0.3197 - val_outbin_acc: 0.8772
# Epoch 41/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0266 - outmap_loss: 0.0163 - outmap4_loss: 0.0280 - outmap5_loss: 0.0381 - outbin_loss: 0.2764 - outbin_acc: 0.8858Epoch 00040: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0265 - outmap_loss: 0.0163 - outmap4_loss: 0.0280 - outmap5_loss: 0.0382 - outbin_loss: 0.2758 - outbin_acc: 0.8863 - val_loss: 0.0297 - val_outmap_loss: 0.0194 - val_outmap4_loss: 0.0270 - val_outmap5_loss: 0.0369 - val_outbin_loss: 0.3067 - val_outbin_acc: 0.8747
# Epoch 42/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0264 - outmap_loss: 0.0162 - outmap4_loss: 0.0279 - outmap5_loss: 0.0384 - outbin_loss: 0.2766 - outbin_acc: 0.8867Epoch 00041: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0265 - outmap_loss: 0.0162 - outmap4_loss: 0.0279 - outmap5_loss: 0.0385 - outbin_loss: 0.2771 - outbin_acc: 0.8863 - val_loss: 0.0294 - val_outmap_loss: 0.0186 - val_outmap4_loss: 0.0271 - val_outmap5_loss: 0.0367 - val_outbin_loss: 0.3560 - val_outbin_acc: 0.8440
# Epoch 43/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0264 - outmap_loss: 0.0161 - outmap4_loss: 0.0277 - outmap5_loss: 0.0386 - outbin_loss: 0.2827 - outbin_acc: 0.8825Epoch 00042: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0264 - outmap_loss: 0.0161 - outmap4_loss: 0.0277 - outmap5_loss: 0.0386 - outbin_loss: 0.2836 - outbin_acc: 0.8822 - val_loss: 0.0311 - val_outmap_loss: 0.0205 - val_outmap4_loss: 0.0277 - val_outmap5_loss: 0.0381 - val_outbin_loss: 0.3146 - val_outbin_acc: 0.8875
# Epoch 44/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0265 - outmap_loss: 0.0162 - outmap4_loss: 0.0279 - outmap5_loss: 0.0386 - outbin_loss: 0.2817 - outbin_acc: 0.8796Epoch 00043: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0265 - outmap_loss: 0.0161 - outmap4_loss: 0.0279 - outmap5_loss: 0.0385 - outbin_loss: 0.2813 - outbin_acc: 0.8799 - val_loss: 0.0287 - val_outmap_loss: 0.0180 - val_outmap4_loss: 0.0277 - val_outmap5_loss: 0.0369 - val_outbin_loss: 0.3325 - val_outbin_acc: 0.8747
# Epoch 45/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0259 - outmap_loss: 0.0158 - outmap4_loss: 0.0276 - outmap5_loss: 0.0384 - outbin_loss: 0.2708 - outbin_acc: 0.8877Epoch 00044: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0259 - outmap_loss: 0.0158 - outmap4_loss: 0.0276 - outmap5_loss: 0.0384 - outbin_loss: 0.2710 - outbin_acc: 0.8875 - val_loss: 0.0318 - val_outmap_loss: 0.0202 - val_outmap4_loss: 0.0290 - val_outmap5_loss: 0.0413 - val_outbin_loss: 0.3693 - val_outbin_acc: 0.8747
# Epoch 46/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0259 - outmap_loss: 0.0157 - outmap4_loss: 0.0277 - outmap5_loss: 0.0386 - outbin_loss: 0.2693 - outbin_acc: 0.8878Epoch 00045: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0259 - outmap_loss: 0.0157 - outmap4_loss: 0.0277 - outmap5_loss: 0.0386 - outbin_loss: 0.2693 - outbin_acc: 0.8877 - val_loss: 0.0307 - val_outmap_loss: 0.0199 - val_outmap4_loss: 0.0281 - val_outmap5_loss: 0.0370 - val_outbin_loss: 0.3347 - val_outbin_acc: 0.8849
# Epoch 47/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0259 - outmap_loss: 0.0158 - outmap4_loss: 0.0276 - outmap5_loss: 0.0389 - outbin_loss: 0.2657 - outbin_acc: 0.8901Epoch 00046: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0259 - outmap_loss: 0.0158 - outmap4_loss: 0.0275 - outmap5_loss: 0.0388 - outbin_loss: 0.2653 - outbin_acc: 0.8903 - val_loss: 0.0291 - val_outmap_loss: 0.0185 - val_outmap4_loss: 0.0274 - val_outmap5_loss: 0.0380 - val_outbin_loss: 0.3233 - val_outbin_acc: 0.8747
# Epoch 48/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0254 - outmap_loss: 0.0154 - outmap4_loss: 0.0274 - outmap5_loss: 0.0380 - outbin_loss: 0.2648 - outbin_acc: 0.8916Epoch 00047: val_loss improved from 0.02837 to 0.02819, saving model to weights.hdf5
# 10545/10545 [==============================] - 133s - loss: 0.0254 - outmap_loss: 0.0154 - outmap4_loss: 0.0274 - outmap5_loss: 0.0380 - outbin_loss: 0.2658 - outbin_acc: 0.8911 - val_loss: 0.0282 - val_outmap_loss: 0.0177 - val_outmap4_loss: 0.0277 - val_outmap5_loss: 0.0360 - val_outbin_loss: 0.3139 - val_outbin_acc: 0.8875
# Epoch 49/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0253 - outmap_loss: 0.0153 - outmap4_loss: 0.0274 - outmap5_loss: 0.0378 - outbin_loss: 0.2634 - outbin_acc: 0.8878Epoch 00048: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0253 - outmap_loss: 0.0153 - outmap4_loss: 0.0274 - outmap5_loss: 0.0378 - outbin_loss: 0.2634 - outbin_acc: 0.8877 - val_loss: 0.0298 - val_outmap_loss: 0.0191 - val_outmap4_loss: 0.0289 - val_outmap5_loss: 0.0383 - val_outbin_loss: 0.3045 - val_outbin_acc: 0.8798
# Epoch 50/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0255 - outmap_loss: 0.0155 - outmap4_loss: 0.0275 - outmap5_loss: 0.0385 - outbin_loss: 0.2607 - outbin_acc: 0.8930Epoch 00049: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0256 - outmap_loss: 0.0155 - outmap4_loss: 0.0275 - outmap5_loss: 0.0385 - outbin_loss: 0.2612 - outbin_acc: 0.8926 - val_loss: 0.0295 - val_outmap_loss: 0.0187 - val_outmap4_loss: 0.0282 - val_outmap5_loss: 0.0374 - val_outbin_loss: 0.3285 - val_outbin_acc: 0.8772
# Epoch 51/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0256 - outmap_loss: 0.0155 - outmap4_loss: 0.0276 - outmap5_loss: 0.0381 - outbin_loss: 0.2616 - outbin_acc: 0.8912Epoch 00050: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0256 - outmap_loss: 0.0155 - outmap4_loss: 0.0276 - outmap5_loss: 0.0381 - outbin_loss: 0.2617 - outbin_acc: 0.8910 - val_loss: 0.0307 - val_outmap_loss: 0.0201 - val_outmap4_loss: 0.0275 - val_outmap5_loss: 0.0364 - val_outbin_loss: 0.3277 - val_outbin_acc: 0.8772
# Epoch 52/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0249 - outmap_loss: 0.0150 - outmap4_loss: 0.0272 - outmap5_loss: 0.0376 - outbin_loss: 0.2530 - outbin_acc: 0.8976Epoch 00051: val_loss did not improve
# 10545/10545 [==============================] - 133s - loss: 0.0249 - outmap_loss: 0.0150 - outmap4_loss: 0.0272 - outmap5_loss: 0.0377 - outbin_loss: 0.2529 - outbin_acc: 0.8977 - val_loss: 0.0290 - val_outmap_loss: 0.0187 - val_outmap4_loss: 0.0270 - val_outmap5_loss: 0.0362 - val_outbin_loss: 0.3106 - val_outbin_acc: 0.8824
# Epoch 53/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0248 - outmap_loss: 0.0150 - outmap4_loss: 0.0272 - outmap5_loss: 0.0376 - outbin_loss: 0.2509 - outbin_acc: 0.8980Epoch 00052: val_loss did not improve
# 10545/10545 [==============================] - 132s - loss: 0.0248 - outmap_loss: 0.0150 - outmap4_loss: 0.0272 - outmap5_loss: 0.0376 - outbin_loss: 0.2504 - outbin_acc: 0.8982 - val_loss: 0.0291 - val_outmap_loss: 0.0185 - val_outmap4_loss: 0.0274 - val_outmap5_loss: 0.0371 - val_outbin_loss: 0.3272 - val_outbin_acc: 0.8824
# Epoch 54/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0249 - outmap_loss: 0.0151 - outmap4_loss: 0.0273 - outmap5_loss: 0.0376 - outbin_loss: 0.2488 - outbin_acc: 0.8999Epoch 00053: val_loss did not improve
# 10545/10545 [==============================] - 132s - loss: 0.0249 - outmap_loss: 0.0151 - outmap4_loss: 0.0273 - outmap5_loss: 0.0376 - outbin_loss: 0.2487 - outbin_acc: 0.9000 - val_loss: 0.0313 - val_outmap_loss: 0.0206 - val_outmap4_loss: 0.0276 - val_outmap5_loss: 0.0361 - val_outbin_loss: 0.3384 - val_outbin_acc: 0.8619
# Epoch 55/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0250 - outmap_loss: 0.0151 - outmap4_loss: 0.0274 - outmap5_loss: 0.0379 - outbin_loss: 0.2535 - outbin_acc: 0.8948Epoch 00054: val_loss did not improve
# 10545/10545 [==============================] - 132s - loss: 0.0251 - outmap_loss: 0.0151 - outmap4_loss: 0.0274 - outmap5_loss: 0.0379 - outbin_loss: 0.2537 - outbin_acc: 0.8946 - val_loss: 0.0293 - val_outmap_loss: 0.0189 - val_outmap4_loss: 0.0272 - val_outmap5_loss: 0.0376 - val_outbin_loss: 0.3165 - val_outbin_acc: 0.8772
# Epoch 56/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0246 - outmap_loss: 0.0148 - outmap4_loss: 0.0271 - outmap5_loss: 0.0375 - outbin_loss: 0.2486 - outbin_acc: 0.8960Epoch 00055: val_loss did not improve
# 10545/10545 [==============================] - 132s - loss: 0.0246 - outmap_loss: 0.0148 - outmap4_loss: 0.0271 - outmap5_loss: 0.0375 - outbin_loss: 0.2483 - outbin_acc: 0.8963 - val_loss: 0.0291 - val_outmap_loss: 0.0185 - val_outmap4_loss: 0.0280 - val_outmap5_loss: 0.0368 - val_outbin_loss: 0.3142 - val_outbin_acc: 0.8824
# Epoch 57/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0242 - outmap_loss: 0.0145 - outmap4_loss: 0.0270 - outmap5_loss: 0.0377 - outbin_loss: 0.2464 - outbin_acc: 0.8982Epoch 00056: val_loss improved from 0.02819 to 0.02780, saving model to weights.hdf5
# 10545/10545 [==============================] - 132s - loss: 0.0242 - outmap_loss: 0.0145 - outmap4_loss: 0.0270 - outmap5_loss: 0.0377 - outbin_loss: 0.2465 - outbin_acc: 0.8982 - val_loss: 0.0278 - val_outmap_loss: 0.0176 - val_outmap4_loss: 0.0271 - val_outmap5_loss: 0.0369 - val_outbin_loss: 0.2939 - val_outbin_acc: 0.8798
# Epoch 58/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0244 - outmap_loss: 0.0147 - outmap4_loss: 0.0271 - outmap5_loss: 0.0378 - outbin_loss: 0.2397 - outbin_acc: 0.9007Epoch 00057: val_loss did not improve
# 10545/10545 [==============================] - 132s - loss: 0.0244 - outmap_loss: 0.0147 - outmap4_loss: 0.0271 - outmap5_loss: 0.0378 - outbin_loss: 0.2398 - outbin_acc: 0.9005 - val_loss: 0.0285 - val_outmap_loss: 0.0178 - val_outmap4_loss: 0.0271 - val_outmap5_loss: 0.0372 - val_outbin_loss: 0.3439 - val_outbin_acc: 0.8721
# Epoch 59/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0245 - outmap_loss: 0.0147 - outmap4_loss: 0.0271 - outmap5_loss: 0.0379 - outbin_loss: 0.2474 - outbin_acc: 0.8983Epoch 00058: val_loss did not improve
# 10545/10545 [==============================] - 132s - loss: 0.0246 - outmap_loss: 0.0148 - outmap4_loss: 0.0271 - outmap5_loss: 0.0380 - outbin_loss: 0.2474 - outbin_acc: 0.8984 - val_loss: 0.0301 - val_outmap_loss: 0.0195 - val_outmap4_loss: 0.0273 - val_outmap5_loss: 0.0371 - val_outbin_loss: 0.3293 - val_outbin_acc: 0.8772
# Epoch 60/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0243 - outmap_loss: 0.0146 - outmap4_loss: 0.0270 - outmap5_loss: 0.0376 - outbin_loss: 0.2408 - outbin_acc: 0.9026Epoch 00059: val_loss did not improve
# 10545/10545 [==============================] - 132s - loss: 0.0243 - outmap_loss: 0.0146 - outmap4_loss: 0.0270 - outmap5_loss: 0.0376 - outbin_loss: 0.2405 - outbin_acc: 0.9026 - val_loss: 0.0296 - val_outmap_loss: 0.0191 - val_outmap4_loss: 0.0272 - val_outmap5_loss: 0.0370 - val_outbin_loss: 0.3267 - val_outbin_acc: 0.8875

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture_final.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights_final.hdf5'))

# %%
def compute_scores_map(X, Y):
    Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X)
    
    map_threshs = np.linspace(0, 1, num=21)
    bin_threshs = np.linspace(0, 1, num=21)
    
    scores = np.zeros((len(map_threshs), len(bin_threshs)))
    for i in range(len(map_threshs)):
        for j in range(len(bin_threshs)):
            _Y_pred = Y_pred > map_threshs[i]
            
            for k in range(_Y_pred.shape[0]):
                # Clear prediction where we detect to little pixels
                if np.sum(_Y_pred[k]) < 150 or Y_pred_binary[k] < bin_threshs[j]:
                    _Y_pred[k,:] = 0
            
            scores[i, j] = utils.average_dice_coefficient(_Y_pred, Y)
    
    pl.imshow(scores, interpolation='nearest')
    pl.yticks(np.arange(len(map_threshs)) + 0.5, ['%.2f' % v for v in map_threshs])
    pl.xticks(np.arange(len(bin_threshs)) + 0.5, ['%.2f' % v for v in bin_threshs], rotation=90)
    pl.ylabel('map thresh')
    pl.xlabel('bin thresh')
    pl.colorbar()
    
    best_i, best_j = np.unravel_index(np.argmax(scores.ravel()), scores.shape)
    best_map_thresh = map_threshs[best_i]
    best_bin_thresh = bin_threshs[best_j]
    return best_map_thresh, best_bin_thresh

map_thresh, bin_thresh = compute_scores_map(X_test, Y_test)
print 'Best map_thresh=%f, bin_thresh=%f' % (map_thresh, bin_thresh)
# Out:
# Best map_thresh=0.350000, bin_thresh=0.400000

# %%
#map_thresh = 0.45
#bin_thresh = 0.9

# %%
def predict(X, map_thresh, bin_thresh):
    Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > map_thresh
    for i in range(Y_pred.shape[0]):
        if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < bin_thresh:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test, map_thresh, bin_thresh)
Y_full_pred, Y_full_pred_proba, Y_full_pred_binary = predict(X_full, map_thresh, bin_thresh)

print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "avg test set score : ", utils.average_dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
print "avg full set score : ", utils.average_dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.681729020804
# avg test set score :  0.832827502055
# full set score :  0.677665965589
# avg full set score :  0.783174632379

# %%
_ = pl.hist(Y_pred_binary)

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[40:45]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(30):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, pred44, pred88, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 15
img, pred_map = dream_output(Y_full[i])
pl.figure(figsize=(12, 4))
pl.subplot(141)
pl.imshow(X_full[i].squeeze(), cmap=cm.gray)
pl.subplot(142)
pl.imshow(Y_full[i].squeeze())
pl.subplot(143)
pl.imshow(img, cmap=cm.gray)
pl.subplot(144)
pl.imshow(pred_map.squeeze())

# %%
# Dream for the binary output
def dream_binoutput(output):
    
    layer_output = layer_dict['outbin'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output - layer_output[:, 0]))
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    
    step = 0.1
    for i in range(40):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    _, _, _, model_pred = model.predict(img[None,None,:,:])
    return img, model_pred

img, model_pred = dream_binoutput(1)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
img, model_pred = dream_binoutput(0)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
def dream_layer_filter(layer_name, filter_index):
    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(4):
        pl.subplot(1, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
_d = np.load('../data/data_128_test.npz')
X_submit = _d['X']

Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X_submit[:,None,:,:])
Y_pred_binary = Y_pred_binary.squeeze()
Y_pred_proba = Y_pred

# %%
def Y_to_binary(Y_pred, Y_pred_binary, map_thresh, bin_thresh):
    Y_pred = Y_pred > map_thresh
    for i in range(Y_pred.shape[0]):
        if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < bin_thresh:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

map_threshs = np.linspace(0, 1, num=11)
bin_threshs = np.linspace(0, 1, num=11)

masks_per = np.zeros((len(map_threshs), len(bin_threshs)))
for i in range(len(map_threshs)):
    for j in range(len(bin_threshs)):
        m_t = map_threshs[i]
        b_t = bin_threshs[j]
        _pred, _pred_proba, _pred_binary = Y_to_binary(Y_pred, Y_pred_binary, m_t, b_t)
        # Turn labels into boolean present/missing
        _pred_binary = np.sum(np.sum(np.sum(_pred, axis=2), axis=1), axis=1) > 0
        _pred_binary = _pred_binary.astype(np.float32)
        per_mask = (100 * np.count_nonzero(_pred_binary) / float(len(_pred_binary)))

        masks_per[i, j] = per_mask

pl.imshow(masks_per, interpolation='nearest')
pl.yticks(np.arange(len(map_threshs)) + 0.5, ['%.2f' % v for v in map_threshs])
pl.xticks(np.arange(len(bin_threshs)) + 0.5, ['%.2f' % v for v in bin_threshs], rotation=90)
pl.ylabel('map thresh')
pl.xlabel('bin thresh')
pl.colorbar()

# %%
map_thresh = 0.4
bin_thresh = 0.35

# %%
if True:
    import cv2
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(50,50))
    
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    test_fnames = _d['test_fnames']
    # bin_thresh
    Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:],
                                                  map_thresh, bin_thresh)
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = (Y_pred[i].squeeze() * 255).astype(np.uint8)
        imre = cv2.morphologyEx(imre, cv2.MORPH_CLOSE, kernel)
        imre = cv2.resize(imre, (580, 420))
        
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
        
        if i % 10 == 0:
            print '\r%d / %d' % (i, len(test_fnames)),
            sys.stdout.flush()
# Out:
# 5500 / 5508

# %%
# Turn labels into boolean present/missing
pred_binary = np.sum(np.sum(np.sum(Y_pred, axis=2), axis=1), axis=1) > 0
pred_binary = pred_binary.astype(np.float32)
print "%.2f%% with masks" % (100 * np.count_nonzero(pred_binary) / float(len(pred_binary)))
# Out:
# 39.89% with masks

# %% [markdown]
# ## Stats on predicted masks

# %%
# on Y_full
nbp_pixels = np.sum(np.sum(np.sum(Y_full, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
pl.xlim((0, 1200))
# Out:
# (0, 1200)

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
pl.xlim((0, 1200))
# Out:
# (0, 1200)
