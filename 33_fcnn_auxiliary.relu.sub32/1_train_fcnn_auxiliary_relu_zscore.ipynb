# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']
X_pids = _d['pids']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
print X.dtype
print Y.dtype
# Out:
# (3906, 128, 128)
# (3906, 128, 128)
# float32
# float32

# %%
if False:
    # Split patients in train/test
    train_pids, test_pids = train_test_split(np.unique(X_pids), test_size=0.2)
    print train_pids
    print test_pids
    
    train_indices = np.flatnonzero(np.in1d(X_pids, train_pids))
    test_indices = np.flatnonzero(np.in1d(X_pids, test_pids))
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]
else:
    nsamples = X.shape[0]

    #train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.2)
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]

# %%
import skimage.transform as sktransf

def rand_float(rng):
    return rng[0] + np.random.random() * (rng[1] - rng[0])

def generate_image(X_img, Y_img, angle_range=None, zoom_range=None, shear_range=None, horiz_shift_range=None,
                   vert_shift_range=None):
    """
    Randomly shift an image by resizing and then random croping
    the resized image
    """
    if angle_range is None:
        angle_range = (-5, 5)
    if zoom_range is None:
        zoom_range = (0.8, 1.2)
    if shear_range is None:
        shear_range = (-5, 5) # shear angle in degrees
    if horiz_shift_range is None:
        horiz_shift_range = (-5, 5)
    if vert_shift_range is None:
        vert_shift_range = (-5, 5)
    inshape = X_img.shape
    
    X2 = X_img.copy()
    Y2 = Y_img.copy()
    
    # -- random rotation
    angle = np.deg2rad(rand_float(angle_range))
    zoom = rand_float(zoom_range)
    shear = np.deg2rad(rand_float(shear_range))
    horiz_shift = rand_float(horiz_shift_range)
    vert_shift = rand_float(vert_shift_range)
    
    tform = sktransf.AffineTransform(
        scale=(zoom, zoom),
        rotation=angle,
        shear=shear,
        translation=(horiz_shift, vert_shift)
    )
    X2 = sktransf.warp(X2, tform, order=5, mode='edge')
    Y2 = sktransf.warp(Y2, tform, order=1)

    # gaussian noise
    #noise_scale = rand_float((0, 0.1))
    #X2 += np.random.normal(scale=noise_scale, size=X2.shape)
    Y2 = Y2 > 0.5
    return X2[None,:,:].astype(np.float32), Y2[None,:,:].astype(np.float32)

X_train_augmented = []
Y_train_augmented = []
for i in range(X_train.shape[0]):
    if i % 10 == 0:
        print '\r%d / %d' % (i, X_train.shape[0]),
        sys.stdout.flush()
    X_train_augmented.append(X_train[i])
    Y_train_augmented.append(Y_train[i])
    for j in range(2):
        X2, Y2 = generate_image(X_train[i].squeeze(), Y_train[i].squeeze())
        X_train_augmented.append(X2)
        Y_train_augmented.append(Y2)
# Out:
# 3120 / 3124

# %%
X_train = np.array(X_train_augmented, dtype=np.float32)
Y_train = np.array(Y_train_augmented, dtype=np.float32)

Y_train_binary = np.sum(np.sum(Y_train.squeeze(), axis=2), axis=1) > 0
Y_train_binary = Y_train_binary.astype(np.float32)
Y_train_binary = Y_train_binary[:,None]

# %%
X_avg = X_train.mean(axis=0)
X_std = X_train.std(axis=0)

X_train = (X_train - X_avg) / X_std
X_test = (X_test - X_avg) / X_std

# %%
print X_train.shape
print Y_train.shape
print X_test.shape
print X_train.min(), X_train.max()
# Out:
# (9372, 1, 128, 128)
# (9372, 1, 128, 128)
# (782, 1, 128, 128)
# -3.621 6.25845

# %%
import cv2
def _resize(Y, outshape):
    return cv2.resize(Y.squeeze(), outshape, interpolation=cv2.INTER_AREA)[None, :, :]
Y_train_88 = np.array([_resize(img, (8, 8)) for img in Y_train])
Y_test_88 = np.array([_resize(img, (8, 8)) for img in Y_test])
Y_train_44 = np.array([_resize(img, (4, 4)) for img in Y_train])
Y_test_44 = np.array([_resize(img, (4, 4)) for img in Y_test])

# %%
with_bp = np.flatnonzero(np.sum(np.sum(np.sum(Y_train, axis=1), axis=1), axis=1))

# %%
for bpi in range(11, 14):
    i = with_bp[bpi]
    pl.figure(figsize=(16, 4))
    pl.subplot(141)
    pl.imshow(X_train[i].squeeze())
    pl.subplot(142)
    pl.imshow(Y_train[i].squeeze())
    pl.subplot(143)
    pl.imshow(Y_train_88[i].squeeze(), interpolation='nearest')
    pl.colorbar()
    pl.subplot(144)
    pl.imshow(Y_train_44[i].squeeze(), interpolation='nearest')
    pl.colorbar()

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float32'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense
from keras.layers import LeakyReLU, BatchNormalization
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
import keras.backend as K
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
# https://www.kaggle.com/c/ultrasound-nerve-segmentation/forums/t/21358/0-57-deep-learning-keras-tutorial
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def dice_coef_batchwise(y_true, y_pred):
    y_true_f = K.batch_flatten(y_true)
    y_pred_f = K.batch_flatten(y_pred)
    intersection = 2. * K.sum(y_true_f * y_pred_f, axis=1, keepdims=True) + smooth
    union = K.sum(y_true_f, axis=1, keepdims=True) + \
            K.sum(y_pred_f, axis=1, keepdims=True) + \
            smooth
    return K.mean(intersection / union)

def dice_coef_loss_batchwise(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %% [markdown]
# http://torch.ch/blog/2015/07/30/cifar.html

# %%
input_img = x = Input(shape=input_shape, name='input_img')
x = Convolution2D(32, 3, 3, border_mode='same', activation='relu')(input_img)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
pool1 = BatchNormalization(name='pool1', axis=1)(x)

x = Convolution2D(32, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
pool2 = BatchNormalization(name='pool2', axis=1)(x)

x = Convolution2D(32, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
pool3 = BatchNormalization(name='pool3', axis=1)(x)

x = Convolution2D(32, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
pool4 = BatchNormalization(name='pool4', axis=1)(x)

x = Convolution2D(32, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
pool5 = BatchNormalization(name='pool5', axis=1)(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(pool5)
x = Dense(32, activation='relu')(x)
x = Dense(16, activation='relu')(x)
x = Dropout(0.25)(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# turn pool5 into a classification map
outmap5 = Convolution2D(1, 3, 3, border_mode='same', activation='sigmoid', name='outmap5')(pool5)

x = UpSampling2D((2, 2))(outmap5)
x = merge([x, pool4], mode='concat', concat_axis=1)
x = Dropout(0.25)(x)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x)
outmap4 = Convolution2D(1, 3, 3, border_mode='same', activation='sigmoid', name='outmap4')(x)
x = UpSampling2D((2, 2))(x)

# upsample the classif map
x = merge([x, pool3], mode='concat', concat_axis=1)
x = Dropout(0.25)(x)
x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(pool3)
x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Dropout(0.25)(x)
x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Dropout(0.25)(x)
x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(x)
x = UpSampling2D((2, 2))(x)

x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(x)
outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outmap4, outmap5, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
metrics={'outbin': 'accuracy'}
model.compile(optimizer='adam', loss='binary_crossentropy',
              loss_weights=[1., 0.2, 0.05, 0.01], metrics=metrics)

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_21 (Convolution2D)   (None, 32, 128, 128)320         input_img[0][0]
# ____________________________________________________________________________________________________
# convolution2d_22 (Convolution2D)   (None, 16, 128, 128)4624        convolution2d_21[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_6 (MaxPooling2D)      (None, 16, 64, 64)  0           convolution2d_22[0][0]
# ____________________________________________________________________________________________________
# convolution2d_23 (Convolution2D)   (None, 32, 64, 64)  4640        maxpooling2d_6[0][0]
# ____________________________________________________________________________________________________
# convolution2d_24 (Convolution2D)   (None, 16, 64, 64)  4624        convolution2d_23[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_7 (MaxPooling2D)      (None, 16, 32, 32)  0           convolution2d_24[0][0]
# ____________________________________________________________________________________________________
# convolution2d_25 (Convolution2D)   (None, 32, 32, 32)  4640        maxpooling2d_7[0][0]
# ____________________________________________________________________________________________________
# convolution2d_26 (Convolution2D)   (None, 16, 32, 32)  4624        convolution2d_25[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_8 (MaxPooling2D)      (None, 16, 16, 16)  0           convolution2d_26[0][0]
# ____________________________________________________________________________________________________
# pool3 (BatchNormalization)         (None, 16, 16, 16)  32          maxpooling2d_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_33 (Convolution2D)   (None, 8, 16, 16)   1160        pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_34 (Convolution2D)   (None, 8, 16, 16)   584         convolution2d_33[0][0]
# ____________________________________________________________________________________________________
# convolution2d_27 (Convolution2D)   (None, 32, 16, 16)  4640        maxpooling2d_8[0][0]
# ____________________________________________________________________________________________________
# pool2 (BatchNormalization)         (None, 16, 32, 32)  32          maxpooling2d_7[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_8 (UpSampling2D)      (None, 8, 32, 32)   0           convolution2d_34[0][0]
# ____________________________________________________________________________________________________
# convolution2d_28 (Convolution2D)   (None, 16, 16, 16)  4624        convolution2d_27[0][0]
# ____________________________________________________________________________________________________
# merge_7 (Merge)                    (None, 24, 32, 32)  0           upsampling2d_8[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)                (None, 24, 32, 32)  0           merge_7[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_9 (MaxPooling2D)      (None, 16, 8, 8)    0           convolution2d_28[0][0]
# ____________________________________________________________________________________________________
# convolution2d_29 (Convolution2D)   (None, 32, 8, 8)    4640        maxpooling2d_9[0][0]
# ____________________________________________________________________________________________________
# convolution2d_35 (Convolution2D)   (None, 8, 32, 32)   1736        dropout_9[0][0]
# ____________________________________________________________________________________________________
# convolution2d_30 (Convolution2D)   (None, 16, 8, 8)    4624        convolution2d_29[0][0]
# ____________________________________________________________________________________________________
# convolution2d_36 (Convolution2D)   (None, 8, 32, 32)   584         convolution2d_35[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_10 (MaxPooling2D)     (None, 16, 4, 4)    0           convolution2d_30[0][0]
# ____________________________________________________________________________________________________
# pool1 (BatchNormalization)         (None, 16, 64, 64)  32          maxpooling2d_6[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_9 (UpSampling2D)      (None, 8, 64, 64)   0           convolution2d_36[0][0]
# ____________________________________________________________________________________________________
# merge_8 (Merge)                    (None, 24, 64, 64)  0           upsampling2d_9[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# pool5 (BatchNormalization)         (None, 16, 4, 4)    32          maxpooling2d_10[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)               (None, 24, 64, 64)  0           merge_8[0][0]
# ____________________________________________________________________________________________________
# outmap5 (Convolution2D)            (None, 1, 4, 4)     145         pool5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_37 (Convolution2D)   (None, 8, 64, 64)   1736        dropout_10[0][0]
# ____________________________________________________________________________________________________
# pool4 (BatchNormalization)         (None, 16, 8, 8)    32          maxpooling2d_9[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_6 (UpSampling2D)      (None, 1, 8, 8)     0           outmap5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_38 (Convolution2D)   (None, 8, 64, 64)   584         convolution2d_37[0][0]
# ____________________________________________________________________________________________________
# flatten_2 (Flatten)                (None, 256)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# merge_5 (Merge)                    (None, 17, 8, 8)    0           upsampling2d_6[0][0]
#                                                                    pool4[0][0]
# ____________________________________________________________________________________________________
# dense_3 (Dense)                    (None, 32)          8224        flatten_2[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)                (None, 17, 8, 8)    0           merge_5[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_10 (UpSampling2D)     (None, 8, 128, 128) 0           convolution2d_38[0][0]
# ____________________________________________________________________________________________________
# convolution2d_31 (Convolution2D)   (None, 16, 8, 8)    2464        dropout_7[0][0]
# ____________________________________________________________________________________________________
# convolution2d_39 (Convolution2D)   (None, 8, 128, 128) 584         upsampling2d_10[0][0]
# ____________________________________________________________________________________________________
# dense_4 (Dense)                    (None, 16)          528         dense_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_32 (Convolution2D)   (None, 16, 8, 8)    2320        convolution2d_31[0][0]
# ____________________________________________________________________________________________________
# convolution2d_40 (Convolution2D)   (None, 8, 128, 128) 584         convolution2d_39[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)                (None, 16)          0           dense_4[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          dropout_6[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 73          convolution2d_40[0][0]
# ____________________________________________________________________________________________________
# outmap4 (Convolution2D)            (None, 1, 8, 8)     145         convolution2d_32[0][0]
# ====================================================================================================
# Total params: 63628
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {
            'outmap': Y_train,
            'outmap4' : Y_train_88,
            'outmap5' : Y_train_44,
            'outbin': Y_train_binary
        },
        batch_size=64,
        validation_data=(X_test, {
                'outmap': Y_test,
                'outmap4' : Y_test_88,
                'outmap5' : Y_test_44,
                'outbin': Y_test_binary
        }),
        nb_epoch=60,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    
    pl.figure()
    pl.plot(history.history['outmap_loss'], label='train loss')
    pl.plot(history.history['val_outmap_loss'], c='g', label='val loss')
    pl.legend()

    pl.figure()
    pl.plot(history.history['outbin_acc'], label='train acc')
    pl.plot(history.history['val_outbin_acc'], c='g', label='val acc')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
                custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.01])
    
    print_summary(model.layers)
# Out:
# Train on 9372 samples, validate on 782 samples
# Epoch 1/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0912 - outmap_loss: 0.0650 - outmap4_loss: 0.0598 - outmap5_loss: 0.1607 - outbin_loss: 0.6160 - outbin_acc: 0.6560Epoch 00000: val_loss improved from inf to 0.05228, saving model to weights.hdf5
# 9372/9372 [==============================] - 61s - loss: 0.0910 - outmap_loss: 0.0649 - outmap4_loss: 0.0598 - outmap5_loss: 0.1604 - outbin_loss: 0.6156 - outbin_acc: 0.6564 - val_loss: 0.0523 - val_outmap_loss: 0.0355 - val_outmap4_loss: 0.0417 - val_outmap5_loss: 0.0707 - val_outbin_loss: 0.4918 - val_outbin_acc: 0.7685
# Epoch 2/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0456 - outmap_loss: 0.0310 - outmap4_loss: 0.0350 - outmap5_loss: 0.0560 - outbin_loss: 0.4760 - outbin_acc: 0.7827Epoch 00001: val_loss improved from 0.05228 to 0.04804, saving model to weights.hdf5
# 9372/9372 [==============================] - 61s - loss: 0.0455 - outmap_loss: 0.0310 - outmap4_loss: 0.0349 - outmap5_loss: 0.0559 - outbin_loss: 0.4753 - outbin_acc: 0.7833 - val_loss: 0.0480 - val_outmap_loss: 0.0284 - val_outmap4_loss: 0.0589 - val_outmap5_loss: 0.0466 - val_outbin_loss: 0.5525 - val_outbin_acc: 0.7647
# Epoch 3/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0392 - outmap_loss: 0.0267 - outmap4_loss: 0.0312 - outmap5_loss: 0.0452 - outbin_loss: 0.4091 - outbin_acc: 0.8217Epoch 00002: val_loss improved from 0.04804 to 0.03608, saving model to weights.hdf5
# 9372/9372 [==============================] - 61s - loss: 0.0393 - outmap_loss: 0.0267 - outmap4_loss: 0.0312 - outmap5_loss: 0.0453 - outbin_loss: 0.4089 - outbin_acc: 0.8218 - val_loss: 0.0361 - val_outmap_loss: 0.0252 - val_outmap4_loss: 0.0269 - val_outmap5_loss: 0.0446 - val_outbin_loss: 0.3238 - val_outbin_acc: 0.8683
# Epoch 4/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0364 - outmap_loss: 0.0246 - outmap4_loss: 0.0295 - outmap5_loss: 0.0418 - outbin_loss: 0.3714 - outbin_acc: 0.8444Epoch 00003: val_loss improved from 0.03608 to 0.03363, saving model to weights.hdf5
# 9372/9372 [==============================] - 61s - loss: 0.0363 - outmap_loss: 0.0246 - outmap4_loss: 0.0295 - outmap5_loss: 0.0418 - outbin_loss: 0.3711 - outbin_acc: 0.8445 - val_loss: 0.0336 - val_outmap_loss: 0.0225 - val_outmap4_loss: 0.0288 - val_outmap5_loss: 0.0366 - val_outbin_loss: 0.3533 - val_outbin_acc: 0.8376
# Epoch 5/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0345 - outmap_loss: 0.0234 - outmap4_loss: 0.0287 - outmap5_loss: 0.0398 - outbin_loss: 0.3399 - outbin_acc: 0.8596Epoch 00004: val_loss improved from 0.03363 to 0.03168, saving model to weights.hdf5
# 9372/9372 [==============================] - 61s - loss: 0.0345 - outmap_loss: 0.0234 - outmap4_loss: 0.0287 - outmap5_loss: 0.0398 - outbin_loss: 0.3395 - outbin_acc: 0.8598 - val_loss: 0.0317 - val_outmap_loss: 0.0217 - val_outmap4_loss: 0.0256 - val_outmap5_loss: 0.0370 - val_outbin_loss: 0.2970 - val_outbin_acc: 0.8824
# Epoch 6/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0329 - outmap_loss: 0.0223 - outmap4_loss: 0.0277 - outmap5_loss: 0.0386 - outbin_loss: 0.3141 - outbin_acc: 0.8735Epoch 00005: val_loss did not improve
# 9372/9372 [==============================] - 61s - loss: 0.0329 - outmap_loss: 0.0223 - outmap4_loss: 0.0277 - outmap5_loss: 0.0386 - outbin_loss: 0.3140 - outbin_acc: 0.8736 - val_loss: 0.0382 - val_outmap_loss: 0.0258 - val_outmap4_loss: 0.0300 - val_outmap5_loss: 0.0424 - val_outbin_loss: 0.4233 - val_outbin_acc: 0.8107
# Epoch 7/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0314 - outmap_loss: 0.0211 - outmap4_loss: 0.0274 - outmap5_loss: 0.0378 - outbin_loss: 0.3015 - outbin_acc: 0.8755Epoch 00006: val_loss did not improve
# 9372/9372 [==============================] - 61s - loss: 0.0314 - outmap_loss: 0.0210 - outmap4_loss: 0.0274 - outmap5_loss: 0.0378 - outbin_loss: 0.3013 - outbin_acc: 0.8756 - val_loss: 0.0343 - val_outmap_loss: 0.0227 - val_outmap4_loss: 0.0300 - val_outmap5_loss: 0.0364 - val_outbin_loss: 0.3838 - val_outbin_acc: 0.8427
# Epoch 8/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0298 - outmap_loss: 0.0197 - outmap4_loss: 0.0267 - outmap5_loss: 0.0373 - outbin_loss: 0.2848 - outbin_acc: 0.8827Epoch 00007: val_loss did not improve
# 9372/9372 [==============================] - 61s - loss: 0.0298 - outmap_loss: 0.0197 - outmap4_loss: 0.0267 - outmap5_loss: 0.0372 - outbin_loss: 0.2846 - outbin_acc: 0.8826 - val_loss: 0.0495 - val_outmap_loss: 0.0310 - val_outmap4_loss: 0.0402 - val_outmap5_loss: 0.0439 - val_outbin_loss: 0.8274 - val_outbin_acc: 0.7570
# Epoch 9/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0288 - outmap_loss: 0.0191 - outmap4_loss: 0.0263 - outmap5_loss: 0.0370 - outbin_loss: 0.2661 - outbin_acc: 0.8994Epoch 00008: val_loss improved from 0.03168 to 0.02931, saving model to weights.hdf5
# 9372/9372 [==============================] - 61s - loss: 0.0288 - outmap_loss: 0.0191 - outmap4_loss: 0.0263 - outmap5_loss: 0.0370 - outbin_loss: 0.2659 - outbin_acc: 0.8995 - val_loss: 0.0293 - val_outmap_loss: 0.0193 - val_outmap4_loss: 0.0257 - val_outmap5_loss: 0.0360 - val_outbin_loss: 0.3070 - val_outbin_acc: 0.8875
# Epoch 10/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0278 - outmap_loss: 0.0183 - outmap4_loss: 0.0259 - outmap5_loss: 0.0362 - outbin_loss: 0.2514 - outbin_acc: 0.9009Epoch 00009: val_loss did not improve
# 9372/9372 [==============================] - 61s - loss: 0.0278 - outmap_loss: 0.0183 - outmap4_loss: 0.0258 - outmap5_loss: 0.0362 - outbin_loss: 0.2510 - outbin_acc: 0.9012 - val_loss: 0.0318 - val_outmap_loss: 0.0211 - val_outmap4_loss: 0.0266 - val_outmap5_loss: 0.0353 - val_outbin_loss: 0.3591 - val_outbin_acc: 0.8632
# Epoch 11/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0266 - outmap_loss: 0.0175 - outmap4_loss: 0.0252 - outmap5_loss: 0.0359 - outbin_loss: 0.2283 - outbin_acc: 0.9077Epoch 00010: val_loss improved from 0.02931 to 0.02929, saving model to weights.hdf5
# 9372/9372 [==============================] - 61s - loss: 0.0266 - outmap_loss: 0.0175 - outmap4_loss: 0.0253 - outmap5_loss: 0.0359 - outbin_loss: 0.2283 - outbin_acc: 0.9078 - val_loss: 0.0293 - val_outmap_loss: 0.0192 - val_outmap4_loss: 0.0258 - val_outmap5_loss: 0.0347 - val_outbin_loss: 0.3157 - val_outbin_acc: 0.8964
# Epoch 12/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0259 - outmap_loss: 0.0169 - outmap4_loss: 0.0249 - outmap5_loss: 0.0358 - outbin_loss: 0.2152 - outbin_acc: 0.9177Epoch 00011: val_loss did not improve
# 9372/9372 [==============================] - 61s - loss: 0.0259 - outmap_loss: 0.0169 - outmap4_loss: 0.0249 - outmap5_loss: 0.0358 - outbin_loss: 0.2149 - outbin_acc: 0.9177 - val_loss: 0.0304 - val_outmap_loss: 0.0198 - val_outmap4_loss: 0.0274 - val_outmap5_loss: 0.0347 - val_outbin_loss: 0.3437 - val_outbin_acc: 0.8887
# Epoch 13/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0249 - outmap_loss: 0.0162 - outmap4_loss: 0.0245 - outmap5_loss: 0.0350 - outbin_loss: 0.2013 - outbin_acc: 0.9233Epoch 00012: val_loss did not improve
# 9372/9372 [==============================] - 62s - loss: 0.0249 - outmap_loss: 0.0162 - outmap4_loss: 0.0245 - outmap5_loss: 0.0351 - outbin_loss: 0.2016 - outbin_acc: 0.9232 - val_loss: 0.0332 - val_outmap_loss: 0.0225 - val_outmap4_loss: 0.0275 - val_outmap5_loss: 0.0361 - val_outbin_loss: 0.3410 - val_outbin_acc: 0.8772
# Epoch 14/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0240 - outmap_loss: 0.0157 - outmap4_loss: 0.0240 - outmap5_loss: 0.0347 - outbin_loss: 0.1775 - outbin_acc: 0.9302Epoch 00013: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0240 - outmap_loss: 0.0157 - outmap4_loss: 0.0240 - outmap5_loss: 0.0347 - outbin_loss: 0.1772 - outbin_acc: 0.9303 - val_loss: 0.0301 - val_outmap_loss: 0.0186 - val_outmap4_loss: 0.0272 - val_outmap5_loss: 0.0359 - val_outbin_loss: 0.4249 - val_outbin_acc: 0.8708
# Epoch 15/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0231 - outmap_loss: 0.0151 - outmap4_loss: 0.0237 - outmap5_loss: 0.0348 - outbin_loss: 0.1613 - outbin_acc: 0.9392Epoch 00014: val_loss improved from 0.02929 to 0.02927, saving model to weights.hdf5
# 9372/9372 [==============================] - 64s - loss: 0.0231 - outmap_loss: 0.0151 - outmap4_loss: 0.0236 - outmap5_loss: 0.0348 - outbin_loss: 0.1614 - outbin_acc: 0.9393 - val_loss: 0.0293 - val_outmap_loss: 0.0190 - val_outmap4_loss: 0.0254 - val_outmap5_loss: 0.0361 - val_outbin_loss: 0.3412 - val_outbin_acc: 0.8926
# Epoch 16/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0223 - outmap_loss: 0.0146 - outmap4_loss: 0.0232 - outmap5_loss: 0.0343 - outbin_loss: 0.1434 - outbin_acc: 0.9465Epoch 00015: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0224 - outmap_loss: 0.0146 - outmap4_loss: 0.0232 - outmap5_loss: 0.0344 - outbin_loss: 0.1442 - outbin_acc: 0.9463 - val_loss: 0.0295 - val_outmap_loss: 0.0192 - val_outmap4_loss: 0.0257 - val_outmap5_loss: 0.0363 - val_outbin_loss: 0.3404 - val_outbin_acc: 0.8811
# Epoch 17/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0218 - outmap_loss: 0.0143 - outmap4_loss: 0.0228 - outmap5_loss: 0.0342 - outbin_loss: 0.1261 - outbin_acc: 0.9537Epoch 00016: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0217 - outmap_loss: 0.0142 - outmap4_loss: 0.0227 - outmap5_loss: 0.0342 - outbin_loss: 0.1260 - outbin_acc: 0.9538 - val_loss: 0.0324 - val_outmap_loss: 0.0211 - val_outmap4_loss: 0.0284 - val_outmap5_loss: 0.0353 - val_outbin_loss: 0.3906 - val_outbin_acc: 0.8798
# Epoch 18/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0207 - outmap_loss: 0.0135 - outmap4_loss: 0.0223 - outmap5_loss: 0.0335 - outbin_loss: 0.1033 - outbin_acc: 0.9646Epoch 00017: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0207 - outmap_loss: 0.0135 - outmap4_loss: 0.0223 - outmap5_loss: 0.0336 - outbin_loss: 0.1033 - outbin_acc: 0.9646 - val_loss: 0.0330 - val_outmap_loss: 0.0209 - val_outmap4_loss: 0.0279 - val_outmap5_loss: 0.0357 - val_outbin_loss: 0.4781 - val_outbin_acc: 0.8529
# Epoch 19/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0204 - outmap_loss: 0.0132 - outmap4_loss: 0.0221 - outmap5_loss: 0.0334 - outbin_loss: 0.1025 - outbin_acc: 0.9644Epoch 00018: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0204 - outmap_loss: 0.0132 - outmap4_loss: 0.0221 - outmap5_loss: 0.0334 - outbin_loss: 0.1022 - outbin_acc: 0.9645 - val_loss: 0.0311 - val_outmap_loss: 0.0200 - val_outmap4_loss: 0.0263 - val_outmap5_loss: 0.0341 - val_outbin_loss: 0.4055 - val_outbin_acc: 0.8849
# Epoch 20/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0196 - outmap_loss: 0.0127 - outmap4_loss: 0.0218 - outmap5_loss: 0.0329 - outbin_loss: 0.0879 - outbin_acc: 0.9694Epoch 00019: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0196 - outmap_loss: 0.0127 - outmap4_loss: 0.0218 - outmap5_loss: 0.0329 - outbin_loss: 0.0880 - outbin_acc: 0.9694 - val_loss: 0.0345 - val_outmap_loss: 0.0220 - val_outmap4_loss: 0.0286 - val_outmap5_loss: 0.0354 - val_outbin_loss: 0.4973 - val_outbin_acc: 0.8772
# Epoch 21/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0192 - outmap_loss: 0.0125 - outmap4_loss: 0.0216 - outmap5_loss: 0.0324 - outbin_loss: 0.0773 - outbin_acc: 0.9728Epoch 00020: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0193 - outmap_loss: 0.0126 - outmap4_loss: 0.0216 - outmap5_loss: 0.0325 - outbin_loss: 0.0773 - outbin_acc: 0.9729 - val_loss: 0.0352 - val_outmap_loss: 0.0220 - val_outmap4_loss: 0.0289 - val_outmap5_loss: 0.0344 - val_outbin_loss: 0.5663 - val_outbin_acc: 0.8747
# Epoch 22/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0192 - outmap_loss: 0.0124 - outmap4_loss: 0.0216 - outmap5_loss: 0.0329 - outbin_loss: 0.0841 - outbin_acc: 0.9708Epoch 00021: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0192 - outmap_loss: 0.0124 - outmap4_loss: 0.0216 - outmap5_loss: 0.0329 - outbin_loss: 0.0840 - outbin_acc: 0.9709 - val_loss: 0.0369 - val_outmap_loss: 0.0240 - val_outmap4_loss: 0.0271 - val_outmap5_loss: 0.0354 - val_outbin_loss: 0.5670 - val_outbin_acc: 0.8645
# Epoch 23/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0184 - outmap_loss: 0.0119 - outmap4_loss: 0.0212 - outmap5_loss: 0.0325 - outbin_loss: 0.0676 - outbin_acc: 0.9775Epoch 00022: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0184 - outmap_loss: 0.0119 - outmap4_loss: 0.0212 - outmap5_loss: 0.0325 - outbin_loss: 0.0674 - outbin_acc: 0.9776 - val_loss: 0.0388 - val_outmap_loss: 0.0236 - val_outmap4_loss: 0.0329 - val_outmap5_loss: 0.0367 - val_outbin_loss: 0.6725 - val_outbin_acc: 0.8721
# Epoch 24/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0184 - outmap_loss: 0.0118 - outmap4_loss: 0.0212 - outmap5_loss: 0.0326 - outbin_loss: 0.0653 - outbin_acc: 0.9767Epoch 00023: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0183 - outmap_loss: 0.0118 - outmap4_loss: 0.0212 - outmap5_loss: 0.0325 - outbin_loss: 0.0657 - outbin_acc: 0.9765 - val_loss: 0.0366 - val_outmap_loss: 0.0233 - val_outmap4_loss: 0.0282 - val_outmap5_loss: 0.0359 - val_outbin_loss: 0.5875 - val_outbin_acc: 0.8772
# Epoch 25/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0178 - outmap_loss: 0.0115 - outmap4_loss: 0.0210 - outmap5_loss: 0.0318 - outbin_loss: 0.0543 - outbin_acc: 0.9815Epoch 00024: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0178 - outmap_loss: 0.0115 - outmap4_loss: 0.0210 - outmap5_loss: 0.0318 - outbin_loss: 0.0542 - outbin_acc: 0.9815 - val_loss: 0.0344 - val_outmap_loss: 0.0212 - val_outmap4_loss: 0.0274 - val_outmap5_loss: 0.0345 - val_outbin_loss: 0.5935 - val_outbin_acc: 0.8836
# Epoch 26/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0170 - outmap_loss: 0.0109 - outmap4_loss: 0.0204 - outmap5_loss: 0.0315 - outbin_loss: 0.0411 - outbin_acc: 0.9860Epoch 00025: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0170 - outmap_loss: 0.0109 - outmap4_loss: 0.0204 - outmap5_loss: 0.0314 - outbin_loss: 0.0411 - outbin_acc: 0.9859 - val_loss: 0.0327 - val_outmap_loss: 0.0202 - val_outmap4_loss: 0.0271 - val_outmap5_loss: 0.0338 - val_outbin_loss: 0.5394 - val_outbin_acc: 0.8887
# Epoch 27/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0171 - outmap_loss: 0.0109 - outmap4_loss: 0.0205 - outmap5_loss: 0.0316 - outbin_loss: 0.0454 - outbin_acc: 0.9828Epoch 00026: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0171 - outmap_loss: 0.0110 - outmap4_loss: 0.0205 - outmap5_loss: 0.0316 - outbin_loss: 0.0454 - outbin_acc: 0.9826 - val_loss: 0.0346 - val_outmap_loss: 0.0213 - val_outmap4_loss: 0.0284 - val_outmap5_loss: 0.0365 - val_outbin_loss: 0.5866 - val_outbin_acc: 0.8824
# Epoch 28/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0174 - outmap_loss: 0.0111 - outmap4_loss: 0.0208 - outmap5_loss: 0.0324 - outbin_loss: 0.0517 - outbin_acc: 0.9819Epoch 00027: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0174 - outmap_loss: 0.0111 - outmap4_loss: 0.0208 - outmap5_loss: 0.0324 - outbin_loss: 0.0520 - outbin_acc: 0.9818 - val_loss: 0.0339 - val_outmap_loss: 0.0214 - val_outmap4_loss: 0.0287 - val_outmap5_loss: 0.0354 - val_outbin_loss: 0.5016 - val_outbin_acc: 0.8824
# Epoch 29/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0163 - outmap_loss: 0.0104 - outmap4_loss: 0.0202 - outmap5_loss: 0.0317 - outbin_loss: 0.0288 - outbin_acc: 0.9900Epoch 00028: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0163 - outmap_loss: 0.0104 - outmap4_loss: 0.0202 - outmap5_loss: 0.0316 - outbin_loss: 0.0293 - outbin_acc: 0.9900 - val_loss: 0.0399 - val_outmap_loss: 0.0259 - val_outmap4_loss: 0.0287 - val_outmap5_loss: 0.0341 - val_outbin_loss: 0.6529 - val_outbin_acc: 0.8785
# Epoch 30/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0159 - outmap_loss: 0.0102 - outmap4_loss: 0.0199 - outmap5_loss: 0.0309 - outbin_loss: 0.0240 - outbin_acc: 0.9928Epoch 00029: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0159 - outmap_loss: 0.0102 - outmap4_loss: 0.0199 - outmap5_loss: 0.0308 - outbin_loss: 0.0240 - outbin_acc: 0.9929 - val_loss: 0.0363 - val_outmap_loss: 0.0214 - val_outmap4_loss: 0.0277 - val_outmap5_loss: 0.0375 - val_outbin_loss: 0.7436 - val_outbin_acc: 0.8632
# Epoch 31/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0161 - outmap_loss: 0.0102 - outmap4_loss: 0.0200 - outmap5_loss: 0.0311 - outbin_loss: 0.0298 - outbin_acc: 0.9909Epoch 00030: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0161 - outmap_loss: 0.0102 - outmap4_loss: 0.0200 - outmap5_loss: 0.0312 - outbin_loss: 0.0297 - outbin_acc: 0.9909 - val_loss: 0.0380 - val_outmap_loss: 0.0228 - val_outmap4_loss: 0.0308 - val_outmap5_loss: 0.0362 - val_outbin_loss: 0.7208 - val_outbin_acc: 0.8836
# Epoch 32/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0160 - outmap_loss: 0.0101 - outmap4_loss: 0.0200 - outmap5_loss: 0.0311 - outbin_loss: 0.0357 - outbin_acc: 0.9864Epoch 00031: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0160 - outmap_loss: 0.0101 - outmap4_loss: 0.0201 - outmap5_loss: 0.0311 - outbin_loss: 0.0358 - outbin_acc: 0.9864 - val_loss: 0.0361 - val_outmap_loss: 0.0222 - val_outmap4_loss: 0.0280 - val_outmap5_loss: 0.0342 - val_outbin_loss: 0.6539 - val_outbin_acc: 0.8657
# Epoch 33/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0158 - outmap_loss: 0.0099 - outmap4_loss: 0.0198 - outmap5_loss: 0.0312 - outbin_loss: 0.0279 - outbin_acc: 0.9904Epoch 00032: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0158 - outmap_loss: 0.0100 - outmap4_loss: 0.0199 - outmap5_loss: 0.0312 - outbin_loss: 0.0278 - outbin_acc: 0.9904 - val_loss: 0.0407 - val_outmap_loss: 0.0258 - val_outmap4_loss: 0.0290 - val_outmap5_loss: 0.0350 - val_outbin_loss: 0.7314 - val_outbin_acc: 0.8708
# Epoch 34/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0157 - outmap_loss: 0.0099 - outmap4_loss: 0.0199 - outmap5_loss: 0.0311 - outbin_loss: 0.0282 - outbin_acc: 0.9904Epoch 00033: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0157 - outmap_loss: 0.0099 - outmap4_loss: 0.0198 - outmap5_loss: 0.0311 - outbin_loss: 0.0281 - outbin_acc: 0.9904 - val_loss: 0.0391 - val_outmap_loss: 0.0243 - val_outmap4_loss: 0.0282 - val_outmap5_loss: 0.0341 - val_outbin_loss: 0.7458 - val_outbin_acc: 0.8606
# Epoch 35/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0156 - outmap_loss: 0.0099 - outmap4_loss: 0.0197 - outmap5_loss: 0.0308 - outbin_loss: 0.0253 - outbin_acc: 0.9925Epoch 00034: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0156 - outmap_loss: 0.0099 - outmap4_loss: 0.0196 - outmap5_loss: 0.0308 - outbin_loss: 0.0254 - outbin_acc: 0.9924 - val_loss: 0.0430 - val_outmap_loss: 0.0251 - val_outmap4_loss: 0.0293 - val_outmap5_loss: 0.0367 - val_outbin_loss: 1.0198 - val_outbin_acc: 0.8286
# Epoch 36/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0154 - outmap_loss: 0.0096 - outmap4_loss: 0.0196 - outmap5_loss: 0.0306 - outbin_loss: 0.0261 - outbin_acc: 0.9911Epoch 00035: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0154 - outmap_loss: 0.0096 - outmap4_loss: 0.0196 - outmap5_loss: 0.0306 - outbin_loss: 0.0261 - outbin_acc: 0.9911 - val_loss: 0.0410 - val_outmap_loss: 0.0248 - val_outmap4_loss: 0.0288 - val_outmap5_loss: 0.0360 - val_outbin_loss: 0.8581 - val_outbin_acc: 0.8427
# Epoch 37/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0151 - outmap_loss: 0.0095 - outmap4_loss: 0.0196 - outmap5_loss: 0.0308 - outbin_loss: 0.0243 - outbin_acc: 0.9930Epoch 00036: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0151 - outmap_loss: 0.0094 - outmap4_loss: 0.0196 - outmap5_loss: 0.0308 - outbin_loss: 0.0242 - outbin_acc: 0.9931 - val_loss: 0.0410 - val_outmap_loss: 0.0243 - val_outmap4_loss: 0.0331 - val_outmap5_loss: 0.0342 - val_outbin_loss: 0.8306 - val_outbin_acc: 0.8875
# Epoch 38/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0145 - outmap_loss: 0.0090 - outmap4_loss: 0.0192 - outmap5_loss: 0.0300 - outbin_loss: 0.0106 - outbin_acc: 0.9966Epoch 00037: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0145 - outmap_loss: 0.0090 - outmap4_loss: 0.0192 - outmap5_loss: 0.0300 - outbin_loss: 0.0106 - outbin_acc: 0.9966 - val_loss: 0.0398 - val_outmap_loss: 0.0237 - val_outmap4_loss: 0.0298 - val_outmap5_loss: 0.0344 - val_outbin_loss: 0.8478 - val_outbin_acc: 0.8811
# Epoch 39/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0150 - outmap_loss: 0.0093 - outmap4_loss: 0.0196 - outmap5_loss: 0.0305 - outbin_loss: 0.0253 - outbin_acc: 0.9908Epoch 00038: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0150 - outmap_loss: 0.0093 - outmap4_loss: 0.0196 - outmap5_loss: 0.0305 - outbin_loss: 0.0252 - outbin_acc: 0.9908 - val_loss: 0.0450 - val_outmap_loss: 0.0293 - val_outmap4_loss: 0.0324 - val_outmap5_loss: 0.0366 - val_outbin_loss: 0.7427 - val_outbin_acc: 0.8785
# Epoch 40/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0155 - outmap_loss: 0.0097 - outmap4_loss: 0.0198 - outmap5_loss: 0.0306 - outbin_loss: 0.0333 - outbin_acc: 0.9889Epoch 00039: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0155 - outmap_loss: 0.0097 - outmap4_loss: 0.0198 - outmap5_loss: 0.0306 - outbin_loss: 0.0333 - outbin_acc: 0.9889 - val_loss: 0.0394 - val_outmap_loss: 0.0243 - val_outmap4_loss: 0.0288 - val_outmap5_loss: 0.0340 - val_outbin_loss: 0.7630 - val_outbin_acc: 0.8862
# Epoch 41/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0144 - outmap_loss: 0.0089 - outmap4_loss: 0.0192 - outmap5_loss: 0.0300 - outbin_loss: 0.0143 - outbin_acc: 0.9945Epoch 00040: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0144 - outmap_loss: 0.0089 - outmap4_loss: 0.0192 - outmap5_loss: 0.0300 - outbin_loss: 0.0146 - outbin_acc: 0.9945 - val_loss: 0.0481 - val_outmap_loss: 0.0289 - val_outmap4_loss: 0.0343 - val_outmap5_loss: 0.0368 - val_outbin_loss: 1.0497 - val_outbin_acc: 0.8670
# Epoch 42/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0154 - outmap_loss: 0.0096 - outmap4_loss: 0.0198 - outmap5_loss: 0.0309 - outbin_loss: 0.0353 - outbin_acc: 0.9867Epoch 00041: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0154 - outmap_loss: 0.0096 - outmap4_loss: 0.0198 - outmap5_loss: 0.0309 - outbin_loss: 0.0352 - outbin_acc: 0.9868 - val_loss: 0.0398 - val_outmap_loss: 0.0229 - val_outmap4_loss: 0.0277 - val_outmap5_loss: 0.0336 - val_outbin_loss: 0.9713 - val_outbin_acc: 0.8517
# Epoch 43/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0145 - outmap_loss: 0.0090 - outmap4_loss: 0.0192 - outmap5_loss: 0.0299 - outbin_loss: 0.0178 - outbin_acc: 0.9934Epoch 00042: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0145 - outmap_loss: 0.0090 - outmap4_loss: 0.0192 - outmap5_loss: 0.0299 - outbin_loss: 0.0178 - outbin_acc: 0.9934 - val_loss: 0.0479 - val_outmap_loss: 0.0298 - val_outmap4_loss: 0.0348 - val_outmap5_loss: 0.0360 - val_outbin_loss: 0.9287 - val_outbin_acc: 0.8708
# Epoch 44/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0147 - outmap_loss: 0.0091 - outmap4_loss: 0.0193 - outmap5_loss: 0.0303 - outbin_loss: 0.0194 - outbin_acc: 0.9926Epoch 00043: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0147 - outmap_loss: 0.0091 - outmap4_loss: 0.0193 - outmap5_loss: 0.0303 - outbin_loss: 0.0193 - outbin_acc: 0.9926 - val_loss: 0.0389 - val_outmap_loss: 0.0238 - val_outmap4_loss: 0.0275 - val_outmap5_loss: 0.0338 - val_outbin_loss: 0.7910 - val_outbin_acc: 0.8593
# Epoch 45/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0144 - outmap_loss: 0.0089 - outmap4_loss: 0.0193 - outmap5_loss: 0.0301 - outbin_loss: 0.0175 - outbin_acc: 0.9938Epoch 00044: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0144 - outmap_loss: 0.0089 - outmap4_loss: 0.0193 - outmap5_loss: 0.0301 - outbin_loss: 0.0174 - outbin_acc: 0.9938 - val_loss: 0.0405 - val_outmap_loss: 0.0246 - val_outmap4_loss: 0.0295 - val_outmap5_loss: 0.0347 - val_outbin_loss: 0.8329 - val_outbin_acc: 0.8875
# Epoch 46/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0148 - outmap_loss: 0.0092 - outmap4_loss: 0.0192 - outmap5_loss: 0.0300 - outbin_loss: 0.0274 - outbin_acc: 0.9914Epoch 00045: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0148 - outmap_loss: 0.0092 - outmap4_loss: 0.0192 - outmap5_loss: 0.0300 - outbin_loss: 0.0274 - outbin_acc: 0.9915 - val_loss: 0.0416 - val_outmap_loss: 0.0237 - val_outmap4_loss: 0.0305 - val_outmap5_loss: 0.0405 - val_outbin_loss: 0.9744 - val_outbin_acc: 0.8376
# Epoch 47/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0144 - outmap_loss: 0.0089 - outmap4_loss: 0.0191 - outmap5_loss: 0.0304 - outbin_loss: 0.0192 - outbin_acc: 0.9946Epoch 00046: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0144 - outmap_loss: 0.0089 - outmap4_loss: 0.0191 - outmap5_loss: 0.0304 - outbin_loss: 0.0192 - outbin_acc: 0.9947 - val_loss: 0.0431 - val_outmap_loss: 0.0261 - val_outmap4_loss: 0.0317 - val_outmap5_loss: 0.0340 - val_outbin_loss: 0.8983 - val_outbin_acc: 0.8811
# Epoch 48/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0142 - outmap_loss: 0.0087 - outmap4_loss: 0.0191 - outmap5_loss: 0.0298 - outbin_loss: 0.0180 - outbin_acc: 0.9927Epoch 00047: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0142 - outmap_loss: 0.0087 - outmap4_loss: 0.0191 - outmap5_loss: 0.0298 - outbin_loss: 0.0180 - outbin_acc: 0.9927 - val_loss: 0.0407 - val_outmap_loss: 0.0254 - val_outmap4_loss: 0.0302 - val_outmap5_loss: 0.0349 - val_outbin_loss: 0.7512 - val_outbin_acc: 0.8836
# Epoch 49/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0143 - outmap_loss: 0.0088 - outmap4_loss: 0.0190 - outmap5_loss: 0.0300 - outbin_loss: 0.0193 - outbin_acc: 0.9929Epoch 00048: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0143 - outmap_loss: 0.0088 - outmap4_loss: 0.0191 - outmap5_loss: 0.0300 - outbin_loss: 0.0193 - outbin_acc: 0.9930 - val_loss: 0.0385 - val_outmap_loss: 0.0235 - val_outmap4_loss: 0.0286 - val_outmap5_loss: 0.0335 - val_outbin_loss: 0.7676 - val_outbin_acc: 0.8824
# Epoch 50/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0139 - outmap_loss: 0.0086 - outmap4_loss: 0.0188 - outmap5_loss: 0.0296 - outbin_loss: 0.0142 - outbin_acc: 0.9965Epoch 00049: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0140 - outmap_loss: 0.0086 - outmap4_loss: 0.0188 - outmap5_loss: 0.0296 - outbin_loss: 0.0142 - outbin_acc: 0.9965 - val_loss: 0.0396 - val_outmap_loss: 0.0237 - val_outmap4_loss: 0.0304 - val_outmap5_loss: 0.0340 - val_outbin_loss: 0.8044 - val_outbin_acc: 0.8836
# Epoch 51/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0143 - outmap_loss: 0.0088 - outmap4_loss: 0.0191 - outmap5_loss: 0.0299 - outbin_loss: 0.0193 - outbin_acc: 0.9935Epoch 00050: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0143 - outmap_loss: 0.0088 - outmap4_loss: 0.0191 - outmap5_loss: 0.0299 - outbin_loss: 0.0193 - outbin_acc: 0.9935 - val_loss: 0.0447 - val_outmap_loss: 0.0273 - val_outmap4_loss: 0.0325 - val_outmap5_loss: 0.0349 - val_outbin_loss: 0.9176 - val_outbin_acc: 0.8939
# Epoch 52/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0134 - outmap_loss: 0.0081 - outmap4_loss: 0.0186 - outmap5_loss: 0.0293 - outbin_loss: 0.0056 - outbin_acc: 0.9983Epoch 00051: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0134 - outmap_loss: 0.0081 - outmap4_loss: 0.0186 - outmap5_loss: 0.0293 - outbin_loss: 0.0056 - outbin_acc: 0.9983 - val_loss: 0.0431 - val_outmap_loss: 0.0251 - val_outmap4_loss: 0.0314 - val_outmap5_loss: 0.0342 - val_outbin_loss: 0.9973 - val_outbin_acc: 0.8824
# Epoch 53/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0145 - outmap_loss: 0.0089 - outmap4_loss: 0.0191 - outmap5_loss: 0.0299 - outbin_loss: 0.0311 - outbin_acc: 0.9904Epoch 00052: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0145 - outmap_loss: 0.0089 - outmap4_loss: 0.0192 - outmap5_loss: 0.0299 - outbin_loss: 0.0312 - outbin_acc: 0.9903 - val_loss: 0.0363 - val_outmap_loss: 0.0223 - val_outmap4_loss: 0.0287 - val_outmap5_loss: 0.0341 - val_outbin_loss: 0.6536 - val_outbin_acc: 0.8760
# Epoch 54/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0138 - outmap_loss: 0.0084 - outmap4_loss: 0.0188 - outmap5_loss: 0.0296 - outbin_loss: 0.0138 - outbin_acc: 0.9955Epoch 00053: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0138 - outmap_loss: 0.0084 - outmap4_loss: 0.0188 - outmap5_loss: 0.0296 - outbin_loss: 0.0138 - outbin_acc: 0.9955 - val_loss: 0.0418 - val_outmap_loss: 0.0249 - val_outmap4_loss: 0.0292 - val_outmap5_loss: 0.0345 - val_outbin_loss: 0.9324 - val_outbin_acc: 0.8657
# Epoch 55/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0137 - outmap_loss: 0.0084 - outmap4_loss: 0.0188 - outmap5_loss: 0.0296 - outbin_loss: 0.0124 - outbin_acc: 0.9953Epoch 00054: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0137 - outmap_loss: 0.0084 - outmap4_loss: 0.0189 - outmap5_loss: 0.0297 - outbin_loss: 0.0124 - outbin_acc: 0.9953 - val_loss: 0.0415 - val_outmap_loss: 0.0252 - val_outmap4_loss: 0.0288 - val_outmap5_loss: 0.0346 - val_outbin_loss: 0.8802 - val_outbin_acc: 0.8734
# Epoch 56/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0138 - outmap_loss: 0.0084 - outmap4_loss: 0.0188 - outmap5_loss: 0.0296 - outbin_loss: 0.0150 - outbin_acc: 0.9953Epoch 00055: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0138 - outmap_loss: 0.0084 - outmap4_loss: 0.0188 - outmap5_loss: 0.0296 - outbin_loss: 0.0150 - outbin_acc: 0.9953 - val_loss: 0.0452 - val_outmap_loss: 0.0247 - val_outmap4_loss: 0.0338 - val_outmap5_loss: 0.0369 - val_outbin_loss: 1.1891 - val_outbin_acc: 0.8734
# Epoch 57/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0142 - outmap_loss: 0.0086 - outmap4_loss: 0.0191 - outmap5_loss: 0.0300 - outbin_loss: 0.0228 - outbin_acc: 0.9925Epoch 00056: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0141 - outmap_loss: 0.0086 - outmap4_loss: 0.0191 - outmap5_loss: 0.0300 - outbin_loss: 0.0227 - outbin_acc: 0.9925 - val_loss: 0.0406 - val_outmap_loss: 0.0245 - val_outmap4_loss: 0.0297 - val_outmap5_loss: 0.0341 - val_outbin_loss: 0.8470 - val_outbin_acc: 0.8849
# Epoch 58/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0137 - outmap_loss: 0.0083 - outmap4_loss: 0.0187 - outmap5_loss: 0.0295 - outbin_loss: 0.0156 - outbin_acc: 0.9961Epoch 00057: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0137 - outmap_loss: 0.0083 - outmap4_loss: 0.0187 - outmap5_loss: 0.0295 - outbin_loss: 0.0156 - outbin_acc: 0.9962 - val_loss: 0.0396 - val_outmap_loss: 0.0236 - val_outmap4_loss: 0.0299 - val_outmap5_loss: 0.0330 - val_outbin_loss: 0.8319 - val_outbin_acc: 0.8811
# Epoch 59/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0138 - outmap_loss: 0.0084 - outmap4_loss: 0.0187 - outmap5_loss: 0.0293 - outbin_loss: 0.0147 - outbin_acc: 0.9954Epoch 00058: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0138 - outmap_loss: 0.0084 - outmap4_loss: 0.0187 - outmap5_loss: 0.0293 - outbin_loss: 0.0146 - outbin_acc: 0.9954 - val_loss: 0.0430 - val_outmap_loss: 0.0248 - val_outmap4_loss: 0.0320 - val_outmap5_loss: 0.0345 - val_outbin_loss: 0.9980 - val_outbin_acc: 0.8785
# Epoch 60/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0130 - outmap_loss: 0.0078 - outmap4_loss: 0.0184 - outmap5_loss: 0.0289 - outbin_loss: 0.0032 - outbin_acc: 0.9987Epoch 00059: val_loss did not improve
# 9372/9372 [==============================] - 64s - loss: 0.0130 - outmap_loss: 0.0078 - outmap4_loss: 0.0184 - outmap5_loss: 0.0289 - outbin_loss: 0.0032 - outbin_acc: 0.9987 - val_loss: 0.0425 - val_outmap_loss: 0.0245 - val_outmap4_loss: 0.0288 - val_outmap5_loss: 0.0330 - val_outbin_loss: 1.0624 - val_outbin_acc: 0.8772

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture_final.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights_final.hdf5'))

# %%
def compute_scores_map(X, Y):
    Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X)
    
    map_threshs = np.linspace(0, 1, num=21)
    bin_threshs = np.linspace(0, 1, num=21)
    
    scores = np.zeros((len(map_threshs), len(bin_threshs)))
    for i in range(len(map_threshs)):
        for j in range(len(bin_threshs)):
            _Y_pred = Y_pred > map_threshs[i]
            
            for k in range(_Y_pred.shape[0]):
                # Clear prediction where we detect to little pixels
                if np.sum(_Y_pred[k]) < 150 or Y_pred_binary[k] < bin_threshs[j]:
                    _Y_pred[k,:] = 0
            
            scores[i, j] = utils.average_dice_coefficient(_Y_pred, Y)
    
    pl.imshow(scores, interpolation='nearest')
    pl.yticks(np.arange(len(map_threshs)) + 0.5, ['%.2f' % v for v in map_threshs])
    pl.xticks(np.arange(len(bin_threshs)) + 0.5, ['%.2f' % v for v in bin_threshs], rotation=90)
    pl.ylabel('map thresh')
    pl.xlabel('bin thresh')
    pl.colorbar()
    
    best_i, best_j = np.unravel_index(np.argmax(scores.ravel()), scores.shape)
    best_map_thresh = map_threshs[best_i]
    best_bin_thresh = bin_threshs[best_j]
    return best_map_thresh, best_bin_thresh

map_thresh, bin_thresh = compute_scores_map(X_test, Y_test)
print 'Best map_thresh=%f, bin_thresh=%f' % (map_thresh, bin_thresh)
# Out:
# Best map_thresh=0.500000, bin_thresh=0.800000

# %%
#map_thresh = 0.5
#bin_thresh = 0.7

# %%
def predict(X, map_thresh, bin_thresh):
    Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > map_thresh
    for i in range(Y_pred.shape[0]):
        if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < bin_thresh:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test, map_thresh, bin_thresh)
Y_full_pred, Y_full_pred_proba, Y_full_pred_binary = predict((X_full - X_avg)/X_std, map_thresh, bin_thresh)

print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "avg test set score : ", utils.average_dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
print "avg full set score : ", utils.average_dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.718379253046
# avg test set score :  0.84724109624
# full set score :  0.708660420646
# avg full set score :  0.808188527615

# %%
_ = pl.hist(Y_pred_binary)

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[40:45]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise.
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(30):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        #print grads_value.max()
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, pred44, pred88, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 15
img, pred_map = dream_output(Y_full[i])
pl.figure(figsize=(12, 4))
pl.subplot(141)
pl.imshow(X_full[i].squeeze(), cmap=cm.gray)
pl.subplot(142)
pl.imshow(Y_full[i].squeeze())
pl.subplot(143)
pl.imshow(img, cmap=cm.gray)
pl.subplot(144)
pl.imshow(pred_map.squeeze())

# %%
def dream_layer_filter(layer_name, filter_index):

    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(4):
        pl.subplot(1, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
_d = np.load('../data/data_128_test.npz')
X_submit = _d['X']
X_submit = (X_submit - X_avg) / X_std

for m_t, b_t in [(0.5, 0), (0.5, 0.5), (0.5, 0.8)]:
    _pred, _pred_proba, _pred_binary = predict(X_submit[:,None,:,:], m_t, b_t)
    # Turn labels into boolean present/missing
    _pred_binary = np.sum(np.sum(np.sum(_pred, axis=2), axis=1), axis=1) > 0
    _pred_binary = _pred_binary.astype(np.float32)
    per_mask = (100 * np.count_nonzero(_pred_binary) / float(len(_pred_binary)))
    print 'map_thresh=%f, bin_thresh=%f => %.2f%% with masks' % (m_t, b_t, per_mask)
# Out:
# map_thresh=0.500000, bin_thresh=0.000000 => 40.01% with masks
# map_thresh=0.500000, bin_thresh=0.500000 => 36.86% with masks
# map_thresh=0.500000, bin_thresh=0.800000 => 35.89% with masks

# %%
map_thresh = 0.5
bin_thresh = 0

# %%
if True:
    import cv2
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(12,12))
    
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    X_submit = (X_submit - X_avg) / X_std
    test_fnames = _d['test_fnames']
    # bin_thresh
    Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:],
                                                  map_thresh, bin_thresh)
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = (Y_pred[i].squeeze() * 255).astype(np.uint8)
        imre = cv2.morphologyEx(imre, cv2.MORPH_CLOSE, kernel)
        imre = cv2.resize(imre, (580, 420))
        
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
        
        if i % 10 == 0:
            print '\r%d / %d' % (i, len(test_fnames)),
            sys.stdout.flush()
# Out:
# 5500 / 5508

# %%
# Turn labels into boolean present/missing
pred_binary = np.sum(np.sum(np.sum(Y_pred, axis=2), axis=1), axis=1) > 0
pred_binary = pred_binary.astype(np.float32)
print "%.2f%% with masks" % (100 * np.count_nonzero(pred_binary) / float(len(pred_binary)))
# Out:
# 40.01% with masks

# %% [markdown]
# ## Stats on predicted masks

# %%
# on Y_full
nbp_pixels = np.sum(np.sum(np.sum(Y_full, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
pl.xlim((0, 1200))
# Out:
# (0, 1200)

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
pl.xlim((0, 1200))
# Out:
# (0, 1200)
