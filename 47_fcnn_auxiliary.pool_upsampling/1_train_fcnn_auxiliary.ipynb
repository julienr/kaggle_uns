# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']
X_pids = _d['pids']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
print X.dtype
print Y.dtype
# Out:
# (3906, 128, 128)
# (3906, 128, 128)
# float32
# float32

# %%
if False:
    # Split patients in train/test
    train_pids, test_pids = train_test_split(np.unique(X_pids), test_size=0.1)
    print train_pids
    print test_pids
    
    train_indices = np.flatnonzero(np.in1d(X_pids, train_pids))
    test_indices = np.flatnonzero(np.in1d(X_pids, test_pids))
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]
else:
    nsamples = X.shape[0]

    #train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]

# %%
import skimage.transform as sktransf

def rand_float(rng):
    return rng[0] + np.random.random() * (rng[1] - rng[0])

def generate_image(X_img, Y_img, angle_range=None, zoom_range=None, shear_range=None, horiz_shift_range=None,
                   vert_shift_range=None):
    """
    Randomly shift an image by resizing and then random croping
    the resized image
    """
    if angle_range is None:
        angle_range = (-5, 5)
    if zoom_range is None:
        zoom_range = (0.8, 1.2)
    if shear_range is None:
        shear_range = (-5, 5) # shear angle in degrees
    if horiz_shift_range is None:
        horiz_shift_range = (-5, 5)
    if vert_shift_range is None:
        vert_shift_range = (-5, 5)
    inshape = X_img.shape
    
    X2 = X_img.copy()
    Y2 = Y_img.copy()
    
    # -- random rotation
    angle = np.deg2rad(rand_float(angle_range))
    zoom = rand_float(zoom_range)
    shear = np.deg2rad(rand_float(shear_range))
    horiz_shift = rand_float(horiz_shift_range)
    vert_shift = rand_float(vert_shift_range)
    
    tform = sktransf.AffineTransform(
        scale=(zoom, zoom),
        rotation=angle,
        shear=shear,
        translation=(horiz_shift, vert_shift)
    )
    X2 = sktransf.warp(X2, tform, order=5, mode='edge')
    Y2 = sktransf.warp(Y2, tform, order=1)

    # gaussian noise
    #noise_scale = rand_float((0, 0.1))
    #X2 += np.random.normal(scale=noise_scale, size=X2.shape)
    Y2 = Y2 > 0.5
    return X2[None,:,:].astype(np.float32), Y2[None,:,:].astype(np.float32)

X_train_augmented = []
Y_train_augmented = []
for i in range(X_train.shape[0]):
    if i % 10 == 0:
        print '\r%d / %d' % (i, X_train.shape[0]),
        sys.stdout.flush()
    X_train_augmented.append(X_train[i])
    Y_train_augmented.append(Y_train[i])
    for j in range(2):
        X2, Y2 = generate_image(X_train[i].squeeze(), Y_train[i].squeeze())
        X_train_augmented.append(X2)
        Y_train_augmented.append(Y2)
# Out:
# 3510 / 3515

# %%
X_train = np.array(X_train_augmented, dtype=np.float32)
Y_train = np.array(Y_train_augmented, dtype=np.float32)

Y_train_binary = np.sum(np.sum(Y_train.squeeze(), axis=2), axis=1) > 0
Y_train_binary = Y_train_binary.astype(np.float32)
Y_train_binary = Y_train_binary[:,None]

# %%
print X_train.shape
print Y_train.shape
print X_test.shape
print X_train.min(), X_train.max()
# Out:
# (10545, 1, 128, 128)
# (10545, 1, 128, 128)
# (391, 1, 128, 128)
# 0.0 1.0

# %%
import cv2
def _resize(Y, outshape):
    return cv2.resize(Y.squeeze(), outshape, interpolation=cv2.INTER_AREA)[None, :, :]
Y_train_64 = np.array([_resize(img, (64, 64)) for img in Y_train])
Y_test_64 = np.array([_resize(img, (64, 64)) for img in Y_test])
Y_train_32 = np.array([_resize(img, (32, 32)) for img in Y_train])
Y_test_32 = np.array([_resize(img, (32, 32)) for img in Y_test])

# %%
with_bp = np.flatnonzero(np.sum(np.sum(np.sum(Y_train, axis=1), axis=1), axis=1))

# %%
for bpi in range(11, 14):
    i = with_bp[bpi]
    pl.figure(figsize=(16, 4))
    pl.subplot(141)
    pl.imshow(X_train[i].squeeze())
    pl.subplot(142)
    pl.imshow(Y_train[i].squeeze())
    pl.subplot(143)
    pl.imshow(Y_train_64[i].squeeze(), interpolation='nearest')
    pl.colorbar()
    pl.subplot(144)
    pl.imshow(Y_train_32[i].squeeze(), interpolation='nearest')
    pl.colorbar()

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float32'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense
from keras.layers import LeakyReLU, BatchNormalization
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
import keras.backend as K
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
from keras.layers import Layer, InputSpec
import keras.initializations
import keras.backend as K

class Maxout2D(Layer):
    def __init__(self, output_dim, cardinality, init='glorot_uniform', **kwargs):
        super(Maxout2D, self).__init__(**kwargs)
        # the k of the maxout paper
        self.cardinality = cardinality
        # the m of the maxout paper
        self.output_dim = output_dim
        self.init = keras.initializations.get(init)
    
    def build(self, input_shape):
        self.input_dim = input_shape[1]
        self.input_spec = [InputSpec(dtype=K.floatx(),
                                     shape=(None, input_shape[1], input_shape[2], input_shape[3]))]
        self.W = self.init((self.input_dim, self.output_dim, self.cardinality),
                           name='{}_W'.format(self.name))
        self.b = K.zeros((self.output_dim, self.cardinality))
        self.trainable_weights = [self.W, self.b]
              
    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        # flatten the spatial dimensions
        flat_x = K.reshape(x, (-1, input_shape[1], input_shape[2] * input_shape[3]))
        output = K.dot(
            K.permute_dimensions(flat_x, (0, 2, 1)),
            K.permute_dimensions(self.W, (1, 0, 2))
        )
        output += K.reshape(self.b, (1, 1, self.output_dim, self.cardinality))
        output = K.max(output, axis=3)
        output = output.transpose(0, 2, 1)
        output = K.reshape(output, (-1, self.output_dim, input_shape[2], input_shape[3]))
        return output
    
    def get_output_shape_for(self, input_shape):
        return (input_shape[0], self.output_dim, input_shape[2], input_shape[3])
    
    def get_config(self):
        config = {
            'output_dim': self.output_dim,
            'cardinality': self.cardinality
        }
        base_config = super(Maxout2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
input_img = x = Input(shape=input_shape, name='input_img')
x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(input_img)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool1 = x = MaxPooling2D((2, 2), name='pool1')(x)

x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool2 = x = MaxPooling2D((2, 2), name='pool2')(x)

x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool3 = x = MaxPooling2D((2, 2), name='pool3')(x)

# -- binary presence part
x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(pool5)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

x = pool5
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(8, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool4], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(8, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool3], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(8, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(8, 2)(x)
outmap32 = Convolution2D(1, 1, 1, border_mode='same', activation='sigmoid', name='outmap32')(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(8, 2)(x)
outmap64 = Convolution2D(1, 1, 1, border_mode='same', activation='sigmoid', name='outmap64')(x)
x = UpSampling2D((2, 2))(x)

x = Dropout(0.25)(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outmap64, outmap32, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
metrics={'outbin': 'accuracy'}
model.compile(optimizer='adam', loss='binary_crossentropy',
              loss_weights=[1., 0.2, 0.05, 0.01], metrics=metrics)

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)    (None, 32, 128, 128)320         input_img[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)    (None, 32, 128, 128)9248        convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# maxout2d_1 (Maxout2D)              (None, 16, 128, 128)1056        convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)               (None, 16, 64, 64)  0           maxout2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)                (None, 16, 64, 64)  0           pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)    (None, 32, 64, 64)  4640        dropout_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)    (None, 32, 64, 64)  9248        convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# maxout2d_2 (Maxout2D)              (None, 16, 64, 64)  1056        convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)               (None, 16, 32, 32)  0           maxout2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)                (None, 16, 32, 32)  0           pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)    (None, 32, 32, 32)  4640        dropout_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_6 (Convolution2D)    (None, 32, 32, 32)  9248        convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# maxout2d_3 (Maxout2D)              (None, 16, 32, 32)  1056        convolution2d_6[0][0]
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)               (None, 16, 16, 16)  0           maxout2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)                (None, 16, 16, 16)  0           pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_7 (Convolution2D)    (None, 32, 16, 16)  4640        dropout_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8 (Convolution2D)    (None, 32, 16, 16)  9248        convolution2d_7[0][0]
# ____________________________________________________________________________________________________
# maxout2d_4 (Maxout2D)              (None, 16, 16, 16)  1056        convolution2d_8[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)               (None, 16, 8, 8)    0           maxout2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)                (None, 16, 8, 8)    0           pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_9 (Convolution2D)    (None, 32, 8, 8)    4640        dropout_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_10 (Convolution2D)   (None, 32, 8, 8)    9248        convolution2d_9[0][0]
# ____________________________________________________________________________________________________
# maxout2d_5 (Maxout2D)              (None, 16, 8, 8)    1056        convolution2d_10[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)               (None, 16, 4, 4)    0           maxout2d_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_11 (Convolution2D)   (None, 16, 4, 4)    2320        pool5[0][0]
# ____________________________________________________________________________________________________
# maxout2d_6 (Maxout2D)              (None, 8, 4, 4)     272         convolution2d_11[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_1 (UpSampling2D)      (None, 8, 8, 8)     0           maxout2d_6[0][0]
# ____________________________________________________________________________________________________
# merge_1 (Merge)                    (None, 24, 8, 8)    0           upsampling2d_1[0][0]
#                                                                    pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_12 (Convolution2D)   (None, 16, 8, 8)    3472        merge_1[0][0]
# ____________________________________________________________________________________________________
# maxout2d_7 (Maxout2D)              (None, 8, 8, 8)     272         convolution2d_12[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_2 (UpSampling2D)      (None, 8, 16, 16)   0           maxout2d_7[0][0]
# ____________________________________________________________________________________________________
# merge_2 (Merge)                    (None, 24, 16, 16)  0           upsampling2d_2[0][0]
#                                                                    pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_13 (Convolution2D)   (None, 16, 16, 16)  3472        merge_2[0][0]
# ____________________________________________________________________________________________________
# maxout2d_8 (Maxout2D)              (None, 8, 16, 16)   272         convolution2d_13[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_3 (UpSampling2D)      (None, 8, 32, 32)   0           maxout2d_8[0][0]
# ____________________________________________________________________________________________________
# merge_3 (Merge)                    (None, 24, 32, 32)  0           upsampling2d_3[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_14 (Convolution2D)   (None, 16, 32, 32)  3472        merge_3[0][0]
# ____________________________________________________________________________________________________
# maxout2d_9 (Maxout2D)              (None, 8, 32, 32)   272         convolution2d_14[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_4 (UpSampling2D)      (None, 8, 64, 64)   0           maxout2d_9[0][0]
# ____________________________________________________________________________________________________
# merge_4 (Merge)                    (None, 24, 64, 64)  0           upsampling2d_4[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_15 (Convolution2D)   (None, 16, 64, 64)  3472        merge_4[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)                (None, 256)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# maxout2d_10 (Maxout2D)             (None, 8, 64, 64)   272         convolution2d_15[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                    (None, 32)          8224        flatten_1[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_5 (UpSampling2D)      (None, 8, 128, 128) 0           maxout2d_10[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)                (None, 8, 128, 128) 0           upsampling2d_5[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_1 (LeakyReLU)            (None, 32)          0           dense_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_16 (Convolution2D)   (None, 8, 128, 128) 584         dropout_6[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                    (None, 16)          528         leakyrelu_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_17 (Convolution2D)   (None, 8, 128, 128) 584         convolution2d_16[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_2 (LeakyReLU)            (None, 16)          0           dense_2[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_2[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 73          convolution2d_17[0][0]
# ____________________________________________________________________________________________________
# outmap32 (Convolution2D)           (None, 1, 32, 32)   9           maxout2d_9[0][0]
# ____________________________________________________________________________________________________
# outmap64 (Convolution2D)           (None, 1, 64, 64)   9           maxout2d_10[0][0]
# ====================================================================================================
# Total params: 97996
# ____________________________________________________________________________________________________

# %%
from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

from keras.utils.visualize_util import plot
plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {
            'outmap': Y_train,
            'outmap64' : Y_train_64,
            'outmap32' : Y_train_32,
            'outbin': Y_train_binary
        },
        batch_size=64,
        validation_data=(X_test, {
                'outmap': Y_test,
                'outmap64' : Y_test_64,
                'outmap32' : Y_test_32,
                'outbin': Y_test_binary
        }),
        nb_epoch=60,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    
    pl.figure()
    pl.plot(history.history['outmap_loss'], label='train loss')
    pl.plot(history.history['val_outmap_loss'], c='g', label='val loss')
    pl.legend()

    pl.figure()
    pl.plot(history.history['outbin_acc'], label='train acc')
    pl.plot(history.history['val_outbin_acc'], c='g', label='val acc')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
                custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.01])
    
    print_summary(model.layers)
# Out:
# Train on 10545 samples, validate on 391 samples
# Epoch 1/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.2357 - outmap_loss: 0.1751 - outmap64_loss: 0.1961 - outmap32_loss: 0.2683 - outbin_loss: 0.7995 - outbin_acc: 0.5976Epoch 00000: val_loss improved from inf to 0.06824, saving model to weights.hdf5
# 10545/10545 [==============================] - 122s - loss: 0.2350 - outmap_loss: 0.1745 - outmap64_loss: 0.1955 - outmap32_loss: 0.2676 - outbin_loss: 0.7990 - outbin_acc: 0.5975 - val_loss: 0.0682 - val_outmap_loss: 0.0375 - val_outmap64_loss: 0.0878 - val_outmap32_loss: 0.1280 - val_outbin_loss: 0.6784 - val_outbin_acc: 0.5806
# Epoch 2/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0615 - outmap_loss: 0.0415 - outmap64_loss: 0.0452 - outmap32_loss: 0.0861 - outbin_loss: 0.6631 - outbin_acc: 0.6183Epoch 00001: val_loss improved from 0.06824 to 0.05169, saving model to weights.hdf5
# 10545/10545 [==============================] - 122s - loss: 0.0614 - outmap_loss: 0.0415 - outmap64_loss: 0.0451 - outmap32_loss: 0.0859 - outbin_loss: 0.6628 - outbin_acc: 0.6190 - val_loss: 0.0517 - val_outmap_loss: 0.0348 - val_outmap64_loss: 0.0352 - val_outmap32_loss: 0.0645 - val_outbin_loss: 0.6609 - val_outbin_acc: 0.6292
# Epoch 3/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0506 - outmap_loss: 0.0342 - outmap64_loss: 0.0352 - outmap32_loss: 0.0605 - outbin_loss: 0.6395 - outbin_acc: 0.6442Epoch 00002: val_loss improved from 0.05169 to 0.04006, saving model to weights.hdf5
# 10545/10545 [==============================] - 122s - loss: 0.0506 - outmap_loss: 0.0341 - outmap64_loss: 0.0352 - outmap32_loss: 0.0605 - outbin_loss: 0.6393 - outbin_acc: 0.6443 - val_loss: 0.0401 - val_outmap_loss: 0.0254 - val_outmap64_loss: 0.0324 - val_outmap32_loss: 0.0538 - val_outbin_loss: 0.5533 - val_outbin_acc: 0.7059
# Epoch 4/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0448 - outmap_loss: 0.0307 - outmap64_loss: 0.0312 - outmap32_loss: 0.0474 - outbin_loss: 0.5536 - outbin_acc: 0.7248Epoch 00003: val_loss did not improve
# 10545/10545 [==============================] - 121s - loss: 0.0448 - outmap_loss: 0.0307 - outmap64_loss: 0.0312 - outmap32_loss: 0.0474 - outbin_loss: 0.5536 - outbin_acc: 0.7249 - val_loss: 0.0414 - val_outmap_loss: 0.0272 - val_outmap64_loss: 0.0375 - val_outmap32_loss: 0.0486 - val_outbin_loss: 0.4246 - val_outbin_acc: 0.8465
# Epoch 5/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0410 - outmap_loss: 0.0283 - outmap64_loss: 0.0287 - outmap32_loss: 0.0387 - outbin_loss: 0.4988 - outbin_acc: 0.7610Epoch 00004: val_loss improved from 0.04006 to 0.03817, saving model to weights.hdf5
# 10545/10545 [==============================] - 122s - loss: 0.0410 - outmap_loss: 0.0283 - outmap64_loss: 0.0287 - outmap32_loss: 0.0387 - outbin_loss: 0.4993 - outbin_acc: 0.7606 - val_loss: 0.0382 - val_outmap_loss: 0.0257 - val_outmap64_loss: 0.0333 - val_outmap32_loss: 0.0389 - val_outbin_loss: 0.3895 - val_outbin_acc: 0.8465
# Epoch 6/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0384 - outmap_loss: 0.0266 - outmap64_loss: 0.0271 - outmap32_loss: 0.0340 - outbin_loss: 0.4698 - outbin_acc: 0.7804Epoch 00005: val_loss improved from 0.03817 to 0.03326, saving model to weights.hdf5
# 10545/10545 [==============================] - 125s - loss: 0.0384 - outmap_loss: 0.0266 - outmap64_loss: 0.0270 - outmap32_loss: 0.0340 - outbin_loss: 0.4688 - outbin_acc: 0.7811 - val_loss: 0.0333 - val_outmap_loss: 0.0225 - val_outmap64_loss: 0.0240 - val_outmap32_loss: 0.0295 - val_outbin_loss: 0.4460 - val_outbin_acc: 0.8056
# Epoch 7/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0363 - outmap_loss: 0.0252 - outmap64_loss: 0.0255 - outmap32_loss: 0.0309 - outbin_loss: 0.4438 - outbin_acc: 0.7991Epoch 00006: val_loss improved from 0.03326 to 0.03231, saving model to weights.hdf5
# 10545/10545 [==============================] - 126s - loss: 0.0363 - outmap_loss: 0.0252 - outmap64_loss: 0.0255 - outmap32_loss: 0.0308 - outbin_loss: 0.4439 - outbin_acc: 0.7992 - val_loss: 0.0323 - val_outmap_loss: 0.0225 - val_outmap64_loss: 0.0240 - val_outmap32_loss: 0.0286 - val_outbin_loss: 0.3593 - val_outbin_acc: 0.8389
# Epoch 8/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0353 - outmap_loss: 0.0245 - outmap64_loss: 0.0249 - outmap32_loss: 0.0290 - outbin_loss: 0.4377 - outbin_acc: 0.7995Epoch 00007: val_loss improved from 0.03231 to 0.03060, saving model to weights.hdf5
# 10545/10545 [==============================] - 126s - loss: 0.0353 - outmap_loss: 0.0245 - outmap64_loss: 0.0249 - outmap32_loss: 0.0290 - outbin_loss: 0.4380 - outbin_acc: 0.7995 - val_loss: 0.0306 - val_outmap_loss: 0.0210 - val_outmap64_loss: 0.0227 - val_outmap32_loss: 0.0259 - val_outbin_loss: 0.3789 - val_outbin_acc: 0.8440
# Epoch 9/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0344 - outmap_loss: 0.0238 - outmap64_loss: 0.0242 - outmap32_loss: 0.0281 - outbin_loss: 0.4276 - outbin_acc: 0.8067Epoch 00008: val_loss improved from 0.03060 to 0.03011, saving model to weights.hdf5
# 10545/10545 [==============================] - 126s - loss: 0.0344 - outmap_loss: 0.0238 - outmap64_loss: 0.0242 - outmap32_loss: 0.0281 - outbin_loss: 0.4277 - outbin_acc: 0.8066 - val_loss: 0.0301 - val_outmap_loss: 0.0209 - val_outmap64_loss: 0.0221 - val_outmap32_loss: 0.0255 - val_outbin_loss: 0.3513 - val_outbin_acc: 0.8440
# Epoch 10/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0332 - outmap_loss: 0.0231 - outmap64_loss: 0.0235 - outmap32_loss: 0.0269 - outbin_loss: 0.4011 - outbin_acc: 0.8274Epoch 00009: val_loss improved from 0.03011 to 0.02937, saving model to weights.hdf5
# 10545/10545 [==============================] - 126s - loss: 0.0332 - outmap_loss: 0.0231 - outmap64_loss: 0.0235 - outmap32_loss: 0.0269 - outbin_loss: 0.4007 - outbin_acc: 0.8275 - val_loss: 0.0294 - val_outmap_loss: 0.0202 - val_outmap64_loss: 0.0221 - val_outmap32_loss: 0.0254 - val_outbin_loss: 0.3429 - val_outbin_acc: 0.8619
# Epoch 11/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0318 - outmap_loss: 0.0221 - outmap64_loss: 0.0225 - outmap32_loss: 0.0257 - outbin_loss: 0.3902 - outbin_acc: 0.8288Epoch 00010: val_loss improved from 0.02937 to 0.02873, saving model to weights.hdf5
# 10545/10545 [==============================] - 126s - loss: 0.0319 - outmap_loss: 0.0222 - outmap64_loss: 0.0225 - outmap32_loss: 0.0257 - outbin_loss: 0.3909 - outbin_acc: 0.8284 - val_loss: 0.0287 - val_outmap_loss: 0.0200 - val_outmap64_loss: 0.0218 - val_outmap32_loss: 0.0248 - val_outbin_loss: 0.3179 - val_outbin_acc: 0.8747
# Epoch 12/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0315 - outmap_loss: 0.0219 - outmap64_loss: 0.0223 - outmap32_loss: 0.0253 - outbin_loss: 0.3828 - outbin_acc: 0.8372Epoch 00011: val_loss improved from 0.02873 to 0.02724, saving model to weights.hdf5
# 10545/10545 [==============================] - 125s - loss: 0.0315 - outmap_loss: 0.0220 - outmap64_loss: 0.0223 - outmap32_loss: 0.0253 - outbin_loss: 0.3830 - outbin_acc: 0.8372 - val_loss: 0.0272 - val_outmap_loss: 0.0190 - val_outmap64_loss: 0.0201 - val_outmap32_loss: 0.0230 - val_outbin_loss: 0.3064 - val_outbin_acc: 0.8696
# Epoch 13/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0304 - outmap_loss: 0.0211 - outmap64_loss: 0.0215 - outmap32_loss: 0.0242 - outbin_loss: 0.3695 - outbin_acc: 0.8419Epoch 00012: val_loss did not improve
# 10545/10545 [==============================] - 124s - loss: 0.0303 - outmap_loss: 0.0211 - outmap64_loss: 0.0215 - outmap32_loss: 0.0242 - outbin_loss: 0.3693 - outbin_acc: 0.8420 - val_loss: 0.0278 - val_outmap_loss: 0.0194 - val_outmap64_loss: 0.0199 - val_outmap32_loss: 0.0223 - val_outbin_loss: 0.3367 - val_outbin_acc: 0.8542
# Epoch 14/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0297 - outmap_loss: 0.0207 - outmap64_loss: 0.0211 - outmap32_loss: 0.0235 - outbin_loss: 0.3610 - outbin_acc: 0.8413Epoch 00013: val_loss did not improve
# 10545/10545 [==============================] - 124s - loss: 0.0297 - outmap_loss: 0.0207 - outmap64_loss: 0.0211 - outmap32_loss: 0.0235 - outbin_loss: 0.3609 - outbin_acc: 0.8413 - val_loss: 0.0283 - val_outmap_loss: 0.0194 - val_outmap64_loss: 0.0209 - val_outmap32_loss: 0.0239 - val_outbin_loss: 0.3503 - val_outbin_acc: 0.8338
# Epoch 15/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0294 - outmap_loss: 0.0206 - outmap64_loss: 0.0209 - outmap32_loss: 0.0231 - outbin_loss: 0.3521 - outbin_acc: 0.8490Epoch 00014: val_loss improved from 0.02724 to 0.02665, saving model to weights.hdf5
# 10545/10545 [==============================] - 123s - loss: 0.0294 - outmap_loss: 0.0206 - outmap64_loss: 0.0209 - outmap32_loss: 0.0231 - outbin_loss: 0.3519 - outbin_acc: 0.8491 - val_loss: 0.0266 - val_outmap_loss: 0.0187 - val_outmap64_loss: 0.0193 - val_outmap32_loss: 0.0212 - val_outbin_loss: 0.2977 - val_outbin_acc: 0.8798
# Epoch 16/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0289 - outmap_loss: 0.0202 - outmap64_loss: 0.0206 - outmap32_loss: 0.0228 - outbin_loss: 0.3467 - outbin_acc: 0.8537Epoch 00015: val_loss did not improve
# 10545/10545 [==============================] - 124s - loss: 0.0290 - outmap_loss: 0.0202 - outmap64_loss: 0.0206 - outmap32_loss: 0.0228 - outbin_loss: 0.3468 - outbin_acc: 0.8535 - val_loss: 0.0271 - val_outmap_loss: 0.0189 - val_outmap64_loss: 0.0198 - val_outmap32_loss: 0.0217 - val_outbin_loss: 0.3193 - val_outbin_acc: 0.8721
# Epoch 17/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0285 - outmap_loss: 0.0199 - outmap64_loss: 0.0203 - outmap32_loss: 0.0223 - outbin_loss: 0.3437 - outbin_acc: 0.8520Epoch 00016: val_loss improved from 0.02665 to 0.02621, saving model to weights.hdf5
# 10545/10545 [==============================] - 121s - loss: 0.0285 - outmap_loss: 0.0199 - outmap64_loss: 0.0203 - outmap32_loss: 0.0223 - outbin_loss: 0.3435 - outbin_acc: 0.8523 - val_loss: 0.0262 - val_outmap_loss: 0.0184 - val_outmap64_loss: 0.0187 - val_outmap32_loss: 0.0205 - val_outbin_loss: 0.3033 - val_outbin_acc: 0.8721
# Epoch 18/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0279 - outmap_loss: 0.0194 - outmap64_loss: 0.0198 - outmap32_loss: 0.0217 - outbin_loss: 0.3456 - outbin_acc: 0.8495Epoch 00017: val_loss did not improve
# 10545/10545 [==============================] - 121s - loss: 0.0279 - outmap_loss: 0.0194 - outmap64_loss: 0.0198 - outmap32_loss: 0.0216 - outbin_loss: 0.3452 - outbin_acc: 0.8496 - val_loss: 0.0267 - val_outmap_loss: 0.0188 - val_outmap64_loss: 0.0194 - val_outmap32_loss: 0.0211 - val_outbin_loss: 0.3016 - val_outbin_acc: 0.8798
# Epoch 19/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0279 - outmap_loss: 0.0194 - outmap64_loss: 0.0198 - outmap32_loss: 0.0216 - outbin_loss: 0.3373 - outbin_acc: 0.8533Epoch 00018: val_loss did not improve
# 10545/10545 [==============================] - 121s - loss: 0.0278 - outmap_loss: 0.0194 - outmap64_loss: 0.0198 - outmap32_loss: 0.0216 - outbin_loss: 0.3372 - outbin_acc: 0.8534 - val_loss: 0.0265 - val_outmap_loss: 0.0183 - val_outmap64_loss: 0.0191 - val_outmap32_loss: 0.0205 - val_outbin_loss: 0.3406 - val_outbin_acc: 0.8542
# Epoch 20/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0271 - outmap_loss: 0.0189 - outmap64_loss: 0.0193 - outmap32_loss: 0.0210 - outbin_loss: 0.3269 - outbin_acc: 0.8646Epoch 00019: val_loss improved from 0.02621 to 0.02581, saving model to weights.hdf5
# 10545/10545 [==============================] - 121s - loss: 0.0271 - outmap_loss: 0.0189 - outmap64_loss: 0.0193 - outmap32_loss: 0.0210 - outbin_loss: 0.3274 - outbin_acc: 0.8642 - val_loss: 0.0258 - val_outmap_loss: 0.0181 - val_outmap64_loss: 0.0187 - val_outmap32_loss: 0.0203 - val_outbin_loss: 0.2999 - val_outbin_acc: 0.8824
# Epoch 21/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0271 - outmap_loss: 0.0189 - outmap64_loss: 0.0193 - outmap32_loss: 0.0210 - outbin_loss: 0.3260 - outbin_acc: 0.8602Epoch 00020: val_loss did not improve
# 10545/10545 [==============================] - 121s - loss: 0.0271 - outmap_loss: 0.0189 - outmap64_loss: 0.0193 - outmap32_loss: 0.0210 - outbin_loss: 0.3255 - outbin_acc: 0.8605 - val_loss: 0.0262 - val_outmap_loss: 0.0183 - val_outmap64_loss: 0.0188 - val_outmap32_loss: 0.0205 - val_outbin_loss: 0.3084 - val_outbin_acc: 0.8798
# Epoch 22/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0265 - outmap_loss: 0.0185 - outmap64_loss: 0.0189 - outmap32_loss: 0.0205 - outbin_loss: 0.3181 - outbin_acc: 0.8680Epoch 00021: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0265 - outmap_loss: 0.0185 - outmap64_loss: 0.0190 - outmap32_loss: 0.0205 - outbin_loss: 0.3182 - outbin_acc: 0.8678 - val_loss: 0.0259 - val_outmap_loss: 0.0181 - val_outmap64_loss: 0.0186 - val_outmap32_loss: 0.0200 - val_outbin_loss: 0.3161 - val_outbin_acc: 0.8747
# Epoch 23/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0265 - outmap_loss: 0.0185 - outmap64_loss: 0.0189 - outmap32_loss: 0.0204 - outbin_loss: 0.3233 - outbin_acc: 0.8673Epoch 00022: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0265 - outmap_loss: 0.0185 - outmap64_loss: 0.0189 - outmap32_loss: 0.0204 - outbin_loss: 0.3239 - outbin_acc: 0.8670 - val_loss: 0.0259 - val_outmap_loss: 0.0181 - val_outmap64_loss: 0.0184 - val_outmap32_loss: 0.0197 - val_outbin_loss: 0.3158 - val_outbin_acc: 0.8696
# Epoch 24/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0257 - outmap_loss: 0.0180 - outmap64_loss: 0.0184 - outmap32_loss: 0.0199 - outbin_loss: 0.3041 - outbin_acc: 0.8714Epoch 00023: val_loss improved from 0.02581 to 0.02505, saving model to weights.hdf5
# 10545/10545 [==============================] - 126s - loss: 0.0257 - outmap_loss: 0.0180 - outmap64_loss: 0.0184 - outmap32_loss: 0.0199 - outbin_loss: 0.3037 - outbin_acc: 0.8716 - val_loss: 0.0251 - val_outmap_loss: 0.0174 - val_outmap64_loss: 0.0180 - val_outmap32_loss: 0.0193 - val_outbin_loss: 0.3087 - val_outbin_acc: 0.8747
# Epoch 25/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0259 - outmap_loss: 0.0181 - outmap64_loss: 0.0185 - outmap32_loss: 0.0200 - outbin_loss: 0.3085 - outbin_acc: 0.8688Epoch 00024: val_loss improved from 0.02505 to 0.02475, saving model to weights.hdf5
# 10545/10545 [==============================] - 126s - loss: 0.0258 - outmap_loss: 0.0181 - outmap64_loss: 0.0184 - outmap32_loss: 0.0200 - outbin_loss: 0.3083 - outbin_acc: 0.8688 - val_loss: 0.0247 - val_outmap_loss: 0.0174 - val_outmap64_loss: 0.0182 - val_outmap32_loss: 0.0192 - val_outbin_loss: 0.2769 - val_outbin_acc: 0.8747
# Epoch 26/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0255 - outmap_loss: 0.0178 - outmap64_loss: 0.0182 - outmap32_loss: 0.0197 - outbin_loss: 0.3014 - outbin_acc: 0.8726Epoch 00025: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0255 - outmap_loss: 0.0178 - outmap64_loss: 0.0182 - outmap32_loss: 0.0197 - outbin_loss: 0.3010 - outbin_acc: 0.8727 - val_loss: 0.0259 - val_outmap_loss: 0.0182 - val_outmap64_loss: 0.0185 - val_outmap32_loss: 0.0199 - val_outbin_loss: 0.2983 - val_outbin_acc: 0.8747
# Epoch 27/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0256 - outmap_loss: 0.0179 - outmap64_loss: 0.0183 - outmap32_loss: 0.0197 - outbin_loss: 0.3075 - outbin_acc: 0.8682Epoch 00026: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0256 - outmap_loss: 0.0179 - outmap64_loss: 0.0183 - outmap32_loss: 0.0197 - outbin_loss: 0.3071 - outbin_acc: 0.8685 - val_loss: 0.0252 - val_outmap_loss: 0.0177 - val_outmap64_loss: 0.0180 - val_outmap32_loss: 0.0191 - val_outbin_loss: 0.2927 - val_outbin_acc: 0.8721
# Epoch 28/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0249 - outmap_loss: 0.0175 - outmap64_loss: 0.0179 - outmap32_loss: 0.0192 - outbin_loss: 0.2946 - outbin_acc: 0.8737Epoch 00027: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0250 - outmap_loss: 0.0175 - outmap64_loss: 0.0179 - outmap32_loss: 0.0192 - outbin_loss: 0.2951 - outbin_acc: 0.8737 - val_loss: 0.0255 - val_outmap_loss: 0.0176 - val_outmap64_loss: 0.0181 - val_outmap32_loss: 0.0195 - val_outbin_loss: 0.3369 - val_outbin_acc: 0.8875
# Epoch 29/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0246 - outmap_loss: 0.0172 - outmap64_loss: 0.0176 - outmap32_loss: 0.0190 - outbin_loss: 0.2901 - outbin_acc: 0.8800Epoch 00028: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0246 - outmap_loss: 0.0172 - outmap64_loss: 0.0176 - outmap32_loss: 0.0190 - outbin_loss: 0.2901 - outbin_acc: 0.8801 - val_loss: 0.0254 - val_outmap_loss: 0.0177 - val_outmap64_loss: 0.0184 - val_outmap32_loss: 0.0197 - val_outbin_loss: 0.2970 - val_outbin_acc: 0.8747
# Epoch 30/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0250 - outmap_loss: 0.0175 - outmap64_loss: 0.0179 - outmap32_loss: 0.0192 - outbin_loss: 0.2947 - outbin_acc: 0.8748Epoch 00029: val_loss improved from 0.02475 to 0.02437, saving model to weights.hdf5
# 10545/10545 [==============================] - 126s - loss: 0.0250 - outmap_loss: 0.0175 - outmap64_loss: 0.0179 - outmap32_loss: 0.0192 - outbin_loss: 0.2950 - outbin_acc: 0.8743 - val_loss: 0.0244 - val_outmap_loss: 0.0171 - val_outmap64_loss: 0.0175 - val_outmap32_loss: 0.0189 - val_outbin_loss: 0.2881 - val_outbin_acc: 0.8900
# Epoch 31/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0240 - outmap_loss: 0.0168 - outmap64_loss: 0.0172 - outmap32_loss: 0.0185 - outbin_loss: 0.2826 - outbin_acc: 0.8810Epoch 00030: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0240 - outmap_loss: 0.0168 - outmap64_loss: 0.0172 - outmap32_loss: 0.0186 - outbin_loss: 0.2833 - outbin_acc: 0.8808 - val_loss: 0.0258 - val_outmap_loss: 0.0179 - val_outmap64_loss: 0.0186 - val_outmap32_loss: 0.0197 - val_outbin_loss: 0.3250 - val_outbin_acc: 0.8721
# Epoch 32/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0247 - outmap_loss: 0.0172 - outmap64_loss: 0.0176 - outmap32_loss: 0.0189 - outbin_loss: 0.2952 - outbin_acc: 0.8770Epoch 00031: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0247 - outmap_loss: 0.0172 - outmap64_loss: 0.0176 - outmap32_loss: 0.0189 - outbin_loss: 0.2951 - outbin_acc: 0.8769 - val_loss: 0.0272 - val_outmap_loss: 0.0190 - val_outmap64_loss: 0.0196 - val_outmap32_loss: 0.0209 - val_outbin_loss: 0.3249 - val_outbin_acc: 0.8568
# Epoch 33/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0239 - outmap_loss: 0.0167 - outmap64_loss: 0.0172 - outmap32_loss: 0.0185 - outbin_loss: 0.2822 - outbin_acc: 0.8821Epoch 00032: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0239 - outmap_loss: 0.0167 - outmap64_loss: 0.0172 - outmap32_loss: 0.0186 - outbin_loss: 0.2824 - outbin_acc: 0.8820 - val_loss: 0.0247 - val_outmap_loss: 0.0174 - val_outmap64_loss: 0.0179 - val_outmap32_loss: 0.0191 - val_outbin_loss: 0.2854 - val_outbin_acc: 0.8951
# Epoch 34/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0239 - outmap_loss: 0.0167 - outmap64_loss: 0.0171 - outmap32_loss: 0.0184 - outbin_loss: 0.2816 - outbin_acc: 0.8845Epoch 00033: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0239 - outmap_loss: 0.0167 - outmap64_loss: 0.0171 - outmap32_loss: 0.0184 - outbin_loss: 0.2819 - outbin_acc: 0.8841 - val_loss: 0.0261 - val_outmap_loss: 0.0182 - val_outmap64_loss: 0.0187 - val_outmap32_loss: 0.0202 - val_outbin_loss: 0.3181 - val_outbin_acc: 0.8721
# Epoch 35/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0238 - outmap_loss: 0.0167 - outmap64_loss: 0.0171 - outmap32_loss: 0.0184 - outbin_loss: 0.2799 - outbin_acc: 0.8796Epoch 00034: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0238 - outmap_loss: 0.0167 - outmap64_loss: 0.0171 - outmap32_loss: 0.0183 - outbin_loss: 0.2796 - outbin_acc: 0.8797 - val_loss: 0.0266 - val_outmap_loss: 0.0185 - val_outmap64_loss: 0.0190 - val_outmap32_loss: 0.0207 - val_outbin_loss: 0.3276 - val_outbin_acc: 0.8696
# Epoch 36/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0234 - outmap_loss: 0.0164 - outmap64_loss: 0.0168 - outmap32_loss: 0.0181 - outbin_loss: 0.2764 - outbin_acc: 0.8838Epoch 00035: val_loss did not improve
# 10545/10545 [==============================] - 122s - loss: 0.0234 - outmap_loss: 0.0164 - outmap64_loss: 0.0168 - outmap32_loss: 0.0181 - outbin_loss: 0.2776 - outbin_acc: 0.8835 - val_loss: 0.0258 - val_outmap_loss: 0.0178 - val_outmap64_loss: 0.0183 - val_outmap32_loss: 0.0197 - val_outbin_loss: 0.3361 - val_outbin_acc: 0.8465
# Epoch 37/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0233 - outmap_loss: 0.0163 - outmap64_loss: 0.0167 - outmap32_loss: 0.0180 - outbin_loss: 0.2703 - outbin_acc: 0.8845Epoch 00036: val_loss did not improve
# 10545/10545 [==============================] - 121s - loss: 0.0233 - outmap_loss: 0.0163 - outmap64_loss: 0.0167 - outmap32_loss: 0.0180 - outbin_loss: 0.2699 - outbin_acc: 0.8849 - val_loss: 0.0259 - val_outmap_loss: 0.0181 - val_outmap64_loss: 0.0183 - val_outmap32_loss: 0.0198 - val_outbin_loss: 0.3189 - val_outbin_acc: 0.8542
# Epoch 38/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0231 - outmap_loss: 0.0162 - outmap64_loss: 0.0166 - outmap32_loss: 0.0179 - outbin_loss: 0.2706 - outbin_acc: 0.8885Epoch 00037: val_loss did not improve
# 10545/10545 [==============================] - 121s - loss: 0.0231 - outmap_loss: 0.0162 - outmap64_loss: 0.0166 - outmap32_loss: 0.0179 - outbin_loss: 0.2714 - outbin_acc: 0.8885 - val_loss: 0.0273 - val_outmap_loss: 0.0192 - val_outmap64_loss: 0.0191 - val_outmap32_loss: 0.0198 - val_outbin_loss: 0.3293 - val_outbin_acc: 0.8696
# Epoch 39/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0237 - outmap_loss: 0.0166 - outmap64_loss: 0.0169 - outmap32_loss: 0.0182 - outbin_loss: 0.2833 - outbin_acc: 0.8835Epoch 00038: val_loss did not improve
# 10545/10545 [==============================] - 121s - loss: 0.0237 - outmap_loss: 0.0165 - outmap64_loss: 0.0169 - outmap32_loss: 0.0182 - outbin_loss: 0.2827 - outbin_acc: 0.8838 - val_loss: 0.0272 - val_outmap_loss: 0.0190 - val_outmap64_loss: 0.0196 - val_outmap32_loss: 0.0212 - val_outbin_loss: 0.3242 - val_outbin_acc: 0.8747
# Epoch 40/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0230 - outmap_loss: 0.0161 - outmap64_loss: 0.0165 - outmap32_loss: 0.0178 - outbin_loss: 0.2705 - outbin_acc: 0.8865Epoch 00039: val_loss did not improve
# 10545/10545 [==============================] - 121s - loss: 0.0230 - outmap_loss: 0.0161 - outmap64_loss: 0.0165 - outmap32_loss: 0.0178 - outbin_loss: 0.2697 - outbin_acc: 0.8869 - val_loss: 0.0264 - val_outmap_loss: 0.0184 - val_outmap64_loss: 0.0187 - val_outmap32_loss: 0.0200 - val_outbin_loss: 0.3254 - val_outbin_acc: 0.8645
# Epoch 41/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0229 - outmap_loss: 0.0160 - outmap64_loss: 0.0164 - outmap32_loss: 0.0177 - outbin_loss: 0.2678 - outbin_acc: 0.8893Epoch 00040: val_loss did not improve
# 10545/10545 [==============================] - 125s - loss: 0.0228 - outmap_loss: 0.0160 - outmap64_loss: 0.0164 - outmap32_loss: 0.0177 - outbin_loss: 0.2678 - outbin_acc: 0.8891 - val_loss: 0.0264 - val_outmap_loss: 0.0183 - val_outmap64_loss: 0.0186 - val_outmap32_loss: 0.0198 - val_outbin_loss: 0.3370 - val_outbin_acc: 0.8568
# Epoch 42/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0229 - outmap_loss: 0.0160 - outmap64_loss: 0.0164 - outmap32_loss: 0.0177 - outbin_loss: 0.2726 - outbin_acc: 0.8858Epoch 00041: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0228 - outmap_loss: 0.0160 - outmap64_loss: 0.0163 - outmap32_loss: 0.0177 - outbin_loss: 0.2723 - outbin_acc: 0.8859 - val_loss: 0.0260 - val_outmap_loss: 0.0183 - val_outmap64_loss: 0.0186 - val_outmap32_loss: 0.0194 - val_outbin_loss: 0.2985 - val_outbin_acc: 0.8875
# Epoch 43/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0227 - outmap_loss: 0.0159 - outmap64_loss: 0.0163 - outmap32_loss: 0.0176 - outbin_loss: 0.2631 - outbin_acc: 0.8883Epoch 00042: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0227 - outmap_loss: 0.0159 - outmap64_loss: 0.0163 - outmap32_loss: 0.0176 - outbin_loss: 0.2628 - outbin_acc: 0.8884 - val_loss: 0.0267 - val_outmap_loss: 0.0186 - val_outmap64_loss: 0.0188 - val_outmap32_loss: 0.0198 - val_outbin_loss: 0.3269 - val_outbin_acc: 0.8824
# Epoch 44/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0225 - outmap_loss: 0.0158 - outmap64_loss: 0.0162 - outmap32_loss: 0.0175 - outbin_loss: 0.2600 - outbin_acc: 0.8925Epoch 00043: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0225 - outmap_loss: 0.0158 - outmap64_loss: 0.0162 - outmap32_loss: 0.0175 - outbin_loss: 0.2597 - outbin_acc: 0.8928 - val_loss: 0.0255 - val_outmap_loss: 0.0176 - val_outmap64_loss: 0.0180 - val_outmap32_loss: 0.0192 - val_outbin_loss: 0.3382 - val_outbin_acc: 0.8721
# Epoch 45/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0219 - outmap_loss: 0.0154 - outmap64_loss: 0.0158 - outmap32_loss: 0.0171 - outbin_loss: 0.2495 - outbin_acc: 0.8942Epoch 00044: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0219 - outmap_loss: 0.0154 - outmap64_loss: 0.0158 - outmap32_loss: 0.0171 - outbin_loss: 0.2490 - outbin_acc: 0.8945 - val_loss: 0.0250 - val_outmap_loss: 0.0176 - val_outmap64_loss: 0.0178 - val_outmap32_loss: 0.0193 - val_outbin_loss: 0.2968 - val_outbin_acc: 0.8696
# Epoch 46/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0224 - outmap_loss: 0.0157 - outmap64_loss: 0.0161 - outmap32_loss: 0.0175 - outbin_loss: 0.2602 - outbin_acc: 0.8928Epoch 00045: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0224 - outmap_loss: 0.0157 - outmap64_loss: 0.0161 - outmap32_loss: 0.0175 - outbin_loss: 0.2600 - outbin_acc: 0.8928 - val_loss: 0.0289 - val_outmap_loss: 0.0198 - val_outmap64_loss: 0.0197 - val_outmap32_loss: 0.0206 - val_outbin_loss: 0.4137 - val_outbin_acc: 0.8363
# Epoch 47/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0223 - outmap_loss: 0.0156 - outmap64_loss: 0.0161 - outmap32_loss: 0.0174 - outbin_loss: 0.2524 - outbin_acc: 0.8967Epoch 00046: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0222 - outmap_loss: 0.0156 - outmap64_loss: 0.0160 - outmap32_loss: 0.0174 - outbin_loss: 0.2520 - outbin_acc: 0.8970 - val_loss: 0.0267 - val_outmap_loss: 0.0185 - val_outmap64_loss: 0.0189 - val_outmap32_loss: 0.0198 - val_outbin_loss: 0.3404 - val_outbin_acc: 0.8772
# Epoch 48/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0217 - outmap_loss: 0.0152 - outmap64_loss: 0.0156 - outmap32_loss: 0.0170 - outbin_loss: 0.2530 - outbin_acc: 0.8959Epoch 00047: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0217 - outmap_loss: 0.0152 - outmap64_loss: 0.0156 - outmap32_loss: 0.0169 - outbin_loss: 0.2533 - outbin_acc: 0.8959 - val_loss: 0.0248 - val_outmap_loss: 0.0173 - val_outmap64_loss: 0.0176 - val_outmap32_loss: 0.0188 - val_outbin_loss: 0.3071 - val_outbin_acc: 0.8670
# Epoch 49/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0216 - outmap_loss: 0.0152 - outmap64_loss: 0.0156 - outmap32_loss: 0.0169 - outbin_loss: 0.2438 - outbin_acc: 0.9009Epoch 00048: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0216 - outmap_loss: 0.0152 - outmap64_loss: 0.0156 - outmap32_loss: 0.0169 - outbin_loss: 0.2438 - outbin_acc: 0.9010 - val_loss: 0.0262 - val_outmap_loss: 0.0181 - val_outmap64_loss: 0.0186 - val_outmap32_loss: 0.0201 - val_outbin_loss: 0.3401 - val_outbin_acc: 0.8798
# Epoch 50/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0215 - outmap_loss: 0.0151 - outmap64_loss: 0.0155 - outmap32_loss: 0.0169 - outbin_loss: 0.2507 - outbin_acc: 0.8956Epoch 00049: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0216 - outmap_loss: 0.0151 - outmap64_loss: 0.0155 - outmap32_loss: 0.0169 - outbin_loss: 0.2507 - outbin_acc: 0.8956 - val_loss: 0.0263 - val_outmap_loss: 0.0181 - val_outmap64_loss: 0.0184 - val_outmap32_loss: 0.0198 - val_outbin_loss: 0.3583 - val_outbin_acc: 0.8747
# Epoch 51/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0218 - outmap_loss: 0.0153 - outmap64_loss: 0.0157 - outmap32_loss: 0.0170 - outbin_loss: 0.2505 - outbin_acc: 0.8962Epoch 00050: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0218 - outmap_loss: 0.0153 - outmap64_loss: 0.0157 - outmap32_loss: 0.0170 - outbin_loss: 0.2505 - outbin_acc: 0.8963 - val_loss: 0.0253 - val_outmap_loss: 0.0175 - val_outmap64_loss: 0.0181 - val_outmap32_loss: 0.0197 - val_outbin_loss: 0.3258 - val_outbin_acc: 0.8568
# Epoch 52/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0214 - outmap_loss: 0.0150 - outmap64_loss: 0.0154 - outmap32_loss: 0.0167 - outbin_loss: 0.2425 - outbin_acc: 0.8986Epoch 00051: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0214 - outmap_loss: 0.0150 - outmap64_loss: 0.0154 - outmap32_loss: 0.0167 - outbin_loss: 0.2423 - outbin_acc: 0.8988 - val_loss: 0.0276 - val_outmap_loss: 0.0183 - val_outmap64_loss: 0.0187 - val_outmap32_loss: 0.0203 - val_outbin_loss: 0.4512 - val_outbin_acc: 0.8005
# Epoch 53/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0214 - outmap_loss: 0.0151 - outmap64_loss: 0.0154 - outmap32_loss: 0.0168 - outbin_loss: 0.2459 - outbin_acc: 0.9005Epoch 00052: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0214 - outmap_loss: 0.0150 - outmap64_loss: 0.0154 - outmap32_loss: 0.0168 - outbin_loss: 0.2460 - outbin_acc: 0.9004 - val_loss: 0.0264 - val_outmap_loss: 0.0184 - val_outmap64_loss: 0.0185 - val_outmap32_loss: 0.0196 - val_outbin_loss: 0.3351 - val_outbin_acc: 0.8824
# Epoch 54/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0214 - outmap_loss: 0.0151 - outmap64_loss: 0.0155 - outmap32_loss: 0.0168 - outbin_loss: 0.2413 - outbin_acc: 0.8998Epoch 00053: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0215 - outmap_loss: 0.0151 - outmap64_loss: 0.0155 - outmap32_loss: 0.0168 - outbin_loss: 0.2416 - outbin_acc: 0.8997 - val_loss: 0.0270 - val_outmap_loss: 0.0186 - val_outmap64_loss: 0.0191 - val_outmap32_loss: 0.0207 - val_outbin_loss: 0.3619 - val_outbin_acc: 0.8389
# Epoch 55/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0212 - outmap_loss: 0.0148 - outmap64_loss: 0.0152 - outmap32_loss: 0.0166 - outbin_loss: 0.2437 - outbin_acc: 0.9000Epoch 00054: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0212 - outmap_loss: 0.0148 - outmap64_loss: 0.0152 - outmap32_loss: 0.0166 - outbin_loss: 0.2436 - outbin_acc: 0.8999 - val_loss: 0.0257 - val_outmap_loss: 0.0178 - val_outmap64_loss: 0.0181 - val_outmap32_loss: 0.0192 - val_outbin_loss: 0.3291 - val_outbin_acc: 0.8772
# Epoch 56/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0211 - outmap_loss: 0.0148 - outmap64_loss: 0.0153 - outmap32_loss: 0.0166 - outbin_loss: 0.2417 - outbin_acc: 0.8981Epoch 00055: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0211 - outmap_loss: 0.0148 - outmap64_loss: 0.0152 - outmap32_loss: 0.0166 - outbin_loss: 0.2420 - outbin_acc: 0.8982 - val_loss: 0.0260 - val_outmap_loss: 0.0179 - val_outmap64_loss: 0.0182 - val_outmap32_loss: 0.0194 - val_outbin_loss: 0.3436 - val_outbin_acc: 0.8593
# Epoch 57/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0212 - outmap_loss: 0.0149 - outmap64_loss: 0.0153 - outmap32_loss: 0.0166 - outbin_loss: 0.2400 - outbin_acc: 0.9024Epoch 00056: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0212 - outmap_loss: 0.0149 - outmap64_loss: 0.0153 - outmap32_loss: 0.0166 - outbin_loss: 0.2403 - outbin_acc: 0.9026 - val_loss: 0.0275 - val_outmap_loss: 0.0194 - val_outmap64_loss: 0.0190 - val_outmap32_loss: 0.0200 - val_outbin_loss: 0.3372 - val_outbin_acc: 0.8696
# Epoch 58/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0204 - outmap_loss: 0.0143 - outmap64_loss: 0.0148 - outmap32_loss: 0.0161 - outbin_loss: 0.2318 - outbin_acc: 0.9052Epoch 00057: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0204 - outmap_loss: 0.0143 - outmap64_loss: 0.0148 - outmap32_loss: 0.0161 - outbin_loss: 0.2316 - outbin_acc: 0.9052 - val_loss: 0.0264 - val_outmap_loss: 0.0183 - val_outmap64_loss: 0.0187 - val_outmap32_loss: 0.0195 - val_outbin_loss: 0.3463 - val_outbin_acc: 0.8542
# Epoch 59/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0206 - outmap_loss: 0.0145 - outmap64_loss: 0.0150 - outmap32_loss: 0.0163 - outbin_loss: 0.2317 - outbin_acc: 0.9036Epoch 00058: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0207 - outmap_loss: 0.0145 - outmap64_loss: 0.0150 - outmap32_loss: 0.0163 - outbin_loss: 0.2315 - outbin_acc: 0.9036 - val_loss: 0.0250 - val_outmap_loss: 0.0174 - val_outmap64_loss: 0.0180 - val_outmap32_loss: 0.0192 - val_outbin_loss: 0.3088 - val_outbin_acc: 0.8747
# Epoch 60/60
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0207 - outmap_loss: 0.0146 - outmap64_loss: 0.0150 - outmap32_loss: 0.0163 - outbin_loss: 0.2323 - outbin_acc: 0.9064Epoch 00059: val_loss did not improve
# 10545/10545 [==============================] - 126s - loss: 0.0207 - outmap_loss: 0.0146 - outmap64_loss: 0.0150 - outmap32_loss: 0.0163 - outbin_loss: 0.2325 - outbin_acc: 0.9065 - val_loss: 0.0266 - val_outmap_loss: 0.0184 - val_outmap64_loss: 0.0192 - val_outmap32_loss: 0.0205 - val_outbin_loss: 0.3339 - val_outbin_acc: 0.8849

# %%
if True:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture_final.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights_final.hdf5'))

# %%
def compute_scores_map(X, Y):
    Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X)
    
    map_threshs = np.linspace(0, 1, num=21)
    bin_threshs = np.linspace(0, 1, num=21)
    
    scores = np.zeros((len(map_threshs), len(bin_threshs)))
    for i in range(len(map_threshs)):
        for j in range(len(bin_threshs)):
            _Y_pred = Y_pred > map_threshs[i]
            
            for k in range(_Y_pred.shape[0]):
                # Clear prediction where we detect to little pixels
                if np.sum(_Y_pred[k]) < 150 or Y_pred_binary[k] < bin_threshs[j]:
                    _Y_pred[k,:] = 0
            
            scores[i, j] = utils.average_dice_coefficient(_Y_pred, Y)
    
    pl.imshow(scores, interpolation='nearest')
    pl.yticks(np.arange(len(map_threshs)) + 0.5, ['%.2f' % v for v in map_threshs])
    pl.xticks(np.arange(len(bin_threshs)) + 0.5, ['%.2f' % v for v in bin_threshs], rotation=90)
    pl.ylabel('map thresh')
    pl.xlabel('bin thresh')
    pl.colorbar()
    
    best_i, best_j = np.unravel_index(np.argmax(scores.ravel()), scores.shape)
    best_map_thresh = map_threshs[best_i]
    best_bin_thresh = bin_threshs[best_j]
    return best_map_thresh, best_bin_thresh

map_thresh, bin_thresh = compute_scores_map(X_test, Y_test)
print 'Best map_thresh=%f, bin_thresh=%f' % (map_thresh, bin_thresh)
# Out:
# Best map_thresh=0.400000, bin_thresh=0.400000

# %%
#map_thresh = 0.45
#bin_thresh = 0.9

# %%
def predict(X, map_thresh, bin_thresh):
    Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > map_thresh
    for i in range(Y_pred.shape[0]):
        if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < bin_thresh:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test, map_thresh, bin_thresh)
Y_full_pred, Y_full_pred_proba, Y_full_pred_binary = predict(X_full, map_thresh, bin_thresh)

print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "avg test set score : ", utils.average_dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
print "avg full set score : ", utils.average_dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.709152325614
# avg test set score :  0.838778626372
# full set score :  0.669143697251
# avg full set score :  0.783354156538

# %%
_ = pl.hist(Y_pred_binary)

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[30:35]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(30):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, pred44, pred88, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 15
img, pred_map = dream_output(Y_full[i])
pl.figure(figsize=(12, 4))
pl.subplot(141)
pl.imshow(X_full[i].squeeze(), cmap=cm.gray)
pl.subplot(142)
pl.imshow(Y_full[i].squeeze())
pl.subplot(143)
pl.imshow(img, cmap=cm.gray)
pl.subplot(144)
pl.imshow(pred_map.squeeze())

# %%
# Dream for the binary output
def dream_binoutput(output):
    
    layer_output = layer_dict['outbin'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output - layer_output[:, 0]))
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    
    step = 0.1
    for i in range(40):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    _, _, _, model_pred = model.predict(img[None,None,:,:])
    return img, model_pred

img, model_pred = dream_binoutput(1)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
img, model_pred = dream_binoutput(0)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
def dream_layer_filter(layer_name, filter_index):
    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(4):
        pl.subplot(1, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
_d = np.load('../data/data_128_test.npz')
X_submit = _d['X']

Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X_submit[:,None,:,:])
Y_pred_binary = Y_pred_binary.squeeze()
Y_pred_proba = Y_pred

# %%
def Y_to_binary(Y_pred, Y_pred_binary, map_thresh, bin_thresh):
    Y_pred = Y_pred > map_thresh
    for i in range(Y_pred.shape[0]):
        if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < bin_thresh:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

map_threshs = np.linspace(0, 1, num=11)
bin_threshs = np.linspace(0, 1, num=11)

masks_per = np.zeros((len(map_threshs), len(bin_threshs)))
for i in range(len(map_threshs)):
    for j in range(len(bin_threshs)):
        m_t = map_threshs[i]
        b_t = bin_threshs[j]
        _pred, _pred_proba, _pred_binary = Y_to_binary(Y_pred, Y_pred_binary, m_t, b_t)
        # Turn labels into boolean present/missing
        _pred_binary = np.sum(np.sum(np.sum(_pred, axis=2), axis=1), axis=1) > 0
        _pred_binary = _pred_binary.astype(np.float32)
        per_mask = (100 * np.count_nonzero(_pred_binary) / float(len(_pred_binary)))

        masks_per[i, j] = per_mask

pl.imshow(masks_per, interpolation='nearest')
pl.yticks(np.arange(len(map_threshs)) + 0.5, ['%.2f' % v for v in map_threshs])
pl.xticks(np.arange(len(bin_threshs)) + 0.5, ['%.2f' % v for v in bin_threshs], rotation=90)
pl.ylabel('map thresh')
pl.xlabel('bin thresh')
pl.colorbar()

# %%
np.count_nonzero(Y_pred_binary > 0.3) / float(len(Y_pred_binary))
# Out:
# 0.47639796659404504

# %%
map_thresh = 0.3
bin_thresh = 0.3

# %%
if True:
    import cv2
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(50,50))
    
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    test_fnames = _d['test_fnames']
    # bin_thresh
    Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:],
                                                  map_thresh, bin_thresh)
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = (Y_pred[i].squeeze() * 255).astype(np.uint8)
        imre = cv2.morphologyEx(imre, cv2.MORPH_CLOSE, kernel)
        imre = cv2.resize(imre, (580, 420))
        
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
        
        if i % 10 == 0:
            print '\r%d / %d' % (i, len(test_fnames)),
            sys.stdout.flush()
# Out:
# 5500 / 5508

# %%
# Turn labels into boolean present/missing
pred_binary = np.sum(np.sum(np.sum(Y_pred, axis=2), axis=1), axis=1) > 0
pred_binary = pred_binary.astype(np.float32)
print "%.2f%% with masks" % (100 * np.count_nonzero(pred_binary) / float(len(pred_binary)))
# Out:
# 44.90% with masks

# %% [markdown]
# ## Stats on predicted masks

# %%
# on Y_full
nbp_pixels = np.sum(np.sum(np.sum(Y_full, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
pl.xlim((0, 1200))
# Out:
# (0, 1200)

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
pl.xlim((0, 1200))
# Out:
# (0, 1200)
