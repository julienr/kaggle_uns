# %% [markdown]
# ## FCNN with a boolean output indicating the likelihood of the image containing nerve

# %% [markdown]
# This is submission 6, got 0.67

# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
# Out:
# (3906, 128, 128)
# (3906, 128, 128)

# %%
nsamples = X.shape[0]

#train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.25)
X_train = X[train_indices][:,None,:,:]
Y_train_binary = Y_binary[train_indices][:,None]
Y_train = Y[train_indices][:,None,:,:]
X_test = X[test_indices][:,None,:,:]
Y_test_binary = Y_binary[test_indices][:,None]
Y_test = Y[test_indices][:,None,:,:]

# %%
print X_train.shape
print Y_train.shape
print Y_train_binary.shape
print X_train.min(), X_train.max()
# Out:
# (2929, 1, 128, 128)
# (2929, 1, 128, 128)
# (2929, 1)
# 0.0 1.0

# %%
#pl.imshow(X_train[0].squeeze())
pl.imshow(Y_train[0].squeeze())
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float16'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense
from keras.layers import LeakyReLU
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
from keras.layers import Layer, InputSpec
import keras.initializations
import keras.backend as K

class Maxout2D(Layer):
    def __init__(self, output_dim, cardinality, init='glorot_uniform', **kwargs):
        super(Maxout2D, self).__init__(**kwargs)
        # the k of the maxout paper
        self.cardinality = cardinality
        # the m of the maxout paper
        self.output_dim = output_dim
        self.init = keras.initializations.get(init)
    
    def build(self, input_shape):
        self.input_dim = input_shape[1]
        self.input_spec = [InputSpec(dtype=K.floatx(),
                                     shape=(None, input_shape[1], input_shape[2], input_shape[3]))]
        self.W = self.init((self.input_dim, self.output_dim, self.cardinality),
                           name='{}_W'.format(self.name))
        self.b = K.zeros((self.output_dim, self.cardinality))
        self.trainable_weights = [self.W, self.b]
              
    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        # flatten the spatial dimensions
        flat_x = K.reshape(x, (-1, input_shape[1], input_shape[2] * input_shape[3]))
        output = K.dot(
            K.permute_dimensions(flat_x, (0, 2, 1)),
            K.permute_dimensions(self.W, (1, 0, 2))
        )
        output += K.reshape(self.b, (1, 1, self.output_dim, self.cardinality))
        output = K.max(output, axis=3)
        output = output.transpose(0, 2, 1)
        output = K.reshape(output, (-1, self.output_dim, input_shape[2], input_shape[3]))
        return output
    
    def get_output_shape_for(self, input_shape):
        return (input_shape[0], self.output_dim, input_shape[2], input_shape[3])
    
    def get_config(self):
        config = {
            'output_dim': self.output_dim,
            'cardinality': self.cardinality
        }
        base_config = super(Maxout2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))
    
input_img = Input(shape=(3, 16, 16))
x = Convolution2D(16, 3, 3, border_mode='same')(input_img)
x = Maxout2D(5, 7)(x)

model = Model(input=input_img, output=x)
model.compile(optimizer='adam', loss='mse')
print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)               (None, 3, 16, 16)   0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)    (None, 16, 16, 16)  448         input_1[0][0]
# ____________________________________________________________________________________________________
# maxout2d_1 (Maxout2D)              (None, 5, 16, 16)   595         convolution2d_1[0][0]
# ====================================================================================================
# Total params: 1043
# ____________________________________________________________________________________________________

# %% [markdown]
#     # maxout in numpy
#     X = np.random.rand(10, 2, 3, 4)
#     X = X.reshape(10, 2, 3 * 4) # 10, 3, 30
#
#     # cardinality
#     k = 2
#     # output dim
#     m = 7
#     d = X.shape[1]
#
#     #W = np.random.rand(d, m, k)
#     W = np.ones((d, m, k), dtype=np.float32)
#     for i in range(m):
#         W[:,i,:] = i
#
#     #X[0].T.dot(W[:,0,:]).shape
#
#     print X.transpose(0, 2, 1).shape
#     print W.transpose(1, 0, 2).shape
#
#     out = np.dot(X.transpose(0, 2, 1), W.transpose(1, 0, 2))
#     #out = np.tensordot(X.transpose(0, 2, 1), W.transpose(0, 1, 2), axes=1)
#     out = np.max(out, axis=3)
#     out = out.transpose(0, 2, 1)
#     out = out.reshape(10, out.shape[1], 3, 4)
#     print out.shape
#     print out[0]

# %% [markdown]
#     k_W = K.variable(W)
#     k_X = K.variable(X)
#
#     flat_x = K.reshape(k_X, (-1, 2, 3 * 4))
#
#     output = K.dot(
#         K.permute_dimensions(flat_x, (0, 2, 1)),
#         K.permute_dimensions(k_W, (1, 0, 2))
#     )
#     output = K.max(output, axis=3)
#     output = output.transpose(0, 2, 1)
#     output = K.reshape(output, (-1, W.shape[1], 3, 4))
#
#     _f = K.function([], [output])
#     k_out = _f([])[0]
#     print k_out.shape
#     print k_out

# %%
input_img = Input(shape=input_shape, name='input_img')
x = Convolution2D(16, 3, 3, border_mode='same')(input_img)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(8, 4)(x)
pool1 = x = MaxPooling2D((2, 2), name='pool1')(x)

x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(8, 4)(x)
pool2 = x = MaxPooling2D((2, 2), name='pool2')(x)

x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(8, 4)(x)
pool3 = x = MaxPooling2D((2, 2), name='pool3')(x)

# -- binary presence part
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(8, 4)(x)
pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(8, 4)(x)
pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(x)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# -- location map
x = Convolution2D(16, 3, 3, border_mode='same')(pool3)
x = Maxout2D(1, 4)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(1, 4)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(1, 4)(x)
x = UpSampling2D((2, 2))(x)

outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
model.compile(optimizer='adam', loss='binary_crossentropy',
              loss_weights=[1., 0.01])

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_55 (Convolution2D)   (None, 16, 128, 128)160         input_img[0][0]
# ____________________________________________________________________________________________________
# convolution2d_56 (Convolution2D)   (None, 16, 128, 128)2320        convolution2d_55[0][0]
# ____________________________________________________________________________________________________
# dropout_31 (Dropout)               (None, 16, 128, 128)0           convolution2d_56[0][0]
# ____________________________________________________________________________________________________
# maxout2d_50 (Maxout2D)             (None, 8, 128, 128) 544         dropout_31[0][0]
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)               (None, 8, 64, 64)   0           maxout2d_50[0][0]
# ____________________________________________________________________________________________________
# convolution2d_57 (Convolution2D)   (None, 16, 64, 64)  1168        pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_58 (Convolution2D)   (None, 16, 64, 64)  2320        convolution2d_57[0][0]
# ____________________________________________________________________________________________________
# dropout_32 (Dropout)               (None, 16, 64, 64)  0           convolution2d_58[0][0]
# ____________________________________________________________________________________________________
# maxout2d_51 (Maxout2D)             (None, 8, 64, 64)   544         dropout_32[0][0]
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)               (None, 8, 32, 32)   0           maxout2d_51[0][0]
# ____________________________________________________________________________________________________
# convolution2d_59 (Convolution2D)   (None, 32, 32, 32)  2336        pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_60 (Convolution2D)   (None, 32, 32, 32)  9248        convolution2d_59[0][0]
# ____________________________________________________________________________________________________
# dropout_33 (Dropout)               (None, 32, 32, 32)  0           convolution2d_60[0][0]
# ____________________________________________________________________________________________________
# maxout2d_52 (Maxout2D)             (None, 8, 32, 32)   1056        dropout_33[0][0]
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)               (None, 8, 16, 16)   0           maxout2d_52[0][0]
# ____________________________________________________________________________________________________
# convolution2d_61 (Convolution2D)   (None, 16, 16, 16)  1168        pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_62 (Convolution2D)   (None, 16, 16, 16)  2320        convolution2d_61[0][0]
# ____________________________________________________________________________________________________
# dropout_34 (Dropout)               (None, 16, 16, 16)  0           convolution2d_62[0][0]
# ____________________________________________________________________________________________________
# maxout2d_53 (Maxout2D)             (None, 8, 16, 16)   544         dropout_34[0][0]
# ____________________________________________________________________________________________________
# convolution2d_65 (Convolution2D)   (None, 16, 16, 16)  1168        pool3[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)               (None, 8, 8, 8)     0           maxout2d_53[0][0]
# ____________________________________________________________________________________________________
# convolution2d_63 (Convolution2D)   (None, 16, 8, 8)    1168        pool4[0][0]
# ____________________________________________________________________________________________________
# maxout2d_55 (Maxout2D)             (None, 1, 16, 16)   68          convolution2d_65[0][0]
# ____________________________________________________________________________________________________
# convolution2d_64 (Convolution2D)   (None, 16, 8, 8)    2320        convolution2d_63[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_19 (UpSampling2D)     (None, 1, 32, 32)   0           maxout2d_55[0][0]
# ____________________________________________________________________________________________________
# dropout_35 (Dropout)               (None, 16, 8, 8)    0           convolution2d_64[0][0]
# ____________________________________________________________________________________________________
# merge_13 (Merge)                   (None, 9, 32, 32)   0           upsampling2d_19[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_66 (Convolution2D)   (None, 16, 32, 32)  1312        merge_13[0][0]
# ____________________________________________________________________________________________________
# maxout2d_54 (Maxout2D)             (None, 8, 8, 8)     544         dropout_35[0][0]
# ____________________________________________________________________________________________________
# maxout2d_56 (Maxout2D)             (None, 1, 32, 32)   68          convolution2d_66[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)               (None, 8, 4, 4)     0           maxout2d_54[0][0]
# ____________________________________________________________________________________________________
# flatten_7 (Flatten)                (None, 128)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_20 (UpSampling2D)     (None, 1, 64, 64)   0           maxout2d_56[0][0]
# ____________________________________________________________________________________________________
# dense_13 (Dense)                   (None, 32)          4128        flatten_7[0][0]
# ____________________________________________________________________________________________________
# merge_14 (Merge)                   (None, 9, 64, 64)   0           upsampling2d_20[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_67 (Convolution2D)   (None, 16, 64, 64)  1312        merge_14[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_13 (LeakyReLU)           (None, 32)          0           dense_13[0][0]
# ____________________________________________________________________________________________________
# dense_14 (Dense)                   (None, 16)          528         leakyrelu_13[0][0]
# ____________________________________________________________________________________________________
# maxout2d_57 (Maxout2D)             (None, 1, 64, 64)   68          convolution2d_67[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_14 (LeakyReLU)           (None, 16)          0           dense_14[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_21 (UpSampling2D)     (None, 1, 128, 128) 0           maxout2d_57[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_14[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 10          upsampling2d_21[0][0]
# ====================================================================================================
# Total params: 36439
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {'outmap': Y_train, 'outbin': Y_train_binary},
        batch_size=64,
        validation_data=(X_test, {'outmap': Y_test, 'outbin': Y_test_binary}),
        nb_epoch=60,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    pl.plot(history.history['loss'], label='train loss')
    pl.plot(history.history['val_loss'], c='g', label='val loss')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
        custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.01])
    
    print_summary(model.layers)
# Out:
# Train on 2929 samples, validate on 977 samples
# Epoch 1/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.1596 - outmap_loss: 0.1003 - outbin_loss: 5.9380Epoch 00000: val_loss improved from inf to 0.16417, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.1595 - outmap_loss: 0.1000 - outbin_loss: 5.9432 - val_loss: 0.1642 - val_outmap_loss: 0.1025 - val_outbin_loss: 6.1701
# Epoch 2/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.1296 - outmap_loss: 0.0700 - outbin_loss: 5.9603Epoch 00001: val_loss improved from 0.16417 to 0.13988, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.1292 - outmap_loss: 0.0697 - outbin_loss: 5.9432 - val_loss: 0.1399 - val_outmap_loss: 0.0782 - val_outbin_loss: 6.1701
# Epoch 3/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.1174 - outmap_loss: 0.0581 - outbin_loss: 5.9212Epoch 00002: val_loss improved from 0.13988 to 0.12297, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.1176 - outmap_loss: 0.0582 - outbin_loss: 5.9432 - val_loss: 0.1230 - val_outmap_loss: 0.0613 - val_outbin_loss: 6.1701
# Epoch 4/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.1125 - outmap_loss: 0.0532 - outbin_loss: 5.9380Epoch 00003: val_loss improved from 0.12297 to 0.12016, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.1125 - outmap_loss: 0.0531 - outbin_loss: 5.9432 - val_loss: 0.1202 - val_outmap_loss: 0.0585 - val_outbin_loss: 6.1701
# Epoch 5/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.1098 - outmap_loss: 0.0499 - outbin_loss: 5.9827Epoch 00004: val_loss improved from 0.12016 to 0.10845, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.1091 - outmap_loss: 0.0497 - outbin_loss: 5.9432 - val_loss: 0.1084 - val_outmap_loss: 0.0467 - val_outbin_loss: 6.1701
# Epoch 6/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.1074 - outmap_loss: 0.0478 - outbin_loss: 5.9603Epoch 00005: val_loss improved from 0.10845 to 0.10667, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.1071 - outmap_loss: 0.0476 - outbin_loss: 5.9432 - val_loss: 0.1067 - val_outmap_loss: 0.0450 - val_outbin_loss: 6.1701
# Epoch 7/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.1027 - outmap_loss: 0.0436 - outbin_loss: 5.9100Epoch 00006: val_loss improved from 0.10667 to 0.10266, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.1031 - outmap_loss: 0.0437 - outbin_loss: 5.9432 - val_loss: 0.1027 - val_outmap_loss: 0.0410 - val_outbin_loss: 6.1701
# Epoch 8/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.1003 - outmap_loss: 0.0409 - outbin_loss: 5.9380Epoch 00007: val_loss improved from 0.10266 to 0.10062, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.1005 - outmap_loss: 0.0410 - outbin_loss: 5.9432 - val_loss: 0.1006 - val_outmap_loss: 0.0389 - val_outbin_loss: 6.1701
# Epoch 9/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0983 - outmap_loss: 0.0389 - outbin_loss: 5.9435Epoch 00008: val_loss improved from 0.10062 to 0.10024, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.0982 - outmap_loss: 0.0388 - outbin_loss: 5.9432 - val_loss: 0.1002 - val_outmap_loss: 0.0385 - val_outbin_loss: 6.1701
# Epoch 10/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0981 - outmap_loss: 0.0385 - outbin_loss: 5.9547Epoch 00009: val_loss improved from 0.10024 to 0.09844, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.0978 - outmap_loss: 0.0384 - outbin_loss: 5.9432 - val_loss: 0.0984 - val_outmap_loss: 0.0367 - val_outbin_loss: 6.1701
# Epoch 11/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0957 - outmap_loss: 0.0362 - outbin_loss: 5.9435Epoch 00010: val_loss improved from 0.09844 to 0.09658, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.0957 - outmap_loss: 0.0363 - outbin_loss: 5.9432 - val_loss: 0.0966 - val_outmap_loss: 0.0349 - val_outbin_loss: 6.1701
# Epoch 12/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0940 - outmap_loss: 0.0344 - outbin_loss: 5.9603Epoch 00011: val_loss improved from 0.09658 to 0.09521, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.0937 - outmap_loss: 0.0342 - outbin_loss: 5.9432 - val_loss: 0.0952 - val_outmap_loss: 0.0335 - val_outbin_loss: 6.1701
# Epoch 13/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0924 - outmap_loss: 0.0331 - outbin_loss: 5.9324Epoch 00012: val_loss improved from 0.09521 to 0.09351, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.0926 - outmap_loss: 0.0331 - outbin_loss: 5.9432 - val_loss: 0.0935 - val_outmap_loss: 0.0318 - val_outbin_loss: 6.1701
# Epoch 14/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0912 - outmap_loss: 0.0321 - outbin_loss: 5.9100Epoch 00013: val_loss did not improve
# 2929/2929 [==============================] - 23s - loss: 0.0918 - outmap_loss: 0.0323 - outbin_loss: 5.9432 - val_loss: 0.0965 - val_outmap_loss: 0.0348 - val_outbin_loss: 6.1701
# Epoch 15/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0922 - outmap_loss: 0.0329 - outbin_loss: 5.9268Epoch 00014: val_loss improved from 0.09351 to 0.09279, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.0924 - outmap_loss: 0.0330 - outbin_loss: 5.9432 - val_loss: 0.0928 - val_outmap_loss: 0.0311 - val_outbin_loss: 6.1701
# Epoch 16/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0917 - outmap_loss: 0.0322 - outbin_loss: 5.9491Epoch 00015: val_loss did not improve
# 2929/2929 [==============================] - 23s - loss: 0.0917 - outmap_loss: 0.0322 - outbin_loss: 5.9432 - val_loss: 0.0938 - val_outmap_loss: 0.0321 - val_outbin_loss: 6.1701
# Epoch 17/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0900 - outmap_loss: 0.0305 - outbin_loss: 5.9491Epoch 00016: val_loss improved from 0.09279 to 0.09079, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.0898 - outmap_loss: 0.0304 - outbin_loss: 5.9432 - val_loss: 0.0908 - val_outmap_loss: 0.0291 - val_outbin_loss: 6.1701
# Epoch 18/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0897 - outmap_loss: 0.0306 - outbin_loss: 5.9100Epoch 00017: val_loss did not improve
# 2929/2929 [==============================] - 23s - loss: 0.0901 - outmap_loss: 0.0307 - outbin_loss: 5.9432 - val_loss: 0.0912 - val_outmap_loss: 0.0295 - val_outbin_loss: 6.1701
# Epoch 19/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0895 - outmap_loss: 0.0296 - outbin_loss: 5.9939Epoch 00018: val_loss improved from 0.09079 to 0.08999, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.0889 - outmap_loss: 0.0295 - outbin_loss: 5.9432 - val_loss: 0.0900 - val_outmap_loss: 0.0283 - val_outbin_loss: 6.1701
# Epoch 20/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0883 - outmap_loss: 0.0290 - outbin_loss: 5.9324Epoch 00019: val_loss did not improve
# 2929/2929 [==============================] - 23s - loss: 0.0885 - outmap_loss: 0.0291 - outbin_loss: 5.9432 - val_loss: 0.0915 - val_outmap_loss: 0.0298 - val_outbin_loss: 6.1701
# Epoch 21/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0886 - outmap_loss: 0.0290 - outbin_loss: 5.9603Epoch 00020: val_loss improved from 0.08999 to 0.08902, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.0885 - outmap_loss: 0.0291 - outbin_loss: 5.9432 - val_loss: 0.0890 - val_outmap_loss: 0.0273 - val_outbin_loss: 6.1701
# Epoch 22/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0874 - outmap_loss: 0.0281 - outbin_loss: 5.9324Epoch 00021: val_loss did not improve
# 2929/2929 [==============================] - 23s - loss: 0.0876 - outmap_loss: 0.0281 - outbin_loss: 5.9432 - val_loss: 0.0897 - val_outmap_loss: 0.0280 - val_outbin_loss: 6.1701
# Epoch 23/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0876 - outmap_loss: 0.0284 - outbin_loss: 5.9156Epoch 00022: val_loss improved from 0.08902 to 0.08845, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.0880 - outmap_loss: 0.0285 - outbin_loss: 5.9432 - val_loss: 0.0884 - val_outmap_loss: 0.0267 - val_outbin_loss: 6.1701
# Epoch 24/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0869 - outmap_loss: 0.0275 - outbin_loss: 5.9435Epoch 00023: val_loss did not improve
# 2929/2929 [==============================] - 23s - loss: 0.0869 - outmap_loss: 0.0274 - outbin_loss: 5.9432 - val_loss: 0.0888 - val_outmap_loss: 0.0271 - val_outbin_loss: 6.1701
# Epoch 25/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0868 - outmap_loss: 0.0274 - outbin_loss: 5.9435Epoch 00024: val_loss did not improve
# 2929/2929 [==============================] - 23s - loss: 0.0869 - outmap_loss: 0.0275 - outbin_loss: 5.9432 - val_loss: 0.0888 - val_outmap_loss: 0.0271 - val_outbin_loss: 6.1701
# Epoch 26/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0877 - outmap_loss: 0.0281 - outbin_loss: 5.9603Epoch 00025: val_loss improved from 0.08845 to 0.08768, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.0874 - outmap_loss: 0.0280 - outbin_loss: 5.9432 - val_loss: 0.0877 - val_outmap_loss: 0.0260 - val_outbin_loss: 6.1701
# Epoch 27/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0865 - outmap_loss: 0.0272 - outbin_loss: 5.9324Epoch 00026: val_loss did not improve
# 2929/2929 [==============================] - 23s - loss: 0.0867 - outmap_loss: 0.0273 - outbin_loss: 5.9432 - val_loss: 0.0883 - val_outmap_loss: 0.0266 - val_outbin_loss: 6.1701
# Epoch 28/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0866 - outmap_loss: 0.0270 - outbin_loss: 5.9603Epoch 00027: val_loss did not improve
# 2929/2929 [==============================] - 23s - loss: 0.0863 - outmap_loss: 0.0269 - outbin_loss: 5.9432 - val_loss: 0.0883 - val_outmap_loss: 0.0266 - val_outbin_loss: 6.1701
# Epoch 29/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0855 - outmap_loss: 0.0261 - outbin_loss: 5.9380Epoch 00028: val_loss did not improve
# 2929/2929 [==============================] - 23s - loss: 0.0855 - outmap_loss: 0.0261 - outbin_loss: 5.9432 - val_loss: 0.0877 - val_outmap_loss: 0.0260 - val_outbin_loss: 6.1701
# Epoch 30/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0853 - outmap_loss: 0.0259 - outbin_loss: 5.9324Epoch 00029: val_loss improved from 0.08768 to 0.08625, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.0853 - outmap_loss: 0.0259 - outbin_loss: 5.9432 - val_loss: 0.0863 - val_outmap_loss: 0.0245 - val_outbin_loss: 6.1701
# Epoch 31/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0851 - outmap_loss: 0.0255 - outbin_loss: 5.9547Epoch 00030: val_loss did not improve
# 2929/2929 [==============================] - 23s - loss: 0.0848 - outmap_loss: 0.0254 - outbin_loss: 5.9432 - val_loss: 0.0864 - val_outmap_loss: 0.0247 - val_outbin_loss: 6.1701
# Epoch 32/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0851 - outmap_loss: 0.0256 - outbin_loss: 5.9491Epoch 00031: val_loss improved from 0.08625 to 0.08585, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.0849 - outmap_loss: 0.0255 - outbin_loss: 5.9432 - val_loss: 0.0859 - val_outmap_loss: 0.0242 - val_outbin_loss: 6.1701
# Epoch 33/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0848 - outmap_loss: 0.0253 - outbin_loss: 5.9547Epoch 00032: val_loss did not improve
# 2929/2929 [==============================] - 23s - loss: 0.0846 - outmap_loss: 0.0252 - outbin_loss: 5.9432 - val_loss: 0.0861 - val_outmap_loss: 0.0244 - val_outbin_loss: 6.1701
# Epoch 34/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0839 - outmap_loss: 0.0246 - outbin_loss: 5.9212Epoch 00033: val_loss improved from 0.08585 to 0.08518, saving model to weights.hdf5
# 2929/2929 [==============================] - 23s - loss: 0.0841 - outmap_loss: 0.0247 - outbin_loss: 5.9432 - val_loss: 0.0852 - val_outmap_loss: 0.0235 - val_outbin_loss: 6.1701
# Epoch 35/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0839 - outmap_loss: 0.0246 - outbin_loss: 5.9324Epoch 00034: val_loss did not improve
# 2929/2929 [==============================] - 23s - loss: 0.0841 - outmap_loss: 0.0246 - outbin_loss: 5.9432 - val_loss: 0.0860 - val_outmap_loss: 0.0243 - val_outbin_loss: 6.1701
# Epoch 36/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0834 - outmap_loss: 0.0243 - outbin_loss: 5.9100Epoch 00035: val_loss improved from 0.08518 to 0.08513, saving model to weights.hdf5
# 2929/2929 [==============================] - 24s - loss: 0.0838 - outmap_loss: 0.0244 - outbin_loss: 5.9432 - val_loss: 0.0851 - val_outmap_loss: 0.0234 - val_outbin_loss: 6.1701
# Epoch 37/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0837 - outmap_loss: 0.0242 - outbin_loss: 5.9491Epoch 00036: val_loss did not improve
# 2929/2929 [==============================] - 24s - loss: 0.0836 - outmap_loss: 0.0242 - outbin_loss: 5.9432 - val_loss: 0.0853 - val_outmap_loss: 0.0236 - val_outbin_loss: 6.1701
# Epoch 38/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0842 - outmap_loss: 0.0246 - outbin_loss: 5.9547Epoch 00037: val_loss did not improve
# 2929/2929 [==============================] - 24s - loss: 0.0840 - outmap_loss: 0.0246 - outbin_loss: 5.9432 - val_loss: 0.0860 - val_outmap_loss: 0.0243 - val_outbin_loss: 6.1701
# Epoch 39/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0831 - outmap_loss: 0.0239 - outbin_loss: 5.9212Epoch 00038: val_loss did not improve
# 2929/2929 [==============================] - 24s - loss: 0.0834 - outmap_loss: 0.0239 - outbin_loss: 5.9432 - val_loss: 0.0852 - val_outmap_loss: 0.0235 - val_outbin_loss: 6.1701
# Epoch 40/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0827 - outmap_loss: 0.0236 - outbin_loss: 5.9100Epoch 00039: val_loss did not improve
# 2929/2929 [==============================] - 24s - loss: 0.0831 - outmap_loss: 0.0237 - outbin_loss: 5.9432 - val_loss: 0.0853 - val_outmap_loss: 0.0236 - val_outbin_loss: 6.1701
# Epoch 41/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0831 - outmap_loss: 0.0238 - outbin_loss: 5.9324Epoch 00040: val_loss did not improve
# 2929/2929 [==============================] - 24s - loss: 0.0832 - outmap_loss: 0.0238 - outbin_loss: 5.9432 - val_loss: 0.0856 - val_outmap_loss: 0.0239 - val_outbin_loss: 6.1701
# Epoch 42/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0831 - outmap_loss: 0.0234 - outbin_loss: 5.9659Epoch 00041: val_loss did not improve
# 2929/2929 [==============================] - 24s - loss: 0.0829 - outmap_loss: 0.0234 - outbin_loss: 5.9432 - val_loss: 0.0859 - val_outmap_loss: 0.0242 - val_outbin_loss: 6.1701
# Epoch 43/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0836 - outmap_loss: 0.0242 - outbin_loss: 5.9435Epoch 00042: val_loss did not improve
# 2929/2929 [==============================] - 24s - loss: 0.0836 - outmap_loss: 0.0242 - outbin_loss: 5.9432 - val_loss: 0.0858 - val_outmap_loss: 0.0241 - val_outbin_loss: 6.1701
# Epoch 44/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0827 - outmap_loss: 0.0234 - outbin_loss: 5.9268Epoch 00043: val_loss improved from 0.08513 to 0.08395, saving model to weights.hdf5
# 2929/2929 [==============================] - 24s - loss: 0.0828 - outmap_loss: 0.0234 - outbin_loss: 5.9432 - val_loss: 0.0840 - val_outmap_loss: 0.0223 - val_outbin_loss: 6.1701
# Epoch 45/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0831 - outmap_loss: 0.0236 - outbin_loss: 5.9547Epoch 00044: val_loss did not improve
# 2929/2929 [==============================] - 24s - loss: 0.0830 - outmap_loss: 0.0235 - outbin_loss: 5.9432 - val_loss: 0.0853 - val_outmap_loss: 0.0236 - val_outbin_loss: 6.1701
# Epoch 46/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0829 - outmap_loss: 0.0234 - outbin_loss: 5.9491Epoch 00045: val_loss did not improve
# 2929/2929 [==============================] - 24s - loss: 0.0828 - outmap_loss: 0.0234 - outbin_loss: 5.9432 - val_loss: 0.0848 - val_outmap_loss: 0.0231 - val_outbin_loss: 6.1701
# Epoch 47/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0823 - outmap_loss: 0.0231 - outbin_loss: 5.9268Epoch 00046: val_loss improved from 0.08395 to 0.08339, saving model to weights.hdf5
# 2929/2929 [==============================] - 24s - loss: 0.0824 - outmap_loss: 0.0230 - outbin_loss: 5.9432 - val_loss: 0.0834 - val_outmap_loss: 0.0217 - val_outbin_loss: 6.1701
# Epoch 48/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0829 - outmap_loss: 0.0235 - outbin_loss: 5.9380Epoch 00047: val_loss did not improve
# 2929/2929 [==============================] - 24s - loss: 0.0830 - outmap_loss: 0.0235 - outbin_loss: 5.9432 - val_loss: 0.0849 - val_outmap_loss: 0.0232 - val_outbin_loss: 6.1701
# Epoch 49/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0821 - outmap_loss: 0.0228 - outbin_loss: 5.9268Epoch 00048: val_loss did not improve
# 2929/2929 [==============================] - 24s - loss: 0.0823 - outmap_loss: 0.0228 - outbin_loss: 5.9432 - val_loss: 0.0860 - val_outmap_loss: 0.0243 - val_outbin_loss: 6.1701
# Epoch 50/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0820 - outmap_loss: 0.0228 - outbin_loss: 5.9268Epoch 00049: val_loss did not improve
# 2929/2929 [==============================] - 24s - loss: 0.0823 - outmap_loss: 0.0229 - outbin_loss: 5.9432 - val_loss: 0.0837 - val_outmap_loss: 0.0220 - val_outbin_loss: 6.1701
# Epoch 51/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0818 - outmap_loss: 0.0227 - outbin_loss: 5.9156Epoch 00050: val_loss did not improve
# 2929/2929 [==============================] - 24s - loss: 0.0822 - outmap_loss: 0.0228 - outbin_loss: 5.9432 - val_loss: 0.0857 - val_outmap_loss: 0.0240 - val_outbin_loss: 6.1701
# Epoch 52/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0820 - outmap_loss: 0.0227 - outbin_loss: 5.9268Epoch 00051: val_loss did not improve
# 2929/2929 [==============================] - 24s - loss: 0.0823 - outmap_loss: 0.0229 - outbin_loss: 5.9432 - val_loss: 0.0835 - val_outmap_loss: 0.0218 - val_outbin_loss: 6.1701
# Epoch 53/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0826 - outmap_loss: 0.0229 - outbin_loss: 5.9715Epoch 00052: val_loss improved from 0.08339 to 0.08326, saving model to weights.hdf5
# 2929/2929 [==============================] - 24s - loss: 0.0822 - outmap_loss: 0.0228 - outbin_loss: 5.9432 - val_loss: 0.0833 - val_outmap_loss: 0.0216 - val_outbin_loss: 6.1701
# Epoch 54/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0814 - outmap_loss: 0.0222 - outbin_loss: 5.9156Epoch 00053: val_loss did not improve
# 2929/2929 [==============================] - 24s - loss: 0.0817 - outmap_loss: 0.0223 - outbin_loss: 5.9432 - val_loss: 0.0833 - val_outmap_loss: 0.0216 - val_outbin_loss: 6.1701
# Epoch 55/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0826 - outmap_loss: 0.0228 - outbin_loss: 5.9827Epoch 00054: val_loss improved from 0.08326 to 0.08295, saving model to weights.hdf5
# 2929/2929 [==============================] - 24s - loss: 0.0822 - outmap_loss: 0.0227 - outbin_loss: 5.9432 - val_loss: 0.0830 - val_outmap_loss: 0.0212 - val_outbin_loss: 6.1701
# Epoch 56/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0814 - outmap_loss: 0.0219 - outbin_loss: 5.9491Epoch 00055: val_loss improved from 0.08295 to 0.08291, saving model to weights.hdf5
# 2929/2929 [==============================] - 24s - loss: 0.0813 - outmap_loss: 0.0219 - outbin_loss: 5.9432 - val_loss: 0.0829 - val_outmap_loss: 0.0212 - val_outbin_loss: 6.1701
# Epoch 57/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0816 - outmap_loss: 0.0222 - outbin_loss: 5.9435Epoch 00056: val_loss did not improve
# 2929/2929 [==============================] - 24s - loss: 0.0816 - outmap_loss: 0.0222 - outbin_loss: 5.9432 - val_loss: 0.0831 - val_outmap_loss: 0.0214 - val_outbin_loss: 6.1701
# Epoch 58/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0817 - outmap_loss: 0.0219 - outbin_loss: 5.9771Epoch 00057: val_loss did not improve
# 2929/2929 [==============================] - 24s - loss: 0.0812 - outmap_loss: 0.0218 - outbin_loss: 5.9432 - val_loss: 0.0832 - val_outmap_loss: 0.0215 - val_outbin_loss: 6.1701
# Epoch 59/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0812 - outmap_loss: 0.0217 - outbin_loss: 5.9491Epoch 00058: val_loss did not improve
# 2929/2929 [==============================] - 24s - loss: 0.0811 - outmap_loss: 0.0217 - outbin_loss: 5.9432 - val_loss: 0.0830 - val_outmap_loss: 0.0213 - val_outbin_loss: 6.1701
# Epoch 60/60
# 2880/2929 [============================>.] - ETA: 0s - loss: 0.0810 - outmap_loss: 0.0214 - outbin_loss: 5.9547Epoch 00059: val_loss did not improve
# 2929/2929 [==============================] - 24s - loss: 0.0809 - outmap_loss: 0.0215 - outbin_loss: 5.9432 - val_loss: 0.0829 - val_outmap_loss: 0.0212 - val_outbin_loss: 6.1701

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights.hdf5'))

# %%
conv1 = model.layers[1].output
_f = K.function([K.learning_phase(), input_img], [conv1])
_convout = _f([0, X_test[:1]])[0]
print _convout.shape

maxout1 = model.layers[3].output
_f = K.function([K.learning_phase(), input_img], [maxout1])
_maxout = _f([0, X_test[:1]])[0]
print _maxout.shape

pl.figure()
pl.imshow(_convout[0, 0], interpolation='nearest')
pl.colorbar()
pl.figure()
pl.imshow(_maxout[0, 0], interpolation='nearest')
pl.colorbar()
# Out:
# (1, 16, 128, 128)
# (1, 16, 128, 128)
# <matplotlib.colorbar.Colorbar instance at 0x7fb0c421bea8>

# %%
def predict(X):
    Y_pred, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > 0.3
    for i in range(Y_pred.shape[0]):
        # Clear prediction where we detect to little pixels
        # Figure it out by
        # pl.hist(np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1))
        if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < 0.5:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test)
Y_full_pred, Y_full_pred_proba, Y_full_pred_binary = predict(X_full)

print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.0
# full set score :  0.0

# %%
Y_pred_binary.max()
# Out:
# 1.4583882604161935e-13

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[:5]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    
    blob_proba = np.mean(Y_pred_proba[i][Y_pred[i] == 1])
    pl.title('prediction proba %f' % blob_proba)
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 15
img, pred_map = dream_output(Y_full[i])
pl.figure(figsize=(12, 4))
pl.subplot(131)
pl.imshow(Y_full[i].squeeze())
pl.subplot(132)
pl.imshow(img, cmap=cm.gray)
pl.subplot(133)
pl.imshow(pred_map.squeeze())

# %%
# Dream for the binary output
def dream_binoutput(output):
    
    layer_output = layer_dict['outbin'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output - layer_output[:, 0]))
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    
    step = 0.1
    for i in range(40):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    _, model_pred = model.predict(img[None,None,:,:])
    return img, model_pred

img, model_pred = dream_binoutput(1)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-2e693f988dee> in <module>()
#      38     return img, model_pred
#      39
# ---> 40 img, model_pred = dream_binoutput(1)
#      41 pl.title('pred : %f' % model_pred)
#      42 pl.imshow(img, cmap=cm.gray)
#
# <ipython-input-39-2e693f988dee> in dream_binoutput(output)
#       6     loss = K.mean(K.square(output - layer_output[:, 0]))
#       7
# ----> 8     input_img = layer_dict['input_1'].input
#       9
#      10     # compute the gradient of the input picture wrt this loss
#
# KeyError: 'input_1'

# %%
img, model_pred = dream_binoutput(0)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
def dream_layer_filter(layer_name, filter_index):

    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_1'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(8):
        pl.subplot(2, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
_d = np.load('../../data_128_test.npz')
X_submit = _d['X']
test_fnames = _d['test_fnames']
Y_pred, Y_pred_proba = predict(X_submit[:,None,:,:])

# %%
OUTDIR='../../preds'
if os.path.exists(OUTDIR):
    shutil.rmtree(OUTDIR)
utils.mkdir_p(OUTDIR)

for i in range(Y_pred.shape[0]):
    imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
    basename = os.path.splitext(test_fnames[i])[0]
    cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
