# %% [markdown]
# ## FCNN with a boolean output indicating the likelihood of the image containing nerve

# %% [markdown]
# This is submission 6, got 0.67

# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
# Out:
# (3906, 128, 128)
# (3906, 128, 128)

# %%
nsamples = X.shape[0]

#train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.25)
X_train = X[train_indices][:,None,:,:]
Y_train_binary = Y_binary[train_indices][:,None]
Y_train = Y[train_indices][:,None,:,:]
X_test = X[test_indices][:,None,:,:]
Y_test_binary = Y_binary[test_indices][:,None]
Y_test = Y[test_indices][:,None,:,:]

# %%
print X_train.shape
print Y_train.shape
print Y_train_binary.shape
print X_train.min(), X_train.max()
# Out:
# (2929, 1, 128, 128)
# (2929, 1, 128, 128)
# (2929, 1)
# 0.0 1.0

# %%
#pl.imshow(X_train[0].squeeze())
pl.imshow(Y_train[0].squeeze())
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float16'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense
from keras.layers import LeakyReLU
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
from keras.layers import Layer, InputSpec
import keras.initializations
import keras.backend as K

class Maxout2D(Layer):
    def __init__(self, output_dim, cardinality, init='glorot_uniform', **kwargs):
        super(Maxout2D, self).__init__(**kwargs)
        # the k of the maxout paper
        self.cardinality = cardinality
        # the m of the maxout paper
        self.output_dim = output_dim
        self.init = keras.initializations.get(init)
    
    def build(self, input_shape):
        self.input_dim = input_shape[1]
        self.input_spec = [InputSpec(dtype=K.floatx(),
                                     shape=(None, input_shape[1], input_shape[2], input_shape[3]))]
        self.W = self.init((self.input_dim, self.output_dim, self.cardinality),
                           name='{}_W'.format(self.name))
        self.b = K.zeros((self.output_dim, self.cardinality))
        self.trainable_weights = [self.W, self.b]
              
    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        # flatten the spatial dimensions
        flat_x = K.reshape(x, (-1, input_shape[1], input_shape[2] * input_shape[3]))
        output = K.dot(
            K.permute_dimensions(flat_x, (0, 2, 1)),
            K.permute_dimensions(self.W, (1, 0, 2))
        )
        output += K.reshape(self.b, (1, 1, self.output_dim, self.cardinality))
        output = K.max(output, axis=3)
        output = output.transpose(0, 2, 1)
        output = K.reshape(output, (-1, self.output_dim, input_shape[2], input_shape[3]))
        return output
    
    def get_output_shape_for(self, input_shape):
        return (input_shape[0], self.output_dim, input_shape[2], input_shape[3])
    
    def get_config(self):
        config = {
            'output_dim': self.output_dim,
            'cardinality': self.cardinality
        }
        base_config = super(Maxout2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))
    
input_img = Input(shape=(3, 16, 16))
x = Convolution2D(16, 3, 3, border_mode='same')(input_img)
x = Maxout2D(5, 7)(x)

model = Model(input=input_img, output=x)
model.compile(optimizer='adam', loss='mse')
print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)               (None, 3, 16, 16)   0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)    (None, 16, 16, 16)  448         input_1[0][0]
# ____________________________________________________________________________________________________
# maxout2d_1 (Maxout2D)              (None, 5, 16, 16)   595         convolution2d_1[0][0]
# ====================================================================================================
# Total params: 1043
# ____________________________________________________________________________________________________

# %% [markdown]
#     # maxout in numpy
#     X = np.random.rand(10, 2, 3, 4)
#     X = X.reshape(10, 2, 3 * 4) # 10, 3, 30
#
#     # cardinality
#     k = 2
#     # output dim
#     m = 7
#     d = X.shape[1]
#
#     #W = np.random.rand(d, m, k)
#     W = np.ones((d, m, k), dtype=np.float32)
#     for i in range(m):
#         W[:,i,:] = i
#
#     #X[0].T.dot(W[:,0,:]).shape
#
#     print X.transpose(0, 2, 1).shape
#     print W.transpose(1, 0, 2).shape
#
#     out = np.dot(X.transpose(0, 2, 1), W.transpose(1, 0, 2))
#     #out = np.tensordot(X.transpose(0, 2, 1), W.transpose(0, 1, 2), axes=1)
#     out = np.max(out, axis=3)
#     out = out.transpose(0, 2, 1)
#     out = out.reshape(10, out.shape[1], 3, 4)
#     print out.shape
#     print out[0]

# %% [markdown]
#     k_W = K.variable(W)
#     k_X = K.variable(X)
#
#     flat_x = K.reshape(k_X, (-1, 2, 3 * 4))
#
#     output = K.dot(
#         K.permute_dimensions(flat_x, (0, 2, 1)),
#         K.permute_dimensions(k_W, (1, 0, 2))
#     )
#     output = K.max(output, axis=3)
#     output = output.transpose(0, 2, 1)
#     output = K.reshape(output, (-1, W.shape[1], 3, 4))
#
#     _f = K.function([], [output])
#     k_out = _f([])[0]
#     print k_out.shape
#     print k_out

# %%
# https://www.kaggle.com/c/ultrasound-nerve-segmentation/forums/t/21358/0-57-deep-learning-keras-tutorial
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def dice_coef_batchwise(y_true, y_pred):
    y_true_f = K.batch_flatten(y_true)
    y_pred_f = K.batch_flatten(y_pred)
    intersection = 2. * K.sum(y_true_f * y_pred_f, axis=1, keepdims=True) + smooth
    union = K.sum(y_true_f, axis=1, keepdims=True) + \
            K.sum(y_pred_f, axis=1, keepdims=True) + \
            smooth
    return K.mean(intersection / union)

def dice_coef_loss_batchwise(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
input_img = Input(shape=input_shape, name='input_img')
x = Convolution2D(16, 3, 3, border_mode='same')(input_img)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(16, 2)(x)
pool1 = x = MaxPooling2D((2, 2), name='pool1')(x)

x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(16, 2)(x)
pool2 = x = MaxPooling2D((2, 2), name='pool2')(x)

x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(16, 2)(x)
pool3 = x = MaxPooling2D((2, 2), name='pool3')(x)

# -- binary presence part
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(16, 2)(x)
pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(16, 2)(x)
pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(x)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# -- location map
x = Convolution2D(16, 3, 3, border_mode='same')(pool3)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
x = UpSampling2D((2, 2))(x)

outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
loss='binary_crossentropy'
loss=[dice_coef_loss_batchwise, 'binary_crossentropy']
metrics={'outmap': dice_coef, 'outbin': 'accuracy'}
model.compile(optimizer='adam',
              loss=loss,
              loss_weights=[1., 0.01],
              metrics=metrics)

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_50 (Convolution2D)   (None, 16, 128, 128)160         input_img[0][0]
# ____________________________________________________________________________________________________
# convolution2d_51 (Convolution2D)   (None, 16, 128, 128)2320        convolution2d_50[0][0]
# ____________________________________________________________________________________________________
# dropout_16 (Dropout)               (None, 16, 128, 128)0           convolution2d_51[0][0]
# ____________________________________________________________________________________________________
# maxout2d_26 (Maxout2D)             (None, 16, 128, 128)544         dropout_16[0][0]
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)               (None, 16, 64, 64)  0           maxout2d_26[0][0]
# ____________________________________________________________________________________________________
# convolution2d_52 (Convolution2D)   (None, 16, 64, 64)  2320        pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_53 (Convolution2D)   (None, 16, 64, 64)  2320        convolution2d_52[0][0]
# ____________________________________________________________________________________________________
# dropout_17 (Dropout)               (None, 16, 64, 64)  0           convolution2d_53[0][0]
# ____________________________________________________________________________________________________
# maxout2d_27 (Maxout2D)             (None, 16, 64, 64)  544         dropout_17[0][0]
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)               (None, 16, 32, 32)  0           maxout2d_27[0][0]
# ____________________________________________________________________________________________________
# convolution2d_54 (Convolution2D)   (None, 32, 32, 32)  4640        pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_55 (Convolution2D)   (None, 32, 32, 32)  9248        convolution2d_54[0][0]
# ____________________________________________________________________________________________________
# dropout_18 (Dropout)               (None, 32, 32, 32)  0           convolution2d_55[0][0]
# ____________________________________________________________________________________________________
# maxout2d_28 (Maxout2D)             (None, 16, 32, 32)  1056        dropout_18[0][0]
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)               (None, 16, 16, 16)  0           maxout2d_28[0][0]
# ____________________________________________________________________________________________________
# convolution2d_56 (Convolution2D)   (None, 16, 16, 16)  2320        pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_57 (Convolution2D)   (None, 16, 16, 16)  2320        convolution2d_56[0][0]
# ____________________________________________________________________________________________________
# convolution2d_60 (Convolution2D)   (None, 16, 16, 16)  2320        pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_61 (Convolution2D)   (None, 16, 16, 16)  2320        convolution2d_60[0][0]
# ____________________________________________________________________________________________________
# dropout_19 (Dropout)               (None, 16, 16, 16)  0           convolution2d_57[0][0]
# ____________________________________________________________________________________________________
# maxout2d_29 (Maxout2D)             (None, 16, 16, 16)  544         dropout_19[0][0]
# ____________________________________________________________________________________________________
# maxout2d_31 (Maxout2D)             (None, 16, 16, 16)  544         convolution2d_61[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)               (None, 16, 8, 8)    0           maxout2d_29[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_10 (UpSampling2D)     (None, 16, 32, 32)  0           maxout2d_31[0][0]
# ____________________________________________________________________________________________________
# convolution2d_58 (Convolution2D)   (None, 16, 8, 8)    2320        pool4[0][0]
# ____________________________________________________________________________________________________
# merge_7 (Merge)                    (None, 32, 32, 32)  0           upsampling2d_10[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_59 (Convolution2D)   (None, 16, 8, 8)    2320        convolution2d_58[0][0]
# ____________________________________________________________________________________________________
# convolution2d_62 (Convolution2D)   (None, 16, 32, 32)  4624        merge_7[0][0]
# ____________________________________________________________________________________________________
# convolution2d_63 (Convolution2D)   (None, 16, 32, 32)  2320        convolution2d_62[0][0]
# ____________________________________________________________________________________________________
# dropout_20 (Dropout)               (None, 16, 8, 8)    0           convolution2d_59[0][0]
# ____________________________________________________________________________________________________
# maxout2d_30 (Maxout2D)             (None, 16, 8, 8)    544         dropout_20[0][0]
# ____________________________________________________________________________________________________
# maxout2d_32 (Maxout2D)             (None, 16, 32, 32)  544         convolution2d_63[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)               (None, 16, 4, 4)    0           maxout2d_30[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_11 (UpSampling2D)     (None, 16, 64, 64)  0           maxout2d_32[0][0]
# ____________________________________________________________________________________________________
# flatten_4 (Flatten)                (None, 256)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# merge_8 (Merge)                    (None, 32, 64, 64)  0           upsampling2d_11[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_64 (Convolution2D)   (None, 16, 64, 64)  4624        merge_8[0][0]
# ____________________________________________________________________________________________________
# dense_7 (Dense)                    (None, 32)          8224        flatten_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_65 (Convolution2D)   (None, 16, 64, 64)  2320        convolution2d_64[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_7 (LeakyReLU)            (None, 32)          0           dense_7[0][0]
# ____________________________________________________________________________________________________
# dense_8 (Dense)                    (None, 16)          528         leakyrelu_7[0][0]
# ____________________________________________________________________________________________________
# maxout2d_33 (Maxout2D)             (None, 16, 64, 64)  544         convolution2d_65[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_8 (LeakyReLU)            (None, 16)          0           dense_8[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_12 (UpSampling2D)     (None, 16, 128, 128)0           maxout2d_33[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_8[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 145         upsampling2d_12[0][0]
# ====================================================================================================
# Total params: 62594
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {'outmap': Y_train, 'outbin': Y_train_binary},
        batch_size=64,
        validation_data=(X_test, {'outmap': Y_test, 'outbin': Y_test_binary}),
        nb_epoch=70,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    pl.plot(history.history['loss'], label='train loss')
    pl.plot(history.history['val_loss'], c='g', label='val loss')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
        custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.01])
    
    print_summary(model.layers)
# Out:
# Train on 2929 samples, validate on 977 samples
# Epoch 1/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.0640 - outmap_loss: -0.0719 - outbin_loss: 0.7921 - outmap_dice_coef: 0.0719 - outbin_dice_coef: 0.4086Epoch 00000: val_loss improved from inf to -0.16259, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.0656 - outmap_loss: -0.0735 - outbin_loss: 0.7900 - outmap_dice_coef: 0.0735 - outbin_dice_coef: 0.4073 - val_loss: -0.1626 - val_outmap_loss: -0.1691 - val_outbin_loss: 0.6521 - val_outmap_dice_coef: 0.1691 - val_outbin_dice_coef: 0.3755
# Epoch 2/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.2346 - outmap_loss: -0.2415 - outbin_loss: 0.6816 - outmap_dice_coef: 0.2415 - outbin_dice_coef: 0.4492Epoch 00001: val_loss improved from -0.16259 to -0.33769, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.2363 - outmap_loss: -0.2431 - outbin_loss: 0.6806 - outmap_dice_coef: 0.2431 - outbin_dice_coef: 0.4491 - val_loss: -0.3377 - val_outmap_loss: -0.3440 - val_outbin_loss: 0.6268 - val_outmap_dice_coef: 0.3440 - val_outbin_dice_coef: 0.4175
# Epoch 3/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.3807 - outmap_loss: -0.3868 - outbin_loss: 0.6113 - outmap_dice_coef: 0.3868 - outbin_dice_coef: 0.4658Epoch 00002: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.3826 - outmap_loss: -0.3887 - outbin_loss: 0.6103 - outmap_dice_coef: 0.3887 - outbin_dice_coef: 0.4667 - val_loss: -0.1178 - val_outmap_loss: -0.1240 - val_outbin_loss: 0.6188 - val_outmap_dice_coef: 0.1240 - val_outbin_dice_coef: 0.4716
# Epoch 4/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.4446 - outmap_loss: -0.4502 - outbin_loss: 0.5657 - outmap_dice_coef: 0.4502 - outbin_dice_coef: 0.5111Epoch 00003: val_loss improved from -0.33769 to -0.42284, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.4431 - outmap_loss: -0.4488 - outbin_loss: 0.5640 - outmap_dice_coef: 0.4488 - outbin_dice_coef: 0.5101 - val_loss: -0.4228 - val_outmap_loss: -0.4281 - val_outbin_loss: 0.5265 - val_outmap_dice_coef: 0.4281 - val_outbin_dice_coef: 0.4756
# Epoch 5/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.5119 - outmap_loss: -0.5170 - outbin_loss: 0.5080 - outmap_dice_coef: 0.5170 - outbin_dice_coef: 0.5582Epoch 00004: val_loss improved from -0.42284 to -0.50544, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.5125 - outmap_loss: -0.5176 - outbin_loss: 0.5066 - outmap_dice_coef: 0.5176 - outbin_dice_coef: 0.5595 - val_loss: -0.5054 - val_outmap_loss: -0.5103 - val_outbin_loss: 0.4830 - val_outmap_dice_coef: 0.5103 - val_outbin_dice_coef: 0.5449
# Epoch 6/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.5478 - outmap_loss: -0.5528 - outbin_loss: 0.4942 - outmap_dice_coef: 0.5528 - outbin_dice_coef: 0.5768Epoch 00005: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.5466 - outmap_loss: -0.5515 - outbin_loss: 0.4973 - outmap_dice_coef: 0.5515 - outbin_dice_coef: 0.5782 - val_loss: -0.4690 - val_outmap_loss: -0.4745 - val_outbin_loss: 0.5478 - val_outmap_dice_coef: 0.4745 - val_outbin_dice_coef: 0.5990
# Epoch 7/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.5573 - outmap_loss: -0.5623 - outbin_loss: 0.4961 - outmap_dice_coef: 0.5623 - outbin_dice_coef: 0.5867Epoch 00006: val_loss improved from -0.50544 to -0.52431, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.5587 - outmap_loss: -0.5637 - outbin_loss: 0.4969 - outmap_dice_coef: 0.5637 - outbin_dice_coef: 0.5877 - val_loss: -0.5243 - val_outmap_loss: -0.5287 - val_outbin_loss: 0.4429 - val_outmap_dice_coef: 0.5287 - val_outbin_dice_coef: 0.5881
# Epoch 8/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.5748 - outmap_loss: -0.5796 - outbin_loss: 0.4860 - outmap_dice_coef: 0.5796 - outbin_dice_coef: 0.5939Epoch 00007: val_loss improved from -0.52431 to -0.56872, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.5738 - outmap_loss: -0.5786 - outbin_loss: 0.4871 - outmap_dice_coef: 0.5786 - outbin_dice_coef: 0.5939 - val_loss: -0.5687 - val_outmap_loss: -0.5733 - val_outbin_loss: 0.4534 - val_outmap_dice_coef: 0.5733 - val_outbin_dice_coef: 0.6037
# Epoch 9/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.5969 - outmap_loss: -0.6012 - outbin_loss: 0.4249 - outmap_dice_coef: 0.6012 - outbin_dice_coef: 0.6510Epoch 00008: val_loss improved from -0.56872 to -0.57384, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.5982 - outmap_loss: -0.6025 - outbin_loss: 0.4273 - outmap_dice_coef: 0.6025 - outbin_dice_coef: 0.6519 - val_loss: -0.5738 - val_outmap_loss: -0.5787 - val_outbin_loss: 0.4830 - val_outmap_dice_coef: 0.5787 - val_outbin_dice_coef: 0.6514
# Epoch 10/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6051 - outmap_loss: -0.6094 - outbin_loss: 0.4355 - outmap_dice_coef: 0.6094 - outbin_dice_coef: 0.6490Epoch 00009: val_loss improved from -0.57384 to -0.59428, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.6054 - outmap_loss: -0.6098 - outbin_loss: 0.4345 - outmap_dice_coef: 0.6098 - outbin_dice_coef: 0.6493 - val_loss: -0.5943 - val_outmap_loss: -0.5983 - val_outbin_loss: 0.4047 - val_outmap_dice_coef: 0.5983 - val_outbin_dice_coef: 0.6337
# Epoch 11/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6147 - outmap_loss: -0.6188 - outbin_loss: 0.4073 - outmap_dice_coef: 0.6188 - outbin_dice_coef: 0.6720Epoch 00010: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6121 - outmap_loss: -0.6161 - outbin_loss: 0.4078 - outmap_dice_coef: 0.6161 - outbin_dice_coef: 0.6692 - val_loss: -0.5873 - val_outmap_loss: -0.5914 - val_outbin_loss: 0.4094 - val_outmap_dice_coef: 0.5914 - val_outbin_dice_coef: 0.6221
# Epoch 12/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.5967 - outmap_loss: -0.6010 - outbin_loss: 0.4344 - outmap_dice_coef: 0.6010 - outbin_dice_coef: 0.6669Epoch 00011: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.5975 - outmap_loss: -0.6019 - outbin_loss: 0.4352 - outmap_dice_coef: 0.6019 - outbin_dice_coef: 0.6672 - val_loss: -0.5749 - val_outmap_loss: -0.5795 - val_outbin_loss: 0.4584 - val_outmap_dice_coef: 0.5795 - val_outbin_dice_coef: 0.5965
# Epoch 13/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6188 - outmap_loss: -0.6229 - outbin_loss: 0.4098 - outmap_dice_coef: 0.6229 - outbin_dice_coef: 0.6654Epoch 00012: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6197 - outmap_loss: -0.6238 - outbin_loss: 0.4095 - outmap_dice_coef: 0.6238 - outbin_dice_coef: 0.6658 - val_loss: -0.5076 - val_outmap_loss: -0.5120 - val_outbin_loss: 0.4423 - val_outmap_dice_coef: 0.5120 - val_outbin_dice_coef: 0.5944
# Epoch 14/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6173 - outmap_loss: -0.6212 - outbin_loss: 0.3926 - outmap_dice_coef: 0.6212 - outbin_dice_coef: 0.6787Epoch 00013: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6179 - outmap_loss: -0.6218 - outbin_loss: 0.3932 - outmap_dice_coef: 0.6218 - outbin_dice_coef: 0.6789 - val_loss: -0.5922 - val_outmap_loss: -0.5960 - val_outbin_loss: 0.3827 - val_outmap_dice_coef: 0.5960 - val_outbin_dice_coef: 0.6650
# Epoch 15/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6206 - outmap_loss: -0.6245 - outbin_loss: 0.3908 - outmap_dice_coef: 0.6245 - outbin_dice_coef: 0.6829Epoch 00014: val_loss improved from -0.59428 to -0.61055, saving model to weights.hdf5
# 2929/2929 [==============================] - 35s - loss: -0.6203 - outmap_loss: -0.6242 - outbin_loss: 0.3904 - outmap_dice_coef: 0.6242 - outbin_dice_coef: 0.6826 - val_loss: -0.6105 - val_outmap_loss: -0.6144 - val_outbin_loss: 0.3847 - val_outmap_dice_coef: 0.6144 - val_outbin_dice_coef: 0.6755
# Epoch 16/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6307 - outmap_loss: -0.6344 - outbin_loss: 0.3664 - outmap_dice_coef: 0.6344 - outbin_dice_coef: 0.7057Epoch 00015: val_loss improved from -0.61055 to -0.62192, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.6318 - outmap_loss: -0.6354 - outbin_loss: 0.3660 - outmap_dice_coef: 0.6354 - outbin_dice_coef: 0.7062 - val_loss: -0.6219 - val_outmap_loss: -0.6259 - val_outbin_loss: 0.4004 - val_outmap_dice_coef: 0.6259 - val_outbin_dice_coef: 0.6597
# Epoch 17/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6363 - outmap_loss: -0.6399 - outbin_loss: 0.3626 - outmap_dice_coef: 0.6399 - outbin_dice_coef: 0.7064Epoch 00016: val_loss did not improve
# 2929/2929 [==============================] - 35s - loss: -0.6355 - outmap_loss: -0.6392 - outbin_loss: 0.3659 - outmap_dice_coef: 0.6392 - outbin_dice_coef: 0.7054 - val_loss: -0.6084 - val_outmap_loss: -0.6120 - val_outbin_loss: 0.3618 - val_outmap_dice_coef: 0.6120 - val_outbin_dice_coef: 0.6840
# Epoch 18/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6520 - outmap_loss: -0.6555 - outbin_loss: 0.3473 - outmap_dice_coef: 0.6555 - outbin_dice_coef: 0.7255Epoch 00017: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6520 - outmap_loss: -0.6555 - outbin_loss: 0.3471 - outmap_dice_coef: 0.6555 - outbin_dice_coef: 0.7254 - val_loss: -0.6074 - val_outmap_loss: -0.6110 - val_outbin_loss: 0.3647 - val_outmap_dice_coef: 0.6110 - val_outbin_dice_coef: 0.6931
# Epoch 19/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6465 - outmap_loss: -0.6502 - outbin_loss: 0.3681 - outmap_dice_coef: 0.6502 - outbin_dice_coef: 0.7038Epoch 00018: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6471 - outmap_loss: -0.6508 - outbin_loss: 0.3661 - outmap_dice_coef: 0.6508 - outbin_dice_coef: 0.7053 - val_loss: -0.6064 - val_outmap_loss: -0.6101 - val_outbin_loss: 0.3740 - val_outmap_dice_coef: 0.6101 - val_outbin_dice_coef: 0.6910
# Epoch 20/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6447 - outmap_loss: -0.6485 - outbin_loss: 0.3875 - outmap_dice_coef: 0.6485 - outbin_dice_coef: 0.6935Epoch 00019: val_loss improved from -0.62192 to -0.64066, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.6442 - outmap_loss: -0.6481 - outbin_loss: 0.3873 - outmap_dice_coef: 0.6481 - outbin_dice_coef: 0.6926 - val_loss: -0.6407 - val_outmap_loss: -0.6445 - val_outbin_loss: 0.3795 - val_outmap_dice_coef: 0.6445 - val_outbin_dice_coef: 0.6927
# Epoch 21/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6575 - outmap_loss: -0.6612 - outbin_loss: 0.3682 - outmap_dice_coef: 0.6612 - outbin_dice_coef: 0.7131Epoch 00020: val_loss improved from -0.64066 to -0.64314, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.6575 - outmap_loss: -0.6612 - outbin_loss: 0.3667 - outmap_dice_coef: 0.6612 - outbin_dice_coef: 0.7131 - val_loss: -0.6431 - val_outmap_loss: -0.6469 - val_outbin_loss: 0.3780 - val_outmap_dice_coef: 0.6469 - val_outbin_dice_coef: 0.6666
# Epoch 22/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6600 - outmap_loss: -0.6634 - outbin_loss: 0.3459 - outmap_dice_coef: 0.6634 - outbin_dice_coef: 0.7209Epoch 00021: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6590 - outmap_loss: -0.6625 - outbin_loss: 0.3452 - outmap_dice_coef: 0.6625 - outbin_dice_coef: 0.7190 - val_loss: -0.6079 - val_outmap_loss: -0.6117 - val_outbin_loss: 0.3812 - val_outmap_dice_coef: 0.6117 - val_outbin_dice_coef: 0.6863
# Epoch 23/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6519 - outmap_loss: -0.6554 - outbin_loss: 0.3504 - outmap_dice_coef: 0.6554 - outbin_dice_coef: 0.7198Epoch 00022: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6519 - outmap_loss: -0.6554 - outbin_loss: 0.3495 - outmap_dice_coef: 0.6554 - outbin_dice_coef: 0.7202 - val_loss: -0.6402 - val_outmap_loss: -0.6438 - val_outbin_loss: 0.3635 - val_outmap_dice_coef: 0.6438 - val_outbin_dice_coef: 0.7042
# Epoch 24/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6613 - outmap_loss: -0.6647 - outbin_loss: 0.3465 - outmap_dice_coef: 0.6647 - outbin_dice_coef: 0.7280Epoch 00023: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6612 - outmap_loss: -0.6647 - outbin_loss: 0.3460 - outmap_dice_coef: 0.6647 - outbin_dice_coef: 0.7288 - val_loss: -0.6381 - val_outmap_loss: -0.6418 - val_outbin_loss: 0.3676 - val_outmap_dice_coef: 0.6418 - val_outbin_dice_coef: 0.7147
# Epoch 25/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6603 - outmap_loss: -0.6638 - outbin_loss: 0.3504 - outmap_dice_coef: 0.6638 - outbin_dice_coef: 0.7184Epoch 00024: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6601 - outmap_loss: -0.6636 - outbin_loss: 0.3493 - outmap_dice_coef: 0.6636 - outbin_dice_coef: 0.7194 - val_loss: -0.6189 - val_outmap_loss: -0.6225 - val_outbin_loss: 0.3632 - val_outmap_dice_coef: 0.6225 - val_outbin_dice_coef: 0.7098
# Epoch 26/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6661 - outmap_loss: -0.6694 - outbin_loss: 0.3213 - outmap_dice_coef: 0.6694 - outbin_dice_coef: 0.7393Epoch 00025: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6666 - outmap_loss: -0.6698 - outbin_loss: 0.3207 - outmap_dice_coef: 0.6698 - outbin_dice_coef: 0.7407 - val_loss: -0.6426 - val_outmap_loss: -0.6461 - val_outbin_loss: 0.3542 - val_outmap_dice_coef: 0.6461 - val_outbin_dice_coef: 0.7318
# Epoch 27/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6699 - outmap_loss: -0.6732 - outbin_loss: 0.3320 - outmap_dice_coef: 0.6732 - outbin_dice_coef: 0.7405Epoch 00026: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6703 - outmap_loss: -0.6736 - outbin_loss: 0.3333 - outmap_dice_coef: 0.6736 - outbin_dice_coef: 0.7405 - val_loss: -0.6360 - val_outmap_loss: -0.6395 - val_outbin_loss: 0.3479 - val_outmap_dice_coef: 0.6395 - val_outbin_dice_coef: 0.7102
# Epoch 28/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6597 - outmap_loss: -0.6633 - outbin_loss: 0.3590 - outmap_dice_coef: 0.6633 - outbin_dice_coef: 0.7159Epoch 00027: val_loss improved from -0.64314 to -0.65055, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.6592 - outmap_loss: -0.6628 - outbin_loss: 0.3565 - outmap_dice_coef: 0.6628 - outbin_dice_coef: 0.7171 - val_loss: -0.6506 - val_outmap_loss: -0.6541 - val_outbin_loss: 0.3499 - val_outmap_dice_coef: 0.6541 - val_outbin_dice_coef: 0.7010
# Epoch 29/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6803 - outmap_loss: -0.6834 - outbin_loss: 0.3146 - outmap_dice_coef: 0.6834 - outbin_dice_coef: 0.7500Epoch 00028: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6805 - outmap_loss: -0.6836 - outbin_loss: 0.3138 - outmap_dice_coef: 0.6836 - outbin_dice_coef: 0.7509 - val_loss: -0.6484 - val_outmap_loss: -0.6519 - val_outbin_loss: 0.3514 - val_outmap_dice_coef: 0.6519 - val_outbin_dice_coef: 0.7306
# Epoch 30/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6627 - outmap_loss: -0.6660 - outbin_loss: 0.3349 - outmap_dice_coef: 0.6660 - outbin_dice_coef: 0.7406Epoch 00029: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6619 - outmap_loss: -0.6653 - outbin_loss: 0.3356 - outmap_dice_coef: 0.6653 - outbin_dice_coef: 0.7417 - val_loss: -0.6209 - val_outmap_loss: -0.6247 - val_outbin_loss: 0.3740 - val_outmap_dice_coef: 0.6247 - val_outbin_dice_coef: 0.7205
# Epoch 31/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6719 - outmap_loss: -0.6752 - outbin_loss: 0.3287 - outmap_dice_coef: 0.6752 - outbin_dice_coef: 0.7317Epoch 00030: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6719 - outmap_loss: -0.6752 - outbin_loss: 0.3298 - outmap_dice_coef: 0.6752 - outbin_dice_coef: 0.7315 - val_loss: -0.6320 - val_outmap_loss: -0.6355 - val_outbin_loss: 0.3503 - val_outmap_dice_coef: 0.6355 - val_outbin_dice_coef: 0.7264
# Epoch 32/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6793 - outmap_loss: -0.6826 - outbin_loss: 0.3310 - outmap_dice_coef: 0.6826 - outbin_dice_coef: 0.7420Epoch 00031: val_loss improved from -0.65055 to -0.65123, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.6792 - outmap_loss: -0.6826 - outbin_loss: 0.3316 - outmap_dice_coef: 0.6826 - outbin_dice_coef: 0.7416 - val_loss: -0.6512 - val_outmap_loss: -0.6546 - val_outbin_loss: 0.3417 - val_outmap_dice_coef: 0.6546 - val_outbin_dice_coef: 0.7203
# Epoch 33/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6711 - outmap_loss: -0.6743 - outbin_loss: 0.3175 - outmap_dice_coef: 0.6743 - outbin_dice_coef: 0.7496Epoch 00032: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6713 - outmap_loss: -0.6745 - outbin_loss: 0.3185 - outmap_dice_coef: 0.6745 - outbin_dice_coef: 0.7493 - val_loss: -0.6499 - val_outmap_loss: -0.6533 - val_outbin_loss: 0.3461 - val_outmap_dice_coef: 0.6533 - val_outbin_dice_coef: 0.7302
# Epoch 34/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6798 - outmap_loss: -0.6829 - outbin_loss: 0.3076 - outmap_dice_coef: 0.6829 - outbin_dice_coef: 0.7547Epoch 00033: val_loss improved from -0.65123 to -0.65378, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.6795 - outmap_loss: -0.6826 - outbin_loss: 0.3078 - outmap_dice_coef: 0.6826 - outbin_dice_coef: 0.7530 - val_loss: -0.6538 - val_outmap_loss: -0.6572 - val_outbin_loss: 0.3435 - val_outmap_dice_coef: 0.6572 - val_outbin_dice_coef: 0.7455
# Epoch 35/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6807 - outmap_loss: -0.6838 - outbin_loss: 0.3070 - outmap_dice_coef: 0.6838 - outbin_dice_coef: 0.7546Epoch 00034: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6815 - outmap_loss: -0.6845 - outbin_loss: 0.3071 - outmap_dice_coef: 0.6845 - outbin_dice_coef: 0.7547 - val_loss: -0.6375 - val_outmap_loss: -0.6413 - val_outbin_loss: 0.3786 - val_outmap_dice_coef: 0.6413 - val_outbin_dice_coef: 0.7085
# Epoch 36/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6774 - outmap_loss: -0.6805 - outbin_loss: 0.3100 - outmap_dice_coef: 0.6805 - outbin_dice_coef: 0.7613Epoch 00035: val_loss improved from -0.65378 to -0.65695, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.6787 - outmap_loss: -0.6818 - outbin_loss: 0.3077 - outmap_dice_coef: 0.6818 - outbin_dice_coef: 0.7625 - val_loss: -0.6570 - val_outmap_loss: -0.6604 - val_outbin_loss: 0.3446 - val_outmap_dice_coef: 0.6604 - val_outbin_dice_coef: 0.7281
# Epoch 37/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6775 - outmap_loss: -0.6806 - outbin_loss: 0.3080 - outmap_dice_coef: 0.6806 - outbin_dice_coef: 0.7566Epoch 00036: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6783 - outmap_loss: -0.6815 - outbin_loss: 0.3109 - outmap_dice_coef: 0.6815 - outbin_dice_coef: 0.7547 - val_loss: -0.6441 - val_outmap_loss: -0.6479 - val_outbin_loss: 0.3731 - val_outmap_dice_coef: 0.6479 - val_outbin_dice_coef: 0.6955
# Epoch 38/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6842 - outmap_loss: -0.6874 - outbin_loss: 0.3173 - outmap_dice_coef: 0.6874 - outbin_dice_coef: 0.7553Epoch 00037: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6845 - outmap_loss: -0.6877 - outbin_loss: 0.3166 - outmap_dice_coef: 0.6877 - outbin_dice_coef: 0.7549 - val_loss: -0.6400 - val_outmap_loss: -0.6435 - val_outbin_loss: 0.3534 - val_outmap_dice_coef: 0.6435 - val_outbin_dice_coef: 0.6961
# Epoch 39/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6888 - outmap_loss: -0.6919 - outbin_loss: 0.3113 - outmap_dice_coef: 0.6919 - outbin_dice_coef: 0.7546Epoch 00038: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6890 - outmap_loss: -0.6921 - outbin_loss: 0.3124 - outmap_dice_coef: 0.6921 - outbin_dice_coef: 0.7540 - val_loss: -0.6517 - val_outmap_loss: -0.6550 - val_outbin_loss: 0.3366 - val_outmap_dice_coef: 0.6550 - val_outbin_dice_coef: 0.7375
# Epoch 40/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6917 - outmap_loss: -0.6947 - outbin_loss: 0.3015 - outmap_dice_coef: 0.6947 - outbin_dice_coef: 0.7581Epoch 00039: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6916 - outmap_loss: -0.6946 - outbin_loss: 0.3022 - outmap_dice_coef: 0.6946 - outbin_dice_coef: 0.7572 - val_loss: -0.6527 - val_outmap_loss: -0.6561 - val_outbin_loss: 0.3403 - val_outmap_dice_coef: 0.6561 - val_outbin_dice_coef: 0.7376
# Epoch 41/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6876 - outmap_loss: -0.6907 - outbin_loss: 0.3088 - outmap_dice_coef: 0.6907 - outbin_dice_coef: 0.7650Epoch 00040: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6885 - outmap_loss: -0.6916 - outbin_loss: 0.3075 - outmap_dice_coef: 0.6916 - outbin_dice_coef: 0.7654 - val_loss: -0.6558 - val_outmap_loss: -0.6591 - val_outbin_loss: 0.3215 - val_outmap_dice_coef: 0.6591 - val_outbin_dice_coef: 0.7368
# Epoch 42/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6704 - outmap_loss: -0.6738 - outbin_loss: 0.3397 - outmap_dice_coef: 0.6738 - outbin_dice_coef: 0.7346Epoch 00041: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6718 - outmap_loss: -0.6752 - outbin_loss: 0.3384 - outmap_dice_coef: 0.6752 - outbin_dice_coef: 0.7352 - val_loss: -0.6485 - val_outmap_loss: -0.6521 - val_outbin_loss: 0.3635 - val_outmap_dice_coef: 0.6521 - val_outbin_dice_coef: 0.7135
# Epoch 43/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6919 - outmap_loss: -0.6949 - outbin_loss: 0.3077 - outmap_dice_coef: 0.6949 - outbin_dice_coef: 0.7520Epoch 00042: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6911 - outmap_loss: -0.6942 - outbin_loss: 0.3079 - outmap_dice_coef: 0.6942 - outbin_dice_coef: 0.7516 - val_loss: -0.6441 - val_outmap_loss: -0.6478 - val_outbin_loss: 0.3608 - val_outmap_dice_coef: 0.6478 - val_outbin_dice_coef: 0.7129
# Epoch 44/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6930 - outmap_loss: -0.6959 - outbin_loss: 0.2898 - outmap_dice_coef: 0.6959 - outbin_dice_coef: 0.7695Epoch 00043: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6938 - outmap_loss: -0.6967 - outbin_loss: 0.2914 - outmap_dice_coef: 0.6967 - outbin_dice_coef: 0.7690 - val_loss: -0.6551 - val_outmap_loss: -0.6584 - val_outbin_loss: 0.3338 - val_outmap_dice_coef: 0.6584 - val_outbin_dice_coef: 0.7527
# Epoch 45/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6941 - outmap_loss: -0.6970 - outbin_loss: 0.2911 - outmap_dice_coef: 0.6970 - outbin_dice_coef: 0.7690Epoch 00044: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6934 - outmap_loss: -0.6964 - outbin_loss: 0.2940 - outmap_dice_coef: 0.6964 - outbin_dice_coef: 0.7683 - val_loss: -0.6159 - val_outmap_loss: -0.6195 - val_outbin_loss: 0.3667 - val_outmap_dice_coef: 0.6195 - val_outbin_dice_coef: 0.7402
# Epoch 46/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6984 - outmap_loss: -0.7014 - outbin_loss: 0.2987 - outmap_dice_coef: 0.7014 - outbin_dice_coef: 0.7650Epoch 00045: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6984 - outmap_loss: -0.7014 - outbin_loss: 0.2984 - outmap_dice_coef: 0.7014 - outbin_dice_coef: 0.7642 - val_loss: -0.6527 - val_outmap_loss: -0.6561 - val_outbin_loss: 0.3391 - val_outmap_dice_coef: 0.6561 - val_outbin_dice_coef: 0.7346
# Epoch 47/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6930 - outmap_loss: -0.6959 - outbin_loss: 0.2993 - outmap_dice_coef: 0.6959 - outbin_dice_coef: 0.7658Epoch 00046: val_loss improved from -0.65695 to -0.66837, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.6933 - outmap_loss: -0.6963 - outbin_loss: 0.3012 - outmap_dice_coef: 0.6963 - outbin_dice_coef: 0.7652 - val_loss: -0.6684 - val_outmap_loss: -0.6718 - val_outbin_loss: 0.3404 - val_outmap_dice_coef: 0.6718 - val_outbin_dice_coef: 0.7283
# Epoch 48/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.7016 - outmap_loss: -0.7044 - outbin_loss: 0.2864 - outmap_dice_coef: 0.7044 - outbin_dice_coef: 0.7789Epoch 00047: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.7016 - outmap_loss: -0.7045 - outbin_loss: 0.2861 - outmap_dice_coef: 0.7045 - outbin_dice_coef: 0.7791 - val_loss: -0.6588 - val_outmap_loss: -0.6622 - val_outbin_loss: 0.3376 - val_outmap_dice_coef: 0.6622 - val_outbin_dice_coef: 0.7399
# Epoch 49/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6908 - outmap_loss: -0.6938 - outbin_loss: 0.3003 - outmap_dice_coef: 0.6938 - outbin_dice_coef: 0.7601Epoch 00048: val_loss improved from -0.66837 to -0.66871, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.6912 - outmap_loss: -0.6942 - outbin_loss: 0.3004 - outmap_dice_coef: 0.6942 - outbin_dice_coef: 0.7605 - val_loss: -0.6687 - val_outmap_loss: -0.6720 - val_outbin_loss: 0.3244 - val_outmap_dice_coef: 0.6720 - val_outbin_dice_coef: 0.7347
# Epoch 50/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.7041 - outmap_loss: -0.7071 - outbin_loss: 0.2949 - outmap_dice_coef: 0.7071 - outbin_dice_coef: 0.7712Epoch 00049: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.7036 - outmap_loss: -0.7066 - outbin_loss: 0.2944 - outmap_dice_coef: 0.7066 - outbin_dice_coef: 0.7693 - val_loss: -0.6583 - val_outmap_loss: -0.6617 - val_outbin_loss: 0.3364 - val_outmap_dice_coef: 0.6617 - val_outbin_dice_coef: 0.7154
# Epoch 51/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6846 - outmap_loss: -0.6877 - outbin_loss: 0.3119 - outmap_dice_coef: 0.6877 - outbin_dice_coef: 0.7591Epoch 00050: val_loss did not improve
# 2929/2929 [==============================] - 35s - loss: -0.6841 - outmap_loss: -0.6873 - outbin_loss: 0.3122 - outmap_dice_coef: 0.6873 - outbin_dice_coef: 0.7583 - val_loss: -0.6631 - val_outmap_loss: -0.6666 - val_outbin_loss: 0.3437 - val_outmap_dice_coef: 0.6666 - val_outbin_dice_coef: 0.7160
# Epoch 52/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.7050 - outmap_loss: -0.7078 - outbin_loss: 0.2755 - outmap_dice_coef: 0.7078 - outbin_dice_coef: 0.7750Epoch 00051: val_loss did not improve
# 2929/2929 [==============================] - 35s - loss: -0.7053 - outmap_loss: -0.7081 - outbin_loss: 0.2756 - outmap_dice_coef: 0.7081 - outbin_dice_coef: 0.7756 - val_loss: -0.6640 - val_outmap_loss: -0.6673 - val_outbin_loss: 0.3287 - val_outmap_dice_coef: 0.6673 - val_outbin_dice_coef: 0.7654
# Epoch 53/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.7031 - outmap_loss: -0.7058 - outbin_loss: 0.2730 - outmap_dice_coef: 0.7058 - outbin_dice_coef: 0.7915Epoch 00052: val_loss improved from -0.66871 to -0.67239, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.7034 - outmap_loss: -0.7061 - outbin_loss: 0.2749 - outmap_dice_coef: 0.7061 - outbin_dice_coef: 0.7904 - val_loss: -0.6724 - val_outmap_loss: -0.6759 - val_outbin_loss: 0.3466 - val_outmap_dice_coef: 0.6759 - val_outbin_dice_coef: 0.7388
# Epoch 54/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.7121 - outmap_loss: -0.7149 - outbin_loss: 0.2751 - outmap_dice_coef: 0.7149 - outbin_dice_coef: 0.7877Epoch 00053: val_loss did not improve
# 2929/2929 [==============================] - 35s - loss: -0.7121 - outmap_loss: -0.7149 - outbin_loss: 0.2753 - outmap_dice_coef: 0.7149 - outbin_dice_coef: 0.7870 - val_loss: -0.6658 - val_outmap_loss: -0.6693 - val_outbin_loss: 0.3483 - val_outmap_dice_coef: 0.6693 - val_outbin_dice_coef: 0.7527
# Epoch 55/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.7014 - outmap_loss: -0.7043 - outbin_loss: 0.2846 - outmap_dice_coef: 0.7043 - outbin_dice_coef: 0.7731Epoch 00054: val_loss did not improve
# 2929/2929 [==============================] - 35s - loss: -0.7010 - outmap_loss: -0.7038 - outbin_loss: 0.2853 - outmap_dice_coef: 0.7038 - outbin_dice_coef: 0.7730 - val_loss: -0.6205 - val_outmap_loss: -0.6240 - val_outbin_loss: 0.3500 - val_outmap_dice_coef: 0.6240 - val_outbin_dice_coef: 0.7391
# Epoch 56/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6965 - outmap_loss: -0.6995 - outbin_loss: 0.2931 - outmap_dice_coef: 0.6995 - outbin_dice_coef: 0.7721Epoch 00055: val_loss did not improve
# 2929/2929 [==============================] - 35s - loss: -0.6963 - outmap_loss: -0.6992 - outbin_loss: 0.2930 - outmap_dice_coef: 0.6992 - outbin_dice_coef: 0.7726 - val_loss: -0.6547 - val_outmap_loss: -0.6581 - val_outbin_loss: 0.3380 - val_outmap_dice_coef: 0.6581 - val_outbin_dice_coef: 0.7412
# Epoch 57/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.7092 - outmap_loss: -0.7119 - outbin_loss: 0.2697 - outmap_dice_coef: 0.7119 - outbin_dice_coef: 0.7844Epoch 00056: val_loss did not improve
# 2929/2929 [==============================] - 35s - loss: -0.7103 - outmap_loss: -0.7130 - outbin_loss: 0.2669 - outmap_dice_coef: 0.7130 - outbin_dice_coef: 0.7860 - val_loss: -0.6643 - val_outmap_loss: -0.6677 - val_outbin_loss: 0.3409 - val_outmap_dice_coef: 0.6677 - val_outbin_dice_coef: 0.7556
# Epoch 58/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.7185 - outmap_loss: -0.7213 - outbin_loss: 0.2735 - outmap_dice_coef: 0.7213 - outbin_dice_coef: 0.7874Epoch 00057: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.7182 - outmap_loss: -0.7209 - outbin_loss: 0.2714 - outmap_dice_coef: 0.7209 - outbin_dice_coef: 0.7885 - val_loss: -0.6609 - val_outmap_loss: -0.6645 - val_outbin_loss: 0.3543 - val_outmap_dice_coef: 0.6645 - val_outbin_dice_coef: 0.7637
# Epoch 59/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.7161 - outmap_loss: -0.7189 - outbin_loss: 0.2729 - outmap_dice_coef: 0.7189 - outbin_dice_coef: 0.7880Epoch 00058: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.7156 - outmap_loss: -0.7184 - outbin_loss: 0.2729 - outmap_dice_coef: 0.7184 - outbin_dice_coef: 0.7883 - val_loss: -0.6644 - val_outmap_loss: -0.6678 - val_outbin_loss: 0.3327 - val_outmap_dice_coef: 0.6678 - val_outbin_dice_coef: 0.7578
# Epoch 60/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.7097 - outmap_loss: -0.7126 - outbin_loss: 0.2877 - outmap_dice_coef: 0.7126 - outbin_dice_coef: 0.7786Epoch 00059: val_loss improved from -0.67239 to -0.67344, saving model to weights.hdf5
# 2929/2929 [==============================] - 35s - loss: -0.7108 - outmap_loss: -0.7136 - outbin_loss: 0.2870 - outmap_dice_coef: 0.7136 - outbin_dice_coef: 0.7789 - val_loss: -0.6734 - val_outmap_loss: -0.6769 - val_outbin_loss: 0.3484 - val_outmap_dice_coef: 0.6769 - val_outbin_dice_coef: 0.7611
# Epoch 61/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.7165 - outmap_loss: -0.7194 - outbin_loss: 0.2825 - outmap_dice_coef: 0.7194 - outbin_dice_coef: 0.7880Epoch 00060: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.7169 - outmap_loss: -0.7197 - outbin_loss: 0.2812 - outmap_dice_coef: 0.7197 - outbin_dice_coef: 0.7879 - val_loss: -0.6528 - val_outmap_loss: -0.6560 - val_outbin_loss: 0.3239 - val_outmap_dice_coef: 0.6560 - val_outbin_dice_coef: 0.7450
# Epoch 62/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.7143 - outmap_loss: -0.7170 - outbin_loss: 0.2710 - outmap_dice_coef: 0.7170 - outbin_dice_coef: 0.7877Epoch 00061: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.7149 - outmap_loss: -0.7176 - outbin_loss: 0.2690 - outmap_dice_coef: 0.7176 - outbin_dice_coef: 0.7891 - val_loss: -0.6659 - val_outmap_loss: -0.6692 - val_outbin_loss: 0.3261 - val_outmap_dice_coef: 0.6692 - val_outbin_dice_coef: 0.7523
# Epoch 63/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.7112 - outmap_loss: -0.7140 - outbin_loss: 0.2743 - outmap_dice_coef: 0.7140 - outbin_dice_coef: 0.7824Epoch 00062: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.7125 - outmap_loss: -0.7152 - outbin_loss: 0.2734 - outmap_dice_coef: 0.7152 - outbin_dice_coef: 0.7839 - val_loss: -0.6732 - val_outmap_loss: -0.6764 - val_outbin_loss: 0.3255 - val_outmap_dice_coef: 0.6764 - val_outbin_dice_coef: 0.7592
# Epoch 64/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.7176 - outmap_loss: -0.7203 - outbin_loss: 0.2735 - outmap_dice_coef: 0.7203 - outbin_dice_coef: 0.7871Epoch 00063: val_loss improved from -0.67344 to -0.67504, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.7178 - outmap_loss: -0.7205 - outbin_loss: 0.2724 - outmap_dice_coef: 0.7205 - outbin_dice_coef: 0.7871 - val_loss: -0.6750 - val_outmap_loss: -0.6785 - val_outbin_loss: 0.3413 - val_outmap_dice_coef: 0.6785 - val_outbin_dice_coef: 0.7706
# Epoch 65/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.7003 - outmap_loss: -0.7031 - outbin_loss: 0.2872 - outmap_dice_coef: 0.7031 - outbin_dice_coef: 0.7859Epoch 00064: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6995 - outmap_loss: -0.7024 - outbin_loss: 0.2908 - outmap_dice_coef: 0.7024 - outbin_dice_coef: 0.7835 - val_loss: -0.6581 - val_outmap_loss: -0.6614 - val_outbin_loss: 0.3233 - val_outmap_dice_coef: 0.6614 - val_outbin_dice_coef: 0.7509
# Epoch 66/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.6984 - outmap_loss: -0.7010 - outbin_loss: 0.2644 - outmap_dice_coef: 0.7010 - outbin_dice_coef: 0.7850Epoch 00065: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.6992 - outmap_loss: -0.7018 - outbin_loss: 0.2661 - outmap_dice_coef: 0.7018 - outbin_dice_coef: 0.7847 - val_loss: -0.6729 - val_outmap_loss: -0.6765 - val_outbin_loss: 0.3662 - val_outmap_dice_coef: 0.6765 - val_outbin_dice_coef: 0.7699
# Epoch 67/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.7083 - outmap_loss: -0.7110 - outbin_loss: 0.2665 - outmap_dice_coef: 0.7110 - outbin_dice_coef: 0.7933Epoch 00066: val_loss improved from -0.67504 to -0.67933, saving model to weights.hdf5
# 2929/2929 [==============================] - 35s - loss: -0.7092 - outmap_loss: -0.7118 - outbin_loss: 0.2660 - outmap_dice_coef: 0.7118 - outbin_dice_coef: 0.7934 - val_loss: -0.6793 - val_outmap_loss: -0.6828 - val_outbin_loss: 0.3502 - val_outmap_dice_coef: 0.6828 - val_outbin_dice_coef: 0.7302
# Epoch 68/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.7171 - outmap_loss: -0.7197 - outbin_loss: 0.2605 - outmap_dice_coef: 0.7197 - outbin_dice_coef: 0.7923Epoch 00067: val_loss did not improve
# 2929/2929 [==============================] - 34s - loss: -0.7172 - outmap_loss: -0.7198 - outbin_loss: 0.2612 - outmap_dice_coef: 0.7198 - outbin_dice_coef: 0.7927 - val_loss: -0.6621 - val_outmap_loss: -0.6661 - val_outbin_loss: 0.3969 - val_outmap_dice_coef: 0.6661 - val_outbin_dice_coef: 0.7610
# Epoch 69/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.7144 - outmap_loss: -0.7174 - outbin_loss: 0.2950 - outmap_dice_coef: 0.7174 - outbin_dice_coef: 0.7772Epoch 00068: val_loss did not improve
# 2929/2929 [==============================] - 35s - loss: -0.7147 - outmap_loss: -0.7176 - outbin_loss: 0.2969 - outmap_dice_coef: 0.7176 - outbin_dice_coef: 0.7757 - val_loss: -0.6771 - val_outmap_loss: -0.6809 - val_outbin_loss: 0.3714 - val_outmap_dice_coef: 0.6809 - val_outbin_dice_coef: 0.7182
# Epoch 70/70
# 2880/2929 [============================>.] - ETA: 0s - loss: -0.7231 - outmap_loss: -0.7257 - outbin_loss: 0.2609 - outmap_dice_coef: 0.7257 - outbin_dice_coef: 0.7968Epoch 00069: val_loss improved from -0.67933 to -0.67999, saving model to weights.hdf5
# 2929/2929 [==============================] - 34s - loss: -0.7224 - outmap_loss: -0.7250 - outbin_loss: 0.2624 - outmap_dice_coef: 0.7250 - outbin_dice_coef: 0.7948 - val_loss: -0.6800 - val_outmap_loss: -0.6833 - val_outbin_loss: 0.3320 - val_outmap_dice_coef: 0.6833 - val_outbin_dice_coef: 0.7370

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights.hdf5'))
# Out:
# [WARNING] ./weights.hdf5 already exists - overwrite? [y/n]y
# [TIP] Next time specify overwrite=True in save_weights!

# %%
conv1 = model.layers[1].output
_f = K.function([K.learning_phase(), input_img], [conv1])
_convout = _f([0, X_test[:1]])[0]
print _convout.shape

maxout1 = model.layers[3].output
_f = K.function([K.learning_phase(), input_img], [maxout1])
_maxout = _f([0, X_test[:1]])[0]
print _maxout.shape

pl.figure()
pl.imshow(_convout[0, 0], interpolation='nearest')
pl.colorbar()
pl.figure()
pl.imshow(_maxout[0, 0], interpolation='nearest')
pl.colorbar()
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/backend/theano_backend.py:514: UserWarning: theano.function was asked to create a function computing outputs given certain inputs, but the provided input variable at index 0 is not part of the computational graph needed to compute the outputs: keras_learning_phase.
# To make this warning into an error, you can pass the parameter on_unused_input='raise' to theano.function. To disable it completely, use on_unused_input='ignore'.
#   **kwargs)
# (1, 16, 128, 128)
# (1, 16, 128, 128)
# <matplotlib.colorbar.Colorbar instance at 0x7f5be9b86ab8>
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
def predict(X):
    Y_pred, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > 0.5
    for i in range(Y_pred.shape[0]):
        # Clear prediction where we detect to little pixels
        # Figure it out by
        # pl.hist(np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1))
        if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < 0.2:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test)
Y_full_pred, Y_full_pred_proba, Y_full_pred_binary = predict(X_full)

print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.687890962079
# full set score :  0.654316709583

# %%
_ = pl.hist(Y_pred_binary)

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[:5]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 15
img, pred_map = dream_output(Y_full[i])
pl.figure(figsize=(12, 4))
pl.subplot(131)
pl.imshow(Y_full[i].squeeze())
pl.subplot(132)
pl.imshow(img, cmap=cm.gray)
pl.subplot(133)
pl.imshow(pred_map.squeeze())

# %%
# Dream for the binary output
def dream_binoutput(output):
    
    layer_output = layer_dict['outbin'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output - layer_output[:, 0]))
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    
    step = 0.1
    for i in range(40):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    _, model_pred = model.predict(img[None,None,:,:])
    return img, model_pred

img, model_pred = dream_binoutput(1)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
img, model_pred = dream_binoutput(0)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
def dream_layer_filter(layer_name, filter_index):

    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(8):
        pl.subplot(2, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
if True:
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    test_fnames = _d['test_fnames']
    Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:])
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)

# %% [markdown]
# ## Stats on predicted masks

# %%
# on Y_full
nbp_pixels = np.sum(np.sum(np.sum(Y_full, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
