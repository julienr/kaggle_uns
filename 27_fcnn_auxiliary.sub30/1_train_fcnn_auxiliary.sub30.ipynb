# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']
X_pids = _d['pids']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
print X.dtype
print Y.dtype
# Out:
# (3906, 128, 128)
# (3906, 128, 128)
# float32
# float32

# %%
if False:
    # Split patients in train/test
    train_pids, test_pids = train_test_split(np.unique(X_pids), test_size=0.2)
    print train_pids
    print test_pids
    
    train_indices = np.flatnonzero(np.in1d(X_pids, train_pids))
    test_indices = np.flatnonzero(np.in1d(X_pids, test_pids))
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]
else:
    nsamples = X.shape[0]

    #train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.2)
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]

# %%
import skimage.transform as sktransf

def rand_float(rng):
    return rng[0] + np.random.random() * (rng[1] - rng[0])

def generate_image(X_img, Y_img, angle_range=None, zoom_range=None, shear_range=None, horiz_shift_range=None,
                   vert_shift_range=None):
    """
    Randomly shift an image by resizing and then random croping
    the resized image
    """
    if angle_range is None:
        angle_range = (-5, 5)
    if zoom_range is None:
        zoom_range = (0.8, 1.2)
    if shear_range is None:
        shear_range = (-5, 5) # shear angle in degrees
    if horiz_shift_range is None:
        horiz_shift_range = (-5, 5)
    if vert_shift_range is None:
        vert_shift_range = (-5, 5)
    inshape = X_img.shape
    
    X2 = X_img.copy()
    Y2 = Y_img.copy()
    
    # -- random rotation
    angle = np.deg2rad(rand_float(angle_range))
    zoom = rand_float(zoom_range)
    shear = np.deg2rad(rand_float(shear_range))
    horiz_shift = rand_float(horiz_shift_range)
    vert_shift = rand_float(vert_shift_range)
    
    tform = sktransf.AffineTransform(
        scale=(zoom, zoom),
        rotation=angle,
        shear=shear,
        translation=(horiz_shift, vert_shift)
    )
    X2 = sktransf.warp(X2, tform, order=5, mode='edge')
    Y2 = sktransf.warp(Y2, tform, order=1)

    # gaussian noise
    #noise_scale = rand_float((0, 0.1))
    #X2 += np.random.normal(scale=noise_scale, size=X2.shape)
    Y2 = Y2 > 0.5
    return X2[None,:,:].astype(np.float32), Y2[None,:,:].astype(np.float32)

X_train_augmented = []
Y_train_augmented = []
for i in range(X_train.shape[0]):
    if i % 10 == 0:
        print '\r%d / %d' % (i, X_train.shape[0]),
        sys.stdout.flush()
    X_train_augmented.append(X_train[i])
    Y_train_augmented.append(Y_train[i])
    for j in range(2):
        X2, Y2 = generate_image(X_train[i].squeeze(), Y_train[i].squeeze())
        X_train_augmented.append(X2)
        Y_train_augmented.append(Y2)
# Out:
# 3120 / 3124

# %%
X_train = np.array(X_train_augmented, dtype=np.float32)
Y_train = np.array(Y_train_augmented, dtype=np.float32)

Y_train_binary = np.sum(np.sum(Y_train.squeeze(), axis=2), axis=1) > 0
Y_train_binary = Y_train_binary.astype(np.float32)
Y_train_binary = Y_train_binary[:,None]

# %%
print X_train.shape
print Y_train.shape
print X_test.shape
print X_train.min(), X_train.max()
# Out:
# (9372, 1, 128, 128)
# (9372, 1, 128, 128)
# (782, 1, 128, 128)
# 0.0 1.0

# %%
import cv2
def _resize(Y, outshape):
    return cv2.resize(Y.squeeze(), outshape, interpolation=cv2.INTER_AREA)[None, :, :]
Y_train_88 = np.array([_resize(img, (8, 8)) for img in Y_train])
Y_test_88 = np.array([_resize(img, (8, 8)) for img in Y_test])
Y_train_44 = np.array([_resize(img, (4, 4)) for img in Y_train])
Y_test_44 = np.array([_resize(img, (4, 4)) for img in Y_test])

# %%
with_bp = np.flatnonzero(np.sum(np.sum(np.sum(Y_train, axis=1), axis=1), axis=1))

# %%
for bpi in range(11, 14):
    i = with_bp[bpi]
    pl.figure(figsize=(16, 4))
    pl.subplot(141)
    pl.imshow(X_train[i].squeeze())
    pl.subplot(142)
    pl.imshow(Y_train[i].squeeze())
    pl.subplot(143)
    pl.imshow(Y_train_88[i].squeeze(), interpolation='nearest')
    pl.colorbar()
    pl.subplot(144)
    pl.imshow(Y_train_44[i].squeeze(), interpolation='nearest')
    pl.colorbar()

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float32'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense
from keras.layers import LeakyReLU, BatchNormalization
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
import keras.backend as K

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
from keras.layers import Layer, InputSpec
import keras.initializations
import keras.backend as K

class Maxout2D(Layer):
    def __init__(self, output_dim, cardinality, init='glorot_uniform', **kwargs):
        super(Maxout2D, self).__init__(**kwargs)
        # the k of the maxout paper
        self.cardinality = cardinality
        # the m of the maxout paper
        self.output_dim = output_dim
        self.init = keras.initializations.get(init)
    
    def build(self, input_shape):
        self.input_dim = input_shape[1]
        self.input_spec = [InputSpec(dtype=K.floatx(),
                                     shape=(None, input_shape[1], input_shape[2], input_shape[3]))]
        self.W = self.init((self.input_dim, self.output_dim, self.cardinality),
                           name='{}_W'.format(self.name))
        self.b = K.zeros((self.output_dim, self.cardinality))
        self.trainable_weights = [self.W, self.b]
              
    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        # flatten the spatial dimensions
        flat_x = K.reshape(x, (-1, input_shape[1], input_shape[2] * input_shape[3]))
        output = K.dot(
            K.permute_dimensions(flat_x, (0, 2, 1)),
            K.permute_dimensions(self.W, (1, 0, 2))
        )
        output += K.reshape(self.b, (1, 1, self.output_dim, self.cardinality))
        output = K.max(output, axis=3)
        output = output.transpose(0, 2, 1)
        output = K.reshape(output, (-1, self.output_dim, input_shape[2], input_shape[3]))
        return output
    
    def get_output_shape_for(self, input_shape):
        return (input_shape[0], self.output_dim, input_shape[2], input_shape[3])
    
    def get_config(self):
        config = {
            'output_dim': self.output_dim,
            'cardinality': self.cardinality
        }
        base_config = super(Maxout2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
# https://www.kaggle.com/c/ultrasound-nerve-segmentation/forums/t/21358/0-57-deep-learning-keras-tutorial
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def dice_coef_batchwise(y_true, y_pred):
    y_true_f = K.batch_flatten(y_true)
    y_pred_f = K.batch_flatten(y_pred)
    intersection = 2. * K.sum(y_true_f * y_pred_f, axis=1, keepdims=True) + smooth
    union = K.sum(y_true_f, axis=1, keepdims=True) + \
            K.sum(y_pred_f, axis=1, keepdims=True) + \
            smooth
    return K.mean(intersection / union)

def dice_coef_loss_batchwise(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %% [markdown]
# http://torch.ch/blog/2015/07/30/cifar.html

# %%
input_img = x = Input(shape=input_shape, name='input_img')
x = Dropout(0.25)(x)
x = Convolution2D(16, 3, 3, border_mode='same')(input_img)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool1 = x = MaxPooling2D((2, 2), name='pool1')(x)

x = Dropout(0.25)(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool2 = x = MaxPooling2D((2, 2), name='pool2')(x)

x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool3 = x = MaxPooling2D((2, 2), name='pool3')(x)

# -- binary presence part
x = Dropout(0.25)(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

x = Dropout(0.25)(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(pool5)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# turn pool4 and 5 into classification map
outmap4 = Convolution2D(1, 3, 3, border_mode='same', activation='sigmoid', name='outmap4')(pool4)

outmap5 = Convolution2D(1, 3, 3, border_mode='same', activation='sigmoid', name='outmap5')(pool5)

# upsample the classif map
x = merge([
        UpSampling2D((2, 2))(outmap4),
        UpSampling2D((4, 4))(outmap5),
        pool3
    ], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(pool3)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(1, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
x = UpSampling2D((2, 2))(x)

x = Dropout(0.25)(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outmap4, outmap5, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
metrics={'outbin': 'accuracy'}
model.compile(optimizer='adam', loss='binary_crossentropy',
              loss_weights=[1., 0.2, 0.05, 0.01], metrics=metrics)

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_2 (InputLayer)               (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_19 (Convolution2D)   (None, 16, 128, 128)160         input_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_20 (Convolution2D)   (None, 16, 128, 128)2320        convolution2d_19[0][0]
# ____________________________________________________________________________________________________
# maxout2d_9 (Maxout2D)              (None, 16, 128, 128)544         convolution2d_20[0][0]
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)               (None, 16, 64, 64)  0           maxout2d_9[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)                (None, 16, 64, 64)  0           pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_21 (Convolution2D)   (None, 16, 64, 64)  2320        dropout_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_22 (Convolution2D)   (None, 16, 64, 64)  2320        convolution2d_21[0][0]
# ____________________________________________________________________________________________________
# maxout2d_10 (Maxout2D)             (None, 16, 64, 64)  544         convolution2d_22[0][0]
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)               (None, 16, 32, 32)  0           maxout2d_10[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)                (None, 16, 32, 32)  0           pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_23 (Convolution2D)   (None, 32, 32, 32)  4640        dropout_9[0][0]
# ____________________________________________________________________________________________________
# convolution2d_24 (Convolution2D)   (None, 32, 32, 32)  9248        convolution2d_23[0][0]
# ____________________________________________________________________________________________________
# maxout2d_11 (Maxout2D)             (None, 16, 32, 32)  1056        convolution2d_24[0][0]
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)               (None, 16, 16, 16)  0           maxout2d_11[0][0]
# ____________________________________________________________________________________________________
# convolution2d_29 (Convolution2D)   (None, 16, 16, 16)  2320        pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_30 (Convolution2D)   (None, 16, 16, 16)  2320        convolution2d_29[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)               (None, 16, 16, 16)  0           pool3[0][0]
# ____________________________________________________________________________________________________
# maxout2d_14 (Maxout2D)             (None, 1, 16, 16)   34          convolution2d_30[0][0]
# ____________________________________________________________________________________________________
# convolution2d_25 (Convolution2D)   (None, 16, 16, 16)  2320        dropout_10[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_8 (UpSampling2D)      (None, 1, 32, 32)   0           maxout2d_14[0][0]
# ____________________________________________________________________________________________________
# convolution2d_26 (Convolution2D)   (None, 16, 16, 16)  2320        convolution2d_25[0][0]
# ____________________________________________________________________________________________________
# merge_5 (Merge)                    (None, 17, 32, 32)  0           upsampling2d_8[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_31 (Convolution2D)   (None, 16, 32, 32)  2464        merge_5[0][0]
# ____________________________________________________________________________________________________
# maxout2d_12 (Maxout2D)             (None, 16, 16, 16)  544         convolution2d_26[0][0]
# ____________________________________________________________________________________________________
# convolution2d_32 (Convolution2D)   (None, 16, 32, 32)  2320        convolution2d_31[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)               (None, 16, 8, 8)    0           maxout2d_12[0][0]
# ____________________________________________________________________________________________________
# dropout_11 (Dropout)               (None, 16, 8, 8)    0           pool4[0][0]
# ____________________________________________________________________________________________________
# maxout2d_15 (Maxout2D)             (None, 16, 32, 32)  544         convolution2d_32[0][0]
# ____________________________________________________________________________________________________
# convolution2d_27 (Convolution2D)   (None, 16, 8, 8)    2320        dropout_11[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_9 (UpSampling2D)      (None, 16, 64, 64)  0           maxout2d_15[0][0]
# ____________________________________________________________________________________________________
# convolution2d_28 (Convolution2D)   (None, 16, 8, 8)    2320        convolution2d_27[0][0]
# ____________________________________________________________________________________________________
# merge_6 (Merge)                    (None, 32, 64, 64)  0           upsampling2d_9[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_33 (Convolution2D)   (None, 16, 64, 64)  4624        merge_6[0][0]
# ____________________________________________________________________________________________________
# maxout2d_13 (Maxout2D)             (None, 16, 8, 8)    544         convolution2d_28[0][0]
# ____________________________________________________________________________________________________
# convolution2d_34 (Convolution2D)   (None, 16, 64, 64)  2320        convolution2d_33[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)               (None, 16, 4, 4)    0           maxout2d_13[0][0]
# ____________________________________________________________________________________________________
# flatten_2 (Flatten)                (None, 256)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# maxout2d_16 (Maxout2D)             (None, 16, 64, 64)  544         convolution2d_34[0][0]
# ____________________________________________________________________________________________________
# dense_3 (Dense)                    (None, 32)          8224        flatten_2[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_10 (UpSampling2D)     (None, 16, 128, 128)0           maxout2d_16[0][0]
# ____________________________________________________________________________________________________
# dropout_12 (Dropout)               (None, 16, 128, 128)0           upsampling2d_10[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_3 (LeakyReLU)            (None, 32)          0           dense_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_35 (Convolution2D)   (None, 8, 128, 128) 1160        dropout_12[0][0]
# ____________________________________________________________________________________________________
# dense_4 (Dense)                    (None, 16)          528         leakyrelu_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_36 (Convolution2D)   (None, 8, 128, 128) 584         convolution2d_35[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_4 (LeakyReLU)            (None, 16)          0           dense_4[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_4[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 73          convolution2d_36[0][0]
# ____________________________________________________________________________________________________
# outmap4 (Convolution2D)            (None, 1, 8, 8)     145         pool4[0][0]
# ____________________________________________________________________________________________________
# outmap5 (Convolution2D)            (None, 1, 4, 4)     145         pool5[0][0]
# ====================================================================================================
# Total params: 61886
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {
            'outmap': Y_train,
            'outmap4' : Y_train_88,
            'outmap5' : Y_train_44,
            'outbin': Y_train_binary
        },
        batch_size=64,
        validation_data=(X_test, {
                'outmap': Y_test,
                'outmap4' : Y_test_88,
                'outmap5' : Y_test_44,
                'outbin': Y_test_binary
        }),
        nb_epoch=60,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    
    pl.figure()
    pl.plot(history.history['outmap_loss'], label='train loss')
    pl.plot(history.history['val_outmap_loss'], c='g', label='val loss')
    pl.legend()

    pl.figure()
    pl.plot(history.history['outbin_acc'], label='train acc')
    pl.plot(history.history['val_outbin_acc'], c='g', label='val acc')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
                custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.01])
    
    print_summary(model.layers)
# Out:
# Train on 9372 samples, validate on 782 samples
# Epoch 1/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.1348 - outmap_loss: 0.0817 - outmap4_loss: 0.1318 - outmap5_loss: 0.3748 - outbin_loss: 0.7992 - outbin_acc: 0.5512Epoch 00000: val_loss improved from inf to 0.06594, saving model to weights.hdf5
# 9372/9372 [==============================] - 106s - loss: 0.1347 - outmap_loss: 0.0816 - outmap4_loss: 0.1316 - outmap5_loss: 0.3739 - outbin_loss: 0.7992 - outbin_acc: 0.5510 - val_loss: 0.0659 - val_outmap_loss: 0.0390 - val_outmap4_loss: 0.0790 - val_outmap5_loss: 0.0909 - val_outbin_loss: 0.6628 - val_outbin_acc: 0.6496
# Epoch 2/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0600 - outmap_loss: 0.0394 - outmap4_loss: 0.0538 - outmap5_loss: 0.0637 - outbin_loss: 0.6605 - outbin_acc: 0.6115Epoch 00001: val_loss improved from 0.06594 to 0.04907, saving model to weights.hdf5
# 9372/9372 [==============================] - 106s - loss: 0.0599 - outmap_loss: 0.0394 - outmap4_loss: 0.0537 - outmap5_loss: 0.0637 - outbin_loss: 0.6603 - outbin_acc: 0.6119 - val_loss: 0.0491 - val_outmap_loss: 0.0316 - val_outmap4_loss: 0.0461 - val_outmap5_loss: 0.0486 - val_outbin_loss: 0.5791 - val_outbin_acc: 0.6777
# Epoch 3/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0502 - outmap_loss: 0.0331 - outmap4_loss: 0.0416 - outmap5_loss: 0.0569 - outbin_loss: 0.5903 - outbin_acc: 0.6834Epoch 00002: val_loss improved from 0.04907 to 0.04439, saving model to weights.hdf5
# 9372/9372 [==============================] - 106s - loss: 0.0502 - outmap_loss: 0.0331 - outmap4_loss: 0.0416 - outmap5_loss: 0.0569 - outbin_loss: 0.5902 - outbin_acc: 0.6833 - val_loss: 0.0444 - val_outmap_loss: 0.0292 - val_outmap4_loss: 0.0400 - val_outmap5_loss: 0.0438 - val_outbin_loss: 0.4978 - val_outbin_acc: 0.7442
# Epoch 4/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0454 - outmap_loss: 0.0298 - outmap4_loss: 0.0377 - outmap5_loss: 0.0527 - outbin_loss: 0.5437 - outbin_acc: 0.7278Epoch 00003: val_loss improved from 0.04439 to 0.03922, saving model to weights.hdf5
# 9372/9372 [==============================] - 106s - loss: 0.0454 - outmap_loss: 0.0298 - outmap4_loss: 0.0377 - outmap5_loss: 0.0527 - outbin_loss: 0.5446 - outbin_acc: 0.7276 - val_loss: 0.0392 - val_outmap_loss: 0.0255 - val_outmap4_loss: 0.0339 - val_outmap5_loss: 0.0416 - val_outbin_loss: 0.4861 - val_outbin_acc: 0.7532
# Epoch 5/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0421 - outmap_loss: 0.0274 - outmap4_loss: 0.0358 - outmap5_loss: 0.0504 - outbin_loss: 0.4970 - outbin_acc: 0.7669Epoch 00004: val_loss improved from 0.03922 to 0.03778, saving model to weights.hdf5
# 9372/9372 [==============================] - 106s - loss: 0.0420 - outmap_loss: 0.0274 - outmap4_loss: 0.0358 - outmap5_loss: 0.0504 - outbin_loss: 0.4967 - outbin_acc: 0.7671 - val_loss: 0.0378 - val_outmap_loss: 0.0245 - val_outmap4_loss: 0.0358 - val_outmap5_loss: 0.0403 - val_outbin_loss: 0.4126 - val_outbin_acc: 0.8146
# Epoch 6/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0398 - outmap_loss: 0.0258 - outmap4_loss: 0.0345 - outmap5_loss: 0.0486 - outbin_loss: 0.4738 - outbin_acc: 0.7816Epoch 00005: val_loss did not improve
# 9372/9372 [==============================] - 108s - loss: 0.0398 - outmap_loss: 0.0258 - outmap4_loss: 0.0345 - outmap5_loss: 0.0486 - outbin_loss: 0.4741 - outbin_acc: 0.7814 - val_loss: 0.0379 - val_outmap_loss: 0.0247 - val_outmap4_loss: 0.0345 - val_outmap5_loss: 0.0403 - val_outbin_loss: 0.4237 - val_outbin_acc: 0.8248
# Epoch 7/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0382 - outmap_loss: 0.0246 - outmap4_loss: 0.0337 - outmap5_loss: 0.0469 - outbin_loss: 0.4537 - outbin_acc: 0.7948Epoch 00006: val_loss improved from 0.03778 to 0.03463, saving model to weights.hdf5
# 9372/9372 [==============================] - 110s - loss: 0.0382 - outmap_loss: 0.0245 - outmap4_loss: 0.0337 - outmap5_loss: 0.0469 - outbin_loss: 0.4536 - outbin_acc: 0.7949 - val_loss: 0.0346 - val_outmap_loss: 0.0222 - val_outmap4_loss: 0.0322 - val_outmap5_loss: 0.0397 - val_outbin_loss: 0.4023 - val_outbin_acc: 0.8184
# Epoch 8/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0378 - outmap_loss: 0.0243 - outmap4_loss: 0.0335 - outmap5_loss: 0.0463 - outbin_loss: 0.4489 - outbin_acc: 0.7990Epoch 00007: val_loss improved from 0.03463 to 0.03414, saving model to weights.hdf5
# 9372/9372 [==============================] - 110s - loss: 0.0378 - outmap_loss: 0.0243 - outmap4_loss: 0.0335 - outmap5_loss: 0.0463 - outbin_loss: 0.4486 - outbin_acc: 0.7993 - val_loss: 0.0341 - val_outmap_loss: 0.0219 - val_outmap4_loss: 0.0317 - val_outmap5_loss: 0.0386 - val_outbin_loss: 0.3940 - val_outbin_acc: 0.8248
# Epoch 9/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0364 - outmap_loss: 0.0233 - outmap4_loss: 0.0327 - outmap5_loss: 0.0448 - outbin_loss: 0.4317 - outbin_acc: 0.8023Epoch 00008: val_loss improved from 0.03414 to 0.03245, saving model to weights.hdf5
# 9372/9372 [==============================] - 109s - loss: 0.0364 - outmap_loss: 0.0233 - outmap4_loss: 0.0327 - outmap5_loss: 0.0447 - outbin_loss: 0.4317 - outbin_acc: 0.8023 - val_loss: 0.0324 - val_outmap_loss: 0.0206 - val_outmap4_loss: 0.0305 - val_outmap5_loss: 0.0386 - val_outbin_loss: 0.3828 - val_outbin_acc: 0.8338
# Epoch 10/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0354 - outmap_loss: 0.0226 - outmap4_loss: 0.0323 - outmap5_loss: 0.0437 - outbin_loss: 0.4143 - outbin_acc: 0.8171Epoch 00009: val_loss improved from 0.03245 to 0.03225, saving model to weights.hdf5
# 9372/9372 [==============================] - 106s - loss: 0.0354 - outmap_loss: 0.0226 - outmap4_loss: 0.0323 - outmap5_loss: 0.0437 - outbin_loss: 0.4141 - outbin_acc: 0.8172 - val_loss: 0.0322 - val_outmap_loss: 0.0207 - val_outmap4_loss: 0.0298 - val_outmap5_loss: 0.0379 - val_outbin_loss: 0.3712 - val_outbin_acc: 0.8402
# Epoch 11/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0351 - outmap_loss: 0.0224 - outmap4_loss: 0.0320 - outmap5_loss: 0.0434 - outbin_loss: 0.4106 - outbin_acc: 0.8140Epoch 00010: val_loss improved from 0.03225 to 0.03163, saving model to weights.hdf5
# 9372/9372 [==============================] - 106s - loss: 0.0351 - outmap_loss: 0.0224 - outmap4_loss: 0.0320 - outmap5_loss: 0.0434 - outbin_loss: 0.4103 - outbin_acc: 0.8142 - val_loss: 0.0316 - val_outmap_loss: 0.0203 - val_outmap4_loss: 0.0298 - val_outmap5_loss: 0.0372 - val_outbin_loss: 0.3545 - val_outbin_acc: 0.8465
# Epoch 12/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0341 - outmap_loss: 0.0217 - outmap4_loss: 0.0315 - outmap5_loss: 0.0424 - outbin_loss: 0.3918 - outbin_acc: 0.8326Epoch 00011: val_loss improved from 0.03163 to 0.03133, saving model to weights.hdf5
# 9372/9372 [==============================] - 106s - loss: 0.0341 - outmap_loss: 0.0217 - outmap4_loss: 0.0315 - outmap5_loss: 0.0424 - outbin_loss: 0.3924 - outbin_acc: 0.8324 - val_loss: 0.0313 - val_outmap_loss: 0.0202 - val_outmap4_loss: 0.0291 - val_outmap5_loss: 0.0374 - val_outbin_loss: 0.3447 - val_outbin_acc: 0.8542
# Epoch 13/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0334 - outmap_loss: 0.0213 - outmap4_loss: 0.0311 - outmap5_loss: 0.0415 - outbin_loss: 0.3772 - outbin_acc: 0.8393Epoch 00012: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0334 - outmap_loss: 0.0214 - outmap4_loss: 0.0311 - outmap5_loss: 0.0415 - outbin_loss: 0.3775 - outbin_acc: 0.8388 - val_loss: 0.0346 - val_outmap_loss: 0.0222 - val_outmap4_loss: 0.0308 - val_outmap5_loss: 0.0396 - val_outbin_loss: 0.4281 - val_outbin_acc: 0.8043
# Epoch 14/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0332 - outmap_loss: 0.0212 - outmap4_loss: 0.0311 - outmap5_loss: 0.0412 - outbin_loss: 0.3719 - outbin_acc: 0.8425Epoch 00013: val_loss improved from 0.03133 to 0.03125, saving model to weights.hdf5
# 9372/9372 [==============================] - 106s - loss: 0.0332 - outmap_loss: 0.0213 - outmap4_loss: 0.0311 - outmap5_loss: 0.0412 - outbin_loss: 0.3719 - outbin_acc: 0.8425 - val_loss: 0.0313 - val_outmap_loss: 0.0200 - val_outmap4_loss: 0.0282 - val_outmap5_loss: 0.0369 - val_outbin_loss: 0.3797 - val_outbin_acc: 0.8363
# Epoch 15/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0326 - outmap_loss: 0.0207 - outmap4_loss: 0.0307 - outmap5_loss: 0.0408 - outbin_loss: 0.3652 - outbin_acc: 0.8425Epoch 00014: val_loss improved from 0.03125 to 0.03011, saving model to weights.hdf5
# 9372/9372 [==============================] - 108s - loss: 0.0326 - outmap_loss: 0.0208 - outmap4_loss: 0.0307 - outmap5_loss: 0.0408 - outbin_loss: 0.3653 - outbin_acc: 0.8424 - val_loss: 0.0301 - val_outmap_loss: 0.0191 - val_outmap4_loss: 0.0289 - val_outmap5_loss: 0.0367 - val_outbin_loss: 0.3399 - val_outbin_acc: 0.8581
# Epoch 16/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0321 - outmap_loss: 0.0204 - outmap4_loss: 0.0303 - outmap5_loss: 0.0402 - outbin_loss: 0.3574 - outbin_acc: 0.8496Epoch 00015: val_loss improved from 0.03011 to 0.02969, saving model to weights.hdf5
# 9372/9372 [==============================] - 110s - loss: 0.0320 - outmap_loss: 0.0204 - outmap4_loss: 0.0303 - outmap5_loss: 0.0402 - outbin_loss: 0.3568 - outbin_acc: 0.8501 - val_loss: 0.0297 - val_outmap_loss: 0.0192 - val_outmap4_loss: 0.0275 - val_outmap5_loss: 0.0361 - val_outbin_loss: 0.3224 - val_outbin_acc: 0.8721
# Epoch 17/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0318 - outmap_loss: 0.0203 - outmap4_loss: 0.0301 - outmap5_loss: 0.0399 - outbin_loss: 0.3494 - outbin_acc: 0.8535Epoch 00016: val_loss did not improve
# 9372/9372 [==============================] - 110s - loss: 0.0318 - outmap_loss: 0.0203 - outmap4_loss: 0.0301 - outmap5_loss: 0.0400 - outbin_loss: 0.3496 - outbin_acc: 0.8533 - val_loss: 0.0315 - val_outmap_loss: 0.0197 - val_outmap4_loss: 0.0302 - val_outmap5_loss: 0.0392 - val_outbin_loss: 0.3718 - val_outbin_acc: 0.8504
# Epoch 18/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0318 - outmap_loss: 0.0203 - outmap4_loss: 0.0301 - outmap5_loss: 0.0398 - outbin_loss: 0.3487 - outbin_acc: 0.8480Epoch 00017: val_loss improved from 0.02969 to 0.02907, saving model to weights.hdf5
# 9372/9372 [==============================] - 110s - loss: 0.0318 - outmap_loss: 0.0203 - outmap4_loss: 0.0301 - outmap5_loss: 0.0397 - outbin_loss: 0.3488 - outbin_acc: 0.8480 - val_loss: 0.0291 - val_outmap_loss: 0.0187 - val_outmap4_loss: 0.0272 - val_outmap5_loss: 0.0358 - val_outbin_loss: 0.3189 - val_outbin_acc: 0.8708
# Epoch 19/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0311 - outmap_loss: 0.0198 - outmap4_loss: 0.0298 - outmap5_loss: 0.0394 - outbin_loss: 0.3370 - outbin_acc: 0.8580Epoch 00018: val_loss did not improve
# 9372/9372 [==============================] - 110s - loss: 0.0311 - outmap_loss: 0.0198 - outmap4_loss: 0.0298 - outmap5_loss: 0.0394 - outbin_loss: 0.3374 - outbin_acc: 0.8578 - val_loss: 0.0306 - val_outmap_loss: 0.0195 - val_outmap4_loss: 0.0283 - val_outmap5_loss: 0.0366 - val_outbin_loss: 0.3565 - val_outbin_acc: 0.8414
# Epoch 20/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0310 - outmap_loss: 0.0197 - outmap4_loss: 0.0296 - outmap5_loss: 0.0392 - outbin_loss: 0.3397 - outbin_acc: 0.8576Epoch 00019: val_loss did not improve
# 9372/9372 [==============================] - 110s - loss: 0.0309 - outmap_loss: 0.0197 - outmap4_loss: 0.0296 - outmap5_loss: 0.0391 - outbin_loss: 0.3394 - outbin_acc: 0.8577 - val_loss: 0.0293 - val_outmap_loss: 0.0189 - val_outmap4_loss: 0.0270 - val_outmap5_loss: 0.0355 - val_outbin_loss: 0.3210 - val_outbin_acc: 0.8670
# Epoch 21/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0305 - outmap_loss: 0.0194 - outmap4_loss: 0.0294 - outmap5_loss: 0.0389 - outbin_loss: 0.3289 - outbin_acc: 0.8600Epoch 00020: val_loss did not improve
# 9372/9372 [==============================] - 110s - loss: 0.0305 - outmap_loss: 0.0194 - outmap4_loss: 0.0295 - outmap5_loss: 0.0389 - outbin_loss: 0.3291 - outbin_acc: 0.8601 - val_loss: 0.0308 - val_outmap_loss: 0.0194 - val_outmap4_loss: 0.0276 - val_outmap5_loss: 0.0357 - val_outbin_loss: 0.4167 - val_outbin_acc: 0.8376
# Epoch 22/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0306 - outmap_loss: 0.0195 - outmap4_loss: 0.0295 - outmap5_loss: 0.0388 - outbin_loss: 0.3295 - outbin_acc: 0.8584Epoch 00021: val_loss did not improve
# 9372/9372 [==============================] - 110s - loss: 0.0306 - outmap_loss: 0.0195 - outmap4_loss: 0.0295 - outmap5_loss: 0.0388 - outbin_loss: 0.3294 - outbin_acc: 0.8583 - val_loss: 0.0316 - val_outmap_loss: 0.0206 - val_outmap4_loss: 0.0281 - val_outmap5_loss: 0.0368 - val_outbin_loss: 0.3481 - val_outbin_acc: 0.8645
# Epoch 23/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0301 - outmap_loss: 0.0191 - outmap4_loss: 0.0292 - outmap5_loss: 0.0383 - outbin_loss: 0.3263 - outbin_acc: 0.8626Epoch 00022: val_loss improved from 0.02907 to 0.02859, saving model to weights.hdf5
# 9372/9372 [==============================] - 110s - loss: 0.0301 - outmap_loss: 0.0191 - outmap4_loss: 0.0292 - outmap5_loss: 0.0383 - outbin_loss: 0.3261 - outbin_acc: 0.8627 - val_loss: 0.0286 - val_outmap_loss: 0.0183 - val_outmap4_loss: 0.0265 - val_outmap5_loss: 0.0354 - val_outbin_loss: 0.3196 - val_outbin_acc: 0.8696
# Epoch 24/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0297 - outmap_loss: 0.0188 - outmap4_loss: 0.0289 - outmap5_loss: 0.0379 - outbin_loss: 0.3172 - outbin_acc: 0.8683Epoch 00023: val_loss improved from 0.02859 to 0.02812, saving model to weights.hdf5
# 9372/9372 [==============================] - 110s - loss: 0.0297 - outmap_loss: 0.0188 - outmap4_loss: 0.0289 - outmap5_loss: 0.0379 - outbin_loss: 0.3173 - outbin_acc: 0.8682 - val_loss: 0.0281 - val_outmap_loss: 0.0180 - val_outmap4_loss: 0.0263 - val_outmap5_loss: 0.0344 - val_outbin_loss: 0.3094 - val_outbin_acc: 0.8747
# Epoch 25/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0300 - outmap_loss: 0.0190 - outmap4_loss: 0.0290 - outmap5_loss: 0.0382 - outbin_loss: 0.3243 - outbin_acc: 0.8602Epoch 00024: val_loss improved from 0.02812 to 0.02807, saving model to weights.hdf5
# 9372/9372 [==============================] - 110s - loss: 0.0300 - outmap_loss: 0.0190 - outmap4_loss: 0.0290 - outmap5_loss: 0.0382 - outbin_loss: 0.3246 - outbin_acc: 0.8600 - val_loss: 0.0281 - val_outmap_loss: 0.0179 - val_outmap4_loss: 0.0261 - val_outmap5_loss: 0.0339 - val_outbin_loss: 0.3202 - val_outbin_acc: 0.8645
# Epoch 26/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0292 - outmap_loss: 0.0185 - outmap4_loss: 0.0286 - outmap5_loss: 0.0376 - outbin_loss: 0.3074 - outbin_acc: 0.8726Epoch 00025: val_loss did not improve
# 9372/9372 [==============================] - 110s - loss: 0.0292 - outmap_loss: 0.0185 - outmap4_loss: 0.0286 - outmap5_loss: 0.0376 - outbin_loss: 0.3076 - outbin_acc: 0.8725 - val_loss: 0.0288 - val_outmap_loss: 0.0184 - val_outmap4_loss: 0.0266 - val_outmap5_loss: 0.0346 - val_outbin_loss: 0.3344 - val_outbin_acc: 0.8491
# Epoch 27/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0291 - outmap_loss: 0.0185 - outmap4_loss: 0.0285 - outmap5_loss: 0.0375 - outbin_loss: 0.3054 - outbin_acc: 0.8716Epoch 00026: val_loss did not improve
# 9372/9372 [==============================] - 110s - loss: 0.0291 - outmap_loss: 0.0185 - outmap4_loss: 0.0284 - outmap5_loss: 0.0375 - outbin_loss: 0.3057 - outbin_acc: 0.8717 - val_loss: 0.0304 - val_outmap_loss: 0.0194 - val_outmap4_loss: 0.0277 - val_outmap5_loss: 0.0359 - val_outbin_loss: 0.3573 - val_outbin_acc: 0.8427
# Epoch 28/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0287 - outmap_loss: 0.0181 - outmap4_loss: 0.0282 - outmap5_loss: 0.0371 - outbin_loss: 0.3055 - outbin_acc: 0.8717Epoch 00027: val_loss did not improve
# 9372/9372 [==============================] - 107s - loss: 0.0287 - outmap_loss: 0.0181 - outmap4_loss: 0.0282 - outmap5_loss: 0.0371 - outbin_loss: 0.3057 - outbin_acc: 0.8716 - val_loss: 0.0282 - val_outmap_loss: 0.0176 - val_outmap4_loss: 0.0264 - val_outmap5_loss: 0.0362 - val_outbin_loss: 0.3541 - val_outbin_acc: 0.8427
# Epoch 29/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0284 - outmap_loss: 0.0179 - outmap4_loss: 0.0281 - outmap5_loss: 0.0369 - outbin_loss: 0.2984 - outbin_acc: 0.8764Epoch 00028: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0284 - outmap_loss: 0.0179 - outmap4_loss: 0.0281 - outmap5_loss: 0.0369 - outbin_loss: 0.2981 - outbin_acc: 0.8765 - val_loss: 0.0283 - val_outmap_loss: 0.0181 - val_outmap4_loss: 0.0261 - val_outmap5_loss: 0.0345 - val_outbin_loss: 0.3332 - val_outbin_acc: 0.8517
# Epoch 30/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0285 - outmap_loss: 0.0180 - outmap4_loss: 0.0281 - outmap5_loss: 0.0369 - outbin_loss: 0.2968 - outbin_acc: 0.8757Epoch 00029: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0285 - outmap_loss: 0.0180 - outmap4_loss: 0.0281 - outmap5_loss: 0.0368 - outbin_loss: 0.2967 - outbin_acc: 0.8755 - val_loss: 0.0281 - val_outmap_loss: 0.0176 - val_outmap4_loss: 0.0260 - val_outmap5_loss: 0.0347 - val_outbin_loss: 0.3541 - val_outbin_acc: 0.8529
# Epoch 31/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0279 - outmap_loss: 0.0176 - outmap4_loss: 0.0277 - outmap5_loss: 0.0366 - outbin_loss: 0.2910 - outbin_acc: 0.8789Epoch 00030: val_loss improved from 0.02807 to 0.02748, saving model to weights.hdf5
# 9372/9372 [==============================] - 106s - loss: 0.0279 - outmap_loss: 0.0176 - outmap4_loss: 0.0277 - outmap5_loss: 0.0366 - outbin_loss: 0.2907 - outbin_acc: 0.8791 - val_loss: 0.0275 - val_outmap_loss: 0.0177 - val_outmap4_loss: 0.0256 - val_outmap5_loss: 0.0337 - val_outbin_loss: 0.2971 - val_outbin_acc: 0.8862
# Epoch 32/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0276 - outmap_loss: 0.0174 - outmap4_loss: 0.0277 - outmap5_loss: 0.0364 - outbin_loss: 0.2811 - outbin_acc: 0.8859Epoch 00031: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0276 - outmap_loss: 0.0174 - outmap4_loss: 0.0277 - outmap5_loss: 0.0364 - outbin_loss: 0.2814 - outbin_acc: 0.8859 - val_loss: 0.0288 - val_outmap_loss: 0.0184 - val_outmap4_loss: 0.0263 - val_outmap5_loss: 0.0344 - val_outbin_loss: 0.3405 - val_outbin_acc: 0.8645
# Epoch 33/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0279 - outmap_loss: 0.0177 - outmap4_loss: 0.0277 - outmap5_loss: 0.0364 - outbin_loss: 0.2881 - outbin_acc: 0.8838Epoch 00032: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0279 - outmap_loss: 0.0176 - outmap4_loss: 0.0277 - outmap5_loss: 0.0364 - outbin_loss: 0.2878 - outbin_acc: 0.8838 - val_loss: 0.0297 - val_outmap_loss: 0.0187 - val_outmap4_loss: 0.0272 - val_outmap5_loss: 0.0358 - val_outbin_loss: 0.3775 - val_outbin_acc: 0.8402
# Epoch 34/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0275 - outmap_loss: 0.0174 - outmap4_loss: 0.0276 - outmap5_loss: 0.0362 - outbin_loss: 0.2825 - outbin_acc: 0.8835Epoch 00033: val_loss did not improve
# 9372/9372 [==============================] - 110s - loss: 0.0275 - outmap_loss: 0.0174 - outmap4_loss: 0.0276 - outmap5_loss: 0.0362 - outbin_loss: 0.2827 - outbin_acc: 0.8835 - val_loss: 0.0288 - val_outmap_loss: 0.0180 - val_outmap4_loss: 0.0267 - val_outmap5_loss: 0.0344 - val_outbin_loss: 0.3768 - val_outbin_acc: 0.8350
# Epoch 35/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0272 - outmap_loss: 0.0171 - outmap4_loss: 0.0274 - outmap5_loss: 0.0359 - outbin_loss: 0.2802 - outbin_acc: 0.8828Epoch 00034: val_loss improved from 0.02748 to 0.02691, saving model to weights.hdf5
# 9372/9372 [==============================] - 110s - loss: 0.0273 - outmap_loss: 0.0172 - outmap4_loss: 0.0274 - outmap5_loss: 0.0360 - outbin_loss: 0.2805 - outbin_acc: 0.8828 - val_loss: 0.0269 - val_outmap_loss: 0.0171 - val_outmap4_loss: 0.0253 - val_outmap5_loss: 0.0335 - val_outbin_loss: 0.3085 - val_outbin_acc: 0.8811
# Epoch 36/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0272 - outmap_loss: 0.0171 - outmap4_loss: 0.0275 - outmap5_loss: 0.0360 - outbin_loss: 0.2838 - outbin_acc: 0.8792Epoch 00035: val_loss did not improve
# 9372/9372 [==============================] - 110s - loss: 0.0272 - outmap_loss: 0.0171 - outmap4_loss: 0.0275 - outmap5_loss: 0.0360 - outbin_loss: 0.2841 - outbin_acc: 0.8792 - val_loss: 0.0274 - val_outmap_loss: 0.0170 - val_outmap4_loss: 0.0258 - val_outmap5_loss: 0.0341 - val_outbin_loss: 0.3558 - val_outbin_acc: 0.8504
# Epoch 37/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0267 - outmap_loss: 0.0167 - outmap4_loss: 0.0272 - outmap5_loss: 0.0357 - outbin_loss: 0.2764 - outbin_acc: 0.8842Epoch 00036: val_loss did not improve
# 9372/9372 [==============================] - 107s - loss: 0.0267 - outmap_loss: 0.0167 - outmap4_loss: 0.0272 - outmap5_loss: 0.0357 - outbin_loss: 0.2772 - outbin_acc: 0.8838 - val_loss: 0.0281 - val_outmap_loss: 0.0181 - val_outmap4_loss: 0.0262 - val_outmap5_loss: 0.0344 - val_outbin_loss: 0.3093 - val_outbin_acc: 0.8555
# Epoch 38/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0269 - outmap_loss: 0.0169 - outmap4_loss: 0.0272 - outmap5_loss: 0.0357 - outbin_loss: 0.2746 - outbin_acc: 0.8860Epoch 00037: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0269 - outmap_loss: 0.0169 - outmap4_loss: 0.0272 - outmap5_loss: 0.0357 - outbin_loss: 0.2750 - outbin_acc: 0.8858 - val_loss: 0.0275 - val_outmap_loss: 0.0176 - val_outmap4_loss: 0.0255 - val_outmap5_loss: 0.0335 - val_outbin_loss: 0.3148 - val_outbin_acc: 0.8632
# Epoch 39/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0266 - outmap_loss: 0.0166 - outmap4_loss: 0.0271 - outmap5_loss: 0.0355 - outbin_loss: 0.2773 - outbin_acc: 0.8886Epoch 00038: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0266 - outmap_loss: 0.0166 - outmap4_loss: 0.0271 - outmap5_loss: 0.0355 - outbin_loss: 0.2772 - outbin_acc: 0.8887 - val_loss: 0.0293 - val_outmap_loss: 0.0186 - val_outmap4_loss: 0.0276 - val_outmap5_loss: 0.0345 - val_outbin_loss: 0.3464 - val_outbin_acc: 0.8555
# Epoch 40/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0263 - outmap_loss: 0.0164 - outmap4_loss: 0.0270 - outmap5_loss: 0.0353 - outbin_loss: 0.2712 - outbin_acc: 0.8887Epoch 00039: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0263 - outmap_loss: 0.0164 - outmap4_loss: 0.0270 - outmap5_loss: 0.0354 - outbin_loss: 0.2713 - outbin_acc: 0.8887 - val_loss: 0.0286 - val_outmap_loss: 0.0179 - val_outmap4_loss: 0.0265 - val_outmap5_loss: 0.0359 - val_outbin_loss: 0.3596 - val_outbin_acc: 0.8568
# Epoch 41/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0264 - outmap_loss: 0.0165 - outmap4_loss: 0.0269 - outmap5_loss: 0.0356 - outbin_loss: 0.2735 - outbin_acc: 0.8859Epoch 00040: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0264 - outmap_loss: 0.0165 - outmap4_loss: 0.0269 - outmap5_loss: 0.0356 - outbin_loss: 0.2732 - outbin_acc: 0.8860 - val_loss: 0.0282 - val_outmap_loss: 0.0180 - val_outmap4_loss: 0.0261 - val_outmap5_loss: 0.0361 - val_outbin_loss: 0.3140 - val_outbin_acc: 0.8772
# Epoch 42/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0260 - outmap_loss: 0.0162 - outmap4_loss: 0.0267 - outmap5_loss: 0.0353 - outbin_loss: 0.2648 - outbin_acc: 0.8926Epoch 00041: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0260 - outmap_loss: 0.0162 - outmap4_loss: 0.0267 - outmap5_loss: 0.0353 - outbin_loss: 0.2645 - outbin_acc: 0.8927 - val_loss: 0.0288 - val_outmap_loss: 0.0182 - val_outmap4_loss: 0.0259 - val_outmap5_loss: 0.0348 - val_outbin_loss: 0.3579 - val_outbin_acc: 0.8734
# Epoch 43/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0259 - outmap_loss: 0.0162 - outmap4_loss: 0.0267 - outmap5_loss: 0.0350 - outbin_loss: 0.2609 - outbin_acc: 0.8930Epoch 00042: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0259 - outmap_loss: 0.0162 - outmap4_loss: 0.0267 - outmap5_loss: 0.0351 - outbin_loss: 0.2606 - outbin_acc: 0.8931 - val_loss: 0.0275 - val_outmap_loss: 0.0176 - val_outmap4_loss: 0.0253 - val_outmap5_loss: 0.0335 - val_outbin_loss: 0.3121 - val_outbin_acc: 0.8824
# Epoch 44/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0257 - outmap_loss: 0.0160 - outmap4_loss: 0.0266 - outmap5_loss: 0.0350 - outbin_loss: 0.2598 - outbin_acc: 0.8942Epoch 00043: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0257 - outmap_loss: 0.0161 - outmap4_loss: 0.0266 - outmap5_loss: 0.0350 - outbin_loss: 0.2602 - outbin_acc: 0.8940 - val_loss: 0.0272 - val_outmap_loss: 0.0172 - val_outmap4_loss: 0.0258 - val_outmap5_loss: 0.0344 - val_outbin_loss: 0.3177 - val_outbin_acc: 0.8670
# Epoch 45/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0254 - outmap_loss: 0.0159 - outmap4_loss: 0.0263 - outmap5_loss: 0.0347 - outbin_loss: 0.2519 - outbin_acc: 0.8997Epoch 00044: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0254 - outmap_loss: 0.0159 - outmap4_loss: 0.0263 - outmap5_loss: 0.0347 - outbin_loss: 0.2518 - outbin_acc: 0.8999 - val_loss: 0.0301 - val_outmap_loss: 0.0187 - val_outmap4_loss: 0.0283 - val_outmap5_loss: 0.0356 - val_outbin_loss: 0.3963 - val_outbin_acc: 0.8363
# Epoch 46/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0256 - outmap_loss: 0.0160 - outmap4_loss: 0.0265 - outmap5_loss: 0.0349 - outbin_loss: 0.2604 - outbin_acc: 0.8893Epoch 00045: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0256 - outmap_loss: 0.0160 - outmap4_loss: 0.0265 - outmap5_loss: 0.0349 - outbin_loss: 0.2606 - outbin_acc: 0.8890 - val_loss: 0.0280 - val_outmap_loss: 0.0181 - val_outmap4_loss: 0.0253 - val_outmap5_loss: 0.0331 - val_outbin_loss: 0.3149 - val_outbin_acc: 0.8721
# Epoch 47/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0255 - outmap_loss: 0.0159 - outmap4_loss: 0.0263 - outmap5_loss: 0.0348 - outbin_loss: 0.2557 - outbin_acc: 0.8950Epoch 00046: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0255 - outmap_loss: 0.0160 - outmap4_loss: 0.0263 - outmap5_loss: 0.0349 - outbin_loss: 0.2556 - outbin_acc: 0.8951 - val_loss: 0.0285 - val_outmap_loss: 0.0180 - val_outmap4_loss: 0.0268 - val_outmap5_loss: 0.0351 - val_outbin_loss: 0.3396 - val_outbin_acc: 0.8491
# Epoch 48/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0250 - outmap_loss: 0.0156 - outmap4_loss: 0.0262 - outmap5_loss: 0.0345 - outbin_loss: 0.2422 - outbin_acc: 0.8992Epoch 00047: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0250 - outmap_loss: 0.0156 - outmap4_loss: 0.0262 - outmap5_loss: 0.0344 - outbin_loss: 0.2425 - outbin_acc: 0.8992 - val_loss: 0.0286 - val_outmap_loss: 0.0183 - val_outmap4_loss: 0.0262 - val_outmap5_loss: 0.0344 - val_outbin_loss: 0.3344 - val_outbin_acc: 0.8568
# Epoch 49/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0251 - outmap_loss: 0.0156 - outmap4_loss: 0.0262 - outmap5_loss: 0.0346 - outbin_loss: 0.2479 - outbin_acc: 0.8988Epoch 00048: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0251 - outmap_loss: 0.0156 - outmap4_loss: 0.0263 - outmap5_loss: 0.0346 - outbin_loss: 0.2479 - outbin_acc: 0.8987 - val_loss: 0.0272 - val_outmap_loss: 0.0170 - val_outmap4_loss: 0.0264 - val_outmap5_loss: 0.0343 - val_outbin_loss: 0.3244 - val_outbin_acc: 0.8581
# Epoch 50/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0248 - outmap_loss: 0.0154 - outmap4_loss: 0.0261 - outmap5_loss: 0.0345 - outbin_loss: 0.2410 - outbin_acc: 0.8969Epoch 00049: val_loss did not improve
# 9372/9372 [==============================] - 109s - loss: 0.0248 - outmap_loss: 0.0154 - outmap4_loss: 0.0261 - outmap5_loss: 0.0345 - outbin_loss: 0.2409 - outbin_acc: 0.8970 - val_loss: 0.0277 - val_outmap_loss: 0.0177 - val_outmap4_loss: 0.0255 - val_outmap5_loss: 0.0329 - val_outbin_loss: 0.3194 - val_outbin_acc: 0.8811
# Epoch 51/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0245 - outmap_loss: 0.0152 - outmap4_loss: 0.0260 - outmap5_loss: 0.0344 - outbin_loss: 0.2410 - outbin_acc: 0.8988Epoch 00050: val_loss did not improve
# 9372/9372 [==============================] - 110s - loss: 0.0245 - outmap_loss: 0.0152 - outmap4_loss: 0.0259 - outmap5_loss: 0.0344 - outbin_loss: 0.2408 - outbin_acc: 0.8988 - val_loss: 0.0275 - val_outmap_loss: 0.0175 - val_outmap4_loss: 0.0255 - val_outmap5_loss: 0.0339 - val_outbin_loss: 0.3216 - val_outbin_acc: 0.8811
# Epoch 52/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0247 - outmap_loss: 0.0154 - outmap4_loss: 0.0261 - outmap5_loss: 0.0343 - outbin_loss: 0.2414 - outbin_acc: 0.9006Epoch 00051: val_loss did not improve
# 9372/9372 [==============================] - 110s - loss: 0.0247 - outmap_loss: 0.0154 - outmap4_loss: 0.0261 - outmap5_loss: 0.0343 - outbin_loss: 0.2410 - outbin_acc: 0.9007 - val_loss: 0.0278 - val_outmap_loss: 0.0176 - val_outmap4_loss: 0.0261 - val_outmap5_loss: 0.0332 - val_outbin_loss: 0.3304 - val_outbin_acc: 0.8747
# Epoch 53/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0246 - outmap_loss: 0.0153 - outmap4_loss: 0.0261 - outmap5_loss: 0.0345 - outbin_loss: 0.2424 - outbin_acc: 0.8979Epoch 00052: val_loss did not improve
# 9372/9372 [==============================] - 110s - loss: 0.0246 - outmap_loss: 0.0153 - outmap4_loss: 0.0261 - outmap5_loss: 0.0345 - outbin_loss: 0.2421 - outbin_acc: 0.8980 - val_loss: 0.0296 - val_outmap_loss: 0.0194 - val_outmap4_loss: 0.0261 - val_outmap5_loss: 0.0342 - val_outbin_loss: 0.3329 - val_outbin_acc: 0.8581
# Epoch 54/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0249 - outmap_loss: 0.0155 - outmap4_loss: 0.0261 - outmap5_loss: 0.0345 - outbin_loss: 0.2405 - outbin_acc: 0.9021Epoch 00053: val_loss did not improve
# 9372/9372 [==============================] - 110s - loss: 0.0249 - outmap_loss: 0.0155 - outmap4_loss: 0.0260 - outmap5_loss: 0.0345 - outbin_loss: 0.2405 - outbin_acc: 0.9022 - val_loss: 0.0292 - val_outmap_loss: 0.0185 - val_outmap4_loss: 0.0260 - val_outmap5_loss: 0.0341 - val_outbin_loss: 0.3809 - val_outbin_acc: 0.8836
# Epoch 55/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0243 - outmap_loss: 0.0150 - outmap4_loss: 0.0259 - outmap5_loss: 0.0344 - outbin_loss: 0.2382 - outbin_acc: 0.9022Epoch 00054: val_loss did not improve
# 9372/9372 [==============================] - 110s - loss: 0.0243 - outmap_loss: 0.0150 - outmap4_loss: 0.0259 - outmap5_loss: 0.0344 - outbin_loss: 0.2380 - outbin_acc: 0.9024 - val_loss: 0.0280 - val_outmap_loss: 0.0181 - val_outmap4_loss: 0.0254 - val_outmap5_loss: 0.0330 - val_outbin_loss: 0.3187 - val_outbin_acc: 0.8708
# Epoch 56/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0243 - outmap_loss: 0.0151 - outmap4_loss: 0.0257 - outmap5_loss: 0.0341 - outbin_loss: 0.2337 - outbin_acc: 0.9053Epoch 00055: val_loss did not improve
# 9372/9372 [==============================] - 110s - loss: 0.0243 - outmap_loss: 0.0151 - outmap4_loss: 0.0257 - outmap5_loss: 0.0342 - outbin_loss: 0.2343 - outbin_acc: 0.9050 - val_loss: 0.0270 - val_outmap_loss: 0.0174 - val_outmap4_loss: 0.0258 - val_outmap5_loss: 0.0327 - val_outbin_loss: 0.2880 - val_outbin_acc: 0.8811
# Epoch 57/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0240 - outmap_loss: 0.0149 - outmap4_loss: 0.0256 - outmap5_loss: 0.0341 - outbin_loss: 0.2288 - outbin_acc: 0.9064Epoch 00056: val_loss did not improve
# 9372/9372 [==============================] - 107s - loss: 0.0241 - outmap_loss: 0.0149 - outmap4_loss: 0.0257 - outmap5_loss: 0.0341 - outbin_loss: 0.2290 - outbin_acc: 0.9061 - val_loss: 0.0274 - val_outmap_loss: 0.0176 - val_outmap4_loss: 0.0255 - val_outmap5_loss: 0.0333 - val_outbin_loss: 0.3036 - val_outbin_acc: 0.8798
# Epoch 58/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0241 - outmap_loss: 0.0149 - outmap4_loss: 0.0257 - outmap5_loss: 0.0341 - outbin_loss: 0.2323 - outbin_acc: 0.9031Epoch 00057: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0241 - outmap_loss: 0.0149 - outmap4_loss: 0.0257 - outmap5_loss: 0.0341 - outbin_loss: 0.2322 - outbin_acc: 0.9032 - val_loss: 0.0276 - val_outmap_loss: 0.0177 - val_outmap4_loss: 0.0251 - val_outmap5_loss: 0.0332 - val_outbin_loss: 0.3212 - val_outbin_acc: 0.8747
# Epoch 59/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0239 - outmap_loss: 0.0149 - outmap4_loss: 0.0256 - outmap5_loss: 0.0339 - outbin_loss: 0.2263 - outbin_acc: 0.9097Epoch 00058: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0239 - outmap_loss: 0.0149 - outmap4_loss: 0.0256 - outmap5_loss: 0.0339 - outbin_loss: 0.2259 - outbin_acc: 0.9098 - val_loss: 0.0280 - val_outmap_loss: 0.0176 - val_outmap4_loss: 0.0255 - val_outmap5_loss: 0.0342 - val_outbin_loss: 0.3593 - val_outbin_acc: 0.8836
# Epoch 60/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0233 - outmap_loss: 0.0144 - outmap4_loss: 0.0253 - outmap5_loss: 0.0336 - outbin_loss: 0.2182 - outbin_acc: 0.9117Epoch 00059: val_loss did not improve
# 9372/9372 [==============================] - 106s - loss: 0.0234 - outmap_loss: 0.0144 - outmap4_loss: 0.0253 - outmap5_loss: 0.0337 - outbin_loss: 0.2181 - outbin_acc: 0.9118 - val_loss: 0.0312 - val_outmap_loss: 0.0196 - val_outmap4_loss: 0.0274 - val_outmap5_loss: 0.0357 - val_outbin_loss: 0.4333 - val_outbin_acc: 0.8414

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture_final.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights_final.hdf5'))

# %%
def compute_scores_map(X, Y):
    Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X)
    
    map_threshs = np.linspace(0, 1, num=21)
    bin_threshs = np.linspace(0, 1, num=21)
    
    scores = np.zeros((len(map_threshs), len(bin_threshs)))
    for i in range(len(map_threshs)):
        for j in range(len(bin_threshs)):
            _Y_pred = Y_pred > map_threshs[i]
            
            for k in range(_Y_pred.shape[0]):
                # Clear prediction where we detect to little pixels
                if np.sum(_Y_pred[k]) < 150 or Y_pred_binary[k] < bin_threshs[j]:
                    _Y_pred[k,:] = 0
            
            scores[i, j] = utils.average_dice_coefficient(_Y_pred, Y)
    
    pl.imshow(scores, interpolation='nearest')
    pl.yticks(np.arange(len(map_threshs)) + 0.5, ['%.2f' % v for v in map_threshs])
    pl.xticks(np.arange(len(bin_threshs)) + 0.5, ['%.2f' % v for v in bin_threshs], rotation=90)
    pl.ylabel('map thresh')
    pl.xlabel('bin thresh')
    pl.colorbar()
    
    best_i, best_j = np.unravel_index(np.argmax(scores.ravel()), scores.shape)
    best_map_thresh = map_threshs[best_i]
    best_bin_thresh = bin_threshs[best_j]
    return best_map_thresh, best_bin_thresh

map_thresh, bin_thresh = compute_scores_map(X_test, Y_test)
print 'Best map_thresh=%f, bin_thresh=%f' % (map_thresh, bin_thresh)
# Out:
# Best map_thresh=0.450000, bin_thresh=0.900000

# %%
map_thresh = 0.45
bin_thresh = 0.9

# %%
def predict(X, map_thresh, bin_thresh):
    Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > map_thresh
    for i in range(Y_pred.shape[0]):
        if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < bin_thresh:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test, map_thresh, bin_thresh)
Y_full_pred, Y_full_pred_proba, Y_full_pred_binary = predict(X_full, map_thresh, bin_thresh)

print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "avg test set score : ", utils.average_dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
print "avg full set score : ", utils.average_dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.697454929494
# avg test set score :  0.835868238632
# full set score :  0.66135679799
# avg full set score :  0.77765709813

# %%
_ = pl.hist(Y_pred_binary)

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[50:55]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_2'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.2
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(30):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, pred44, pred88, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 15
img, pred_map = dream_output(Y_full[i])
pl.figure(figsize=(12, 4))
pl.subplot(141)
pl.imshow(X_full[i].squeeze(), cmap=cm.gray)
pl.subplot(142)
pl.imshow(Y_full[i].squeeze())
pl.subplot(143)
pl.imshow(img, cmap=cm.gray)
pl.subplot(144)
pl.imshow(pred_map.squeeze())

# %%
# Dream for the binary output
def dream_binoutput(output):
    
    layer_output = layer_dict['outbin'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output - layer_output[:, 0]))
    
    input_img = layer_dict['input_2'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    
    step = 0.1
    for i in range(40):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    _, _, _, model_pred = model.predict(img[None,None,:,:])
    return img, model_pred

img, model_pred = dream_binoutput(1)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
img, model_pred = dream_binoutput(0)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
def dream_layer_filter(layer_name, filter_index):

    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(4):
        pl.subplot(1, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
if True:
    import cv2
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(50,50))
    
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    test_fnames = _d['test_fnames']
    # bin_thresh
    Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:],
                                                  map_thresh, bin_thresh)
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
        #imre = cv2.morphologyEx(imre, cv2.MORPH_CLOSE, kernel)
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
        
        if i % 10 == 0:
            print '\r%d / %d' % (i, len(test_fnames)),
            sys.stdout.flush()
# Out:
# 5500 / 5508

# %% [markdown]
# ## Stats on predicted masks

# %%
# on Y_full
nbp_pixels = np.sum(np.sum(np.sum(Y_full, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
pl.xlim((0, 1200))
# Out:
# (0, 1200)

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
pl.xlim((0, 1200))
# Out:
# (0, 1200)
