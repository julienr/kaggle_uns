# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
# Out:
# (3906, 128, 128)
# (3906, 128, 128)

# %%
nsamples = X.shape[0]

train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
#train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.25)
X_train = X[train_indices][:,None,:,:]
Y_train_binary = Y_binary[train_indices][:,None]
Y_train = Y[train_indices][:,None,:,:]
X_test = X[test_indices][:,None,:,:]
Y_test_binary = Y_binary[test_indices][:,None]
Y_test = Y[test_indices][:,None,:,:]

# %%
print X_train.shape
print Y_train.shape
print Y_train_binary.shape
print X_train.min(), X_train.max()
# Out:
# (3515, 1, 128, 128)
# (3515, 1, 128, 128)
# (3515, 1)
# 0.0 1.0

# %%
#pl.imshow(X_train[0].squeeze())
pl.imshow(Y_train[0].squeeze())
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float16'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense, BatchNormalization
from keras.layers import LeakyReLU
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
from keras.layers import Layer, InputSpec
import keras.initializations
import keras.backend as K

class Maxout2D(Layer):
    def __init__(self, output_dim, cardinality, init='glorot_uniform', **kwargs):
        super(Maxout2D, self).__init__(**kwargs)
        # the k of the maxout paper
        self.cardinality = cardinality
        # the m of the maxout paper
        self.output_dim = output_dim
        self.init = keras.initializations.get(init)
    
    def build(self, input_shape):
        self.input_dim = input_shape[1]
        self.input_spec = [InputSpec(dtype=K.floatx(),
                                     shape=(None, input_shape[1], input_shape[2], input_shape[3]))]
        self.W = self.init((self.input_dim, self.output_dim, self.cardinality),
                           name='{}_W'.format(self.name))
        self.b = K.zeros((self.output_dim, self.cardinality))
        self.trainable_weights = [self.W, self.b]
              
    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        # flatten the spatial dimensions
        flat_x = K.reshape(x, (-1, input_shape[1], input_shape[2] * input_shape[3]))
        output = K.dot(
            K.permute_dimensions(flat_x, (0, 2, 1)),
            K.permute_dimensions(self.W, (1, 0, 2))
        )
        output += K.reshape(self.b, (1, 1, self.output_dim, self.cardinality))
        output = K.max(output, axis=3)
        output = output.transpose(0, 2, 1)
        output = K.reshape(output, (-1, self.output_dim, input_shape[2], input_shape[3]))
        return output
    
    def get_output_shape_for(self, input_shape):
        return (input_shape[0], self.output_dim, input_shape[2], input_shape[3])
    
    def get_config(self):
        config = {
            'output_dim': self.output_dim,
            'cardinality': self.cardinality
        }
        base_config = super(Maxout2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))
    
input_img = Input(shape=(3, 16, 16))
x = Convolution2D(16, 3, 3, border_mode='same')(input_img)
x = Maxout2D(5, 7)(x)

model = Model(input=input_img, output=x)
model.compile(optimizer='adam', loss='mse')
print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)               (None, 3, 16, 16)   0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)    (None, 16, 16, 16)  448         input_1[0][0]
# ____________________________________________________________________________________________________
# maxout2d_1 (Maxout2D)              (None, 5, 16, 16)   595         convolution2d_1[0][0]
# ====================================================================================================
# Total params: 1043
# ____________________________________________________________________________________________________

# %%
# https://www.kaggle.com/c/ultrasound-nerve-segmentation/forums/t/21358/0-57-deep-learning-keras-tutorial
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def dice_coef_batchwise(y_true, y_pred):
    y_true_f = K.batch_flatten(y_true)
    y_pred_f = K.batch_flatten(y_pred)
    intersection = 2. * K.sum(y_true_f * y_pred_f, axis=1, keepdims=True) + smooth
    union = K.sum(y_true_f, axis=1, keepdims=True) + \
            K.sum(y_pred_f, axis=1, keepdims=True) + \
            smooth
    return K.mean(intersection / union)

def dice_coef_loss_batchwise(y_true, y_pred):
    return 1.0 - dice_coef_batchwise(y_true, y_pred)

# %%
input_img = Input(shape=input_shape, name='input_img')
x = Convolution2D(8, 7, 7, border_mode='same')(input_img)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
pool1 = x = MaxPooling2D((2, 2), name='pool1')(x)

x = Convolution2D(8, 5, 5, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
pool2 = x = MaxPooling2D((2, 2), name='pool2')(x)

x = Convolution2D(8, 5, 5, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
pool3 = x = MaxPooling2D((2, 2), name='pool3')(x)

# -- binary presence part
x = Convolution2D(8, 5, 5, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(x)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# -- location map
x = Convolution2D(8, 3, 3, border_mode='same')(pool5)
x = BatchNormalization()(x)
#x = Maxout2D(8, 2)(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool4], mode='concat', concat_axis=1)
x = Convolution2D(8, 5, 5, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool3], mode='concat', concat_axis=1)
x = Convolution2D(8, 5, 5, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Convolution2D(8, 5, 5, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Convolution2D(8, 7, 7, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
x = UpSampling2D((2, 2))(x)

outmap = Convolution2D(1, 7, 7, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
loss='binary_crossentropy'
#loss=[dice_coef_loss_batchwise, 'binary_crossentropy']
metrics={'outmap': dice_coef_batchwise, 'outbin': 'accuracy'}
model.compile(optimizer='adam',
              loss=loss,
              loss_weights=[1., 0.01],
              metrics=metrics)

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)    (None, 8, 128, 128) 400         input_img[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_1 (BatchNormaliz(None, 8, 128, 128) 256         convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_1 (LeakyReLU)            (None, 8, 128, 128) 0           batchnormalization_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)                (None, 8, 128, 128) 0           leakyrelu_1[0][0]
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)               (None, 8, 64, 64)   0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)    (None, 8, 64, 64)   1608        pool1[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_2 (BatchNormaliz(None, 8, 64, 64)   128         convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_2 (LeakyReLU)            (None, 8, 64, 64)   0           batchnormalization_2[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)                (None, 8, 64, 64)   0           leakyrelu_2[0][0]
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)               (None, 8, 32, 32)   0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)    (None, 8, 32, 32)   1608        pool2[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_3 (BatchNormaliz(None, 8, 32, 32)   64          convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_3 (LeakyReLU)            (None, 8, 32, 32)   0           batchnormalization_3[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)                (None, 8, 32, 32)   0           leakyrelu_3[0][0]
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)               (None, 8, 16, 16)   0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)    (None, 8, 16, 16)   1608        pool3[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_4 (BatchNormaliz(None, 8, 16, 16)   32          convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_4 (LeakyReLU)            (None, 8, 16, 16)   0           batchnormalization_4[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)                (None, 8, 16, 16)   0           leakyrelu_4[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)               (None, 8, 8, 8)     0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_6 (Convolution2D)    (None, 8, 8, 8)     584         pool4[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_5 (BatchNormaliz(None, 8, 8, 8)     16          convolution2d_6[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_5 (LeakyReLU)            (None, 8, 8, 8)     0           batchnormalization_5[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)                (None, 8, 8, 8)     0           leakyrelu_5[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)               (None, 8, 4, 4)     0           dropout_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_7 (Convolution2D)    (None, 8, 4, 4)     584         pool5[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_6 (BatchNormaliz(None, 8, 4, 4)     8           convolution2d_7[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_8 (LeakyReLU)            (None, 8, 4, 4)     0           batchnormalization_6[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)                (None, 8, 4, 4)     0           leakyrelu_8[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_1 (UpSampling2D)      (None, 8, 8, 8)     0           dropout_6[0][0]
# ____________________________________________________________________________________________________
# merge_1 (Merge)                    (None, 16, 8, 8)    0           upsampling2d_1[0][0]
#                                                                    pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8 (Convolution2D)    (None, 8, 8, 8)     3208        merge_1[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_7 (BatchNormaliz(None, 8, 8, 8)     16          convolution2d_8[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_9 (LeakyReLU)            (None, 8, 8, 8)     0           batchnormalization_7[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)                (None, 8, 8, 8)     0           leakyrelu_9[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_2 (UpSampling2D)      (None, 8, 16, 16)   0           dropout_7[0][0]
# ____________________________________________________________________________________________________
# merge_2 (Merge)                    (None, 16, 16, 16)  0           upsampling2d_2[0][0]
#                                                                    pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_9 (Convolution2D)    (None, 8, 16, 16)   3208        merge_2[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_8 (BatchNormaliz(None, 8, 16, 16)   32          convolution2d_9[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_10 (LeakyReLU)           (None, 8, 16, 16)   0           batchnormalization_8[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)                (None, 8, 16, 16)   0           leakyrelu_10[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_3 (UpSampling2D)      (None, 8, 32, 32)   0           dropout_8[0][0]
# ____________________________________________________________________________________________________
# merge_3 (Merge)                    (None, 16, 32, 32)  0           upsampling2d_3[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_10 (Convolution2D)   (None, 8, 32, 32)   3208        merge_3[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_9 (BatchNormaliz(None, 8, 32, 32)   64          convolution2d_10[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_11 (LeakyReLU)           (None, 8, 32, 32)   0           batchnormalization_9[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)                (None, 8, 32, 32)   0           leakyrelu_11[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_4 (UpSampling2D)      (None, 8, 64, 64)   0           dropout_9[0][0]
# ____________________________________________________________________________________________________
# merge_4 (Merge)                    (None, 16, 64, 64)  0           upsampling2d_4[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_11 (Convolution2D)   (None, 8, 64, 64)   6280        merge_4[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)                (None, 128)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_10 (BatchNormali(None, 8, 64, 64)   128         convolution2d_11[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                    (None, 32)          4128        flatten_1[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_12 (LeakyReLU)           (None, 8, 64, 64)   0           batchnormalization_10[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_6 (LeakyReLU)            (None, 32)          0           dense_1[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                    (None, 16)          528         leakyrelu_6[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)               (None, 8, 64, 64)   0           leakyrelu_12[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_7 (LeakyReLU)            (None, 16)          0           dense_2[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_5 (UpSampling2D)      (None, 8, 128, 128) 0           dropout_10[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_7[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 393         upsampling2d_5[0][0]
# ====================================================================================================
# Total params: 28106
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {'outmap': Y_train, 'outbin': Y_train_binary},
        batch_size=32,
        validation_data=(X_test, {'outmap': Y_test, 'outbin': Y_test_binary}),
        nb_epoch=60,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    pl.plot(history.history['loss'], label='train loss')
    pl.plot(history.history['val_loss'], c='g', label='val loss')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
        custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.05])
    
    print_summary(model.layers)
# Out:
# Train on 3515 samples, validate on 391 samples
# Epoch 1/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0763 - outmap_loss: 0.0694 - outbin_loss: 0.6865 - outmap_dice_coef_batchwise: 0.0265 - outbin_acc: 0.6067Epoch 00000: val_loss improved from inf to 0.04515, saving model to weights.hdf5
# 3515/3515 [==============================] - 31s - loss: 0.0761 - outmap_loss: 0.0692 - outbin_loss: 0.6866 - outmap_dice_coef_batchwise: 0.0270 - outbin_acc: 0.6065 - val_loss: 0.0452 - val_outmap_loss: 0.0387 - val_outbin_loss: 0.6427 - val_outmap_dice_coef_batchwise: 0.0384 - val_outbin_acc: 0.6701
# Epoch 2/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0390 - outmap_loss: 0.0331 - outbin_loss: 0.5893 - outmap_dice_coef_batchwise: 0.1083 - outbin_acc: 0.6927Epoch 00001: val_loss improved from 0.04515 to 0.04394, saving model to weights.hdf5
# 3515/3515 [==============================] - 32s - loss: 0.0391 - outmap_loss: 0.0332 - outbin_loss: 0.5890 - outmap_dice_coef_batchwise: 0.1085 - outbin_acc: 0.6925 - val_loss: 0.0439 - val_outmap_loss: 0.0385 - val_outbin_loss: 0.5475 - val_outmap_dice_coef_batchwise: 0.0796 - val_outbin_acc: 0.7442
# Epoch 3/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0314 - outmap_loss: 0.0266 - outbin_loss: 0.4810 - outmap_dice_coef_batchwise: 0.1617 - outbin_acc: 0.7833Epoch 00002: val_loss improved from 0.04394 to 0.02903, saving model to weights.hdf5
# 3515/3515 [==============================] - 32s - loss: 0.0314 - outmap_loss: 0.0266 - outbin_loss: 0.4809 - outmap_dice_coef_batchwise: 0.1620 - outbin_acc: 0.7832 - val_loss: 0.0290 - val_outmap_loss: 0.0245 - val_outbin_loss: 0.4535 - val_outmap_dice_coef_batchwise: 0.1406 - val_outbin_acc: 0.8133
# Epoch 4/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0287 - outmap_loss: 0.0244 - outbin_loss: 0.4337 - outmap_dice_coef_batchwise: 0.1851 - outbin_acc: 0.8071Epoch 00003: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0287 - outmap_loss: 0.0244 - outbin_loss: 0.4332 - outmap_dice_coef_batchwise: 0.1853 - outbin_acc: 0.8074 - val_loss: 0.0296 - val_outmap_loss: 0.0255 - val_outbin_loss: 0.4163 - val_outmap_dice_coef_batchwise: 0.1611 - val_outbin_acc: 0.8184
# Epoch 5/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0269 - outmap_loss: 0.0230 - outbin_loss: 0.3929 - outmap_dice_coef_batchwise: 0.1990 - outbin_acc: 0.8329Epoch 00004: val_loss improved from 0.02903 to 0.02721, saving model to weights.hdf5
# 3515/3515 [==============================] - 31s - loss: 0.0270 - outmap_loss: 0.0231 - outbin_loss: 0.3944 - outmap_dice_coef_batchwise: 0.1987 - outbin_acc: 0.8324 - val_loss: 0.0272 - val_outmap_loss: 0.0232 - val_outbin_loss: 0.4048 - val_outmap_dice_coef_batchwise: 0.1770 - val_outbin_acc: 0.8133
# Epoch 6/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0258 - outmap_loss: 0.0220 - outbin_loss: 0.3740 - outmap_dice_coef_batchwise: 0.2117 - outbin_acc: 0.8432Epoch 00005: val_loss improved from 0.02721 to 0.02461, saving model to weights.hdf5
# 3515/3515 [==============================] - 31s - loss: 0.0258 - outmap_loss: 0.0220 - outbin_loss: 0.3744 - outmap_dice_coef_batchwise: 0.2110 - outbin_acc: 0.8430 - val_loss: 0.0246 - val_outmap_loss: 0.0205 - val_outbin_loss: 0.4083 - val_outmap_dice_coef_batchwise: 0.1745 - val_outbin_acc: 0.8184
# Epoch 7/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0249 - outmap_loss: 0.0212 - outbin_loss: 0.3680 - outmap_dice_coef_batchwise: 0.2181 - outbin_acc: 0.8383Epoch 00006: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0249 - outmap_loss: 0.0212 - outbin_loss: 0.3675 - outmap_dice_coef_batchwise: 0.2174 - outbin_acc: 0.8384 - val_loss: 0.0289 - val_outmap_loss: 0.0247 - val_outbin_loss: 0.4277 - val_outmap_dice_coef_batchwise: 0.1876 - val_outbin_acc: 0.8107
# Epoch 8/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0239 - outmap_loss: 0.0205 - outbin_loss: 0.3374 - outmap_dice_coef_batchwise: 0.2266 - outbin_acc: 0.8587Epoch 00007: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0239 - outmap_loss: 0.0206 - outbin_loss: 0.3383 - outmap_dice_coef_batchwise: 0.2269 - outbin_acc: 0.8580 - val_loss: 0.0283 - val_outmap_loss: 0.0240 - val_outbin_loss: 0.4319 - val_outmap_dice_coef_batchwise: 0.2044 - val_outbin_acc: 0.8107
# Epoch 9/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0232 - outmap_loss: 0.0199 - outbin_loss: 0.3310 - outmap_dice_coef_batchwise: 0.2325 - outbin_acc: 0.8635Epoch 00008: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0233 - outmap_loss: 0.0200 - outbin_loss: 0.3331 - outmap_dice_coef_batchwise: 0.2327 - outbin_acc: 0.8634 - val_loss: 0.0249 - val_outmap_loss: 0.0211 - val_outbin_loss: 0.3799 - val_outmap_dice_coef_batchwise: 0.2174 - val_outbin_acc: 0.8338
# Epoch 10/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0225 - outmap_loss: 0.0193 - outbin_loss: 0.3184 - outmap_dice_coef_batchwise: 0.2394 - outbin_acc: 0.8655Epoch 00009: val_loss improved from 0.02461 to 0.02314, saving model to weights.hdf5
# 3515/3515 [==============================] - 32s - loss: 0.0226 - outmap_loss: 0.0194 - outbin_loss: 0.3181 - outmap_dice_coef_batchwise: 0.2394 - outbin_acc: 0.8654 - val_loss: 0.0231 - val_outmap_loss: 0.0193 - val_outbin_loss: 0.3857 - val_outmap_dice_coef_batchwise: 0.2120 - val_outbin_acc: 0.8184
# Epoch 11/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0228 - outmap_loss: 0.0195 - outbin_loss: 0.3255 - outmap_dice_coef_batchwise: 0.2409 - outbin_acc: 0.8632Epoch 00010: val_loss improved from 0.02314 to 0.02305, saving model to weights.hdf5
# 3515/3515 [==============================] - 31s - loss: 0.0227 - outmap_loss: 0.0195 - outbin_loss: 0.3252 - outmap_dice_coef_batchwise: 0.2415 - outbin_acc: 0.8632 - val_loss: 0.0230 - val_outmap_loss: 0.0193 - val_outbin_loss: 0.3776 - val_outmap_dice_coef_batchwise: 0.2096 - val_outbin_acc: 0.8312
# Epoch 12/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0224 - outmap_loss: 0.0193 - outbin_loss: 0.3181 - outmap_dice_coef_batchwise: 0.2456 - outbin_acc: 0.8664Epoch 00011: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0224 - outmap_loss: 0.0192 - outbin_loss: 0.3173 - outmap_dice_coef_batchwise: 0.2462 - outbin_acc: 0.8666 - val_loss: 0.0266 - val_outmap_loss: 0.0226 - val_outbin_loss: 0.4001 - val_outmap_dice_coef_batchwise: 0.2021 - val_outbin_acc: 0.8184
# Epoch 13/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0219 - outmap_loss: 0.0189 - outbin_loss: 0.2996 - outmap_dice_coef_batchwise: 0.2513 - outbin_acc: 0.8724Epoch 00012: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0218 - outmap_loss: 0.0188 - outbin_loss: 0.2981 - outmap_dice_coef_batchwise: 0.2519 - outbin_acc: 0.8734 - val_loss: 0.0259 - val_outmap_loss: 0.0218 - val_outbin_loss: 0.4155 - val_outmap_dice_coef_batchwise: 0.2204 - val_outbin_acc: 0.8312
# Epoch 14/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0214 - outmap_loss: 0.0184 - outbin_loss: 0.2979 - outmap_dice_coef_batchwise: 0.2550 - outbin_acc: 0.8764Epoch 00013: val_loss improved from 0.02305 to 0.02224, saving model to weights.hdf5
# 3515/3515 [==============================] - 32s - loss: 0.0214 - outmap_loss: 0.0184 - outbin_loss: 0.2981 - outmap_dice_coef_batchwise: 0.2549 - outbin_acc: 0.8765 - val_loss: 0.0222 - val_outmap_loss: 0.0183 - val_outbin_loss: 0.3962 - val_outmap_dice_coef_batchwise: 0.2073 - val_outbin_acc: 0.8261
# Epoch 15/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0210 - outmap_loss: 0.0181 - outbin_loss: 0.2900 - outmap_dice_coef_batchwise: 0.2624 - outbin_acc: 0.8793Epoch 00014: val_loss improved from 0.02224 to 0.02159, saving model to weights.hdf5
# 3515/3515 [==============================] - 31s - loss: 0.0209 - outmap_loss: 0.0180 - outbin_loss: 0.2911 - outmap_dice_coef_batchwise: 0.2614 - outbin_acc: 0.8791 - val_loss: 0.0216 - val_outmap_loss: 0.0180 - val_outbin_loss: 0.3605 - val_outmap_dice_coef_batchwise: 0.2185 - val_outbin_acc: 0.8389
# Epoch 16/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0205 - outmap_loss: 0.0178 - outbin_loss: 0.2782 - outmap_dice_coef_batchwise: 0.2658 - outbin_acc: 0.8839Epoch 00015: val_loss did not improve
# 3515/3515 [==============================] - 32s - loss: 0.0205 - outmap_loss: 0.0177 - outbin_loss: 0.2773 - outmap_dice_coef_batchwise: 0.2655 - outbin_acc: 0.8842 - val_loss: 0.0225 - val_outmap_loss: 0.0188 - val_outbin_loss: 0.3659 - val_outmap_dice_coef_batchwise: 0.2513 - val_outbin_acc: 0.8389
# Epoch 17/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0208 - outmap_loss: 0.0180 - outbin_loss: 0.2787 - outmap_dice_coef_batchwise: 0.2654 - outbin_acc: 0.8807Epoch 00016: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0208 - outmap_loss: 0.0180 - outbin_loss: 0.2792 - outmap_dice_coef_batchwise: 0.2650 - outbin_acc: 0.8805 - val_loss: 0.0232 - val_outmap_loss: 0.0192 - val_outbin_loss: 0.4002 - val_outmap_dice_coef_batchwise: 0.2053 - val_outbin_acc: 0.8338
# Epoch 18/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0202 - outmap_loss: 0.0175 - outbin_loss: 0.2760 - outmap_dice_coef_batchwise: 0.2686 - outbin_acc: 0.8885Epoch 00017: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0202 - outmap_loss: 0.0175 - outbin_loss: 0.2751 - outmap_dice_coef_batchwise: 0.2686 - outbin_acc: 0.8885 - val_loss: 0.0252 - val_outmap_loss: 0.0211 - val_outbin_loss: 0.4079 - val_outmap_dice_coef_batchwise: 0.2594 - val_outbin_acc: 0.8338
# Epoch 19/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0199 - outmap_loss: 0.0172 - outbin_loss: 0.2705 - outmap_dice_coef_batchwise: 0.2743 - outbin_acc: 0.8905Epoch 00018: val_loss improved from 0.02159 to 0.02129, saving model to weights.hdf5
# 3515/3515 [==============================] - 31s - loss: 0.0199 - outmap_loss: 0.0172 - outbin_loss: 0.2706 - outmap_dice_coef_batchwise: 0.2743 - outbin_acc: 0.8905 - val_loss: 0.0213 - val_outmap_loss: 0.0178 - val_outbin_loss: 0.3534 - val_outmap_dice_coef_batchwise: 0.2474 - val_outbin_acc: 0.8491
# Epoch 20/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0196 - outmap_loss: 0.0170 - outbin_loss: 0.2600 - outmap_dice_coef_batchwise: 0.2823 - outbin_acc: 0.8931Epoch 00019: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0196 - outmap_loss: 0.0170 - outbin_loss: 0.2587 - outmap_dice_coef_batchwise: 0.2825 - outbin_acc: 0.8939 - val_loss: 0.0221 - val_outmap_loss: 0.0181 - val_outbin_loss: 0.3996 - val_outmap_dice_coef_batchwise: 0.2379 - val_outbin_acc: 0.8338
# Epoch 21/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0194 - outmap_loss: 0.0168 - outbin_loss: 0.2528 - outmap_dice_coef_batchwise: 0.2844 - outbin_acc: 0.8976Epoch 00020: val_loss did not improve
# 3515/3515 [==============================] - 32s - loss: 0.0194 - outmap_loss: 0.0169 - outbin_loss: 0.2543 - outmap_dice_coef_batchwise: 0.2842 - outbin_acc: 0.8970 - val_loss: 0.0240 - val_outmap_loss: 0.0202 - val_outbin_loss: 0.3813 - val_outmap_dice_coef_batchwise: 0.2404 - val_outbin_acc: 0.8261
# Epoch 22/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0192 - outmap_loss: 0.0167 - outbin_loss: 0.2463 - outmap_dice_coef_batchwise: 0.2880 - outbin_acc: 0.8979Epoch 00021: val_loss improved from 0.02129 to 0.02115, saving model to weights.hdf5
# 3515/3515 [==============================] - 31s - loss: 0.0192 - outmap_loss: 0.0167 - outbin_loss: 0.2461 - outmap_dice_coef_batchwise: 0.2885 - outbin_acc: 0.8982 - val_loss: 0.0212 - val_outmap_loss: 0.0175 - val_outbin_loss: 0.3689 - val_outmap_dice_coef_batchwise: 0.2361 - val_outbin_acc: 0.8363
# Epoch 23/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0191 - outmap_loss: 0.0166 - outbin_loss: 0.2500 - outmap_dice_coef_batchwise: 0.2854 - outbin_acc: 0.8982Epoch 00022: val_loss improved from 0.02115 to 0.02092, saving model to weights.hdf5
# 3515/3515 [==============================] - 31s - loss: 0.0191 - outmap_loss: 0.0166 - outbin_loss: 0.2489 - outmap_dice_coef_batchwise: 0.2853 - outbin_acc: 0.8987 - val_loss: 0.0209 - val_outmap_loss: 0.0174 - val_outbin_loss: 0.3547 - val_outmap_dice_coef_batchwise: 0.2257 - val_outbin_acc: 0.8312
# Epoch 24/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0189 - outmap_loss: 0.0164 - outbin_loss: 0.2585 - outmap_dice_coef_batchwise: 0.2943 - outbin_acc: 0.8945Epoch 00023: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0190 - outmap_loss: 0.0164 - outbin_loss: 0.2598 - outmap_dice_coef_batchwise: 0.2940 - outbin_acc: 0.8936 - val_loss: 0.0249 - val_outmap_loss: 0.0210 - val_outbin_loss: 0.3942 - val_outmap_dice_coef_batchwise: 0.2934 - val_outbin_acc: 0.8261
# Epoch 25/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0185 - outmap_loss: 0.0161 - outbin_loss: 0.2422 - outmap_dice_coef_batchwise: 0.2959 - outbin_acc: 0.8988Epoch 00024: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0186 - outmap_loss: 0.0161 - outbin_loss: 0.2419 - outmap_dice_coef_batchwise: 0.2967 - outbin_acc: 0.8987 - val_loss: 0.0217 - val_outmap_loss: 0.0181 - val_outbin_loss: 0.3584 - val_outmap_dice_coef_batchwise: 0.2799 - val_outbin_acc: 0.8414
# Epoch 26/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0184 - outmap_loss: 0.0161 - outbin_loss: 0.2356 - outmap_dice_coef_batchwise: 0.3020 - outbin_acc: 0.9065Epoch 00025: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0184 - outmap_loss: 0.0161 - outbin_loss: 0.2355 - outmap_dice_coef_batchwise: 0.3022 - outbin_acc: 0.9061 - val_loss: 0.0240 - val_outmap_loss: 0.0205 - val_outbin_loss: 0.3490 - val_outmap_dice_coef_batchwise: 0.2954 - val_outbin_acc: 0.8568
# Epoch 27/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0179 - outmap_loss: 0.0157 - outbin_loss: 0.2263 - outmap_dice_coef_batchwise: 0.3091 - outbin_acc: 0.9134Epoch 00026: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0180 - outmap_loss: 0.0157 - outbin_loss: 0.2267 - outmap_dice_coef_batchwise: 0.3102 - outbin_acc: 0.9129 - val_loss: 0.0210 - val_outmap_loss: 0.0175 - val_outbin_loss: 0.3538 - val_outmap_dice_coef_batchwise: 0.2607 - val_outbin_acc: 0.8670
# Epoch 28/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0180 - outmap_loss: 0.0158 - outbin_loss: 0.2266 - outmap_dice_coef_batchwise: 0.3088 - outbin_acc: 0.9071Epoch 00027: val_loss did not improve
# 3515/3515 [==============================] - 32s - loss: 0.0181 - outmap_loss: 0.0158 - outbin_loss: 0.2271 - outmap_dice_coef_batchwise: 0.3096 - outbin_acc: 0.9070 - val_loss: 0.0211 - val_outmap_loss: 0.0174 - val_outbin_loss: 0.3680 - val_outmap_dice_coef_batchwise: 0.2456 - val_outbin_acc: 0.8542
# Epoch 29/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0181 - outmap_loss: 0.0159 - outbin_loss: 0.2267 - outmap_dice_coef_batchwise: 0.3126 - outbin_acc: 0.9051Epoch 00028: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0181 - outmap_loss: 0.0159 - outbin_loss: 0.2265 - outmap_dice_coef_batchwise: 0.3124 - outbin_acc: 0.9053 - val_loss: 0.0224 - val_outmap_loss: 0.0188 - val_outbin_loss: 0.3676 - val_outmap_dice_coef_batchwise: 0.3051 - val_outbin_acc: 0.8389
# Epoch 30/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0176 - outmap_loss: 0.0155 - outbin_loss: 0.2102 - outmap_dice_coef_batchwise: 0.3146 - outbin_acc: 0.9151Epoch 00029: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0176 - outmap_loss: 0.0155 - outbin_loss: 0.2093 - outmap_dice_coef_batchwise: 0.3144 - outbin_acc: 0.9155 - val_loss: 0.0246 - val_outmap_loss: 0.0207 - val_outbin_loss: 0.3942 - val_outmap_dice_coef_batchwise: 0.3312 - val_outbin_acc: 0.8593
# Epoch 31/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0175 - outmap_loss: 0.0153 - outbin_loss: 0.2126 - outmap_dice_coef_batchwise: 0.3213 - outbin_acc: 0.9146Epoch 00030: val_loss did not improve
# 3515/3515 [==============================] - 32s - loss: 0.0175 - outmap_loss: 0.0153 - outbin_loss: 0.2123 - outmap_dice_coef_batchwise: 0.3216 - outbin_acc: 0.9147 - val_loss: 0.0236 - val_outmap_loss: 0.0193 - val_outbin_loss: 0.4245 - val_outmap_dice_coef_batchwise: 0.2484 - val_outbin_acc: 0.8363
# Epoch 32/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0173 - outmap_loss: 0.0151 - outbin_loss: 0.2114 - outmap_dice_coef_batchwise: 0.3306 - outbin_acc: 0.9114Epoch 00031: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0173 - outmap_loss: 0.0152 - outbin_loss: 0.2110 - outmap_dice_coef_batchwise: 0.3303 - outbin_acc: 0.9112 - val_loss: 0.0234 - val_outmap_loss: 0.0197 - val_outbin_loss: 0.3722 - val_outmap_dice_coef_batchwise: 0.3176 - val_outbin_acc: 0.8389
# Epoch 33/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0175 - outmap_loss: 0.0153 - outbin_loss: 0.2146 - outmap_dice_coef_batchwise: 0.3320 - outbin_acc: 0.9120Epoch 00032: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0175 - outmap_loss: 0.0153 - outbin_loss: 0.2138 - outmap_dice_coef_batchwise: 0.3321 - outbin_acc: 0.9127 - val_loss: 0.0215 - val_outmap_loss: 0.0179 - val_outbin_loss: 0.3588 - val_outmap_dice_coef_batchwise: 0.2336 - val_outbin_acc: 0.8491
# Epoch 34/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0166 - outmap_loss: 0.0147 - outbin_loss: 0.1934 - outmap_dice_coef_batchwise: 0.3409 - outbin_acc: 0.9223Epoch 00033: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0166 - outmap_loss: 0.0147 - outbin_loss: 0.1936 - outmap_dice_coef_batchwise: 0.3408 - outbin_acc: 0.9223 - val_loss: 0.0245 - val_outmap_loss: 0.0206 - val_outbin_loss: 0.3964 - val_outmap_dice_coef_batchwise: 0.3631 - val_outbin_acc: 0.8465
# Epoch 35/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0168 - outmap_loss: 0.0148 - outbin_loss: 0.2023 - outmap_dice_coef_batchwise: 0.3430 - outbin_acc: 0.9174Epoch 00034: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0169 - outmap_loss: 0.0149 - outbin_loss: 0.2029 - outmap_dice_coef_batchwise: 0.3433 - outbin_acc: 0.9175 - val_loss: 0.0241 - val_outmap_loss: 0.0205 - val_outbin_loss: 0.3609 - val_outmap_dice_coef_batchwise: 0.3791 - val_outbin_acc: 0.8363
# Epoch 36/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0171 - outmap_loss: 0.0151 - outbin_loss: 0.2044 - outmap_dice_coef_batchwise: 0.3361 - outbin_acc: 0.9088Epoch 00035: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0172 - outmap_loss: 0.0151 - outbin_loss: 0.2047 - outmap_dice_coef_batchwise: 0.3371 - outbin_acc: 0.9084 - val_loss: 0.0239 - val_outmap_loss: 0.0199 - val_outbin_loss: 0.4001 - val_outmap_dice_coef_batchwise: 0.3182 - val_outbin_acc: 0.8517
# Epoch 37/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0165 - outmap_loss: 0.0146 - outbin_loss: 0.1873 - outmap_dice_coef_batchwise: 0.3399 - outbin_acc: 0.9269Epoch 00036: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0165 - outmap_loss: 0.0146 - outbin_loss: 0.1879 - outmap_dice_coef_batchwise: 0.3400 - outbin_acc: 0.9269 - val_loss: 0.0213 - val_outmap_loss: 0.0177 - val_outbin_loss: 0.3657 - val_outmap_dice_coef_batchwise: 0.2853 - val_outbin_acc: 0.8517
# Epoch 38/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0165 - outmap_loss: 0.0147 - outbin_loss: 0.1888 - outmap_dice_coef_batchwise: 0.3465 - outbin_acc: 0.9235Epoch 00037: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0166 - outmap_loss: 0.0147 - outbin_loss: 0.1887 - outmap_dice_coef_batchwise: 0.3467 - outbin_acc: 0.9235 - val_loss: 0.0271 - val_outmap_loss: 0.0228 - val_outbin_loss: 0.4295 - val_outmap_dice_coef_batchwise: 0.3861 - val_outbin_acc: 0.8440
# Epoch 39/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0164 - outmap_loss: 0.0145 - outbin_loss: 0.1908 - outmap_dice_coef_batchwise: 0.3512 - outbin_acc: 0.9189Epoch 00038: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0164 - outmap_loss: 0.0145 - outbin_loss: 0.1900 - outmap_dice_coef_batchwise: 0.3510 - outbin_acc: 0.9195 - val_loss: 0.0230 - val_outmap_loss: 0.0192 - val_outbin_loss: 0.3767 - val_outmap_dice_coef_batchwise: 0.3396 - val_outbin_acc: 0.8491
# Epoch 40/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0157 - outmap_loss: 0.0141 - outbin_loss: 0.1660 - outmap_dice_coef_batchwise: 0.3686 - outbin_acc: 0.9338Epoch 00039: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0158 - outmap_loss: 0.0141 - outbin_loss: 0.1680 - outmap_dice_coef_batchwise: 0.3678 - outbin_acc: 0.9331 - val_loss: 0.0228 - val_outmap_loss: 0.0190 - val_outbin_loss: 0.3790 - val_outmap_dice_coef_batchwise: 0.3294 - val_outbin_acc: 0.8593
# Epoch 41/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0162 - outmap_loss: 0.0143 - outbin_loss: 0.1921 - outmap_dice_coef_batchwise: 0.3530 - outbin_acc: 0.9209Epoch 00040: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0162 - outmap_loss: 0.0143 - outbin_loss: 0.1923 - outmap_dice_coef_batchwise: 0.3530 - outbin_acc: 0.9206 - val_loss: 0.0275 - val_outmap_loss: 0.0231 - val_outbin_loss: 0.4485 - val_outmap_dice_coef_batchwise: 0.4265 - val_outbin_acc: 0.8389
# Epoch 42/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0158 - outmap_loss: 0.0140 - outbin_loss: 0.1820 - outmap_dice_coef_batchwise: 0.3683 - outbin_acc: 0.9286Epoch 00041: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0158 - outmap_loss: 0.0140 - outbin_loss: 0.1823 - outmap_dice_coef_batchwise: 0.3693 - outbin_acc: 0.9286 - val_loss: 0.0218 - val_outmap_loss: 0.0179 - val_outbin_loss: 0.3940 - val_outmap_dice_coef_batchwise: 0.2971 - val_outbin_acc: 0.8491
# Epoch 43/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0157 - outmap_loss: 0.0140 - outbin_loss: 0.1775 - outmap_dice_coef_batchwise: 0.3735 - outbin_acc: 0.9257Epoch 00042: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0157 - outmap_loss: 0.0140 - outbin_loss: 0.1774 - outmap_dice_coef_batchwise: 0.3738 - outbin_acc: 0.9255 - val_loss: 0.0230 - val_outmap_loss: 0.0190 - val_outbin_loss: 0.4025 - val_outmap_dice_coef_batchwise: 0.3605 - val_outbin_acc: 0.8517
# Epoch 44/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0158 - outmap_loss: 0.0141 - outbin_loss: 0.1708 - outmap_dice_coef_batchwise: 0.3878 - outbin_acc: 0.9309Epoch 00043: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0158 - outmap_loss: 0.0141 - outbin_loss: 0.1717 - outmap_dice_coef_batchwise: 0.3869 - outbin_acc: 0.9309 - val_loss: 0.0217 - val_outmap_loss: 0.0181 - val_outbin_loss: 0.3659 - val_outmap_dice_coef_batchwise: 0.2831 - val_outbin_acc: 0.8414
# Epoch 45/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0160 - outmap_loss: 0.0141 - outbin_loss: 0.1805 - outmap_dice_coef_batchwise: 0.3688 - outbin_acc: 0.9272Epoch 00044: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0160 - outmap_loss: 0.0142 - outbin_loss: 0.1799 - outmap_dice_coef_batchwise: 0.3689 - outbin_acc: 0.9272 - val_loss: 0.0229 - val_outmap_loss: 0.0191 - val_outbin_loss: 0.3758 - val_outmap_dice_coef_batchwise: 0.3054 - val_outbin_acc: 0.8465
# Epoch 46/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0155 - outmap_loss: 0.0138 - outbin_loss: 0.1665 - outmap_dice_coef_batchwise: 0.3861 - outbin_acc: 0.9292Epoch 00045: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0155 - outmap_loss: 0.0138 - outbin_loss: 0.1668 - outmap_dice_coef_batchwise: 0.3861 - outbin_acc: 0.9292 - val_loss: 0.0255 - val_outmap_loss: 0.0213 - val_outbin_loss: 0.4207 - val_outmap_dice_coef_batchwise: 0.4059 - val_outbin_acc: 0.8465
# Epoch 47/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0152 - outmap_loss: 0.0135 - outbin_loss: 0.1669 - outmap_dice_coef_batchwise: 0.3823 - outbin_acc: 0.9326Epoch 00046: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0152 - outmap_loss: 0.0135 - outbin_loss: 0.1668 - outmap_dice_coef_batchwise: 0.3822 - outbin_acc: 0.9326 - val_loss: 0.0236 - val_outmap_loss: 0.0191 - val_outbin_loss: 0.4471 - val_outmap_dice_coef_batchwise: 0.3588 - val_outbin_acc: 0.8593
# Epoch 48/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0153 - outmap_loss: 0.0137 - outbin_loss: 0.1590 - outmap_dice_coef_batchwise: 0.3880 - outbin_acc: 0.9346Epoch 00047: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0153 - outmap_loss: 0.0137 - outbin_loss: 0.1587 - outmap_dice_coef_batchwise: 0.3883 - outbin_acc: 0.9349 - val_loss: 0.0286 - val_outmap_loss: 0.0240 - val_outbin_loss: 0.4622 - val_outmap_dice_coef_batchwise: 0.4532 - val_outbin_acc: 0.8440
# Epoch 49/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0151 - outmap_loss: 0.0135 - outbin_loss: 0.1576 - outmap_dice_coef_batchwise: 0.3986 - outbin_acc: 0.9346Epoch 00048: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0151 - outmap_loss: 0.0135 - outbin_loss: 0.1582 - outmap_dice_coef_batchwise: 0.3988 - outbin_acc: 0.9340 - val_loss: 0.0248 - val_outmap_loss: 0.0201 - val_outbin_loss: 0.4748 - val_outmap_dice_coef_batchwise: 0.3276 - val_outbin_acc: 0.8414
# Epoch 50/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0150 - outmap_loss: 0.0134 - outbin_loss: 0.1610 - outmap_dice_coef_batchwise: 0.4016 - outbin_acc: 0.9364Epoch 00049: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0150 - outmap_loss: 0.0134 - outbin_loss: 0.1628 - outmap_dice_coef_batchwise: 0.4015 - outbin_acc: 0.9360 - val_loss: 0.0229 - val_outmap_loss: 0.0187 - val_outbin_loss: 0.4177 - val_outmap_dice_coef_batchwise: 0.2632 - val_outbin_acc: 0.8619
# Epoch 51/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0149 - outmap_loss: 0.0133 - outbin_loss: 0.1599 - outmap_dice_coef_batchwise: 0.4160 - outbin_acc: 0.9361Epoch 00050: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0149 - outmap_loss: 0.0133 - outbin_loss: 0.1611 - outmap_dice_coef_batchwise: 0.4153 - outbin_acc: 0.9360 - val_loss: 0.0247 - val_outmap_loss: 0.0207 - val_outbin_loss: 0.3992 - val_outmap_dice_coef_batchwise: 0.4223 - val_outbin_acc: 0.8670
# Epoch 52/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0148 - outmap_loss: 0.0133 - outbin_loss: 0.1527 - outmap_dice_coef_batchwise: 0.4129 - outbin_acc: 0.9384Epoch 00051: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0148 - outmap_loss: 0.0133 - outbin_loss: 0.1523 - outmap_dice_coef_batchwise: 0.4128 - outbin_acc: 0.9385 - val_loss: 0.0253 - val_outmap_loss: 0.0209 - val_outbin_loss: 0.4400 - val_outmap_dice_coef_batchwise: 0.4451 - val_outbin_acc: 0.8593
# Epoch 53/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0154 - outmap_loss: 0.0138 - outbin_loss: 0.1632 - outmap_dice_coef_batchwise: 0.4045 - outbin_acc: 0.9295Epoch 00052: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0154 - outmap_loss: 0.0137 - outbin_loss: 0.1624 - outmap_dice_coef_batchwise: 0.4037 - outbin_acc: 0.9300 - val_loss: 0.0224 - val_outmap_loss: 0.0186 - val_outbin_loss: 0.3836 - val_outmap_dice_coef_batchwise: 0.3130 - val_outbin_acc: 0.8542
# Epoch 54/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0147 - outmap_loss: 0.0132 - outbin_loss: 0.1489 - outmap_dice_coef_batchwise: 0.4072 - outbin_acc: 0.9409Epoch 00053: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0147 - outmap_loss: 0.0132 - outbin_loss: 0.1522 - outmap_dice_coef_batchwise: 0.4067 - outbin_acc: 0.9400 - val_loss: 0.0243 - val_outmap_loss: 0.0200 - val_outbin_loss: 0.4272 - val_outmap_dice_coef_batchwise: 0.3965 - val_outbin_acc: 0.8645
# Epoch 55/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0144 - outmap_loss: 0.0130 - outbin_loss: 0.1391 - outmap_dice_coef_batchwise: 0.4307 - outbin_acc: 0.9490Epoch 00054: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0145 - outmap_loss: 0.0131 - outbin_loss: 0.1401 - outmap_dice_coef_batchwise: 0.4304 - outbin_acc: 0.9485 - val_loss: 0.0245 - val_outmap_loss: 0.0201 - val_outbin_loss: 0.4417 - val_outmap_dice_coef_batchwise: 0.3859 - val_outbin_acc: 0.8568
# Epoch 56/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0146 - outmap_loss: 0.0131 - outbin_loss: 0.1488 - outmap_dice_coef_batchwise: 0.4234 - outbin_acc: 0.9381Epoch 00055: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0146 - outmap_loss: 0.0131 - outbin_loss: 0.1493 - outmap_dice_coef_batchwise: 0.4237 - outbin_acc: 0.9374 - val_loss: 0.0252 - val_outmap_loss: 0.0206 - val_outbin_loss: 0.4627 - val_outmap_dice_coef_batchwise: 0.4224 - val_outbin_acc: 0.8568
# Epoch 57/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0146 - outmap_loss: 0.0131 - outbin_loss: 0.1510 - outmap_dice_coef_batchwise: 0.4197 - outbin_acc: 0.9361Epoch 00056: val_loss did not improve
# 3515/3515 [==============================] - 32s - loss: 0.0146 - outmap_loss: 0.0131 - outbin_loss: 0.1503 - outmap_dice_coef_batchwise: 0.4206 - outbin_acc: 0.9366 - val_loss: 0.0234 - val_outmap_loss: 0.0193 - val_outbin_loss: 0.4080 - val_outmap_dice_coef_batchwise: 0.3781 - val_outbin_acc: 0.8568
# Epoch 58/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0145 - outmap_loss: 0.0130 - outbin_loss: 0.1459 - outmap_dice_coef_batchwise: 0.4397 - outbin_acc: 0.9418Epoch 00057: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0145 - outmap_loss: 0.0130 - outbin_loss: 0.1453 - outmap_dice_coef_batchwise: 0.4395 - outbin_acc: 0.9422 - val_loss: 0.0233 - val_outmap_loss: 0.0191 - val_outbin_loss: 0.4197 - val_outmap_dice_coef_batchwise: 0.3241 - val_outbin_acc: 0.8517
# Epoch 59/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0145 - outmap_loss: 0.0132 - outbin_loss: 0.1365 - outmap_dice_coef_batchwise: 0.4187 - outbin_acc: 0.9421Epoch 00058: val_loss did not improve
# 3515/3515 [==============================] - 32s - loss: 0.0145 - outmap_loss: 0.0131 - outbin_loss: 0.1362 - outmap_dice_coef_batchwise: 0.4192 - outbin_acc: 0.9422 - val_loss: 0.0249 - val_outmap_loss: 0.0205 - val_outbin_loss: 0.4368 - val_outmap_dice_coef_batchwise: 0.3902 - val_outbin_acc: 0.8645
# Epoch 60/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0143 - outmap_loss: 0.0129 - outbin_loss: 0.1464 - outmap_dice_coef_batchwise: 0.4308 - outbin_acc: 0.9407Epoch 00059: val_loss did not improve
# 3515/3515 [==============================] - 31s - loss: 0.0143 - outmap_loss: 0.0129 - outbin_loss: 0.1464 - outmap_dice_coef_batchwise: 0.4310 - outbin_acc: 0.9405 - val_loss: 0.0244 - val_outmap_loss: 0.0201 - val_outbin_loss: 0.4324 - val_outmap_dice_coef_batchwise: 0.4177 - val_outbin_acc: 0.8670

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights.hdf5'))

# %%
conv1 = model.layers[1].output
_f = K.function([K.learning_phase(), input_img], [conv1])
_convout = _f([0, X_test[:1]])[0]
print _convout.shape

maxout1 = model.layers[3].output
_f = K.function([K.learning_phase(), input_img], [maxout1])
_maxout = _f([0, X_test[:1]])[0]
print _maxout.shape

pl.figure()
pl.imshow(_convout[0, 0], interpolation='nearest')
pl.colorbar()
pl.figure()
pl.imshow(_maxout[0, 0], interpolation='nearest')
pl.colorbar()
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/backend/theano_backend.py:514: UserWarning: theano.function was asked to create a function computing outputs given certain inputs, but the provided input variable at index 0 is not part of the computational graph needed to compute the outputs: keras_learning_phase.
# To make this warning into an error, you can pass the parameter on_unused_input='raise' to theano.function. To disable it completely, use on_unused_input='ignore'.
#   **kwargs)
# (1, 8, 128, 128)
# (1, 8, 128, 128)
# <matplotlib.colorbar.Colorbar instance at 0x7f0bbcbaed88>
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
def predict(X):
    Y_pred, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > 0.3
    for i in range(Y_pred.shape[0]):
        # Clear prediction where we detect to little pixels
        # Figure it out by
        # pl.hist(np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1))
        if np.sum(Y_pred[i]) < 200 or Y_pred_binary[i] < 0.2:
        #if np.sum(Y_pred[i]) < 200:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test)
Y_full_pred, Y_full_pred_proba, Y_full_pred_binary = predict(X_full)

reload(utils)
print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "test set average score : ", utils.average_dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
print "full set average score : ", utils.average_dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.672193224849
# test set average score :  0.819071089784
# full set score :  0.680388759076
# full set average score :  0.801172069145

# %%
if False:
    y_pred = K.placeholder(shape=Y_pred.shape)
    y_true = K.placeholder(shape=Y_test.shape)

    _dice_coef = K.function([y_true, y_pred], dice_coef_batchwise(y_true, y_pred))

    Y_pred, _, _ = predict(X_train)
    print _np_dice_coef(Y_train, Y_pred)
    print utils.average_dice_coefficient(Y_pred, Y_train)
    print _dice_coef([Y_train, Y_pred])

# %%
_ = pl.hist(Y_pred_binary)

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[60:65]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 15
img, pred_map = dream_output(Y_full[i])
pl.figure(figsize=(12, 4))
pl.subplot(131)
pl.imshow(Y_full[i].squeeze())
pl.subplot(132)
pl.imshow(img, cmap=cm.gray)
pl.subplot(133)
pl.imshow(pred_map.squeeze())

# %%
# Dream for the binary output
def dream_binoutput(output):
    
    layer_output = layer_dict['outbin'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output - layer_output[:, 0]))
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    _, model_pred = model.predict(img[None,None,:,:])
    return img, model_pred

img, model_pred = dream_binoutput(1)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
img, model_pred = dream_binoutput(0)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
def dream_layer_filter(layer_name, filter_index):

    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(8):
        pl.subplot(2, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
if True:
    import cv2
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(50,50))
    
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    test_fnames = _d['test_fnames']
    Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:])
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
        imre = cv2.morphologyEx(imre, cv2.MORPH_CLOSE, kernel)
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
        
        if i % 10 == 0:
            print '\r%d / %d' % (i, len(test_fnames)),
            sys.stdout.flush()
# Out:
# 5500 / 5508

# %% [markdown]
# ## Stats on predicted masks

# %%
# on Y_full
nbp_pixels = np.sum(np.sum(np.sum(Y_full, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
