# %% [markdown]
# ## FCNN with a boolean output indicating the likelihood of the image containing nerve

# %% [markdown]
# This is submission 6, got 0.67

# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
# Out:
# (3906, 128, 128)
# (3906, 128, 128)

# %%
nsamples = X.shape[0]

train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
#train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.25)
X_train = X[train_indices][:,None,:,:]
Y_train_binary = Y_binary[train_indices][:,None]
Y_train = Y[train_indices][:,None,:,:]
X_test = X[test_indices][:,None,:,:]
Y_test_binary = Y_binary[test_indices][:,None]
Y_test = Y[test_indices][:,None,:,:]

# %%
print X_train.shape
print Y_train.shape
print Y_train_binary.shape
print X_train.min(), X_train.max()
# Out:
# (3515, 1, 128, 128)
# (3515, 1, 128, 128)
# (3515, 1)
# 0.0 1.0

# %%
#pl.imshow(X_train[0].squeeze())
pl.imshow(Y_train[0].squeeze())
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float16'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense, BatchNormalization
from keras.layers import LeakyReLU
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
from keras.layers import Layer, InputSpec
import keras.initializations
import keras.backend as K

class Maxout2D(Layer):
    def __init__(self, output_dim, cardinality, init='glorot_uniform', **kwargs):
        super(Maxout2D, self).__init__(**kwargs)
        # the k of the maxout paper
        self.cardinality = cardinality
        # the m of the maxout paper
        self.output_dim = output_dim
        self.init = keras.initializations.get(init)
    
    def build(self, input_shape):
        self.input_dim = input_shape[1]
        self.input_spec = [InputSpec(dtype=K.floatx(),
                                     shape=(None, input_shape[1], input_shape[2], input_shape[3]))]
        self.W = self.init((self.input_dim, self.output_dim, self.cardinality),
                           name='{}_W'.format(self.name))
        self.b = K.zeros((self.output_dim, self.cardinality))
        self.trainable_weights = [self.W, self.b]
              
    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        # flatten the spatial dimensions
        flat_x = K.reshape(x, (-1, input_shape[1], input_shape[2] * input_shape[3]))
        output = K.dot(
            K.permute_dimensions(flat_x, (0, 2, 1)),
            K.permute_dimensions(self.W, (1, 0, 2))
        )
        output += K.reshape(self.b, (1, 1, self.output_dim, self.cardinality))
        output = K.max(output, axis=3)
        output = output.transpose(0, 2, 1)
        output = K.reshape(output, (-1, self.output_dim, input_shape[2], input_shape[3]))
        return output
    
    def get_output_shape_for(self, input_shape):
        return (input_shape[0], self.output_dim, input_shape[2], input_shape[3])
    
    def get_config(self):
        config = {
            'output_dim': self.output_dim,
            'cardinality': self.cardinality
        }
        base_config = super(Maxout2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))
    
input_img = Input(shape=(3, 16, 16))
x = Convolution2D(16, 3, 3, border_mode='same')(input_img)
x = Maxout2D(5, 7)(x)

model = Model(input=input_img, output=x)
model.compile(optimizer='adam', loss='mse')
print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)               (None, 3, 16, 16)   0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)    (None, 16, 16, 16)  448         input_1[0][0]
# ____________________________________________________________________________________________________
# maxout2d_1 (Maxout2D)              (None, 5, 16, 16)   595         convolution2d_1[0][0]
# ====================================================================================================
# Total params: 1043
# ____________________________________________________________________________________________________

# %%
# https://www.kaggle.com/c/ultrasound-nerve-segmentation/forums/t/21358/0-57-deep-learning-keras-tutorial
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def dice_coef_batchwise(y_true, y_pred):
    y_true_f = K.batch_flatten(y_true)
    y_pred_f = K.batch_flatten(y_pred)
    intersection = 2. * K.sum(y_true_f * y_pred_f, axis=1, keepdims=True) + smooth
    union = K.sum(y_true_f, axis=1, keepdims=True) + \
            K.sum(y_pred_f, axis=1, keepdims=True) + \
            smooth
    return K.mean(intersection / union)

def dice_coef_loss_batchwise(y_true, y_pred):
    return 1.0 - dice_coef_batchwise(y_true, y_pred)

# %%
input_img = Input(shape=input_shape, name='input_img')
x = Convolution2D(8, 3, 3, border_mode='same')(input_img)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
#x = Maxout2D(8, 2)(x)
pool1 = x = MaxPooling2D((2, 2), name='pool1')(x)

x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
pool2 = x = MaxPooling2D((2, 2), name='pool2')(x)

x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
pool3 = x = MaxPooling2D((2, 2), name='pool3')(x)

# -- binary presence part
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(x)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# -- location map
x = Convolution2D(8, 3, 3, border_mode='same')(pool5)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
#x = Maxout2D(8, 2)(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool4], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool3], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
x = UpSampling2D((2, 2))(x)

outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
loss='binary_crossentropy'
#loss=[dice_coef_loss_batchwise, 'binary_crossentropy']
metrics={'outmap': dice_coef_batchwise, 'outbin': 'accuracy'}
model.compile(optimizer='adam',
              loss=loss,
              loss_weights=[1., 0.01],
              metrics=metrics)

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)    (None, 8, 128, 128) 80          input_img[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)    (None, 8, 128, 128) 584         convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_1 (BatchNormaliz(None, 8, 128, 128) 256         convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_1 (LeakyReLU)            (None, 8, 128, 128) 0           batchnormalization_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)                (None, 8, 128, 128) 0           leakyrelu_1[0][0]
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)               (None, 8, 64, 64)   0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)    (None, 8, 64, 64)   584         pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)    (None, 8, 64, 64)   584         convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_2 (BatchNormaliz(None, 8, 64, 64)   128         convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_2 (LeakyReLU)            (None, 8, 64, 64)   0           batchnormalization_2[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)                (None, 8, 64, 64)   0           leakyrelu_2[0][0]
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)               (None, 8, 32, 32)   0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_6 (Convolution2D)    (None, 8, 32, 32)   584         pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_7 (Convolution2D)    (None, 8, 32, 32)   584         convolution2d_6[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_3 (BatchNormaliz(None, 8, 32, 32)   64          convolution2d_7[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_3 (LeakyReLU)            (None, 8, 32, 32)   0           batchnormalization_3[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)                (None, 8, 32, 32)   0           leakyrelu_3[0][0]
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)               (None, 8, 16, 16)   0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8 (Convolution2D)    (None, 8, 16, 16)   584         pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_9 (Convolution2D)    (None, 8, 16, 16)   584         convolution2d_8[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_4 (BatchNormaliz(None, 8, 16, 16)   32          convolution2d_9[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_4 (LeakyReLU)            (None, 8, 16, 16)   0           batchnormalization_4[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)                (None, 8, 16, 16)   0           leakyrelu_4[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)               (None, 8, 8, 8)     0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_10 (Convolution2D)   (None, 8, 8, 8)     584         pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_11 (Convolution2D)   (None, 8, 8, 8)     584         convolution2d_10[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_5 (BatchNormaliz(None, 8, 8, 8)     16          convolution2d_11[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_5 (LeakyReLU)            (None, 8, 8, 8)     0           batchnormalization_5[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)                (None, 8, 8, 8)     0           leakyrelu_5[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)               (None, 8, 4, 4)     0           dropout_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_12 (Convolution2D)   (None, 8, 4, 4)     584         pool5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_13 (Convolution2D)   (None, 8, 4, 4)     584         convolution2d_12[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_6 (BatchNormaliz(None, 8, 4, 4)     8           convolution2d_13[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_8 (LeakyReLU)            (None, 8, 4, 4)     0           batchnormalization_6[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)                (None, 8, 4, 4)     0           leakyrelu_8[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_1 (UpSampling2D)      (None, 8, 8, 8)     0           dropout_6[0][0]
# ____________________________________________________________________________________________________
# merge_1 (Merge)                    (None, 16, 8, 8)    0           upsampling2d_1[0][0]
#                                                                    pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_14 (Convolution2D)   (None, 8, 8, 8)     1160        merge_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_15 (Convolution2D)   (None, 8, 8, 8)     584         convolution2d_14[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_7 (BatchNormaliz(None, 8, 8, 8)     16          convolution2d_15[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_9 (LeakyReLU)            (None, 8, 8, 8)     0           batchnormalization_7[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)                (None, 8, 8, 8)     0           leakyrelu_9[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_2 (UpSampling2D)      (None, 8, 16, 16)   0           dropout_7[0][0]
# ____________________________________________________________________________________________________
# merge_2 (Merge)                    (None, 16, 16, 16)  0           upsampling2d_2[0][0]
#                                                                    pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_16 (Convolution2D)   (None, 8, 16, 16)   1160        merge_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_17 (Convolution2D)   (None, 8, 16, 16)   584         convolution2d_16[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_8 (BatchNormaliz(None, 8, 16, 16)   32          convolution2d_17[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_10 (LeakyReLU)           (None, 8, 16, 16)   0           batchnormalization_8[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)                (None, 8, 16, 16)   0           leakyrelu_10[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_3 (UpSampling2D)      (None, 8, 32, 32)   0           dropout_8[0][0]
# ____________________________________________________________________________________________________
# merge_3 (Merge)                    (None, 16, 32, 32)  0           upsampling2d_3[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_18 (Convolution2D)   (None, 8, 32, 32)   1160        merge_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_19 (Convolution2D)   (None, 8, 32, 32)   584         convolution2d_18[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_9 (BatchNormaliz(None, 8, 32, 32)   64          convolution2d_19[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_11 (LeakyReLU)           (None, 8, 32, 32)   0           batchnormalization_9[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)                (None, 8, 32, 32)   0           leakyrelu_11[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_4 (UpSampling2D)      (None, 8, 64, 64)   0           dropout_9[0][0]
# ____________________________________________________________________________________________________
# merge_4 (Merge)                    (None, 16, 64, 64)  0           upsampling2d_4[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_20 (Convolution2D)   (None, 8, 64, 64)   1160        merge_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_21 (Convolution2D)   (None, 8, 64, 64)   584         convolution2d_20[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)                (None, 128)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_10 (BatchNormali(None, 8, 64, 64)   128         convolution2d_21[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                    (None, 32)          4128        flatten_1[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_12 (LeakyReLU)           (None, 8, 64, 64)   0           batchnormalization_10[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_6 (LeakyReLU)            (None, 32)          0           dense_1[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                    (None, 16)          528         leakyrelu_6[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)               (None, 8, 64, 64)   0           leakyrelu_12[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_7 (LeakyReLU)            (None, 16)          0           dense_2[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_5 (UpSampling2D)      (None, 8, 128, 128) 0           dropout_10[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_7[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 73          upsampling2d_5[0][0]
# ====================================================================================================
# Total params: 18970
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {'outmap': Y_train, 'outbin': Y_train_binary},
        batch_size=32,
        validation_data=(X_test, {'outmap': Y_test, 'outbin': Y_test_binary}),
        nb_epoch=60,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    pl.plot(history.history['loss'], label='train loss')
    pl.plot(history.history['val_loss'], c='g', label='val loss')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
        custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.05])
    
    print_summary(model.layers)
# Out:
# Train on 3515 samples, validate on 391 samples
# Epoch 1/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.1082 - outmap_loss: 0.1015 - outbin_loss: 0.6671 - outmap_dice_coef_batchwise: 0.0176 - outbin_acc: 0.6190Epoch 00000: val_loss improved from inf to 0.05645, saving model to weights.hdf5
# 3515/3515 [==============================] - 26s - loss: 0.1077 - outmap_loss: 0.1010 - outbin_loss: 0.6668 - outmap_dice_coef_batchwise: 0.0177 - outbin_acc: 0.6196 - val_loss: 0.0565 - val_outmap_loss: 0.0499 - val_outbin_loss: 0.6567 - val_outmap_dice_coef_batchwise: 0.0352 - val_outbin_acc: 0.6292
# Epoch 2/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0524 - outmap_loss: 0.0458 - outbin_loss: 0.6538 - outmap_dice_coef_batchwise: 0.0471 - outbin_acc: 0.6239Epoch 00001: val_loss improved from 0.05645 to 0.04648, saving model to weights.hdf5
# 3515/3515 [==============================] - 25s - loss: 0.0525 - outmap_loss: 0.0460 - outbin_loss: 0.6556 - outmap_dice_coef_batchwise: 0.0474 - outbin_acc: 0.6216 - val_loss: 0.0465 - val_outmap_loss: 0.0402 - val_outbin_loss: 0.6303 - val_outmap_dice_coef_batchwise: 0.0476 - val_outbin_acc: 0.6292
# Epoch 3/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0442 - outmap_loss: 0.0382 - outbin_loss: 0.5950 - outmap_dice_coef_batchwise: 0.0781 - outbin_acc: 0.6998Epoch 00002: val_loss improved from 0.04648 to 0.04448, saving model to weights.hdf5
# 3515/3515 [==============================] - 25s - loss: 0.0441 - outmap_loss: 0.0382 - outbin_loss: 0.5952 - outmap_dice_coef_batchwise: 0.0779 - outbin_acc: 0.6996 - val_loss: 0.0445 - val_outmap_loss: 0.0388 - val_outbin_loss: 0.5651 - val_outmap_dice_coef_batchwise: 0.0664 - val_outbin_acc: 0.7621
# Epoch 4/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0372 - outmap_loss: 0.0319 - outbin_loss: 0.5359 - outmap_dice_coef_batchwise: 0.1187 - outbin_acc: 0.7486Epoch 00003: val_loss improved from 0.04448 to 0.03734, saving model to weights.hdf5
# 3515/3515 [==============================] - 26s - loss: 0.0371 - outmap_loss: 0.0318 - outbin_loss: 0.5354 - outmap_dice_coef_batchwise: 0.1184 - outbin_acc: 0.7491 - val_loss: 0.0373 - val_outmap_loss: 0.0321 - val_outbin_loss: 0.5283 - val_outmap_dice_coef_batchwise: 0.1152 - val_outbin_acc: 0.7749
# Epoch 5/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0333 - outmap_loss: 0.0283 - outbin_loss: 0.5013 - outmap_dice_coef_batchwise: 0.1458 - outbin_acc: 0.7689Epoch 00004: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0333 - outmap_loss: 0.0283 - outbin_loss: 0.5023 - outmap_dice_coef_batchwise: 0.1454 - outbin_acc: 0.7670 - val_loss: 0.0382 - val_outmap_loss: 0.0333 - val_outbin_loss: 0.4894 - val_outmap_dice_coef_batchwise: 0.1303 - val_outbin_acc: 0.7877
# Epoch 6/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0304 - outmap_loss: 0.0257 - outbin_loss: 0.4611 - outmap_dice_coef_batchwise: 0.1663 - outbin_acc: 0.7896Epoch 00005: val_loss improved from 0.03734 to 0.02651, saving model to weights.hdf5
# 3515/3515 [==============================] - 26s - loss: 0.0303 - outmap_loss: 0.0257 - outbin_loss: 0.4602 - outmap_dice_coef_batchwise: 0.1666 - outbin_acc: 0.7900 - val_loss: 0.0265 - val_outmap_loss: 0.0221 - val_outbin_loss: 0.4438 - val_outmap_dice_coef_batchwise: 0.1869 - val_outbin_acc: 0.7928
# Epoch 7/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0293 - outmap_loss: 0.0249 - outbin_loss: 0.4380 - outmap_dice_coef_batchwise: 0.1766 - outbin_acc: 0.8073Epoch 00006: val_loss did not improve
# 3515/3515 [==============================] - 25s - loss: 0.0293 - outmap_loss: 0.0249 - outbin_loss: 0.4377 - outmap_dice_coef_batchwise: 0.1767 - outbin_acc: 0.8071 - val_loss: 0.0265 - val_outmap_loss: 0.0223 - val_outbin_loss: 0.4228 - val_outmap_dice_coef_batchwise: 0.1858 - val_outbin_acc: 0.8184
# Epoch 8/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0277 - outmap_loss: 0.0236 - outbin_loss: 0.4149 - outmap_dice_coef_batchwise: 0.1860 - outbin_acc: 0.8225Epoch 00007: val_loss improved from 0.02651 to 0.02618, saving model to weights.hdf5
# 3515/3515 [==============================] - 29s - loss: 0.0277 - outmap_loss: 0.0236 - outbin_loss: 0.4139 - outmap_dice_coef_batchwise: 0.1860 - outbin_acc: 0.8233 - val_loss: 0.0262 - val_outmap_loss: 0.0219 - val_outbin_loss: 0.4270 - val_outmap_dice_coef_batchwise: 0.1936 - val_outbin_acc: 0.8056
# Epoch 9/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0270 - outmap_loss: 0.0229 - outbin_loss: 0.4082 - outmap_dice_coef_batchwise: 0.1928 - outbin_acc: 0.8197Epoch 00008: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0270 - outmap_loss: 0.0229 - outbin_loss: 0.4079 - outmap_dice_coef_batchwise: 0.1932 - outbin_acc: 0.8202 - val_loss: 0.0278 - val_outmap_loss: 0.0238 - val_outbin_loss: 0.3954 - val_outmap_dice_coef_batchwise: 0.1905 - val_outbin_acc: 0.8286
# Epoch 10/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0263 - outmap_loss: 0.0224 - outbin_loss: 0.3903 - outmap_dice_coef_batchwise: 0.1985 - outbin_acc: 0.8294Epoch 00009: val_loss improved from 0.02618 to 0.02484, saving model to weights.hdf5
# 3515/3515 [==============================] - 25s - loss: 0.0263 - outmap_loss: 0.0224 - outbin_loss: 0.3898 - outmap_dice_coef_batchwise: 0.1990 - outbin_acc: 0.8299 - val_loss: 0.0248 - val_outmap_loss: 0.0212 - val_outbin_loss: 0.3661 - val_outmap_dice_coef_batchwise: 0.2082 - val_outbin_acc: 0.8542
# Epoch 11/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0255 - outmap_loss: 0.0217 - outbin_loss: 0.3764 - outmap_dice_coef_batchwise: 0.2056 - outbin_acc: 0.8351Epoch 00010: val_loss improved from 0.02484 to 0.02478, saving model to weights.hdf5
# 3515/3515 [==============================] - 26s - loss: 0.0255 - outmap_loss: 0.0218 - outbin_loss: 0.3772 - outmap_dice_coef_batchwise: 0.2051 - outbin_acc: 0.8350 - val_loss: 0.0248 - val_outmap_loss: 0.0211 - val_outbin_loss: 0.3688 - val_outmap_dice_coef_batchwise: 0.2150 - val_outbin_acc: 0.8465
# Epoch 12/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0250 - outmap_loss: 0.0213 - outbin_loss: 0.3705 - outmap_dice_coef_batchwise: 0.2095 - outbin_acc: 0.8374Epoch 00011: val_loss improved from 0.02478 to 0.02307, saving model to weights.hdf5
# 3515/3515 [==============================] - 26s - loss: 0.0250 - outmap_loss: 0.0213 - outbin_loss: 0.3707 - outmap_dice_coef_batchwise: 0.2101 - outbin_acc: 0.8376 - val_loss: 0.0231 - val_outmap_loss: 0.0195 - val_outbin_loss: 0.3609 - val_outmap_dice_coef_batchwise: 0.2222 - val_outbin_acc: 0.8670
# Epoch 13/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0246 - outmap_loss: 0.0210 - outbin_loss: 0.3600 - outmap_dice_coef_batchwise: 0.2143 - outbin_acc: 0.8417Epoch 00012: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0245 - outmap_loss: 0.0209 - outbin_loss: 0.3592 - outmap_dice_coef_batchwise: 0.2144 - outbin_acc: 0.8415 - val_loss: 0.0238 - val_outmap_loss: 0.0201 - val_outbin_loss: 0.3667 - val_outmap_dice_coef_batchwise: 0.2279 - val_outbin_acc: 0.8465
# Epoch 14/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0241 - outmap_loss: 0.0207 - outbin_loss: 0.3439 - outmap_dice_coef_batchwise: 0.2183 - outbin_acc: 0.8521Epoch 00013: val_loss improved from 0.02307 to 0.02265, saving model to weights.hdf5
# 3515/3515 [==============================] - 26s - loss: 0.0242 - outmap_loss: 0.0207 - outbin_loss: 0.3444 - outmap_dice_coef_batchwise: 0.2185 - outbin_acc: 0.8526 - val_loss: 0.0227 - val_outmap_loss: 0.0194 - val_outbin_loss: 0.3301 - val_outmap_dice_coef_batchwise: 0.2256 - val_outbin_acc: 0.8747
# Epoch 15/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0238 - outmap_loss: 0.0203 - outbin_loss: 0.3472 - outmap_dice_coef_batchwise: 0.2216 - outbin_acc: 0.8489Epoch 00014: val_loss improved from 0.02265 to 0.02234, saving model to weights.hdf5
# 3515/3515 [==============================] - 26s - loss: 0.0238 - outmap_loss: 0.0203 - outbin_loss: 0.3468 - outmap_dice_coef_batchwise: 0.2216 - outbin_acc: 0.8489 - val_loss: 0.0223 - val_outmap_loss: 0.0190 - val_outbin_loss: 0.3319 - val_outmap_dice_coef_batchwise: 0.2261 - val_outbin_acc: 0.8696
# Epoch 16/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0235 - outmap_loss: 0.0201 - outbin_loss: 0.3399 - outmap_dice_coef_batchwise: 0.2231 - outbin_acc: 0.8549Epoch 00015: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0235 - outmap_loss: 0.0201 - outbin_loss: 0.3399 - outmap_dice_coef_batchwise: 0.2235 - outbin_acc: 0.8549 - val_loss: 0.0224 - val_outmap_loss: 0.0190 - val_outbin_loss: 0.3400 - val_outmap_dice_coef_batchwise: 0.2342 - val_outbin_acc: 0.8747
# Epoch 17/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0232 - outmap_loss: 0.0198 - outbin_loss: 0.3409 - outmap_dice_coef_batchwise: 0.2283 - outbin_acc: 0.8509Epoch 00016: val_loss did not improve
# 3515/3515 [==============================] - 27s - loss: 0.0232 - outmap_loss: 0.0198 - outbin_loss: 0.3395 - outmap_dice_coef_batchwise: 0.2287 - outbin_acc: 0.8518 - val_loss: 0.0242 - val_outmap_loss: 0.0209 - val_outbin_loss: 0.3309 - val_outmap_dice_coef_batchwise: 0.2522 - val_outbin_acc: 0.8772
# Epoch 18/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0232 - outmap_loss: 0.0199 - outbin_loss: 0.3299 - outmap_dice_coef_batchwise: 0.2287 - outbin_acc: 0.8621Epoch 00017: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0232 - outmap_loss: 0.0199 - outbin_loss: 0.3314 - outmap_dice_coef_batchwise: 0.2291 - outbin_acc: 0.8615 - val_loss: 0.0228 - val_outmap_loss: 0.0194 - val_outbin_loss: 0.3448 - val_outmap_dice_coef_batchwise: 0.2275 - val_outbin_acc: 0.8542
# Epoch 19/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0225 - outmap_loss: 0.0193 - outbin_loss: 0.3203 - outmap_dice_coef_batchwise: 0.2360 - outbin_acc: 0.8630Epoch 00018: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0225 - outmap_loss: 0.0193 - outbin_loss: 0.3211 - outmap_dice_coef_batchwise: 0.2368 - outbin_acc: 0.8620 - val_loss: 0.0235 - val_outmap_loss: 0.0200 - val_outbin_loss: 0.3509 - val_outmap_dice_coef_batchwise: 0.2438 - val_outbin_acc: 0.8670
# Epoch 20/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0222 - outmap_loss: 0.0190 - outbin_loss: 0.3179 - outmap_dice_coef_batchwise: 0.2387 - outbin_acc: 0.8630Epoch 00019: val_loss improved from 0.02234 to 0.02180, saving model to weights.hdf5
# 3515/3515 [==============================] - 26s - loss: 0.0222 - outmap_loss: 0.0190 - outbin_loss: 0.3181 - outmap_dice_coef_batchwise: 0.2389 - outbin_acc: 0.8626 - val_loss: 0.0218 - val_outmap_loss: 0.0186 - val_outbin_loss: 0.3209 - val_outmap_dice_coef_batchwise: 0.2435 - val_outbin_acc: 0.8849
# Epoch 21/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0221 - outmap_loss: 0.0190 - outbin_loss: 0.3084 - outmap_dice_coef_batchwise: 0.2406 - outbin_acc: 0.8658Epoch 00020: val_loss did not improve
# 3515/3515 [==============================] - 25s - loss: 0.0221 - outmap_loss: 0.0190 - outbin_loss: 0.3090 - outmap_dice_coef_batchwise: 0.2403 - outbin_acc: 0.8654 - val_loss: 0.0222 - val_outmap_loss: 0.0190 - val_outbin_loss: 0.3166 - val_outmap_dice_coef_batchwise: 0.2430 - val_outbin_acc: 0.8772
# Epoch 22/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0218 - outmap_loss: 0.0187 - outbin_loss: 0.3036 - outmap_dice_coef_batchwise: 0.2451 - outbin_acc: 0.8710Epoch 00021: val_loss did not improve
# 3515/3515 [==============================] - 25s - loss: 0.0217 - outmap_loss: 0.0187 - outbin_loss: 0.3031 - outmap_dice_coef_batchwise: 0.2450 - outbin_acc: 0.8711 - val_loss: 0.0220 - val_outmap_loss: 0.0187 - val_outbin_loss: 0.3288 - val_outmap_dice_coef_batchwise: 0.2370 - val_outbin_acc: 0.8772
# Epoch 23/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0216 - outmap_loss: 0.0186 - outbin_loss: 0.3001 - outmap_dice_coef_batchwise: 0.2454 - outbin_acc: 0.8756Epoch 00022: val_loss did not improve
# 3515/3515 [==============================] - 25s - loss: 0.0217 - outmap_loss: 0.0187 - outbin_loss: 0.3021 - outmap_dice_coef_batchwise: 0.2454 - outbin_acc: 0.8748 - val_loss: 0.0222 - val_outmap_loss: 0.0191 - val_outbin_loss: 0.3051 - val_outmap_dice_coef_batchwise: 0.2676 - val_outbin_acc: 0.8772
# Epoch 24/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0217 - outmap_loss: 0.0187 - outbin_loss: 0.2955 - outmap_dice_coef_batchwise: 0.2482 - outbin_acc: 0.8739Epoch 00023: val_loss did not improve
# 3515/3515 [==============================] - 25s - loss: 0.0216 - outmap_loss: 0.0186 - outbin_loss: 0.2941 - outmap_dice_coef_batchwise: 0.2476 - outbin_acc: 0.8743 - val_loss: 0.0228 - val_outmap_loss: 0.0197 - val_outbin_loss: 0.3077 - val_outmap_dice_coef_batchwise: 0.2543 - val_outbin_acc: 0.8875
# Epoch 25/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0217 - outmap_loss: 0.0187 - outbin_loss: 0.2993 - outmap_dice_coef_batchwise: 0.2460 - outbin_acc: 0.8744Epoch 00024: val_loss improved from 0.02180 to 0.02116, saving model to weights.hdf5
# 3515/3515 [==============================] - 25s - loss: 0.0217 - outmap_loss: 0.0187 - outbin_loss: 0.2996 - outmap_dice_coef_batchwise: 0.2462 - outbin_acc: 0.8740 - val_loss: 0.0212 - val_outmap_loss: 0.0181 - val_outbin_loss: 0.3040 - val_outmap_dice_coef_batchwise: 0.2516 - val_outbin_acc: 0.8926
# Epoch 26/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0216 - outmap_loss: 0.0187 - outbin_loss: 0.2934 - outmap_dice_coef_batchwise: 0.2496 - outbin_acc: 0.8750Epoch 00025: val_loss did not improve
# 3515/3515 [==============================] - 25s - loss: 0.0216 - outmap_loss: 0.0187 - outbin_loss: 0.2924 - outmap_dice_coef_batchwise: 0.2498 - outbin_acc: 0.8754 - val_loss: 0.0229 - val_outmap_loss: 0.0195 - val_outbin_loss: 0.3390 - val_outmap_dice_coef_batchwise: 0.2449 - val_outbin_acc: 0.8747
# Epoch 27/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0211 - outmap_loss: 0.0182 - outbin_loss: 0.2844 - outmap_dice_coef_batchwise: 0.2529 - outbin_acc: 0.8793Epoch 00026: val_loss did not improve
# 3515/3515 [==============================] - 25s - loss: 0.0211 - outmap_loss: 0.0183 - outbin_loss: 0.2836 - outmap_dice_coef_batchwise: 0.2532 - outbin_acc: 0.8799 - val_loss: 0.0238 - val_outmap_loss: 0.0202 - val_outbin_loss: 0.3521 - val_outmap_dice_coef_batchwise: 0.2581 - val_outbin_acc: 0.8696
# Epoch 28/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0207 - outmap_loss: 0.0179 - outbin_loss: 0.2766 - outmap_dice_coef_batchwise: 0.2620 - outbin_acc: 0.8782Epoch 00027: val_loss did not improve
# 3515/3515 [==============================] - 25s - loss: 0.0207 - outmap_loss: 0.0179 - outbin_loss: 0.2777 - outmap_dice_coef_batchwise: 0.2623 - outbin_acc: 0.8774 - val_loss: 0.0212 - val_outmap_loss: 0.0181 - val_outbin_loss: 0.3087 - val_outmap_dice_coef_batchwise: 0.2495 - val_outbin_acc: 0.8849
# Epoch 29/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0207 - outmap_loss: 0.0178 - outbin_loss: 0.2904 - outmap_dice_coef_batchwise: 0.2613 - outbin_acc: 0.8733Epoch 00028: val_loss did not improve
# 3515/3515 [==============================] - 25s - loss: 0.0208 - outmap_loss: 0.0179 - outbin_loss: 0.2912 - outmap_dice_coef_batchwise: 0.2611 - outbin_acc: 0.8728 - val_loss: 0.0219 - val_outmap_loss: 0.0188 - val_outbin_loss: 0.3175 - val_outmap_dice_coef_batchwise: 0.2418 - val_outbin_acc: 0.8772
# Epoch 30/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0206 - outmap_loss: 0.0178 - outbin_loss: 0.2817 - outmap_dice_coef_batchwise: 0.2643 - outbin_acc: 0.8847Epoch 00029: val_loss did not improve
# 3515/3515 [==============================] - 25s - loss: 0.0205 - outmap_loss: 0.0177 - outbin_loss: 0.2802 - outmap_dice_coef_batchwise: 0.2635 - outbin_acc: 0.8856 - val_loss: 0.0239 - val_outmap_loss: 0.0205 - val_outbin_loss: 0.3402 - val_outmap_dice_coef_batchwise: 0.2802 - val_outbin_acc: 0.8798
# Epoch 31/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0203 - outmap_loss: 0.0176 - outbin_loss: 0.2740 - outmap_dice_coef_batchwise: 0.2681 - outbin_acc: 0.8839Epoch 00030: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0203 - outmap_loss: 0.0176 - outbin_loss: 0.2728 - outmap_dice_coef_batchwise: 0.2679 - outbin_acc: 0.8848 - val_loss: 0.0234 - val_outmap_loss: 0.0202 - val_outbin_loss: 0.3204 - val_outmap_dice_coef_batchwise: 0.3044 - val_outbin_acc: 0.8721
# Epoch 32/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0202 - outmap_loss: 0.0175 - outbin_loss: 0.2751 - outmap_dice_coef_batchwise: 0.2673 - outbin_acc: 0.8822Epoch 00031: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0202 - outmap_loss: 0.0175 - outbin_loss: 0.2748 - outmap_dice_coef_batchwise: 0.2674 - outbin_acc: 0.8819 - val_loss: 0.0249 - val_outmap_loss: 0.0216 - val_outbin_loss: 0.3306 - val_outmap_dice_coef_batchwise: 0.2975 - val_outbin_acc: 0.8696
# Epoch 33/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0200 - outmap_loss: 0.0173 - outbin_loss: 0.2733 - outmap_dice_coef_batchwise: 0.2788 - outbin_acc: 0.8804Epoch 00032: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0200 - outmap_loss: 0.0173 - outbin_loss: 0.2729 - outmap_dice_coef_batchwise: 0.2788 - outbin_acc: 0.8808 - val_loss: 0.0245 - val_outmap_loss: 0.0212 - val_outbin_loss: 0.3292 - val_outmap_dice_coef_batchwise: 0.3049 - val_outbin_acc: 0.8747
# Epoch 34/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0196 - outmap_loss: 0.0170 - outbin_loss: 0.2638 - outmap_dice_coef_batchwise: 0.2806 - outbin_acc: 0.8908Epoch 00033: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0197 - outmap_loss: 0.0171 - outbin_loss: 0.2651 - outmap_dice_coef_batchwise: 0.2803 - outbin_acc: 0.8908 - val_loss: 0.0215 - val_outmap_loss: 0.0184 - val_outbin_loss: 0.3033 - val_outmap_dice_coef_batchwise: 0.3055 - val_outbin_acc: 0.8900
# Epoch 35/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0201 - outmap_loss: 0.0174 - outbin_loss: 0.2647 - outmap_dice_coef_batchwise: 0.2803 - outbin_acc: 0.8885Epoch 00034: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0200 - outmap_loss: 0.0174 - outbin_loss: 0.2641 - outmap_dice_coef_batchwise: 0.2795 - outbin_acc: 0.8890 - val_loss: 0.0217 - val_outmap_loss: 0.0185 - val_outbin_loss: 0.3253 - val_outmap_dice_coef_batchwise: 0.2648 - val_outbin_acc: 0.8875
# Epoch 36/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0196 - outmap_loss: 0.0171 - outbin_loss: 0.2547 - outmap_dice_coef_batchwise: 0.2820 - outbin_acc: 0.8956Epoch 00035: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0196 - outmap_loss: 0.0171 - outbin_loss: 0.2547 - outmap_dice_coef_batchwise: 0.2819 - outbin_acc: 0.8956 - val_loss: 0.0257 - val_outmap_loss: 0.0224 - val_outbin_loss: 0.3243 - val_outmap_dice_coef_batchwise: 0.3178 - val_outbin_acc: 0.8696
# Epoch 37/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0196 - outmap_loss: 0.0170 - outbin_loss: 0.2527 - outmap_dice_coef_batchwise: 0.2807 - outbin_acc: 0.8908Epoch 00036: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0196 - outmap_loss: 0.0171 - outbin_loss: 0.2551 - outmap_dice_coef_batchwise: 0.2809 - outbin_acc: 0.8899 - val_loss: 0.0217 - val_outmap_loss: 0.0187 - val_outbin_loss: 0.3059 - val_outmap_dice_coef_batchwise: 0.3151 - val_outbin_acc: 0.8900
# Epoch 38/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0195 - outmap_loss: 0.0169 - outbin_loss: 0.2615 - outmap_dice_coef_batchwise: 0.2829 - outbin_acc: 0.8911Epoch 00037: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0195 - outmap_loss: 0.0169 - outbin_loss: 0.2623 - outmap_dice_coef_batchwise: 0.2831 - outbin_acc: 0.8908 - val_loss: 0.0216 - val_outmap_loss: 0.0184 - val_outbin_loss: 0.3186 - val_outmap_dice_coef_batchwise: 0.2936 - val_outbin_acc: 0.8900
# Epoch 39/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0192 - outmap_loss: 0.0167 - outbin_loss: 0.2519 - outmap_dice_coef_batchwise: 0.2851 - outbin_acc: 0.8942Epoch 00038: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0192 - outmap_loss: 0.0167 - outbin_loss: 0.2508 - outmap_dice_coef_batchwise: 0.2860 - outbin_acc: 0.8947 - val_loss: 0.0215 - val_outmap_loss: 0.0187 - val_outbin_loss: 0.2833 - val_outmap_dice_coef_batchwise: 0.3040 - val_outbin_acc: 0.9054
# Epoch 40/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0188 - outmap_loss: 0.0164 - outbin_loss: 0.2461 - outmap_dice_coef_batchwise: 0.2968 - outbin_acc: 0.8928Epoch 00039: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0189 - outmap_loss: 0.0164 - outbin_loss: 0.2467 - outmap_dice_coef_batchwise: 0.2970 - outbin_acc: 0.8922 - val_loss: 0.0213 - val_outmap_loss: 0.0183 - val_outbin_loss: 0.3057 - val_outmap_dice_coef_batchwise: 0.2957 - val_outbin_acc: 0.8824
# Epoch 41/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0190 - outmap_loss: 0.0165 - outbin_loss: 0.2469 - outmap_dice_coef_batchwise: 0.2924 - outbin_acc: 0.8962Epoch 00040: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0190 - outmap_loss: 0.0165 - outbin_loss: 0.2477 - outmap_dice_coef_batchwise: 0.2925 - outbin_acc: 0.8959 - val_loss: 0.0221 - val_outmap_loss: 0.0192 - val_outbin_loss: 0.2904 - val_outmap_dice_coef_batchwise: 0.2988 - val_outbin_acc: 0.8875
# Epoch 42/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0191 - outmap_loss: 0.0166 - outbin_loss: 0.2496 - outmap_dice_coef_batchwise: 0.2904 - outbin_acc: 0.8942Epoch 00041: val_loss improved from 0.02116 to 0.02081, saving model to weights.hdf5
# 3515/3515 [==============================] - 26s - loss: 0.0191 - outmap_loss: 0.0166 - outbin_loss: 0.2490 - outmap_dice_coef_batchwise: 0.2900 - outbin_acc: 0.8945 - val_loss: 0.0208 - val_outmap_loss: 0.0178 - val_outbin_loss: 0.3030 - val_outmap_dice_coef_batchwise: 0.2765 - val_outbin_acc: 0.8900
# Epoch 43/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0188 - outmap_loss: 0.0164 - outbin_loss: 0.2402 - outmap_dice_coef_batchwise: 0.2950 - outbin_acc: 0.8991Epoch 00042: val_loss did not improve
# 3515/3515 [==============================] - 25s - loss: 0.0187 - outmap_loss: 0.0163 - outbin_loss: 0.2392 - outmap_dice_coef_batchwise: 0.2951 - outbin_acc: 0.8996 - val_loss: 0.0255 - val_outmap_loss: 0.0211 - val_outbin_loss: 0.4357 - val_outmap_dice_coef_batchwise: 0.3258 - val_outbin_acc: 0.8286
# Epoch 44/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0188 - outmap_loss: 0.0165 - outbin_loss: 0.2383 - outmap_dice_coef_batchwise: 0.2993 - outbin_acc: 0.8948Epoch 00043: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0188 - outmap_loss: 0.0164 - outbin_loss: 0.2381 - outmap_dice_coef_batchwise: 0.2995 - outbin_acc: 0.8953 - val_loss: 0.0216 - val_outmap_loss: 0.0187 - val_outbin_loss: 0.2886 - val_outmap_dice_coef_batchwise: 0.3082 - val_outbin_acc: 0.8900
# Epoch 45/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0188 - outmap_loss: 0.0164 - outbin_loss: 0.2401 - outmap_dice_coef_batchwise: 0.2997 - outbin_acc: 0.8976Epoch 00044: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0188 - outmap_loss: 0.0164 - outbin_loss: 0.2396 - outmap_dice_coef_batchwise: 0.2997 - outbin_acc: 0.8982 - val_loss: 0.0213 - val_outmap_loss: 0.0183 - val_outbin_loss: 0.3020 - val_outmap_dice_coef_batchwise: 0.2945 - val_outbin_acc: 0.8772
# Epoch 46/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0187 - outmap_loss: 0.0163 - outbin_loss: 0.2415 - outmap_dice_coef_batchwise: 0.3100 - outbin_acc: 0.8974Epoch 00045: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0186 - outmap_loss: 0.0162 - outbin_loss: 0.2407 - outmap_dice_coef_batchwise: 0.3093 - outbin_acc: 0.8979 - val_loss: 0.0211 - val_outmap_loss: 0.0183 - val_outbin_loss: 0.2870 - val_outmap_dice_coef_batchwise: 0.2519 - val_outbin_acc: 0.8951
# Epoch 47/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0185 - outmap_loss: 0.0163 - outbin_loss: 0.2265 - outmap_dice_coef_batchwise: 0.3008 - outbin_acc: 0.9025Epoch 00046: val_loss did not improve
# 3515/3515 [==============================] - 25s - loss: 0.0185 - outmap_loss: 0.0162 - outbin_loss: 0.2270 - outmap_dice_coef_batchwise: 0.3004 - outbin_acc: 0.9021 - val_loss: 0.0231 - val_outmap_loss: 0.0200 - val_outbin_loss: 0.3140 - val_outmap_dice_coef_batchwise: 0.3230 - val_outbin_acc: 0.8900
# Epoch 48/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0186 - outmap_loss: 0.0163 - outbin_loss: 0.2313 - outmap_dice_coef_batchwise: 0.3063 - outbin_acc: 0.8999Epoch 00047: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0186 - outmap_loss: 0.0163 - outbin_loss: 0.2308 - outmap_dice_coef_batchwise: 0.3062 - outbin_acc: 0.9004 - val_loss: 0.0254 - val_outmap_loss: 0.0218 - val_outbin_loss: 0.3549 - val_outmap_dice_coef_batchwise: 0.3479 - val_outbin_acc: 0.8670
# Epoch 49/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0183 - outmap_loss: 0.0161 - outbin_loss: 0.2232 - outmap_dice_coef_batchwise: 0.3069 - outbin_acc: 0.9060Epoch 00048: val_loss did not improve
# 3515/3515 [==============================] - 25s - loss: 0.0183 - outmap_loss: 0.0161 - outbin_loss: 0.2224 - outmap_dice_coef_batchwise: 0.3061 - outbin_acc: 0.9064 - val_loss: 0.0215 - val_outmap_loss: 0.0183 - val_outbin_loss: 0.3250 - val_outmap_dice_coef_batchwise: 0.2734 - val_outbin_acc: 0.8977
# Epoch 50/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0183 - outmap_loss: 0.0160 - outbin_loss: 0.2302 - outmap_dice_coef_batchwise: 0.3100 - outbin_acc: 0.9002Epoch 00049: val_loss did not improve
# 3515/3515 [==============================] - 25s - loss: 0.0183 - outmap_loss: 0.0160 - outbin_loss: 0.2311 - outmap_dice_coef_batchwise: 0.3103 - outbin_acc: 0.8993 - val_loss: 0.0215 - val_outmap_loss: 0.0184 - val_outbin_loss: 0.3090 - val_outmap_dice_coef_batchwise: 0.3209 - val_outbin_acc: 0.8875
# Epoch 51/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0177 - outmap_loss: 0.0155 - outbin_loss: 0.2141 - outmap_dice_coef_batchwise: 0.3217 - outbin_acc: 0.9100Epoch 00050: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0176 - outmap_loss: 0.0155 - outbin_loss: 0.2149 - outmap_dice_coef_batchwise: 0.3212 - outbin_acc: 0.9092 - val_loss: 0.0213 - val_outmap_loss: 0.0182 - val_outbin_loss: 0.3092 - val_outmap_dice_coef_batchwise: 0.3130 - val_outbin_acc: 0.8747
# Epoch 52/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0177 - outmap_loss: 0.0156 - outbin_loss: 0.2093 - outmap_dice_coef_batchwise: 0.3225 - outbin_acc: 0.9117Epoch 00051: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0177 - outmap_loss: 0.0156 - outbin_loss: 0.2094 - outmap_dice_coef_batchwise: 0.3224 - outbin_acc: 0.9115 - val_loss: 0.0213 - val_outmap_loss: 0.0182 - val_outbin_loss: 0.3088 - val_outmap_dice_coef_batchwise: 0.2832 - val_outbin_acc: 0.8670
# Epoch 53/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0177 - outmap_loss: 0.0156 - outbin_loss: 0.2157 - outmap_dice_coef_batchwise: 0.3257 - outbin_acc: 0.9068Epoch 00052: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0177 - outmap_loss: 0.0156 - outbin_loss: 0.2159 - outmap_dice_coef_batchwise: 0.3258 - outbin_acc: 0.9061 - val_loss: 0.0215 - val_outmap_loss: 0.0182 - val_outbin_loss: 0.3296 - val_outmap_dice_coef_batchwise: 0.2602 - val_outbin_acc: 0.8721
# Epoch 54/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0176 - outmap_loss: 0.0155 - outbin_loss: 0.2081 - outmap_dice_coef_batchwise: 0.3271 - outbin_acc: 0.9080Epoch 00053: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0176 - outmap_loss: 0.0155 - outbin_loss: 0.2074 - outmap_dice_coef_batchwise: 0.3270 - outbin_acc: 0.9081 - val_loss: 0.0228 - val_outmap_loss: 0.0197 - val_outbin_loss: 0.3103 - val_outmap_dice_coef_batchwise: 0.3413 - val_outbin_acc: 0.8977
# Epoch 55/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0175 - outmap_loss: 0.0153 - outbin_loss: 0.2170 - outmap_dice_coef_batchwise: 0.3294 - outbin_acc: 0.9077Epoch 00054: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0174 - outmap_loss: 0.0153 - outbin_loss: 0.2160 - outmap_dice_coef_batchwise: 0.3298 - outbin_acc: 0.9084 - val_loss: 0.0208 - val_outmap_loss: 0.0181 - val_outbin_loss: 0.2772 - val_outmap_dice_coef_batchwise: 0.3300 - val_outbin_acc: 0.9105
# Epoch 56/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0175 - outmap_loss: 0.0154 - outbin_loss: 0.2050 - outmap_dice_coef_batchwise: 0.3364 - outbin_acc: 0.9194Epoch 00055: val_loss did not improve
# 3515/3515 [==============================] - 25s - loss: 0.0175 - outmap_loss: 0.0154 - outbin_loss: 0.2045 - outmap_dice_coef_batchwise: 0.3361 - outbin_acc: 0.9192 - val_loss: 0.0212 - val_outmap_loss: 0.0182 - val_outbin_loss: 0.3001 - val_outmap_dice_coef_batchwise: 0.3071 - val_outbin_acc: 0.8875
# Epoch 57/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0173 - outmap_loss: 0.0153 - outbin_loss: 0.1986 - outmap_dice_coef_batchwise: 0.3323 - outbin_acc: 0.9200Epoch 00056: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0173 - outmap_loss: 0.0153 - outbin_loss: 0.1977 - outmap_dice_coef_batchwise: 0.3327 - outbin_acc: 0.9203 - val_loss: 0.0226 - val_outmap_loss: 0.0192 - val_outbin_loss: 0.3381 - val_outmap_dice_coef_batchwise: 0.3356 - val_outbin_acc: 0.8951
# Epoch 58/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0172 - outmap_loss: 0.0152 - outbin_loss: 0.1989 - outmap_dice_coef_batchwise: 0.3342 - outbin_acc: 0.9149Epoch 00057: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0172 - outmap_loss: 0.0152 - outbin_loss: 0.1992 - outmap_dice_coef_batchwise: 0.3336 - outbin_acc: 0.9149 - val_loss: 0.0216 - val_outmap_loss: 0.0184 - val_outbin_loss: 0.3123 - val_outmap_dice_coef_batchwise: 0.2796 - val_outbin_acc: 0.8875
# Epoch 59/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0170 - outmap_loss: 0.0151 - outbin_loss: 0.1965 - outmap_dice_coef_batchwise: 0.3360 - outbin_acc: 0.9154Epoch 00058: val_loss did not improve
# 3515/3515 [==============================] - 26s - loss: 0.0171 - outmap_loss: 0.0151 - outbin_loss: 0.1965 - outmap_dice_coef_batchwise: 0.3356 - outbin_acc: 0.9155 - val_loss: 0.0221 - val_outmap_loss: 0.0190 - val_outbin_loss: 0.3115 - val_outmap_dice_coef_batchwise: 0.3479 - val_outbin_acc: 0.8900
# Epoch 60/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0174 - outmap_loss: 0.0153 - outbin_loss: 0.2096 - outmap_dice_coef_batchwise: 0.3384 - outbin_acc: 0.9137Epoch 00059: val_loss did not improve
# 3515/3515 [==============================] - 25s - loss: 0.0173 - outmap_loss: 0.0152 - outbin_loss: 0.2098 - outmap_dice_coef_batchwise: 0.3381 - outbin_acc: 0.9135 - val_loss: 0.0225 - val_outmap_loss: 0.0193 - val_outbin_loss: 0.3150 - val_outmap_dice_coef_batchwise: 0.3122 - val_outbin_acc: 0.8824

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights.hdf5'))

# %%
conv1 = model.layers[1].output
_f = K.function([K.learning_phase(), input_img], [conv1])
_convout = _f([0, X_test[:1]])[0]
print _convout.shape

maxout1 = model.layers[3].output
_f = K.function([K.learning_phase(), input_img], [maxout1])
_maxout = _f([0, X_test[:1]])[0]
print _maxout.shape

pl.figure()
pl.imshow(_convout[0, 0], interpolation='nearest')
pl.colorbar()
pl.figure()
pl.imshow(_maxout[0, 0], interpolation='nearest')
pl.colorbar()
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/backend/theano_backend.py:514: UserWarning: theano.function was asked to create a function computing outputs given certain inputs, but the provided input variable at index 0 is not part of the computational graph needed to compute the outputs: keras_learning_phase.
# To make this warning into an error, you can pass the parameter on_unused_input='raise' to theano.function. To disable it completely, use on_unused_input='ignore'.
#   **kwargs)
# (1, 8, 128, 128)
# (1, 8, 128, 128)
# <matplotlib.colorbar.Colorbar instance at 0x7f81a71c2d40>
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
def predict(X):
    Y_pred, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > 0.3
    for i in range(Y_pred.shape[0]):
        # Clear prediction where we detect to little pixels
        # Figure it out by
        # pl.hist(np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1))
        #if np.sum(Y_pred[i]) < 200 or Y_pred_binary[i] < 0.2:
        if np.sum(Y_pred[i]) < 200:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test)
Y_full_pred, Y_full_pred_proba, Y_full_pred_binary = predict(X_full)

reload(utils)
print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "test set average score : ", utils.average_dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
print "full set average score : ", utils.average_dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.707991451075
# test set average score :  0.84316468548
# full set score :  0.642994786962
# full set average score :  0.771840411185

# %%
if False:
    y_pred = K.placeholder(shape=Y_pred.shape)
    y_true = K.placeholder(shape=Y_test.shape)

    _dice_coef = K.function([y_true, y_pred], dice_coef_batchwise(y_true, y_pred))

    Y_pred, _, _ = predict(X_train)
    print _np_dice_coef(Y_train, Y_pred)
    print utils.average_dice_coefficient(Y_pred, Y_train)
    print _dice_coef([Y_train, Y_pred])

# %%
_ = pl.hist(Y_pred_binary)

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[:5]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 15
img, pred_map = dream_output(Y_full[i])
pl.figure(figsize=(12, 4))
pl.subplot(131)
pl.imshow(Y_full[i].squeeze())
pl.subplot(132)
pl.imshow(img, cmap=cm.gray)
pl.subplot(133)
pl.imshow(pred_map.squeeze())

# %%
# Dream for the binary output
def dream_binoutput(output):
    
    layer_output = layer_dict['outbin'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output - layer_output[:, 0]))
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    
    step = 0.1
    for i in range(40):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    _, model_pred = model.predict(img[None,None,:,:])
    return img, model_pred

img, model_pred = dream_binoutput(1)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
img, model_pred = dream_binoutput(0)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
def dream_layer_filter(layer_name, filter_index):

    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(8):
        pl.subplot(2, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
if True:
    import cv2
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(50,50))
    
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    test_fnames = _d['test_fnames']
    Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:])
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
        imre = cv2.morphologyEx(imre, cv2.MORPH_CLOSE, kernel)
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
        
        if i % 10 == 0:
            print '\r%d / %d' % (i, len(test_fnames)),
            sys.stdout.flush()
# Out:
# 5500 / 5508

# %% [markdown]
# ## Stats on predicted masks

# %%
# on Y_full
nbp_pixels = np.sum(np.sum(np.sum(Y_full, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
