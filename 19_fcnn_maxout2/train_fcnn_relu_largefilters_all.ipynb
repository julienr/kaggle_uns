# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):

# %%
_d = np.load('../data/data_128_train.npz')
X = _d['X']
Y = _d['Y']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
print X.shape
print Y.shape
# Out:
# (5635, 128, 128)
# (5635, 128, 128)

# %%
nsamples = X.shape[0]

train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
#train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.25)
X_train = X[train_indices][:,None,:,:]
Y_train_binary = Y_binary[train_indices][:,None]
Y_train = Y[train_indices][:,None,:,:]
X_test = X[test_indices][:,None,:,:]
Y_test_binary = Y_binary[test_indices][:,None]
Y_test = Y[test_indices][:,None,:,:]

# %%
print X_train.shape
print Y_train.shape
print Y_train_binary.shape
print X_train.min(), X_train.max()
# Out:
# (5071, 1, 128, 128)
# (5071, 1, 128, 128)
# (5071, 1)
# 0.0 1.0

# %%
#pl.imshow(X_train[0].squeeze())
pl.imshow(Y_train[0].squeeze())
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float32'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense, BatchNormalization
from keras.layers import LeakyReLU
from keras.models import Model
import keras.backend as K
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
input_img = Input(shape=input_shape, name='input_img')
x = Convolution2D(8, 7, 7, border_mode='same')(input_img)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.25)(x)
pool1 = x = MaxPooling2D((2, 2), name='pool1')(x)

x = Convolution2D(8, 5, 5, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
pool2 = x = MaxPooling2D((2, 2), name='pool2')(x)

x = Convolution2D(8, 5, 5, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
pool3 = x = MaxPooling2D((2, 2), name='pool3')(x)

# -- binary presence part
x = Convolution2D(8, 5, 5, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# -- location map
x = Convolution2D(8, 3, 3, border_mode='same')(pool5)
x = BatchNormalization()(x)
#x = Maxout2D(8, 2)(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool4], mode='concat', concat_axis=1)
x = Convolution2D(8, 5, 5, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool3], mode='concat', concat_axis=1)
x = Convolution2D(8, 5, 5, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Convolution2D(8, 5, 5, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Convolution2D(8, 7, 7, border_mode='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.1)(x)
x = UpSampling2D((2, 2))(x)

outmap = Convolution2D(1, 7, 7, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=outmap
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
#loss=[dice_coef_loss_batchwise, 'binary_crossentropy']
model.compile(optimizer='adam', loss='binary_crossentropy')

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_21 (Convolution2D)   (None, 8, 128, 128) 400         input_img[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_21 (BatchNormali(None, 8, 128, 128) 256         convolution2d_21[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_21 (LeakyReLU)           (None, 8, 128, 128) 0           batchnormalization_21[0][0]
# ____________________________________________________________________________________________________
# dropout_21 (Dropout)               (None, 8, 128, 128) 0           leakyrelu_21[0][0]
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)               (None, 8, 64, 64)   0           dropout_21[0][0]
# ____________________________________________________________________________________________________
# convolution2d_22 (Convolution2D)   (None, 8, 64, 64)   1608        pool1[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_22 (BatchNormali(None, 8, 64, 64)   128         convolution2d_22[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_22 (LeakyReLU)           (None, 8, 64, 64)   0           batchnormalization_22[0][0]
# ____________________________________________________________________________________________________
# dropout_22 (Dropout)               (None, 8, 64, 64)   0           leakyrelu_22[0][0]
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)               (None, 8, 32, 32)   0           dropout_22[0][0]
# ____________________________________________________________________________________________________
# convolution2d_23 (Convolution2D)   (None, 8, 32, 32)   1608        pool2[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_23 (BatchNormali(None, 8, 32, 32)   64          convolution2d_23[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_23 (LeakyReLU)           (None, 8, 32, 32)   0           batchnormalization_23[0][0]
# ____________________________________________________________________________________________________
# dropout_23 (Dropout)               (None, 8, 32, 32)   0           leakyrelu_23[0][0]
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)               (None, 8, 16, 16)   0           dropout_23[0][0]
# ____________________________________________________________________________________________________
# convolution2d_24 (Convolution2D)   (None, 8, 16, 16)   1608        pool3[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_24 (BatchNormali(None, 8, 16, 16)   32          convolution2d_24[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_24 (LeakyReLU)           (None, 8, 16, 16)   0           batchnormalization_24[0][0]
# ____________________________________________________________________________________________________
# dropout_24 (Dropout)               (None, 8, 16, 16)   0           leakyrelu_24[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)               (None, 8, 8, 8)     0           dropout_24[0][0]
# ____________________________________________________________________________________________________
# convolution2d_25 (Convolution2D)   (None, 8, 8, 8)     584         pool4[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_25 (BatchNormali(None, 8, 8, 8)     16          convolution2d_25[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_25 (LeakyReLU)           (None, 8, 8, 8)     0           batchnormalization_25[0][0]
# ____________________________________________________________________________________________________
# dropout_25 (Dropout)               (None, 8, 8, 8)     0           leakyrelu_25[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)               (None, 8, 4, 4)     0           dropout_25[0][0]
# ____________________________________________________________________________________________________
# convolution2d_26 (Convolution2D)   (None, 8, 4, 4)     584         pool5[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_26 (BatchNormali(None, 8, 4, 4)     8           convolution2d_26[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_26 (LeakyReLU)           (None, 8, 4, 4)     0           batchnormalization_26[0][0]
# ____________________________________________________________________________________________________
# dropout_26 (Dropout)               (None, 8, 4, 4)     0           leakyrelu_26[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_11 (UpSampling2D)     (None, 8, 8, 8)     0           dropout_26[0][0]
# ____________________________________________________________________________________________________
# merge_9 (Merge)                    (None, 16, 8, 8)    0           upsampling2d_11[0][0]
#                                                                    pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_27 (Convolution2D)   (None, 8, 8, 8)     3208        merge_9[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_27 (BatchNormali(None, 8, 8, 8)     16          convolution2d_27[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_27 (LeakyReLU)           (None, 8, 8, 8)     0           batchnormalization_27[0][0]
# ____________________________________________________________________________________________________
# dropout_27 (Dropout)               (None, 8, 8, 8)     0           leakyrelu_27[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_12 (UpSampling2D)     (None, 8, 16, 16)   0           dropout_27[0][0]
# ____________________________________________________________________________________________________
# merge_10 (Merge)                   (None, 16, 16, 16)  0           upsampling2d_12[0][0]
#                                                                    pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_28 (Convolution2D)   (None, 8, 16, 16)   3208        merge_10[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_28 (BatchNormali(None, 8, 16, 16)   32          convolution2d_28[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_28 (LeakyReLU)           (None, 8, 16, 16)   0           batchnormalization_28[0][0]
# ____________________________________________________________________________________________________
# dropout_28 (Dropout)               (None, 8, 16, 16)   0           leakyrelu_28[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_13 (UpSampling2D)     (None, 8, 32, 32)   0           dropout_28[0][0]
# ____________________________________________________________________________________________________
# merge_11 (Merge)                   (None, 16, 32, 32)  0           upsampling2d_13[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_29 (Convolution2D)   (None, 8, 32, 32)   3208        merge_11[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_29 (BatchNormali(None, 8, 32, 32)   64          convolution2d_29[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_29 (LeakyReLU)           (None, 8, 32, 32)   0           batchnormalization_29[0][0]
# ____________________________________________________________________________________________________
# dropout_29 (Dropout)               (None, 8, 32, 32)   0           leakyrelu_29[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_14 (UpSampling2D)     (None, 8, 64, 64)   0           dropout_29[0][0]
# ____________________________________________________________________________________________________
# merge_12 (Merge)                   (None, 16, 64, 64)  0           upsampling2d_14[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_30 (Convolution2D)   (None, 8, 64, 64)   6280        merge_12[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_30 (BatchNormali(None, 8, 64, 64)   128         convolution2d_30[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_30 (LeakyReLU)           (None, 8, 64, 64)   0           batchnormalization_30[0][0]
# ____________________________________________________________________________________________________
# dropout_30 (Dropout)               (None, 8, 64, 64)   0           leakyrelu_30[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_15 (UpSampling2D)     (None, 8, 128, 128) 0           dropout_30[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 393         upsampling2d_15[0][0]
# ====================================================================================================
# Total params: 23433
# ____________________________________________________________________________________________________

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        Y_train,
        batch_size=64,
        validation_data=(X_test, Y_test),
        nb_epoch=60,
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    pl.plot(history.history['loss'], label='train loss')
    pl.plot(history.history['val_loss'], c='g', label='val loss')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
        custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.05])
    
    print_summary(model.layers)
# Out:
# Train on 5071 samples, validate on 564 samples
# Epoch 1/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0933Epoch 00000: val_loss improved from inf to 0.07083, saving model to weights.hdf5
# 5071/5071 [==============================] - 41s - loss: 0.0931 - val_loss: 0.0708
# Epoch 2/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0426Epoch 00001: val_loss improved from 0.07083 to 0.05309, saving model to weights.hdf5
# 5071/5071 [==============================] - 41s - loss: 0.0425 - val_loss: 0.0531
# Epoch 3/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0347Epoch 00002: val_loss improved from 0.05309 to 0.05287, saving model to weights.hdf5
# 5071/5071 [==============================] - 40s - loss: 0.0347 - val_loss: 0.0529
# Epoch 4/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0321Epoch 00003: val_loss improved from 0.05287 to 0.05154, saving model to weights.hdf5
# 5071/5071 [==============================] - 40s - loss: 0.0321 - val_loss: 0.0515
# Epoch 5/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0301Epoch 00004: val_loss improved from 0.05154 to 0.04269, saving model to weights.hdf5
# 5071/5071 [==============================] - 40s - loss: 0.0301 - val_loss: 0.0427
# Epoch 6/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0294Epoch 00005: val_loss did not improve
# 5071/5071 [==============================] - 40s - loss: 0.0294 - val_loss: 0.0441
# Epoch 7/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0281Epoch 00006: val_loss improved from 0.04269 to 0.03942, saving model to weights.hdf5
# 5071/5071 [==============================] - 40s - loss: 0.0281 - val_loss: 0.0394
# Epoch 8/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0277Epoch 00007: val_loss did not improve
# 5071/5071 [==============================] - 40s - loss: 0.0277 - val_loss: 0.0407
# Epoch 9/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0272Epoch 00008: val_loss improved from 0.03942 to 0.03805, saving model to weights.hdf5
# 5071/5071 [==============================] - 42s - loss: 0.0271 - val_loss: 0.0380
# Epoch 10/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0265Epoch 00009: val_loss improved from 0.03805 to 0.03244, saving model to weights.hdf5
# 5071/5071 [==============================] - 40s - loss: 0.0264 - val_loss: 0.0324
# Epoch 11/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0262Epoch 00010: val_loss improved from 0.03244 to 0.02983, saving model to weights.hdf5
# 5071/5071 [==============================] - 40s - loss: 0.0262 - val_loss: 0.0298
# Epoch 12/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0255Epoch 00011: val_loss improved from 0.02983 to 0.02892, saving model to weights.hdf5
# 5071/5071 [==============================] - 40s - loss: 0.0255 - val_loss: 0.0289
# Epoch 13/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0253Epoch 00012: val_loss improved from 0.02892 to 0.02834, saving model to weights.hdf5
# 5071/5071 [==============================] - 40s - loss: 0.0253 - val_loss: 0.0283
# Epoch 14/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0249Epoch 00013: val_loss improved from 0.02834 to 0.02756, saving model to weights.hdf5
# 5071/5071 [==============================] - 40s - loss: 0.0249 - val_loss: 0.0276
# Epoch 15/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0247Epoch 00014: val_loss improved from 0.02756 to 0.02745, saving model to weights.hdf5
# 5071/5071 [==============================] - 40s - loss: 0.0247 - val_loss: 0.0275
# Epoch 16/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0243Epoch 00015: val_loss did not improve
# 5071/5071 [==============================] - 39s - loss: 0.0244 - val_loss: 0.0368
# Epoch 17/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0242Epoch 00016: val_loss did not improve
# 5071/5071 [==============================] - 39s - loss: 0.0242 - val_loss: 0.0308
# Epoch 18/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0238Epoch 00017: val_loss did not improve
# 5071/5071 [==============================] - 39s - loss: 0.0238 - val_loss: 0.0321
# Epoch 19/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0235Epoch 00018: val_loss did not improve
# 5071/5071 [==============================] - 39s - loss: 0.0235 - val_loss: 0.0350
# Epoch 20/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0234Epoch 00019: val_loss did not improve
# 5071/5071 [==============================] - 39s - loss: 0.0234 - val_loss: 0.0275
# Epoch 21/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0230Epoch 00020: val_loss did not improve
# 5071/5071 [==============================] - 39s - loss: 0.0230 - val_loss: 0.0278
# Epoch 22/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0230Epoch 00021: val_loss did not improve
# 5071/5071 [==============================] - 39s - loss: 0.0230 - val_loss: 0.0363
# Epoch 23/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0228Epoch 00022: val_loss improved from 0.02745 to 0.02633, saving model to weights.hdf5
# 5071/5071 [==============================] - 39s - loss: 0.0228 - val_loss: 0.0263
# Epoch 24/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0227Epoch 00023: val_loss did not improve
# 5071/5071 [==============================] - 39s - loss: 0.0227 - val_loss: 0.0344
# Epoch 25/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0226Epoch 00024: val_loss did not improve
# 5071/5071 [==============================] - 39s - loss: 0.0227 - val_loss: 0.0299
# Epoch 26/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0225Epoch 00025: val_loss did not improve
# 5071/5071 [==============================] - 39s - loss: 0.0225 - val_loss: 0.0303
# Epoch 27/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0223Epoch 00026: val_loss did not improve
# 5071/5071 [==============================] - 39s - loss: 0.0222 - val_loss: 0.0360
# Epoch 28/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0225Epoch 00027: val_loss improved from 0.02633 to 0.02589, saving model to weights.hdf5
# 5071/5071 [==============================] - 40s - loss: 0.0225 - val_loss: 0.0259
# Epoch 29/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0220Epoch 00028: val_loss did not improve
# 5071/5071 [==============================] - 41s - loss: 0.0219 - val_loss: 0.0296
# Epoch 30/60
# 5056/5071 [============================>.] - ETA: 0s - loss: 0.0221Epoch 00029: val_loss did not improve
# 5071/5071 [==============================] - 41s - loss: 0.0221 - val_loss: 0.0334
# Epoch 31/60
# 3776/5071 [=====================>........] - ETA: 10s - loss: 0.0220
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-29cc27df3d4e> in <module>()
#      13         verbose=1,
#      14         shuffle=True,
# ---> 15         callbacks=[model_checkpoint]
#      16     )
#      17     pl.plot(history.history['loss'], label='train loss')
#
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight)
#    1050                               verbose=verbose, callbacks=callbacks,
#    1051                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
# -> 1052                               callback_metrics=callback_metrics)
#    1053
#    1054     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, nb_epoch, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics)
#     788                 batch_logs['size'] = len(batch_ids)
#     789                 callbacks.on_batch_begin(batch_index, batch_logs)
# --> 790                 outs = f(ins_batch)
#     791                 if type(outs) != list:
#     792                     outs = [outs]
#
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/backend/theano_backend.pyc in __call__(self, inputs)
#     516     def __call__(self, inputs):
#     517         assert type(inputs) in {list, tuple}
# --> 518         return self.function(*inputs)
#     519
#     520
#
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# KeyboardInterrupt:

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights.hdf5'))

# %%
conv1 = model.layers[1].output
_f = K.function([K.learning_phase(), input_img], [conv1])
_convout = _f([0, X_test[:1]])[0]
print _convout.shape

maxout1 = model.layers[3].output
_f = K.function([K.learning_phase(), input_img], [maxout1])
_maxout = _f([0, X_test[:1]])[0]
print _maxout.shape

pl.figure()
pl.imshow(_convout[0, 0], interpolation='nearest')
pl.colorbar()
pl.figure()
pl.imshow(_maxout[0, 0], interpolation='nearest')
pl.colorbar()
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/backend/theano_backend.py:514: UserWarning: theano.function was asked to create a function computing outputs given certain inputs, but the provided input variable at index 0 is not part of the computational graph needed to compute the outputs: keras_learning_phase.
# To make this warning into an error, you can pass the parameter on_unused_input='raise' to theano.function. To disable it completely, use on_unused_input='ignore'.
#   **kwargs)
# (1, 8, 128, 128)
# (1, 8, 128, 128)
# <matplotlib.colorbar.Colorbar instance at 0x7f222a332c20>
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
def predict(X):
    Y_pred = model.predict(X)
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > 0.3
    for i in range(Y_pred.shape[0]):
        # Clear prediction where we detect to little pixels
        # Figure it out by
        # pl.hist(np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1))
        if np.sum(Y_pred[i]) < 200:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba

Y_pred, Y_pred_proba = predict(X_test)

reload(utils)
print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "test set average score : ", utils.average_dice_coefficient(Y_pred, Y_test)
# Out:
# test set score :  0.491342474009
# test set average score :  0.707251395982

# %%
if False:
    y_pred = K.placeholder(shape=Y_pred.shape)
    y_true = K.placeholder(shape=Y_test.shape)

    _dice_coef = K.function([y_true, y_pred], dice_coef_batchwise(y_true, y_pred))

    Y_pred, _, _ = predict(X_train)
    print _np_dice_coef(Y_train, Y_pred)
    print utils.average_dice_coefficient(Y_pred, Y_train)
    print _dice_coef([Y_train, Y_pred])

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[60:65]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 15
img, pred_map = dream_output(Y_test[i])
pl.figure(figsize=(12, 4))
pl.subplot(131)
pl.imshow(Y_full[i].squeeze())
pl.subplot(132)
pl.imshow(img, cmap=cm.gray)
pl.subplot(133)
pl.imshow(pred_map.squeeze())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-0a4e60239b18> in <module>()
#      36
#      37 i = 15
# ---> 38 img, pred_map = dream_output(Y_test[i])
#      39 pl.figure(figsize=(12, 4))
#      40 pl.subplot(131)
#
# <ipython-input-36-0a4e60239b18> in dream_output(output)
#      32     img = input_img_data[0].squeeze()
#      33     # run the image through the model to get prediction
# ---> 34     pred_map, binary_pred = model.predict(img[None,None,:,:])
#      35     return img, pred_map
#      36
#
# ValueError: need more than 1 value to unpack

# %%
# Dream for the binary output
def dream_binoutput(output):
    
    layer_output = layer_dict['outbin'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output - layer_output[:, 0]))
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    _, model_pred = model.predict(img[None,None,:,:])
    return img, model_pred

img, model_pred = dream_binoutput(1)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
img, model_pred = dream_binoutput(0)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
def dream_layer_filter(layer_name, filter_index):

    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(8):
        pl.subplot(2, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
if True:
    import cv2
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(50,50))
    
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    test_fnames = _d['test_fnames']
    Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:])
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
        imre = cv2.morphologyEx(imre, cv2.MORPH_CLOSE, kernel)
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
        
        if i % 10 == 0:
            print '\r%d / %d' % (i, len(test_fnames)),
            sys.stdout.flush()
# Out:
# 5500 / 5508

# %% [markdown]
# ## Stats on predicted masks

# %%
# on Y_full
nbp_pixels = np.sum(np.sum(np.sum(Y_full, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
