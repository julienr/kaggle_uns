# %% [markdown]
# ## FCNN with a boolean output indicating the likelihood of the image containing nerve

# %% [markdown]
# This is submission 6, got 0.67

# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
# Out:
# (3906, 128, 128)
# (3906, 128, 128)

# %%
nsamples = X.shape[0]

train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
#train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.25)
X_train = X[train_indices][:,None,:,:]
Y_train_binary = Y_binary[train_indices][:,None]
Y_train = Y[train_indices][:,None,:,:]
X_test = X[test_indices][:,None,:,:]
Y_test_binary = Y_binary[test_indices][:,None]
Y_test = Y[test_indices][:,None,:,:]

# %%
print X_train.shape
print Y_train.shape
print Y_train_binary.shape
print X_train.min(), X_train.max()
# Out:
# (3515, 1, 128, 128)
# (3515, 1, 128, 128)
# (3515, 1)
# 0.0 1.0

# %%
#pl.imshow(X_train[0].squeeze())
pl.imshow(Y_train[0].squeeze())
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float16'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense, BatchNormalization
from keras.layers import LeakyReLU
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
from keras.layers import Layer, InputSpec
import keras.initializations
import keras.backend as K

class Maxout2D(Layer):
    def __init__(self, output_dim, cardinality, init='glorot_uniform', **kwargs):
        super(Maxout2D, self).__init__(**kwargs)
        # the k of the maxout paper
        self.cardinality = cardinality
        # the m of the maxout paper
        self.output_dim = output_dim
        self.init = keras.initializations.get(init)
    
    def build(self, input_shape):
        self.input_dim = input_shape[1]
        self.input_spec = [InputSpec(dtype=K.floatx(),
                                     shape=(None, input_shape[1], input_shape[2], input_shape[3]))]
        self.W = self.init((self.input_dim, self.output_dim, self.cardinality),
                           name='{}_W'.format(self.name))
        self.b = K.zeros((self.output_dim, self.cardinality))
        self.trainable_weights = [self.W, self.b]
              
    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        # flatten the spatial dimensions
        flat_x = K.reshape(x, (-1, input_shape[1], input_shape[2] * input_shape[3]))
        output = K.dot(
            K.permute_dimensions(flat_x, (0, 2, 1)),
            K.permute_dimensions(self.W, (1, 0, 2))
        )
        output += K.reshape(self.b, (1, 1, self.output_dim, self.cardinality))
        output = K.max(output, axis=3)
        output = output.transpose(0, 2, 1)
        output = K.reshape(output, (-1, self.output_dim, input_shape[2], input_shape[3]))
        return output
    
    def get_output_shape_for(self, input_shape):
        return (input_shape[0], self.output_dim, input_shape[2], input_shape[3])
    
    def get_config(self):
        config = {
            'output_dim': self.output_dim,
            'cardinality': self.cardinality
        }
        base_config = super(Maxout2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))
    
input_img = Input(shape=(3, 16, 16))
x = Convolution2D(16, 3, 3, border_mode='same')(input_img)
x = Maxout2D(5, 7)(x)

model = Model(input=input_img, output=x)
model.compile(optimizer='adam', loss='mse')
print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)               (None, 3, 16, 16)   0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)    (None, 16, 16, 16)  448         input_1[0][0]
# ____________________________________________________________________________________________________
# maxout2d_1 (Maxout2D)              (None, 5, 16, 16)   595         convolution2d_1[0][0]
# ====================================================================================================
# Total params: 1043
# ____________________________________________________________________________________________________

# %%
# https://www.kaggle.com/c/ultrasound-nerve-segmentation/forums/t/21358/0-57-deep-learning-keras-tutorial
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def dice_coef_batchwise(y_true, y_pred):
    y_true_f = K.batch_flatten(y_true)
    y_pred_f = K.batch_flatten(y_pred)
    intersection = 2. * K.sum(y_true_f * y_pred_f, axis=1, keepdims=True) + smooth
    union = K.sum(y_true_f, axis=1, keepdims=True) + \
            K.sum(y_pred_f, axis=1, keepdims=True) + \
            smooth
    return K.mean(intersection / union)

def dice_coef_loss_batchwise(y_true, y_pred):
    return 1.0 - dice_coef_batchwise(y_true, y_pred)

# %%
input_img = Input(shape=input_shape, name='input_img')
x = Convolution2D(8, 3, 3, border_mode='same')(input_img)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = Dropout(0.25)(x)
x = Maxout2D(8, 2)(x)
pool1 = x = MaxPooling2D((2, 2), name='pool1')(x)

x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = Dropout(0.1)(x)
x = Maxout2D(8, 2)(x)
pool2 = x = MaxPooling2D((2, 2), name='pool2')(x)

x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = Dropout(0.1)(x)
x = Maxout2D(8, 2)(x)
pool3 = x = MaxPooling2D((2, 2), name='pool3')(x)

# -- binary presence part
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = Dropout(0.1)(x)
x = Maxout2D(8, 2)(x)
pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = Dropout(0.1)(x)
x = Maxout2D(8, 2)(x)
pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(x)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# -- location map
x = Convolution2D(8, 3, 3, border_mode='same')(pool5)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = Dropout(0.1)(x)
x = Maxout2D(8, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool4], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = Dropout(0.1)(x)
x = Maxout2D(8, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool3], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = Dropout(0.1)(x)
x = Maxout2D(8, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = Dropout(0.1)(x)
x = Maxout2D(8, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = Dropout(0.1)(x)
x = Maxout2D(8, 2)(x)
x = UpSampling2D((2, 2))(x)

outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
loss='binary_crossentropy'
#loss=[dice_coef_loss_batchwise, 'binary_crossentropy']
metrics={'outmap': dice_coef_batchwise, 'outbin': 'accuracy'}
model.compile(optimizer='adam',
              loss=loss,
              loss_weights=[1., 0.01],
              metrics=metrics)

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_42 (Convolution2D)   (None, 8, 128, 128) 80          input_img[0][0]
# ____________________________________________________________________________________________________
# convolution2d_43 (Convolution2D)   (None, 8, 128, 128) 584         convolution2d_42[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_21 (BatchNormali(None, 8, 128, 128) 256         convolution2d_43[0][0]
# ____________________________________________________________________________________________________
# dropout_11 (Dropout)               (None, 8, 128, 128) 0           batchnormalization_21[0][0]
# ____________________________________________________________________________________________________
# maxout2d_22 (Maxout2D)             (None, 8, 128, 128) 144         dropout_11[0][0]
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)               (None, 8, 64, 64)   0           maxout2d_22[0][0]
# ____________________________________________________________________________________________________
# convolution2d_44 (Convolution2D)   (None, 8, 64, 64)   584         pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_45 (Convolution2D)   (None, 8, 64, 64)   584         convolution2d_44[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_22 (BatchNormali(None, 8, 64, 64)   128         convolution2d_45[0][0]
# ____________________________________________________________________________________________________
# dropout_12 (Dropout)               (None, 8, 64, 64)   0           batchnormalization_22[0][0]
# ____________________________________________________________________________________________________
# maxout2d_23 (Maxout2D)             (None, 8, 64, 64)   144         dropout_12[0][0]
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)               (None, 8, 32, 32)   0           maxout2d_23[0][0]
# ____________________________________________________________________________________________________
# convolution2d_46 (Convolution2D)   (None, 8, 32, 32)   584         pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_47 (Convolution2D)   (None, 8, 32, 32)   584         convolution2d_46[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_23 (BatchNormali(None, 8, 32, 32)   64          convolution2d_47[0][0]
# ____________________________________________________________________________________________________
# dropout_13 (Dropout)               (None, 8, 32, 32)   0           batchnormalization_23[0][0]
# ____________________________________________________________________________________________________
# maxout2d_24 (Maxout2D)             (None, 8, 32, 32)   144         dropout_13[0][0]
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)               (None, 8, 16, 16)   0           maxout2d_24[0][0]
# ____________________________________________________________________________________________________
# convolution2d_48 (Convolution2D)   (None, 8, 16, 16)   584         pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_49 (Convolution2D)   (None, 8, 16, 16)   584         convolution2d_48[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_24 (BatchNormali(None, 8, 16, 16)   32          convolution2d_49[0][0]
# ____________________________________________________________________________________________________
# dropout_14 (Dropout)               (None, 8, 16, 16)   0           batchnormalization_24[0][0]
# ____________________________________________________________________________________________________
# maxout2d_25 (Maxout2D)             (None, 8, 16, 16)   144         dropout_14[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)               (None, 8, 8, 8)     0           maxout2d_25[0][0]
# ____________________________________________________________________________________________________
# convolution2d_50 (Convolution2D)   (None, 8, 8, 8)     584         pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_51 (Convolution2D)   (None, 8, 8, 8)     584         convolution2d_50[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_25 (BatchNormali(None, 8, 8, 8)     16          convolution2d_51[0][0]
# ____________________________________________________________________________________________________
# dropout_15 (Dropout)               (None, 8, 8, 8)     0           batchnormalization_25[0][0]
# ____________________________________________________________________________________________________
# maxout2d_26 (Maxout2D)             (None, 8, 8, 8)     144         dropout_15[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)               (None, 8, 4, 4)     0           maxout2d_26[0][0]
# ____________________________________________________________________________________________________
# convolution2d_52 (Convolution2D)   (None, 8, 4, 4)     584         pool5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_53 (Convolution2D)   (None, 8, 4, 4)     584         convolution2d_52[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_26 (BatchNormali(None, 8, 4, 4)     8           convolution2d_53[0][0]
# ____________________________________________________________________________________________________
# dropout_16 (Dropout)               (None, 8, 4, 4)     0           batchnormalization_26[0][0]
# ____________________________________________________________________________________________________
# maxout2d_27 (Maxout2D)             (None, 8, 4, 4)     144         dropout_16[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_11 (UpSampling2D)     (None, 8, 8, 8)     0           maxout2d_27[0][0]
# ____________________________________________________________________________________________________
# merge_9 (Merge)                    (None, 16, 8, 8)    0           upsampling2d_11[0][0]
#                                                                    pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_54 (Convolution2D)   (None, 8, 8, 8)     1160        merge_9[0][0]
# ____________________________________________________________________________________________________
# convolution2d_55 (Convolution2D)   (None, 8, 8, 8)     584         convolution2d_54[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_27 (BatchNormali(None, 8, 8, 8)     16          convolution2d_55[0][0]
# ____________________________________________________________________________________________________
# dropout_17 (Dropout)               (None, 8, 8, 8)     0           batchnormalization_27[0][0]
# ____________________________________________________________________________________________________
# maxout2d_28 (Maxout2D)             (None, 8, 8, 8)     144         dropout_17[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_12 (UpSampling2D)     (None, 8, 16, 16)   0           maxout2d_28[0][0]
# ____________________________________________________________________________________________________
# merge_10 (Merge)                   (None, 16, 16, 16)  0           upsampling2d_12[0][0]
#                                                                    pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_56 (Convolution2D)   (None, 8, 16, 16)   1160        merge_10[0][0]
# ____________________________________________________________________________________________________
# convolution2d_57 (Convolution2D)   (None, 8, 16, 16)   584         convolution2d_56[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_28 (BatchNormali(None, 8, 16, 16)   32          convolution2d_57[0][0]
# ____________________________________________________________________________________________________
# dropout_18 (Dropout)               (None, 8, 16, 16)   0           batchnormalization_28[0][0]
# ____________________________________________________________________________________________________
# maxout2d_29 (Maxout2D)             (None, 8, 16, 16)   144         dropout_18[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_13 (UpSampling2D)     (None, 8, 32, 32)   0           maxout2d_29[0][0]
# ____________________________________________________________________________________________________
# merge_11 (Merge)                   (None, 16, 32, 32)  0           upsampling2d_13[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_58 (Convolution2D)   (None, 8, 32, 32)   1160        merge_11[0][0]
# ____________________________________________________________________________________________________
# convolution2d_59 (Convolution2D)   (None, 8, 32, 32)   584         convolution2d_58[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_29 (BatchNormali(None, 8, 32, 32)   64          convolution2d_59[0][0]
# ____________________________________________________________________________________________________
# dropout_19 (Dropout)               (None, 8, 32, 32)   0           batchnormalization_29[0][0]
# ____________________________________________________________________________________________________
# maxout2d_30 (Maxout2D)             (None, 8, 32, 32)   144         dropout_19[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_14 (UpSampling2D)     (None, 8, 64, 64)   0           maxout2d_30[0][0]
# ____________________________________________________________________________________________________
# merge_12 (Merge)                   (None, 16, 64, 64)  0           upsampling2d_14[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_60 (Convolution2D)   (None, 8, 64, 64)   1160        merge_12[0][0]
# ____________________________________________________________________________________________________
# convolution2d_61 (Convolution2D)   (None, 8, 64, 64)   584         convolution2d_60[0][0]
# ____________________________________________________________________________________________________
# flatten_3 (Flatten)                (None, 128)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_30 (BatchNormali(None, 8, 64, 64)   128         convolution2d_61[0][0]
# ____________________________________________________________________________________________________
# dense_5 (Dense)                    (None, 32)          4128        flatten_3[0][0]
# ____________________________________________________________________________________________________
# dropout_20 (Dropout)               (None, 8, 64, 64)   0           batchnormalization_30[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_5 (LeakyReLU)            (None, 32)          0           dense_5[0][0]
# ____________________________________________________________________________________________________
# dense_6 (Dense)                    (None, 16)          528         leakyrelu_5[0][0]
# ____________________________________________________________________________________________________
# maxout2d_31 (Maxout2D)             (None, 8, 64, 64)   144         dropout_20[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_6 (LeakyReLU)            (None, 16)          0           dense_6[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_15 (UpSampling2D)     (None, 8, 128, 128) 0           maxout2d_31[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_6[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 73          upsampling2d_15[0][0]
# ====================================================================================================
# Total params: 20410
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {'outmap': Y_train, 'outbin': Y_train_binary},
        batch_size=32,
        validation_data=(X_test, {'outmap': Y_test, 'outbin': Y_test_binary}),
        nb_epoch=60,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    pl.plot(history.history['loss'], label='train loss')
    pl.plot(history.history['val_loss'], c='g', label='val loss')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
        custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.05])
    
    print_summary(model.layers)
# Out:
# Train on 3515 samples, validate on 391 samples
# Epoch 1/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.1233 - outmap_loss: 0.1167 - outbin_loss: 0.6586 - outmap_dice_coef_batchwise: 0.0232 - outbin_acc: 0.6193Epoch 00000: val_loss improved from inf to 0.05781, saving model to weights.hdf5
# 3515/3515 [==============================] - 46s - loss: 0.1228 - outmap_loss: 0.1162 - outbin_loss: 0.6582 - outmap_dice_coef_batchwise: 0.0234 - outbin_acc: 0.6199 - val_loss: 0.0578 - val_outmap_loss: 0.0515 - val_outbin_loss: 0.6306 - val_outmap_dice_coef_batchwise: 0.0497 - val_outbin_acc: 0.6087
# Epoch 2/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0438 - outmap_loss: 0.0381 - outbin_loss: 0.5773 - outmap_dice_coef_batchwise: 0.0923 - outbin_acc: 0.7021Epoch 00001: val_loss improved from 0.05781 to 0.04922, saving model to weights.hdf5
# 3515/3515 [==============================] - 46s - loss: 0.0437 - outmap_loss: 0.0379 - outbin_loss: 0.5761 - outmap_dice_coef_batchwise: 0.0923 - outbin_acc: 0.7033 - val_loss: 0.0492 - val_outmap_loss: 0.0440 - val_outbin_loss: 0.5247 - val_outmap_dice_coef_batchwise: 0.0622 - val_outbin_acc: 0.7596
# Epoch 3/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0354 - outmap_loss: 0.0304 - outbin_loss: 0.5032 - outmap_dice_coef_batchwise: 0.1342 - outbin_acc: 0.7615Epoch 00002: val_loss improved from 0.04922 to 0.04272, saving model to weights.hdf5
# 3515/3515 [==============================] - 46s - loss: 0.0353 - outmap_loss: 0.0303 - outbin_loss: 0.5021 - outmap_dice_coef_batchwise: 0.1340 - outbin_acc: 0.7622 - val_loss: 0.0427 - val_outmap_loss: 0.0379 - val_outbin_loss: 0.4857 - val_outmap_dice_coef_batchwise: 0.0925 - val_outbin_acc: 0.8005
# Epoch 4/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0320 - outmap_loss: 0.0273 - outbin_loss: 0.4734 - outmap_dice_coef_batchwise: 0.1526 - outbin_acc: 0.7838Epoch 00003: val_loss improved from 0.04272 to 0.03381, saving model to weights.hdf5
# 3515/3515 [==============================] - 46s - loss: 0.0321 - outmap_loss: 0.0273 - outbin_loss: 0.4720 - outmap_dice_coef_batchwise: 0.1530 - outbin_acc: 0.7844 - val_loss: 0.0338 - val_outmap_loss: 0.0292 - val_outbin_loss: 0.4625 - val_outmap_dice_coef_batchwise: 0.1478 - val_outbin_acc: 0.8005
# Epoch 5/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0299 - outmap_loss: 0.0254 - outbin_loss: 0.4520 - outmap_dice_coef_batchwise: 0.1708 - outbin_acc: 0.7924Epoch 00004: val_loss did not improve
# 3515/3515 [==============================] - 46s - loss: 0.0299 - outmap_loss: 0.0254 - outbin_loss: 0.4516 - outmap_dice_coef_batchwise: 0.1705 - outbin_acc: 0.7926 - val_loss: 0.0348 - val_outmap_loss: 0.0305 - val_outbin_loss: 0.4264 - val_outmap_dice_coef_batchwise: 0.1590 - val_outbin_acc: 0.8082
# Epoch 6/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0287 - outmap_loss: 0.0243 - outbin_loss: 0.4399 - outmap_dice_coef_batchwise: 0.1773 - outbin_acc: 0.8025Epoch 00005: val_loss improved from 0.03381 to 0.03090, saving model to weights.hdf5
# 3515/3515 [==============================] - 47s - loss: 0.0288 - outmap_loss: 0.0244 - outbin_loss: 0.4410 - outmap_dice_coef_batchwise: 0.1770 - outbin_acc: 0.8014 - val_loss: 0.0309 - val_outmap_loss: 0.0267 - val_outbin_loss: 0.4187 - val_outmap_dice_coef_batchwise: 0.1748 - val_outbin_acc: 0.8414
# Epoch 7/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0274 - outmap_loss: 0.0232 - outbin_loss: 0.4208 - outmap_dice_coef_batchwise: 0.1885 - outbin_acc: 0.8139Epoch 00006: val_loss did not improve
# 3515/3515 [==============================] - 47s - loss: 0.0274 - outmap_loss: 0.0232 - outbin_loss: 0.4210 - outmap_dice_coef_batchwise: 0.1881 - outbin_acc: 0.8139 - val_loss: 0.0310 - val_outmap_loss: 0.0268 - val_outbin_loss: 0.4277 - val_outmap_dice_coef_batchwise: 0.1803 - val_outbin_acc: 0.8133
# Epoch 8/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0268 - outmap_loss: 0.0227 - outbin_loss: 0.4051 - outmap_dice_coef_batchwise: 0.1921 - outbin_acc: 0.8243Epoch 00007: val_loss improved from 0.03090 to 0.02962, saving model to weights.hdf5
# 3515/3515 [==============================] - 46s - loss: 0.0268 - outmap_loss: 0.0227 - outbin_loss: 0.4062 - outmap_dice_coef_batchwise: 0.1920 - outbin_acc: 0.8236 - val_loss: 0.0296 - val_outmap_loss: 0.0256 - val_outbin_loss: 0.3984 - val_outmap_dice_coef_batchwise: 0.2026 - val_outbin_acc: 0.8389
# Epoch 9/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0260 - outmap_loss: 0.0221 - outbin_loss: 0.3963 - outmap_dice_coef_batchwise: 0.1996 - outbin_acc: 0.8280Epoch 00008: val_loss did not improve
# 3515/3515 [==============================] - 46s - loss: 0.0260 - outmap_loss: 0.0221 - outbin_loss: 0.3964 - outmap_dice_coef_batchwise: 0.1994 - outbin_acc: 0.8279 - val_loss: 0.0308 - val_outmap_loss: 0.0267 - val_outbin_loss: 0.4167 - val_outmap_dice_coef_batchwise: 0.2081 - val_outbin_acc: 0.8082
# Epoch 10/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0256 - outmap_loss: 0.0217 - outbin_loss: 0.3919 - outmap_dice_coef_batchwise: 0.2035 - outbin_acc: 0.8306Epoch 00009: val_loss improved from 0.02962 to 0.02846, saving model to weights.hdf5
# 3515/3515 [==============================] - 46s - loss: 0.0256 - outmap_loss: 0.0217 - outbin_loss: 0.3917 - outmap_dice_coef_batchwise: 0.2040 - outbin_acc: 0.8310 - val_loss: 0.0285 - val_outmap_loss: 0.0238 - val_outbin_loss: 0.4628 - val_outmap_dice_coef_batchwise: 0.2096 - val_outbin_acc: 0.7928
# Epoch 11/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0252 - outmap_loss: 0.0214 - outbin_loss: 0.3804 - outmap_dice_coef_batchwise: 0.2082 - outbin_acc: 0.8326Epoch 00010: val_loss improved from 0.02846 to 0.02837, saving model to weights.hdf5
# 3515/3515 [==============================] - 46s - loss: 0.0252 - outmap_loss: 0.0214 - outbin_loss: 0.3794 - outmap_dice_coef_batchwise: 0.2082 - outbin_acc: 0.8336 - val_loss: 0.0284 - val_outmap_loss: 0.0243 - val_outbin_loss: 0.4106 - val_outmap_dice_coef_batchwise: 0.2147 - val_outbin_acc: 0.8210
# Epoch 12/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0247 - outmap_loss: 0.0210 - outbin_loss: 0.3722 - outmap_dice_coef_batchwise: 0.2105 - outbin_acc: 0.8426Epoch 00011: val_loss did not improve
# 3515/3515 [==============================] - 46s - loss: 0.0247 - outmap_loss: 0.0210 - outbin_loss: 0.3707 - outmap_dice_coef_batchwise: 0.2106 - outbin_acc: 0.8435 - val_loss: 0.0291 - val_outmap_loss: 0.0249 - val_outbin_loss: 0.4127 - val_outmap_dice_coef_batchwise: 0.2386 - val_outbin_acc: 0.8235
# Epoch 13/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0243 - outmap_loss: 0.0207 - outbin_loss: 0.3617 - outmap_dice_coef_batchwise: 0.2163 - outbin_acc: 0.8400Epoch 00012: val_loss did not improve
# 3515/3515 [==============================] - 46s - loss: 0.0244 - outmap_loss: 0.0208 - outbin_loss: 0.3629 - outmap_dice_coef_batchwise: 0.2163 - outbin_acc: 0.8395 - val_loss: 0.0290 - val_outmap_loss: 0.0248 - val_outbin_loss: 0.4168 - val_outmap_dice_coef_batchwise: 0.2504 - val_outbin_acc: 0.8261
# Epoch 14/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0238 - outmap_loss: 0.0202 - outbin_loss: 0.3605 - outmap_dice_coef_batchwise: 0.2225 - outbin_acc: 0.8452Epoch 00013: val_loss improved from 0.02837 to 0.02741, saving model to weights.hdf5
# 3515/3515 [==============================] - 46s - loss: 0.0237 - outmap_loss: 0.0201 - outbin_loss: 0.3598 - outmap_dice_coef_batchwise: 0.2226 - outbin_acc: 0.8455 - val_loss: 0.0274 - val_outmap_loss: 0.0233 - val_outbin_loss: 0.4099 - val_outmap_dice_coef_batchwise: 0.2390 - val_outbin_acc: 0.8312
# Epoch 15/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0238 - outmap_loss: 0.0202 - outbin_loss: 0.3549 - outmap_dice_coef_batchwise: 0.2221 - outbin_acc: 0.8483Epoch 00014: val_loss did not improve
# 3515/3515 [==============================] - 46s - loss: 0.0237 - outmap_loss: 0.0202 - outbin_loss: 0.3537 - outmap_dice_coef_batchwise: 0.2225 - outbin_acc: 0.8489 - val_loss: 0.0295 - val_outmap_loss: 0.0249 - val_outbin_loss: 0.4534 - val_outmap_dice_coef_batchwise: 0.2157 - val_outbin_acc: 0.8133
# Epoch 16/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0234 - outmap_loss: 0.0200 - outbin_loss: 0.3393 - outmap_dice_coef_batchwise: 0.2259 - outbin_acc: 0.8555Epoch 00015: val_loss did not improve
# 3515/3515 [==============================] - 46s - loss: 0.0234 - outmap_loss: 0.0200 - outbin_loss: 0.3396 - outmap_dice_coef_batchwise: 0.2255 - outbin_acc: 0.8552 - val_loss: 0.0274 - val_outmap_loss: 0.0236 - val_outbin_loss: 0.3809 - val_outmap_dice_coef_batchwise: 0.2563 - val_outbin_acc: 0.8414
# Epoch 17/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0232 - outmap_loss: 0.0197 - outbin_loss: 0.3460 - outmap_dice_coef_batchwise: 0.2288 - outbin_acc: 0.8535Epoch 00016: val_loss improved from 0.02741 to 0.02533, saving model to weights.hdf5
# 3515/3515 [==============================] - 46s - loss: 0.0232 - outmap_loss: 0.0197 - outbin_loss: 0.3450 - outmap_dice_coef_batchwise: 0.2288 - outbin_acc: 0.8543 - val_loss: 0.0253 - val_outmap_loss: 0.0218 - val_outbin_loss: 0.3574 - val_outmap_dice_coef_batchwise: 0.2462 - val_outbin_acc: 0.8670
# Epoch 18/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0228 - outmap_loss: 0.0194 - outbin_loss: 0.3420 - outmap_dice_coef_batchwise: 0.2339 - outbin_acc: 0.8555Epoch 00017: val_loss improved from 0.02533 to 0.02524, saving model to weights.hdf5
# 3515/3515 [==============================] - 46s - loss: 0.0228 - outmap_loss: 0.0194 - outbin_loss: 0.3410 - outmap_dice_coef_batchwise: 0.2334 - outbin_acc: 0.8558 - val_loss: 0.0252 - val_outmap_loss: 0.0209 - val_outbin_loss: 0.4329 - val_outmap_dice_coef_batchwise: 0.2435 - val_outbin_acc: 0.8184
# Epoch 19/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0225 - outmap_loss: 0.0192 - outbin_loss: 0.3345 - outmap_dice_coef_batchwise: 0.2350 - outbin_acc: 0.8521Epoch 00018: val_loss did not improve
# 3515/3515 [==============================] - 46s - loss: 0.0226 - outmap_loss: 0.0192 - outbin_loss: 0.3339 - outmap_dice_coef_batchwise: 0.2350 - outbin_acc: 0.8523 - val_loss: 0.0290 - val_outmap_loss: 0.0236 - val_outbin_loss: 0.5353 - val_outmap_dice_coef_batchwise: 0.2370 - val_outbin_acc: 0.7647
# Epoch 20/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0223 - outmap_loss: 0.0191 - outbin_loss: 0.3264 - outmap_dice_coef_batchwise: 0.2388 - outbin_acc: 0.8612Epoch 00019: val_loss did not improve
# 3515/3515 [==============================] - 46s - loss: 0.0223 - outmap_loss: 0.0191 - outbin_loss: 0.3255 - outmap_dice_coef_batchwise: 0.2388 - outbin_acc: 0.8617 - val_loss: 0.0270 - val_outmap_loss: 0.0231 - val_outbin_loss: 0.3853 - val_outmap_dice_coef_batchwise: 0.2675 - val_outbin_acc: 0.8465
# Epoch 21/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0225 - outmap_loss: 0.0192 - outbin_loss: 0.3203 - outmap_dice_coef_batchwise: 0.2352 - outbin_acc: 0.8641Epoch 00020: val_loss did not improve
# 3515/3515 [==============================] - 46s - loss: 0.0224 - outmap_loss: 0.0192 - outbin_loss: 0.3207 - outmap_dice_coef_batchwise: 0.2354 - outbin_acc: 0.8634 - val_loss: 0.0278 - val_outmap_loss: 0.0239 - val_outbin_loss: 0.3968 - val_outmap_dice_coef_batchwise: 0.2640 - val_outbin_acc: 0.8363
# Epoch 22/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0219 - outmap_loss: 0.0187 - outbin_loss: 0.3170 - outmap_dice_coef_batchwise: 0.2421 - outbin_acc: 0.8673Epoch 00021: val_loss did not improve
# 3515/3515 [==============================] - 46s - loss: 0.0218 - outmap_loss: 0.0187 - outbin_loss: 0.3169 - outmap_dice_coef_batchwise: 0.2420 - outbin_acc: 0.8671 - val_loss: 0.0264 - val_outmap_loss: 0.0218 - val_outbin_loss: 0.4617 - val_outmap_dice_coef_batchwise: 0.2773 - val_outbin_acc: 0.8056
# Epoch 23/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0218 - outmap_loss: 0.0186 - outbin_loss: 0.3173 - outmap_dice_coef_batchwise: 0.2446 - outbin_acc: 0.8698Epoch 00022: val_loss did not improve
# 3515/3515 [==============================] - 46s - loss: 0.0218 - outmap_loss: 0.0186 - outbin_loss: 0.3176 - outmap_dice_coef_batchwise: 0.2445 - outbin_acc: 0.8697 - val_loss: 0.0290 - val_outmap_loss: 0.0245 - val_outbin_loss: 0.4444 - val_outmap_dice_coef_batchwise: 0.2692 - val_outbin_acc: 0.8159
# Epoch 24/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0215 - outmap_loss: 0.0183 - outbin_loss: 0.3197 - outmap_dice_coef_batchwise: 0.2487 - outbin_acc: 0.8664Epoch 00023: val_loss did not improve
# 3515/3515 [==============================] - 46s - loss: 0.0217 - outmap_loss: 0.0185 - outbin_loss: 0.3208 - outmap_dice_coef_batchwise: 0.2490 - outbin_acc: 0.8657 - val_loss: 0.0336 - val_outmap_loss: 0.0294 - val_outbin_loss: 0.4181 - val_outmap_dice_coef_batchwise: 0.3414 - val_outbin_acc: 0.8542
# Epoch 25/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0216 - outmap_loss: 0.0185 - outbin_loss: 0.3102 - outmap_dice_coef_batchwise: 0.2460 - outbin_acc: 0.8658Epoch 00024: val_loss did not improve
# 3515/3515 [==============================] - 46s - loss: 0.0216 - outmap_loss: 0.0185 - outbin_loss: 0.3113 - outmap_dice_coef_batchwise: 0.2457 - outbin_acc: 0.8651 - val_loss: 0.0257 - val_outmap_loss: 0.0217 - val_outbin_loss: 0.3982 - val_outmap_dice_coef_batchwise: 0.2580 - val_outbin_acc: 0.8363
# Epoch 26/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0209 - outmap_loss: 0.0178 - outbin_loss: 0.3066 - outmap_dice_coef_batchwise: 0.2536 - outbin_acc: 0.8690Epoch 00025: val_loss did not improve
# 3515/3515 [==============================] - 46s - loss: 0.0210 - outmap_loss: 0.0179 - outbin_loss: 0.3081 - outmap_dice_coef_batchwise: 0.2539 - outbin_acc: 0.8688 - val_loss: 0.0262 - val_outmap_loss: 0.0221 - val_outbin_loss: 0.4185 - val_outmap_dice_coef_batchwise: 0.2694 - val_outbin_acc: 0.8363
# Epoch 27/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0208 - outmap_loss: 0.0177 - outbin_loss: 0.3058 - outmap_dice_coef_batchwise: 0.2581 - outbin_acc: 0.8701Epoch 00026: val_loss did not improve
# 3515/3515 [==============================] - 46s - loss: 0.0208 - outmap_loss: 0.0177 - outbin_loss: 0.3065 - outmap_dice_coef_batchwise: 0.2591 - outbin_acc: 0.8697 - val_loss: 0.0273 - val_outmap_loss: 0.0230 - val_outbin_loss: 0.4341 - val_outmap_dice_coef_batchwise: 0.2760 - val_outbin_acc: 0.8159
# Epoch 28/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0210 - outmap_loss: 0.0180 - outbin_loss: 0.3071 - outmap_dice_coef_batchwise: 0.2594 - outbin_acc: 0.8716Epoch 00027: val_loss did not improve
# 3515/3515 [==============================] - 46s - loss: 0.0210 - outmap_loss: 0.0180 - outbin_loss: 0.3067 - outmap_dice_coef_batchwise: 0.2588 - outbin_acc: 0.8717 - val_loss: 0.0253 - val_outmap_loss: 0.0212 - val_outbin_loss: 0.4060 - val_outmap_dice_coef_batchwise: 0.2734 - val_outbin_acc: 0.8363
# Epoch 29/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0210 - outmap_loss: 0.0180 - outbin_loss: 0.3074 - outmap_dice_coef_batchwise: 0.2580 - outbin_acc: 0.8750Epoch 00028: val_loss did not improve
# 3515/3515 [==============================] - 46s - loss: 0.0210 - outmap_loss: 0.0180 - outbin_loss: 0.3070 - outmap_dice_coef_batchwise: 0.2580 - outbin_acc: 0.8757 - val_loss: 0.0261 - val_outmap_loss: 0.0220 - val_outbin_loss: 0.4048 - val_outmap_dice_coef_batchwise: 0.2873 - val_outbin_acc: 0.8491
# Epoch 30/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0205 - outmap_loss: 0.0176 - outbin_loss: 0.2951 - outmap_dice_coef_batchwise: 0.2612 - outbin_acc: 0.8776Epoch 00029: val_loss did not improve
# 3515/3515 [==============================] - 46s - loss: 0.0205 - outmap_loss: 0.0176 - outbin_loss: 0.2943 - outmap_dice_coef_batchwise: 0.2614 - outbin_acc: 0.8782 - val_loss: 0.0253 - val_outmap_loss: 0.0216 - val_outbin_loss: 0.3698 - val_outmap_dice_coef_batchwise: 0.2991 - val_outbin_acc: 0.8619
# Epoch 31/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0202 - outmap_loss: 0.0173 - outbin_loss: 0.2929 - outmap_dice_coef_batchwise: 0.2672 - outbin_acc: 0.8779Epoch 00030: val_loss improved from 0.02524 to 0.02497, saving model to weights.hdf5
# 3515/3515 [==============================] - 46s - loss: 0.0202 - outmap_loss: 0.0173 - outbin_loss: 0.2945 - outmap_dice_coef_batchwise: 0.2665 - outbin_acc: 0.8774 - val_loss: 0.0250 - val_outmap_loss: 0.0211 - val_outbin_loss: 0.3847 - val_outmap_dice_coef_batchwise: 0.2877 - val_outbin_acc: 0.8440
# Epoch 32/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0201 - outmap_loss: 0.0172 - outbin_loss: 0.2925 - outmap_dice_coef_batchwise: 0.2745 - outbin_acc: 0.8784Epoch 00031: val_loss did not improve
# 3515/3515 [==============================] - 46s - loss: 0.0201 - outmap_loss: 0.0172 - outbin_loss: 0.2938 - outmap_dice_coef_batchwise: 0.2743 - outbin_acc: 0.8782 - val_loss: 0.0269 - val_outmap_loss: 0.0229 - val_outbin_loss: 0.4026 - val_outmap_dice_coef_batchwise: 0.2945 - val_outbin_acc: 0.8389
# Epoch 33/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0203 - outmap_loss: 0.0174 - outbin_loss: 0.2835 - outmap_dice_coef_batchwise: 0.2656 - outbin_acc: 0.8796Epoch 00032: val_loss did not improve
# 3515/3515 [==============================] - 47s - loss: 0.0202 - outmap_loss: 0.0174 - outbin_loss: 0.2827 - outmap_dice_coef_batchwise: 0.2657 - outbin_acc: 0.8799 - val_loss: 0.0261 - val_outmap_loss: 0.0221 - val_outbin_loss: 0.3955 - val_outmap_dice_coef_batchwise: 0.3201 - val_outbin_acc: 0.8619
# Epoch 34/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0200 - outmap_loss: 0.0172 - outbin_loss: 0.2794 - outmap_dice_coef_batchwise: 0.2691 - outbin_acc: 0.8836Epoch 00033: val_loss did not improve
# 3515/3515 [==============================] - 47s - loss: 0.0200 - outmap_loss: 0.0172 - outbin_loss: 0.2798 - outmap_dice_coef_batchwise: 0.2694 - outbin_acc: 0.8834 - val_loss: 0.0254 - val_outmap_loss: 0.0217 - val_outbin_loss: 0.3639 - val_outmap_dice_coef_batchwise: 0.3259 - val_outbin_acc: 0.8517
# Epoch 35/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0198 - outmap_loss: 0.0170 - outbin_loss: 0.2853 - outmap_dice_coef_batchwise: 0.2776 - outbin_acc: 0.8759Epoch 00034: val_loss did not improve
# 3515/3515 [==============================] - 47s - loss: 0.0198 - outmap_loss: 0.0170 - outbin_loss: 0.2851 - outmap_dice_coef_batchwise: 0.2781 - outbin_acc: 0.8760 - val_loss: 0.0252 - val_outmap_loss: 0.0214 - val_outbin_loss: 0.3859 - val_outmap_dice_coef_batchwise: 0.2901 - val_outbin_acc: 0.8389
# Epoch 36/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0200 - outmap_loss: 0.0171 - outbin_loss: 0.2927 - outmap_dice_coef_batchwise: 0.2777 - outbin_acc: 0.8787Epoch 00035: val_loss did not improve
# 3515/3515 [==============================] - 47s - loss: 0.0200 - outmap_loss: 0.0170 - outbin_loss: 0.2922 - outmap_dice_coef_batchwise: 0.2772 - outbin_acc: 0.8794 - val_loss: 0.0279 - val_outmap_loss: 0.0237 - val_outbin_loss: 0.4241 - val_outmap_dice_coef_batchwise: 0.3471 - val_outbin_acc: 0.8389
# Epoch 37/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0197 - outmap_loss: 0.0169 - outbin_loss: 0.2794 - outmap_dice_coef_batchwise: 0.2741 - outbin_acc: 0.8816Epoch 00036: val_loss did not improve
# 3515/3515 [==============================] - 47s - loss: 0.0196 - outmap_loss: 0.0169 - outbin_loss: 0.2786 - outmap_dice_coef_batchwise: 0.2741 - outbin_acc: 0.8822 - val_loss: 0.0258 - val_outmap_loss: 0.0221 - val_outbin_loss: 0.3668 - val_outmap_dice_coef_batchwise: 0.3349 - val_outbin_acc: 0.8619
# Epoch 38/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0196 - outmap_loss: 0.0169 - outbin_loss: 0.2730 - outmap_dice_coef_batchwise: 0.2738 - outbin_acc: 0.8859Epoch 00037: val_loss did not improve
# 3515/3515 [==============================] - 47s - loss: 0.0196 - outmap_loss: 0.0169 - outbin_loss: 0.2733 - outmap_dice_coef_batchwise: 0.2734 - outbin_acc: 0.8859 - val_loss: 0.0261 - val_outmap_loss: 0.0222 - val_outbin_loss: 0.3933 - val_outmap_dice_coef_batchwise: 0.3105 - val_outbin_acc: 0.8363
# Epoch 39/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0195 - outmap_loss: 0.0167 - outbin_loss: 0.2774 - outmap_dice_coef_batchwise: 0.2828 - outbin_acc: 0.8776Epoch 00038: val_loss did not improve
# 3515/3515 [==============================] - 47s - loss: 0.0195 - outmap_loss: 0.0167 - outbin_loss: 0.2776 - outmap_dice_coef_batchwise: 0.2829 - outbin_acc: 0.8777 - val_loss: 0.0260 - val_outmap_loss: 0.0222 - val_outbin_loss: 0.3797 - val_outmap_dice_coef_batchwise: 0.3093 - val_outbin_acc: 0.8363
# Epoch 40/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0192 - outmap_loss: 0.0165 - outbin_loss: 0.2711 - outmap_dice_coef_batchwise: 0.2821 - outbin_acc: 0.8847Epoch 00039: val_loss did not improve
# 3515/3515 [==============================] - 47s - loss: 0.0192 - outmap_loss: 0.0165 - outbin_loss: 0.2705 - outmap_dice_coef_batchwise: 0.2823 - outbin_acc: 0.8848 - val_loss: 0.0268 - val_outmap_loss: 0.0226 - val_outbin_loss: 0.4198 - val_outmap_dice_coef_batchwise: 0.3593 - val_outbin_acc: 0.8414
# Epoch 41/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0193 - outmap_loss: 0.0166 - outbin_loss: 0.2742 - outmap_dice_coef_batchwise: 0.2891 - outbin_acc: 0.8856Epoch 00040: val_loss did not improve
# 3515/3515 [==============================] - 47s - loss: 0.0195 - outmap_loss: 0.0167 - outbin_loss: 0.2770 - outmap_dice_coef_batchwise: 0.2890 - outbin_acc: 0.8851 - val_loss: 0.0262 - val_outmap_loss: 0.0221 - val_outbin_loss: 0.4152 - val_outmap_dice_coef_batchwise: 0.2987 - val_outbin_acc: 0.8440
# Epoch 42/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0191 - outmap_loss: 0.0163 - outbin_loss: 0.2729 - outmap_dice_coef_batchwise: 0.2878 - outbin_acc: 0.8847Epoch 00041: val_loss improved from 0.02497 to 0.02436, saving model to weights.hdf5
# 3515/3515 [==============================] - 47s - loss: 0.0191 - outmap_loss: 0.0163 - outbin_loss: 0.2734 - outmap_dice_coef_batchwise: 0.2880 - outbin_acc: 0.8845 - val_loss: 0.0244 - val_outmap_loss: 0.0206 - val_outbin_loss: 0.3788 - val_outmap_dice_coef_batchwise: 0.2950 - val_outbin_acc: 0.8465
# Epoch 43/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0195 - outmap_loss: 0.0168 - outbin_loss: 0.2716 - outmap_dice_coef_batchwise: 0.2787 - outbin_acc: 0.8839Epoch 00042: val_loss did not improve
# 3515/3515 [==============================] - 47s - loss: 0.0195 - outmap_loss: 0.0168 - outbin_loss: 0.2719 - outmap_dice_coef_batchwise: 0.2797 - outbin_acc: 0.8834 - val_loss: 0.0246 - val_outmap_loss: 0.0209 - val_outbin_loss: 0.3748 - val_outmap_dice_coef_batchwise: 0.2721 - val_outbin_acc: 0.8645
# Epoch 44/60
# 3488/3515 [============================>.] - ETA: 0s - loss: 0.0186 - outmap_loss: 0.0161 - outbin_loss: 0.2570 - outmap_dice_coef_batchwise: 0.2905 - outbin_acc: 0.8939Epoch 00043: val_loss did not improve
# 3515/3515 [==============================] - 47s - loss: 0.0186 - outmap_loss: 0.0160 - outbin_loss: 0.2571 - outmap_dice_coef_batchwise: 0.2898 - outbin_acc: 0.8936 - val_loss: 0.0247 - val_outmap_loss: 0.0212 - val_outbin_loss: 0.3541 - val_outmap_dice_coef_batchwise: 0.2961 - val_outbin_acc: 0.8670
# Epoch 45/60
# 3072/3515 [=========================>....] - ETA: 5s - loss: 0.0187 - outmap_loss: 0.0162 - outbin_loss: 0.2581 - outmap_dice_coef_batchwise: 0.2938 - outbin_acc: 0.8923
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-9409db5f3f90> in <module>()
#      13         verbose=1,
#      14         shuffle=True,
# ---> 15         callbacks=[model_checkpoint]
#      16     )
#      17     pl.plot(history.history['loss'], label='train loss')
#
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight)
#    1050                               verbose=verbose, callbacks=callbacks,
#    1051                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
# -> 1052                               callback_metrics=callback_metrics)
#    1053
#    1054     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, nb_epoch, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics)
#     788                 batch_logs['size'] = len(batch_ids)
#     789                 callbacks.on_batch_begin(batch_index, batch_logs)
# --> 790                 outs = f(ins_batch)
#     791                 if type(outs) != list:
#     792                     outs = [outs]
#
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/backend/theano_backend.pyc in __call__(self, inputs)
#     516     def __call__(self, inputs):
#     517         assert type(inputs) in {list, tuple}
# --> 518         return self.function(*inputs)
#     519
#     520
#
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/theano/gof/op.pyc in rval(p, i, o, n)
#     909         if params is graph.NoParams:
#     910             # default arguments are stored in the closure of `rval`
# --> 911             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
#     912                 r = p(n, [x[0] for x in i], o)
#     913                 for o in node.outputs:
#
# KeyboardInterrupt:

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights.hdf5'))

# %%
conv1 = model.layers[1].output
_f = K.function([K.learning_phase(), input_img], [conv1])
_convout = _f([0, X_test[:1]])[0]
print _convout.shape

maxout1 = model.layers[3].output
_f = K.function([K.learning_phase(), input_img], [maxout1])
_maxout = _f([0, X_test[:1]])[0]
print _maxout.shape

pl.figure()
pl.imshow(_convout[0, 0], interpolation='nearest')
pl.colorbar()
pl.figure()
pl.imshow(_maxout[0, 0], interpolation='nearest')
pl.colorbar()
# Out:
# (1, 8, 128, 128)
# (1, 8, 128, 128)
# <matplotlib.colorbar.Colorbar instance at 0x7f236816e950>

# %%
def predict(X):
    Y_pred, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > 0.3
    for i in range(Y_pred.shape[0]):
        # Clear prediction where we detect to little pixels
        # Figure it out by
        # pl.hist(np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1))
        #if np.sum(Y_pred[i]) < 200 or Y_pred_binary[i] < 0.2:
        if np.sum(Y_pred[i]) < 200:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test)
Y_full_pred, Y_full_pred_proba, Y_full_pred_binary = predict(X_full)

reload(utils)
print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "test set average score : ", utils.average_dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
print "full set average score : ", utils.average_dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.676656383135
# test set average score :  0.80374292728
# full set score :  0.628272927492
# full set average score :  0.758007222704

# %%
if False:
    y_pred = K.placeholder(shape=Y_pred.shape)
    y_true = K.placeholder(shape=Y_test.shape)

    _dice_coef = K.function([y_true, y_pred], dice_coef_batchwise(y_true, y_pred))

    Y_pred, _, _ = predict(X_train)
    print _np_dice_coef(Y_train, Y_pred)
    print utils.average_dice_coefficient(Y_pred, Y_train)
    print _dice_coef([Y_train, Y_pred])

# %%
_ = pl.hist(Y_pred_binary)

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[:5]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 15
img, pred_map = dream_output(Y_full[i])
pl.figure(figsize=(12, 4))
pl.subplot(131)
pl.imshow(Y_full[i].squeeze())
pl.subplot(132)
pl.imshow(img, cmap=cm.gray)
pl.subplot(133)
pl.imshow(pred_map.squeeze())

# %%
# Dream for the binary output
def dream_binoutput(output):
    
    layer_output = layer_dict['outbin'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output - layer_output[:, 0]))
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    
    step = 0.1
    for i in range(40):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    _, model_pred = model.predict(img[None,None,:,:])
    return img, model_pred

img, model_pred = dream_binoutput(1)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
img, model_pred = dream_binoutput(0)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
def dream_layer_filter(layer_name, filter_index):

    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(8):
        pl.subplot(2, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
if True:
    import cv2
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(50,50))
    
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    test_fnames = _d['test_fnames']
    Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:])
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
        imre = cv2.morphologyEx(imre, cv2.MORPH_CLOSE, kernel)
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
        
        if i % 10 == 0:
            print '\r%d / %d' % (i, len(test_fnames)),
            sys.stdout.flush()

# %% [markdown]
# ## Stats on predicted masks

# %%
# on Y_full
nbp_pixels = np.sum(np.sum(np.sum(Y_full, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
