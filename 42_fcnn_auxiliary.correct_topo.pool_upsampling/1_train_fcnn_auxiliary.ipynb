# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']
X_pids = _d['pids']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
print X.dtype
print Y.dtype
# Out:
# (3906, 128, 128)
# (3906, 128, 128)
# float32
# float32

# %%
if False:
    # Split patients in train/test
    train_pids, test_pids = train_test_split(np.unique(X_pids), test_size=0.1)
    print train_pids
    print test_pids
    
    train_indices = np.flatnonzero(np.in1d(X_pids, train_pids))
    test_indices = np.flatnonzero(np.in1d(X_pids, test_pids))
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]
else:
    nsamples = X.shape[0]

    #train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]

# %%
import skimage.transform as sktransf

def rand_float(rng):
    return rng[0] + np.random.random() * (rng[1] - rng[0])

def generate_image(X_img, Y_img, angle_range=None, zoom_range=None, shear_range=None, horiz_shift_range=None,
                   vert_shift_range=None):
    """
    Randomly shift an image by resizing and then random croping
    the resized image
    """
    if angle_range is None:
        angle_range = (-5, 5)
    if zoom_range is None:
        zoom_range = (0.8, 1.2)
    if shear_range is None:
        shear_range = (-5, 5) # shear angle in degrees
    if horiz_shift_range is None:
        horiz_shift_range = (-5, 5)
    if vert_shift_range is None:
        vert_shift_range = (-5, 5)
    inshape = X_img.shape
    
    X2 = X_img.copy()
    Y2 = Y_img.copy()
    
    # -- random rotation
    angle = np.deg2rad(rand_float(angle_range))
    zoom = rand_float(zoom_range)
    shear = np.deg2rad(rand_float(shear_range))
    horiz_shift = rand_float(horiz_shift_range)
    vert_shift = rand_float(vert_shift_range)
    
    tform = sktransf.AffineTransform(
        scale=(zoom, zoom),
        rotation=angle,
        shear=shear,
        translation=(horiz_shift, vert_shift)
    )
    X2 = sktransf.warp(X2, tform, order=5, mode='edge')
    Y2 = sktransf.warp(Y2, tform, order=1)

    # gaussian noise
    #noise_scale = rand_float((0, 0.1))
    #X2 += np.random.normal(scale=noise_scale, size=X2.shape)
    Y2 = Y2 > 0.5
    return X2[None,:,:].astype(np.float32), Y2[None,:,:].astype(np.float32)

X_train_augmented = []
Y_train_augmented = []
for i in range(X_train.shape[0]):
    if i % 10 == 0:
        print '\r%d / %d' % (i, X_train.shape[0]),
        sys.stdout.flush()
    X_train_augmented.append(X_train[i])
    Y_train_augmented.append(Y_train[i])
    for j in range(2):
        X2, Y2 = generate_image(X_train[i].squeeze(), Y_train[i].squeeze())
        X_train_augmented.append(X2)
        Y_train_augmented.append(Y2)
# Out:
# 3510 / 3515

# %%
X_train = np.array(X_train_augmented, dtype=np.float32)
Y_train = np.array(Y_train_augmented, dtype=np.float32)

Y_train_binary = np.sum(np.sum(Y_train.squeeze(), axis=2), axis=1) > 0
Y_train_binary = Y_train_binary.astype(np.float32)
Y_train_binary = Y_train_binary[:,None]

# %%
print X_train.shape
print Y_train.shape
print X_test.shape
print X_train.min(), X_train.max()
# Out:
# (10545, 1, 128, 128)
# (10545, 1, 128, 128)
# (391, 1, 128, 128)
# 0.0 1.0

# %%
import cv2
def _resize(Y, outshape):
    return cv2.resize(Y.squeeze(), outshape, interpolation=cv2.INTER_AREA)[None, :, :]
Y_train_88 = np.array([_resize(img, (8, 8)) for img in Y_train])
Y_test_88 = np.array([_resize(img, (8, 8)) for img in Y_test])
Y_train_44 = np.array([_resize(img, (4, 4)) for img in Y_train])
Y_test_44 = np.array([_resize(img, (4, 4)) for img in Y_test])

# %%
with_bp = np.flatnonzero(np.sum(np.sum(np.sum(Y_train, axis=1), axis=1), axis=1))

# %%
for bpi in range(11, 14):
    i = with_bp[bpi]
    pl.figure(figsize=(16, 4))
    pl.subplot(141)
    pl.imshow(X_train[i].squeeze())
    pl.subplot(142)
    pl.imshow(Y_train[i].squeeze())
    pl.subplot(143)
    pl.imshow(Y_train_88[i].squeeze(), interpolation='nearest')
    pl.colorbar()
    pl.subplot(144)
    pl.imshow(Y_train_44[i].squeeze(), interpolation='nearest')
    pl.colorbar()

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float32'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense
from keras.layers import LeakyReLU, BatchNormalization
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
import keras.backend as K
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
from keras.layers import Layer, InputSpec
import keras.initializations
import keras.backend as K

class Maxout2D(Layer):
    def __init__(self, output_dim, cardinality, init='glorot_uniform', **kwargs):
        super(Maxout2D, self).__init__(**kwargs)
        # the k of the maxout paper
        self.cardinality = cardinality
        # the m of the maxout paper
        self.output_dim = output_dim
        self.init = keras.initializations.get(init)
    
    def build(self, input_shape):
        self.input_dim = input_shape[1]
        self.input_spec = [InputSpec(dtype=K.floatx(),
                                     shape=(None, input_shape[1], input_shape[2], input_shape[3]))]
        self.W = self.init((self.input_dim, self.output_dim, self.cardinality),
                           name='{}_W'.format(self.name))
        self.b = K.zeros((self.output_dim, self.cardinality))
        self.trainable_weights = [self.W, self.b]
              
    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        # flatten the spatial dimensions
        flat_x = K.reshape(x, (-1, input_shape[1], input_shape[2] * input_shape[3]))
        output = K.dot(
            K.permute_dimensions(flat_x, (0, 2, 1)),
            K.permute_dimensions(self.W, (1, 0, 2))
        )
        output += K.reshape(self.b, (1, 1, self.output_dim, self.cardinality))
        output = K.max(output, axis=3)
        output = output.transpose(0, 2, 1)
        output = K.reshape(output, (-1, self.output_dim, input_shape[2], input_shape[3]))
        return output
    
    def get_output_shape_for(self, input_shape):
        return (input_shape[0], self.output_dim, input_shape[2], input_shape[3])
    
    def get_config(self):
        config = {
            'output_dim': self.output_dim,
            'cardinality': self.cardinality
        }
        base_config = super(Maxout2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
input_img = x = Input(shape=input_shape, name='input_img')
x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(input_img)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool1 = x = MaxPooling2D((2, 2), name='pool1')(x)

x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool2 = x = MaxPooling2D((2, 2), name='pool2')(x)

x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool3 = x = MaxPooling2D((2, 2), name='pool3')(x)

# -- binary presence part
x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(pool5)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

x = Maxout2D(8, 2)(pool5)
outmap5 = Convolution2D(1, 1, 1, border_mode='same', activation='sigmoid', name='outmap5')(x)
x = UpSampling2D((2, 2))(x)


x = merge([x, pool4], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(8, 2)(x)
outmap4 = Convolution2D(1, 1, 1, border_mode='same', activation='sigmoid', name='outmap4')(x)

x = UpSampling2D((2, 2))(x)

x = merge([x, pool3], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(8, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(8, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(8, 2)(x)
x = UpSampling2D((2, 2))(x)

x = Dropout(0.25)(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outmap4, outmap5, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
metrics={'outbin': 'accuracy'}
model.compile(optimizer='adam', loss='binary_crossentropy',
              loss_weights=[1., 0.2, 0.05, 0.01], metrics=metrics)

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_94 (Convolution2D)   (None, 32, 128, 128)320         input_img[0][0]
# ____________________________________________________________________________________________________
# convolution2d_95 (Convolution2D)   (None, 32, 128, 128)9248        convolution2d_94[0][0]
# ____________________________________________________________________________________________________
# maxout2d_42 (Maxout2D)             (None, 16, 128, 128)1056        convolution2d_95[0][0]
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)               (None, 16, 64, 64)  0           maxout2d_42[0][0]
# ____________________________________________________________________________________________________
# dropout_37 (Dropout)               (None, 16, 64, 64)  0           pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_96 (Convolution2D)   (None, 32, 64, 64)  4640        dropout_37[0][0]
# ____________________________________________________________________________________________________
# convolution2d_97 (Convolution2D)   (None, 32, 64, 64)  9248        convolution2d_96[0][0]
# ____________________________________________________________________________________________________
# maxout2d_43 (Maxout2D)             (None, 16, 64, 64)  1056        convolution2d_97[0][0]
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)               (None, 16, 32, 32)  0           maxout2d_43[0][0]
# ____________________________________________________________________________________________________
# dropout_38 (Dropout)               (None, 16, 32, 32)  0           pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_98 (Convolution2D)   (None, 32, 32, 32)  4640        dropout_38[0][0]
# ____________________________________________________________________________________________________
# convolution2d_99 (Convolution2D)   (None, 32, 32, 32)  9248        convolution2d_98[0][0]
# ____________________________________________________________________________________________________
# maxout2d_44 (Maxout2D)             (None, 16, 32, 32)  1056        convolution2d_99[0][0]
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)               (None, 16, 16, 16)  0           maxout2d_44[0][0]
# ____________________________________________________________________________________________________
# dropout_39 (Dropout)               (None, 16, 16, 16)  0           pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_100 (Convolution2D)  (None, 32, 16, 16)  4640        dropout_39[0][0]
# ____________________________________________________________________________________________________
# convolution2d_101 (Convolution2D)  (None, 32, 16, 16)  9248        convolution2d_100[0][0]
# ____________________________________________________________________________________________________
# maxout2d_45 (Maxout2D)             (None, 16, 16, 16)  1056        convolution2d_101[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)               (None, 16, 8, 8)    0           maxout2d_45[0][0]
# ____________________________________________________________________________________________________
# dropout_40 (Dropout)               (None, 16, 8, 8)    0           pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_102 (Convolution2D)  (None, 32, 8, 8)    4640        dropout_40[0][0]
# ____________________________________________________________________________________________________
# convolution2d_103 (Convolution2D)  (None, 32, 8, 8)    9248        convolution2d_102[0][0]
# ____________________________________________________________________________________________________
# maxout2d_46 (Maxout2D)             (None, 16, 8, 8)    1056        convolution2d_103[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)               (None, 16, 4, 4)    0           maxout2d_46[0][0]
# ____________________________________________________________________________________________________
# maxout2d_47 (Maxout2D)             (None, 8, 4, 4)     272         pool5[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_28 (UpSampling2D)     (None, 8, 8, 8)     0           maxout2d_47[0][0]
# ____________________________________________________________________________________________________
# merge_18 (Merge)                   (None, 24, 8, 8)    0           upsampling2d_28[0][0]
#                                                                    pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_104 (Convolution2D)  (None, 16, 8, 8)    3472        merge_18[0][0]
# ____________________________________________________________________________________________________
# maxout2d_48 (Maxout2D)             (None, 8, 8, 8)     272         convolution2d_104[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_29 (UpSampling2D)     (None, 8, 16, 16)   0           maxout2d_48[0][0]
# ____________________________________________________________________________________________________
# merge_19 (Merge)                   (None, 24, 16, 16)  0           upsampling2d_29[0][0]
#                                                                    pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_105 (Convolution2D)  (None, 16, 16, 16)  3472        merge_19[0][0]
# ____________________________________________________________________________________________________
# maxout2d_49 (Maxout2D)             (None, 8, 16, 16)   272         convolution2d_105[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_30 (UpSampling2D)     (None, 8, 32, 32)   0           maxout2d_49[0][0]
# ____________________________________________________________________________________________________
# merge_20 (Merge)                   (None, 24, 32, 32)  0           upsampling2d_30[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_106 (Convolution2D)  (None, 16, 32, 32)  3472        merge_20[0][0]
# ____________________________________________________________________________________________________
# maxout2d_50 (Maxout2D)             (None, 8, 32, 32)   272         convolution2d_106[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_31 (UpSampling2D)     (None, 8, 64, 64)   0           maxout2d_50[0][0]
# ____________________________________________________________________________________________________
# merge_21 (Merge)                   (None, 24, 64, 64)  0           upsampling2d_31[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_107 (Convolution2D)  (None, 16, 64, 64)  3472        merge_21[0][0]
# ____________________________________________________________________________________________________
# flatten_7 (Flatten)                (None, 256)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# maxout2d_51 (Maxout2D)             (None, 8, 64, 64)   272         convolution2d_107[0][0]
# ____________________________________________________________________________________________________
# dense_13 (Dense)                   (None, 32)          8224        flatten_7[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_32 (UpSampling2D)     (None, 8, 128, 128) 0           maxout2d_51[0][0]
# ____________________________________________________________________________________________________
# dropout_41 (Dropout)               (None, 8, 128, 128) 0           upsampling2d_32[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_13 (LeakyReLU)           (None, 32)          0           dense_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_108 (Convolution2D)  (None, 8, 128, 128) 584         dropout_41[0][0]
# ____________________________________________________________________________________________________
# dense_14 (Dense)                   (None, 16)          528         leakyrelu_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_109 (Convolution2D)  (None, 8, 128, 128) 584         convolution2d_108[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_14 (LeakyReLU)           (None, 16)          0           dense_14[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_14[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 73          convolution2d_109[0][0]
# ____________________________________________________________________________________________________
# outmap4 (Convolution2D)            (None, 1, 8, 8)     9           maxout2d_48[0][0]
# ____________________________________________________________________________________________________
# outmap5 (Convolution2D)            (None, 1, 4, 4)     9           maxout2d_47[0][0]
# ====================================================================================================
# Total params: 95676
# ____________________________________________________________________________________________________

# %%
from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

from keras.utils.visualize_util import plot
plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {
            'outmap': Y_train,
            'outmap4' : Y_train_88,
            'outmap5' : Y_train_44,
            'outbin': Y_train_binary
        },
        batch_size=64,
        validation_data=(X_test, {
                'outmap': Y_test,
                'outmap4' : Y_test_88,
                'outmap5' : Y_test_44,
                'outbin': Y_test_binary
        }),
        nb_epoch=40,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    
    pl.figure()
    pl.plot(history.history['outmap_loss'], label='train loss')
    pl.plot(history.history['val_outmap_loss'], c='g', label='val loss')
    pl.legend()

    pl.figure()
    pl.plot(history.history['outbin_acc'], label='train acc')
    pl.plot(history.history['val_outbin_acc'], c='g', label='val acc')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
                custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.01])
    
    print_summary(model.layers)
# Out:
# Train on 10545 samples, validate on 391 samples
# Epoch 1/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1412 - outmap_loss: 0.1055 - outmap4_loss: 0.0739 - outmap5_loss: 0.2781 - outbin_loss: 0.7022 - outbin_acc: 0.6142Epoch 00000: val_loss improved from inf to 0.06889, saving model to weights.hdf5
# 10545/10545 [==============================] - 120s - loss: 0.1409 - outmap_loss: 0.1052 - outmap4_loss: 0.0739 - outmap5_loss: 0.2772 - outbin_loss: 0.7022 - outbin_acc: 0.6139 - val_loss: 0.0689 - val_outmap_loss: 0.0368 - val_outmap4_loss: 0.0993 - val_outmap5_loss: 0.1107 - val_outbin_loss: 0.6685 - val_outbin_acc: 0.6624
# Epoch 2/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0561 - outmap_loss: 0.0374 - outmap4_loss: 0.0461 - outmap5_loss: 0.0619 - outbin_loss: 0.6380 - outbin_acc: 0.6409Epoch 00001: val_loss improved from 0.06889 to 0.04156, saving model to weights.hdf5
# 10545/10545 [==============================] - 120s - loss: 0.0561 - outmap_loss: 0.0374 - outmap4_loss: 0.0461 - outmap5_loss: 0.0619 - outbin_loss: 0.6383 - outbin_acc: 0.6404 - val_loss: 0.0416 - val_outmap_loss: 0.0265 - val_outmap4_loss: 0.0350 - val_outmap5_loss: 0.0480 - val_outbin_loss: 0.5637 - val_outbin_acc: 0.6675
# Epoch 3/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0478 - outmap_loss: 0.0316 - outmap4_loss: 0.0391 - outmap5_loss: 0.0522 - outbin_loss: 0.5780 - outbin_acc: 0.6983Epoch 00002: val_loss improved from 0.04156 to 0.03771, saving model to weights.hdf5
# 10545/10545 [==============================] - 120s - loss: 0.0479 - outmap_loss: 0.0317 - outmap4_loss: 0.0392 - outmap5_loss: 0.0523 - outbin_loss: 0.5783 - outbin_acc: 0.6982 - val_loss: 0.0377 - val_outmap_loss: 0.0240 - val_outmap4_loss: 0.0332 - val_outmap5_loss: 0.0436 - val_outbin_loss: 0.4885 - val_outbin_acc: 0.7417
# Epoch 4/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0448 - outmap_loss: 0.0296 - outmap4_loss: 0.0372 - outmap5_loss: 0.0494 - outbin_loss: 0.5379 - outbin_acc: 0.7308Epoch 00003: val_loss improved from 0.03771 to 0.03729, saving model to weights.hdf5
# 10545/10545 [==============================] - 121s - loss: 0.0448 - outmap_loss: 0.0295 - outmap4_loss: 0.0371 - outmap5_loss: 0.0494 - outbin_loss: 0.5373 - outbin_acc: 0.7314 - val_loss: 0.0373 - val_outmap_loss: 0.0235 - val_outmap4_loss: 0.0343 - val_outmap5_loss: 0.0456 - val_outbin_loss: 0.4606 - val_outbin_acc: 0.7775
# Epoch 5/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0408 - outmap_loss: 0.0266 - outmap4_loss: 0.0345 - outmap5_loss: 0.0465 - outbin_loss: 0.4931 - outbin_acc: 0.7651Epoch 00004: val_loss improved from 0.03729 to 0.03514, saving model to weights.hdf5
# 10545/10545 [==============================] - 122s - loss: 0.0408 - outmap_loss: 0.0267 - outmap4_loss: 0.0345 - outmap5_loss: 0.0465 - outbin_loss: 0.4932 - outbin_acc: 0.7655 - val_loss: 0.0351 - val_outmap_loss: 0.0221 - val_outmap4_loss: 0.0336 - val_outmap5_loss: 0.0408 - val_outbin_loss: 0.4298 - val_outbin_acc: 0.8056
# Epoch 6/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0386 - outmap_loss: 0.0251 - outmap4_loss: 0.0332 - outmap5_loss: 0.0449 - outbin_loss: 0.4565 - outbin_acc: 0.7931Epoch 00005: val_loss improved from 0.03514 to 0.03449, saving model to weights.hdf5
# 10545/10545 [==============================] - 125s - loss: 0.0386 - outmap_loss: 0.0251 - outmap4_loss: 0.0332 - outmap5_loss: 0.0449 - outbin_loss: 0.4572 - outbin_acc: 0.7923 - val_loss: 0.0345 - val_outmap_loss: 0.0213 - val_outmap4_loss: 0.0355 - val_outmap5_loss: 0.0416 - val_outbin_loss: 0.4015 - val_outbin_acc: 0.8286
# Epoch 7/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0375 - outmap_loss: 0.0243 - outmap4_loss: 0.0326 - outmap5_loss: 0.0445 - outbin_loss: 0.4413 - outbin_acc: 0.7969Epoch 00006: val_loss did not improve
# 10545/10545 [==============================] - 125s - loss: 0.0375 - outmap_loss: 0.0243 - outmap4_loss: 0.0326 - outmap5_loss: 0.0445 - outbin_loss: 0.4416 - outbin_acc: 0.7969 - val_loss: 0.0406 - val_outmap_loss: 0.0242 - val_outmap4_loss: 0.0453 - val_outmap5_loss: 0.0551 - val_outbin_loss: 0.4590 - val_outbin_acc: 0.7698
# Epoch 8/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0361 - outmap_loss: 0.0234 - outmap4_loss: 0.0317 - outmap5_loss: 0.0435 - outbin_loss: 0.4148 - outbin_acc: 0.8159Epoch 00007: val_loss improved from 0.03449 to 0.03421, saving model to weights.hdf5
# 10545/10545 [==============================] - 125s - loss: 0.0361 - outmap_loss: 0.0234 - outmap4_loss: 0.0317 - outmap5_loss: 0.0435 - outbin_loss: 0.4147 - outbin_acc: 0.8158 - val_loss: 0.0342 - val_outmap_loss: 0.0215 - val_outmap4_loss: 0.0340 - val_outmap5_loss: 0.0408 - val_outbin_loss: 0.3882 - val_outbin_acc: 0.8312
# Epoch 9/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0351 - outmap_loss: 0.0228 - outmap4_loss: 0.0311 - outmap5_loss: 0.0426 - outbin_loss: 0.3945 - outbin_acc: 0.8230Epoch 00008: val_loss did not improve
# 10545/10545 [==============================] - 125s - loss: 0.0351 - outmap_loss: 0.0228 - outmap4_loss: 0.0311 - outmap5_loss: 0.0427 - outbin_loss: 0.3943 - outbin_acc: 0.8233 - val_loss: 0.0353 - val_outmap_loss: 0.0225 - val_outmap4_loss: 0.0342 - val_outmap5_loss: 0.0454 - val_outbin_loss: 0.3722 - val_outbin_acc: 0.8363
# Epoch 10/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0338 - outmap_loss: 0.0219 - outmap4_loss: 0.0303 - outmap5_loss: 0.0418 - outbin_loss: 0.3814 - outbin_acc: 0.8323Epoch 00009: val_loss improved from 0.03421 to 0.03349, saving model to weights.hdf5
# 10545/10545 [==============================] - 125s - loss: 0.0339 - outmap_loss: 0.0219 - outmap4_loss: 0.0304 - outmap5_loss: 0.0419 - outbin_loss: 0.3823 - outbin_acc: 0.8321 - val_loss: 0.0335 - val_outmap_loss: 0.0206 - val_outmap4_loss: 0.0327 - val_outmap5_loss: 0.0441 - val_outbin_loss: 0.4181 - val_outbin_acc: 0.8210
# Epoch 11/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0341 - outmap_loss: 0.0220 - outmap4_loss: 0.0306 - outmap5_loss: 0.0421 - outbin_loss: 0.3830 - outbin_acc: 0.8379Epoch 00010: val_loss improved from 0.03349 to 0.03090, saving model to weights.hdf5
# 10545/10545 [==============================] - 124s - loss: 0.0341 - outmap_loss: 0.0220 - outmap4_loss: 0.0306 - outmap5_loss: 0.0422 - outbin_loss: 0.3829 - outbin_acc: 0.8381 - val_loss: 0.0309 - val_outmap_loss: 0.0198 - val_outmap4_loss: 0.0280 - val_outmap5_loss: 0.0370 - val_outbin_loss: 0.3614 - val_outbin_acc: 0.8363
# Epoch 12/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0332 - outmap_loss: 0.0214 - outmap4_loss: 0.0299 - outmap5_loss: 0.0414 - outbin_loss: 0.3733 - outbin_acc: 0.8409Epoch 00011: val_loss improved from 0.03090 to 0.03052, saving model to weights.hdf5
# 10545/10545 [==============================] - 121s - loss: 0.0333 - outmap_loss: 0.0215 - outmap4_loss: 0.0300 - outmap5_loss: 0.0414 - outbin_loss: 0.3732 - outbin_acc: 0.8410 - val_loss: 0.0305 - val_outmap_loss: 0.0193 - val_outmap4_loss: 0.0284 - val_outmap5_loss: 0.0373 - val_outbin_loss: 0.3637 - val_outbin_acc: 0.8338
# Epoch 13/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0321 - outmap_loss: 0.0207 - outmap4_loss: 0.0292 - outmap5_loss: 0.0408 - outbin_loss: 0.3551 - outbin_acc: 0.8457Epoch 00012: val_loss improved from 0.03052 to 0.02992, saving model to weights.hdf5
# 10545/10545 [==============================] - 120s - loss: 0.0321 - outmap_loss: 0.0207 - outmap4_loss: 0.0292 - outmap5_loss: 0.0408 - outbin_loss: 0.3549 - outbin_acc: 0.8459 - val_loss: 0.0299 - val_outmap_loss: 0.0192 - val_outmap4_loss: 0.0268 - val_outmap5_loss: 0.0363 - val_outbin_loss: 0.3557 - val_outbin_acc: 0.8465
# Epoch 14/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0316 - outmap_loss: 0.0203 - outmap4_loss: 0.0287 - outmap5_loss: 0.0404 - outbin_loss: 0.3457 - outbin_acc: 0.8495Epoch 00013: val_loss did not improve
# 10545/10545 [==============================] - 120s - loss: 0.0316 - outmap_loss: 0.0204 - outmap4_loss: 0.0288 - outmap5_loss: 0.0404 - outbin_loss: 0.3462 - outbin_acc: 0.8493 - val_loss: 0.0313 - val_outmap_loss: 0.0197 - val_outmap4_loss: 0.0295 - val_outmap5_loss: 0.0380 - val_outbin_loss: 0.3741 - val_outbin_acc: 0.8568
# Epoch 15/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0313 - outmap_loss: 0.0201 - outmap4_loss: 0.0286 - outmap5_loss: 0.0401 - outbin_loss: 0.3450 - outbin_acc: 0.8535Epoch 00014: val_loss improved from 0.02992 to 0.02983, saving model to weights.hdf5
# 10545/10545 [==============================] - 121s - loss: 0.0313 - outmap_loss: 0.0201 - outmap4_loss: 0.0286 - outmap5_loss: 0.0402 - outbin_loss: 0.3454 - outbin_acc: 0.8534 - val_loss: 0.0298 - val_outmap_loss: 0.0189 - val_outmap4_loss: 0.0271 - val_outmap5_loss: 0.0362 - val_outbin_loss: 0.3661 - val_outbin_acc: 0.8465
# Epoch 16/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0309 - outmap_loss: 0.0199 - outmap4_loss: 0.0283 - outmap5_loss: 0.0396 - outbin_loss: 0.3401 - outbin_acc: 0.8552Epoch 00015: val_loss improved from 0.02983 to 0.02965, saving model to weights.hdf5
# 10545/10545 [==============================] - 120s - loss: 0.0309 - outmap_loss: 0.0199 - outmap4_loss: 0.0283 - outmap5_loss: 0.0396 - outbin_loss: 0.3401 - outbin_acc: 0.8552 - val_loss: 0.0297 - val_outmap_loss: 0.0190 - val_outmap4_loss: 0.0264 - val_outmap5_loss: 0.0349 - val_outbin_loss: 0.3624 - val_outbin_acc: 0.8312
# Epoch 17/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0301 - outmap_loss: 0.0193 - outmap4_loss: 0.0278 - outmap5_loss: 0.0392 - outbin_loss: 0.3315 - outbin_acc: 0.8612Epoch 00016: val_loss did not improve
# 10545/10545 [==============================] - 120s - loss: 0.0301 - outmap_loss: 0.0193 - outmap4_loss: 0.0278 - outmap5_loss: 0.0392 - outbin_loss: 0.3315 - outbin_acc: 0.8612 - val_loss: 0.0304 - val_outmap_loss: 0.0192 - val_outmap4_loss: 0.0270 - val_outmap5_loss: 0.0360 - val_outbin_loss: 0.3987 - val_outbin_acc: 0.8286
# Epoch 18/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0302 - outmap_loss: 0.0194 - outmap4_loss: 0.0279 - outmap5_loss: 0.0396 - outbin_loss: 0.3248 - outbin_acc: 0.8646Epoch 00017: val_loss did not improve
# 10545/10545 [==============================] - 120s - loss: 0.0302 - outmap_loss: 0.0194 - outmap4_loss: 0.0279 - outmap5_loss: 0.0395 - outbin_loss: 0.3252 - outbin_acc: 0.8646 - val_loss: 0.0298 - val_outmap_loss: 0.0189 - val_outmap4_loss: 0.0265 - val_outmap5_loss: 0.0360 - val_outbin_loss: 0.3795 - val_outbin_acc: 0.8440
# Epoch 19/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0295 - outmap_loss: 0.0188 - outmap4_loss: 0.0274 - outmap5_loss: 0.0388 - outbin_loss: 0.3196 - outbin_acc: 0.8676Epoch 00018: val_loss did not improve
# 10545/10545 [==============================] - 120s - loss: 0.0294 - outmap_loss: 0.0188 - outmap4_loss: 0.0273 - outmap5_loss: 0.0388 - outbin_loss: 0.3188 - outbin_acc: 0.8678 - val_loss: 0.0305 - val_outmap_loss: 0.0197 - val_outmap4_loss: 0.0269 - val_outmap5_loss: 0.0356 - val_outbin_loss: 0.3631 - val_outbin_acc: 0.8440
# Epoch 20/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0289 - outmap_loss: 0.0185 - outmap4_loss: 0.0270 - outmap5_loss: 0.0385 - outbin_loss: 0.3115 - outbin_acc: 0.8681Epoch 00019: val_loss did not improve
# 10545/10545 [==============================] - 121s - loss: 0.0289 - outmap_loss: 0.0185 - outmap4_loss: 0.0270 - outmap5_loss: 0.0385 - outbin_loss: 0.3115 - outbin_acc: 0.8680 - val_loss: 0.0308 - val_outmap_loss: 0.0194 - val_outmap4_loss: 0.0267 - val_outmap5_loss: 0.0348 - val_outbin_loss: 0.4360 - val_outbin_acc: 0.7954
# Epoch 21/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0288 - outmap_loss: 0.0184 - outmap4_loss: 0.0270 - outmap5_loss: 0.0384 - outbin_loss: 0.3072 - outbin_acc: 0.8754Epoch 00020: val_loss did not improve
# 10545/10545 [==============================] - 125s - loss: 0.0288 - outmap_loss: 0.0184 - outmap4_loss: 0.0270 - outmap5_loss: 0.0385 - outbin_loss: 0.3073 - outbin_acc: 0.8756 - val_loss: 0.0299 - val_outmap_loss: 0.0192 - val_outmap4_loss: 0.0260 - val_outmap5_loss: 0.0354 - val_outbin_loss: 0.3721 - val_outbin_acc: 0.8312
# Epoch 22/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0283 - outmap_loss: 0.0181 - outmap4_loss: 0.0267 - outmap5_loss: 0.0382 - outbin_loss: 0.2967 - outbin_acc: 0.8756Epoch 00021: val_loss did not improve
# 10545/10545 [==============================] - 125s - loss: 0.0283 - outmap_loss: 0.0181 - outmap4_loss: 0.0267 - outmap5_loss: 0.0382 - outbin_loss: 0.2965 - outbin_acc: 0.8758 - val_loss: 0.0305 - val_outmap_loss: 0.0193 - val_outmap4_loss: 0.0273 - val_outmap5_loss: 0.0375 - val_outbin_loss: 0.3890 - val_outbin_acc: 0.8184
# Epoch 23/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0286 - outmap_loss: 0.0182 - outmap4_loss: 0.0268 - outmap5_loss: 0.0383 - outbin_loss: 0.3101 - outbin_acc: 0.8711Epoch 00022: val_loss did not improve
# 10545/10545 [==============================] - 125s - loss: 0.0286 - outmap_loss: 0.0182 - outmap4_loss: 0.0268 - outmap5_loss: 0.0383 - outbin_loss: 0.3097 - outbin_acc: 0.8713 - val_loss: 0.0302 - val_outmap_loss: 0.0196 - val_outmap4_loss: 0.0263 - val_outmap5_loss: 0.0350 - val_outbin_loss: 0.3682 - val_outbin_acc: 0.8363
# Epoch 24/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0281 - outmap_loss: 0.0179 - outmap4_loss: 0.0266 - outmap5_loss: 0.0380 - outbin_loss: 0.2962 - outbin_acc: 0.8780Epoch 00023: val_loss improved from 0.02965 to 0.02868, saving model to weights.hdf5
# 10545/10545 [==============================] - 125s - loss: 0.0282 - outmap_loss: 0.0180 - outmap4_loss: 0.0266 - outmap5_loss: 0.0380 - outbin_loss: 0.2971 - outbin_acc: 0.8778 - val_loss: 0.0287 - val_outmap_loss: 0.0185 - val_outmap4_loss: 0.0251 - val_outmap5_loss: 0.0342 - val_outbin_loss: 0.3457 - val_outbin_acc: 0.8440
# Epoch 25/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0282 - outmap_loss: 0.0179 - outmap4_loss: 0.0266 - outmap5_loss: 0.0383 - outbin_loss: 0.2966 - outbin_acc: 0.8785Epoch 00024: val_loss did not improve
# 10545/10545 [==============================] - 125s - loss: 0.0282 - outmap_loss: 0.0180 - outmap4_loss: 0.0266 - outmap5_loss: 0.0383 - outbin_loss: 0.2965 - outbin_acc: 0.8783 - val_loss: 0.0292 - val_outmap_loss: 0.0185 - val_outmap4_loss: 0.0255 - val_outmap5_loss: 0.0357 - val_outbin_loss: 0.3729 - val_outbin_acc: 0.8440
# Epoch 26/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0273 - outmap_loss: 0.0174 - outmap4_loss: 0.0261 - outmap5_loss: 0.0377 - outbin_loss: 0.2829 - outbin_acc: 0.8839Epoch 00025: val_loss did not improve
# 10545/10545 [==============================] - 125s - loss: 0.0273 - outmap_loss: 0.0174 - outmap4_loss: 0.0261 - outmap5_loss: 0.0377 - outbin_loss: 0.2830 - outbin_acc: 0.8836 - val_loss: 0.0289 - val_outmap_loss: 0.0186 - val_outmap4_loss: 0.0251 - val_outmap5_loss: 0.0345 - val_outbin_loss: 0.3597 - val_outbin_acc: 0.8414
# Epoch 27/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0275 - outmap_loss: 0.0175 - outmap4_loss: 0.0262 - outmap5_loss: 0.0379 - outbin_loss: 0.2836 - outbin_acc: 0.8818Epoch 00026: val_loss did not improve
# 10545/10545 [==============================] - 125s - loss: 0.0274 - outmap_loss: 0.0175 - outmap4_loss: 0.0262 - outmap5_loss: 0.0379 - outbin_loss: 0.2835 - outbin_acc: 0.8818 - val_loss: 0.0293 - val_outmap_loss: 0.0189 - val_outmap4_loss: 0.0254 - val_outmap5_loss: 0.0340 - val_outbin_loss: 0.3642 - val_outbin_acc: 0.8568
# Epoch 28/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0271 - outmap_loss: 0.0172 - outmap4_loss: 0.0259 - outmap5_loss: 0.0375 - outbin_loss: 0.2796 - outbin_acc: 0.8825Epoch 00027: val_loss improved from 0.02868 to 0.02811, saving model to weights.hdf5
# 10545/10545 [==============================] - 125s - loss: 0.0271 - outmap_loss: 0.0172 - outmap4_loss: 0.0260 - outmap5_loss: 0.0375 - outbin_loss: 0.2798 - outbin_acc: 0.8823 - val_loss: 0.0281 - val_outmap_loss: 0.0180 - val_outmap4_loss: 0.0252 - val_outmap5_loss: 0.0339 - val_outbin_loss: 0.3393 - val_outbin_acc: 0.8593
# Epoch 29/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0271 - outmap_loss: 0.0172 - outmap4_loss: 0.0261 - outmap5_loss: 0.0374 - outbin_loss: 0.2838 - outbin_acc: 0.8821Epoch 00028: val_loss did not improve
# 10545/10545 [==============================] - 125s - loss: 0.0271 - outmap_loss: 0.0172 - outmap4_loss: 0.0261 - outmap5_loss: 0.0375 - outbin_loss: 0.2831 - outbin_acc: 0.8823 - val_loss: 0.0285 - val_outmap_loss: 0.0185 - val_outmap4_loss: 0.0250 - val_outmap5_loss: 0.0340 - val_outbin_loss: 0.3327 - val_outbin_acc: 0.8542
# Epoch 30/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0266 - outmap_loss: 0.0168 - outmap4_loss: 0.0257 - outmap5_loss: 0.0373 - outbin_loss: 0.2732 - outbin_acc: 0.8886Epoch 00029: val_loss did not improve
# 10545/10545 [==============================] - 125s - loss: 0.0266 - outmap_loss: 0.0168 - outmap4_loss: 0.0257 - outmap5_loss: 0.0373 - outbin_loss: 0.2729 - outbin_acc: 0.8887 - val_loss: 0.0286 - val_outmap_loss: 0.0181 - val_outmap4_loss: 0.0251 - val_outmap5_loss: 0.0349 - val_outbin_loss: 0.3761 - val_outbin_acc: 0.8363
# Epoch 31/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0266 - outmap_loss: 0.0169 - outmap4_loss: 0.0258 - outmap5_loss: 0.0372 - outbin_loss: 0.2693 - outbin_acc: 0.8902Epoch 00030: val_loss did not improve
# 10545/10545 [==============================] - 125s - loss: 0.0266 - outmap_loss: 0.0169 - outmap4_loss: 0.0258 - outmap5_loss: 0.0372 - outbin_loss: 0.2691 - outbin_acc: 0.8904 - val_loss: 0.0293 - val_outmap_loss: 0.0190 - val_outmap4_loss: 0.0255 - val_outmap5_loss: 0.0351 - val_outbin_loss: 0.3476 - val_outbin_acc: 0.8517
# Epoch 32/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0269 - outmap_loss: 0.0170 - outmap4_loss: 0.0260 - outmap5_loss: 0.0376 - outbin_loss: 0.2766 - outbin_acc: 0.8883Epoch 00031: val_loss improved from 0.02811 to 0.02805, saving model to weights.hdf5
# 10545/10545 [==============================] - 125s - loss: 0.0269 - outmap_loss: 0.0170 - outmap4_loss: 0.0260 - outmap5_loss: 0.0376 - outbin_loss: 0.2766 - outbin_acc: 0.8884 - val_loss: 0.0280 - val_outmap_loss: 0.0180 - val_outmap4_loss: 0.0253 - val_outmap5_loss: 0.0335 - val_outbin_loss: 0.3348 - val_outbin_acc: 0.8670
# Epoch 33/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0272 - outmap_loss: 0.0172 - outmap4_loss: 0.0260 - outmap5_loss: 0.0377 - outbin_loss: 0.2834 - outbin_acc: 0.8831Epoch 00032: val_loss did not improve
# 10545/10545 [==============================] - 125s - loss: 0.0272 - outmap_loss: 0.0173 - outmap4_loss: 0.0260 - outmap5_loss: 0.0377 - outbin_loss: 0.2844 - outbin_acc: 0.8828 - val_loss: 0.0291 - val_outmap_loss: 0.0187 - val_outmap4_loss: 0.0255 - val_outmap5_loss: 0.0333 - val_outbin_loss: 0.3622 - val_outbin_acc: 0.8440
# Epoch 34/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0265 - outmap_loss: 0.0168 - outmap4_loss: 0.0256 - outmap5_loss: 0.0371 - outbin_loss: 0.2693 - outbin_acc: 0.8902Epoch 00033: val_loss improved from 0.02805 to 0.02792, saving model to weights.hdf5
# 10545/10545 [==============================] - 125s - loss: 0.0265 - outmap_loss: 0.0168 - outmap4_loss: 0.0257 - outmap5_loss: 0.0371 - outbin_loss: 0.2692 - outbin_acc: 0.8903 - val_loss: 0.0279 - val_outmap_loss: 0.0178 - val_outmap4_loss: 0.0250 - val_outmap5_loss: 0.0339 - val_outbin_loss: 0.3467 - val_outbin_acc: 0.8670
# Epoch 35/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0259 - outmap_loss: 0.0164 - outmap4_loss: 0.0253 - outmap5_loss: 0.0367 - outbin_loss: 0.2619 - outbin_acc: 0.8947Epoch 00034: val_loss did not improve
# 10545/10545 [==============================] - 125s - loss: 0.0259 - outmap_loss: 0.0164 - outmap4_loss: 0.0253 - outmap5_loss: 0.0366 - outbin_loss: 0.2614 - outbin_acc: 0.8948 - val_loss: 0.0284 - val_outmap_loss: 0.0180 - val_outmap4_loss: 0.0253 - val_outmap5_loss: 0.0336 - val_outbin_loss: 0.3678 - val_outbin_acc: 0.8670
# Epoch 36/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0260 - outmap_loss: 0.0164 - outmap4_loss: 0.0252 - outmap5_loss: 0.0369 - outbin_loss: 0.2644 - outbin_acc: 0.8926Epoch 00035: val_loss did not improve
# 10545/10545 [==============================] - 125s - loss: 0.0260 - outmap_loss: 0.0165 - outmap4_loss: 0.0252 - outmap5_loss: 0.0369 - outbin_loss: 0.2647 - outbin_acc: 0.8927 - val_loss: 0.0287 - val_outmap_loss: 0.0183 - val_outmap4_loss: 0.0248 - val_outmap5_loss: 0.0334 - val_outbin_loss: 0.3703 - val_outbin_acc: 0.8465
# Epoch 37/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0255 - outmap_loss: 0.0161 - outmap4_loss: 0.0251 - outmap5_loss: 0.0365 - outbin_loss: 0.2526 - outbin_acc: 0.8983Epoch 00036: val_loss did not improve
# 10545/10545 [==============================] - 125s - loss: 0.0254 - outmap_loss: 0.0161 - outmap4_loss: 0.0251 - outmap5_loss: 0.0364 - outbin_loss: 0.2522 - outbin_acc: 0.8984 - val_loss: 0.0298 - val_outmap_loss: 0.0189 - val_outmap4_loss: 0.0256 - val_outmap5_loss: 0.0340 - val_outbin_loss: 0.4094 - val_outbin_acc: 0.8363
# Epoch 38/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0258 - outmap_loss: 0.0163 - outmap4_loss: 0.0253 - outmap5_loss: 0.0365 - outbin_loss: 0.2662 - outbin_acc: 0.8935Epoch 00037: val_loss did not improve
# 10545/10545 [==============================] - 125s - loss: 0.0259 - outmap_loss: 0.0164 - outmap4_loss: 0.0253 - outmap5_loss: 0.0366 - outbin_loss: 0.2661 - outbin_acc: 0.8934 - val_loss: 0.0285 - val_outmap_loss: 0.0187 - val_outmap4_loss: 0.0245 - val_outmap5_loss: 0.0331 - val_outbin_loss: 0.3232 - val_outbin_acc: 0.8542
# Epoch 39/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0251 - outmap_loss: 0.0158 - outmap4_loss: 0.0249 - outmap5_loss: 0.0362 - outbin_loss: 0.2505 - outbin_acc: 0.8957Epoch 00038: val_loss did not improve
# 10545/10545 [==============================] - 121s - loss: 0.0251 - outmap_loss: 0.0158 - outmap4_loss: 0.0249 - outmap5_loss: 0.0362 - outbin_loss: 0.2502 - outbin_acc: 0.8958 - val_loss: 0.0300 - val_outmap_loss: 0.0193 - val_outmap4_loss: 0.0261 - val_outmap5_loss: 0.0416 - val_outbin_loss: 0.3366 - val_outbin_acc: 0.8670
# Epoch 40/40
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.0255 - outmap_loss: 0.0161 - outmap4_loss: 0.0252 - outmap5_loss: 0.0366 - outbin_loss: 0.2514 - outbin_acc: 0.8984Epoch 00039: val_loss improved from 0.02792 to 0.02785, saving model to weights.hdf5
# 10545/10545 [==============================] - 121s - loss: 0.0255 - outmap_loss: 0.0161 - outmap4_loss: 0.0252 - outmap5_loss: 0.0367 - outbin_loss: 0.2513 - outbin_acc: 0.8985 - val_loss: 0.0278 - val_outmap_loss: 0.0177 - val_outmap4_loss: 0.0253 - val_outmap5_loss: 0.0332 - val_outbin_loss: 0.3389 - val_outbin_acc: 0.8645

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture_final.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights_final.hdf5'))

# %%
def compute_scores_map(X, Y):
    Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X)
    
    map_threshs = np.linspace(0, 1, num=21)
    bin_threshs = np.linspace(0, 1, num=21)
    
    scores = np.zeros((len(map_threshs), len(bin_threshs)))
    for i in range(len(map_threshs)):
        for j in range(len(bin_threshs)):
            _Y_pred = Y_pred > map_threshs[i]
            
            for k in range(_Y_pred.shape[0]):
                # Clear prediction where we detect to little pixels
                if np.sum(_Y_pred[k]) < 150 or Y_pred_binary[k] < bin_threshs[j]:
                    _Y_pred[k,:] = 0
            
            scores[i, j] = utils.average_dice_coefficient(_Y_pred, Y)
    
    pl.imshow(scores, interpolation='nearest')
    pl.yticks(np.arange(len(map_threshs)) + 0.5, ['%.2f' % v for v in map_threshs])
    pl.xticks(np.arange(len(bin_threshs)) + 0.5, ['%.2f' % v for v in bin_threshs], rotation=90)
    pl.ylabel('map thresh')
    pl.xlabel('bin thresh')
    pl.colorbar()
    
    best_i, best_j = np.unravel_index(np.argmax(scores.ravel()), scores.shape)
    best_map_thresh = map_threshs[best_i]
    best_bin_thresh = bin_threshs[best_j]
    return best_map_thresh, best_bin_thresh

map_thresh, bin_thresh = compute_scores_map(X_test, Y_test)
print 'Best map_thresh=%f, bin_thresh=%f' % (map_thresh, bin_thresh)
# Out:
# Best map_thresh=0.350000, bin_thresh=0.700000

# %%
#map_thresh = 0.45
#bin_thresh = 0.9

# %%
def predict(X, map_thresh, bin_thresh):
    Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > map_thresh
    for i in range(Y_pred.shape[0]):
        if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < bin_thresh:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test, map_thresh, bin_thresh)
Y_full_pred, Y_full_pred_proba, Y_full_pred_binary = predict(X_full, map_thresh, bin_thresh)

print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "avg test set score : ", utils.average_dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
print "avg full set score : ", utils.average_dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.655224998421
# avg test set score :  0.831411990193
# full set score :  0.632240067821
# avg full set score :  0.770004651893

# %%
_ = pl.hist(Y_pred_binary)

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[40:45]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(30):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, pred44, pred88, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 15
img, pred_map = dream_output(Y_full[i])
pl.figure(figsize=(12, 4))
pl.subplot(141)
pl.imshow(X_full[i].squeeze(), cmap=cm.gray)
pl.subplot(142)
pl.imshow(Y_full[i].squeeze())
pl.subplot(143)
pl.imshow(img, cmap=cm.gray)
pl.subplot(144)
pl.imshow(pred_map.squeeze())

# %%
# Dream for the binary output
def dream_binoutput(output):
    
    layer_output = layer_dict['outbin'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output - layer_output[:, 0]))
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    
    step = 0.1
    for i in range(40):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    _, _, _, model_pred = model.predict(img[None,None,:,:])
    return img, model_pred

img, model_pred = dream_binoutput(1)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
img, model_pred = dream_binoutput(0)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
def dream_layer_filter(layer_name, filter_index):
    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(4):
        pl.subplot(1, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
_d = np.load('../data/data_128_test.npz')
X_submit = _d['X']

Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X_submit[:,None,:,:])
Y_pred_binary = Y_pred_binary.squeeze()
Y_pred_proba = Y_pred

# %%
def Y_to_binary(Y_pred, Y_pred_binary, map_thresh, bin_thresh):
    Y_pred = Y_pred > map_thresh
    for i in range(Y_pred.shape[0]):
        if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < bin_thresh:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

map_threshs = np.linspace(0, 1, num=11)
bin_threshs = np.linspace(0, 1, num=11)

masks_per = np.zeros((len(map_threshs), len(bin_threshs)))
for i in range(len(map_threshs)):
    for j in range(len(bin_threshs)):
        m_t = map_threshs[i]
        b_t = bin_threshs[j]
        _pred, _pred_proba, _pred_binary = Y_to_binary(Y_pred, Y_pred_binary, m_t, b_t)
        # Turn labels into boolean present/missing
        _pred_binary = np.sum(np.sum(np.sum(_pred, axis=2), axis=1), axis=1) > 0
        _pred_binary = _pred_binary.astype(np.float32)
        per_mask = (100 * np.count_nonzero(_pred_binary) / float(len(_pred_binary)))

        masks_per[i, j] = per_mask

pl.imshow(masks_per, interpolation='nearest')
pl.yticks(np.arange(len(map_threshs)) + 0.5, ['%.2f' % v for v in map_threshs])
pl.xticks(np.arange(len(bin_threshs)) + 0.5, ['%.2f' % v for v in bin_threshs], rotation=90)
pl.ylabel('map thresh')
pl.xlabel('bin thresh')
pl.colorbar()

# %%
map_thresh = 0.3
bin_thresh = 0.5

# %%
if True:
    import cv2
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(50,50))
    
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    test_fnames = _d['test_fnames']
    # bin_thresh
    Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:],
                                                  map_thresh, bin_thresh)
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = (Y_pred[i].squeeze() * 255).astype(np.uint8)
        imre = cv2.morphologyEx(imre, cv2.MORPH_CLOSE, kernel)
        imre = cv2.resize(imre, (580, 420))
        
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
        
        if i % 10 == 0:
            print '\r%d / %d' % (i, len(test_fnames)),
            sys.stdout.flush()
# Out:
# 5500 / 5508

# %%
# Turn labels into boolean present/missing
pred_binary = np.sum(np.sum(np.sum(Y_pred, axis=2), axis=1), axis=1) > 0
pred_binary = pred_binary.astype(np.float32)
print "%.2f%% with masks" % (100 * np.count_nonzero(pred_binary) / float(len(pred_binary)))
# Out:
# 37.67% with masks

# %% [markdown]
# ## Stats on predicted masks

# %%
# on Y_full
nbp_pixels = np.sum(np.sum(np.sum(Y_full, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
pl.xlim((0, 1200))
# Out:
# (0, 1200)

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
pl.xlim((0, 1200))
# Out:
# (0, 1200)
