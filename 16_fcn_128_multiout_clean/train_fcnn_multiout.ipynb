# %% [markdown]
# ## FCNN with a boolean output indicating the likelihood of the image containing nerve

# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline

# %%
_d = np.load('../../data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../../data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
# Out:
# (3906, 128, 128)
# (3906, 128, 128)

# %%
nsamples = X.shape[0]

train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
#train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.25)
X_train = X[train_indices][:,None,:,:]
Y_train_binary = Y_binary[train_indices][:,None]
Y_train = Y[train_indices][:,None,:,:]
X_test = X[test_indices][:,None,:,:]
Y_test_binary = Y_binary[test_indices][:,None]
Y_test = Y[test_indices][:,None,:,:]

# %%
print X_train.shape
print Y_train.shape
print Y_train_binary.shape
print X_train.min(), X_train.max()
# Out:
# (3515, 1, 128, 128)
# (3515, 1, 128, 128)
# (3515, 1)
# 0.0 1.0

# %%
#pl.imshow(X_train[0].squeeze())
pl.imshow(Y_train[0].squeeze())
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float16'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D
from keras.layers import LeakyReLU
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
input_img = Input(shape=input_shape)
x = Convolution2D(16, 11, 11, border_mode='same')(input_img)
x = LeakyReLU()(x)
#x = Convolution2D(16, 3, 3, border_mode='same')(x)
#x = LeakyReLU()(x)
x = MaxPooling2D((2, 2), border_mode='same')(x)
pool1 = Dropout(0.25, name='pool1')(x)

x = Convolution2D(16, 7, 7, border_mode='same')(pool1)
x = LeakyReLU()(x)
#x = Convolution2D(32, 3, 3, border_mode='same')(x)
#x = LeakyReLU()(x)
x = MaxPooling2D((2, 2), border_mode='same')(x)
pool2 = Dropout(0.25, name='pool2')(x)

x = Convolution2D(16, 5, 5, border_mode='same')(pool2)
x = LeakyReLU()(x)
#x = Convolution2D(64, 3, 3, border_mode='same')(x)
#x = LeakyReLU()(x)
x = MaxPooling2D((2, 2), border_mode='same')(x)
pool3 = Dropout(0.25, name='pool3')(x)

# -- binary presence part
x = Convolution2D(16, 5, 5, border_mode='valid')(pool3)
x = LeakyReLU()(x)
#x = Convolution2D(16, 3, 3)(x)
#x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool4 = Dropout(0.25, name='pool4')(x)

x = Convolution2D(16, 3, 3, border_mode='valid')(pool4)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool5 = Dropout(0.25, name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(pool5)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# -- location map
x = Convolution2D(4, 3, 3, border_mode='same')(pool3)
x = LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Convolution2D(4, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Convolution2D(4, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)

outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
model.compile(optimizer='adam', loss='binary_crossentropy',
              loss_weights=[1., 0.01])

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_10 (InputLayer)              (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_71 (Convolution2D)   (None, 16, 128, 128)1952        input_10[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_89 (LeakyReLU)           (None, 16, 128, 128)0           convolution2d_71[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_46 (MaxPooling2D)     (None, 16, 64, 64)  0           leakyrelu_89[0][0]
# ____________________________________________________________________________________________________
# pool1 (Dropout)                    (None, 16, 64, 64)  0           maxpooling2d_46[0][0]
# ____________________________________________________________________________________________________
# convolution2d_72 (Convolution2D)   (None, 16, 64, 64)  12560       pool1[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_90 (LeakyReLU)           (None, 16, 64, 64)  0           convolution2d_72[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_47 (MaxPooling2D)     (None, 16, 32, 32)  0           leakyrelu_90[0][0]
# ____________________________________________________________________________________________________
# pool2 (Dropout)                    (None, 16, 32, 32)  0           maxpooling2d_47[0][0]
# ____________________________________________________________________________________________________
# convolution2d_73 (Convolution2D)   (None, 16, 32, 32)  6416        pool2[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_91 (LeakyReLU)           (None, 16, 32, 32)  0           convolution2d_73[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_48 (MaxPooling2D)     (None, 16, 16, 16)  0           leakyrelu_91[0][0]
# ____________________________________________________________________________________________________
# pool3 (Dropout)                    (None, 16, 16, 16)  0           maxpooling2d_48[0][0]
# ____________________________________________________________________________________________________
# convolution2d_74 (Convolution2D)   (None, 16, 12, 12)  6416        pool3[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_92 (LeakyReLU)           (None, 16, 12, 12)  0           convolution2d_74[0][0]
# ____________________________________________________________________________________________________
# convolution2d_76 (Convolution2D)   (None, 4, 16, 16)   580         pool3[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_49 (MaxPooling2D)     (None, 16, 6, 6)    0           leakyrelu_92[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_96 (LeakyReLU)           (None, 4, 16, 16)   0           convolution2d_76[0][0]
# ____________________________________________________________________________________________________
# pool4 (Dropout)                    (None, 16, 6, 6)    0           maxpooling2d_49[0][0]
# ____________________________________________________________________________________________________
# convolution2d_75 (Convolution2D)   (None, 16, 4, 4)    2320        pool4[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_26 (UpSampling2D)     (None, 4, 32, 32)   0           leakyrelu_96[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_93 (LeakyReLU)           (None, 16, 4, 4)    0           convolution2d_75[0][0]
# ____________________________________________________________________________________________________
# merge_19 (Merge)                   (None, 20, 32, 32)  0           upsampling2d_26[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_77 (Convolution2D)   (None, 4, 32, 32)   724         merge_19[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_50 (MaxPooling2D)     (None, 16, 2, 2)    0           leakyrelu_93[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_97 (LeakyReLU)           (None, 4, 32, 32)   0           convolution2d_77[0][0]
# ____________________________________________________________________________________________________
# pool5 (Dropout)                    (None, 16, 2, 2)    0           maxpooling2d_50[0][0]
# ____________________________________________________________________________________________________
# flatten_10 (Flatten)               (None, 64)          0           pool5[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_27 (UpSampling2D)     (None, 4, 64, 64)   0           leakyrelu_97[0][0]
# ____________________________________________________________________________________________________
# dense_19 (Dense)                   (None, 32)          2080        flatten_10[0][0]
# ____________________________________________________________________________________________________
# merge_20 (Merge)                   (None, 20, 64, 64)  0           upsampling2d_27[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_78 (Convolution2D)   (None, 4, 64, 64)   724         merge_20[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_94 (LeakyReLU)           (None, 32)          0           dense_19[0][0]
# ____________________________________________________________________________________________________
# dense_20 (Dense)                   (None, 16)          528         leakyrelu_94[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_98 (LeakyReLU)           (None, 4, 64, 64)   0           convolution2d_78[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_95 (LeakyReLU)           (None, 16)          0           dense_20[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_28 (UpSampling2D)     (None, 4, 128, 128) 0           leakyrelu_98[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_95[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 37          upsampling2d_28[0][0]
# ====================================================================================================
# Total params: 34354
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

from keras.utils.visualize_util import plot
plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {'outmap': Y_train, 'outbin': Y_train_binary},
        batch_size=64,
        validation_data=(X_test, {'outmap': Y_test, 'outbin': Y_test_binary}),
        nb_epoch=60,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    pl.plot(history.history['loss'], label='train loss')
    pl.plot(history.history['val_loss'], c='g', label='val loss')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(open(os.path.join(model_dir, 'architecture.json')).read())
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adagrad', loss='mse')
    
    print_summary(model.layers)
# Out:
# Train on 3515 samples, validate on 391 samples
# Epoch 1/60
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.1959 - outmap_loss: 0.1857 - outbin_loss: 1.0206Epoch 00000: val_loss improved from inf to 0.11183, saving model to weights.hdf5
# 3515/3515 [==============================] - 10s - loss: 0.1944 - outmap_loss: 0.1842 - outbin_loss: 1.0161 - val_loss: 0.1118 - val_outmap_loss: 0.1050 - val_outbin_loss: 0.6817
# Epoch 2/60
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.1045 - outmap_loss: 0.0975 - outbin_loss: 0.7051Epoch 00001: val_loss improved from 0.11183 to 0.10167, saving model to weights.hdf5
# 3515/3515 [==============================] - 10s - loss: 0.1044 - outmap_loss: 0.0973 - outbin_loss: 0.7052 - val_loss: 0.1017 - val_outmap_loss: 0.0951 - val_outbin_loss: 0.6622
# Epoch 3/60
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0896 - outmap_loss: 0.0827 - outbin_loss: 0.6911Epoch 00002: val_loss improved from 0.10167 to 0.08604, saving model to weights.hdf5
# 3515/3515 [==============================] - 10s - loss: 0.0895 - outmap_loss: 0.0826 - outbin_loss: 0.6912 - val_loss: 0.0860 - val_outmap_loss: 0.0795 - val_outbin_loss: 0.6572
# Epoch 4/60
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0723 - outmap_loss: 0.0655 - outbin_loss: 0.6826Epoch 00003: val_loss improved from 0.08604 to 0.08392, saving model to weights.hdf5
# 3515/3515 [==============================] - 11s - loss: 0.0723 - outmap_loss: 0.0655 - outbin_loss: 0.6828 - val_loss: 0.0839 - val_outmap_loss: 0.0772 - val_outbin_loss: 0.6669
# Epoch 5/60
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0600 - outmap_loss: 0.0534 - outbin_loss: 0.6559Epoch 00004: val_loss improved from 0.08392 to 0.07952, saving model to weights.hdf5
# 3515/3515 [==============================] - 10s - loss: 0.0600 - outmap_loss: 0.0534 - outbin_loss: 0.6553 - val_loss: 0.0795 - val_outmap_loss: 0.0731 - val_outbin_loss: 0.6452
# Epoch 6/60
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0227 - outmap_loss: 0.0199 - outbin_loss: 0.2816Epoch 00059: val_loss did not improve
# 3515/3515 [==============================] - 10s - loss: 0.0227 - outmap_loss: 0.0199 - outbin_loss: 0.2820 - val_loss: 0.0236 - val_outmap_loss: 0.0208 - val_outbin_loss: 0.2767

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights.hdf5'))

# %%
def predict(X):
    Y_pred, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > 0.5
    for i in range(Y_pred.shape[0]):
        # Clear prediction where we detect to little pixels
        # Figure it out by
        # pl.hist(np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1))
        if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < 0.5:
            Y_pred[i,:] = 0
    return Y_pred, Y_pred_proba

Y_pred, Y_pred_proba = predict(X_test)
Y_full_pred, Y_full_pred_proba = predict(X_full)

print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.697765118317
# full set score :  0.614531135806

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[-450:-445]:
for i in lowest[:5]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    
    blob_proba = np.mean(Y_pred_proba[i][Y_pred[i] == 1])
    pl.title('prediction proba %f' % blob_proba)
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
_d = np.load('../../data_128_test.npz')
X_submit = _d['X']
test_fnames = _d['test_fnames']
Y_pred, Y_pred_proba = predict(X_submit[:,None,:,:])

# %%
OUTDIR='../../preds'
if os.path.exists(OUTDIR):
    shutil.rmtree(OUTDIR)
utils.mkdir_p(OUTDIR)

for i in range(Y_pred.shape[0]):
    imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
    basename = os.path.splitext(test_fnames[i])[0]
    cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
