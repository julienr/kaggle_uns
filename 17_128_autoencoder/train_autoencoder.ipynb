# %% [markdown]
# ## Autoencoder

# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
_d = np.load('../data/data_128_test.npz')
X_submit = _d['X'][:,None,:,:]

# %%
print X.shape
print Y.shape
print X_submit.shape
# Out:
# (3906, 128, 128)
# (3906, 128, 128)
# (5508, 1, 128, 128)

# %%
nsamples = X.shape[0]

train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
#train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.25)
X_train = X[train_indices][:,None,:,:]
Y_train_binary = Y_binary[train_indices][:,None]
Y_train = Y[train_indices][:,None,:,:]
X_test = X[test_indices][:,None,:,:]
Y_test_binary = Y_binary[test_indices][:,None]
Y_test = Y[test_indices][:,None,:,:]

# %%
X_train2 = np.concatenate((X_train, X_submit), axis=0)
print X_train2.shape
# Out:
# (9023, 1, 128, 128)

# %%
print X_train.shape
print Y_train.shape
print Y_train_binary.shape
print X_train.min(), X_train.max()
# Out:
# (3515, 1, 128, 128)
# (3515, 1, 128, 128)
# (3515, 1)
# 0.0 1.0

# %%
#pl.imshow(X_train[0].squeeze())
pl.imshow(Y_train[0].squeeze())
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float16'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D
from keras.layers import LeakyReLU, ZeroPadding2D
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
input_img = x = Input(shape=input_shape)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool1 = x = Dropout(0.25, name='pool1')(x)

x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool2 = x = Dropout(0.1, name='pool2')(x)

x = Convolution2D(64, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)
x = Convolution2D(64, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool3 = x = Dropout(0.1, name='pool3')(x)

x = Convolution2D(64, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)
x = Convolution2D(64, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)
pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)
pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# -- decoding
x = UpSampling2D((2, 2))(x)
x = Convolution2D(64, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)
x = Convolution2D(64, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)

x = UpSampling2D((2, 2))(x)
x = Convolution2D(64, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)
x = Convolution2D(64, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)

x = UpSampling2D((2, 2))(x)
x = Convolution2D(64, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)
x = Convolution2D(64, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)

x = UpSampling2D((2, 2))(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)

x = UpSampling2D((2, 2))(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = LeakyReLU()(x)

x = Convolution2D(1, 3, 3, border_mode='same')(x)
outimg = x = Activation('sigmoid')(x)
#outimg = x = LeakyReLU(name='outimg')(x)

model = Model(
    input=input_img,
    output=outimg
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
model.compile(optimizer='adam', loss='binary_crossentropy')

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_16 (InputLayer)              (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_240 (Convolution2D)  (None, 16, 128, 128)160         input_16[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_237 (LeakyReLU)          (None, 16, 128, 128)0           convolution2d_240[0][0]
# ____________________________________________________________________________________________________
# convolution2d_241 (Convolution2D)  (None, 16, 128, 128)2320        leakyrelu_237[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_238 (LeakyReLU)          (None, 16, 128, 128)0           convolution2d_241[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_58 (MaxPooling2D)     (None, 16, 64, 64)  0           leakyrelu_238[0][0]
# ____________________________________________________________________________________________________
# pool1 (Dropout)                    (None, 16, 64, 64)  0           maxpooling2d_58[0][0]
# ____________________________________________________________________________________________________
# convolution2d_242 (Convolution2D)  (None, 32, 64, 64)  4640        pool1[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_239 (LeakyReLU)          (None, 32, 64, 64)  0           convolution2d_242[0][0]
# ____________________________________________________________________________________________________
# convolution2d_243 (Convolution2D)  (None, 32, 64, 64)  9248        leakyrelu_239[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_240 (LeakyReLU)          (None, 32, 64, 64)  0           convolution2d_243[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_59 (MaxPooling2D)     (None, 32, 32, 32)  0           leakyrelu_240[0][0]
# ____________________________________________________________________________________________________
# pool2 (Dropout)                    (None, 32, 32, 32)  0           maxpooling2d_59[0][0]
# ____________________________________________________________________________________________________
# convolution2d_244 (Convolution2D)  (None, 64, 32, 32)  18496       pool2[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_241 (LeakyReLU)          (None, 64, 32, 32)  0           convolution2d_244[0][0]
# ____________________________________________________________________________________________________
# convolution2d_245 (Convolution2D)  (None, 64, 32, 32)  36928       leakyrelu_241[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_242 (LeakyReLU)          (None, 64, 32, 32)  0           convolution2d_245[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_60 (MaxPooling2D)     (None, 64, 16, 16)  0           leakyrelu_242[0][0]
# ____________________________________________________________________________________________________
# pool3 (Dropout)                    (None, 64, 16, 16)  0           maxpooling2d_60[0][0]
# ____________________________________________________________________________________________________
# convolution2d_246 (Convolution2D)  (None, 64, 16, 16)  36928       pool3[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_243 (LeakyReLU)          (None, 64, 16, 16)  0           convolution2d_246[0][0]
# ____________________________________________________________________________________________________
# convolution2d_247 (Convolution2D)  (None, 64, 16, 16)  36928       leakyrelu_243[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_244 (LeakyReLU)          (None, 64, 16, 16)  0           convolution2d_247[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)               (None, 64, 8, 8)    0           leakyrelu_244[0][0]
# ____________________________________________________________________________________________________
# convolution2d_248 (Convolution2D)  (None, 32, 8, 8)    18464       pool4[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_245 (LeakyReLU)          (None, 32, 8, 8)    0           convolution2d_248[0][0]
# ____________________________________________________________________________________________________
# convolution2d_249 (Convolution2D)  (None, 16, 8, 8)    4624        leakyrelu_245[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_246 (LeakyReLU)          (None, 16, 8, 8)    0           convolution2d_249[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)               (None, 16, 4, 4)    0           leakyrelu_246[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_80 (UpSampling2D)     (None, 16, 8, 8)    0           pool5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_250 (Convolution2D)  (None, 64, 8, 8)    9280        upsampling2d_80[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_247 (LeakyReLU)          (None, 64, 8, 8)    0           convolution2d_250[0][0]
# ____________________________________________________________________________________________________
# convolution2d_251 (Convolution2D)  (None, 64, 8, 8)    36928       leakyrelu_247[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_248 (LeakyReLU)          (None, 64, 8, 8)    0           convolution2d_251[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_81 (UpSampling2D)     (None, 64, 16, 16)  0           leakyrelu_248[0][0]
# ____________________________________________________________________________________________________
# convolution2d_252 (Convolution2D)  (None, 64, 16, 16)  36928       upsampling2d_81[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_249 (LeakyReLU)          (None, 64, 16, 16)  0           convolution2d_252[0][0]
# ____________________________________________________________________________________________________
# convolution2d_253 (Convolution2D)  (None, 64, 16, 16)  36928       leakyrelu_249[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_250 (LeakyReLU)          (None, 64, 16, 16)  0           convolution2d_253[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_82 (UpSampling2D)     (None, 64, 32, 32)  0           leakyrelu_250[0][0]
# ____________________________________________________________________________________________________
# convolution2d_254 (Convolution2D)  (None, 64, 32, 32)  36928       upsampling2d_82[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_251 (LeakyReLU)          (None, 64, 32, 32)  0           convolution2d_254[0][0]
# ____________________________________________________________________________________________________
# convolution2d_255 (Convolution2D)  (None, 64, 32, 32)  36928       leakyrelu_251[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_252 (LeakyReLU)          (None, 64, 32, 32)  0           convolution2d_255[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_83 (UpSampling2D)     (None, 64, 64, 64)  0           leakyrelu_252[0][0]
# ____________________________________________________________________________________________________
# convolution2d_256 (Convolution2D)  (None, 32, 64, 64)  18464       upsampling2d_83[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_253 (LeakyReLU)          (None, 32, 64, 64)  0           convolution2d_256[0][0]
# ____________________________________________________________________________________________________
# convolution2d_257 (Convolution2D)  (None, 32, 64, 64)  9248        leakyrelu_253[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_254 (LeakyReLU)          (None, 32, 64, 64)  0           convolution2d_257[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_84 (UpSampling2D)     (None, 32, 128, 128)0           leakyrelu_254[0][0]
# ____________________________________________________________________________________________________
# convolution2d_258 (Convolution2D)  (None, 16, 128, 128)4624        upsampling2d_84[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_255 (LeakyReLU)          (None, 16, 128, 128)0           convolution2d_258[0][0]
# ____________________________________________________________________________________________________
# convolution2d_259 (Convolution2D)  (None, 16, 128, 128)2320        leakyrelu_255[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_256 (LeakyReLU)          (None, 16, 128, 128)0           convolution2d_259[0][0]
# ____________________________________________________________________________________________________
# convolution2d_260 (Convolution2D)  (None, 1, 128, 128) 145         leakyrelu_256[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)          (None, 1, 128, 128) 0           convolution2d_260[0][0]
# ====================================================================================================
# Total params: 397457
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train2,
        X_train2,
        batch_size=64,
        validation_data=(X_test, X_test),
        nb_epoch=80,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    pl.plot(history.history['loss'], label='train loss')
    pl.plot(history.history['val_loss'], c='g', label='val loss')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(open(os.path.join(model_dir, 'architecture.json')).read())
    model.load_weights(os.path.join(model_dir, 'weights.h5'))
    model.compile(optimizer='adagrad', loss='mse')
    
    print_summary(model.layers)
# Out:
# Train on 9023 samples, validate on 391 samples
# Epoch 1/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6437Epoch 00000: val_loss improved from inf to 0.63185, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6436 - val_loss: 0.6318
# Epoch 2/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6247Epoch 00001: val_loss improved from 0.63185 to 0.62619, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6247 - val_loss: 0.6262
# Epoch 3/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6218Epoch 00002: val_loss improved from 0.62619 to 0.62282, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6219 - val_loss: 0.6228
# Epoch 4/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6200Epoch 00003: val_loss did not improve
# 9023/9023 [==============================] - 95s - loss: 0.6199 - val_loss: 0.6229
# Epoch 5/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6184Epoch 00004: val_loss improved from 0.62282 to 0.62199, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6184 - val_loss: 0.6220
# Epoch 6/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6170Epoch 00005: val_loss improved from 0.62199 to 0.61750, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6170 - val_loss: 0.6175
# Epoch 7/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6155Epoch 00006: val_loss improved from 0.61750 to 0.61665, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6155 - val_loss: 0.6166
# Epoch 8/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6144Epoch 00007: val_loss improved from 0.61665 to 0.61621, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6144 - val_loss: 0.6162
# Epoch 9/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6127Epoch 00008: val_loss improved from 0.61621 to 0.61387, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6127 - val_loss: 0.6139
# Epoch 10/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6118Epoch 00009: val_loss improved from 0.61387 to 0.61248, saving model to weights.hdf5
# 9023/9023 [==============================] - 96s - loss: 0.6118 - val_loss: 0.6125
# Epoch 11/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6108Epoch 00010: val_loss improved from 0.61248 to 0.61199, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6108 - val_loss: 0.6120
# Epoch 12/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6099Epoch 00011: val_loss improved from 0.61199 to 0.61186, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6099 - val_loss: 0.6119
# Epoch 13/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6090Epoch 00012: val_loss improved from 0.61186 to 0.61032, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6091 - val_loss: 0.6103
# Epoch 14/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6084Epoch 00013: val_loss improved from 0.61032 to 0.60954, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6084 - val_loss: 0.6095
# Epoch 15/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6075Epoch 00014: val_loss improved from 0.60954 to 0.60904, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6075 - val_loss: 0.6090
# Epoch 16/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6069Epoch 00015: val_loss did not improve
# 9023/9023 [==============================] - 95s - loss: 0.6069 - val_loss: 0.6093
# Epoch 17/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6067Epoch 00016: val_loss did not improve
# 9023/9023 [==============================] - 95s - loss: 0.6067 - val_loss: 0.6092
# Epoch 18/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6057Epoch 00017: val_loss improved from 0.60904 to 0.60808, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6057 - val_loss: 0.6081
# Epoch 19/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6053Epoch 00018: val_loss improved from 0.60808 to 0.60790, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6053 - val_loss: 0.6079
# Epoch 20/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6047Epoch 00019: val_loss improved from 0.60790 to 0.60653, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6047 - val_loss: 0.6065
# Epoch 21/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6044Epoch 00020: val_loss improved from 0.60653 to 0.60631, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6044 - val_loss: 0.6063
# Epoch 22/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6038Epoch 00021: val_loss improved from 0.60631 to 0.60582, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6038 - val_loss: 0.6058
# Epoch 23/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6034Epoch 00022: val_loss did not improve
# 9023/9023 [==============================] - 95s - loss: 0.6034 - val_loss: 0.6064
# Epoch 24/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6029Epoch 00023: val_loss improved from 0.60582 to 0.60513, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6030 - val_loss: 0.6051
# Epoch 25/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6026Epoch 00024: val_loss improved from 0.60513 to 0.60472, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6027 - val_loss: 0.6047
# Epoch 26/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6021Epoch 00025: val_loss improved from 0.60472 to 0.60445, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6021 - val_loss: 0.6044
# Epoch 27/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6018Epoch 00026: val_loss improved from 0.60445 to 0.60419, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6018 - val_loss: 0.6042
# Epoch 28/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6014Epoch 00027: val_loss did not improve
# 9023/9023 [==============================] - 95s - loss: 0.6015 - val_loss: 0.6043
# Epoch 29/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6013Epoch 00028: val_loss improved from 0.60419 to 0.60376, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6013 - val_loss: 0.6038
# Epoch 30/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6008Epoch 00029: val_loss did not improve
# 9023/9023 [==============================] - 95s - loss: 0.6008 - val_loss: 0.6041
# Epoch 31/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6008Epoch 00030: val_loss did not improve
# 9023/9023 [==============================] - 95s - loss: 0.6008 - val_loss: 0.6041
# Epoch 32/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6002Epoch 00031: val_loss improved from 0.60376 to 0.60295, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.6002 - val_loss: 0.6030
# Epoch 33/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.6002Epoch 00032: val_loss improved from 0.60295 to 0.60288, saving model to weights.hdf5
# 9023/9023 [==============================] - 100s - loss: 0.6001 - val_loss: 0.6029
# Epoch 34/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5997Epoch 00033: val_loss improved from 0.60288 to 0.60270, saving model to weights.hdf5
# 9023/9023 [==============================] - 100s - loss: 0.5997 - val_loss: 0.6027
# Epoch 35/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5995Epoch 00034: val_loss did not improve
# 9023/9023 [==============================] - 99s - loss: 0.5995 - val_loss: 0.6030
# Epoch 36/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5991Epoch 00035: val_loss did not improve
# 9023/9023 [==============================] - 99s - loss: 0.5991 - val_loss: 0.6035
# Epoch 37/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5992Epoch 00036: val_loss improved from 0.60270 to 0.60187, saving model to weights.hdf5
# 9023/9023 [==============================] - 98s - loss: 0.5991 - val_loss: 0.6019
# Epoch 38/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5988Epoch 00037: val_loss did not improve
# 9023/9023 [==============================] - 95s - loss: 0.5989 - val_loss: 0.6061
# Epoch 39/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5988Epoch 00038: val_loss improved from 0.60187 to 0.60169, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.5988 - val_loss: 0.6017
# Epoch 40/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5988Epoch 00039: val_loss did not improve
# 9023/9023 [==============================] - 95s - loss: 0.5988 - val_loss: 0.6040
# Epoch 41/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5983Epoch 00040: val_loss improved from 0.60169 to 0.60108, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.5983 - val_loss: 0.6011
# Epoch 42/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5979Epoch 00041: val_loss improved from 0.60108 to 0.60085, saving model to weights.hdf5
# 9023/9023 [==============================] - 95s - loss: 0.5979 - val_loss: 0.6009
# Epoch 43/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5978Epoch 00042: val_loss did not improve
# 9023/9023 [==============================] - 95s - loss: 0.5978 - val_loss: 0.6019
# Epoch 44/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5976Epoch 00043: val_loss improved from 0.60085 to 0.60079, saving model to weights.hdf5
# 9023/9023 [==============================] - 99s - loss: 0.5976 - val_loss: 0.6008
# Epoch 45/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5975Epoch 00044: val_loss improved from 0.60079 to 0.60063, saving model to weights.hdf5
# 9023/9023 [==============================] - 100s - loss: 0.5975 - val_loss: 0.6006
# Epoch 46/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5974Epoch 00045: val_loss improved from 0.60063 to 0.60059, saving model to weights.hdf5
# 9023/9023 [==============================] - 100s - loss: 0.5974 - val_loss: 0.6006
# Epoch 47/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5975Epoch 00046: val_loss improved from 0.60059 to 0.60040, saving model to weights.hdf5
# 9023/9023 [==============================] - 100s - loss: 0.5975 - val_loss: 0.6004
# Epoch 48/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5969Epoch 00047: val_loss improved from 0.60040 to 0.60018, saving model to weights.hdf5
# 9023/9023 [==============================] - 100s - loss: 0.5969 - val_loss: 0.6002
# Epoch 49/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5968Epoch 00048: val_loss did not improve
# 9023/9023 [==============================] - 100s - loss: 0.5968 - val_loss: 0.6002
# Epoch 50/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5967Epoch 00049: val_loss improved from 0.60018 to 0.60011, saving model to weights.hdf5
# 9023/9023 [==============================] - 99s - loss: 0.5967 - val_loss: 0.6001
# Epoch 51/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5966Epoch 00050: val_loss improved from 0.60011 to 0.59987, saving model to weights.hdf5
# 9023/9023 [==============================] - 99s - loss: 0.5966 - val_loss: 0.5999
# Epoch 52/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5963Epoch 00051: val_loss did not improve
# 9023/9023 [==============================] - 99s - loss: 0.5963 - val_loss: 0.5999
# Epoch 53/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5962Epoch 00052: val_loss improved from 0.59987 to 0.59972, saving model to weights.hdf5
# 9023/9023 [==============================] - 99s - loss: 0.5963 - val_loss: 0.5997
# Epoch 54/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5961Epoch 00053: val_loss did not improve
# 9023/9023 [==============================] - 99s - loss: 0.5961 - val_loss: 0.5998
# Epoch 55/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5960Epoch 00054: val_loss did not improve
# 9023/9023 [==============================] - 99s - loss: 0.5960 - val_loss: 0.5998
# Epoch 56/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5970Epoch 00055: val_loss improved from 0.59972 to 0.59962, saving model to weights.hdf5
# 9023/9023 [==============================] - 99s - loss: 0.5970 - val_loss: 0.5996
# Epoch 57/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5956Epoch 00056: val_loss improved from 0.59962 to 0.59932, saving model to weights.hdf5
# 9023/9023 [==============================] - 99s - loss: 0.5956 - val_loss: 0.5993
# Epoch 58/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5956Epoch 00057: val_loss did not improve
# 9023/9023 [==============================] - 99s - loss: 0.5956 - val_loss: 0.5996
# Epoch 59/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5955Epoch 00058: val_loss did not improve
# 9023/9023 [==============================] - 99s - loss: 0.5955 - val_loss: 0.6002
# Epoch 60/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5955Epoch 00059: val_loss improved from 0.59932 to 0.59919, saving model to weights.hdf5
# 9023/9023 [==============================] - 99s - loss: 0.5954 - val_loss: 0.5992
# Epoch 61/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5953Epoch 00060: val_loss improved from 0.59919 to 0.59895, saving model to weights.hdf5
# 9023/9023 [==============================] - 99s - loss: 0.5953 - val_loss: 0.5990
# Epoch 62/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5955Epoch 00061: val_loss improved from 0.59895 to 0.59880, saving model to weights.hdf5
# 9023/9023 [==============================] - 100s - loss: 0.5955 - val_loss: 0.5988
# Epoch 63/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5951Epoch 00062: val_loss did not improve
# 9023/9023 [==============================] - 100s - loss: 0.5951 - val_loss: 0.5989
# Epoch 64/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5950Epoch 00063: val_loss did not improve
# 9023/9023 [==============================] - 100s - loss: 0.5950 - val_loss: 0.5990
# Epoch 65/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5949Epoch 00064: val_loss improved from 0.59880 to 0.59879, saving model to weights.hdf5
# 9023/9023 [==============================] - 100s - loss: 0.5949 - val_loss: 0.5988
# Epoch 66/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5948Epoch 00065: val_loss did not improve
# 9023/9023 [==============================] - 100s - loss: 0.5948 - val_loss: 0.5988
# Epoch 67/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5948Epoch 00066: val_loss did not improve
# 9023/9023 [==============================] - 100s - loss: 0.5948 - val_loss: 0.5989
# Epoch 68/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5946Epoch 00067: val_loss improved from 0.59879 to 0.59853, saving model to weights.hdf5
# 9023/9023 [==============================] - 100s - loss: 0.5946 - val_loss: 0.5985
# Epoch 69/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5946Epoch 00068: val_loss did not improve
# 9023/9023 [==============================] - 100s - loss: 0.5946 - val_loss: 0.5987
# Epoch 70/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5945Epoch 00069: val_loss did not improve
# 9023/9023 [==============================] - 100s - loss: 0.5945 - val_loss: 0.5986
# Epoch 71/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5943Epoch 00070: val_loss did not improve
# 9023/9023 [==============================] - 100s - loss: 0.5944 - val_loss: 0.5992
# Epoch 72/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5942Epoch 00071: val_loss did not improve
# 9023/9023 [==============================] - 100s - loss: 0.5943 - val_loss: 0.5987
# Epoch 73/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5943Epoch 00072: val_loss did not improve
# 9023/9023 [==============================] - 100s - loss: 0.5943 - val_loss: 0.5986
# Epoch 74/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5941Epoch 00073: val_loss improved from 0.59853 to 0.59813, saving model to weights.hdf5
# 9023/9023 [==============================] - 100s - loss: 0.5941 - val_loss: 0.5981
# Epoch 75/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5941Epoch 00074: val_loss did not improve
# 9023/9023 [==============================] - 100s - loss: 0.5941 - val_loss: 0.5984
# Epoch 76/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5940Epoch 00075: val_loss did not improve
# 9023/9023 [==============================] - 100s - loss: 0.5941 - val_loss: 0.5984
# Epoch 77/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5939Epoch 00076: val_loss improved from 0.59813 to 0.59811, saving model to weights.hdf5
# 9023/9023 [==============================] - 100s - loss: 0.5939 - val_loss: 0.5981
# Epoch 78/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5939Epoch 00077: val_loss did not improve
# 9023/9023 [==============================] - 100s - loss: 0.5939 - val_loss: 0.5981
# Epoch 79/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5938Epoch 00078: val_loss did not improve
# 9023/9023 [==============================] - 100s - loss: 0.5938 - val_loss: 0.5982
# Epoch 80/80
# 8960/9023 [============================>.] - ETA: 0s - loss: 0.5937Epoch 00079: val_loss improved from 0.59811 to 0.59781, saving model to weights.hdf5
# 9023/9023 [==============================] - 99s - loss: 0.5937 - val_loss: 0.5978

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights.hdf5'))

# %%
X_test_pred = model.predict(X_test)

# %%
#i = 50
#i = 47

#for i in lowest[2000:2005]:
for i in np.random.choice(X_test_pred.shape[0], 5, replace=False):
    pl.figure(figsize=(12, 3))
    pl.subplot(121)
    pl.imshow(X_test[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(122)
    pl.imshow(X_test_pred[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Visualize filters
#
# See http://blog.keras.io/how-convolutional-neural-networks-see-the-world.html

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
def dream_layer_filter(layer_name, filter_index):

    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(40):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(8):
        pl.subplot(2, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)
