# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']
X_pids = _d['pids']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
print X.dtype
print Y.dtype
# Out:
# (3906, 128, 128)
# (3906, 128, 128)
# float32
# float32

# %%
if False:
    # Split patients in train/test
    train_pids, test_pids = train_test_split(np.unique(X_pids), test_size=0.1)
    print train_pids
    print test_pids
    
    train_indices = np.flatnonzero(np.in1d(X_pids, train_pids))
    test_indices = np.flatnonzero(np.in1d(X_pids, test_pids))
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]
else:
    nsamples = X.shape[0]

    #train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]

# %%
import skimage.transform as sktransf

def rand_float(rng):
    return rng[0] + np.random.random() * (rng[1] - rng[0])

def generate_image(X_img, Y_img, angle_range=None, zoom_range=None, shear_range=None, horiz_shift_range=None,
                   vert_shift_range=None):
    """
    Randomly shift an image by resizing and then random croping
    the resized image
    """
    if angle_range is None:
        angle_range = (-5, 5)
    if zoom_range is None:
        zoom_range = (0.8, 1.2)
    if shear_range is None:
        shear_range = (-5, 5) # shear angle in degrees
    if horiz_shift_range is None:
        horiz_shift_range = (-5, 5)
    if vert_shift_range is None:
        vert_shift_range = (-5, 5)
    inshape = X_img.shape
    
    X2 = X_img.copy()
    Y2 = Y_img.copy()
    
    # -- random rotation
    angle = np.deg2rad(rand_float(angle_range))
    zoom = rand_float(zoom_range)
    shear = np.deg2rad(rand_float(shear_range))
    horiz_shift = rand_float(horiz_shift_range)
    vert_shift = rand_float(vert_shift_range)
    
    tform = sktransf.AffineTransform(
        scale=(zoom, zoom),
        rotation=angle,
        shear=shear,
        translation=(horiz_shift, vert_shift)
    )
    X2 = sktransf.warp(X2, tform, order=5, mode='edge')
    Y2 = sktransf.warp(Y2, tform, order=1)

    # gaussian noise
    #noise_scale = rand_float((0, 0.1))
    #X2 += np.random.normal(scale=noise_scale, size=X2.shape)
    Y2 = Y2 > 0.5
    return X2[None,:,:].astype(np.float32), Y2[None,:,:].astype(np.float32)

X_train_augmented = []
Y_train_augmented = []
for i in range(X_train.shape[0]):
    if i % 10 == 0:
        print '\r%d / %d' % (i, X_train.shape[0]),
        sys.stdout.flush()
    X_train_augmented.append(X_train[i])
    Y_train_augmented.append(Y_train[i])
    for j in range(2):
        X2, Y2 = generate_image(X_train[i].squeeze(), Y_train[i].squeeze())
        X_train_augmented.append(X2)
        Y_train_augmented.append(Y2)
# Out:
# 3510 / 3515

# %%
X_train = np.array(X_train_augmented, dtype=np.float32)
Y_train = np.array(Y_train_augmented, dtype=np.float32)

Y_train_binary = np.sum(np.sum(Y_train.squeeze(), axis=2), axis=1) > 0
Y_train_binary = Y_train_binary.astype(np.float32)
Y_train_binary = Y_train_binary[:,None]

# %%
print X_train.shape
print Y_train.shape
print X_test.shape
print X_train.min(), X_train.max()
# Out:
# (10545, 1, 128, 128)
# (10545, 1, 128, 128)
# (391, 1, 128, 128)
# 0.0 1.0

# %%
import cv2
def _resize(Y, outshape):
    return cv2.resize(Y.squeeze(), outshape, interpolation=cv2.INTER_AREA)[None, :, :]
Y_train_64 = np.array([_resize(img, (64, 64)) for img in Y_train])
Y_test_64 = np.array([_resize(img, (64, 64)) for img in Y_test])
Y_train_32 = np.array([_resize(img, (32, 32)) for img in Y_train])
Y_test_32 = np.array([_resize(img, (32, 32)) for img in Y_test])

# %%
with_bp = np.flatnonzero(np.sum(np.sum(np.sum(Y_train, axis=1), axis=1), axis=1))

# %%
for bpi in range(11, 14):
    i = with_bp[bpi]
    pl.figure(figsize=(16, 4))
    pl.subplot(141)
    pl.imshow(X_train[i].squeeze())
    pl.subplot(142)
    pl.imshow(Y_train[i].squeeze())
    pl.subplot(143)
    pl.imshow(Y_train_64[i].squeeze(), interpolation='nearest')
    pl.colorbar()
    pl.subplot(144)
    pl.imshow(Y_train_32[i].squeeze(), interpolation='nearest')
    pl.colorbar()

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float32'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense
from keras.layers import LeakyReLU, BatchNormalization
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
import keras.backend as K
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
from keras.layers import Layer, InputSpec
import keras.initializations
import keras.backend as K

class Maxout2D(Layer):
    def __init__(self, output_dim, cardinality, init='glorot_uniform', **kwargs):
        super(Maxout2D, self).__init__(**kwargs)
        # the k of the maxout paper
        self.cardinality = cardinality
        # the m of the maxout paper
        self.output_dim = output_dim
        self.init = keras.initializations.get(init)
    
    def build(self, input_shape):
        self.input_dim = input_shape[1]
        self.input_spec = [InputSpec(dtype=K.floatx(),
                                     shape=(None, input_shape[1], input_shape[2], input_shape[3]))]
        self.W = self.init((self.input_dim, self.output_dim, self.cardinality),
                           name='{}_W'.format(self.name))
        self.b = K.zeros((self.output_dim, self.cardinality))
        self.trainable_weights = [self.W, self.b]
              
    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        # flatten the spatial dimensions
        flat_x = K.reshape(x, (-1, input_shape[1], input_shape[2] * input_shape[3]))
        output = K.dot(
            K.permute_dimensions(flat_x, (0, 2, 1)),
            K.permute_dimensions(self.W, (1, 0, 2))
        )
        output += K.reshape(self.b, (1, 1, self.output_dim, self.cardinality))
        output = K.max(output, axis=3)
        output = output.transpose(0, 2, 1)
        output = K.reshape(output, (-1, self.output_dim, input_shape[2], input_shape[3]))
        return output
    
    def get_output_shape_for(self, input_shape):
        return (input_shape[0], self.output_dim, input_shape[2], input_shape[3])
    
    def get_config(self):
        config = {
            'output_dim': self.output_dim,
            'cardinality': self.cardinality
        }
        base_config = super(Maxout2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
input_img = x = Input(shape=input_shape, name='input_img')
x = Dropout(0.25)(x)
x = Convolution2D(16, 3, 3, border_mode='same')(input_img)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool1 = x = MaxPooling2D((2, 2), name='pool1')(x)

x = Dropout(0.25)(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool2 = x = MaxPooling2D((2, 2), name='pool2')(x)

x = Dropout(0.25)(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool3 = x = MaxPooling2D((2, 2), name='pool3')(x)

# -- binary presence part
x = Dropout(0.25)(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

x = Dropout(0.25)(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(pool5)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

x = pool5
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Maxout2D(4, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool4], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Maxout2D(4, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool3], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Maxout2D(4, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Maxout2D(4, 2)(x)
outmap32 = Convolution2D(1, 3, 3, border_mode='same', activation='sigmoid', name='outmap32')(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Maxout2D(4, 2)(x)
outmap64 = Convolution2D(1, 3, 3, border_mode='same', activation='sigmoid', name='outmap64')(x)
x = UpSampling2D((2, 2))(x)

x = Dropout(0.25)(x)
x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(x)
outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outmap64, outmap32, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
metrics={'outbin': 'accuracy'}
model.compile(optimizer='adam', loss='binary_crossentropy',
              loss_weights=[1., 0.2, 0.05, 0.5], metrics=metrics)

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_52 (Convolution2D)   (None, 16, 128, 128)160         input_img[0][0]
# ____________________________________________________________________________________________________
# convolution2d_53 (Convolution2D)   (None, 16, 128, 128)2320        convolution2d_52[0][0]
# ____________________________________________________________________________________________________
# maxout2d_31 (Maxout2D)             (None, 16, 128, 128)544         convolution2d_53[0][0]
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)               (None, 16, 64, 64)  0           maxout2d_31[0][0]
# ____________________________________________________________________________________________________
# dropout_20 (Dropout)               (None, 16, 64, 64)  0           pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_54 (Convolution2D)   (None, 16, 64, 64)  2320        dropout_20[0][0]
# ____________________________________________________________________________________________________
# convolution2d_55 (Convolution2D)   (None, 16, 64, 64)  2320        convolution2d_54[0][0]
# ____________________________________________________________________________________________________
# maxout2d_32 (Maxout2D)             (None, 16, 64, 64)  544         convolution2d_55[0][0]
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)               (None, 16, 32, 32)  0           maxout2d_32[0][0]
# ____________________________________________________________________________________________________
# dropout_21 (Dropout)               (None, 16, 32, 32)  0           pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_56 (Convolution2D)   (None, 16, 32, 32)  2320        dropout_21[0][0]
# ____________________________________________________________________________________________________
# convolution2d_57 (Convolution2D)   (None, 16, 32, 32)  2320        convolution2d_56[0][0]
# ____________________________________________________________________________________________________
# maxout2d_33 (Maxout2D)             (None, 16, 32, 32)  544         convolution2d_57[0][0]
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)               (None, 16, 16, 16)  0           maxout2d_33[0][0]
# ____________________________________________________________________________________________________
# dropout_22 (Dropout)               (None, 16, 16, 16)  0           pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_58 (Convolution2D)   (None, 16, 16, 16)  2320        dropout_22[0][0]
# ____________________________________________________________________________________________________
# convolution2d_59 (Convolution2D)   (None, 16, 16, 16)  2320        convolution2d_58[0][0]
# ____________________________________________________________________________________________________
# maxout2d_34 (Maxout2D)             (None, 16, 16, 16)  544         convolution2d_59[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)               (None, 16, 8, 8)    0           maxout2d_34[0][0]
# ____________________________________________________________________________________________________
# dropout_23 (Dropout)               (None, 16, 8, 8)    0           pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_60 (Convolution2D)   (None, 16, 8, 8)    2320        dropout_23[0][0]
# ____________________________________________________________________________________________________
# convolution2d_61 (Convolution2D)   (None, 16, 8, 8)    2320        convolution2d_60[0][0]
# ____________________________________________________________________________________________________
# maxout2d_35 (Maxout2D)             (None, 16, 8, 8)    544         convolution2d_61[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)               (None, 16, 4, 4)    0           maxout2d_35[0][0]
# ____________________________________________________________________________________________________
# convolution2d_62 (Convolution2D)   (None, 8, 4, 4)     1160        pool5[0][0]
# ____________________________________________________________________________________________________
# maxout2d_36 (Maxout2D)             (None, 4, 4, 4)     72          convolution2d_62[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_16 (UpSampling2D)     (None, 4, 8, 8)     0           maxout2d_36[0][0]
# ____________________________________________________________________________________________________
# merge_13 (Merge)                   (None, 20, 8, 8)    0           upsampling2d_16[0][0]
#                                                                    pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_63 (Convolution2D)   (None, 8, 8, 8)     1448        merge_13[0][0]
# ____________________________________________________________________________________________________
# maxout2d_37 (Maxout2D)             (None, 4, 8, 8)     72          convolution2d_63[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_17 (UpSampling2D)     (None, 4, 16, 16)   0           maxout2d_37[0][0]
# ____________________________________________________________________________________________________
# merge_14 (Merge)                   (None, 20, 16, 16)  0           upsampling2d_17[0][0]
#                                                                    pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_64 (Convolution2D)   (None, 8, 16, 16)   1448        merge_14[0][0]
# ____________________________________________________________________________________________________
# maxout2d_38 (Maxout2D)             (None, 4, 16, 16)   72          convolution2d_64[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_18 (UpSampling2D)     (None, 4, 32, 32)   0           maxout2d_38[0][0]
# ____________________________________________________________________________________________________
# merge_15 (Merge)                   (None, 20, 32, 32)  0           upsampling2d_18[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_65 (Convolution2D)   (None, 8, 32, 32)   1448        merge_15[0][0]
# ____________________________________________________________________________________________________
# maxout2d_39 (Maxout2D)             (None, 4, 32, 32)   72          convolution2d_65[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_19 (UpSampling2D)     (None, 4, 64, 64)   0           maxout2d_39[0][0]
# ____________________________________________________________________________________________________
# merge_16 (Merge)                   (None, 20, 64, 64)  0           upsampling2d_19[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_66 (Convolution2D)   (None, 8, 64, 64)   1448        merge_16[0][0]
# ____________________________________________________________________________________________________
# flatten_4 (Flatten)                (None, 256)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# maxout2d_40 (Maxout2D)             (None, 4, 64, 64)   72          convolution2d_66[0][0]
# ____________________________________________________________________________________________________
# dense_7 (Dense)                    (None, 32)          8224        flatten_4[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_20 (UpSampling2D)     (None, 4, 128, 128) 0           maxout2d_40[0][0]
# ____________________________________________________________________________________________________
# dropout_24 (Dropout)               (None, 4, 128, 128) 0           upsampling2d_20[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_7 (LeakyReLU)            (None, 32)          0           dense_7[0][0]
# ____________________________________________________________________________________________________
# convolution2d_67 (Convolution2D)   (None, 8, 128, 128) 296         dropout_24[0][0]
# ____________________________________________________________________________________________________
# dense_8 (Dense)                    (None, 16)          528         leakyrelu_7[0][0]
# ____________________________________________________________________________________________________
# convolution2d_68 (Convolution2D)   (None, 8, 128, 128) 584         convolution2d_67[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_8 (LeakyReLU)            (None, 16)          0           dense_8[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_8[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 73          convolution2d_68[0][0]
# ____________________________________________________________________________________________________
# outmap32 (Convolution2D)           (None, 1, 32, 32)   37          maxout2d_39[0][0]
# ____________________________________________________________________________________________________
# outmap64 (Convolution2D)           (None, 1, 64, 64)   37          maxout2d_40[0][0]
# ====================================================================================================
# Total params: 40868
# ____________________________________________________________________________________________________

# %%
from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

from keras.utils.visualize_util import plot
plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {
            'outmap': Y_train,
            'outmap64' : Y_train_64,
            'outmap32' : Y_train_32,
            'outbin': Y_train_binary
        },
        batch_size=64,
        validation_data=(X_test, {
                'outmap': Y_test,
                'outmap64' : Y_test_64,
                'outmap32' : Y_test_32,
                'outbin': Y_test_binary
        }),
        nb_epoch=25,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    
    pl.figure()
    pl.plot(history.history['outmap_loss'], label='train loss')
    pl.plot(history.history['val_outmap_loss'], c='g', label='val loss')
    pl.legend()

    pl.figure()
    pl.plot(history.history['outbin_acc'], label='train acc')
    pl.plot(history.history['val_outbin_acc'], c='g', label='val acc')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
                custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.01])
    
    print_summary(model.layers)
# Out:
# Train on 10545 samples, validate on 391 samples
# Epoch 1/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1753 - outmap_loss: 0.0222 - outmap64_loss: 0.0225 - outmap32_loss: 0.0244 - outbin_loss: 0.2947 - outbin_acc: 0.8788Epoch 00000: val_loss improved from inf to 0.19868, saving model to weights.hdf5
# 10545/10545 [==============================] - 102s - loss: 0.1751 - outmap_loss: 0.0222 - outmap64_loss: 0.0225 - outmap32_loss: 0.0244 - outbin_loss: 0.2944 - outbin_acc: 0.8789 - val_loss: 0.1987 - val_outmap_loss: 0.0212 - val_outmap64_loss: 0.0215 - val_outmap32_loss: 0.0235 - val_outbin_loss: 0.3441 - val_outbin_acc: 0.8824
# Epoch 2/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1651 - outmap_loss: 0.0217 - outmap64_loss: 0.0220 - outmap32_loss: 0.0239 - outbin_loss: 0.2756 - outbin_acc: 0.8852Epoch 00001: val_loss improved from 0.19868 to 0.18960, saving model to weights.hdf5
# 10545/10545 [==============================] - 106s - loss: 0.1651 - outmap_loss: 0.0217 - outmap64_loss: 0.0220 - outmap32_loss: 0.0239 - outbin_loss: 0.2756 - outbin_acc: 0.8851 - val_loss: 0.1896 - val_outmap_loss: 0.0202 - val_outmap64_loss: 0.0206 - val_outmap32_loss: 0.0232 - val_outbin_loss: 0.3281 - val_outbin_acc: 0.8619
# Epoch 3/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1660 - outmap_loss: 0.0214 - outmap64_loss: 0.0217 - outmap32_loss: 0.0237 - outbin_loss: 0.2782 - outbin_acc: 0.8846Epoch 00002: val_loss did not improve
# 10545/10545 [==============================] - 104s - loss: 0.1662 - outmap_loss: 0.0214 - outmap64_loss: 0.0217 - outmap32_loss: 0.0237 - outbin_loss: 0.2785 - outbin_acc: 0.8843 - val_loss: 0.1948 - val_outmap_loss: 0.0222 - val_outmap64_loss: 0.0221 - val_outmap32_loss: 0.0234 - val_outbin_loss: 0.3342 - val_outbin_acc: 0.8721
# Epoch 4/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1638 - outmap_loss: 0.0213 - outmap64_loss: 0.0216 - outmap32_loss: 0.0235 - outbin_loss: 0.2740 - outbin_acc: 0.8867Epoch 00003: val_loss did not improve
# 10545/10545 [==============================] - 103s - loss: 0.1637 - outmap_loss: 0.0213 - outmap64_loss: 0.0216 - outmap32_loss: 0.0234 - outbin_loss: 0.2739 - outbin_acc: 0.8869 - val_loss: 0.2105 - val_outmap_loss: 0.0213 - val_outmap64_loss: 0.0222 - val_outmap32_loss: 0.0241 - val_outbin_loss: 0.3671 - val_outbin_acc: 0.8747
# Epoch 5/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1618 - outmap_loss: 0.0211 - outmap64_loss: 0.0214 - outmap32_loss: 0.0233 - outbin_loss: 0.2705 - outbin_acc: 0.8858Epoch 00004: val_loss did not improve
# 10545/10545 [==============================] - 103s - loss: 0.1624 - outmap_loss: 0.0212 - outmap64_loss: 0.0215 - outmap32_loss: 0.0234 - outbin_loss: 0.2714 - outbin_acc: 0.8854 - val_loss: 0.2029 - val_outmap_loss: 0.0196 - val_outmap64_loss: 0.0201 - val_outmap32_loss: 0.0219 - val_outbin_loss: 0.3564 - val_outbin_acc: 0.8619
# Epoch 6/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1582 - outmap_loss: 0.0208 - outmap64_loss: 0.0211 - outmap32_loss: 0.0230 - outbin_loss: 0.2640 - outbin_acc: 0.8901Epoch 00005: val_loss improved from 0.18960 to 0.17498, saving model to weights.hdf5
# 10545/10545 [==============================] - 103s - loss: 0.1585 - outmap_loss: 0.0208 - outmap64_loss: 0.0211 - outmap32_loss: 0.0230 - outbin_loss: 0.2646 - outbin_acc: 0.8898 - val_loss: 0.1750 - val_outmap_loss: 0.0193 - val_outmap64_loss: 0.0198 - val_outmap32_loss: 0.0219 - val_outbin_loss: 0.3013 - val_outbin_acc: 0.8824
# Epoch 7/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1594 - outmap_loss: 0.0211 - outmap64_loss: 0.0214 - outmap32_loss: 0.0232 - outbin_loss: 0.2656 - outbin_acc: 0.8919Epoch 00006: val_loss did not improve
# 10545/10545 [==============================] - 103s - loss: 0.1595 - outmap_loss: 0.0211 - outmap64_loss: 0.0214 - outmap32_loss: 0.0232 - outbin_loss: 0.2658 - outbin_acc: 0.8918 - val_loss: 0.1779 - val_outmap_loss: 0.0193 - val_outmap64_loss: 0.0195 - val_outmap32_loss: 0.0212 - val_outbin_loss: 0.3073 - val_outbin_acc: 0.8824
# Epoch 8/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1544 - outmap_loss: 0.0206 - outmap64_loss: 0.0209 - outmap32_loss: 0.0228 - outbin_loss: 0.2570 - outbin_acc: 0.8918Epoch 00007: val_loss did not improve
# 10545/10545 [==============================] - 103s - loss: 0.1543 - outmap_loss: 0.0206 - outmap64_loss: 0.0209 - outmap32_loss: 0.0228 - outbin_loss: 0.2567 - outbin_acc: 0.8920 - val_loss: 0.1784 - val_outmap_loss: 0.0195 - val_outmap64_loss: 0.0198 - val_outmap32_loss: 0.0217 - val_outbin_loss: 0.3077 - val_outbin_acc: 0.8721
# Epoch 9/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1545 - outmap_loss: 0.0209 - outmap64_loss: 0.0211 - outmap32_loss: 0.0229 - outbin_loss: 0.2566 - outbin_acc: 0.8953Epoch 00008: val_loss did not improve
# 10545/10545 [==============================] - 106s - loss: 0.1548 - outmap_loss: 0.0209 - outmap64_loss: 0.0211 - outmap32_loss: 0.0229 - outbin_loss: 0.2571 - outbin_acc: 0.8949 - val_loss: 0.1997 - val_outmap_loss: 0.0206 - val_outmap64_loss: 0.0208 - val_outmap32_loss: 0.0223 - val_outbin_loss: 0.3477 - val_outbin_acc: 0.8721
# Epoch 10/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1553 - outmap_loss: 0.0205 - outmap64_loss: 0.0208 - outmap32_loss: 0.0226 - outbin_loss: 0.2590 - outbin_acc: 0.8948Epoch 00009: val_loss did not improve
# 10545/10545 [==============================] - 106s - loss: 0.1552 - outmap_loss: 0.0205 - outmap64_loss: 0.0208 - outmap32_loss: 0.0226 - outbin_loss: 0.2588 - outbin_acc: 0.8948 - val_loss: 0.1784 - val_outmap_loss: 0.0201 - val_outmap64_loss: 0.0206 - val_outmap32_loss: 0.0222 - val_outbin_loss: 0.3062 - val_outbin_acc: 0.8926
# Epoch 11/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1518 - outmap_loss: 0.0204 - outmap64_loss: 0.0207 - outmap32_loss: 0.0225 - outbin_loss: 0.2523 - outbin_acc: 0.8953Epoch 00010: val_loss did not improve
# 10545/10545 [==============================] - 106s - loss: 0.1519 - outmap_loss: 0.0204 - outmap64_loss: 0.0207 - outmap32_loss: 0.0225 - outbin_loss: 0.2525 - outbin_acc: 0.8951 - val_loss: 0.1829 - val_outmap_loss: 0.0192 - val_outmap64_loss: 0.0196 - val_outmap32_loss: 0.0218 - val_outbin_loss: 0.3175 - val_outbin_acc: 0.8696
# Epoch 12/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1543 - outmap_loss: 0.0205 - outmap64_loss: 0.0208 - outmap32_loss: 0.0226 - outbin_loss: 0.2569 - outbin_acc: 0.8939Epoch 00011: val_loss did not improve
# 10545/10545 [==============================] - 106s - loss: 0.1543 - outmap_loss: 0.0205 - outmap64_loss: 0.0208 - outmap32_loss: 0.0226 - outbin_loss: 0.2571 - outbin_acc: 0.8939 - val_loss: 0.1959 - val_outmap_loss: 0.0210 - val_outmap64_loss: 0.0209 - val_outmap32_loss: 0.0232 - val_outbin_loss: 0.3393 - val_outbin_acc: 0.8619
# Epoch 13/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1500 - outmap_loss: 0.0203 - outmap64_loss: 0.0206 - outmap32_loss: 0.0224 - outbin_loss: 0.2489 - outbin_acc: 0.8974Epoch 00012: val_loss did not improve
# 10545/10545 [==============================] - 106s - loss: 0.1501 - outmap_loss: 0.0203 - outmap64_loss: 0.0206 - outmap32_loss: 0.0224 - outbin_loss: 0.2492 - outbin_acc: 0.8973 - val_loss: 0.1852 - val_outmap_loss: 0.0195 - val_outmap64_loss: 0.0199 - val_outmap32_loss: 0.0216 - val_outbin_loss: 0.3212 - val_outbin_acc: 0.8849
# Epoch 14/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1485 - outmap_loss: 0.0202 - outmap64_loss: 0.0205 - outmap32_loss: 0.0221 - outbin_loss: 0.2463 - outbin_acc: 0.9018Epoch 00013: val_loss did not improve
# 10545/10545 [==============================] - 106s - loss: 0.1486 - outmap_loss: 0.0202 - outmap64_loss: 0.0205 - outmap32_loss: 0.0221 - outbin_loss: 0.2465 - outbin_acc: 0.9017 - val_loss: 0.1896 - val_outmap_loss: 0.0198 - val_outmap64_loss: 0.0197 - val_outmap32_loss: 0.0214 - val_outbin_loss: 0.3296 - val_outbin_acc: 0.8772
# Epoch 15/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1455 - outmap_loss: 0.0202 - outmap64_loss: 0.0205 - outmap32_loss: 0.0222 - outbin_loss: 0.2401 - outbin_acc: 0.9036Epoch 00014: val_loss did not improve
# 10545/10545 [==============================] - 106s - loss: 0.1453 - outmap_loss: 0.0202 - outmap64_loss: 0.0205 - outmap32_loss: 0.0222 - outbin_loss: 0.2398 - outbin_acc: 0.9036 - val_loss: 0.2135 - val_outmap_loss: 0.0203 - val_outmap64_loss: 0.0202 - val_outmap32_loss: 0.0221 - val_outbin_loss: 0.3761 - val_outbin_acc: 0.8593
# Epoch 16/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1421 - outmap_loss: 0.0197 - outmap64_loss: 0.0201 - outmap32_loss: 0.0218 - outbin_loss: 0.2346 - outbin_acc: 0.9025Epoch 00015: val_loss did not improve
# 10545/10545 [==============================] - 106s - loss: 0.1421 - outmap_loss: 0.0197 - outmap64_loss: 0.0201 - outmap32_loss: 0.0218 - outbin_loss: 0.2345 - outbin_acc: 0.9027 - val_loss: 0.2076 - val_outmap_loss: 0.0199 - val_outmap64_loss: 0.0203 - val_outmap32_loss: 0.0216 - val_outbin_loss: 0.3652 - val_outbin_acc: 0.8721
# Epoch 17/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1415 - outmap_loss: 0.0199 - outmap64_loss: 0.0202 - outmap32_loss: 0.0219 - outbin_loss: 0.2329 - outbin_acc: 0.9077Epoch 00016: val_loss did not improve
# 10545/10545 [==============================] - 106s - loss: 0.1414 - outmap_loss: 0.0199 - outmap64_loss: 0.0202 - outmap32_loss: 0.0219 - outbin_loss: 0.2327 - outbin_acc: 0.9078 - val_loss: 0.2011 - val_outmap_loss: 0.0195 - val_outmap64_loss: 0.0199 - val_outmap32_loss: 0.0213 - val_outbin_loss: 0.3531 - val_outbin_acc: 0.8670
# Epoch 18/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1413 - outmap_loss: 0.0197 - outmap64_loss: 0.0200 - outmap32_loss: 0.0217 - outbin_loss: 0.2332 - outbin_acc: 0.9048Epoch 00017: val_loss did not improve
# 10545/10545 [==============================] - 106s - loss: 0.1416 - outmap_loss: 0.0197 - outmap64_loss: 0.0201 - outmap32_loss: 0.0217 - outbin_loss: 0.2337 - outbin_acc: 0.9045 - val_loss: 0.1967 - val_outmap_loss: 0.0191 - val_outmap64_loss: 0.0196 - val_outmap32_loss: 0.0215 - val_outbin_loss: 0.3451 - val_outbin_acc: 0.8645
# Epoch 19/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1395 - outmap_loss: 0.0195 - outmap64_loss: 0.0198 - outmap32_loss: 0.0215 - outbin_loss: 0.2300 - outbin_acc: 0.9039Epoch 00018: val_loss did not improve
# 10545/10545 [==============================] - 106s - loss: 0.1395 - outmap_loss: 0.0195 - outmap64_loss: 0.0198 - outmap32_loss: 0.0215 - outbin_loss: 0.2299 - outbin_acc: 0.9038 - val_loss: 0.2025 - val_outmap_loss: 0.0188 - val_outmap64_loss: 0.0191 - val_outmap32_loss: 0.0208 - val_outbin_loss: 0.3577 - val_outbin_acc: 0.8670
# Epoch 20/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1416 - outmap_loss: 0.0197 - outmap64_loss: 0.0200 - outmap32_loss: 0.0216 - outbin_loss: 0.2336 - outbin_acc: 0.9030Epoch 00019: val_loss did not improve
# 10545/10545 [==============================] - 106s - loss: 0.1415 - outmap_loss: 0.0197 - outmap64_loss: 0.0200 - outmap32_loss: 0.0216 - outbin_loss: 0.2333 - outbin_acc: 0.9032 - val_loss: 0.1958 - val_outmap_loss: 0.0191 - val_outmap64_loss: 0.0194 - val_outmap32_loss: 0.0210 - val_outbin_loss: 0.3436 - val_outbin_acc: 0.8798
# Epoch 21/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1369 - outmap_loss: 0.0193 - outmap64_loss: 0.0197 - outmap32_loss: 0.0212 - outbin_loss: 0.2253 - outbin_acc: 0.9074Epoch 00020: val_loss did not improve
# 10545/10545 [==============================] - 106s - loss: 0.1371 - outmap_loss: 0.0193 - outmap64_loss: 0.0197 - outmap32_loss: 0.0213 - outbin_loss: 0.2257 - outbin_acc: 0.9072 - val_loss: 0.2202 - val_outmap_loss: 0.0193 - val_outmap64_loss: 0.0195 - val_outmap32_loss: 0.0213 - val_outbin_loss: 0.3919 - val_outbin_acc: 0.8696
# Epoch 22/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1367 - outmap_loss: 0.0192 - outmap64_loss: 0.0196 - outmap32_loss: 0.0212 - outbin_loss: 0.2250 - outbin_acc: 0.9055Epoch 00021: val_loss did not improve
# 10545/10545 [==============================] - 106s - loss: 0.1369 - outmap_loss: 0.0192 - outmap64_loss: 0.0196 - outmap32_loss: 0.0212 - outbin_loss: 0.2254 - outbin_acc: 0.9055 - val_loss: 0.2019 - val_outmap_loss: 0.0210 - val_outmap64_loss: 0.0212 - val_outmap32_loss: 0.0220 - val_outbin_loss: 0.3512 - val_outbin_acc: 0.8721
# Epoch 23/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1338 - outmap_loss: 0.0191 - outmap64_loss: 0.0195 - outmap32_loss: 0.0210 - outbin_loss: 0.2195 - outbin_acc: 0.9092Epoch 00022: val_loss did not improve
# 10545/10545 [==============================] - 106s - loss: 0.1339 - outmap_loss: 0.0191 - outmap64_loss: 0.0195 - outmap32_loss: 0.0210 - outbin_loss: 0.2196 - outbin_acc: 0.9091 - val_loss: 0.2033 - val_outmap_loss: 0.0186 - val_outmap64_loss: 0.0190 - val_outmap32_loss: 0.0208 - val_outbin_loss: 0.3595 - val_outbin_acc: 0.8824
# Epoch 24/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1397 - outmap_loss: 0.0195 - outmap64_loss: 0.0199 - outmap32_loss: 0.0214 - outbin_loss: 0.2303 - outbin_acc: 0.9043Epoch 00023: val_loss did not improve
# 10545/10545 [==============================] - 106s - loss: 0.1398 - outmap_loss: 0.0195 - outmap64_loss: 0.0198 - outmap32_loss: 0.0214 - outbin_loss: 0.2306 - outbin_acc: 0.9045 - val_loss: 0.2158 - val_outmap_loss: 0.0191 - val_outmap64_loss: 0.0193 - val_outmap32_loss: 0.0210 - val_outbin_loss: 0.3835 - val_outbin_acc: 0.8696
# Epoch 25/25
# 10496/10545 [============================>.] - ETA: 0s - loss: 0.1336 - outmap_loss: 0.0191 - outmap64_loss: 0.0195 - outmap32_loss: 0.0209 - outbin_loss: 0.2193 - outbin_acc: 0.9108Epoch 00024: val_loss did not improve
# 10545/10545 [==============================] - 106s - loss: 0.1337 - outmap_loss: 0.0190 - outmap64_loss: 0.0194 - outmap32_loss: 0.0209 - outbin_loss: 0.2194 - outbin_acc: 0.9107 - val_loss: 0.1924 - val_outmap_loss: 0.0185 - val_outmap64_loss: 0.0187 - val_outmap32_loss: 0.0202 - val_outbin_loss: 0.3383 - val_outbin_acc: 0.8824

# %%
if True:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture_final.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights_final.hdf5'))

# %%
def compute_scores_map(X, Y):
    Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X)
    
    map_threshs = np.linspace(0, 1, num=21)
    bin_threshs = np.linspace(0, 1, num=21)
    
    scores = np.zeros((len(map_threshs), len(bin_threshs)))
    for i in range(len(map_threshs)):
        for j in range(len(bin_threshs)):
            _Y_pred = Y_pred > map_threshs[i]
            
            for k in range(_Y_pred.shape[0]):
                # Clear prediction where we detect to little pixels
                if np.sum(_Y_pred[k]) < 150 or Y_pred_binary[k] < bin_threshs[j]:
                    _Y_pred[k,:] = 0
            
            scores[i, j] = utils.average_dice_coefficient(_Y_pred, Y)
    
    pl.imshow(scores, interpolation='nearest')
    pl.yticks(np.arange(len(map_threshs)) + 0.5, ['%.2f' % v for v in map_threshs])
    pl.xticks(np.arange(len(bin_threshs)) + 0.5, ['%.2f' % v for v in bin_threshs], rotation=90)
    pl.ylabel('map thresh')
    pl.xlabel('bin thresh')
    pl.colorbar()
    
    best_i, best_j = np.unravel_index(np.argmax(scores.ravel()), scores.shape)
    best_map_thresh = map_threshs[best_i]
    best_bin_thresh = bin_threshs[best_j]
    return best_map_thresh, best_bin_thresh

map_thresh, bin_thresh = compute_scores_map(X_test, Y_test)
print 'Best map_thresh=%f, bin_thresh=%f' % (map_thresh, bin_thresh)
# Out:
# Best map_thresh=0.400000, bin_thresh=0.400000

# %%
map_thresh = 0.4
bin_thresh = 0.4

# %%
def predict(X, map_thresh, bin_thresh):
    Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > map_thresh
    for i in range(Y_pred.shape[0]):
        if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < bin_thresh:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test, map_thresh, bin_thresh)
Y_full_pred, Y_full_pred_proba, Y_full_pred_binary = predict(X_full, map_thresh, bin_thresh)

print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "avg test set score : ", utils.average_dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
print "avg full set score : ", utils.average_dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.696388668637
# avg test set score :  0.831405442851
# full set score :  0.631394321851
# avg full set score :  0.767165143124

# %%
_ = pl.hist(Y_pred_binary)

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[30:35]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(30):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, pred44, pred88, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 15
img, pred_map = dream_output(Y_full[i])
pl.figure(figsize=(12, 4))
pl.subplot(141)
pl.imshow(X_full[i].squeeze(), cmap=cm.gray)
pl.subplot(142)
pl.imshow(Y_full[i].squeeze())
pl.subplot(143)
pl.imshow(img, cmap=cm.gray)
pl.subplot(144)
pl.imshow(pred_map.squeeze())

# %%
# Dream for the binary output
def dream_binoutput(output):
    
    layer_output = layer_dict['outbin'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output - layer_output[:, 0]))
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    
    step = 0.1
    for i in range(40):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    _, _, _, model_pred = model.predict(img[None,None,:,:])
    return img, model_pred

img, model_pred = dream_binoutput(1)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
img, model_pred = dream_binoutput(0)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
def dream_layer_filter(layer_name, filter_index):
    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(4):
        pl.subplot(1, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
_d = np.load('../data/data_128_test.npz')
X_submit = _d['X']

Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X_submit[:,None,:,:])
Y_pred_binary = Y_pred_binary.squeeze()
Y_pred_proba = Y_pred

# %%
def Y_to_binary(Y_pred, Y_pred_binary, map_thresh, bin_thresh):
    Y_pred = Y_pred > map_thresh
    for i in range(Y_pred.shape[0]):
        if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < bin_thresh:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

map_threshs = np.linspace(0, 1, num=11)
bin_threshs = np.linspace(0, 1, num=11)

masks_per = np.zeros((len(map_threshs), len(bin_threshs)))
for i in range(len(map_threshs)):
    for j in range(len(bin_threshs)):
        m_t = map_threshs[i]
        b_t = bin_threshs[j]
        _pred, _pred_proba, _pred_binary = Y_to_binary(Y_pred, Y_pred_binary, m_t, b_t)
        # Turn labels into boolean present/missing
        _pred_binary = np.sum(np.sum(np.sum(_pred, axis=2), axis=1), axis=1) > 0
        _pred_binary = _pred_binary.astype(np.float32)
        per_mask = (100 * np.count_nonzero(_pred_binary) / float(len(_pred_binary)))

        masks_per[i, j] = per_mask

pl.imshow(masks_per, interpolation='nearest')
pl.yticks(np.arange(len(map_threshs)) + 0.5, ['%.2f' % v for v in map_threshs])
pl.xticks(np.arange(len(bin_threshs)) + 0.5, ['%.2f' % v for v in bin_threshs], rotation=90)
pl.ylabel('map thresh')
pl.xlabel('bin thresh')
pl.colorbar()

# %%
np.count_nonzero(Y_pred_binary > 0.5) / float(len(Y_pred_binary))
# Out:
# 0.39215686274509803

# %%
print map_thresh
print bin_thresh
# Out:
# 0.4
# 0.4

# %%
if True:
    import cv2
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(50,50))
    
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    test_fnames = _d['test_fnames']
    # bin_thresh
    Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:],
                                                  map_thresh, bin_thresh)
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = (Y_pred[i].squeeze() * 255).astype(np.uint8)
        imre = cv2.morphologyEx(imre, cv2.MORPH_CLOSE, kernel)
        imre = cv2.resize(imre, (580, 420))
        
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
        
        if i % 10 == 0:
            print '\r%d / %d' % (i, len(test_fnames)),
            sys.stdout.flush()
# Out:
# 5500 / 5508

# %%
# Turn labels into boolean present/missing
pred_binary = np.sum(np.sum(np.sum(Y_pred, axis=2), axis=1), axis=1) > 0
pred_binary = pred_binary.astype(np.float32)
print "%.2f%% with masks" % (100 * np.count_nonzero(pred_binary) / float(len(pred_binary)))
# Out:
# 37.55% with masks

# %% [markdown]
# ## Stats on predicted masks

# %%
# on Y_full
nbp_pixels = np.sum(np.sum(np.sum(Y_full, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
pl.xlim((0, 1200))
# Out:
# (0, 1200)

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
pl.xlim((0, 1200))
# Out:
# (0, 1200)
