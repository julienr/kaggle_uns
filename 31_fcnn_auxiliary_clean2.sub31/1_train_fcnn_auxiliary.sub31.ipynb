# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)

# %%
_d = np.load('../data/data_clean2_128_train.npz')
X = _d['X']
Y = _d['Y']
X_pids = _d['pids']

# %%
print X.shape
print Y.shape
print X.dtype
print Y.dtype
# Out:
# (5635, 128, 128)
# (5635, 128, 128)
# float32
# float32

# %%
# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0

if False:
    # Split patients in train/test
    train_pids, test_pids = train_test_split(np.unique(X_pids), test_size=0.1)
    print train_pids
    print test_pids
       
    train_indices = np.flatnonzero(np.in1d(X_pids, train_pids))
    test_indices = np.flatnonzero(np.in1d(X_pids, test_pids))
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]
    
    print X_train.shape
    print X_test.shape
else:
    nsamples = X.shape[0]

    train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    #train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.2)
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]
    
    print X_train.shape
    print X_test.shape
# Out:
# (5071, 1, 128, 128)
# (564, 1, 128, 128)

# %%
import skimage.transform as sktransf

def rand_float(rng):
    return rng[0] + np.random.random() * (rng[1] - rng[0])

def generate_image(X_img, Y_img, angle_range=None, zoom_range=None, shear_range=None, horiz_shift_range=None,
                   vert_shift_range=None):
    """
    Randomly shift an image by resizing and then random croping
    the resized image
    """
    if angle_range is None:
        angle_range = (-5, 5)
    if zoom_range is None:
        zoom_range = (0.8, 1.2)
    if shear_range is None:
        shear_range = (-7, 7) # shear angle in degrees
    if horiz_shift_range is None:
        horiz_shift_range = (-5, 5)
    if vert_shift_range is None:
        vert_shift_range = (-5, 5)
    inshape = X_img.shape
    
    X2 = X_img.copy()
    Y2 = Y_img.copy()
    
    # -- random rotation
    angle = np.deg2rad(rand_float(angle_range))
    zoom = rand_float(zoom_range)
    shear = np.deg2rad(rand_float(shear_range))
    horiz_shift = rand_float(horiz_shift_range)
    vert_shift = rand_float(vert_shift_range)
    
    tform = sktransf.AffineTransform(
        scale=(zoom, zoom),
        rotation=angle,
        shear=shear,
        translation=(horiz_shift, vert_shift)
    )
    X2 = sktransf.warp(X2, tform, order=1, mode='edge')
    Y2 = sktransf.warp(Y2, tform, order=1)

    # gaussian noise
    #noise_scale = rand_float((0, 0.1))
    #X2 += np.random.normal(scale=noise_scale, size=X2.shape)
    Y2 = Y2 > 0.5
    return X2[None,:,:].astype(np.float32), Y2[None,:,:].astype(np.float32)

X_train_augmented = []
Y_train_augmented = []
for i in range(X_train.shape[0]):
    if i % 10 == 0:
        print '\r%d / %d' % (i, X_train.shape[0]),
        sys.stdout.flush()
    X_train_augmented.append(X_train[i])
    Y_train_augmented.append(Y_train[i])
    for j in range(3):
        X2, Y2 = generate_image(X_train[i].squeeze(), Y_train[i].squeeze())
        X_train_augmented.append(X2)
        Y_train_augmented.append(Y2)
# Out:
# 5070 / 5071

# %%
X_train = np.array(X_train_augmented, dtype=np.float32)
Y_train = np.array(Y_train_augmented, dtype=np.float32)

# %%
print X_train.shape
print X_test.shape
print X_train.min(), X_train.max()
# Out:
# (20284, 1, 128, 128)
# (564, 1, 128, 128)
# 0.0 1.0

# %%
import cv2
def _resize(Y, outshape):
    return cv2.resize(Y.squeeze(), outshape, interpolation=cv2.INTER_AREA)[None, :, :]
# binarize
Y_train_8_8 = np.array([_resize(img, (8, 8)) for img in Y_train])
Y_test_8_8 = np.array([_resize(img, (8, 8)) for img in Y_test])

# %%
def reduce_to_center_pixel(Y):
    Y2 = np.zeros_like(Y)
    for i in range(Y.shape[0]):
        if np.sum(Y[i]) > 0:
            # https://en.wikipedia.org/wiki/Image_moment
            # center of mass
            moments = cv2.moments(Y[i,0])
            x = moments['m10'] / moments['m00']
            y = moments['m01'] / moments['m00']
            x = int(x)
            y = int(y)
            Y2[i,0,y,x] = 1
    return Y2

Y_train_8_8 = reduce_to_center_pixel(Y_train_8_8)
Y_test_8_8 = reduce_to_center_pixel(Y_test_8_8)

# %%
with_bp = np.flatnonzero(np.sum(np.sum(np.sum(Y_train, axis=1), axis=1), axis=1))

# %%
for bpi in range(15, 19):
    i = with_bp[bpi]
    pl.figure(figsize=(16, 4))
    pl.subplot(131)
    pl.imshow(X_train[i].squeeze())
    pl.subplot(132)
    pl.imshow(Y_train[i].squeeze())
    pl.subplot(133)
    pl.imshow(Y_train_8_8[i].squeeze(), interpolation='nearest')
    pl.colorbar()

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float32'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense
from keras.layers import LeakyReLU, BatchNormalization
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
import keras.backend as K
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
from keras.layers import Layer, InputSpec
import keras.initializations
import keras.backend as K

class Maxout2D(Layer):
    def __init__(self, output_dim, cardinality, init='glorot_uniform', **kwargs):
        super(Maxout2D, self).__init__(**kwargs)
        # the k of the maxout paper
        self.cardinality = cardinality
        # the m of the maxout paper
        self.output_dim = output_dim
        self.init = keras.initializations.get(init)
    
    def build(self, input_shape):
        self.input_dim = input_shape[1]
        self.input_spec = [InputSpec(dtype=K.floatx(),
                                     shape=(None, input_shape[1], input_shape[2], input_shape[3]))]
        self.W = self.init((self.input_dim, self.output_dim, self.cardinality),
                           name='{}_W'.format(self.name))
        self.b = K.zeros((self.output_dim, self.cardinality))
        self.trainable_weights = [self.W, self.b]
              
    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        # flatten the spatial dimensions
        flat_x = K.reshape(x, (-1, input_shape[1], input_shape[2] * input_shape[3]))
        output = K.dot(
            K.permute_dimensions(flat_x, (0, 2, 1)),
            K.permute_dimensions(self.W, (1, 0, 2))
        )
        output += K.reshape(self.b, (1, 1, self.output_dim, self.cardinality))
        output = K.max(output, axis=3)
        output = output.transpose(0, 2, 1)
        output = K.reshape(output, (-1, self.output_dim, input_shape[2], input_shape[3]))
        return output
    
    def get_output_shape_for(self, input_shape):
        return (input_shape[0], self.output_dim, input_shape[2], input_shape[3])
    
    def get_config(self):
        config = {
            'output_dim': self.output_dim,
            'cardinality': self.cardinality
        }
        base_config = super(Maxout2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
# https://www.kaggle.com/c/ultrasound-nerve-segmentation/forums/t/21358/0-57-deep-learning-keras-tutorial
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def dice_coef_batchwise(y_true, y_pred):
    y_true_f = K.batch_flatten(y_true)
    y_pred_f = K.batch_flatten(y_pred)
    intersection = 2. * K.sum(y_true_f * y_pred_f, axis=1, keepdims=True) + smooth
    union = K.sum(y_true_f, axis=1, keepdims=True) + \
            K.sum(y_pred_f, axis=1, keepdims=True) + \
            smooth
    return K.mean(intersection / union)

def dice_coef_loss_batchwise(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %% [markdown]
# http://torch.ch/blog/2015/07/30/cifar.html

# %%
input_img = x = Input(shape=input_shape, name='input_img')
x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(input_img)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Maxout2D(32, 2)(x)
pool1 = x = MaxPooling2D((2, 2), name='pool1')(x)

x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Maxout2D(32, 2)(x)
pool2 = x = MaxPooling2D((2, 2), name='pool2')(x)

x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Maxout2D(32, 2)(x)
pool3 = x = MaxPooling2D((2, 2), name='pool3')(x)

# -- binary presence part
x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Maxout2D(32, 2)(x)
pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

#x = Dropout(0.25)(x)
#x = Convolution2D(16, 3, 3, border_mode='same')(x)
#x = Convolution2D(16, 3, 3, border_mode='same')(x)
#x = Maxout2D(16, 2)(x)
#pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# turn pool4 and 5 into classification map
#outmap4 = Convolution2D(1, 3, 3, border_mode='same', activation='sigmoid', name='outmap4')(pool4)
#outmap5 = Convolution2D(1, 3, 3, border_mode='same', activation='sigmoid', name='outmap5')(pool5)

x = Maxout2D(8, 4)(pool4)
outmap4 = Convolution2D(1, 1, 1, activation='sigmoid', border_mode='same', name='outmap4')(x)
#outmap5 = x = Maxout2D(1, 4, name='outmap5')(pool5)

# upsample the classif map
x = merge([
        UpSampling2D((2, 2))(outmap4),
        #UpSampling2D((4, 4))(outmap5),
        Maxout2D(8, 4)(pool3)
    ], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(pool3)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
# In theory, we could use sigmoids, but they make backprop harded, so fallback on maxout
#outmap3 = x = Convolution2D(1, 3, 3, border_mode='same', activation='sigmoid', name='outmap3')(x)
outmap3 = x = Maxout2D(8, 4)(x)
x = UpSampling2D((2, 2))(x)

x = merge([
        x,
        Maxout2D(16, 4)(pool2)
    ], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
#outmap2 = x = Convolution2D(1, 3, 3, border_mode='same', activation='sigmoid', name='outmap2')(x)
outmap2 = x = Maxout2D(16, 4)(x)
x = UpSampling2D((2, 2))(x)

x = merge([
        x,
        Maxout2D(16, 4)(pool1)
    ], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
#outmap1 = x = Convolution2D(1, 3, 3, border_mode='same', activation='sigmoid', name='outmap1')(x)
outmap1 = x = Maxout2D(16, 4)(x)
x = UpSampling2D((2, 2))(x)

x = Dropout(0.25)(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outmap4]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
loss='binary_crossentropy'
#loss=[dice_coef_loss, dice_coef_loss]
metrics={'outmap': dice_coef_loss}
model.compile(optimizer='adam', loss=loss,
              loss_weights=[1., 0.1], metrics=metrics)

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)    (None, 32, 128, 128)320         input_img[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)    (None, 32, 128, 128)9248        convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# maxout2d_1 (Maxout2D)              (None, 32, 128, 128)2112        convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)               (None, 32, 64, 64)  0           maxout2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)                (None, 32, 64, 64)  0           pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)    (None, 32, 64, 64)  9248        dropout_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)    (None, 32, 64, 64)  9248        convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# maxout2d_2 (Maxout2D)              (None, 32, 64, 64)  2112        convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)               (None, 32, 32, 32)  0           maxout2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)                (None, 32, 32, 32)  0           pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)    (None, 32, 32, 32)  9248        dropout_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_6 (Convolution2D)    (None, 32, 32, 32)  9248        convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# maxout2d_3 (Maxout2D)              (None, 32, 32, 32)  2112        convolution2d_6[0][0]
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)               (None, 32, 16, 16)  0           maxout2d_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_9 (Convolution2D)    (None, 8, 16, 16)   2312        pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_10 (Convolution2D)   (None, 8, 16, 16)   584         convolution2d_9[0][0]
# ____________________________________________________________________________________________________
# maxout2d_7 (Maxout2D)              (None, 8, 16, 16)   288         convolution2d_10[0][0]
# ____________________________________________________________________________________________________
# maxout2d_8 (Maxout2D)              (None, 16, 32, 32)  2112        pool2[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_2 (UpSampling2D)      (None, 8, 32, 32)   0           maxout2d_7[0][0]
# ____________________________________________________________________________________________________
# merge_2 (Merge)                    (None, 24, 32, 32)  0           upsampling2d_2[0][0]
#                                                                    maxout2d_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_11 (Convolution2D)   (None, 16, 32, 32)  3472        merge_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_12 (Convolution2D)   (None, 16, 32, 32)  2320        convolution2d_11[0][0]
# ____________________________________________________________________________________________________
# maxout2d_9 (Maxout2D)              (None, 16, 32, 32)  1088        convolution2d_12[0][0]
# ____________________________________________________________________________________________________
# maxout2d_10 (Maxout2D)             (None, 16, 64, 64)  2112        pool1[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_3 (UpSampling2D)      (None, 16, 64, 64)  0           maxout2d_9[0][0]
# ____________________________________________________________________________________________________
# merge_3 (Merge)                    (None, 32, 64, 64)  0           upsampling2d_3[0][0]
#                                                                    maxout2d_10[0][0]
# ____________________________________________________________________________________________________
# convolution2d_13 (Convolution2D)   (None, 16, 64, 64)  4624        merge_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_14 (Convolution2D)   (None, 16, 64, 64)  2320        convolution2d_13[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)                (None, 32, 16, 16)  0           pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_7 (Convolution2D)    (None, 32, 16, 16)  9248        dropout_4[0][0]
# ____________________________________________________________________________________________________
# maxout2d_11 (Maxout2D)             (None, 16, 64, 64)  1088        convolution2d_14[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8 (Convolution2D)    (None, 32, 16, 16)  9248        convolution2d_7[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_4 (UpSampling2D)      (None, 16, 128, 128)0           maxout2d_11[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)                (None, 16, 128, 128)0           upsampling2d_4[0][0]
# ____________________________________________________________________________________________________
# maxout2d_4 (Maxout2D)              (None, 32, 16, 16)  2112        convolution2d_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_15 (Convolution2D)   (None, 16, 128, 128)2320        dropout_5[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)               (None, 32, 8, 8)    0           maxout2d_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_16 (Convolution2D)   (None, 16, 128, 128)2320        convolution2d_15[0][0]
# ____________________________________________________________________________________________________
# maxout2d_5 (Maxout2D)              (None, 8, 8, 8)     1056        pool4[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 145         convolution2d_16[0][0]
# ____________________________________________________________________________________________________
# outmap4 (Convolution2D)            (None, 1, 8, 8)     9           maxout2d_5[0][0]
# ====================================================================================================
# Total params: 101674
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {
            'outmap': Y_train,
            'outmap4' : Y_train_8_8
        },
        batch_size=64,
        validation_data=(X_test, {
                'outmap': Y_test,
                'outmap4' : Y_test_8_8
        }),
        nb_epoch=80,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    
    pl.figure()
    pl.plot(history.history['loss'], label='train loss')
    pl.plot(history.history['val_loss'], c='g', label='val loss')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
                custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.01])
    
    print_summary(model.layers)
# Out:
# Train on 20284 samples, validate on 564 samples
# Epoch 1/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0680 - outmap_loss: 0.0612 - outmap4_loss: 0.0678 - outmap_dice_coef_loss: -0.2166Epoch 00000: val_loss improved from inf to 0.04283, saving model to weights.hdf5
# 20284/20284 [==============================] - 360s - loss: 0.0679 - outmap_loss: 0.0612 - outmap4_loss: 0.0677 - outmap_dice_coef_loss: -0.2170 - val_loss: 0.0428 - val_outmap_loss: 0.0396 - val_outmap4_loss: 0.0319 - val_outmap_dice_coef_loss: -0.3860
# Epoch 2/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0438 - outmap_loss: 0.0407 - outmap4_loss: 0.0310 - outmap_dice_coef_loss: -0.3815Epoch 00001: val_loss improved from 0.04283 to 0.03682, saving model to weights.hdf5
# 20284/20284 [==============================] - 365s - loss: 0.0438 - outmap_loss: 0.0407 - outmap4_loss: 0.0310 - outmap_dice_coef_loss: -0.3818 - val_loss: 0.0368 - val_outmap_loss: 0.0331 - val_outmap4_loss: 0.0369 - val_outmap_dice_coef_loss: -0.4369
# Epoch 3/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0386 - outmap_loss: 0.0359 - outmap4_loss: 0.0270 - outmap_dice_coef_loss: -0.4434Epoch 00002: val_loss improved from 0.03682 to 0.03169, saving model to weights.hdf5
# 20284/20284 [==============================] - 372s - loss: 0.0386 - outmap_loss: 0.0359 - outmap4_loss: 0.0270 - outmap_dice_coef_loss: -0.4437 - val_loss: 0.0317 - val_outmap_loss: 0.0291 - val_outmap4_loss: 0.0258 - val_outmap_dice_coef_loss: -0.4890
# Epoch 4/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0362 - outmap_loss: 0.0336 - outmap4_loss: 0.0252 - outmap_dice_coef_loss: -0.4744Epoch 00003: val_loss improved from 0.03169 to 0.03052, saving model to weights.hdf5
# 20284/20284 [==============================] - 371s - loss: 0.0361 - outmap_loss: 0.0336 - outmap4_loss: 0.0252 - outmap_dice_coef_loss: -0.4745 - val_loss: 0.0305 - val_outmap_loss: 0.0279 - val_outmap4_loss: 0.0259 - val_outmap_dice_coef_loss: -0.5014
# Epoch 5/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0341 - outmap_loss: 0.0317 - outmap4_loss: 0.0239 - outmap_dice_coef_loss: -0.4995Epoch 00004: val_loss improved from 0.03052 to 0.03002, saving model to weights.hdf5
# 20284/20284 [==============================] - 371s - loss: 0.0341 - outmap_loss: 0.0317 - outmap4_loss: 0.0239 - outmap_dice_coef_loss: -0.4994 - val_loss: 0.0300 - val_outmap_loss: 0.0274 - val_outmap4_loss: 0.0260 - val_outmap_dice_coef_loss: -0.5120
# Epoch 6/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0326 - outmap_loss: 0.0304 - outmap4_loss: 0.0228 - outmap_dice_coef_loss: -0.5177Epoch 00005: val_loss improved from 0.03002 to 0.02805, saving model to weights.hdf5
# 20284/20284 [==============================] - 372s - loss: 0.0326 - outmap_loss: 0.0304 - outmap4_loss: 0.0228 - outmap_dice_coef_loss: -0.5177 - val_loss: 0.0281 - val_outmap_loss: 0.0258 - val_outmap4_loss: 0.0224 - val_outmap_dice_coef_loss: -0.5387
# Epoch 7/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0316 - outmap_loss: 0.0294 - outmap4_loss: 0.0219 - outmap_dice_coef_loss: -0.5310Epoch 00006: val_loss improved from 0.02805 to 0.02753, saving model to weights.hdf5
# 20284/20284 [==============================] - 371s - loss: 0.0316 - outmap_loss: 0.0294 - outmap4_loss: 0.0219 - outmap_dice_coef_loss: -0.5311 - val_loss: 0.0275 - val_outmap_loss: 0.0253 - val_outmap4_loss: 0.0219 - val_outmap_dice_coef_loss: -0.5463
# Epoch 8/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0307 - outmap_loss: 0.0286 - outmap4_loss: 0.0212 - outmap_dice_coef_loss: -0.5421Epoch 00007: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0307 - outmap_loss: 0.0286 - outmap4_loss: 0.0212 - outmap_dice_coef_loss: -0.5422 - val_loss: 0.0281 - val_outmap_loss: 0.0260 - val_outmap4_loss: 0.0217 - val_outmap_dice_coef_loss: -0.5855
# Epoch 9/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0299 - outmap_loss: 0.0279 - outmap4_loss: 0.0206 - outmap_dice_coef_loss: -0.5503Epoch 00008: val_loss did not improve
# 20284/20284 [==============================] - 371s - loss: 0.0299 - outmap_loss: 0.0279 - outmap4_loss: 0.0206 - outmap_dice_coef_loss: -0.5503 - val_loss: 0.0296 - val_outmap_loss: 0.0275 - val_outmap4_loss: 0.0209 - val_outmap_dice_coef_loss: -0.5606
# Epoch 10/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0292 - outmap_loss: 0.0272 - outmap4_loss: 0.0203 - outmap_dice_coef_loss: -0.5619Epoch 00009: val_loss improved from 0.02753 to 0.02649, saving model to weights.hdf5
# 20284/20284 [==============================] - 371s - loss: 0.0292 - outmap_loss: 0.0272 - outmap4_loss: 0.0203 - outmap_dice_coef_loss: -0.5619 - val_loss: 0.0265 - val_outmap_loss: 0.0245 - val_outmap4_loss: 0.0195 - val_outmap_dice_coef_loss: -0.5802
# Epoch 11/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0286 - outmap_loss: 0.0266 - outmap4_loss: 0.0198 - outmap_dice_coef_loss: -0.5682Epoch 00010: val_loss did not improve
# 20284/20284 [==============================] - 371s - loss: 0.0286 - outmap_loss: 0.0266 - outmap4_loss: 0.0198 - outmap_dice_coef_loss: -0.5681 - val_loss: 0.0272 - val_outmap_loss: 0.0252 - val_outmap4_loss: 0.0208 - val_outmap_dice_coef_loss: -0.5801
# Epoch 12/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0279 - outmap_loss: 0.0260 - outmap4_loss: 0.0195 - outmap_dice_coef_loss: -0.5767Epoch 00011: val_loss improved from 0.02649 to 0.02486, saving model to weights.hdf5
# 20284/20284 [==============================] - 371s - loss: 0.0279 - outmap_loss: 0.0260 - outmap4_loss: 0.0195 - outmap_dice_coef_loss: -0.5768 - val_loss: 0.0249 - val_outmap_loss: 0.0230 - val_outmap4_loss: 0.0185 - val_outmap_dice_coef_loss: -0.6058
# Epoch 13/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0275 - outmap_loss: 0.0256 - outmap4_loss: 0.0194 - outmap_dice_coef_loss: -0.5830Epoch 00012: val_loss improved from 0.02486 to 0.02475, saving model to weights.hdf5
# 20284/20284 [==============================] - 371s - loss: 0.0275 - outmap_loss: 0.0256 - outmap4_loss: 0.0194 - outmap_dice_coef_loss: -0.5830 - val_loss: 0.0247 - val_outmap_loss: 0.0230 - val_outmap4_loss: 0.0175 - val_outmap_dice_coef_loss: -0.5859
# Epoch 14/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0267 - outmap_loss: 0.0248 - outmap4_loss: 0.0188 - outmap_dice_coef_loss: -0.5918Epoch 00013: val_loss did not improve
# 20284/20284 [==============================] - 371s - loss: 0.0267 - outmap_loss: 0.0248 - outmap4_loss: 0.0188 - outmap_dice_coef_loss: -0.5919 - val_loss: 0.0248 - val_outmap_loss: 0.0232 - val_outmap4_loss: 0.0156 - val_outmap_dice_coef_loss: -0.6320
# Epoch 15/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0264 - outmap_loss: 0.0245 - outmap4_loss: 0.0187 - outmap_dice_coef_loss: -0.5977Epoch 00014: val_loss improved from 0.02475 to 0.02364, saving model to weights.hdf5
# 20284/20284 [==============================] - 371s - loss: 0.0264 - outmap_loss: 0.0245 - outmap4_loss: 0.0187 - outmap_dice_coef_loss: -0.5978 - val_loss: 0.0236 - val_outmap_loss: 0.0220 - val_outmap4_loss: 0.0164 - val_outmap_dice_coef_loss: -0.6327
# Epoch 16/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0261 - outmap_loss: 0.0243 - outmap4_loss: 0.0185 - outmap_dice_coef_loss: -0.6018Epoch 00015: val_loss improved from 0.02364 to 0.02362, saving model to weights.hdf5
# 20284/20284 [==============================] - 371s - loss: 0.0261 - outmap_loss: 0.0243 - outmap4_loss: 0.0185 - outmap_dice_coef_loss: -0.6018 - val_loss: 0.0236 - val_outmap_loss: 0.0220 - val_outmap4_loss: 0.0161 - val_outmap_dice_coef_loss: -0.6096
# Epoch 17/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0255 - outmap_loss: 0.0236 - outmap4_loss: 0.0183 - outmap_dice_coef_loss: -0.6096Epoch 00016: val_loss did not improve
# 20284/20284 [==============================] - 369s - loss: 0.0255 - outmap_loss: 0.0236 - outmap4_loss: 0.0183 - outmap_dice_coef_loss: -0.6095 - val_loss: 0.0247 - val_outmap_loss: 0.0229 - val_outmap4_loss: 0.0181 - val_outmap_dice_coef_loss: -0.6108
# Epoch 18/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0252 - outmap_loss: 0.0234 - outmap4_loss: 0.0182 - outmap_dice_coef_loss: -0.6152Epoch 00017: val_loss did not improve
# 20284/20284 [==============================] - 361s - loss: 0.0252 - outmap_loss: 0.0234 - outmap4_loss: 0.0182 - outmap_dice_coef_loss: -0.6151 - val_loss: 0.0242 - val_outmap_loss: 0.0227 - val_outmap4_loss: 0.0154 - val_outmap_dice_coef_loss: -0.6292
# Epoch 19/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0250 - outmap_loss: 0.0232 - outmap4_loss: 0.0181 - outmap_dice_coef_loss: -0.6160Epoch 00018: val_loss did not improve
# 20284/20284 [==============================] - 366s - loss: 0.0250 - outmap_loss: 0.0232 - outmap4_loss: 0.0181 - outmap_dice_coef_loss: -0.6163 - val_loss: 0.0249 - val_outmap_loss: 0.0232 - val_outmap4_loss: 0.0174 - val_outmap_dice_coef_loss: -0.6367
# Epoch 20/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0247 - outmap_loss: 0.0229 - outmap4_loss: 0.0179 - outmap_dice_coef_loss: -0.6212Epoch 00019: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0247 - outmap_loss: 0.0229 - outmap4_loss: 0.0179 - outmap_dice_coef_loss: -0.6213 - val_loss: 0.0245 - val_outmap_loss: 0.0229 - val_outmap4_loss: 0.0160 - val_outmap_dice_coef_loss: -0.6675
# Epoch 21/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0243 - outmap_loss: 0.0226 - outmap4_loss: 0.0177 - outmap_dice_coef_loss: -0.6264Epoch 00020: val_loss improved from 0.02362 to 0.02292, saving model to weights.hdf5
# 20284/20284 [==============================] - 372s - loss: 0.0243 - outmap_loss: 0.0225 - outmap4_loss: 0.0177 - outmap_dice_coef_loss: -0.6264 - val_loss: 0.0229 - val_outmap_loss: 0.0214 - val_outmap4_loss: 0.0157 - val_outmap_dice_coef_loss: -0.6097
# Epoch 22/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0239 - outmap_loss: 0.0221 - outmap4_loss: 0.0175 - outmap_dice_coef_loss: -0.6329Epoch 00021: val_loss improved from 0.02292 to 0.02272, saving model to weights.hdf5
# 20284/20284 [==============================] - 372s - loss: 0.0239 - outmap_loss: 0.0221 - outmap4_loss: 0.0175 - outmap_dice_coef_loss: -0.6329 - val_loss: 0.0227 - val_outmap_loss: 0.0212 - val_outmap4_loss: 0.0157 - val_outmap_dice_coef_loss: -0.6236
# Epoch 23/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0236 - outmap_loss: 0.0219 - outmap4_loss: 0.0175 - outmap_dice_coef_loss: -0.6371Epoch 00022: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0237 - outmap_loss: 0.0219 - outmap4_loss: 0.0175 - outmap_dice_coef_loss: -0.6370 - val_loss: 0.0253 - val_outmap_loss: 0.0237 - val_outmap4_loss: 0.0160 - val_outmap_dice_coef_loss: -0.6151
# Epoch 24/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0236 - outmap_loss: 0.0218 - outmap4_loss: 0.0174 - outmap_dice_coef_loss: -0.6378Epoch 00023: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0236 - outmap_loss: 0.0218 - outmap4_loss: 0.0174 - outmap_dice_coef_loss: -0.6378 - val_loss: 0.0243 - val_outmap_loss: 0.0227 - val_outmap4_loss: 0.0163 - val_outmap_dice_coef_loss: -0.6371
# Epoch 25/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0232 - outmap_loss: 0.0215 - outmap4_loss: 0.0171 - outmap_dice_coef_loss: -0.6433Epoch 00024: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0232 - outmap_loss: 0.0215 - outmap4_loss: 0.0171 - outmap_dice_coef_loss: -0.6434 - val_loss: 0.0237 - val_outmap_loss: 0.0222 - val_outmap4_loss: 0.0146 - val_outmap_dice_coef_loss: -0.6349
# Epoch 26/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0228 - outmap_loss: 0.0211 - outmap4_loss: 0.0171 - outmap_dice_coef_loss: -0.6481Epoch 00025: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0228 - outmap_loss: 0.0211 - outmap4_loss: 0.0171 - outmap_dice_coef_loss: -0.6480 - val_loss: 0.0241 - val_outmap_loss: 0.0226 - val_outmap4_loss: 0.0147 - val_outmap_dice_coef_loss: -0.6469
# Epoch 27/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0230 - outmap_loss: 0.0213 - outmap4_loss: 0.0170 - outmap_dice_coef_loss: -0.6467Epoch 00026: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0230 - outmap_loss: 0.0213 - outmap4_loss: 0.0170 - outmap_dice_coef_loss: -0.6468 - val_loss: 0.0248 - val_outmap_loss: 0.0232 - val_outmap4_loss: 0.0162 - val_outmap_dice_coef_loss: -0.6208
# Epoch 28/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0225 - outmap_loss: 0.0208 - outmap4_loss: 0.0167 - outmap_dice_coef_loss: -0.6529Epoch 00027: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0225 - outmap_loss: 0.0208 - outmap4_loss: 0.0167 - outmap_dice_coef_loss: -0.6530 - val_loss: 0.0228 - val_outmap_loss: 0.0213 - val_outmap4_loss: 0.0153 - val_outmap_dice_coef_loss: -0.6459
# Epoch 29/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0223 - outmap_loss: 0.0207 - outmap4_loss: 0.0166 - outmap_dice_coef_loss: -0.6552Epoch 00028: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0223 - outmap_loss: 0.0207 - outmap4_loss: 0.0166 - outmap_dice_coef_loss: -0.6553 - val_loss: 0.0240 - val_outmap_loss: 0.0226 - val_outmap4_loss: 0.0144 - val_outmap_dice_coef_loss: -0.6508
# Epoch 30/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0222 - outmap_loss: 0.0205 - outmap4_loss: 0.0166 - outmap_dice_coef_loss: -0.6580Epoch 00029: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0222 - outmap_loss: 0.0205 - outmap4_loss: 0.0166 - outmap_dice_coef_loss: -0.6578 - val_loss: 0.0229 - val_outmap_loss: 0.0214 - val_outmap4_loss: 0.0148 - val_outmap_dice_coef_loss: -0.6389
# Epoch 31/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0220 - outmap_loss: 0.0203 - outmap4_loss: 0.0166 - outmap_dice_coef_loss: -0.6611Epoch 00030: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0220 - outmap_loss: 0.0203 - outmap4_loss: 0.0166 - outmap_dice_coef_loss: -0.6610 - val_loss: 0.0244 - val_outmap_loss: 0.0228 - val_outmap4_loss: 0.0164 - val_outmap_dice_coef_loss: -0.6337
# Epoch 32/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0218 - outmap_loss: 0.0201 - outmap4_loss: 0.0163 - outmap_dice_coef_loss: -0.6645Epoch 00031: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0218 - outmap_loss: 0.0201 - outmap4_loss: 0.0163 - outmap_dice_coef_loss: -0.6645 - val_loss: 0.0232 - val_outmap_loss: 0.0216 - val_outmap4_loss: 0.0156 - val_outmap_dice_coef_loss: -0.6628
# Epoch 33/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0216 - outmap_loss: 0.0200 - outmap4_loss: 0.0163 - outmap_dice_coef_loss: -0.6665Epoch 00032: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0216 - outmap_loss: 0.0200 - outmap4_loss: 0.0163 - outmap_dice_coef_loss: -0.6665 - val_loss: 0.0237 - val_outmap_loss: 0.0221 - val_outmap4_loss: 0.0156 - val_outmap_dice_coef_loss: -0.6378
# Epoch 34/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0213 - outmap_loss: 0.0197 - outmap4_loss: 0.0161 - outmap_dice_coef_loss: -0.6705Epoch 00033: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0213 - outmap_loss: 0.0197 - outmap4_loss: 0.0161 - outmap_dice_coef_loss: -0.6705 - val_loss: 0.0239 - val_outmap_loss: 0.0222 - val_outmap4_loss: 0.0171 - val_outmap_dice_coef_loss: -0.6727
# Epoch 35/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0212 - outmap_loss: 0.0195 - outmap4_loss: 0.0161 - outmap_dice_coef_loss: -0.6730Epoch 00034: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0212 - outmap_loss: 0.0196 - outmap4_loss: 0.0161 - outmap_dice_coef_loss: -0.6730 - val_loss: 0.0240 - val_outmap_loss: 0.0225 - val_outmap4_loss: 0.0148 - val_outmap_dice_coef_loss: -0.6519
# Epoch 36/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0211 - outmap_loss: 0.0195 - outmap4_loss: 0.0159 - outmap_dice_coef_loss: -0.6740Epoch 00035: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0211 - outmap_loss: 0.0195 - outmap4_loss: 0.0160 - outmap_dice_coef_loss: -0.6740 - val_loss: 0.0238 - val_outmap_loss: 0.0222 - val_outmap4_loss: 0.0157 - val_outmap_dice_coef_loss: -0.6453
# Epoch 37/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0209 - outmap_loss: 0.0193 - outmap4_loss: 0.0159 - outmap_dice_coef_loss: -0.6768Epoch 00036: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0209 - outmap_loss: 0.0193 - outmap4_loss: 0.0159 - outmap_dice_coef_loss: -0.6768 - val_loss: 0.0231 - val_outmap_loss: 0.0216 - val_outmap4_loss: 0.0153 - val_outmap_dice_coef_loss: -0.6536
# Epoch 38/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0207 - outmap_loss: 0.0191 - outmap4_loss: 0.0158 - outmap_dice_coef_loss: -0.6795Epoch 00037: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0207 - outmap_loss: 0.0191 - outmap4_loss: 0.0158 - outmap_dice_coef_loss: -0.6796 - val_loss: 0.0234 - val_outmap_loss: 0.0219 - val_outmap4_loss: 0.0149 - val_outmap_dice_coef_loss: -0.6662
# Epoch 39/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0208 - outmap_loss: 0.0192 - outmap4_loss: 0.0158 - outmap_dice_coef_loss: -0.6782Epoch 00038: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0208 - outmap_loss: 0.0192 - outmap4_loss: 0.0158 - outmap_dice_coef_loss: -0.6782 - val_loss: 0.0232 - val_outmap_loss: 0.0218 - val_outmap4_loss: 0.0136 - val_outmap_dice_coef_loss: -0.6733
# Epoch 40/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0206 - outmap_loss: 0.0191 - outmap4_loss: 0.0157 - outmap_dice_coef_loss: -0.6806Epoch 00039: val_loss improved from 0.02272 to 0.02268, saving model to weights.hdf5
# 20284/20284 [==============================] - 372s - loss: 0.0206 - outmap_loss: 0.0191 - outmap4_loss: 0.0157 - outmap_dice_coef_loss: -0.6805 - val_loss: 0.0227 - val_outmap_loss: 0.0212 - val_outmap4_loss: 0.0145 - val_outmap_dice_coef_loss: -0.6551
# Epoch 41/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0203 - outmap_loss: 0.0188 - outmap4_loss: 0.0155 - outmap_dice_coef_loss: -0.6849Epoch 00040: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0203 - outmap_loss: 0.0188 - outmap4_loss: 0.0155 - outmap_dice_coef_loss: -0.6848 - val_loss: 0.0259 - val_outmap_loss: 0.0242 - val_outmap4_loss: 0.0169 - val_outmap_dice_coef_loss: -0.6343
# Epoch 42/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0202 - outmap_loss: 0.0187 - outmap4_loss: 0.0156 - outmap_dice_coef_loss: -0.6867Epoch 00041: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0202 - outmap_loss: 0.0187 - outmap4_loss: 0.0156 - outmap_dice_coef_loss: -0.6867 - val_loss: 0.0235 - val_outmap_loss: 0.0218 - val_outmap4_loss: 0.0166 - val_outmap_dice_coef_loss: -0.6574
# Epoch 43/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0200 - outmap_loss: 0.0184 - outmap4_loss: 0.0153 - outmap_dice_coef_loss: -0.6904Epoch 00042: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0200 - outmap_loss: 0.0185 - outmap4_loss: 0.0153 - outmap_dice_coef_loss: -0.6903 - val_loss: 0.0229 - val_outmap_loss: 0.0213 - val_outmap4_loss: 0.0162 - val_outmap_dice_coef_loss: -0.6560
# Epoch 44/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0199 - outmap_loss: 0.0184 - outmap4_loss: 0.0154 - outmap_dice_coef_loss: -0.6910Epoch 00043: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0199 - outmap_loss: 0.0184 - outmap4_loss: 0.0154 - outmap_dice_coef_loss: -0.6911 - val_loss: 0.0243 - val_outmap_loss: 0.0227 - val_outmap4_loss: 0.0154 - val_outmap_dice_coef_loss: -0.6726
# Epoch 45/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0200 - outmap_loss: 0.0185 - outmap4_loss: 0.0153 - outmap_dice_coef_loss: -0.6898Epoch 00044: val_loss did not improve
# 20284/20284 [==============================] - 364s - loss: 0.0200 - outmap_loss: 0.0185 - outmap4_loss: 0.0153 - outmap_dice_coef_loss: -0.6897 - val_loss: 0.0231 - val_outmap_loss: 0.0217 - val_outmap4_loss: 0.0144 - val_outmap_dice_coef_loss: -0.6501
# Epoch 46/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0197 - outmap_loss: 0.0182 - outmap4_loss: 0.0154 - outmap_dice_coef_loss: -0.6938Epoch 00045: val_loss did not improve
# 20284/20284 [==============================] - 361s - loss: 0.0197 - outmap_loss: 0.0182 - outmap4_loss: 0.0154 - outmap_dice_coef_loss: -0.6939 - val_loss: 0.0231 - val_outmap_loss: 0.0216 - val_outmap4_loss: 0.0152 - val_outmap_dice_coef_loss: -0.6670
# Epoch 47/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0197 - outmap_loss: 0.0182 - outmap4_loss: 0.0154 - outmap_dice_coef_loss: -0.6946Epoch 00046: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0197 - outmap_loss: 0.0182 - outmap4_loss: 0.0154 - outmap_dice_coef_loss: -0.6947 - val_loss: 0.0239 - val_outmap_loss: 0.0224 - val_outmap4_loss: 0.0156 - val_outmap_dice_coef_loss: -0.6833
# Epoch 48/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0196 - outmap_loss: 0.0181 - outmap4_loss: 0.0154 - outmap_dice_coef_loss: -0.6957Epoch 00047: val_loss did not improve
# 20284/20284 [==============================] - 373s - loss: 0.0196 - outmap_loss: 0.0181 - outmap4_loss: 0.0154 - outmap_dice_coef_loss: -0.6957 - val_loss: 0.0231 - val_outmap_loss: 0.0217 - val_outmap4_loss: 0.0141 - val_outmap_dice_coef_loss: -0.6848
# Epoch 49/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0196 - outmap_loss: 0.0181 - outmap4_loss: 0.0152 - outmap_dice_coef_loss: -0.6965Epoch 00048: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0196 - outmap_loss: 0.0180 - outmap4_loss: 0.0152 - outmap_dice_coef_loss: -0.6965 - val_loss: 0.0236 - val_outmap_loss: 0.0221 - val_outmap4_loss: 0.0145 - val_outmap_dice_coef_loss: -0.6835
# Epoch 50/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0195 - outmap_loss: 0.0179 - outmap4_loss: 0.0150 - outmap_dice_coef_loss: -0.6982Epoch 00049: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0194 - outmap_loss: 0.0179 - outmap4_loss: 0.0151 - outmap_dice_coef_loss: -0.6982 - val_loss: 0.0237 - val_outmap_loss: 0.0223 - val_outmap4_loss: 0.0140 - val_outmap_dice_coef_loss: -0.6864
# Epoch 51/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0196 - outmap_loss: 0.0180 - outmap4_loss: 0.0152 - outmap_dice_coef_loss: -0.6976Epoch 00050: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0196 - outmap_loss: 0.0180 - outmap4_loss: 0.0152 - outmap_dice_coef_loss: -0.6976 - val_loss: 0.0234 - val_outmap_loss: 0.0220 - val_outmap4_loss: 0.0146 - val_outmap_dice_coef_loss: -0.6521
# Epoch 52/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0192 - outmap_loss: 0.0177 - outmap4_loss: 0.0151 - outmap_dice_coef_loss: -0.7021Epoch 00051: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0192 - outmap_loss: 0.0177 - outmap4_loss: 0.0151 - outmap_dice_coef_loss: -0.7021 - val_loss: 0.0235 - val_outmap_loss: 0.0219 - val_outmap4_loss: 0.0156 - val_outmap_dice_coef_loss: -0.6545
# Epoch 53/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0195 - outmap_loss: 0.0180 - outmap4_loss: 0.0151 - outmap_dice_coef_loss: -0.6977Epoch 00052: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0195 - outmap_loss: 0.0180 - outmap4_loss: 0.0151 - outmap_dice_coef_loss: -0.6976 - val_loss: 0.0235 - val_outmap_loss: 0.0219 - val_outmap4_loss: 0.0159 - val_outmap_dice_coef_loss: -0.6494
# Epoch 54/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0192 - outmap_loss: 0.0177 - outmap4_loss: 0.0149 - outmap_dice_coef_loss: -0.7013Epoch 00053: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0192 - outmap_loss: 0.0178 - outmap4_loss: 0.0149 - outmap_dice_coef_loss: -0.7013 - val_loss: 0.0235 - val_outmap_loss: 0.0220 - val_outmap4_loss: 0.0151 - val_outmap_dice_coef_loss: -0.6756
# Epoch 55/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0192 - outmap_loss: 0.0177 - outmap4_loss: 0.0149 - outmap_dice_coef_loss: -0.7024Epoch 00054: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0192 - outmap_loss: 0.0177 - outmap4_loss: 0.0149 - outmap_dice_coef_loss: -0.7025 - val_loss: 0.0230 - val_outmap_loss: 0.0216 - val_outmap4_loss: 0.0143 - val_outmap_dice_coef_loss: -0.6831
# Epoch 56/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0189 - outmap_loss: 0.0175 - outmap4_loss: 0.0148 - outmap_dice_coef_loss: -0.7059Epoch 00055: val_loss improved from 0.02268 to 0.02259, saving model to weights.hdf5
# 20284/20284 [==============================] - 372s - loss: 0.0189 - outmap_loss: 0.0175 - outmap4_loss: 0.0148 - outmap_dice_coef_loss: -0.7059 - val_loss: 0.0226 - val_outmap_loss: 0.0212 - val_outmap4_loss: 0.0144 - val_outmap_dice_coef_loss: -0.6736
# Epoch 57/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0189 - outmap_loss: 0.0174 - outmap4_loss: 0.0148 - outmap_dice_coef_loss: -0.7076Epoch 00056: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0189 - outmap_loss: 0.0174 - outmap4_loss: 0.0148 - outmap_dice_coef_loss: -0.7077 - val_loss: 0.0229 - val_outmap_loss: 0.0214 - val_outmap4_loss: 0.0145 - val_outmap_dice_coef_loss: -0.6684
# Epoch 58/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0189 - outmap_loss: 0.0174 - outmap4_loss: 0.0148 - outmap_dice_coef_loss: -0.7075Epoch 00057: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0189 - outmap_loss: 0.0174 - outmap4_loss: 0.0148 - outmap_dice_coef_loss: -0.7075 - val_loss: 0.0234 - val_outmap_loss: 0.0219 - val_outmap4_loss: 0.0153 - val_outmap_dice_coef_loss: -0.6721
# Epoch 59/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0186 - outmap_loss: 0.0172 - outmap4_loss: 0.0146 - outmap_dice_coef_loss: -0.7103Epoch 00058: val_loss improved from 0.02259 to 0.02200, saving model to weights.hdf5
# 20284/20284 [==============================] - 372s - loss: 0.0187 - outmap_loss: 0.0172 - outmap4_loss: 0.0146 - outmap_dice_coef_loss: -0.7102 - val_loss: 0.0220 - val_outmap_loss: 0.0205 - val_outmap4_loss: 0.0145 - val_outmap_dice_coef_loss: -0.6718
# Epoch 60/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0188 - outmap_loss: 0.0173 - outmap4_loss: 0.0147 - outmap_dice_coef_loss: -0.7084Epoch 00059: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0188 - outmap_loss: 0.0173 - outmap4_loss: 0.0147 - outmap_dice_coef_loss: -0.7084 - val_loss: 0.0238 - val_outmap_loss: 0.0224 - val_outmap4_loss: 0.0143 - val_outmap_dice_coef_loss: -0.6878
# Epoch 61/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0186 - outmap_loss: 0.0172 - outmap4_loss: 0.0145 - outmap_dice_coef_loss: -0.7109Epoch 00060: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0186 - outmap_loss: 0.0172 - outmap4_loss: 0.0145 - outmap_dice_coef_loss: -0.7110 - val_loss: 0.0250 - val_outmap_loss: 0.0234 - val_outmap4_loss: 0.0160 - val_outmap_dice_coef_loss: -0.6752
# Epoch 62/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0185 - outmap_loss: 0.0170 - outmap4_loss: 0.0146 - outmap_dice_coef_loss: -0.7140Epoch 00061: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0185 - outmap_loss: 0.0170 - outmap4_loss: 0.0146 - outmap_dice_coef_loss: -0.7139 - val_loss: 0.0233 - val_outmap_loss: 0.0218 - val_outmap4_loss: 0.0147 - val_outmap_dice_coef_loss: -0.6665
# Epoch 63/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0186 - outmap_loss: 0.0172 - outmap4_loss: 0.0146 - outmap_dice_coef_loss: -0.7114Epoch 00062: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0186 - outmap_loss: 0.0172 - outmap4_loss: 0.0146 - outmap_dice_coef_loss: -0.7113 - val_loss: 0.0238 - val_outmap_loss: 0.0224 - val_outmap4_loss: 0.0138 - val_outmap_dice_coef_loss: -0.6734
# Epoch 64/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0185 - outmap_loss: 0.0170 - outmap4_loss: 0.0146 - outmap_dice_coef_loss: -0.7128Epoch 00063: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0185 - outmap_loss: 0.0171 - outmap4_loss: 0.0146 - outmap_dice_coef_loss: -0.7128 - val_loss: 0.0234 - val_outmap_loss: 0.0220 - val_outmap4_loss: 0.0143 - val_outmap_dice_coef_loss: -0.6616
# Epoch 65/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0183 - outmap_loss: 0.0169 - outmap4_loss: 0.0146 - outmap_dice_coef_loss: -0.7155Epoch 00064: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0183 - outmap_loss: 0.0169 - outmap4_loss: 0.0146 - outmap_dice_coef_loss: -0.7154 - val_loss: 0.0238 - val_outmap_loss: 0.0223 - val_outmap4_loss: 0.0153 - val_outmap_dice_coef_loss: -0.6695
# Epoch 66/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0186 - outmap_loss: 0.0171 - outmap4_loss: 0.0145 - outmap_dice_coef_loss: -0.7123Epoch 00065: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0186 - outmap_loss: 0.0171 - outmap4_loss: 0.0145 - outmap_dice_coef_loss: -0.7123 - val_loss: 0.0231 - val_outmap_loss: 0.0217 - val_outmap4_loss: 0.0142 - val_outmap_dice_coef_loss: -0.6673
# Epoch 67/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0184 - outmap_loss: 0.0170 - outmap4_loss: 0.0145 - outmap_dice_coef_loss: -0.7136Epoch 00066: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0184 - outmap_loss: 0.0170 - outmap4_loss: 0.0145 - outmap_dice_coef_loss: -0.7136 - val_loss: 0.0247 - val_outmap_loss: 0.0231 - val_outmap4_loss: 0.0162 - val_outmap_dice_coef_loss: -0.6691
# Epoch 68/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0182 - outmap_loss: 0.0168 - outmap4_loss: 0.0144 - outmap_dice_coef_loss: -0.7178Epoch 00067: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0182 - outmap_loss: 0.0168 - outmap4_loss: 0.0144 - outmap_dice_coef_loss: -0.7177 - val_loss: 0.0235 - val_outmap_loss: 0.0220 - val_outmap4_loss: 0.0144 - val_outmap_dice_coef_loss: -0.6584
# Epoch 69/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0181 - outmap_loss: 0.0167 - outmap4_loss: 0.0144 - outmap_dice_coef_loss: -0.7190Epoch 00068: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0181 - outmap_loss: 0.0167 - outmap4_loss: 0.0144 - outmap_dice_coef_loss: -0.7190 - val_loss: 0.0252 - val_outmap_loss: 0.0237 - val_outmap4_loss: 0.0154 - val_outmap_dice_coef_loss: -0.6708
# Epoch 70/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0182 - outmap_loss: 0.0167 - outmap4_loss: 0.0144 - outmap_dice_coef_loss: -0.7182Epoch 00069: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0182 - outmap_loss: 0.0167 - outmap4_loss: 0.0144 - outmap_dice_coef_loss: -0.7182 - val_loss: 0.0244 - val_outmap_loss: 0.0228 - val_outmap4_loss: 0.0153 - val_outmap_dice_coef_loss: -0.6713
# Epoch 71/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0179 - outmap_loss: 0.0165 - outmap4_loss: 0.0142 - outmap_dice_coef_loss: -0.7214Epoch 00070: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0179 - outmap_loss: 0.0165 - outmap4_loss: 0.0142 - outmap_dice_coef_loss: -0.7214 - val_loss: 0.0237 - val_outmap_loss: 0.0223 - val_outmap4_loss: 0.0139 - val_outmap_dice_coef_loss: -0.6765
# Epoch 72/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0180 - outmap_loss: 0.0166 - outmap4_loss: 0.0141 - outmap_dice_coef_loss: -0.7198Epoch 00071: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0180 - outmap_loss: 0.0166 - outmap4_loss: 0.0141 - outmap_dice_coef_loss: -0.7198 - val_loss: 0.0236 - val_outmap_loss: 0.0221 - val_outmap4_loss: 0.0147 - val_outmap_dice_coef_loss: -0.6777
# Epoch 73/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0180 - outmap_loss: 0.0166 - outmap4_loss: 0.0143 - outmap_dice_coef_loss: -0.7208Epoch 00072: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0180 - outmap_loss: 0.0166 - outmap4_loss: 0.0143 - outmap_dice_coef_loss: -0.7209 - val_loss: 0.0234 - val_outmap_loss: 0.0219 - val_outmap4_loss: 0.0157 - val_outmap_dice_coef_loss: -0.6916
# Epoch 74/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0179 - outmap_loss: 0.0165 - outmap4_loss: 0.0141 - outmap_dice_coef_loss: -0.7211Epoch 00073: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0179 - outmap_loss: 0.0165 - outmap4_loss: 0.0141 - outmap_dice_coef_loss: -0.7211 - val_loss: 0.0233 - val_outmap_loss: 0.0218 - val_outmap4_loss: 0.0147 - val_outmap_dice_coef_loss: -0.6753
# Epoch 75/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0180 - outmap_loss: 0.0166 - outmap4_loss: 0.0143 - outmap_dice_coef_loss: -0.7205Epoch 00074: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0180 - outmap_loss: 0.0166 - outmap4_loss: 0.0143 - outmap_dice_coef_loss: -0.7205 - val_loss: 0.0233 - val_outmap_loss: 0.0219 - val_outmap4_loss: 0.0140 - val_outmap_dice_coef_loss: -0.6669
# Epoch 76/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0178 - outmap_loss: 0.0164 - outmap4_loss: 0.0140 - outmap_dice_coef_loss: -0.7223Epoch 00075: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0179 - outmap_loss: 0.0165 - outmap4_loss: 0.0140 - outmap_dice_coef_loss: -0.7223 - val_loss: 0.0249 - val_outmap_loss: 0.0235 - val_outmap4_loss: 0.0139 - val_outmap_dice_coef_loss: -0.6722
# Epoch 77/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0177 - outmap_loss: 0.0163 - outmap4_loss: 0.0141 - outmap_dice_coef_loss: -0.7253Epoch 00076: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0177 - outmap_loss: 0.0163 - outmap4_loss: 0.0141 - outmap_dice_coef_loss: -0.7253 - val_loss: 0.0250 - val_outmap_loss: 0.0235 - val_outmap4_loss: 0.0156 - val_outmap_dice_coef_loss: -0.6688
# Epoch 78/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0176 - outmap_loss: 0.0162 - outmap4_loss: 0.0139 - outmap_dice_coef_loss: -0.7254Epoch 00077: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0176 - outmap_loss: 0.0162 - outmap4_loss: 0.0139 - outmap_dice_coef_loss: -0.7253 - val_loss: 0.0237 - val_outmap_loss: 0.0222 - val_outmap4_loss: 0.0148 - val_outmap_dice_coef_loss: -0.6564
# Epoch 79/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0177 - outmap_loss: 0.0163 - outmap4_loss: 0.0139 - outmap_dice_coef_loss: -0.7246Epoch 00078: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0177 - outmap_loss: 0.0163 - outmap4_loss: 0.0139 - outmap_dice_coef_loss: -0.7245 - val_loss: 0.0225 - val_outmap_loss: 0.0211 - val_outmap4_loss: 0.0141 - val_outmap_dice_coef_loss: -0.6663
# Epoch 80/80
# 20224/20284 [============================>.] - ETA: 1s - loss: 0.0175 - outmap_loss: 0.0161 - outmap4_loss: 0.0139 - outmap_dice_coef_loss: -0.7285Epoch 00079: val_loss did not improve
# 20284/20284 [==============================] - 372s - loss: 0.0174 - outmap_loss: 0.0161 - outmap4_loss: 0.0139 - outmap_dice_coef_loss: -0.7285 - val_loss: 0.0227 - val_outmap_loss: 0.0212 - val_outmap4_loss: 0.0141 - val_outmap_dice_coef_loss: -0.6792

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture_final.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights_final.hdf5'))

# %%
def compute_scores_map(X, Y):
    Y_pred, Y_pred44 = model.predict(X)
    
    map_threshs = np.linspace(0, 1, num=21)
    
    scores = np.zeros(len(map_threshs))
    for i in range(len(map_threshs)):
        _Y_pred = Y_pred > map_threshs[i]

        for k in range(_Y_pred.shape[0]):
            # Clear prediction where we detect to little pixels
            if np.sum(_Y_pred[k]) < 150:
                _Y_pred[k,:] = 0

        scores[i] = utils.average_dice_coefficient(_Y_pred, Y)
    
    pl.plot(scores)
    pl.xticks(np.arange(len(map_threshs)) + 0.5, ['%.2f' % v for v in map_threshs], rotation=90)
    pl.ylabel('map thresh')
    
    best_i = np.argmax(scores.ravel())
    best_map_thresh = map_threshs[best_i]
    return best_map_thresh

map_thresh = compute_scores_map(X_test, Y_test)
print 'Best map_thresh=%f' % map_thresh
# Out:
# Best map_thresh=0.600000

# %%
map_thresh = 0.6

# %%
def predict(X, map_thresh):
    Y_pred, Y_pred44 = model.predict(X)
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > map_thresh
    for i in range(Y_pred.shape[0]):
        if np.sum(Y_pred[i]) < 150:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba

Y_pred, Y_pred_proba = predict(X_test, map_thresh)

print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "avg test set score : ", utils.average_dice_coefficient(Y_pred, Y_test)

Y_pred_mask = np.any(Y_pred.reshape(-1, 128 * 128), axis=1)
print "%.2f%% with masks in pred" % (100 * np.count_nonzero(Y_pred_mask) / float(len(Y_pred_mask)))
# Out:
# test set score :  0.736641770401
# avg test set score :  0.790591513529
# 55.67% with masks in pred

# %%
avg_pred = np.sum(Y_pred.squeeze(), axis=0)
pl.figure(figsize=(10, 4))
pl.subplot(121)
pl.imshow(avg_pred)
pl.colorbar(shrink=0.5)
pl.subplot(122)
pl.imshow(avg_pred > 3, cmap=cm.binary)
pl.colorbar(shrink=0.5)
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/matplotlib/transforms.py:2764: DeprecationWarning: numpy boolean subtract, the `-` operator, is deprecated, use the bitwise_xor, the `^` operator, or the logical_xor function instead.
#   elif vmax - vmin <= maxabsvalue * tiny:

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[45:50]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.2
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(30):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, pred44 = model.predict(img[None,None,:,:])
    return img, pred_map

i = 15
img, pred_map = dream_output(Y_train[i])
pl.figure(figsize=(12, 4))
pl.subplot(141)
pl.imshow(X_train[i].squeeze(), cmap=cm.gray)
pl.subplot(142)
pl.imshow(Y_train[i].squeeze())
pl.subplot(143)
pl.imshow(img, cmap=cm.gray)
pl.subplot(144)
pl.imshow(pred_map.squeeze())

# %%
def dream_layer_filter(layer_name, filter_index):

    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4']:
    pl.figure(figsize=(16, 8))
    for i in range(4):
        pl.subplot(1, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-a426d7c48f8a> in <module>()
#      43         pl.subplot(1, 4, i + 1)
#      44         pl.title('%s:%d' % (layer_name, i))
# ---> 45         img = dream_layer_filter(layer_name, i)
#      46         pl.imshow(img, cmap=cm.gray)
#
# <ipython-input-39-a426d7c48f8a> in dream_layer_filter(layer_name, filter_index)
#       3     # build a loss function that maximizes the activation
#       4     # of the nth filter of the layer considered
# ----> 5     layer_output = layer_dict[layer_name].output
#       6     loss = K.mean(layer_output[:, filter_index, :, :])
#       7
#
# KeyError: 'pool5'

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
if True:
    import cv2
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(50,50))
    
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    test_fnames = _d['test_fnames']
    # bin_thresh
    Y_pred, Y_pred_proba = predict(X_submit[:,None,:,:], map_thresh)
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
        #imre = cv2.morphologyEx(imre, cv2.MORPH_CLOSE, kernel)
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
        
        if i % 10 == 0:
            print '\r%d / %d' % (i, len(test_fnames)),
            sys.stdout.flush()
# Out:
# 5500 / 5508

# %% [markdown]
# ## Stats on predicted masks

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
pl.xlim((0, 1200))
# Out:
# (0, 1200)
