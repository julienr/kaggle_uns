# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']
X_pids = _d['pids']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
print X.dtype
print Y.dtype
# Out:
# (3906, 128, 128)
# (3906, 128, 128)
# float32
# float32

# %%
if True:
    # Split patients in train/test
    train_pids, test_pids = train_test_split(np.unique(X_pids), test_size=0.1)
    print train_pids
    print test_pids
    
    train_indices = np.flatnonzero(np.in1d(X_pids, train_pids))
    test_indices = np.flatnonzero(np.in1d(X_pids, test_pids))
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]
else:
    nsamples = X.shape[0]

    #train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.2)
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]
# Out:
# [ 5 31 36 26  7 25 28  9 14  6 18 34 45 30 23 22 13 41 10 47 43 21 20 17 35
#  32 12 44 39 16 27  2  3 29 40 37 24 19  8  1 15  4]
# [38 42 46 11 33]

# %%
import skimage.transform as sktransf

def rand_float(rng):
    return rng[0] + np.random.random() * (rng[1] - rng[0])

def generate_image(X_img, Y_img, angle_range=None, zoom_range=None, shear_range=None, horiz_shift_range=None,
                   vert_shift_range=None):
    """
    Randomly shift an image by resizing and then random croping
    the resized image
    """
    if angle_range is None:
        angle_range = (-5, 5)
    if zoom_range is None:
        zoom_range = (0.8, 1.2)
    if shear_range is None:
        shear_range = (-5, 5) # shear angle in degrees
    if horiz_shift_range is None:
        horiz_shift_range = (-5, 5)
    if vert_shift_range is None:
        vert_shift_range = (-5, 5)
    inshape = X_img.shape
    
    X2 = X_img.copy()
    Y2 = Y_img.copy()
    
    # -- random rotation
    angle = np.deg2rad(rand_float(angle_range))
    zoom = rand_float(zoom_range)
    shear = np.deg2rad(rand_float(shear_range))
    horiz_shift = rand_float(horiz_shift_range)
    vert_shift = rand_float(vert_shift_range)
    
    tform = sktransf.AffineTransform(
        scale=(zoom, zoom),
        rotation=angle,
        shear=shear,
        translation=(horiz_shift, vert_shift)
    )
    X2 = sktransf.warp(X2, tform, order=5, mode='edge')
    Y2 = sktransf.warp(Y2, tform, order=1)

    # gaussian noise
    #noise_scale = rand_float((0, 0.1))
    #X2 += np.random.normal(scale=noise_scale, size=X2.shape)
    Y2 = Y2 > 0.5
    return X2[None,:,:].astype(np.float32), Y2[None,:,:].astype(np.float32)

X_train_augmented = []
Y_train_augmented = []
for i in range(X_train.shape[0]):
    if i % 10 == 0:
        print '\r%d / %d' % (i, X_train.shape[0]),
        sys.stdout.flush()
    X_train_augmented.append(X_train[i])
    Y_train_augmented.append(Y_train[i])
    for j in range(2):
        X2, Y2 = generate_image(X_train[i].squeeze(), Y_train[i].squeeze())
        X_train_augmented.append(X2)
        Y_train_augmented.append(Y2)
# Out:
# 3450 / 3457

# %%
X_train = np.array(X_train_augmented, dtype=np.float32)
Y_train = np.array(Y_train_augmented, dtype=np.float32)

Y_train_binary = np.sum(np.sum(Y_train.squeeze(), axis=2), axis=1) > 0
Y_train_binary = Y_train_binary.astype(np.float32)
Y_train_binary = Y_train_binary[:,None]

# %%
print X_train.shape
print Y_train.shape
print X_test.shape
print X_train.min(), X_train.max()
# Out:
# (10371, 1, 128, 128)
# (10371, 1, 128, 128)
# (449, 1, 128, 128)
# 0.0 1.0

# %%
import cv2
def _resize(Y, outshape):
    return cv2.resize(Y.squeeze(), outshape, interpolation=cv2.INTER_AREA)[None, :, :]
Y_train_88 = np.array([_resize(img, (8, 8)) for img in Y_train])
Y_test_88 = np.array([_resize(img, (8, 8)) for img in Y_test])
Y_train_44 = np.array([_resize(img, (4, 4)) for img in Y_train])
Y_test_44 = np.array([_resize(img, (4, 4)) for img in Y_test])

# %%
with_bp = np.flatnonzero(np.sum(np.sum(np.sum(Y_train, axis=1), axis=1), axis=1))

# %%
for bpi in range(11, 14):
    i = with_bp[bpi]
    pl.figure(figsize=(16, 4))
    pl.subplot(141)
    pl.imshow(X_train[i].squeeze())
    pl.subplot(142)
    pl.imshow(Y_train[i].squeeze())
    pl.subplot(143)
    pl.imshow(Y_train_88[i].squeeze(), interpolation='nearest')
    pl.colorbar()
    pl.subplot(144)
    pl.imshow(Y_train_44[i].squeeze(), interpolation='nearest')
    pl.colorbar()

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float32'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense
from keras.layers import LeakyReLU, BatchNormalization
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
import keras.backend as K
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
from keras.layers import Layer, InputSpec
import keras.initializations
import keras.backend as K

class Maxout2D(Layer):
    def __init__(self, output_dim, cardinality, init='glorot_uniform', **kwargs):
        super(Maxout2D, self).__init__(**kwargs)
        # the k of the maxout paper
        self.cardinality = cardinality
        # the m of the maxout paper
        self.output_dim = output_dim
        self.init = keras.initializations.get(init)
    
    def build(self, input_shape):
        self.input_dim = input_shape[1]
        self.input_spec = [InputSpec(dtype=K.floatx(),
                                     shape=(None, input_shape[1], input_shape[2], input_shape[3]))]
        self.W = self.init((self.input_dim, self.output_dim, self.cardinality),
                           name='{}_W'.format(self.name))
        self.b = K.zeros((self.output_dim, self.cardinality))
        self.trainable_weights = [self.W, self.b]
              
    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        # flatten the spatial dimensions
        flat_x = K.reshape(x, (-1, input_shape[1], input_shape[2] * input_shape[3]))
        output = K.dot(
            K.permute_dimensions(flat_x, (0, 2, 1)),
            K.permute_dimensions(self.W, (1, 0, 2))
        )
        output += K.reshape(self.b, (1, 1, self.output_dim, self.cardinality))
        output = K.max(output, axis=3)
        output = output.transpose(0, 2, 1)
        output = K.reshape(output, (-1, self.output_dim, input_shape[2], input_shape[3]))
        return output
    
    def get_output_shape_for(self, input_shape):
        return (input_shape[0], self.output_dim, input_shape[2], input_shape[3])
    
    def get_config(self):
        config = {
            'output_dim': self.output_dim,
            'cardinality': self.cardinality
        }
        base_config = super(Maxout2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
input_img = x = Input(shape=input_shape, name='input_img')
x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(input_img)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool1 = x = MaxPooling2D((2, 2), name='pool1')(x)

x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool2 = x = MaxPooling2D((2, 2), name='pool2')(x)

x = Dropout(0.25)(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool3 = x = MaxPooling2D((2, 2), name='pool3')(x)

# -- binary presence part
x = Dropout(0.25)(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

x = Dropout(0.25)(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(pool5)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# turn pool4 and 5 into classification map
outmap4 = Convolution2D(1, 3, 3, border_mode='same', activation='sigmoid', name='outmap4')(pool4)

outmap5 = Convolution2D(1, 3, 3, border_mode='same', activation='sigmoid', name='outmap5')(pool5)

# upsample the classif map
x = merge([
        UpSampling2D((2, 2))(outmap4),
        UpSampling2D((4, 4))(outmap5),
        pool3
    ], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(pool3)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
x = UpSampling2D((2, 2))(x)

x = Dropout(0.25)(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outmap4, outmap5, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
metrics={'outbin': 'accuracy'}
model.compile(optimizer='adam', loss='binary_crossentropy',
              loss_weights=[1., 0.2, 0.05, 0.01], metrics=metrics)

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)    (None, 32, 128, 128)320         input_img[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)    (None, 16, 128, 128)4624        convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# maxout2d_1 (Maxout2D)              (None, 16, 128, 128)544         convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)               (None, 16, 64, 64)  0           maxout2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)                (None, 16, 64, 64)  0           pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)    (None, 32, 64, 64)  4640        dropout_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)    (None, 16, 64, 64)  4624        convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# maxout2d_2 (Maxout2D)              (None, 16, 64, 64)  544         convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)               (None, 16, 32, 32)  0           maxout2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)                (None, 16, 32, 32)  0           pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)    (None, 32, 32, 32)  4640        dropout_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_6 (Convolution2D)    (None, 16, 32, 32)  4624        convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# maxout2d_3 (Maxout2D)              (None, 16, 32, 32)  544         convolution2d_6[0][0]
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)               (None, 16, 16, 16)  0           maxout2d_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_11 (Convolution2D)   (None, 16, 16, 16)  2320        pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_12 (Convolution2D)   (None, 16, 16, 16)  2320        convolution2d_11[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)                (None, 16, 16, 16)  0           pool3[0][0]
# ____________________________________________________________________________________________________
# maxout2d_6 (Maxout2D)              (None, 16, 16, 16)  544         convolution2d_12[0][0]
# ____________________________________________________________________________________________________
# convolution2d_7 (Convolution2D)    (None, 16, 16, 16)  2320        dropout_4[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_3 (UpSampling2D)      (None, 16, 32, 32)  0           maxout2d_6[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8 (Convolution2D)    (None, 16, 16, 16)  2320        convolution2d_7[0][0]
# ____________________________________________________________________________________________________
# merge_2 (Merge)                    (None, 32, 32, 32)  0           upsampling2d_3[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_13 (Convolution2D)   (None, 16, 32, 32)  4624        merge_2[0][0]
# ____________________________________________________________________________________________________
# maxout2d_4 (Maxout2D)              (None, 16, 16, 16)  544         convolution2d_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_14 (Convolution2D)   (None, 16, 32, 32)  2320        convolution2d_13[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)               (None, 16, 8, 8)    0           maxout2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)                (None, 16, 8, 8)    0           pool4[0][0]
# ____________________________________________________________________________________________________
# maxout2d_7 (Maxout2D)              (None, 16, 32, 32)  544         convolution2d_14[0][0]
# ____________________________________________________________________________________________________
# convolution2d_9 (Convolution2D)    (None, 16, 8, 8)    2320        dropout_5[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_4 (UpSampling2D)      (None, 16, 64, 64)  0           maxout2d_7[0][0]
# ____________________________________________________________________________________________________
# convolution2d_10 (Convolution2D)   (None, 16, 8, 8)    2320        convolution2d_9[0][0]
# ____________________________________________________________________________________________________
# merge_3 (Merge)                    (None, 32, 64, 64)  0           upsampling2d_4[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_15 (Convolution2D)   (None, 16, 64, 64)  4624        merge_3[0][0]
# ____________________________________________________________________________________________________
# maxout2d_5 (Maxout2D)              (None, 16, 8, 8)    544         convolution2d_10[0][0]
# ____________________________________________________________________________________________________
# convolution2d_16 (Convolution2D)   (None, 16, 64, 64)  2320        convolution2d_15[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)               (None, 16, 4, 4)    0           maxout2d_5[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)                (None, 256)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# maxout2d_8 (Maxout2D)              (None, 16, 64, 64)  544         convolution2d_16[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                    (None, 32)          8224        flatten_1[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_5 (UpSampling2D)      (None, 16, 128, 128)0           maxout2d_8[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)                (None, 16, 128, 128)0           upsampling2d_5[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_1 (LeakyReLU)            (None, 32)          0           dense_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_17 (Convolution2D)   (None, 8, 128, 128) 1160        dropout_6[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                    (None, 16)          528         leakyrelu_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_18 (Convolution2D)   (None, 8, 128, 128) 584         convolution2d_17[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_2 (LeakyReLU)            (None, 16)          0           dense_2[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_2[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 73          convolution2d_18[0][0]
# ____________________________________________________________________________________________________
# outmap4 (Convolution2D)            (None, 1, 8, 8)     145         pool4[0][0]
# ____________________________________________________________________________________________________
# outmap5 (Convolution2D)            (None, 1, 4, 4)     145         pool5[0][0]
# ====================================================================================================
# Total params: 66508
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {
            'outmap': Y_train,
            'outmap4' : Y_train_88,
            'outmap5' : Y_train_44,
            'outbin': Y_train_binary
        },
        batch_size=64,
        validation_data=(X_test, {
                'outmap': Y_test,
                'outmap4' : Y_test_88,
                'outmap5' : Y_test_44,
                'outbin': Y_test_binary
        }),
        nb_epoch=60,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    
    pl.figure()
    pl.plot(history.history['outmap_loss'], label='train loss')
    pl.plot(history.history['val_outmap_loss'], c='g', label='val loss')
    pl.legend()

    pl.figure()
    pl.plot(history.history['outbin_acc'], label='train acc')
    pl.plot(history.history['val_outbin_acc'], c='g', label='val acc')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
                custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.01])
    
    print_summary(model.layers)
# Out:
# Train on 10371 samples, validate on 449 samples
# Epoch 1/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.1237 - outmap_loss: 0.0893 - outmap4_loss: 0.0927 - outmap5_loss: 0.1416 - outbin_loss: 0.8765 - outbin_acc: 0.5774Epoch 00000: val_loss improved from inf to 0.08002, saving model to weights.hdf5
# 10371/10371 [==============================] - 125s - loss: 0.1237 - outmap_loss: 0.0893 - outmap4_loss: 0.0927 - outmap5_loss: 0.1415 - outbin_loss: 0.8765 - outbin_acc: 0.5774 - val_loss: 0.0800 - val_outmap_loss: 0.0481 - val_outmap4_loss: 0.0955 - val_outmap5_loss: 0.1274 - val_outbin_loss: 0.6406 - val_outbin_acc: 0.5768
# Epoch 2/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0573 - outmap_loss: 0.0374 - outmap4_loss: 0.0513 - outmap5_loss: 0.0597 - outbin_loss: 0.6631 - outbin_acc: 0.6184Epoch 00001: val_loss improved from 0.08002 to 0.06632, saving model to weights.hdf5
# 10371/10371 [==============================] - 127s - loss: 0.0573 - outmap_loss: 0.0374 - outmap4_loss: 0.0513 - outmap5_loss: 0.0597 - outbin_loss: 0.6630 - outbin_acc: 0.6186 - val_loss: 0.0663 - val_outmap_loss: 0.0474 - val_outmap4_loss: 0.0476 - val_outmap5_loss: 0.0567 - val_outbin_loss: 0.6530 - val_outbin_acc: 0.5657
# Epoch 3/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0494 - outmap_loss: 0.0323 - outmap4_loss: 0.0423 - outmap5_loss: 0.0526 - outbin_loss: 0.5976 - outbin_acc: 0.6800Epoch 00002: val_loss improved from 0.06632 to 0.05967, saving model to weights.hdf5
# 10371/10371 [==============================] - 126s - loss: 0.0494 - outmap_loss: 0.0323 - outmap4_loss: 0.0423 - outmap5_loss: 0.0527 - outbin_loss: 0.5977 - outbin_acc: 0.6800 - val_loss: 0.0597 - val_outmap_loss: 0.0384 - val_outmap4_loss: 0.0626 - val_outmap5_loss: 0.0596 - val_outbin_loss: 0.5775 - val_outbin_acc: 0.6927
# Epoch 4/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0446 - outmap_loss: 0.0295 - outmap4_loss: 0.0382 - outmap5_loss: 0.0481 - outbin_loss: 0.5156 - outbin_acc: 0.7525Epoch 00003: val_loss improved from 0.05967 to 0.05231, saving model to weights.hdf5
# 10371/10371 [==============================] - 126s - loss: 0.0446 - outmap_loss: 0.0295 - outmap4_loss: 0.0382 - outmap5_loss: 0.0481 - outbin_loss: 0.5156 - outbin_acc: 0.7525 - val_loss: 0.0523 - val_outmap_loss: 0.0316 - val_outmap4_loss: 0.0634 - val_outmap5_loss: 0.0646 - val_outbin_loss: 0.4771 - val_outbin_acc: 0.7862
# Epoch 5/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0412 - outmap_loss: 0.0271 - outmap4_loss: 0.0357 - outmap5_loss: 0.0456 - outbin_loss: 0.4691 - outbin_acc: 0.7829Epoch 00004: val_loss improved from 0.05231 to 0.04470, saving model to weights.hdf5
# 10371/10371 [==============================] - 126s - loss: 0.0412 - outmap_loss: 0.0271 - outmap4_loss: 0.0358 - outmap5_loss: 0.0456 - outbin_loss: 0.4691 - outbin_acc: 0.7829 - val_loss: 0.0447 - val_outmap_loss: 0.0291 - val_outmap4_loss: 0.0387 - val_outmap5_loss: 0.0449 - val_outbin_loss: 0.5588 - val_outbin_acc: 0.7060
# Epoch 6/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0407 - outmap_loss: 0.0269 - outmap4_loss: 0.0350 - outmap5_loss: 0.0448 - outbin_loss: 0.4552 - outbin_acc: 0.7896Epoch 00005: val_loss improved from 0.04470 to 0.04053, saving model to weights.hdf5
# 10371/10371 [==============================] - 126s - loss: 0.0407 - outmap_loss: 0.0269 - outmap4_loss: 0.0350 - outmap5_loss: 0.0448 - outbin_loss: 0.4551 - outbin_acc: 0.7897 - val_loss: 0.0405 - val_outmap_loss: 0.0266 - val_outmap4_loss: 0.0353 - val_outmap5_loss: 0.0420 - val_outbin_loss: 0.4734 - val_outbin_acc: 0.7661
# Epoch 7/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0382 - outmap_loss: 0.0250 - outmap4_loss: 0.0336 - outmap5_loss: 0.0431 - outbin_loss: 0.4319 - outbin_acc: 0.8064Epoch 00006: val_loss improved from 0.04053 to 0.03862, saving model to weights.hdf5
# 10371/10371 [==============================] - 126s - loss: 0.0382 - outmap_loss: 0.0250 - outmap4_loss: 0.0336 - outmap5_loss: 0.0431 - outbin_loss: 0.4318 - outbin_acc: 0.8065 - val_loss: 0.0386 - val_outmap_loss: 0.0252 - val_outmap4_loss: 0.0345 - val_outmap5_loss: 0.0423 - val_outbin_loss: 0.4388 - val_outbin_acc: 0.7951
# Epoch 8/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0365 - outmap_loss: 0.0237 - outmap4_loss: 0.0326 - outmap5_loss: 0.0420 - outbin_loss: 0.4166 - outbin_acc: 0.8131Epoch 00007: val_loss improved from 0.03862 to 0.03805, saving model to weights.hdf5
# 10371/10371 [==============================] - 126s - loss: 0.0365 - outmap_loss: 0.0237 - outmap4_loss: 0.0326 - outmap5_loss: 0.0420 - outbin_loss: 0.4167 - outbin_acc: 0.8130 - val_loss: 0.0381 - val_outmap_loss: 0.0249 - val_outmap4_loss: 0.0326 - val_outmap5_loss: 0.0427 - val_outbin_loss: 0.4493 - val_outbin_acc: 0.7840
# Epoch 9/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0359 - outmap_loss: 0.0233 - outmap4_loss: 0.0322 - outmap5_loss: 0.0417 - outbin_loss: 0.4142 - outbin_acc: 0.8154Epoch 00008: val_loss did not improve
# 10371/10371 [==============================] - 126s - loss: 0.0359 - outmap_loss: 0.0232 - outmap4_loss: 0.0322 - outmap5_loss: 0.0416 - outbin_loss: 0.4141 - outbin_acc: 0.8154 - val_loss: 0.0445 - val_outmap_loss: 0.0283 - val_outmap4_loss: 0.0330 - val_outmap5_loss: 0.0432 - val_outbin_loss: 0.7448 - val_outbin_acc: 0.6526
# Epoch 10/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0353 - outmap_loss: 0.0228 - outmap4_loss: 0.0318 - outmap5_loss: 0.0410 - outbin_loss: 0.4083 - outbin_acc: 0.8186Epoch 00009: val_loss did not improve
# 10371/10371 [==============================] - 126s - loss: 0.0353 - outmap_loss: 0.0228 - outmap4_loss: 0.0318 - outmap5_loss: 0.0410 - outbin_loss: 0.4082 - outbin_acc: 0.8186 - val_loss: 0.0386 - val_outmap_loss: 0.0256 - val_outmap4_loss: 0.0342 - val_outmap5_loss: 0.0456 - val_outbin_loss: 0.3911 - val_outbin_acc: 0.8352
# Epoch 11/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0344 - outmap_loss: 0.0222 - outmap4_loss: 0.0313 - outmap5_loss: 0.0404 - outbin_loss: 0.3899 - outbin_acc: 0.8322Epoch 00010: val_loss improved from 0.03805 to 0.03803, saving model to weights.hdf5
# 10371/10371 [==============================] - 126s - loss: 0.0344 - outmap_loss: 0.0222 - outmap4_loss: 0.0313 - outmap5_loss: 0.0404 - outbin_loss: 0.3903 - outbin_acc: 0.8320 - val_loss: 0.0380 - val_outmap_loss: 0.0249 - val_outmap4_loss: 0.0343 - val_outmap5_loss: 0.0460 - val_outbin_loss: 0.3939 - val_outbin_acc: 0.8307
# Epoch 12/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0349 - outmap_loss: 0.0227 - outmap4_loss: 0.0314 - outmap5_loss: 0.0404 - outbin_loss: 0.3902 - outbin_acc: 0.8304Epoch 00011: val_loss improved from 0.03803 to 0.03626, saving model to weights.hdf5
# 10371/10371 [==============================] - 126s - loss: 0.0349 - outmap_loss: 0.0227 - outmap4_loss: 0.0313 - outmap5_loss: 0.0404 - outbin_loss: 0.3902 - outbin_acc: 0.8305 - val_loss: 0.0363 - val_outmap_loss: 0.0235 - val_outmap4_loss: 0.0343 - val_outmap5_loss: 0.0448 - val_outbin_loss: 0.3654 - val_outbin_acc: 0.8441
# Epoch 13/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0330 - outmap_loss: 0.0212 - outmap4_loss: 0.0305 - outmap5_loss: 0.0395 - outbin_loss: 0.3715 - outbin_acc: 0.8386Epoch 00012: val_loss improved from 0.03626 to 0.03566, saving model to weights.hdf5
# 10371/10371 [==============================] - 130s - loss: 0.0330 - outmap_loss: 0.0212 - outmap4_loss: 0.0305 - outmap5_loss: 0.0395 - outbin_loss: 0.3716 - outbin_acc: 0.8386 - val_loss: 0.0357 - val_outmap_loss: 0.0235 - val_outmap4_loss: 0.0313 - val_outmap5_loss: 0.0417 - val_outbin_loss: 0.3811 - val_outbin_acc: 0.8396
# Epoch 14/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0326 - outmap_loss: 0.0209 - outmap4_loss: 0.0302 - outmap5_loss: 0.0391 - outbin_loss: 0.3662 - outbin_acc: 0.8394Epoch 00013: val_loss did not improve
# 10371/10371 [==============================] - 131s - loss: 0.0326 - outmap_loss: 0.0209 - outmap4_loss: 0.0302 - outmap5_loss: 0.0391 - outbin_loss: 0.3662 - outbin_acc: 0.8394 - val_loss: 0.0368 - val_outmap_loss: 0.0229 - val_outmap4_loss: 0.0379 - val_outmap5_loss: 0.0463 - val_outbin_loss: 0.3989 - val_outbin_acc: 0.8307
# Epoch 15/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0326 - outmap_loss: 0.0210 - outmap4_loss: 0.0302 - outmap5_loss: 0.0390 - outbin_loss: 0.3617 - outbin_acc: 0.8430Epoch 00014: val_loss improved from 0.03566 to 0.03562, saving model to weights.hdf5
# 10371/10371 [==============================] - 131s - loss: 0.0326 - outmap_loss: 0.0210 - outmap4_loss: 0.0302 - outmap5_loss: 0.0389 - outbin_loss: 0.3616 - outbin_acc: 0.8430 - val_loss: 0.0356 - val_outmap_loss: 0.0231 - val_outmap4_loss: 0.0332 - val_outmap5_loss: 0.0435 - val_outbin_loss: 0.3734 - val_outbin_acc: 0.8352
# Epoch 16/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0316 - outmap_loss: 0.0203 - outmap4_loss: 0.0297 - outmap5_loss: 0.0384 - outbin_loss: 0.3509 - outbin_acc: 0.8519Epoch 00015: val_loss did not improve
# 10371/10371 [==============================] - 131s - loss: 0.0316 - outmap_loss: 0.0203 - outmap4_loss: 0.0297 - outmap5_loss: 0.0384 - outbin_loss: 0.3509 - outbin_acc: 0.8520 - val_loss: 0.0373 - val_outmap_loss: 0.0238 - val_outmap4_loss: 0.0352 - val_outmap5_loss: 0.0450 - val_outbin_loss: 0.4277 - val_outbin_acc: 0.7996
# Epoch 17/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0314 - outmap_loss: 0.0201 - outmap4_loss: 0.0294 - outmap5_loss: 0.0381 - outbin_loss: 0.3437 - outbin_acc: 0.8526Epoch 00016: val_loss did not improve
# 10371/10371 [==============================] - 131s - loss: 0.0314 - outmap_loss: 0.0201 - outmap4_loss: 0.0294 - outmap5_loss: 0.0381 - outbin_loss: 0.3437 - outbin_acc: 0.8526 - val_loss: 0.0368 - val_outmap_loss: 0.0234 - val_outmap4_loss: 0.0315 - val_outmap5_loss: 0.0403 - val_outbin_loss: 0.5110 - val_outbin_acc: 0.7261
# Epoch 18/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0311 - outmap_loss: 0.0200 - outmap4_loss: 0.0291 - outmap5_loss: 0.0378 - outbin_loss: 0.3402 - outbin_acc: 0.8554Epoch 00017: val_loss improved from 0.03562 to 0.03472, saving model to weights.hdf5
# 10371/10371 [==============================] - 131s - loss: 0.0311 - outmap_loss: 0.0200 - outmap4_loss: 0.0291 - outmap5_loss: 0.0378 - outbin_loss: 0.3403 - outbin_acc: 0.8554 - val_loss: 0.0347 - val_outmap_loss: 0.0231 - val_outmap4_loss: 0.0299 - val_outmap5_loss: 0.0385 - val_outbin_loss: 0.3733 - val_outbin_acc: 0.8508
# Epoch 19/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0305 - outmap_loss: 0.0195 - outmap4_loss: 0.0289 - outmap5_loss: 0.0377 - outbin_loss: 0.3326 - outbin_acc: 0.8560Epoch 00018: val_loss did not improve
# 10371/10371 [==============================] - 131s - loss: 0.0305 - outmap_loss: 0.0195 - outmap4_loss: 0.0288 - outmap5_loss: 0.0377 - outbin_loss: 0.3326 - outbin_acc: 0.8560 - val_loss: 0.0353 - val_outmap_loss: 0.0234 - val_outmap4_loss: 0.0303 - val_outmap5_loss: 0.0398 - val_outbin_loss: 0.3848 - val_outbin_acc: 0.8330
# Epoch 20/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0304 - outmap_loss: 0.0195 - outmap4_loss: 0.0287 - outmap5_loss: 0.0372 - outbin_loss: 0.3364 - outbin_acc: 0.8601Epoch 00019: val_loss improved from 0.03472 to 0.03421, saving model to weights.hdf5
# 10371/10371 [==============================] - 131s - loss: 0.0304 - outmap_loss: 0.0195 - outmap4_loss: 0.0287 - outmap5_loss: 0.0372 - outbin_loss: 0.3363 - outbin_acc: 0.8602 - val_loss: 0.0342 - val_outmap_loss: 0.0224 - val_outmap4_loss: 0.0305 - val_outmap5_loss: 0.0407 - val_outbin_loss: 0.3648 - val_outbin_acc: 0.8151
# Epoch 21/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0300 - outmap_loss: 0.0192 - outmap4_loss: 0.0286 - outmap5_loss: 0.0371 - outbin_loss: 0.3268 - outbin_acc: 0.8663Epoch 00020: val_loss did not improve
# 10371/10371 [==============================] - 131s - loss: 0.0300 - outmap_loss: 0.0192 - outmap4_loss: 0.0286 - outmap5_loss: 0.0371 - outbin_loss: 0.3267 - outbin_acc: 0.8664 - val_loss: 0.0358 - val_outmap_loss: 0.0243 - val_outmap4_loss: 0.0300 - val_outmap5_loss: 0.0381 - val_outbin_loss: 0.3576 - val_outbin_acc: 0.8396
# Epoch 22/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0298 - outmap_loss: 0.0190 - outmap4_loss: 0.0284 - outmap5_loss: 0.0369 - outbin_loss: 0.3231 - outbin_acc: 0.8656Epoch 00021: val_loss did not improve
# 10371/10371 [==============================] - 131s - loss: 0.0298 - outmap_loss: 0.0190 - outmap4_loss: 0.0284 - outmap5_loss: 0.0369 - outbin_loss: 0.3230 - outbin_acc: 0.8657 - val_loss: 0.0366 - val_outmap_loss: 0.0237 - val_outmap4_loss: 0.0318 - val_outmap5_loss: 0.0438 - val_outbin_loss: 0.4328 - val_outbin_acc: 0.7996
# Epoch 23/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0294 - outmap_loss: 0.0187 - outmap4_loss: 0.0282 - outmap5_loss: 0.0367 - outbin_loss: 0.3173 - outbin_acc: 0.8662Epoch 00022: val_loss improved from 0.03421 to 0.03354, saving model to weights.hdf5
# 10371/10371 [==============================] - 131s - loss: 0.0294 - outmap_loss: 0.0187 - outmap4_loss: 0.0282 - outmap5_loss: 0.0367 - outbin_loss: 0.3173 - outbin_acc: 0.8663 - val_loss: 0.0335 - val_outmap_loss: 0.0218 - val_outmap4_loss: 0.0309 - val_outmap5_loss: 0.0394 - val_outbin_loss: 0.3638 - val_outbin_acc: 0.8374
# Epoch 24/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0290 - outmap_loss: 0.0185 - outmap4_loss: 0.0279 - outmap5_loss: 0.0364 - outbin_loss: 0.3113 - outbin_acc: 0.8710Epoch 00023: val_loss did not improve
# 10371/10371 [==============================] - 128s - loss: 0.0290 - outmap_loss: 0.0185 - outmap4_loss: 0.0279 - outmap5_loss: 0.0364 - outbin_loss: 0.3113 - outbin_acc: 0.8711 - val_loss: 0.0348 - val_outmap_loss: 0.0228 - val_outmap4_loss: 0.0313 - val_outmap5_loss: 0.0386 - val_outbin_loss: 0.3829 - val_outbin_acc: 0.8218
# Epoch 25/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0291 - outmap_loss: 0.0185 - outmap4_loss: 0.0280 - outmap5_loss: 0.0364 - outbin_loss: 0.3106 - outbin_acc: 0.8708Epoch 00024: val_loss did not improve
# 10371/10371 [==============================] - 126s - loss: 0.0291 - outmap_loss: 0.0185 - outmap4_loss: 0.0280 - outmap5_loss: 0.0364 - outbin_loss: 0.3106 - outbin_acc: 0.8708 - val_loss: 0.0367 - val_outmap_loss: 0.0250 - val_outmap4_loss: 0.0299 - val_outmap5_loss: 0.0381 - val_outbin_loss: 0.3767 - val_outbin_acc: 0.8218
# Epoch 26/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0291 - outmap_loss: 0.0187 - outmap4_loss: 0.0279 - outmap5_loss: 0.0362 - outbin_loss: 0.3089 - outbin_acc: 0.8693Epoch 00025: val_loss did not improve
# 10371/10371 [==============================] - 126s - loss: 0.0291 - outmap_loss: 0.0186 - outmap4_loss: 0.0279 - outmap5_loss: 0.0362 - outbin_loss: 0.3088 - outbin_acc: 0.8693 - val_loss: 0.0375 - val_outmap_loss: 0.0257 - val_outmap4_loss: 0.0305 - val_outmap5_loss: 0.0388 - val_outbin_loss: 0.3779 - val_outbin_acc: 0.8151
# Epoch 27/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0284 - outmap_loss: 0.0181 - outmap4_loss: 0.0275 - outmap5_loss: 0.0360 - outbin_loss: 0.3015 - outbin_acc: 0.8732Epoch 00026: val_loss improved from 0.03354 to 0.03265, saving model to weights.hdf5
# 10371/10371 [==============================] - 126s - loss: 0.0284 - outmap_loss: 0.0181 - outmap4_loss: 0.0275 - outmap5_loss: 0.0359 - outbin_loss: 0.3015 - outbin_acc: 0.8732 - val_loss: 0.0327 - val_outmap_loss: 0.0215 - val_outmap4_loss: 0.0286 - val_outmap5_loss: 0.0375 - val_outbin_loss: 0.3575 - val_outbin_acc: 0.8396
# Epoch 28/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0281 - outmap_loss: 0.0179 - outmap4_loss: 0.0274 - outmap5_loss: 0.0358 - outbin_loss: 0.3011 - outbin_acc: 0.8730Epoch 00027: val_loss did not improve
# 10371/10371 [==============================] - 126s - loss: 0.0282 - outmap_loss: 0.0179 - outmap4_loss: 0.0274 - outmap5_loss: 0.0358 - outbin_loss: 0.3012 - outbin_acc: 0.8729 - val_loss: 0.0367 - val_outmap_loss: 0.0238 - val_outmap4_loss: 0.0323 - val_outmap5_loss: 0.0422 - val_outbin_loss: 0.4327 - val_outbin_acc: 0.8040
# Epoch 29/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0305 - outmap_loss: 0.0198 - outmap4_loss: 0.0287 - outmap5_loss: 0.0367 - outbin_loss: 0.3223 - outbin_acc: 0.8674Epoch 00028: val_loss did not improve
# 10371/10371 [==============================] - 130s - loss: 0.0305 - outmap_loss: 0.0198 - outmap4_loss: 0.0287 - outmap5_loss: 0.0367 - outbin_loss: 0.3223 - outbin_acc: 0.8674 - val_loss: 0.0352 - val_outmap_loss: 0.0232 - val_outmap4_loss: 0.0306 - val_outmap5_loss: 0.0397 - val_outbin_loss: 0.3944 - val_outbin_acc: 0.8263
# Epoch 30/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0284 - outmap_loss: 0.0182 - outmap4_loss: 0.0275 - outmap5_loss: 0.0357 - outbin_loss: 0.2966 - outbin_acc: 0.8759Epoch 00029: val_loss did not improve
# 10371/10371 [==============================] - 131s - loss: 0.0284 - outmap_loss: 0.0182 - outmap4_loss: 0.0275 - outmap5_loss: 0.0357 - outbin_loss: 0.2965 - outbin_acc: 0.8759 - val_loss: 0.0343 - val_outmap_loss: 0.0225 - val_outmap4_loss: 0.0309 - val_outmap5_loss: 0.0388 - val_outbin_loss: 0.3677 - val_outbin_acc: 0.8307
# Epoch 31/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0281 - outmap_loss: 0.0179 - outmap4_loss: 0.0271 - outmap5_loss: 0.0355 - outbin_loss: 0.2975 - outbin_acc: 0.8768Epoch 00030: val_loss did not improve
# 10371/10371 [==============================] - 130s - loss: 0.0281 - outmap_loss: 0.0179 - outmap4_loss: 0.0271 - outmap5_loss: 0.0355 - outbin_loss: 0.2975 - outbin_acc: 0.8769 - val_loss: 0.0349 - val_outmap_loss: 0.0233 - val_outmap4_loss: 0.0293 - val_outmap5_loss: 0.0383 - val_outbin_loss: 0.3876 - val_outbin_acc: 0.8241
# Epoch 32/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0278 - outmap_loss: 0.0176 - outmap4_loss: 0.0271 - outmap5_loss: 0.0355 - outbin_loss: 0.3004 - outbin_acc: 0.8752Epoch 00031: val_loss did not improve
# 10371/10371 [==============================] - 131s - loss: 0.0278 - outmap_loss: 0.0176 - outmap4_loss: 0.0271 - outmap5_loss: 0.0354 - outbin_loss: 0.3003 - outbin_acc: 0.8752 - val_loss: 0.0351 - val_outmap_loss: 0.0236 - val_outmap4_loss: 0.0293 - val_outmap5_loss: 0.0379 - val_outbin_loss: 0.3828 - val_outbin_acc: 0.7973
# Epoch 33/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0271 - outmap_loss: 0.0171 - outmap4_loss: 0.0268 - outmap5_loss: 0.0351 - outbin_loss: 0.2859 - outbin_acc: 0.8840Epoch 00032: val_loss did not improve
# 10371/10371 [==============================] - 130s - loss: 0.0271 - outmap_loss: 0.0172 - outmap4_loss: 0.0268 - outmap5_loss: 0.0351 - outbin_loss: 0.2860 - outbin_acc: 0.8838 - val_loss: 0.0338 - val_outmap_loss: 0.0212 - val_outmap4_loss: 0.0299 - val_outmap5_loss: 0.0392 - val_outbin_loss: 0.4656 - val_outbin_acc: 0.7884
# Epoch 34/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0273 - outmap_loss: 0.0172 - outmap4_loss: 0.0269 - outmap5_loss: 0.0351 - outbin_loss: 0.2888 - outbin_acc: 0.8844Epoch 00033: val_loss did not improve
# 10371/10371 [==============================] - 129s - loss: 0.0273 - outmap_loss: 0.0173 - outmap4_loss: 0.0269 - outmap5_loss: 0.0351 - outbin_loss: 0.2890 - outbin_acc: 0.8843 - val_loss: 0.0327 - val_outmap_loss: 0.0207 - val_outmap4_loss: 0.0296 - val_outmap5_loss: 0.0381 - val_outbin_loss: 0.4093 - val_outbin_acc: 0.8107
# Epoch 35/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0274 - outmap_loss: 0.0174 - outmap4_loss: 0.0268 - outmap5_loss: 0.0353 - outbin_loss: 0.2850 - outbin_acc: 0.8824Epoch 00034: val_loss did not improve
# 10371/10371 [==============================] - 126s - loss: 0.0274 - outmap_loss: 0.0174 - outmap4_loss: 0.0268 - outmap5_loss: 0.0354 - outbin_loss: 0.2849 - outbin_acc: 0.8825 - val_loss: 0.0374 - val_outmap_loss: 0.0243 - val_outmap4_loss: 0.0320 - val_outmap5_loss: 0.0422 - val_outbin_loss: 0.4644 - val_outbin_acc: 0.8129
# Epoch 36/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0278 - outmap_loss: 0.0176 - outmap4_loss: 0.0272 - outmap5_loss: 0.0354 - outbin_loss: 0.2972 - outbin_acc: 0.8754Epoch 00035: val_loss did not improve
# 10371/10371 [==============================] - 126s - loss: 0.0278 - outmap_loss: 0.0176 - outmap4_loss: 0.0272 - outmap5_loss: 0.0354 - outbin_loss: 0.2972 - outbin_acc: 0.8753 - val_loss: 0.0367 - val_outmap_loss: 0.0229 - val_outmap4_loss: 0.0329 - val_outmap5_loss: 0.0437 - val_outbin_loss: 0.5057 - val_outbin_acc: 0.7639
# Epoch 37/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0265 - outmap_loss: 0.0168 - outmap4_loss: 0.0264 - outmap5_loss: 0.0346 - outbin_loss: 0.2732 - outbin_acc: 0.8870Epoch 00036: val_loss did not improve
# 10371/10371 [==============================] - 126s - loss: 0.0265 - outmap_loss: 0.0168 - outmap4_loss: 0.0264 - outmap5_loss: 0.0346 - outbin_loss: 0.2733 - outbin_acc: 0.8868 - val_loss: 0.0361 - val_outmap_loss: 0.0234 - val_outmap4_loss: 0.0305 - val_outmap5_loss: 0.0411 - val_outbin_loss: 0.4493 - val_outbin_acc: 0.8107
# Epoch 38/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0279 - outmap_loss: 0.0178 - outmap4_loss: 0.0272 - outmap5_loss: 0.0353 - outbin_loss: 0.2940 - outbin_acc: 0.8770Epoch 00037: val_loss did not improve
# 10371/10371 [==============================] - 126s - loss: 0.0279 - outmap_loss: 0.0178 - outmap4_loss: 0.0272 - outmap5_loss: 0.0353 - outbin_loss: 0.2939 - outbin_acc: 0.8771 - val_loss: 0.0359 - val_outmap_loss: 0.0238 - val_outmap4_loss: 0.0303 - val_outmap5_loss: 0.0400 - val_outbin_loss: 0.4017 - val_outbin_acc: 0.8196
# Epoch 39/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0264 - outmap_loss: 0.0167 - outmap4_loss: 0.0264 - outmap5_loss: 0.0346 - outbin_loss: 0.2720 - outbin_acc: 0.8893Epoch 00038: val_loss did not improve
# 10371/10371 [==============================] - 128s - loss: 0.0264 - outmap_loss: 0.0167 - outmap4_loss: 0.0264 - outmap5_loss: 0.0346 - outbin_loss: 0.2721 - outbin_acc: 0.8892 - val_loss: 0.0346 - val_outmap_loss: 0.0229 - val_outmap4_loss: 0.0301 - val_outmap5_loss: 0.0390 - val_outbin_loss: 0.3796 - val_outbin_acc: 0.8085
# Epoch 40/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0260 - outmap_loss: 0.0164 - outmap4_loss: 0.0263 - outmap5_loss: 0.0345 - outbin_loss: 0.2689 - outbin_acc: 0.8902Epoch 00039: val_loss improved from 0.03265 to 0.03244, saving model to weights.hdf5
# 10371/10371 [==============================] - 130s - loss: 0.0260 - outmap_loss: 0.0164 - outmap4_loss: 0.0263 - outmap5_loss: 0.0345 - outbin_loss: 0.2688 - outbin_acc: 0.8903 - val_loss: 0.0324 - val_outmap_loss: 0.0212 - val_outmap4_loss: 0.0283 - val_outmap5_loss: 0.0376 - val_outbin_loss: 0.3720 - val_outbin_acc: 0.8285
# Epoch 41/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0259 - outmap_loss: 0.0162 - outmap4_loss: 0.0262 - outmap5_loss: 0.0344 - outbin_loss: 0.2698 - outbin_acc: 0.8870Epoch 00040: val_loss did not improve
# 10371/10371 [==============================] - 130s - loss: 0.0259 - outmap_loss: 0.0162 - outmap4_loss: 0.0262 - outmap5_loss: 0.0344 - outbin_loss: 0.2698 - outbin_acc: 0.8870 - val_loss: 0.0332 - val_outmap_loss: 0.0218 - val_outmap4_loss: 0.0287 - val_outmap5_loss: 0.0373 - val_outbin_loss: 0.3747 - val_outbin_acc: 0.8352
# Epoch 42/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0256 - outmap_loss: 0.0159 - outmap4_loss: 0.0260 - outmap5_loss: 0.0343 - outbin_loss: 0.2693 - outbin_acc: 0.8887Epoch 00041: val_loss did not improve
# 10371/10371 [==============================] - 130s - loss: 0.0256 - outmap_loss: 0.0160 - outmap4_loss: 0.0260 - outmap5_loss: 0.0343 - outbin_loss: 0.2695 - outbin_acc: 0.8886 - val_loss: 0.0334 - val_outmap_loss: 0.0217 - val_outmap4_loss: 0.0291 - val_outmap5_loss: 0.0383 - val_outbin_loss: 0.4001 - val_outbin_acc: 0.8263
# Epoch 43/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0269 - outmap_loss: 0.0170 - outmap4_loss: 0.0266 - outmap5_loss: 0.0349 - outbin_loss: 0.2842 - outbin_acc: 0.8833Epoch 00042: val_loss did not improve
# 10371/10371 [==============================] - 130s - loss: 0.0269 - outmap_loss: 0.0170 - outmap4_loss: 0.0266 - outmap5_loss: 0.0349 - outbin_loss: 0.2845 - outbin_acc: 0.8831 - val_loss: 0.0465 - val_outmap_loss: 0.0325 - val_outmap4_loss: 0.0330 - val_outmap5_loss: 0.0410 - val_outbin_loss: 0.5302 - val_outbin_acc: 0.7840
# Epoch 44/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0266 - outmap_loss: 0.0168 - outmap4_loss: 0.0265 - outmap5_loss: 0.0349 - outbin_loss: 0.2812 - outbin_acc: 0.8844Epoch 00043: val_loss did not improve
# 10371/10371 [==============================] - 131s - loss: 0.0266 - outmap_loss: 0.0168 - outmap4_loss: 0.0265 - outmap5_loss: 0.0349 - outbin_loss: 0.2812 - outbin_acc: 0.8843 - val_loss: 0.0338 - val_outmap_loss: 0.0225 - val_outmap4_loss: 0.0288 - val_outmap5_loss: 0.0378 - val_outbin_loss: 0.3596 - val_outbin_acc: 0.8419
# Epoch 45/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0253 - outmap_loss: 0.0158 - outmap4_loss: 0.0258 - outmap5_loss: 0.0341 - outbin_loss: 0.2601 - outbin_acc: 0.8945Epoch 00044: val_loss did not improve
# 10371/10371 [==============================] - 131s - loss: 0.0253 - outmap_loss: 0.0158 - outmap4_loss: 0.0258 - outmap5_loss: 0.0341 - outbin_loss: 0.2602 - outbin_acc: 0.8944 - val_loss: 0.0328 - val_outmap_loss: 0.0214 - val_outmap4_loss: 0.0291 - val_outmap5_loss: 0.0397 - val_outbin_loss: 0.3572 - val_outbin_acc: 0.8374
# Epoch 46/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0255 - outmap_loss: 0.0159 - outmap4_loss: 0.0261 - outmap5_loss: 0.0341 - outbin_loss: 0.2666 - outbin_acc: 0.8915Epoch 00045: val_loss did not improve
# 10371/10371 [==============================] - 131s - loss: 0.0255 - outmap_loss: 0.0159 - outmap4_loss: 0.0261 - outmap5_loss: 0.0341 - outbin_loss: 0.2666 - outbin_acc: 0.8915 - val_loss: 0.0377 - val_outmap_loss: 0.0250 - val_outmap4_loss: 0.0295 - val_outmap5_loss: 0.0398 - val_outbin_loss: 0.4884 - val_outbin_acc: 0.8040
# Epoch 47/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0251 - outmap_loss: 0.0157 - outmap4_loss: 0.0257 - outmap5_loss: 0.0339 - outbin_loss: 0.2589 - outbin_acc: 0.8926Epoch 00046: val_loss did not improve
# 10371/10371 [==============================] - 131s - loss: 0.0251 - outmap_loss: 0.0157 - outmap4_loss: 0.0257 - outmap5_loss: 0.0339 - outbin_loss: 0.2589 - outbin_acc: 0.8926 - val_loss: 0.0335 - val_outmap_loss: 0.0222 - val_outmap4_loss: 0.0290 - val_outmap5_loss: 0.0382 - val_outbin_loss: 0.3519 - val_outbin_acc: 0.8330
# Epoch 48/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0250 - outmap_loss: 0.0156 - outmap4_loss: 0.0258 - outmap5_loss: 0.0338 - outbin_loss: 0.2568 - outbin_acc: 0.8959Epoch 00047: val_loss did not improve
# 10371/10371 [==============================] - 130s - loss: 0.0250 - outmap_loss: 0.0156 - outmap4_loss: 0.0258 - outmap5_loss: 0.0338 - outbin_loss: 0.2568 - outbin_acc: 0.8960 - val_loss: 0.0361 - val_outmap_loss: 0.0233 - val_outmap4_loss: 0.0295 - val_outmap5_loss: 0.0413 - val_outbin_loss: 0.4790 - val_outbin_acc: 0.7951
# Epoch 49/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0246 - outmap_loss: 0.0153 - outmap4_loss: 0.0256 - outmap5_loss: 0.0338 - outbin_loss: 0.2477 - outbin_acc: 0.8974Epoch 00048: val_loss did not improve
# 10371/10371 [==============================] - 130s - loss: 0.0246 - outmap_loss: 0.0153 - outmap4_loss: 0.0256 - outmap5_loss: 0.0338 - outbin_loss: 0.2477 - outbin_acc: 0.8974 - val_loss: 0.0340 - val_outmap_loss: 0.0227 - val_outmap4_loss: 0.0288 - val_outmap5_loss: 0.0378 - val_outbin_loss: 0.3647 - val_outbin_acc: 0.8196
# Epoch 50/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0250 - outmap_loss: 0.0156 - outmap4_loss: 0.0257 - outmap5_loss: 0.0339 - outbin_loss: 0.2519 - outbin_acc: 0.9000Epoch 00049: val_loss did not improve
# 10371/10371 [==============================] - 130s - loss: 0.0250 - outmap_loss: 0.0156 - outmap4_loss: 0.0257 - outmap5_loss: 0.0339 - outbin_loss: 0.2518 - outbin_acc: 0.9000 - val_loss: 0.0355 - val_outmap_loss: 0.0236 - val_outmap4_loss: 0.0295 - val_outmap5_loss: 0.0380 - val_outbin_loss: 0.4093 - val_outbin_acc: 0.8263
# Epoch 51/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0246 - outmap_loss: 0.0152 - outmap4_loss: 0.0256 - outmap5_loss: 0.0338 - outbin_loss: 0.2530 - outbin_acc: 0.8974Epoch 00050: val_loss did not improve
# 10371/10371 [==============================] - 130s - loss: 0.0246 - outmap_loss: 0.0152 - outmap4_loss: 0.0256 - outmap5_loss: 0.0338 - outbin_loss: 0.2530 - outbin_acc: 0.8974 - val_loss: 0.0332 - val_outmap_loss: 0.0219 - val_outmap4_loss: 0.0291 - val_outmap5_loss: 0.0377 - val_outbin_loss: 0.3617 - val_outbin_acc: 0.8396
# Epoch 52/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0246 - outmap_loss: 0.0153 - outmap4_loss: 0.0256 - outmap5_loss: 0.0337 - outbin_loss: 0.2484 - outbin_acc: 0.8975Epoch 00051: val_loss did not improve
# 10371/10371 [==============================] - 130s - loss: 0.0246 - outmap_loss: 0.0153 - outmap4_loss: 0.0256 - outmap5_loss: 0.0337 - outbin_loss: 0.2484 - outbin_acc: 0.8975 - val_loss: 0.0383 - val_outmap_loss: 0.0268 - val_outmap4_loss: 0.0291 - val_outmap5_loss: 0.0381 - val_outbin_loss: 0.3797 - val_outbin_acc: 0.8441
# Epoch 53/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0246 - outmap_loss: 0.0153 - outmap4_loss: 0.0255 - outmap5_loss: 0.0338 - outbin_loss: 0.2465 - outbin_acc: 0.8990Epoch 00052: val_loss did not improve
# 10371/10371 [==============================] - 130s - loss: 0.0245 - outmap_loss: 0.0153 - outmap4_loss: 0.0255 - outmap5_loss: 0.0338 - outbin_loss: 0.2465 - outbin_acc: 0.8990 - val_loss: 0.0371 - val_outmap_loss: 0.0244 - val_outmap4_loss: 0.0304 - val_outmap5_loss: 0.0384 - val_outbin_loss: 0.4633 - val_outbin_acc: 0.7973
# Epoch 54/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0240 - outmap_loss: 0.0148 - outmap4_loss: 0.0254 - outmap5_loss: 0.0336 - outbin_loss: 0.2385 - outbin_acc: 0.9017Epoch 00053: val_loss did not improve
# 10371/10371 [==============================] - 130s - loss: 0.0240 - outmap_loss: 0.0148 - outmap4_loss: 0.0254 - outmap5_loss: 0.0336 - outbin_loss: 0.2384 - outbin_acc: 0.9017 - val_loss: 0.0419 - val_outmap_loss: 0.0291 - val_outmap4_loss: 0.0299 - val_outmap5_loss: 0.0392 - val_outbin_loss: 0.4850 - val_outbin_acc: 0.8174
# Epoch 55/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0245 - outmap_loss: 0.0153 - outmap4_loss: 0.0255 - outmap5_loss: 0.0338 - outbin_loss: 0.2482 - outbin_acc: 0.8977Epoch 00054: val_loss did not improve
# 10371/10371 [==============================] - 130s - loss: 0.0245 - outmap_loss: 0.0153 - outmap4_loss: 0.0255 - outmap5_loss: 0.0338 - outbin_loss: 0.2483 - outbin_acc: 0.8976 - val_loss: 0.0348 - val_outmap_loss: 0.0235 - val_outmap4_loss: 0.0294 - val_outmap5_loss: 0.0378 - val_outbin_loss: 0.3605 - val_outbin_acc: 0.8374
# Epoch 56/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0244 - outmap_loss: 0.0151 - outmap4_loss: 0.0257 - outmap5_loss: 0.0338 - outbin_loss: 0.2507 - outbin_acc: 0.8957Epoch 00055: val_loss did not improve
# 10371/10371 [==============================] - 130s - loss: 0.0244 - outmap_loss: 0.0151 - outmap4_loss: 0.0257 - outmap5_loss: 0.0338 - outbin_loss: 0.2507 - outbin_acc: 0.8958 - val_loss: 0.0360 - val_outmap_loss: 0.0246 - val_outmap4_loss: 0.0290 - val_outmap5_loss: 0.0378 - val_outbin_loss: 0.3738 - val_outbin_acc: 0.8174
# Epoch 57/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0239 - outmap_loss: 0.0148 - outmap4_loss: 0.0253 - outmap5_loss: 0.0334 - outbin_loss: 0.2370 - outbin_acc: 0.9036Epoch 00056: val_loss did not improve
# 10371/10371 [==============================] - 130s - loss: 0.0239 - outmap_loss: 0.0148 - outmap4_loss: 0.0253 - outmap5_loss: 0.0334 - outbin_loss: 0.2370 - outbin_acc: 0.9037 - val_loss: 0.0366 - val_outmap_loss: 0.0249 - val_outmap4_loss: 0.0292 - val_outmap5_loss: 0.0384 - val_outbin_loss: 0.3910 - val_outbin_acc: 0.8196
# Epoch 58/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0240 - outmap_loss: 0.0149 - outmap4_loss: 0.0253 - outmap5_loss: 0.0334 - outbin_loss: 0.2352 - outbin_acc: 0.9018Epoch 00057: val_loss did not improve
# 10371/10371 [==============================] - 130s - loss: 0.0240 - outmap_loss: 0.0149 - outmap4_loss: 0.0253 - outmap5_loss: 0.0334 - outbin_loss: 0.2357 - outbin_acc: 0.9016 - val_loss: 0.0352 - val_outmap_loss: 0.0231 - val_outmap4_loss: 0.0297 - val_outmap5_loss: 0.0381 - val_outbin_loss: 0.4288 - val_outbin_acc: 0.8396
# Epoch 59/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0248 - outmap_loss: 0.0155 - outmap4_loss: 0.0257 - outmap5_loss: 0.0338 - outbin_loss: 0.2523 - outbin_acc: 0.8938Epoch 00058: val_loss did not improve
# 10371/10371 [==============================] - 130s - loss: 0.0248 - outmap_loss: 0.0155 - outmap4_loss: 0.0257 - outmap5_loss: 0.0339 - outbin_loss: 0.2524 - outbin_acc: 0.8937 - val_loss: 0.0356 - val_outmap_loss: 0.0228 - val_outmap4_loss: 0.0301 - val_outmap5_loss: 0.0401 - val_outbin_loss: 0.4774 - val_outbin_acc: 0.8062
# Epoch 60/60
# 10368/10371 [============================>.] - ETA: 0s - loss: 0.0245 - outmap_loss: 0.0152 - outmap4_loss: 0.0257 - outmap5_loss: 0.0337 - outbin_loss: 0.2460 - outbin_acc: 0.9003Epoch 00059: val_loss did not improve
# 10371/10371 [==============================] - 130s - loss: 0.0245 - outmap_loss: 0.0152 - outmap4_loss: 0.0257 - outmap5_loss: 0.0337 - outbin_loss: 0.2460 - outbin_acc: 0.9003 - val_loss: 0.0362 - val_outmap_loss: 0.0245 - val_outmap4_loss: 0.0291 - val_outmap5_loss: 0.0391 - val_outbin_loss: 0.3910 - val_outbin_acc: 0.8374

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture_final.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights_final.hdf5'))

# %%
def compute_scores_map(X, Y):
    Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X)
    
    map_threshs = np.linspace(0, 1, num=21)
    bin_threshs = np.linspace(0, 1, num=21)
    
    scores = np.zeros((len(map_threshs), len(bin_threshs)))
    for i in range(len(map_threshs)):
        for j in range(len(bin_threshs)):
            _Y_pred = Y_pred > map_threshs[i]
            
            for k in range(_Y_pred.shape[0]):
                # Clear prediction where we detect to little pixels
                if np.sum(_Y_pred[k]) < 150 or Y_pred_binary[k] < bin_threshs[j]:
                    _Y_pred[k,:] = 0
            
            scores[i, j] = utils.average_dice_coefficient(_Y_pred, Y)
    
    pl.imshow(scores, interpolation='nearest')
    pl.yticks(np.arange(len(map_threshs)) + 0.5, ['%.2f' % v for v in map_threshs])
    pl.xticks(np.arange(len(bin_threshs)) + 0.5, ['%.2f' % v for v in bin_threshs], rotation=90)
    pl.ylabel('map thresh')
    pl.xlabel('bin thresh')
    pl.colorbar()
    
    best_i, best_j = np.unravel_index(np.argmax(scores.ravel()), scores.shape)
    best_map_thresh = map_threshs[best_i]
    best_bin_thresh = bin_threshs[best_j]
    return best_map_thresh, best_bin_thresh

map_thresh, bin_thresh = compute_scores_map(X_test, Y_test)
print 'Best map_thresh=%f, bin_thresh=%f' % (map_thresh, bin_thresh)
# Out:
# Best map_thresh=0.300000, bin_thresh=0.800000

# %%
#map_thresh = 0.45
#bin_thresh = 0.9

# %%
def predict(X, map_thresh, bin_thresh):
    Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > map_thresh
    for i in range(Y_pred.shape[0]):
        if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < bin_thresh:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test, map_thresh, bin_thresh)
Y_full_pred, Y_full_pred_proba, Y_full_pred_binary = predict(X_full, map_thresh, bin_thresh)

print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "avg test set score : ", utils.average_dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
print "avg full set score : ", utils.average_dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.620796108331
# avg test set score :  0.766409352257
# full set score :  0.637149733321
# avg full set score :  0.767408760747

# %%
_ = pl.hist(Y_pred_binary)

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[50:55]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(30):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, pred44, pred88, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 15
img, pred_map = dream_output(Y_full[i])
pl.figure(figsize=(12, 4))
pl.subplot(141)
pl.imshow(X_full[i].squeeze(), cmap=cm.gray)
pl.subplot(142)
pl.imshow(Y_full[i].squeeze())
pl.subplot(143)
pl.imshow(img, cmap=cm.gray)
pl.subplot(144)
pl.imshow(pred_map.squeeze())

# %%
# Dream for the binary output
def dream_binoutput(output):
    
    layer_output = layer_dict['outbin'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output - layer_output[:, 0]))
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    
    step = 0.1
    for i in range(40):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    _, _, _, model_pred = model.predict(img[None,None,:,:])
    return img, model_pred

img, model_pred = dream_binoutput(1)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
img, model_pred = dream_binoutput(0)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
def dream_layer_filter(layer_name, filter_index):
    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(4):
        pl.subplot(1, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
_d = np.load('../data/data_128_test.npz')
X_submit = _d['X']

for m_t, b_t in [(0.3, 0), (0.5, 0), (0.5, 0.5), (0.5, 0.8)]:
    _pred, _pred_proba, _pred_binary = predict(X_submit[:,None,:,:], m_t, b_t)
    # Turn labels into boolean present/missing
    _pred_binary = np.sum(np.sum(np.sum(_pred, axis=2), axis=1), axis=1) > 0
    _pred_binary = _pred_binary.astype(np.float32)
    per_mask = (100 * np.count_nonzero(_pred_binary) / float(len(_pred_binary)))
    print 'map_thresh=%f, bin_thresh=%f => %.2f%% with masks' % (m_t, b_t, per_mask)
# Out:
# map_thresh=0.300000, bin_thresh=0.000000 => 52.81% with masks
# map_thresh=0.500000, bin_thresh=0.000000 => 44.54% with masks
# map_thresh=0.500000, bin_thresh=0.500000 => 40.90% with masks
# map_thresh=0.500000, bin_thresh=0.800000 => 33.02% with masks

# %%
map_thresh = 0.5
bin_thresh = 0.5

# %%
if True:
    import cv2
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(50,50))
    
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    test_fnames = _d['test_fnames']
    # bin_thresh
    Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:],
                                                  map_thresh, bin_thresh)
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
        #imre = cv2.morphologyEx(imre, cv2.MORPH_CLOSE, kernel)
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
        
        if i % 10 == 0:
            print '\r%d / %d' % (i, len(test_fnames)),
            sys.stdout.flush()
# Out:
# 5500 / 5508

# %% [markdown]
# ## Stats on predicted masks

# %%
# on Y_full
nbp_pixels = np.sum(np.sum(np.sum(Y_full, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
pl.xlim((0, 1200))
# Out:
# (0, 1200)

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
pl.xlim((0, 1200))
# Out:
# (0, 1200)
