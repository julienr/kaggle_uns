# %% [markdown]
# ## FCNN with a boolean output indicating the likelihood of the image containing nerve

# %% [markdown]
# Trying to improve on the model that gave use 0.65

# %%
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):

# %%
_d = np.load('../../data_64_train.npz')
X = _d['X']
Y = _d['Y']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
print X.shape
print Y.shape
# Out:
# (5635, 64, 64)
# (5635, 64, 64)

# %%
nsamples = X.shape[0]

train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
#train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.25)
X_train = X[train_indices][:,None,:,:]
Y_train_binary = Y_binary[train_indices][:,None]
Y_train = Y[train_indices][:,None,:,:]
X_test = X[test_indices][:,None,:,:]
Y_test_binary = Y_binary[test_indices][:,None]
Y_test = Y[test_indices][:,None,:,:]

# %%
print X_train.shape
print Y_train.shape
print Y_train_binary.shape
print X_train.min(), X_train.max()

print X_test.shape
# Out:
# (5071, 1, 64, 64)
# (5071, 1, 64, 64)
# (5071, 1)
# 0.0 1.0
# (564, 1, 64, 64)

# %%
#pl.imshow(X_train[0].squeeze())
pl.imshow(Y_train[0].squeeze())
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 64, 64)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float16'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, GaussianNoise, ZeroPadding2D
from keras.layers import BatchNormalization
from keras.layers import LeakyReLU, PReLU
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
nf = 16

input_img = Input(shape=input_shape)
x = ZeroPadding2D((1, 1))(input_img)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool1 = x = Dropout(0.25, name='pool1')(x)

x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool2 = x = Dropout(0.25, name='pool2')(x)

x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool3 = x = Dropout(0.25, name='pool3')(x)

# -- binary presence part
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool4 = x = Dropout(0.1, name='pool4')(x)

x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool5 = x = Dropout(0.1, name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(x)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# -- location map upsampling
seg5 = ZeroPadding2D((1, 1))(pool5)
seg5 = Convolution2D(1, 3, 3)(seg5)
seg5 = LeakyReLU(name='seg5')(seg5)
x = UpSampling2D((2, 2))(seg5)


seg4 = ZeroPadding2D((1, 1))(pool4)
seg4 = Convolution2D(1, 3, 3)(seg4)
seg4 = LeakyReLU(name='seg4')(seg4)

x = merge([x, seg4], mode='concat', concat_axis=1)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(1, 3, 3)(x)
x = LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)

seg3 = ZeroPadding2D((1, 1))(pool3)
seg3 = Convolution2D(1, 3, 3)(seg3)
seg3 = LeakyReLU(name='seg3')(seg3)

x = merge([x, seg3], mode='concat', concat_axis=1)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(1, 3, 3)(x)
x = LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)


seg2 = ZeroPadding2D((1, 1))(pool2)
seg2 = Convolution2D(1, 3, 3)(seg2)
seg2 = LeakyReLU(name='seg2')(seg2)

x = merge([x, seg2], mode='concat', concat_axis=1)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(1, 3, 3)(x)
x = LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)


seg1 = ZeroPadding2D((1, 1))(pool1)
seg1 = Convolution2D(1, 3, 3)(seg1)
seg1 = LeakyReLU(name='seg1')(seg1)

x = merge([x, seg1], mode='concat', concat_axis=1)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(1, 3, 3)(x)
x = LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)

# Flatten across filters
#x = Convolution2D(1, 3, 3, border_mode='same')(x)
#x = LeakyReLU()(x)

outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
optimizer='adam'
#optimizer=sgd
#optimizer=rmsprop
model.compile(optimizer=optimizer, loss='binary_crossentropy',
              loss_weights=[1., 0.01], metrics=['accuracy'])

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_5 (InputLayer)               (None, 1, 64, 64)   0
# ____________________________________________________________________________________________________
# zeropadding2d_73 (ZeroPadding2D)   (None, 1, 66, 66)   0           input_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_73 (Convolution2D)   (None, 16, 64, 64)  160         zeropadding2d_73[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_61 (LeakyReLU)           (None, 16, 64, 64)  0           convolution2d_73[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_74 (ZeroPadding2D)   (None, 16, 66, 66)  0           leakyrelu_61[0][0]
# ____________________________________________________________________________________________________
# convolution2d_74 (Convolution2D)   (None, 16, 64, 64)  2320        zeropadding2d_74[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_62 (LeakyReLU)           (None, 16, 64, 64)  0           convolution2d_74[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_21 (MaxPooling2D)     (None, 16, 32, 32)  0           leakyrelu_62[0][0]
# ____________________________________________________________________________________________________
# pool1 (Dropout)                    (None, 16, 32, 32)  0           maxpooling2d_21[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_75 (ZeroPadding2D)   (None, 16, 34, 34)  0           pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_75 (Convolution2D)   (None, 16, 32, 32)  2320        zeropadding2d_75[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_63 (LeakyReLU)           (None, 16, 32, 32)  0           convolution2d_75[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_76 (ZeroPadding2D)   (None, 16, 34, 34)  0           leakyrelu_63[0][0]
# ____________________________________________________________________________________________________
# convolution2d_76 (Convolution2D)   (None, 16, 32, 32)  2320        zeropadding2d_76[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_64 (LeakyReLU)           (None, 16, 32, 32)  0           convolution2d_76[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_22 (MaxPooling2D)     (None, 16, 16, 16)  0           leakyrelu_64[0][0]
# ____________________________________________________________________________________________________
# pool2 (Dropout)                    (None, 16, 16, 16)  0           maxpooling2d_22[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_77 (ZeroPadding2D)   (None, 16, 18, 18)  0           pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_77 (Convolution2D)   (None, 16, 16, 16)  2320        zeropadding2d_77[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_65 (LeakyReLU)           (None, 16, 16, 16)  0           convolution2d_77[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_78 (ZeroPadding2D)   (None, 16, 18, 18)  0           leakyrelu_65[0][0]
# ____________________________________________________________________________________________________
# convolution2d_78 (Convolution2D)   (None, 16, 16, 16)  2320        zeropadding2d_78[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_66 (LeakyReLU)           (None, 16, 16, 16)  0           convolution2d_78[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_23 (MaxPooling2D)     (None, 16, 8, 8)    0           leakyrelu_66[0][0]
# ____________________________________________________________________________________________________
# pool3 (Dropout)                    (None, 16, 8, 8)    0           maxpooling2d_23[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_79 (ZeroPadding2D)   (None, 16, 10, 10)  0           pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_79 (Convolution2D)   (None, 16, 8, 8)    2320        zeropadding2d_79[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_67 (LeakyReLU)           (None, 16, 8, 8)    0           convolution2d_79[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_80 (ZeroPadding2D)   (None, 16, 10, 10)  0           leakyrelu_67[0][0]
# ____________________________________________________________________________________________________
# convolution2d_80 (Convolution2D)   (None, 16, 8, 8)    2320        zeropadding2d_80[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_68 (LeakyReLU)           (None, 16, 8, 8)    0           convolution2d_80[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_24 (MaxPooling2D)     (None, 16, 4, 4)    0           leakyrelu_68[0][0]
# ____________________________________________________________________________________________________
# pool4 (Dropout)                    (None, 16, 4, 4)    0           maxpooling2d_24[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_81 (ZeroPadding2D)   (None, 16, 6, 6)    0           pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_81 (Convolution2D)   (None, 16, 4, 4)    2320        zeropadding2d_81[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_69 (LeakyReLU)           (None, 16, 4, 4)    0           convolution2d_81[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_25 (MaxPooling2D)     (None, 16, 2, 2)    0           leakyrelu_69[0][0]
# ____________________________________________________________________________________________________
# pool5 (Dropout)                    (None, 16, 2, 2)    0           maxpooling2d_25[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_82 (ZeroPadding2D)   (None, 16, 4, 4)    0           pool5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_82 (Convolution2D)   (None, 1, 2, 2)     145         zeropadding2d_82[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_83 (ZeroPadding2D)   (None, 16, 6, 6)    0           pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_83 (Convolution2D)   (None, 1, 4, 4)     145         zeropadding2d_83[0][0]
# ____________________________________________________________________________________________________
# seg5 (LeakyReLU)                   (None, 1, 2, 2)     0           convolution2d_82[0][0]
# ____________________________________________________________________________________________________
# seg4 (LeakyReLU)                   (None, 1, 4, 4)     0           convolution2d_83[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_21 (UpSampling2D)     (None, 1, 4, 4)     0           seg5[0][0]
# ____________________________________________________________________________________________________
# merge_17 (Merge)                   (None, 2, 4, 4)     0           upsampling2d_21[0][0]
#                                                                    seg4[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_84 (ZeroPadding2D)   (None, 2, 6, 6)     0           merge_17[0][0]
# ____________________________________________________________________________________________________
# convolution2d_84 (Convolution2D)   (None, 1, 4, 4)     19          zeropadding2d_84[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_85 (ZeroPadding2D)   (None, 16, 10, 10)  0           pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_85 (Convolution2D)   (None, 1, 8, 8)     145         zeropadding2d_85[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_72 (LeakyReLU)           (None, 1, 4, 4)     0           convolution2d_84[0][0]
# ____________________________________________________________________________________________________
# seg3 (LeakyReLU)                   (None, 1, 8, 8)     0           convolution2d_85[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_22 (UpSampling2D)     (None, 1, 8, 8)     0           leakyrelu_72[0][0]
# ____________________________________________________________________________________________________
# merge_18 (Merge)                   (None, 2, 8, 8)     0           upsampling2d_22[0][0]
#                                                                    seg3[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_86 (ZeroPadding2D)   (None, 2, 10, 10)   0           merge_18[0][0]
# ____________________________________________________________________________________________________
# convolution2d_86 (Convolution2D)   (None, 1, 8, 8)     19          zeropadding2d_86[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_87 (ZeroPadding2D)   (None, 16, 18, 18)  0           pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_87 (Convolution2D)   (None, 1, 16, 16)   145         zeropadding2d_87[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_73 (LeakyReLU)           (None, 1, 8, 8)     0           convolution2d_86[0][0]
# ____________________________________________________________________________________________________
# seg2 (LeakyReLU)                   (None, 1, 16, 16)   0           convolution2d_87[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_23 (UpSampling2D)     (None, 1, 16, 16)   0           leakyrelu_73[0][0]
# ____________________________________________________________________________________________________
# merge_19 (Merge)                   (None, 2, 16, 16)   0           upsampling2d_23[0][0]
#                                                                    seg2[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_88 (ZeroPadding2D)   (None, 2, 18, 18)   0           merge_19[0][0]
# ____________________________________________________________________________________________________
# convolution2d_88 (Convolution2D)   (None, 1, 16, 16)   19          zeropadding2d_88[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_89 (ZeroPadding2D)   (None, 16, 34, 34)  0           pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_89 (Convolution2D)   (None, 1, 32, 32)   145         zeropadding2d_89[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_74 (LeakyReLU)           (None, 1, 16, 16)   0           convolution2d_88[0][0]
# ____________________________________________________________________________________________________
# seg1 (LeakyReLU)                   (None, 1, 32, 32)   0           convolution2d_89[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_24 (UpSampling2D)     (None, 1, 32, 32)   0           leakyrelu_74[0][0]
# ____________________________________________________________________________________________________
# flatten_5 (Flatten)                (None, 64)          0           pool5[0][0]
# ____________________________________________________________________________________________________
# merge_20 (Merge)                   (None, 2, 32, 32)   0           upsampling2d_24[0][0]
#                                                                    seg1[0][0]
# ____________________________________________________________________________________________________
# dense_9 (Dense)                    (None, 32)          2080        flatten_5[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_90 (ZeroPadding2D)   (None, 2, 34, 34)   0           merge_20[0][0]
# ____________________________________________________________________________________________________
# convolution2d_90 (Convolution2D)   (None, 1, 32, 32)   19          zeropadding2d_90[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_70 (LeakyReLU)           (None, 32)          0           dense_9[0][0]
# ____________________________________________________________________________________________________
# dense_10 (Dense)                   (None, 16)          528         leakyrelu_70[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_75 (LeakyReLU)           (None, 1, 32, 32)   0           convolution2d_90[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_71 (LeakyReLU)           (None, 16)          0           dense_10[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_25 (UpSampling2D)     (None, 1, 64, 64)   0           leakyrelu_75[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_71[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 64, 64)   10          upsampling2d_25[0][0]
# ====================================================================================================
# Total params: 22156
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    history = model.fit(
        X_train,
        {'outmap': Y_train, 'outbin': Y_train_binary},
        batch_size=64,
        validation_data=(X_test, {'outmap': Y_test, 'outbin': Y_test_binary}),
        nb_epoch=50 # 50 + 20
    )
    pl.plot(history.history['loss'], label='train loss')
    pl.plot(history.history['val_loss'], c='g', label='val loss')
    pl.legend()
else:
    model_dir = '../models/fcnn_128_multiout'
    model = model_from_json(open(os.path.join(model_dir, 'architecture.json')).read())
    model.load_weights(os.path.join(model_dir, 'weights.h5'))
    model.compile(optimizer='adagrad', loss='mse')
# Out:
# Train on 5071 samples, validate on 564 samples
# Epoch 1/50
# 5071/5071 [==============================] - 7s - loss: 0.1459 - outmap_loss: 0.1386 - outbin_loss: 0.7278 - outmap_acc: 0.3067 - outbin_acc: 0.5425 - val_loss: 0.1083 - val_outmap_loss: 0.1014 - val_outbin_loss: 0.6895 - val_outmap_acc: 0.1451 - val_outbin_acc: 0.5638
# Epoch 2/50
# 5071/5071 [==============================] - 6s - loss: 0.0903 - outmap_loss: 0.0834 - outbin_loss: 0.6907 - outmap_acc: 0.0370 - outbin_acc: 0.5612 - val_loss: 0.0840 - val_outmap_loss: 0.0771 - val_outbin_loss: 0.6866 - val_outmap_acc: 0.0294 - val_outbin_acc: 0.5638
# Epoch 3/50
# 5071/5071 [==============================] - 6s - loss: 0.0691 - outmap_loss: 0.0622 - outbin_loss: 0.6850 - outmap_acc: 0.0126 - outbin_acc: 0.5705 - val_loss: 0.0637 - val_outmap_loss: 0.0568 - val_outbin_loss: 0.6857 - val_outmap_acc: 0.0282 - val_outbin_acc: 0.5638
# Epoch 4/50
# 5071/5071 [==============================] - 6s - loss: 0.0588 - outmap_loss: 0.0520 - outbin_loss: 0.6804 - outmap_acc: 0.0335 - outbin_acc: 0.5796 - val_loss: 0.0561 - val_outmap_loss: 0.0492 - val_outbin_loss: 0.6854 - val_outmap_acc: 0.1101 - val_outbin_acc: 0.5638
# Epoch 5/50
# 5071/5071 [==============================] - 7s - loss: 0.0540 - outmap_loss: 0.0472 - outbin_loss: 0.6791 - outmap_acc: 0.0532 - outbin_acc: 0.5884 - val_loss: 0.0516 - val_outmap_loss: 0.0448 - val_outbin_loss: 0.6828 - val_outmap_acc: 0.0796 - val_outbin_acc: 0.5638
# Epoch 6/50
# 5071/5071 [==============================] - 6s - loss: 0.0504 - outmap_loss: 0.0437 - outbin_loss: 0.6742 - outmap_acc: 0.0579 - outbin_acc: 0.5894 - val_loss: 0.0487 - val_outmap_loss: 0.0419 - val_outbin_loss: 0.6777 - val_outmap_acc: 0.0949 - val_outbin_acc: 0.5638
# Epoch 7/50
# Epoch 26/50
# 5071/5071 [==============================] - 10s - loss: 0.0345 - outmap_loss: 0.0294 - outbin_loss: 0.5089 - outmap_acc: 0.1485 - outbin_acc: 0.7525 - val_loss: 0.0348 - val_outmap_loss: 0.0295 - val_outbin_loss: 0.5335 - val_outmap_acc: 0.1412 - val_outbin_acc: 0.7270
# Epoch 27/50
# 5071/5071 [==============================] - 9s - loss: 0.0349 - outmap_loss: 0.0297 - outbin_loss: 0.5127 - outmap_acc: 0.1427 - outbin_acc: 0.7450 - val_loss: 0.0351 - val_outmap_loss: 0.0300 - val_outbin_loss: 0.5048 - val_outmap_acc: 0.1682 - val_outbin_acc: 0.7358
# Epoch 28/50
# 5071/5071 [==============================] - 9s - loss: 0.0336 - outmap_loss: 0.0287 - outbin_loss: 0.4941 - outmap_acc: 0.1296 - outbin_acc: 0.7636 - val_loss: 0.0355 - val_outmap_loss: 0.0303 - val_outbin_loss: 0.5190 - val_outmap_acc: 0.1934 - val_outbin_acc: 0.7553
# Epoch 29/50
# 4096/5071 [=======================>......] - ETA: 1s - loss: 0.0334 - outmap_loss: 0.0285 - outbin_loss: 0.4879 - outmap_acc: 0.1502 - outbin_acc: 0.7656
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-83ae9f88b06f> in <module>()
#       5         batch_size=64,
#       6         validation_data=(X_test, {'outmap': Y_test, 'outbin': Y_test_binary}),
# ----> 7         nb_epoch=50 # 50 + 20
#       8     )
#       9     pl.plot(history.history['loss'], label='train loss')
#
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight)
#    1050                               verbose=verbose, callbacks=callbacks,
#    1051                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
# -> 1052                               callback_metrics=callback_metrics)
#    1053
#    1054     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, nb_epoch, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics)
#     788                 batch_logs['size'] = len(batch_ids)
#     789                 callbacks.on_batch_begin(batch_index, batch_logs)
# --> 790                 outs = f(ins_batch)
#     791                 if type(outs) != list:
#     792                     outs = [outs]
#
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/backend/theano_backend.pyc in __call__(self, inputs)
#     516     def __call__(self, inputs):
#     517         assert type(inputs) in {list, tuple}
# --> 518         return self.function(*inputs)
#     519
#     520
#
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# KeyboardInterrupt:

# %%
if False:
    model_dir = '../models/fcnn_64_multiout'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights.h5'))

# %%
import skimage.measure as measure

def predict(X):
    Y_pred, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > 0.3
    for i in range(Y_pred.shape[0]):
        # Clear prediction where we detect to little pixels
        # Figure it out by
        # pl.hist(np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1))
        if np.sum(Y_pred[i]) < 0 or Y_pred_binary[i] < 0.0:
            Y_pred[i,:] = 0
        avg_zone_proba = np.mean(Y_pred_proba[i][Y_pred[i] == 1])
        if avg_zone_proba < 0.2:
            Y_pred[i,:] = 0
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test)
print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
# Out:
# test set score :  0.563871758532

# %%
# Find the images with lowest scores
dice_scores = []
avg_pred_proba = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
    if np.any(Y_pred[i] == 1):
        avg_pred_proba.append(
            np.mean(Y_pred_proba[i][Y_pred[i] == 1])
        )
    else:
        avg_pred_proba.append(0)
dice_scores = np.array(dice_scores)
avg_pred_proba = np.array(avg_pred_proba)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
ax = pl.twinx()
ax.plot(avg_pred_proba[lowest], c='r')
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[-35:-30]:
#for i in lowest[215:220]:
for i in lowest[10:15]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    
    #blob_proba = np.mean(Y_pred_proba[i][Y_pred[i] == 1])
    pl.title('prediction proba %f\nzone avg proba %f' % (Y_pred_binary[i], avg_pred_proba[i]))
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Visualize filters
#
# See http://blog.keras.io/how-convolutional-neural-networks-see-the-world.html

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

layer_name = 'pool5'
filter_index = 0

# build a loss function that maximizes the activation
# of the nth filter of the layer considered
layer_output = layer_dict[layer_name].output
loss = K.mean(layer_output[:, filter_index, :, :])

# compute the gradient of the input picture wrt this loss
grads = K.gradients(loss, input_img)[0]

# normalization trick: we normalize the gradient
grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

# this function returns the loss and grads given the input picture
iterate = K.function([K.learning_phase(), input_img], [loss, grads])

# we start from a gray image with some noise
input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
input_img_data = input_img_data.astype(np.float32)

orig_img = input_img_data.copy()

# run gradient ascent for 20 steps
step = 0.1
for i in range(20):
    # 0 is to disable training_phase
    loss_value, grads_value = iterate([0, input_img_data])
    input_img_data += grads_value * step
    
img = input_img_data[0].squeeze()
#img = deprocess_image(img)

pl.figure(figsize=(12, 5))
pl.subplot(121)
pl.imshow(orig_img.squeeze())
pl.subplot(122)
pl.imshow(img)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
_d = np.load('../../data_64_test.npz')
X_submit = _d['X']
test_fnames = _d['test_fnames']
Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:])

# %%
#pl.imshow(Y_pred_proba[50].squeeze())

# %%
OUTDIR='../../preds'
if os.path.exists(OUTDIR):
    shutil.rmtree(OUTDIR)
utils.mkdir_p(OUTDIR)

for i in range(Y_pred.shape[0]):
    imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
    basename = os.path.splitext(test_fnames[i])[0]
    cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
