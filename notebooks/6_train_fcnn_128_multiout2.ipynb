# %% [markdown]
# ## FCNN with a boolean output indicating the likelihood of the image containing nerve

# %% [markdown]
# Trying to improve on the model that gave use 0.65

# %%
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline

# %%
_d = np.load('../../data_128_train.npz')
X = _d['X']
Y = _d['Y']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
print X.shape
print Y.shape
# Out:
# (5635, 128, 128)
# (5635, 128, 128)

# %%
nsamples = X.shape[0]

train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
#train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.25)
X_train = X[train_indices][:,None,:,:]
Y_train_binary = Y_binary[train_indices][:,None]
Y_train = Y[train_indices][:,None,:,:]
X_test = X[test_indices][:,None,:,:]
Y_test_binary = Y_binary[test_indices][:,None]
Y_test = Y[test_indices][:,None,:,:]

# %%
print X_train.shape
print Y_train.shape
print Y_train_binary.shape
print X_train.min(), X_train.max()

print X_test.shape
# Out:
# (5071, 1, 128, 128)
# (5071, 1, 128, 128)
# (5071, 1)
# 0.0 1.0
# (564, 1, 128, 128)

# %%
#pl.imshow(X_train[0].squeeze())
pl.imshow(Y_train[0].squeeze())
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float16'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, GaussianNoise, ZeroPadding2D
from keras.layers import BatchNormalization
from keras.layers import LeakyReLU, PReLU
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
nf = 32

input_img = Input(shape=input_shape)
x = ZeroPadding2D((1, 1))(input_img)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool1 = x = Dropout(0.25, name='pool1')(x)

x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool2 = x = Dropout(0.25, name='pool2')(x)

x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool3 = x = Dropout(0.25, name='pool3')(x)

# -- binary presence part
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool4 = x = Dropout(0.1, name='pool4')(x)

x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool5 = x = Dropout(0.1, name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(x)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# -- location map upsampling
seg5 = ZeroPadding2D((1, 1))(pool5)
seg5 = Convolution2D(1, 3, 3)(seg5)
seg5 = LeakyReLU(name='seg5')(seg5)
x = UpSampling2D((2, 2))(seg5)


seg4 = ZeroPadding2D((1, 1))(pool4)
seg4 = Convolution2D(1, 3, 3)(seg4)
seg4 = LeakyReLU(name='seg4')(seg4)

x = merge([x, seg4], mode='concat', concat_axis=1)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(1, 3, 3)(x)
x = LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)

seg3 = ZeroPadding2D((1, 1))(pool3)
seg3 = Convolution2D(1, 3, 3)(seg3)
seg3 = LeakyReLU(name='seg3')(seg3)

x = merge([x, seg3], mode='concat', concat_axis=1)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(1, 3, 3)(x)
x = LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)


seg2 = ZeroPadding2D((1, 1))(pool2)
seg2 = Convolution2D(1, 3, 3)(seg2)
seg2 = LeakyReLU(name='seg2')(seg2)

x = merge([x, seg2], mode='concat', concat_axis=1)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(1, 3, 3)(x)
x = LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)


seg1 = ZeroPadding2D((1, 1))(pool1)
seg1 = Convolution2D(1, 3, 3)(seg1)
seg1 = LeakyReLU(name='seg1')(seg1)

x = merge([x, seg1], mode='concat', concat_axis=1)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(1, 3, 3)(x)
x = LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)

# Flatten across filters
#x = Convolution2D(1, 3, 3, border_mode='same')(x)
#x = LeakyReLU()(x)

outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
optimizer='adam'
#optimizer=sgd
#optimizer=rmsprop
model.compile(optimizer=optimizer, loss='binary_crossentropy',
              loss_weights=[1., 0.01], metrics=['accuracy'])

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_30 (InputLayer)              (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# zeropadding2d_332 (ZeroPadding2D)  (None, 1, 130, 130) 0           input_30[0][0]
# ____________________________________________________________________________________________________
# convolution2d_338 (Convolution2D)  (None, 32, 128, 128)320         zeropadding2d_332[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_342 (LeakyReLU)          (None, 32, 128, 128)0           convolution2d_338[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_333 (ZeroPadding2D)  (None, 32, 130, 130)0           leakyrelu_342[0][0]
# ____________________________________________________________________________________________________
# convolution2d_339 (Convolution2D)  (None, 32, 128, 128)9248        zeropadding2d_333[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_343 (LeakyReLU)          (None, 32, 128, 128)0           convolution2d_339[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_128 (MaxPooling2D)    (None, 32, 64, 64)  0           leakyrelu_343[0][0]
# ____________________________________________________________________________________________________
# pool1 (Dropout)                    (None, 32, 64, 64)  0           maxpooling2d_128[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_334 (ZeroPadding2D)  (None, 32, 66, 66)  0           pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_340 (Convolution2D)  (None, 32, 64, 64)  9248        zeropadding2d_334[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_344 (LeakyReLU)          (None, 32, 64, 64)  0           convolution2d_340[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_335 (ZeroPadding2D)  (None, 32, 66, 66)  0           leakyrelu_344[0][0]
# ____________________________________________________________________________________________________
# convolution2d_341 (Convolution2D)  (None, 32, 64, 64)  9248        zeropadding2d_335[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_345 (LeakyReLU)          (None, 32, 64, 64)  0           convolution2d_341[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_129 (MaxPooling2D)    (None, 32, 32, 32)  0           leakyrelu_345[0][0]
# ____________________________________________________________________________________________________
# pool2 (Dropout)                    (None, 32, 32, 32)  0           maxpooling2d_129[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_336 (ZeroPadding2D)  (None, 32, 34, 34)  0           pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_342 (Convolution2D)  (None, 32, 32, 32)  9248        zeropadding2d_336[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_346 (LeakyReLU)          (None, 32, 32, 32)  0           convolution2d_342[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_337 (ZeroPadding2D)  (None, 32, 34, 34)  0           leakyrelu_346[0][0]
# ____________________________________________________________________________________________________
# convolution2d_343 (Convolution2D)  (None, 32, 32, 32)  9248        zeropadding2d_337[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_347 (LeakyReLU)          (None, 32, 32, 32)  0           convolution2d_343[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_130 (MaxPooling2D)    (None, 32, 16, 16)  0           leakyrelu_347[0][0]
# ____________________________________________________________________________________________________
# pool3 (Dropout)                    (None, 32, 16, 16)  0           maxpooling2d_130[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_338 (ZeroPadding2D)  (None, 32, 18, 18)  0           pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_344 (Convolution2D)  (None, 32, 16, 16)  9248        zeropadding2d_338[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_348 (LeakyReLU)          (None, 32, 16, 16)  0           convolution2d_344[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_339 (ZeroPadding2D)  (None, 32, 18, 18)  0           leakyrelu_348[0][0]
# ____________________________________________________________________________________________________
# convolution2d_345 (Convolution2D)  (None, 32, 16, 16)  9248        zeropadding2d_339[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_349 (LeakyReLU)          (None, 32, 16, 16)  0           convolution2d_345[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_131 (MaxPooling2D)    (None, 32, 8, 8)    0           leakyrelu_349[0][0]
# ____________________________________________________________________________________________________
# pool4 (Dropout)                    (None, 32, 8, 8)    0           maxpooling2d_131[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_340 (ZeroPadding2D)  (None, 32, 10, 10)  0           pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_346 (Convolution2D)  (None, 32, 8, 8)    9248        zeropadding2d_340[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_350 (LeakyReLU)          (None, 32, 8, 8)    0           convolution2d_346[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_132 (MaxPooling2D)    (None, 32, 4, 4)    0           leakyrelu_350[0][0]
# ____________________________________________________________________________________________________
# pool5 (Dropout)                    (None, 32, 4, 4)    0           maxpooling2d_132[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_341 (ZeroPadding2D)  (None, 32, 6, 6)    0           pool5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_347 (Convolution2D)  (None, 1, 4, 4)     289         zeropadding2d_341[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_342 (ZeroPadding2D)  (None, 32, 10, 10)  0           pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_348 (Convolution2D)  (None, 1, 8, 8)     289         zeropadding2d_342[0][0]
# ____________________________________________________________________________________________________
# seg5 (LeakyReLU)                   (None, 1, 4, 4)     0           convolution2d_347[0][0]
# ____________________________________________________________________________________________________
# seg4 (LeakyReLU)                   (None, 1, 8, 8)     0           convolution2d_348[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_50 (UpSampling2D)     (None, 1, 8, 8)     0           seg5[0][0]
# ____________________________________________________________________________________________________
# merge_32 (Merge)                   (None, 2, 8, 8)     0           upsampling2d_50[0][0]
#                                                                    seg4[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_343 (ZeroPadding2D)  (None, 2, 10, 10)   0           merge_32[0][0]
# ____________________________________________________________________________________________________
# convolution2d_349 (Convolution2D)  (None, 1, 8, 8)     19          zeropadding2d_343[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_344 (ZeroPadding2D)  (None, 32, 18, 18)  0           pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_350 (Convolution2D)  (None, 1, 16, 16)   289         zeropadding2d_344[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_353 (LeakyReLU)          (None, 1, 8, 8)     0           convolution2d_349[0][0]
# ____________________________________________________________________________________________________
# seg3 (LeakyReLU)                   (None, 1, 16, 16)   0           convolution2d_350[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_51 (UpSampling2D)     (None, 1, 16, 16)   0           leakyrelu_353[0][0]
# ____________________________________________________________________________________________________
# merge_33 (Merge)                   (None, 2, 16, 16)   0           upsampling2d_51[0][0]
#                                                                    seg3[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_345 (ZeroPadding2D)  (None, 2, 18, 18)   0           merge_33[0][0]
# ____________________________________________________________________________________________________
# convolution2d_351 (Convolution2D)  (None, 1, 16, 16)   19          zeropadding2d_345[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_346 (ZeroPadding2D)  (None, 32, 34, 34)  0           pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_352 (Convolution2D)  (None, 1, 32, 32)   289         zeropadding2d_346[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_354 (LeakyReLU)          (None, 1, 16, 16)   0           convolution2d_351[0][0]
# ____________________________________________________________________________________________________
# seg2 (LeakyReLU)                   (None, 1, 32, 32)   0           convolution2d_352[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_52 (UpSampling2D)     (None, 1, 32, 32)   0           leakyrelu_354[0][0]
# ____________________________________________________________________________________________________
# merge_34 (Merge)                   (None, 2, 32, 32)   0           upsampling2d_52[0][0]
#                                                                    seg2[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_347 (ZeroPadding2D)  (None, 2, 34, 34)   0           merge_34[0][0]
# ____________________________________________________________________________________________________
# convolution2d_353 (Convolution2D)  (None, 1, 32, 32)   19          zeropadding2d_347[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_348 (ZeroPadding2D)  (None, 32, 66, 66)  0           pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_354 (Convolution2D)  (None, 1, 64, 64)   289         zeropadding2d_348[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_355 (LeakyReLU)          (None, 1, 32, 32)   0           convolution2d_353[0][0]
# ____________________________________________________________________________________________________
# seg1 (LeakyReLU)                   (None, 1, 64, 64)   0           convolution2d_354[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_53 (UpSampling2D)     (None, 1, 64, 64)   0           leakyrelu_355[0][0]
# ____________________________________________________________________________________________________
# flatten_30 (Flatten)               (None, 512)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# merge_35 (Merge)                   (None, 2, 64, 64)   0           upsampling2d_53[0][0]
#                                                                    seg1[0][0]
# ____________________________________________________________________________________________________
# dense_59 (Dense)                   (None, 32)          16416       flatten_30[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_349 (ZeroPadding2D)  (None, 2, 66, 66)   0           merge_35[0][0]
# ____________________________________________________________________________________________________
# convolution2d_355 (Convolution2D)  (None, 1, 64, 64)   19          zeropadding2d_349[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_351 (LeakyReLU)          (None, 32)          0           dense_59[0][0]
# ____________________________________________________________________________________________________
# dense_60 (Dense)                   (None, 16)          528         leakyrelu_351[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_356 (LeakyReLU)          (None, 1, 64, 64)   0           convolution2d_355[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_352 (LeakyReLU)          (None, 16)          0           dense_60[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_54 (UpSampling2D)     (None, 1, 128, 128) 0           leakyrelu_356[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_352[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 10          upsampling2d_54[0][0]
# ====================================================================================================
# Total params: 92796
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    history = model.fit(
        X_train,
        {'outmap': Y_train, 'outbin': Y_train_binary},
        batch_size=64,
        validation_data=(X_test, {'outmap': Y_test, 'outbin': Y_test_binary}),
        nb_epoch=30
    )
    pl.plot(history.history['loss'], label='train loss')
    pl.plot(history.history['val_loss'], c='g', label='val loss')
    pl.legend()
else:
    model_dir = '../models/fcnn_128_multiout'
    model = model_from_json(open(os.path.join(model_dir, 'architecture.json')).read())
    model.load_weights(os.path.join(model_dir, 'weights.h5'))
    model.compile(optimizer='adagrad', loss='mse')
# Out:
# Train on 5071 samples, validate on 564 samples
# Epoch 1/30
# 5071/5071 [==============================] - 29s - loss: 0.1304 - outmap_loss: 0.1231 - outbin_loss: 0.7297 - outmap_acc: 0.0366 - outbin_acc: 0.5468 - val_loss: 0.0982 - val_outmap_loss: 0.0906 - val_outbin_loss: 0.7595 - val_outmap_acc: 1.5237e-04 - val_outbin_acc: 0.4007
# Epoch 2/30
# 5071/5071 [==============================] - 29s - loss: 0.0696 - outmap_loss: 0.0624 - outbin_loss: 0.7125 - outmap_acc: 0.0064 - outbin_acc: 0.5502 - val_loss: 0.0618 - val_outmap_loss: 0.0548 - val_outbin_loss: 0.6959 - val_outmap_acc: 0.0011 - val_outbin_acc: 0.4557
# Epoch 3/30
# 5071/5071 [==============================] - 29s - loss: 0.0533 - outmap_loss: 0.0466 - outbin_loss: 0.6721 - outmap_acc: 0.0107 - outbin_acc: 0.5880 - val_loss: 0.0491 - val_outmap_loss: 0.0425 - val_outbin_loss: 0.6641 - val_outmap_acc: 0.0030 - val_outbin_acc: 0.6082
# Epoch 4/30
# 5071/5071 [==============================] - 28s - loss: 0.0466 - outmap_loss: 0.0403 - outbin_loss: 0.6377 - outmap_acc: 0.0159 - outbin_acc: 0.6427 - val_loss: 0.0447 - val_outmap_loss: 0.0387 - val_outbin_loss: 0.6001 - val_outmap_acc: 0.0124 - val_outbin_acc: 0.6879
# Epoch 5/30
# 5071/5071 [==============================] - 28s - loss: 0.0433 - outmap_loss: 0.0373 - outbin_loss: 0.6002 - outmap_acc: 0.0531 - outbin_acc: 0.6770 - val_loss: 0.0387 - val_outmap_loss: 0.0331 - val_outbin_loss: 0.5667 - val_outmap_acc: 0.0282 - val_outbin_acc: 0.7394
# Epoch 6/30
# 5071/5071 [==============================] - 30s - loss: 0.0280 - outmap_loss: 0.0239 - outbin_loss: 0.4077 - outmap_acc: 0.2023 - outbin_acc: 0.8105 - val_loss: 0.0285 - val_outmap_loss: 0.0237 - val_outbin_loss: 0.4739 - val_outmap_acc: 0.2408 - val_outbin_acc: 0.7872
# Epoch 25/30
# 5071/5071 [==============================] - 29s - loss: 0.0278 - outmap_loss: 0.0237 - outbin_loss: 0.4079 - outmap_acc: 0.2284 - outbin_acc: 0.8081 - val_loss: 0.0281 - val_outmap_loss: 0.0236 - val_outbin_loss: 0.4477 - val_outmap_acc: 0.1632 - val_outbin_acc: 0.7855
# Epoch 26/30
# 5071/5071 [==============================] - 28s - loss: 0.0274 - outmap_loss: 0.0234 - outbin_loss: 0.4002 - outmap_acc: 0.1952 - outbin_acc: 0.8111 - val_loss: 0.0280 - val_outmap_loss: 0.0233 - val_outbin_loss: 0.4689 - val_outmap_acc: 0.1563 - val_outbin_acc: 0.7890
# Epoch 27/30
# 5071/5071 [==============================] - 29s - loss: 0.0269 - outmap_loss: 0.0230 - outbin_loss: 0.3852 - outmap_acc: 0.2044 - outbin_acc: 0.8190 - val_loss: 0.0306 - val_outmap_loss: 0.0254 - val_outbin_loss: 0.5156 - val_outmap_acc: 0.1306 - val_outbin_acc: 0.7447
# Epoch 28/30
# 5071/5071 [==============================] - 29s - loss: 0.0272 - outmap_loss: 0.0233 - outbin_loss: 0.3920 - outmap_acc: 0.1998 - outbin_acc: 0.8198 - val_loss: 0.0282 - val_outmap_loss: 0.0235 - val_outbin_loss: 0.4709 - val_outmap_acc: 0.2117 - val_outbin_acc: 0.7926
# Epoch 29/30
# 5071/5071 [==============================] - 28s - loss: 0.0274 - outmap_loss: 0.0235 - outbin_loss: 0.3891 - outmap_acc: 0.2248 - outbin_acc: 0.8217 - val_loss: 0.0290 - val_outmap_loss: 0.0243 - val_outbin_loss: 0.4771 - val_outmap_acc: 0.1798 - val_outbin_acc: 0.7819
# Epoch 30/30
# 5071/5071 [==============================] - 29s - loss: 0.0265 - outmap_loss: 0.0227 - outbin_loss: 0.3829 - outmap_acc: 0.2058 - outbin_acc: 0.8271 - val_loss: 0.0278 - val_outmap_loss: 0.0233 - val_outbin_loss: 0.4529 - val_outmap_acc: 0.1928 - val_outbin_acc: 0.8032

# %%
if False:
    model_dir = '../models/fcnn_128_multiout'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights.h5'))

# %%
import skimage.measure as measure

def predict(X):
    Y_pred, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > 0.3
    for i in range(Y_pred.shape[0]):
        # Clear prediction where we detect to little pixels
        # Figure it out by
        # pl.hist(np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1))
        if np.sum(Y_pred[i]) < 200 or Y_pred_binary[i] < 0.4:
            Y_pred[i,:] = 0
    return Y_pred, Y_pred_proba, Y_pred_binary

# %%
Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test)
print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
# Out:
# test set score :  0.60086081453

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[-450:-445]:
for i in lowest[35:40]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    
    #blob_proba = np.mean(Y_pred_proba[i][Y_pred[i] == 1])
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Visualize filters
#
# See http://blog.keras.io/how-convolutional-neural-networks-see-the-world.html

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

layer_name = 'pool5'
filter_index = 0  # can be any integer from 0 to 511, as there are 512 filters in that layer

# build a loss function that maximizes the activation
# of the nth filter of the layer considered
layer_output = layer_dict[layer_name].output
loss = K.mean(layer_output[:, filter_index, :, :])

# compute the gradient of the input picture wrt this loss
grads = K.gradients(loss, input_img)[0]

# normalization trick: we normalize the gradient
grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

# this function returns the loss and grads given the input picture
iterate = K.function([K.learning_phase(), input_img], [loss, grads])

# we start from a gray image with some noise
input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
input_img_data = input_img_data.astype(np.float32)

orig_img = input_img_data.copy()

# run gradient ascent for 20 steps
step = 0.1
for i in range(20):
    # 0 is to disable training_phase
    loss_value, grads_value = iterate([0, input_img_data])
    input_img_data += grads_value * step
    
img = input_img_data[0].squeeze()
#img = deprocess_image(img)

pl.figure(figsize=(12, 5))
pl.subplot(121)
pl.imshow(orig_img.squeeze())
pl.subplot(122)
pl.imshow(img)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
_d = np.load('../../data_test.npz')
X_submit = _d['X']
test_fnames = _d['test_fnames']
Y_pred = predict(X_submit[:,None,:,:])

# %%
Y_pred.shape
# Out:
# (5508, 1, 104, 144)

# %%
OUTDIR='../../preds'
if os.path.exists(OUTDIR):
    shutil.rmtree(OUTDIR)
utils.mkdir_p(OUTDIR)

for i in range(Y_pred.shape[0]):
    imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
    basename = os.path.splitext(test_fnames[i])[0]
    cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
