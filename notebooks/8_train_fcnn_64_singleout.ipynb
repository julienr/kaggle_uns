# %% [markdown]
# ## FCNN with a boolean output indicating the likelihood of the image containing nerve

# %% [markdown]
# Trying to improve on the model that gave use 0.65

# %%
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):

# %%
_d = np.load('../../data_64_train.npz')
X = _d['X']
Y = _d['Y']

# %%
print X.shape
print Y.shape
# Out:
# (5635, 64, 64)
# (5635, 64, 64)

# %%
nsamples = X.shape[0]

train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
#train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.25)
X_train = X[train_indices][:,None,:,:]
Y_train = Y[train_indices][:,None,:,:]
X_test = X[test_indices][:,None,:,:]
Y_test = Y[test_indices][:,None,:,:]

# %%
print X_train.shape
print Y_train.shape
print X_train.min(), X_train.max()

print X_test.shape
# Out:
# (5071, 1, 64, 64)
# (5071, 1, 64, 64)
# 0.0 1.0
# (564, 1, 64, 64)

# %%
#pl.imshow(X_train[0].squeeze())
pl.imshow(Y_train[0].squeeze())
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 64, 64)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float16'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, GaussianNoise, ZeroPadding2D
from keras.layers import BatchNormalization
from keras.layers import LeakyReLU, PReLU
import keras.backend as K
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
def dice_metric(y_true, y_pred):
    denom = K.sum(K.equal(y_pred, 1)) + K.sum(K.equal(y_true, 1))
    # Convoluted way of computing logical_and(y_pred == 1, y_true == 1)
    common = K.equal(
        K.sum(
            K.cast(K.concatenate((K.equal(y_pred, 1), K.equal(y_true, 1)), axis=1), 'int32'), axis=1
        ),
        2
    )
    common = K.cast(common, 'float32')
    return K.switch(
        K.equal(denom, 0),
        1.,
        2. * K.sum(common) / K.cast(denom, 'float32')
    )

# %%
nf = 16

input_img = Input(shape=input_shape)
x = ZeroPadding2D((1, 1))(input_img)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool1 = x = Dropout(0.25, name='pool1')(x)

x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool2 = x = Dropout(0.25, name='pool2')(x)

x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool3 = x = Dropout(0.25, name='pool3')(x)

# -- binary presence part
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool4 = x = Dropout(0.1, name='pool4')(x)

x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = MaxPooling2D((2, 2))(x)
pool5 = x = Dropout(0.1, name='pool5')(x)

# -- location map upsampling
seg5 = ZeroPadding2D((1, 1))(pool5)
seg5 = Convolution2D(nf, 3, 3)(seg5)
seg5 = LeakyReLU(name='seg5')(seg5)
x = UpSampling2D((2, 2))(seg5)

seg4 = ZeroPadding2D((1, 1))(pool4)
seg4 = Convolution2D(nf, 3, 3)(seg4)
seg4 = LeakyReLU(name='seg4')(seg4)

x = merge([x, seg4], mode='concat', concat_axis=1)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)

seg3 = ZeroPadding2D((1, 1))(pool3)
seg3 = Convolution2D(nf, 3, 3)(seg3)
seg3 = LeakyReLU(name='seg3')(seg3)

x = merge([x, seg3], mode='concat', concat_axis=1)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)


seg2 = ZeroPadding2D((1, 1))(pool2)
seg2 = Convolution2D(1, 3, 3)(seg2)
seg2 = LeakyReLU(name='seg2')(seg2)

x = merge([x, seg2], mode='concat', concat_axis=1)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(nf, 3, 3)(x)
x = LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)


seg1 = ZeroPadding2D((1, 1))(pool1)
seg1 = Convolution2D(nf, 3, 3)(seg1)
seg1 = LeakyReLU(name='seg1')(seg1)

x = merge([x, seg1], mode='concat', concat_axis=1)
x = ZeroPadding2D((1, 1))(x)
x = Convolution2D(1, 3, 3)(x)
x = LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)

# Flatten across filters
#x = Convolution2D(1, 3, 3, border_mode='same')(x)
#x = LeakyReLU()(x)

outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=outmap
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
optimizer='adam'
#optimizer=sgd
#optimizer=rmsprop

model.compile(optimizer=optimizer, loss='binary_crossentropy')
#model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=[dice_metric])

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_4 (InputLayer)               (None, 1, 64, 64)   0
# ____________________________________________________________________________________________________
# zeropadding2d_55 (ZeroPadding2D)   (None, 1, 66, 66)   0           input_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_55 (Convolution2D)   (None, 8, 64, 64)   80          zeropadding2d_55[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_40 (LeakyReLU)           (None, 8, 64, 64)   0           convolution2d_55[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_56 (ZeroPadding2D)   (None, 8, 66, 66)   0           leakyrelu_40[0][0]
# ____________________________________________________________________________________________________
# convolution2d_56 (Convolution2D)   (None, 8, 64, 64)   584         zeropadding2d_56[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_41 (LeakyReLU)           (None, 8, 64, 64)   0           convolution2d_56[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_16 (MaxPooling2D)     (None, 8, 32, 32)   0           leakyrelu_41[0][0]
# ____________________________________________________________________________________________________
# pool1 (Dropout)                    (None, 8, 32, 32)   0           maxpooling2d_16[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_57 (ZeroPadding2D)   (None, 8, 34, 34)   0           pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_57 (Convolution2D)   (None, 8, 32, 32)   584         zeropadding2d_57[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_42 (LeakyReLU)           (None, 8, 32, 32)   0           convolution2d_57[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_58 (ZeroPadding2D)   (None, 8, 34, 34)   0           leakyrelu_42[0][0]
# ____________________________________________________________________________________________________
# convolution2d_58 (Convolution2D)   (None, 8, 32, 32)   584         zeropadding2d_58[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_43 (LeakyReLU)           (None, 8, 32, 32)   0           convolution2d_58[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_17 (MaxPooling2D)     (None, 8, 16, 16)   0           leakyrelu_43[0][0]
# ____________________________________________________________________________________________________
# pool2 (Dropout)                    (None, 8, 16, 16)   0           maxpooling2d_17[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_59 (ZeroPadding2D)   (None, 8, 18, 18)   0           pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_59 (Convolution2D)   (None, 8, 16, 16)   584         zeropadding2d_59[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_44 (LeakyReLU)           (None, 8, 16, 16)   0           convolution2d_59[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_60 (ZeroPadding2D)   (None, 8, 18, 18)   0           leakyrelu_44[0][0]
# ____________________________________________________________________________________________________
# convolution2d_60 (Convolution2D)   (None, 8, 16, 16)   584         zeropadding2d_60[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_45 (LeakyReLU)           (None, 8, 16, 16)   0           convolution2d_60[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_18 (MaxPooling2D)     (None, 8, 8, 8)     0           leakyrelu_45[0][0]
# ____________________________________________________________________________________________________
# pool3 (Dropout)                    (None, 8, 8, 8)     0           maxpooling2d_18[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_61 (ZeroPadding2D)   (None, 8, 10, 10)   0           pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_61 (Convolution2D)   (None, 8, 8, 8)     584         zeropadding2d_61[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_46 (LeakyReLU)           (None, 8, 8, 8)     0           convolution2d_61[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_62 (ZeroPadding2D)   (None, 8, 10, 10)   0           leakyrelu_46[0][0]
# ____________________________________________________________________________________________________
# convolution2d_62 (Convolution2D)   (None, 8, 8, 8)     584         zeropadding2d_62[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_47 (LeakyReLU)           (None, 8, 8, 8)     0           convolution2d_62[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_19 (MaxPooling2D)     (None, 8, 4, 4)     0           leakyrelu_47[0][0]
# ____________________________________________________________________________________________________
# pool4 (Dropout)                    (None, 8, 4, 4)     0           maxpooling2d_19[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_63 (ZeroPadding2D)   (None, 8, 6, 6)     0           pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_63 (Convolution2D)   (None, 8, 4, 4)     584         zeropadding2d_63[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_48 (LeakyReLU)           (None, 8, 4, 4)     0           convolution2d_63[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_20 (MaxPooling2D)     (None, 8, 2, 2)     0           leakyrelu_48[0][0]
# ____________________________________________________________________________________________________
# pool5 (Dropout)                    (None, 8, 2, 2)     0           maxpooling2d_20[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_64 (ZeroPadding2D)   (None, 8, 4, 4)     0           pool5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_64 (Convolution2D)   (None, 8, 2, 2)     584         zeropadding2d_64[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_65 (ZeroPadding2D)   (None, 8, 6, 6)     0           pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_65 (Convolution2D)   (None, 8, 4, 4)     584         zeropadding2d_65[0][0]
# ____________________________________________________________________________________________________
# seg5 (LeakyReLU)                   (None, 8, 2, 2)     0           convolution2d_64[0][0]
# ____________________________________________________________________________________________________
# seg4 (LeakyReLU)                   (None, 8, 4, 4)     0           convolution2d_65[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_16 (UpSampling2D)     (None, 8, 4, 4)     0           seg5[0][0]
# ____________________________________________________________________________________________________
# merge_13 (Merge)                   (None, 16, 4, 4)    0           upsampling2d_16[0][0]
#                                                                    seg4[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_66 (ZeroPadding2D)   (None, 16, 6, 6)    0           merge_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_66 (Convolution2D)   (None, 8, 4, 4)     1160        zeropadding2d_66[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_67 (ZeroPadding2D)   (None, 8, 10, 10)   0           pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_67 (Convolution2D)   (None, 8, 8, 8)     584         zeropadding2d_67[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_49 (LeakyReLU)           (None, 8, 4, 4)     0           convolution2d_66[0][0]
# ____________________________________________________________________________________________________
# seg3 (LeakyReLU)                   (None, 8, 8, 8)     0           convolution2d_67[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_17 (UpSampling2D)     (None, 8, 8, 8)     0           leakyrelu_49[0][0]
# ____________________________________________________________________________________________________
# merge_14 (Merge)                   (None, 16, 8, 8)    0           upsampling2d_17[0][0]
#                                                                    seg3[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_68 (ZeroPadding2D)   (None, 16, 10, 10)  0           merge_14[0][0]
# ____________________________________________________________________________________________________
# convolution2d_68 (Convolution2D)   (None, 8, 8, 8)     1160        zeropadding2d_68[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_69 (ZeroPadding2D)   (None, 8, 18, 18)   0           pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_69 (Convolution2D)   (None, 1, 16, 16)   73          zeropadding2d_69[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_50 (LeakyReLU)           (None, 8, 8, 8)     0           convolution2d_68[0][0]
# ____________________________________________________________________________________________________
# seg2 (LeakyReLU)                   (None, 1, 16, 16)   0           convolution2d_69[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_18 (UpSampling2D)     (None, 8, 16, 16)   0           leakyrelu_50[0][0]
# ____________________________________________________________________________________________________
# merge_15 (Merge)                   (None, 9, 16, 16)   0           upsampling2d_18[0][0]
#                                                                    seg2[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_70 (ZeroPadding2D)   (None, 9, 18, 18)   0           merge_15[0][0]
# ____________________________________________________________________________________________________
# convolution2d_70 (Convolution2D)   (None, 8, 16, 16)   656         zeropadding2d_70[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_71 (ZeroPadding2D)   (None, 8, 34, 34)   0           pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_71 (Convolution2D)   (None, 8, 32, 32)   584         zeropadding2d_71[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_51 (LeakyReLU)           (None, 8, 16, 16)   0           convolution2d_70[0][0]
# ____________________________________________________________________________________________________
# seg1 (LeakyReLU)                   (None, 8, 32, 32)   0           convolution2d_71[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_19 (UpSampling2D)     (None, 8, 32, 32)   0           leakyrelu_51[0][0]
# ____________________________________________________________________________________________________
# merge_16 (Merge)                   (None, 16, 32, 32)  0           upsampling2d_19[0][0]
#                                                                    seg1[0][0]
# ____________________________________________________________________________________________________
# zeropadding2d_72 (ZeroPadding2D)   (None, 16, 34, 34)  0           merge_16[0][0]
# ____________________________________________________________________________________________________
# convolution2d_72 (Convolution2D)   (None, 1, 32, 32)   145         zeropadding2d_72[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_52 (LeakyReLU)           (None, 1, 32, 32)   0           convolution2d_72[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_20 (UpSampling2D)     (None, 1, 64, 64)   0           leakyrelu_52[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 64, 64)   10          upsampling2d_20[0][0]
# ====================================================================================================
# Total params: 10292
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    history = model.fit(
        X_train,
        Y_train,
        batch_size=64,
        validation_data=(X_test, Y_test),
        nb_epoch=50 # 40 + 10 + 10 + 5 + 5
    )
    pl.plot(history.history['loss'], label='train loss')
    pl.plot(history.history['val_loss'], c='g', label='val loss')
    pl.legend()
else:
    model_dir = '../models/fcnn_64_singleout'
    model = model_from_json(open(os.path.join(model_dir, 'architecture.json')).read())
    model.load_weights(os.path.join(model_dir, 'weights.h5'))
    model.compile(optimizer='adagrad', loss='mse')
# Out:
# Train on 5071 samples, validate on 564 samples
# Epoch 1/50
# 5071/5071 [==============================] - 4s - loss: 0.1279 - val_loss: 0.0752
# Epoch 2/50
# 5071/5071 [==============================] - 4s - loss: 0.0484 - val_loss: 0.0670
# Epoch 3/50
# 5071/5071 [==============================] - 5s - loss: 0.0457 - val_loss: 0.0643
# Epoch 4/50
# 5071/5071 [==============================] - 5s - loss: 0.0446 - val_loss: 0.0595
# Epoch 5/50
# 5071/5071 [==============================] - 5s - loss: 0.0436 - val_loss: 0.0526
# Epoch 6/50
# 5071/5071 [==============================] - 4s - loss: 0.0422 - val_loss: 0.0455
# Epoch 7/50
# 5071/5071 [==============================] - 4s - loss: 0.0402 - val_loss: 0.0437
# Epoch 8/50
# 5071/5071 [==============================] - 5s - loss: 0.0388 - val_loss: 0.0413
# Epoch 9/50
# 5071/5071 [==============================] - 4s - loss: 0.0374 - val_loss: 0.0385
# Epoch 10/50
# 5071/5071 [==============================] - 4s - loss: 0.0364 - val_loss: 0.0363
# Epoch 11/50
# 5071/5071 [==============================] - 4s - loss: 0.0352 - val_loss: 0.0345
# Epoch 12/50
# 5071/5071 [==============================] - 5s - loss: 0.0346 - val_loss: 0.0350
# Epoch 13/50
# 5071/5071 [==============================] - 5s - loss: 0.0336 - val_loss: 0.0330
# Epoch 14/50
# 5071/5071 [==============================] - 5s - loss: 0.0325 - val_loss: 0.0303
# Epoch 15/50
# 5071/5071 [==============================] - 5s - loss: 0.0318 - val_loss: 0.0306
# Epoch 16/50
# 5071/5071 [==============================] - 4s - loss: 0.0312 - val_loss: 0.0299
# Epoch 17/50
# 5071/5071 [==============================] - 4s - loss: 0.0309 - val_loss: 0.0314
# Epoch 18/50
# 5071/5071 [==============================] - 5s - loss: 0.0306 - val_loss: 0.0291
# Epoch 19/50
# 5071/5071 [==============================] - 5s - loss: 0.0301 - val_loss: 0.0284
# Epoch 20/50
# 5071/5071 [==============================] - 4s - loss: 0.0298 - val_loss: 0.0283
# Epoch 21/50
# 5071/5071 [==============================] - 4s - loss: 0.0293 - val_loss: 0.0282
# Epoch 22/50
# 5071/5071 [==============================] - 4s - loss: 0.0290 - val_loss: 0.0291
# Epoch 23/50
# 5071/5071 [==============================] - 5s - loss: 0.0289 - val_loss: 0.0275
# Epoch 24/50
# 5071/5071 [==============================] - 5s - loss: 0.0289 - val_loss: 0.0289
# Epoch 25/50
# 5071/5071 [==============================] - 4s - loss: 0.0283 - val_loss: 0.0276
# Epoch 26/50
# 5071/5071 [==============================] - 5s - loss: 0.0280 - val_loss: 0.0287
# Epoch 27/50
# 5071/5071 [==============================] - 4s - loss: 0.0281 - val_loss: 0.0275
# Epoch 28/50
# 5071/5071 [==============================] - 5s - loss: 0.0277 - val_loss: 0.0271
# Epoch 29/50
# 5071/5071 [==============================] - 5s - loss: 0.0276 - val_loss: 0.0260
# Epoch 30/50
# 5071/5071 [==============================] - 5s - loss: 0.0273 - val_loss: 0.0281
# Epoch 31/50
# 5071/5071 [==============================] - 5s - loss: 0.0270 - val_loss: 0.0259
# Epoch 32/50
# 5071/5071 [==============================] - 4s - loss: 0.0271 - val_loss: 0.0259
# Epoch 33/50
# 5071/5071 [==============================] - 5s - loss: 0.0270 - val_loss: 0.0255
# Epoch 34/50
# 5071/5071 [==============================] - 5s - loss: 0.0266 - val_loss: 0.0256
# Epoch 35/50
# 5071/5071 [==============================] - 5s - loss: 0.0263 - val_loss: 0.0255
# Epoch 36/50
# 5071/5071 [==============================] - 5s - loss: 0.0267 - val_loss: 0.0253
# Epoch 37/50
# 5071/5071 [==============================] - 5s - loss: 0.0265 - val_loss: 0.0253
# Epoch 38/50
# 5071/5071 [==============================] - 4s - loss: 0.0260 - val_loss: 0.0256
# Epoch 39/50
# 5071/5071 [==============================] - 5s - loss: 0.0259 - val_loss: 0.0263
# Epoch 40/50
# 5071/5071 [==============================] - 5s - loss: 0.0262 - val_loss: 0.0254
# Epoch 41/50
# 5071/5071 [==============================] - 5s - loss: 0.0258 - val_loss: 0.0256
# Epoch 42/50
# 5071/5071 [==============================] - 4s - loss: 0.0258 - val_loss: 0.0249
# Epoch 43/50
# 5071/5071 [==============================] - 5s - loss: 0.0256 - val_loss: 0.0248
# Epoch 44/50
# 5071/5071 [==============================] - 5s - loss: 0.0255 - val_loss: 0.0258
# Epoch 45/50
# 5071/5071 [==============================] - 4s - loss: 0.0252 - val_loss: 0.0248
# Epoch 46/50
# 5071/5071 [==============================] - 4s - loss: 0.0252 - val_loss: 0.0248
# Epoch 47/50
# 5071/5071 [==============================] - 4s - loss: 0.0252 - val_loss: 0.0251
# Epoch 48/50
# 5071/5071 [==============================] - 5s - loss: 0.0253 - val_loss: 0.0245
# Epoch 49/50
# 5071/5071 [==============================] - 4s - loss: 0.0251 - val_loss: 0.0247
# Epoch 50/50
# 5071/5071 [==============================] - 5s - loss: 0.0251 - val_loss: 0.0245

# %%
if False:
    model_dir = '../models/fcnn_64_singleout'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights.h5'))

# %%
import skimage.measure as measure

def predict(X):
    Y_pred = model.predict(X)
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > 0.3
    for i in range(Y_pred.shape[0]):
        # Clear prediction where we detect to little pixels
        # Figure it out by
        # pl.hist(np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1))
        if np.sum(Y_pred[i]) < 0:
            Y_pred[i,:] = 0
    return Y_pred, Y_pred_proba

Y_pred, Y_pred_proba = predict(X_test)
print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
# Out:
# test set score :  0.568182622545

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

for i in lowest[-15:-10]:
#for i in lowest[215:220]:
#for i in lowest[10:15]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    
    #blob_proba = np.mean(Y_pred_proba[i][Y_pred[i] == 1])
    #pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Visualize filters
#
# See http://blog.keras.io/how-convolutional-neural-networks-see-the-world.html

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

layer_name = 'pool5'
filter_index = 0

# build a loss function that maximizes the activation
# of the nth filter of the layer considered
layer_output = layer_dict[layer_name].output
loss = K.mean(layer_output[:, filter_index, :, :])

# compute the gradient of the input picture wrt this loss
grads = K.gradients(loss, input_img)[0]

# normalization trick: we normalize the gradient
grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

# this function returns the loss and grads given the input picture
iterate = K.function([K.learning_phase(), input_img], [loss, grads])

# we start from a gray image with some noise
input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
input_img_data = input_img_data.astype(np.float32)

orig_img = input_img_data.copy()

# run gradient ascent for 20 steps
step = 0.1
for i in range(20):
    # 0 is to disable training_phase
    loss_value, grads_value = iterate([0, input_img_data])
    input_img_data += grads_value * step
    
img = input_img_data[0].squeeze()
#img = deprocess_image(img)

pl.figure(figsize=(12, 5))
pl.subplot(121)
pl.imshow(orig_img.squeeze())
pl.subplot(122)
pl.imshow(img)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
_d = np.load('../../data_64_test.npz')
X_submit = _d['X']
test_fnames = _d['test_fnames']
Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:])

# %%
#pl.imshow(Y_pred_proba[50].squeeze())

# %%
OUTDIR='../../preds'
if os.path.exists(OUTDIR):
    shutil.rmtree(OUTDIR)
utils.mkdir_p(OUTDIR)

for i in range(Y_pred.shape[0]):
    imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
    basename = os.path.splitext(test_fnames[i])[0]
    cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
