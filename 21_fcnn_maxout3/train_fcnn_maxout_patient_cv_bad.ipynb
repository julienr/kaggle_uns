# %% [markdown]
# ## FCNN with a boolean output indicating the likelihood of the image containing nerve

# %% [markdown]
# Like submission 10, but using patient cv. Doesn't work well..

# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']
X_pids = _d['pids']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
# Out:
# (3906, 128, 128)
# (3906, 128, 128)

# %%
# Split patients in train/test
train_pids, test_pids = train_test_split(np.unique(X_pids), test_size=0.1)
print train_pids
print test_pids
# Out:
# [43  5 33 11 31 32 20 25 42 21 19 39  6 15  7 12  4  1 40 16 45 24 18 30  9
#   2 14 34 41 44 17 13 46  8 28 22 23  3 47 26 38 37]
# [27 10 35 36 29]

# %%
train_indices = np.flatnonzero(np.in1d(X_pids, train_pids))
test_indices = np.flatnonzero(np.in1d(X_pids, test_pids))
X_train = X[train_indices][:,None,:,:]
Y_train_binary = Y_binary[train_indices][:,None]
Y_train = Y[train_indices][:,None,:,:]
X_test = X[test_indices][:,None,:,:]
Y_test_binary = Y_binary[test_indices][:,None]
Y_test = Y[test_indices][:,None,:,:]

# %%
print X_train.shape
print Y_train.shape
print X_test.shape
print X_train.min(), X_train.max()
# Out:
# (3517, 1, 128, 128)
# (3517, 1, 128, 128)
# (389, 1, 128, 128)
# 0.0 1.0

# %%
#pl.imshow(X_train[0].squeeze())
pl.imshow(Y_train[0].squeeze())
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float32,lib.cnmem=0.75'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense
from keras.layers import LeakyReLU, BatchNormalization
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is enabled with initial size: 75.0% of memory, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
from keras.layers import Layer, InputSpec
import keras.initializations
import keras.backend as K

class Maxout2D(Layer):
    def __init__(self, output_dim, cardinality, init='glorot_uniform', **kwargs):
        super(Maxout2D, self).__init__(**kwargs)
        # the k of the maxout paper
        self.cardinality = cardinality
        # the m of the maxout paper
        self.output_dim = output_dim
        self.init = keras.initializations.get(init)
    
    def build(self, input_shape):
        self.input_dim = input_shape[1]
        self.input_spec = [InputSpec(dtype=K.floatx(),
                                     shape=(None, input_shape[1], input_shape[2], input_shape[3]))]
        self.W = self.init((self.input_dim, self.output_dim, self.cardinality),
                           name='{}_W'.format(self.name))
        self.b = K.zeros((self.output_dim, self.cardinality))
        self.trainable_weights = [self.W, self.b]
              
    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        # flatten the spatial dimensions
        flat_x = K.reshape(x, (-1, input_shape[1], input_shape[2] * input_shape[3]))
        output = K.dot(
            K.permute_dimensions(flat_x, (0, 2, 1)),
            K.permute_dimensions(self.W, (1, 0, 2))
        )
        output += K.reshape(self.b, (1, 1, self.output_dim, self.cardinality))
        output = K.max(output, axis=3)
        output = output.transpose(0, 2, 1)
        output = K.reshape(output, (-1, self.output_dim, input_shape[2], input_shape[3]))
        return output
    
    def get_output_shape_for(self, input_shape):
        return (input_shape[0], self.output_dim, input_shape[2], input_shape[3])
    
    def get_config(self):
        config = {
            'output_dim': self.output_dim,
            'cardinality': self.cardinality
        }
        base_config = super(Maxout2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))
    
input_img = Input(shape=(3, 16, 16))
x = Convolution2D(16, 3, 3, border_mode='same')(input_img)
x = Maxout2D(5, 7)(x)

model = Model(input=input_img, output=x)
model.compile(optimizer='adam', loss='mse')
print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_2 (InputLayer)               (None, 3, 16, 16)   0
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)    (None, 16, 16, 16)  448         input_2[0][0]
# ____________________________________________________________________________________________________
# maxout2d_2 (Maxout2D)              (None, 5, 16, 16)   595         convolution2d_2[0][0]
# ====================================================================================================
# Total params: 1043
# ____________________________________________________________________________________________________

# %%
input_img = Input(shape=input_shape, name='input_img')
x = Convolution2D(16, 3, 3, border_mode='same')(input_img)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(16, 2)(x)
pool1 = x = MaxPooling2D((2, 2), name='pool1')(x)

x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(16, 2)(x)
pool2 = x = MaxPooling2D((2, 2), name='pool2')(x)

x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(16, 2)(x)
pool3 = x = MaxPooling2D((2, 2), name='pool3')(x)

# -- binary presence part
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(16, 2)(x)
pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(16, 2)(x)
pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(x)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# -- location map
x = Convolution2D(16, 3, 3, border_mode='same')(pool3)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Maxout2D(16, 2)(x)
x = UpSampling2D((2, 2))(x)

outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
loss='binary_crossentropy'
metrics={'outbin': 'accuracy'}
model.compile(optimizer='adam',
              loss=loss,
              loss_weights=[1., 0.01],
              metrics=metrics)

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_79 (Convolution2D)   (None, 16, 128, 128)160         input_img[0][0]
# ____________________________________________________________________________________________________
# convolution2d_80 (Convolution2D)   (None, 16, 128, 128)2320        convolution2d_79[0][0]
# ____________________________________________________________________________________________________
# dropout_36 (Dropout)               (None, 16, 128, 128)0           convolution2d_80[0][0]
# ____________________________________________________________________________________________________
# maxout2d_11 (Maxout2D)             (None, 16, 128, 128)544         dropout_36[0][0]
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)               (None, 16, 64, 64)  0           maxout2d_11[0][0]
# ____________________________________________________________________________________________________
# convolution2d_81 (Convolution2D)   (None, 16, 64, 64)  2320        pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_82 (Convolution2D)   (None, 16, 64, 64)  2320        convolution2d_81[0][0]
# ____________________________________________________________________________________________________
# dropout_37 (Dropout)               (None, 16, 64, 64)  0           convolution2d_82[0][0]
# ____________________________________________________________________________________________________
# maxout2d_12 (Maxout2D)             (None, 16, 64, 64)  544         dropout_37[0][0]
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)               (None, 16, 32, 32)  0           maxout2d_12[0][0]
# ____________________________________________________________________________________________________
# convolution2d_83 (Convolution2D)   (None, 32, 32, 32)  4640        pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_84 (Convolution2D)   (None, 32, 32, 32)  9248        convolution2d_83[0][0]
# ____________________________________________________________________________________________________
# dropout_38 (Dropout)               (None, 32, 32, 32)  0           convolution2d_84[0][0]
# ____________________________________________________________________________________________________
# maxout2d_13 (Maxout2D)             (None, 16, 32, 32)  1056        dropout_38[0][0]
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)               (None, 16, 16, 16)  0           maxout2d_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_85 (Convolution2D)   (None, 16, 16, 16)  2320        pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_86 (Convolution2D)   (None, 16, 16, 16)  2320        convolution2d_85[0][0]
# ____________________________________________________________________________________________________
# convolution2d_89 (Convolution2D)   (None, 8, 16, 16)   1160        pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_90 (Convolution2D)   (None, 8, 16, 16)   584         convolution2d_89[0][0]
# ____________________________________________________________________________________________________
# dropout_39 (Dropout)               (None, 16, 16, 16)  0           convolution2d_86[0][0]
# ____________________________________________________________________________________________________
# maxout2d_14 (Maxout2D)             (None, 16, 16, 16)  544         dropout_39[0][0]
# ____________________________________________________________________________________________________
# maxout2d_16 (Maxout2D)             (None, 8, 16, 16)   1152        convolution2d_90[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)               (None, 16, 8, 8)    0           maxout2d_14[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_34 (UpSampling2D)     (None, 8, 32, 32)   0           maxout2d_16[0][0]
# ____________________________________________________________________________________________________
# convolution2d_87 (Convolution2D)   (None, 16, 8, 8)    2320        pool4[0][0]
# ____________________________________________________________________________________________________
# merge_27 (Merge)                   (None, 24, 32, 32)  0           upsampling2d_34[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_88 (Convolution2D)   (None, 16, 8, 8)    2320        convolution2d_87[0][0]
# ____________________________________________________________________________________________________
# convolution2d_91 (Convolution2D)   (None, 8, 32, 32)   1736        merge_27[0][0]
# ____________________________________________________________________________________________________
# convolution2d_92 (Convolution2D)   (None, 8, 32, 32)   584         convolution2d_91[0][0]
# ____________________________________________________________________________________________________
# dropout_40 (Dropout)               (None, 16, 8, 8)    0           convolution2d_88[0][0]
# ____________________________________________________________________________________________________
# maxout2d_15 (Maxout2D)             (None, 16, 8, 8)    544         dropout_40[0][0]
# ____________________________________________________________________________________________________
# maxout2d_17 (Maxout2D)             (None, 8, 32, 32)   1152        convolution2d_92[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)               (None, 16, 4, 4)    0           maxout2d_15[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_35 (UpSampling2D)     (None, 8, 64, 64)   0           maxout2d_17[0][0]
# ____________________________________________________________________________________________________
# flatten_8 (Flatten)                (None, 256)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# merge_28 (Merge)                   (None, 24, 64, 64)  0           upsampling2d_35[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_93 (Convolution2D)   (None, 8, 64, 64)   1736        merge_28[0][0]
# ____________________________________________________________________________________________________
# dense_15 (Dense)                   (None, 32)          8224        flatten_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_94 (Convolution2D)   (None, 8, 64, 64)   584         convolution2d_93[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_45 (LeakyReLU)           (None, 32)          0           dense_15[0][0]
# ____________________________________________________________________________________________________
# dense_16 (Dense)                   (None, 16)          528         leakyrelu_45[0][0]
# ____________________________________________________________________________________________________
# maxout2d_18 (Maxout2D)             (None, 8, 64, 64)   1152        convolution2d_94[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_46 (LeakyReLU)           (None, 16)          0           dense_16[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_36 (UpSampling2D)     (None, 8, 128, 128) 0           maxout2d_18[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_46[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 73          upsampling2d_36[0][0]
# ====================================================================================================
# Total params: 52202
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {'outmap': Y_train, 'outbin': Y_train_binary},
        batch_size=64,
        validation_data=(X_test, {'outmap': Y_test, 'outbin': Y_test_binary}),
        nb_epoch=70,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    pl.plot(history.history['loss'], label='train loss')
    pl.plot(history.history['val_loss'], c='g', label='val loss')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
        custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.01])
    
    print_summary(model.layers)
# Out:
# Train on 3517 samples, validate on 389 samples
# Epoch 1/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.1343 - outmap_loss: 0.1234 - outbin_loss: 1.0888 - outbin_acc: 0.5611Epoch 00000: val_loss improved from inf to 0.11887, saving model to weights.hdf5
# 3517/3517 [==============================] - 36s - loss: 0.1332 - outmap_loss: 0.1224 - outbin_loss: 1.0826 - outbin_acc: 0.5624 - val_loss: 0.1189 - val_outmap_loss: 0.1125 - val_outbin_loss: 0.6421 - val_outbin_acc: 0.6504
# Epoch 2/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0658 - outmap_loss: 0.0590 - outbin_loss: 0.6762 - outbin_acc: 0.6146Epoch 00001: val_loss improved from 0.11887 to 0.08573, saving model to weights.hdf5
# 3517/3517 [==============================] - 36s - loss: 0.0658 - outmap_loss: 0.0590 - outbin_loss: 0.6749 - outbin_acc: 0.6156 - val_loss: 0.0857 - val_outmap_loss: 0.0792 - val_outbin_loss: 0.6492 - val_outbin_acc: 0.6632
# Epoch 3/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0559 - outmap_loss: 0.0495 - outbin_loss: 0.6372 - outbin_acc: 0.6458Epoch 00002: val_loss improved from 0.08573 to 0.05916, saving model to weights.hdf5
# 3517/3517 [==============================] - 36s - loss: 0.0560 - outmap_loss: 0.0496 - outbin_loss: 0.6378 - outbin_acc: 0.6443 - val_loss: 0.0592 - val_outmap_loss: 0.0529 - val_outbin_loss: 0.6225 - val_outbin_acc: 0.7532
# Epoch 4/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0485 - outmap_loss: 0.0424 - outbin_loss: 0.6146 - outbin_acc: 0.6600Epoch 00003: val_loss improved from 0.05916 to 0.05001, saving model to weights.hdf5
# 3517/3517 [==============================] - 36s - loss: 0.0486 - outmap_loss: 0.0425 - outbin_loss: 0.6165 - outbin_acc: 0.6582 - val_loss: 0.0500 - val_outmap_loss: 0.0438 - val_outbin_loss: 0.6185 - val_outbin_acc: 0.6555
# Epoch 5/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0458 - outmap_loss: 0.0397 - outbin_loss: 0.6037 - outbin_acc: 0.6782Epoch 00004: val_loss improved from 0.05001 to 0.04831, saving model to weights.hdf5
# 3517/3517 [==============================] - 36s - loss: 0.0458 - outmap_loss: 0.0397 - outbin_loss: 0.6041 - outbin_acc: 0.6779 - val_loss: 0.0483 - val_outmap_loss: 0.0421 - val_outbin_loss: 0.6254 - val_outbin_acc: 0.6812
# Epoch 6/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0405 - outmap_loss: 0.0347 - outbin_loss: 0.5769 - outbin_acc: 0.6959Epoch 00005: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0405 - outmap_loss: 0.0347 - outbin_loss: 0.5779 - outbin_acc: 0.6952 - val_loss: 0.0510 - val_outmap_loss: 0.0454 - val_outbin_loss: 0.5652 - val_outbin_acc: 0.6941
# Epoch 7/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0389 - outmap_loss: 0.0334 - outbin_loss: 0.5507 - outbin_acc: 0.7190Epoch 00006: val_loss improved from 0.04831 to 0.04393, saving model to weights.hdf5
# 3517/3517 [==============================] - 35s - loss: 0.0388 - outmap_loss: 0.0333 - outbin_loss: 0.5503 - outbin_acc: 0.7194 - val_loss: 0.0439 - val_outmap_loss: 0.0385 - val_outbin_loss: 0.5383 - val_outbin_acc: 0.7301
# Epoch 8/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0358 - outmap_loss: 0.0307 - outbin_loss: 0.5150 - outbin_acc: 0.7439Epoch 00007: val_loss improved from 0.04393 to 0.04188, saving model to weights.hdf5
# 3517/3517 [==============================] - 36s - loss: 0.0358 - outmap_loss: 0.0306 - outbin_loss: 0.5156 - outbin_acc: 0.7435 - val_loss: 0.0419 - val_outmap_loss: 0.0369 - val_outbin_loss: 0.4995 - val_outbin_acc: 0.7995
# Epoch 9/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0337 - outmap_loss: 0.0288 - outbin_loss: 0.4862 - outbin_acc: 0.7740Epoch 00008: val_loss improved from 0.04188 to 0.03909, saving model to weights.hdf5
# 3517/3517 [==============================] - 35s - loss: 0.0336 - outmap_loss: 0.0288 - outbin_loss: 0.4856 - outbin_acc: 0.7745 - val_loss: 0.0391 - val_outmap_loss: 0.0341 - val_outbin_loss: 0.5015 - val_outbin_acc: 0.7712
# Epoch 10/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0318 - outmap_loss: 0.0273 - outbin_loss: 0.4484 - outbin_acc: 0.7954Epoch 00009: val_loss improved from 0.03909 to 0.03840, saving model to weights.hdf5
# 3517/3517 [==============================] - 35s - loss: 0.0320 - outmap_loss: 0.0275 - outbin_loss: 0.4488 - outbin_acc: 0.7947 - val_loss: 0.0384 - val_outmap_loss: 0.0336 - val_outbin_loss: 0.4766 - val_outbin_acc: 0.7763
# Epoch 11/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0321 - outmap_loss: 0.0277 - outbin_loss: 0.4436 - outbin_acc: 0.7977Epoch 00010: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0320 - outmap_loss: 0.0276 - outbin_loss: 0.4431 - outbin_acc: 0.7984 - val_loss: 0.0405 - val_outmap_loss: 0.0360 - val_outbin_loss: 0.4459 - val_outbin_acc: 0.8098
# Epoch 12/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0301 - outmap_loss: 0.0258 - outbin_loss: 0.4269 - outbin_acc: 0.8122Epoch 00011: val_loss improved from 0.03840 to 0.03686, saving model to weights.hdf5
# 3517/3517 [==============================] - 35s - loss: 0.0300 - outmap_loss: 0.0258 - outbin_loss: 0.4259 - outbin_acc: 0.8129 - val_loss: 0.0369 - val_outmap_loss: 0.0323 - val_outbin_loss: 0.4566 - val_outbin_acc: 0.8072
# Epoch 13/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0286 - outmap_loss: 0.0246 - outbin_loss: 0.4001 - outbin_acc: 0.8252Epoch 00012: val_loss improved from 0.03686 to 0.03525, saving model to weights.hdf5
# 3517/3517 [==============================] - 35s - loss: 0.0286 - outmap_loss: 0.0246 - outbin_loss: 0.3988 - outbin_acc: 0.8251 - val_loss: 0.0352 - val_outmap_loss: 0.0309 - val_outbin_loss: 0.4387 - val_outbin_acc: 0.8046
# Epoch 14/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0281 - outmap_loss: 0.0242 - outbin_loss: 0.3914 - outbin_acc: 0.8330Epoch 00013: val_loss did not improve
# 3517/3517 [==============================] - 35s - loss: 0.0284 - outmap_loss: 0.0245 - outbin_loss: 0.3943 - outbin_acc: 0.8314 - val_loss: 0.0390 - val_outmap_loss: 0.0346 - val_outbin_loss: 0.4435 - val_outbin_acc: 0.8072
# Epoch 15/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0280 - outmap_loss: 0.0241 - outbin_loss: 0.3880 - outbin_acc: 0.8333Epoch 00014: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0281 - outmap_loss: 0.0242 - outbin_loss: 0.3890 - outbin_acc: 0.8339 - val_loss: 0.0360 - val_outmap_loss: 0.0316 - val_outbin_loss: 0.4413 - val_outbin_acc: 0.8098
# Epoch 16/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0276 - outmap_loss: 0.0238 - outbin_loss: 0.3859 - outbin_acc: 0.8287Epoch 00015: val_loss did not improve
# 3517/3517 [==============================] - 35s - loss: 0.0277 - outmap_loss: 0.0238 - outbin_loss: 0.3858 - outbin_acc: 0.8283 - val_loss: 0.0363 - val_outmap_loss: 0.0317 - val_outbin_loss: 0.4539 - val_outbin_acc: 0.7815
# Epoch 17/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0268 - outmap_loss: 0.0231 - outbin_loss: 0.3702 - outbin_acc: 0.8391Epoch 00016: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0268 - outmap_loss: 0.0231 - outbin_loss: 0.3709 - outbin_acc: 0.8391 - val_loss: 0.0354 - val_outmap_loss: 0.0313 - val_outbin_loss: 0.4126 - val_outbin_acc: 0.8175
# Epoch 18/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0272 - outmap_loss: 0.0234 - outbin_loss: 0.3753 - outbin_acc: 0.8394Epoch 00017: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0272 - outmap_loss: 0.0234 - outbin_loss: 0.3769 - outbin_acc: 0.8391 - val_loss: 0.0356 - val_outmap_loss: 0.0313 - val_outbin_loss: 0.4327 - val_outbin_acc: 0.8201
# Epoch 19/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0267 - outmap_loss: 0.0230 - outbin_loss: 0.3730 - outbin_acc: 0.8380Epoch 00018: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0267 - outmap_loss: 0.0230 - outbin_loss: 0.3738 - outbin_acc: 0.8371 - val_loss: 0.0355 - val_outmap_loss: 0.0311 - val_outbin_loss: 0.4394 - val_outbin_acc: 0.7763
# Epoch 20/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0257 - outmap_loss: 0.0222 - outbin_loss: 0.3503 - outbin_acc: 0.8536Epoch 00019: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0258 - outmap_loss: 0.0223 - outbin_loss: 0.3506 - outbin_acc: 0.8530 - val_loss: 0.0359 - val_outmap_loss: 0.0315 - val_outbin_loss: 0.4330 - val_outbin_acc: 0.8201
# Epoch 21/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0258 - outmap_loss: 0.0222 - outbin_loss: 0.3608 - outbin_acc: 0.8475Epoch 00020: val_loss improved from 0.03525 to 0.03384, saving model to weights.hdf5
# 3517/3517 [==============================] - 37s - loss: 0.0258 - outmap_loss: 0.0222 - outbin_loss: 0.3603 - outbin_acc: 0.8479 - val_loss: 0.0338 - val_outmap_loss: 0.0296 - val_outbin_loss: 0.4272 - val_outbin_acc: 0.8149
# Epoch 22/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0255 - outmap_loss: 0.0220 - outbin_loss: 0.3500 - outbin_acc: 0.8426Epoch 00021: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0256 - outmap_loss: 0.0220 - outbin_loss: 0.3516 - outbin_acc: 0.8428 - val_loss: 0.0393 - val_outmap_loss: 0.0345 - val_outbin_loss: 0.4857 - val_outbin_acc: 0.7404
# Epoch 23/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0252 - outmap_loss: 0.0217 - outbin_loss: 0.3501 - outbin_acc: 0.8547Epoch 00022: val_loss improved from 0.03384 to 0.03370, saving model to weights.hdf5
# 3517/3517 [==============================] - 36s - loss: 0.0252 - outmap_loss: 0.0217 - outbin_loss: 0.3491 - outbin_acc: 0.8553 - val_loss: 0.0337 - val_outmap_loss: 0.0297 - val_outbin_loss: 0.4045 - val_outbin_acc: 0.8226
# Epoch 24/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0244 - outmap_loss: 0.0210 - outbin_loss: 0.3363 - outbin_acc: 0.8562Epoch 00023: val_loss did not improve
# 3517/3517 [==============================] - 35s - loss: 0.0244 - outmap_loss: 0.0210 - outbin_loss: 0.3352 - outbin_acc: 0.8570 - val_loss: 0.0358 - val_outmap_loss: 0.0317 - val_outbin_loss: 0.4125 - val_outbin_acc: 0.8226
# Epoch 25/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0253 - outmap_loss: 0.0218 - outbin_loss: 0.3509 - outbin_acc: 0.8446Epoch 00024: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0252 - outmap_loss: 0.0217 - outbin_loss: 0.3499 - outbin_acc: 0.8459 - val_loss: 0.0339 - val_outmap_loss: 0.0297 - val_outbin_loss: 0.4229 - val_outbin_acc: 0.8175
# Epoch 26/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0243 - outmap_loss: 0.0209 - outbin_loss: 0.3425 - outbin_acc: 0.8519Epoch 00025: val_loss improved from 0.03370 to 0.03251, saving model to weights.hdf5
# 3517/3517 [==============================] - 36s - loss: 0.0243 - outmap_loss: 0.0209 - outbin_loss: 0.3432 - outbin_acc: 0.8516 - val_loss: 0.0325 - val_outmap_loss: 0.0283 - val_outbin_loss: 0.4165 - val_outbin_acc: 0.8329
# Epoch 27/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0244 - outmap_loss: 0.0211 - outbin_loss: 0.3300 - outbin_acc: 0.8620Epoch 00026: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0244 - outmap_loss: 0.0211 - outbin_loss: 0.3304 - outbin_acc: 0.8615 - val_loss: 0.0355 - val_outmap_loss: 0.0311 - val_outbin_loss: 0.4393 - val_outbin_acc: 0.8123
# Epoch 28/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0238 - outmap_loss: 0.0206 - outbin_loss: 0.3184 - outbin_acc: 0.8681Epoch 00027: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0237 - outmap_loss: 0.0205 - outbin_loss: 0.3183 - outbin_acc: 0.8675 - val_loss: 0.0358 - val_outmap_loss: 0.0314 - val_outbin_loss: 0.4418 - val_outbin_acc: 0.8201
# Epoch 29/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0240 - outmap_loss: 0.0206 - outbin_loss: 0.3357 - outbin_acc: 0.8539Epoch 00028: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0239 - outmap_loss: 0.0206 - outbin_loss: 0.3355 - outbin_acc: 0.8539 - val_loss: 0.0354 - val_outmap_loss: 0.0310 - val_outbin_loss: 0.4427 - val_outbin_acc: 0.7686
# Epoch 30/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0233 - outmap_loss: 0.0201 - outbin_loss: 0.3180 - outbin_acc: 0.8652Epoch 00029: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0233 - outmap_loss: 0.0201 - outbin_loss: 0.3213 - outbin_acc: 0.8641 - val_loss: 0.0334 - val_outmap_loss: 0.0290 - val_outbin_loss: 0.4436 - val_outbin_acc: 0.7841
# Epoch 31/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0231 - outmap_loss: 0.0199 - outbin_loss: 0.3189 - outbin_acc: 0.8617Epoch 00030: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0230 - outmap_loss: 0.0198 - outbin_loss: 0.3201 - outbin_acc: 0.8607 - val_loss: 0.0355 - val_outmap_loss: 0.0311 - val_outbin_loss: 0.4431 - val_outbin_acc: 0.7738
# Epoch 32/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0232 - outmap_loss: 0.0199 - outbin_loss: 0.3284 - outbin_acc: 0.8637Epoch 00031: val_loss did not improve
# 3517/3517 [==============================] - 37s - loss: 0.0232 - outmap_loss: 0.0199 - outbin_loss: 0.3283 - outbin_acc: 0.8635 - val_loss: 0.0353 - val_outmap_loss: 0.0311 - val_outbin_loss: 0.4158 - val_outbin_acc: 0.8175
# Epoch 33/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0229 - outmap_loss: 0.0198 - outbin_loss: 0.3073 - outbin_acc: 0.8744Epoch 00032: val_loss improved from 0.03251 to 0.03053, saving model to weights.hdf5
# 3517/3517 [==============================] - 37s - loss: 0.0229 - outmap_loss: 0.0198 - outbin_loss: 0.3102 - outbin_acc: 0.8726 - val_loss: 0.0305 - val_outmap_loss: 0.0266 - val_outbin_loss: 0.3950 - val_outbin_acc: 0.8432
# Epoch 34/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0229 - outmap_loss: 0.0197 - outbin_loss: 0.3167 - outbin_acc: 0.8675Epoch 00033: val_loss did not improve
# 3517/3517 [==============================] - 37s - loss: 0.0229 - outmap_loss: 0.0198 - outbin_loss: 0.3176 - outbin_acc: 0.8664 - val_loss: 0.0318 - val_outmap_loss: 0.0276 - val_outbin_loss: 0.4254 - val_outbin_acc: 0.8278
# Epoch 35/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0222 - outmap_loss: 0.0191 - outbin_loss: 0.3080 - outbin_acc: 0.8701Epoch 00034: val_loss did not improve
# 3517/3517 [==============================] - 37s - loss: 0.0223 - outmap_loss: 0.0192 - outbin_loss: 0.3082 - outbin_acc: 0.8698 - val_loss: 0.0317 - val_outmap_loss: 0.0275 - val_outbin_loss: 0.4234 - val_outbin_acc: 0.8123
# Epoch 36/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0221 - outmap_loss: 0.0191 - outbin_loss: 0.2961 - outbin_acc: 0.8709Epoch 00035: val_loss did not improve
# 3517/3517 [==============================] - 37s - loss: 0.0220 - outmap_loss: 0.0191 - outbin_loss: 0.2946 - outbin_acc: 0.8718 - val_loss: 0.0362 - val_outmap_loss: 0.0319 - val_outbin_loss: 0.4214 - val_outbin_acc: 0.8072
# Epoch 37/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0219 - outmap_loss: 0.0189 - outbin_loss: 0.2969 - outbin_acc: 0.8762Epoch 00036: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0219 - outmap_loss: 0.0189 - outbin_loss: 0.2970 - outbin_acc: 0.8763 - val_loss: 0.0330 - val_outmap_loss: 0.0291 - val_outbin_loss: 0.3915 - val_outbin_acc: 0.8329
# Epoch 38/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0216 - outmap_loss: 0.0188 - outbin_loss: 0.2815 - outbin_acc: 0.8837Epoch 00037: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0217 - outmap_loss: 0.0188 - outbin_loss: 0.2810 - outbin_acc: 0.8840 - val_loss: 0.0325 - val_outmap_loss: 0.0284 - val_outbin_loss: 0.4071 - val_outbin_acc: 0.8123
# Epoch 39/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0228 - outmap_loss: 0.0197 - outbin_loss: 0.3134 - outbin_acc: 0.8727Epoch 00038: val_loss did not improve
# 3517/3517 [==============================] - 35s - loss: 0.0227 - outmap_loss: 0.0196 - outbin_loss: 0.3118 - outbin_acc: 0.8740 - val_loss: 0.0346 - val_outmap_loss: 0.0298 - val_outbin_loss: 0.4850 - val_outbin_acc: 0.7686
# Epoch 40/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0224 - outmap_loss: 0.0193 - outbin_loss: 0.3119 - outbin_acc: 0.8701Epoch 00039: val_loss did not improve
# 3517/3517 [==============================] - 35s - loss: 0.0224 - outmap_loss: 0.0193 - outbin_loss: 0.3130 - outbin_acc: 0.8701 - val_loss: 0.0323 - val_outmap_loss: 0.0276 - val_outbin_loss: 0.4719 - val_outbin_acc: 0.7532
# Epoch 41/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0219 - outmap_loss: 0.0189 - outbin_loss: 0.2994 - outbin_acc: 0.8695Epoch 00040: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0219 - outmap_loss: 0.0189 - outbin_loss: 0.3003 - outbin_acc: 0.8698 - val_loss: 0.0335 - val_outmap_loss: 0.0295 - val_outbin_loss: 0.4038 - val_outbin_acc: 0.8149
# Epoch 42/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0212 - outmap_loss: 0.0184 - outbin_loss: 0.2820 - outbin_acc: 0.8854Epoch 00041: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0213 - outmap_loss: 0.0184 - outbin_loss: 0.2828 - outbin_acc: 0.8846 - val_loss: 0.0325 - val_outmap_loss: 0.0286 - val_outbin_loss: 0.3944 - val_outbin_acc: 0.8149
# Epoch 43/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0213 - outmap_loss: 0.0183 - outbin_loss: 0.2944 - outbin_acc: 0.8845Epoch 00042: val_loss did not improve
# 3517/3517 [==============================] - 35s - loss: 0.0213 - outmap_loss: 0.0184 - outbin_loss: 0.2941 - outbin_acc: 0.8843 - val_loss: 0.0329 - val_outmap_loss: 0.0291 - val_outbin_loss: 0.3856 - val_outbin_acc: 0.8458
# Epoch 44/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0214 - outmap_loss: 0.0185 - outbin_loss: 0.2884 - outbin_acc: 0.8805Epoch 00043: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0214 - outmap_loss: 0.0185 - outbin_loss: 0.2861 - outbin_acc: 0.8817 - val_loss: 0.0319 - val_outmap_loss: 0.0277 - val_outbin_loss: 0.4186 - val_outbin_acc: 0.8149
# Epoch 45/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0215 - outmap_loss: 0.0186 - outbin_loss: 0.2945 - outbin_acc: 0.8782Epoch 00044: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0215 - outmap_loss: 0.0186 - outbin_loss: 0.2942 - outbin_acc: 0.8775 - val_loss: 0.0321 - val_outmap_loss: 0.0281 - val_outbin_loss: 0.3979 - val_outbin_acc: 0.8278
# Epoch 46/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0209 - outmap_loss: 0.0182 - outbin_loss: 0.2757 - outbin_acc: 0.8843Epoch 00045: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0211 - outmap_loss: 0.0183 - outbin_loss: 0.2790 - outbin_acc: 0.8820 - val_loss: 0.0321 - val_outmap_loss: 0.0281 - val_outbin_loss: 0.4036 - val_outbin_acc: 0.8149
# Epoch 47/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0217 - outmap_loss: 0.0187 - outbin_loss: 0.2982 - outbin_acc: 0.8738Epoch 00046: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0217 - outmap_loss: 0.0187 - outbin_loss: 0.2977 - outbin_acc: 0.8738 - val_loss: 0.0349 - val_outmap_loss: 0.0303 - val_outbin_loss: 0.4571 - val_outbin_acc: 0.7686
# Epoch 48/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0211 - outmap_loss: 0.0183 - outbin_loss: 0.2835 - outbin_acc: 0.8825Epoch 00047: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0211 - outmap_loss: 0.0183 - outbin_loss: 0.2851 - outbin_acc: 0.8817 - val_loss: 0.0331 - val_outmap_loss: 0.0290 - val_outbin_loss: 0.4082 - val_outbin_acc: 0.8123
# Epoch 49/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0209 - outmap_loss: 0.0180 - outbin_loss: 0.2861 - outbin_acc: 0.8840Epoch 00048: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0209 - outmap_loss: 0.0180 - outbin_loss: 0.2871 - outbin_acc: 0.8834 - val_loss: 0.0326 - val_outmap_loss: 0.0285 - val_outbin_loss: 0.4125 - val_outbin_acc: 0.8149
# Epoch 50/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0206 - outmap_loss: 0.0178 - outbin_loss: 0.2710 - outbin_acc: 0.8950Epoch 00049: val_loss did not improve
# 3517/3517 [==============================] - 35s - loss: 0.0206 - outmap_loss: 0.0179 - outbin_loss: 0.2713 - outbin_acc: 0.8939 - val_loss: 0.0331 - val_outmap_loss: 0.0292 - val_outbin_loss: 0.3928 - val_outbin_acc: 0.8278
# Epoch 51/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0203 - outmap_loss: 0.0176 - outbin_loss: 0.2692 - outbin_acc: 0.8857Epoch 00050: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0203 - outmap_loss: 0.0176 - outbin_loss: 0.2694 - outbin_acc: 0.8854 - val_loss: 0.0337 - val_outmap_loss: 0.0297 - val_outbin_loss: 0.4043 - val_outbin_acc: 0.8149
# Epoch 52/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0207 - outmap_loss: 0.0180 - outbin_loss: 0.2706 - outbin_acc: 0.8892Epoch 00051: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0208 - outmap_loss: 0.0181 - outbin_loss: 0.2701 - outbin_acc: 0.8891 - val_loss: 0.0323 - val_outmap_loss: 0.0283 - val_outbin_loss: 0.4041 - val_outbin_acc: 0.8406
# Epoch 53/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0201 - outmap_loss: 0.0174 - outbin_loss: 0.2718 - outbin_acc: 0.8886Epoch 00052: val_loss did not improve
# 3517/3517 [==============================] - 35s - loss: 0.0202 - outmap_loss: 0.0175 - outbin_loss: 0.2722 - outbin_acc: 0.8877 - val_loss: 0.0339 - val_outmap_loss: 0.0298 - val_outbin_loss: 0.4018 - val_outbin_acc: 0.8278
# Epoch 54/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0200 - outmap_loss: 0.0172 - outbin_loss: 0.2743 - outbin_acc: 0.8863Epoch 00053: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0201 - outmap_loss: 0.0173 - outbin_loss: 0.2758 - outbin_acc: 0.8857 - val_loss: 0.0322 - val_outmap_loss: 0.0281 - val_outbin_loss: 0.4158 - val_outbin_acc: 0.8226
# Epoch 55/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0203 - outmap_loss: 0.0176 - outbin_loss: 0.2722 - outbin_acc: 0.8869Epoch 00054: val_loss did not improve
# 3517/3517 [==============================] - 35s - loss: 0.0203 - outmap_loss: 0.0175 - outbin_loss: 0.2716 - outbin_acc: 0.8866 - val_loss: 0.0352 - val_outmap_loss: 0.0313 - val_outbin_loss: 0.3968 - val_outbin_acc: 0.8252
# Epoch 56/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0201 - outmap_loss: 0.0174 - outbin_loss: 0.2628 - outbin_acc: 0.8892Epoch 00055: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0201 - outmap_loss: 0.0175 - outbin_loss: 0.2645 - outbin_acc: 0.8880 - val_loss: 0.0365 - val_outmap_loss: 0.0320 - val_outbin_loss: 0.4454 - val_outbin_acc: 0.8021
# Epoch 57/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0201 - outmap_loss: 0.0174 - outbin_loss: 0.2629 - outbin_acc: 0.8915Epoch 00056: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0201 - outmap_loss: 0.0175 - outbin_loss: 0.2630 - outbin_acc: 0.8917 - val_loss: 0.0328 - val_outmap_loss: 0.0288 - val_outbin_loss: 0.4003 - val_outbin_acc: 0.8252
# Epoch 58/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0199 - outmap_loss: 0.0173 - outbin_loss: 0.2534 - outbin_acc: 0.9010Epoch 00057: val_loss did not improve
# 3517/3517 [==============================] - 38s - loss: 0.0198 - outmap_loss: 0.0173 - outbin_loss: 0.2526 - outbin_acc: 0.9013 - val_loss: 0.0332 - val_outmap_loss: 0.0291 - val_outbin_loss: 0.4038 - val_outbin_acc: 0.8355
# Epoch 59/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0200 - outmap_loss: 0.0173 - outbin_loss: 0.2725 - outbin_acc: 0.8880Epoch 00058: val_loss did not improve
# 3517/3517 [==============================] - 38s - loss: 0.0200 - outmap_loss: 0.0173 - outbin_loss: 0.2718 - outbin_acc: 0.8883 - val_loss: 0.0356 - val_outmap_loss: 0.0315 - val_outbin_loss: 0.4067 - val_outbin_acc: 0.8226
# Epoch 60/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0195 - outmap_loss: 0.0169 - outbin_loss: 0.2516 - outbin_acc: 0.8947Epoch 00059: val_loss did not improve
# 3517/3517 [==============================] - 38s - loss: 0.0195 - outmap_loss: 0.0170 - outbin_loss: 0.2528 - outbin_acc: 0.8951 - val_loss: 0.0358 - val_outmap_loss: 0.0320 - val_outbin_loss: 0.3744 - val_outbin_acc: 0.8278
# Epoch 61/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0197 - outmap_loss: 0.0171 - outbin_loss: 0.2609 - outbin_acc: 0.8900Epoch 00060: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0196 - outmap_loss: 0.0170 - outbin_loss: 0.2590 - outbin_acc: 0.8905 - val_loss: 0.0344 - val_outmap_loss: 0.0303 - val_outbin_loss: 0.4097 - val_outbin_acc: 0.8201
# Epoch 62/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0200 - outmap_loss: 0.0173 - outbin_loss: 0.2693 - outbin_acc: 0.8872Epoch 00061: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0200 - outmap_loss: 0.0173 - outbin_loss: 0.2696 - outbin_acc: 0.8871 - val_loss: 0.0346 - val_outmap_loss: 0.0299 - val_outbin_loss: 0.4706 - val_outbin_acc: 0.7841
# Epoch 63/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0205 - outmap_loss: 0.0178 - outbin_loss: 0.2738 - outbin_acc: 0.8866Epoch 00062: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0207 - outmap_loss: 0.0179 - outbin_loss: 0.2764 - outbin_acc: 0.8854 - val_loss: 0.0329 - val_outmap_loss: 0.0288 - val_outbin_loss: 0.4148 - val_outbin_acc: 0.8098
# Epoch 64/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0197 - outmap_loss: 0.0170 - outbin_loss: 0.2646 - outbin_acc: 0.8944Epoch 00063: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0198 - outmap_loss: 0.0171 - outbin_loss: 0.2652 - outbin_acc: 0.8945 - val_loss: 0.0321 - val_outmap_loss: 0.0280 - val_outbin_loss: 0.4133 - val_outbin_acc: 0.7969
# Epoch 65/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0199 - outmap_loss: 0.0174 - outbin_loss: 0.2515 - outbin_acc: 0.8953Epoch 00064: val_loss did not improve
# 3517/3517 [==============================] - 38s - loss: 0.0198 - outmap_loss: 0.0173 - outbin_loss: 0.2506 - outbin_acc: 0.8959 - val_loss: 0.0332 - val_outmap_loss: 0.0291 - val_outbin_loss: 0.4077 - val_outbin_acc: 0.8149
# Epoch 66/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0195 - outmap_loss: 0.0170 - outbin_loss: 0.2526 - outbin_acc: 0.8906Epoch 00065: val_loss did not improve
# 3517/3517 [==============================] - 38s - loss: 0.0194 - outmap_loss: 0.0169 - outbin_loss: 0.2523 - outbin_acc: 0.8902 - val_loss: 0.0342 - val_outmap_loss: 0.0300 - val_outbin_loss: 0.4147 - val_outbin_acc: 0.8252
# Epoch 67/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0196 - outmap_loss: 0.0170 - outbin_loss: 0.2578 - outbin_acc: 0.8958Epoch 00066: val_loss did not improve
# 3517/3517 [==============================] - 38s - loss: 0.0196 - outmap_loss: 0.0170 - outbin_loss: 0.2585 - outbin_acc: 0.8954 - val_loss: 0.0375 - val_outmap_loss: 0.0336 - val_outbin_loss: 0.3944 - val_outbin_acc: 0.8278
# Epoch 68/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0195 - outmap_loss: 0.0169 - outbin_loss: 0.2573 - outbin_acc: 0.8921Epoch 00067: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0195 - outmap_loss: 0.0169 - outbin_loss: 0.2583 - outbin_acc: 0.8917 - val_loss: 0.0344 - val_outmap_loss: 0.0304 - val_outbin_loss: 0.4015 - val_outbin_acc: 0.8072
# Epoch 69/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0189 - outmap_loss: 0.0164 - outbin_loss: 0.2537 - outbin_acc: 0.8976Epoch 00068: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0190 - outmap_loss: 0.0164 - outbin_loss: 0.2536 - outbin_acc: 0.8979 - val_loss: 0.0324 - val_outmap_loss: 0.0286 - val_outbin_loss: 0.3842 - val_outbin_acc: 0.8303
# Epoch 70/70
# 3456/3517 [============================>.] - ETA: 0s - loss: 0.0189 - outmap_loss: 0.0164 - outbin_loss: 0.2457 - outbin_acc: 0.8947Epoch 00069: val_loss did not improve
# 3517/3517 [==============================] - 36s - loss: 0.0188 - outmap_loss: 0.0164 - outbin_loss: 0.2445 - outbin_acc: 0.8951 - val_loss: 0.0352 - val_outmap_loss: 0.0313 - val_outbin_loss: 0.3871 - val_outbin_acc: 0.8252

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights.hdf5'))

# %%
conv1 = model.layers[1].output
_f = K.function([K.learning_phase(), input_img], [conv1])
_convout = _f([0, X_test[30:31]])[0]
print _convout.shape

maxout1 = model.layers[3].output
_f = K.function([K.learning_phase(), input_img], [maxout1])
_maxout = _f([0, X_test[30:31]])[0]
print _maxout.shape

pl.figure()
pl.imshow(_convout[0, 0], interpolation='nearest')
pl.colorbar()
pl.figure()
pl.imshow(_maxout[0, 0], interpolation='nearest')
pl.colorbar()
# Out:
# (1, 16, 128, 128)
# (1, 16, 128, 128)
# <matplotlib.colorbar.Colorbar instance at 0x7f22865c1d88>

# %%
def predict(X):
    Y_pred, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > 0.2
    for i in range(Y_pred.shape[0]):
        # Clear prediction where we detect to little pixels
        # Figure it out by
        # pl.hist(np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1))
        if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < 0.2:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test)
Y_full_pred, Y_full_pred_proba, Y_full_pred_binary = predict(X_full)

print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.493674109203
# full set score :  0.626698000357

# %%
_ = pl.hist(Y_pred_binary)

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

for i in lowest[130:135]:
#for i in lowest[:5]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 15
img, pred_map = dream_output(Y_full[i])
pl.figure(figsize=(12, 4))
pl.subplot(131)
pl.imshow(Y_full[i].squeeze())
pl.subplot(132)
pl.imshow(img, cmap=cm.gray)
pl.subplot(133)
pl.imshow(pred_map.squeeze())

# %%
# Dream for the binary output
def dream_binoutput(output):
    
    layer_output = layer_dict['outbin'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output - layer_output[:, 0]))
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    
    step = 0.1
    for i in range(40):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    _, model_pred = model.predict(img[None,None,:,:])
    return img, model_pred

img, model_pred = dream_binoutput(1)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
img, model_pred = dream_binoutput(0)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
def dream_layer_filter(layer_name, filter_index):

    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(8):
        pl.subplot(2, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
if True:
    import cv2
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(50,50))
    
    
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    test_fnames = _d['test_fnames']
    Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:])
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
        imre = cv2.morphologyEx(imre, cv2.MORPH_CLOSE, kernel)
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)

# %% [markdown]
# ## Stats on predicted masks

# %%
# on Y_full
nbp_pixels = np.sum(np.sum(np.sum(Y_full, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
