# %% [markdown]
# sub 25 - scored  0.65099

# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']
X_pids = _d['pids']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
# Out:
# (3906, 128, 128)
# (3906, 128, 128)

# %%
# Split patients in train/test
train_pids, test_pids = train_test_split(np.unique(X_pids), test_size=0.2)
print train_pids
print test_pids
# Out:
# [ 4 12  3 16 10 15 39 43 13 18 11 17 27 34 14 46 36 26 38  6 30 22 20 32  2
#   7 28 42 47 31 29 19  8 33 40 25  1]
# [23  9 41 35 44 37  5 21 24 45]

# %%
if True:
    train_indices = np.flatnonzero(np.in1d(X_pids, train_pids))
    test_indices = np.flatnonzero(np.in1d(X_pids, test_pids))
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]
else:
    nsamples = X.shape[0]

    #train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]

# %%
import skimage.transform as sktransf

def rand_float(rng):
    return rng[0] + np.random.random() * (rng[1] - rng[0])

def generate_image(X_img, Y_img, angle_range=None, zoom_range=None, shear_range=None, horiz_shift_range=None,
                   vert_shift_range=None):
    """
    Randomly shift an image by resizing and then random croping
    the resized image
    """
    if angle_range is None:
        angle_range = (-10, 10)
    if zoom_range is None:
        zoom_range = (0.9, 1.1)
    if shear_range is None:
        shear_range = (-5, 5) # shear angle in degrees
    if horiz_shift_range is None:
        horiz_shift_range = (-2, 2)
    if vert_shift_range is None:
        vert_shift_range = (-2, 2)
    inshape = X_img.shape
    
    X2 = X_img
    Y2 = Y_img
    
    # -- random rotation
    angle = np.deg2rad(rand_float(angle_range))
    zoom = rand_float(zoom_range)
    shear = np.deg2rad(rand_float(shear_range))
    horiz_shift = rand_float(horiz_shift_range)
    vert_shift = rand_float(vert_shift_range)
    
    tform = sktransf.AffineTransform(
        scale=(zoom, zoom),
        rotation=angle,
        shear=shear,
        translation=(horiz_shift, vert_shift)
    )
    X2 = sktransf.warp(X2, tform, order=5, mode='edge')
    Y2 = sktransf.warp(Y2, tform, order=1)

    # gaussian noise
    #noise_scale = rand_float((0, 0.1))
    #X2 += np.random.normal(scale=noise_scale, size=X2.shape)
    Y2 = Y2 > 0.5
    return X2[None,:,:], Y2[None,:,:]

X_train_augmented = []
Y_train_augmented = []
for i in range(X_train.shape[0]):
    if i % 10 == 0:
        print '\r%d / %d' % (i, X_train.shape[0]),
        sys.stdout.flush()
    X_train_augmented.append(X_train[i])
    Y_train_augmented.append(Y_train[i])
    for j in range(2):
        X2, Y2 = generate_image(X_train[i].squeeze(), Y_train[i].squeeze())
        X_train_augmented.append(X2)
        Y_train_augmented.append(Y2)
# Out:
# 3000 / 3010

# %%
X_train = np.array(X_train_augmented)
Y_train = np.array(Y_train_augmented)

Y_train_binary = np.sum(np.sum(Y_train.squeeze(), axis=2), axis=1) > 0
Y_train_binary = Y_train_binary.astype(np.float32)
Y_train_binary = Y_train_binary[:,None]

# %%
print X_train.shape
print Y_train.shape
print X_test.shape
print X_train.min(), X_train.max()
# Out:
# (9030, 1, 128, 128)
# (9030, 1, 128, 128)
# (896, 1, 128, 128)
# 0.0 1.0

# %%
#pl.imshow(X_train[0].squeeze())
pl.imshow(Y_train[0].squeeze())
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float32'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense
from keras.layers import LeakyReLU, BatchNormalization
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
from keras.layers import Layer, InputSpec
import keras.initializations
import keras.backend as K

class Maxout2D(Layer):
    def __init__(self, output_dim, cardinality, init='glorot_uniform', **kwargs):
        super(Maxout2D, self).__init__(**kwargs)
        # the k of the maxout paper
        self.cardinality = cardinality
        # the m of the maxout paper
        self.output_dim = output_dim
        self.init = keras.initializations.get(init)
    
    def build(self, input_shape):
        self.input_dim = input_shape[1]
        self.input_spec = [InputSpec(dtype=K.floatx(),
                                     shape=(None, input_shape[1], input_shape[2], input_shape[3]))]
        self.W = self.init((self.input_dim, self.output_dim, self.cardinality),
                           name='{}_W'.format(self.name))
        self.b = K.zeros((self.output_dim, self.cardinality))
        self.trainable_weights = [self.W, self.b]
              
    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        # flatten the spatial dimensions
        flat_x = K.reshape(x, (-1, input_shape[1], input_shape[2] * input_shape[3]))
        output = K.dot(
            K.permute_dimensions(flat_x, (0, 2, 1)),
            K.permute_dimensions(self.W, (1, 0, 2))
        )
        output += K.reshape(self.b, (1, 1, self.output_dim, self.cardinality))
        output = K.max(output, axis=3)
        output = output.transpose(0, 2, 1)
        output = K.reshape(output, (-1, self.output_dim, input_shape[2], input_shape[3]))
        return output
    
    def get_output_shape_for(self, input_shape):
        return (input_shape[0], self.output_dim, input_shape[2], input_shape[3])
    
    def get_config(self):
        config = {
            'output_dim': self.output_dim,
            'cardinality': self.cardinality
        }
        base_config = super(Maxout2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))
    
input_img = Input(shape=(3, 16, 16))
x = Convolution2D(16, 3, 3, border_mode='same')(input_img)
x = Maxout2D(5, 7)(x)

model = Model(input=input_img, output=x)
model.compile(optimizer='adam', loss='mse')
print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)               (None, 3, 16, 16)   0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)    (None, 16, 16, 16)  448         input_1[0][0]
# ____________________________________________________________________________________________________
# maxout2d_1 (Maxout2D)              (None, 5, 16, 16)   595         convolution2d_1[0][0]
# ====================================================================================================
# Total params: 1043
# ____________________________________________________________________________________________________

# %%
# https://www.kaggle.com/c/ultrasound-nerve-segmentation/forums/t/21358/0-57-deep-learning-keras-tutorial
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def dice_coef_batchwise(y_true, y_pred):
    y_true_f = K.batch_flatten(y_true)
    y_pred_f = K.batch_flatten(y_pred)
    intersection = 2. * K.sum(y_true_f * y_pred_f, axis=1, keepdims=True) + smooth
    union = K.sum(y_true_f, axis=1, keepdims=True) + \
            K.sum(y_pred_f, axis=1, keepdims=True) + \
            smooth
    return K.mean(intersection / union)

def dice_coef_loss_batchwise(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
input_img = Input(shape=input_shape, name='input_img')
x = Convolution2D(32, 3, 3, border_mode='same')(input_img)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(16, 2)(x)
pool1 = x = MaxPooling2D((2, 2), name='pool1')(x)

x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(16, 2)(x)
pool2 = x = MaxPooling2D((2, 2), name='pool2')(x)

x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Dropout(0.1)(x)
x = Maxout2D(16, 2)(x)
pool3 = x = MaxPooling2D((2, 2), name='pool3')(x)

# -- binary presence part
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.1)(x)
x = Maxout2D(16, 2)(x)
pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.1)(x)
x = Maxout2D(16, 2)(x)
#x = BatchNormalization()(x)
pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(x)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# -- location map
x = Convolution2D(8, 3, 3, border_mode='same')(pool3)
x = Convolution2D(4, 3, 3, border_mode='same')(x)
x = Maxout2D(1, 2)(x)
#x = BatchNormalization()(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(4, 3, 3, border_mode='same')(x)
x = Maxout2D(1, 2)(x)
#x = BatchNormalization()(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(4, 3, 3, border_mode='same')(x)
x = Maxout2D(1, 2)(x)
#x = BatchNormalization()(x)
x = UpSampling2D((2, 2))(x)

x = Convolution2D(4, 3, 3, border_mode='same')(x)
x = Convolution2D(4, 3, 3, border_mode='same')(x)
x = Convolution2D(4, 3, 3, border_mode='same')(x)
outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
loss='binary_crossentropy'
#loss=[dice_coef_loss_batchwise, 'binary_crossentropy']
metrics={'outmap': dice_coef, 'outbin': 'accuracy'}
model.compile(optimizer='adam',
              loss=loss,
              loss_weights=[1., 0.01],
              metrics=metrics)

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)    (None, 32, 128, 128)320         input_img[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)    (None, 32, 128, 128)9248        convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)    (None, 32, 128, 128)9248        convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)                (None, 32, 128, 128)0           convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# maxout2d_2 (Maxout2D)              (None, 16, 128, 128)1056        dropout_1[0][0]
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)               (None, 16, 64, 64)  0           maxout2d_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)    (None, 32, 64, 64)  4640        pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_6 (Convolution2D)    (None, 32, 64, 64)  9248        convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_7 (Convolution2D)    (None, 32, 64, 64)  9248        convolution2d_6[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)                (None, 32, 64, 64)  0           convolution2d_7[0][0]
# ____________________________________________________________________________________________________
# maxout2d_3 (Maxout2D)              (None, 16, 64, 64)  1056        dropout_2[0][0]
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)               (None, 16, 32, 32)  0           maxout2d_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8 (Convolution2D)    (None, 32, 32, 32)  4640        pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_9 (Convolution2D)    (None, 32, 32, 32)  9248        convolution2d_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_10 (Convolution2D)   (None, 32, 32, 32)  9248        convolution2d_9[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)                (None, 32, 32, 32)  0           convolution2d_10[0][0]
# ____________________________________________________________________________________________________
# maxout2d_4 (Maxout2D)              (None, 16, 32, 32)  1056        dropout_3[0][0]
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)               (None, 16, 16, 16)  0           maxout2d_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_11 (Convolution2D)   (None, 16, 16, 16)  2320        pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_17 (Convolution2D)   (None, 8, 16, 16)   1160        pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_12 (Convolution2D)   (None, 16, 16, 16)  2320        convolution2d_11[0][0]
# ____________________________________________________________________________________________________
# convolution2d_18 (Convolution2D)   (None, 4, 16, 16)   292         convolution2d_17[0][0]
# ____________________________________________________________________________________________________
# convolution2d_13 (Convolution2D)   (None, 16, 16, 16)  2320        convolution2d_12[0][0]
# ____________________________________________________________________________________________________
# maxout2d_7 (Maxout2D)              (None, 1, 16, 16)   10          convolution2d_18[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)                (None, 16, 16, 16)  0           convolution2d_13[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_1 (UpSampling2D)      (None, 1, 32, 32)   0           maxout2d_7[0][0]
# ____________________________________________________________________________________________________
# maxout2d_5 (Maxout2D)              (None, 16, 16, 16)  544         dropout_4[0][0]
# ____________________________________________________________________________________________________
# merge_1 (Merge)                    (None, 17, 32, 32)  0           upsampling2d_1[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_19 (Convolution2D)   (None, 8, 32, 32)   1232        merge_1[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)               (None, 16, 8, 8)    0           maxout2d_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_14 (Convolution2D)   (None, 16, 8, 8)    2320        pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_20 (Convolution2D)   (None, 4, 32, 32)   292         convolution2d_19[0][0]
# ____________________________________________________________________________________________________
# convolution2d_15 (Convolution2D)   (None, 16, 8, 8)    2320        convolution2d_14[0][0]
# ____________________________________________________________________________________________________
# maxout2d_8 (Maxout2D)              (None, 1, 32, 32)   10          convolution2d_20[0][0]
# ____________________________________________________________________________________________________
# convolution2d_16 (Convolution2D)   (None, 16, 8, 8)    2320        convolution2d_15[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_2 (UpSampling2D)      (None, 1, 64, 64)   0           maxout2d_8[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)                (None, 16, 8, 8)    0           convolution2d_16[0][0]
# ____________________________________________________________________________________________________
# merge_2 (Merge)                    (None, 17, 64, 64)  0           upsampling2d_2[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_21 (Convolution2D)   (None, 8, 64, 64)   1232        merge_2[0][0]
# ____________________________________________________________________________________________________
# maxout2d_6 (Maxout2D)              (None, 16, 8, 8)    544         dropout_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_22 (Convolution2D)   (None, 4, 64, 64)   292         convolution2d_21[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)               (None, 16, 4, 4)    0           maxout2d_6[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)                (None, 256)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# maxout2d_9 (Maxout2D)              (None, 1, 64, 64)   10          convolution2d_22[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                    (None, 32)          8224        flatten_1[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_3 (UpSampling2D)      (None, 1, 128, 128) 0           maxout2d_9[0][0]
# ____________________________________________________________________________________________________
# convolution2d_23 (Convolution2D)   (None, 4, 128, 128) 40          upsampling2d_3[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_1 (LeakyReLU)            (None, 32)          0           dense_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_24 (Convolution2D)   (None, 4, 128, 128) 148         convolution2d_23[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                    (None, 16)          528         leakyrelu_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_25 (Convolution2D)   (None, 4, 128, 128) 148         convolution2d_24[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_2 (LeakyReLU)            (None, 16)          0           dense_2[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_2[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 37          convolution2d_25[0][0]
# ====================================================================================================
# Total params: 96936
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {'outmap': Y_train, 'outbin': Y_train_binary},
        batch_size=32,
        validation_data=(X_test, {'outmap': Y_test, 'outbin': Y_test_binary}),
        nb_epoch=60,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    
    pl.figure()
    pl.plot(history.history['outmap_loss'], label='train loss')
    pl.plot(history.history['val_outmap_loss'], c='g', label='val loss')
    pl.legend()

    pl.figure()
    pl.plot(history.history['outbin_acc'], label='train acc')
    pl.plot(history.history['val_outbin_acc'], c='g', label='val acc')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
        custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.01])
    
    print_summary(model.layers)
# Out:
# Train on 9030 samples, validate on 896 samples
# Epoch 1/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.1364 - outmap_loss: 0.1285 - outbin_loss: 0.7887 - outmap_dice_coef: 0.0057 - outbin_acc: 0.6413Epoch 00000: val_loss improved from inf to 0.11369, saving model to weights.hdf5
# 9030/9030 [==============================] - 118s - loss: 0.1363 - outmap_loss: 0.1284 - outbin_loss: 0.7886 - outmap_dice_coef: 0.0057 - outbin_acc: 0.6413 - val_loss: 0.1137 - val_outmap_loss: 0.1063 - val_outbin_loss: 0.7401 - val_outmap_dice_coef: 0.0033 - val_outbin_acc: 0.4442
# Epoch 2/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0534 - outmap_loss: 0.0469 - outbin_loss: 0.6497 - outmap_dice_coef: 0.0530 - outbin_acc: 0.6590Epoch 00001: val_loss did not improve
# 9030/9030 [==============================] - 118s - loss: 0.0534 - outmap_loss: 0.0469 - outbin_loss: 0.6497 - outmap_dice_coef: 0.0530 - outbin_acc: 0.6590 - val_loss: 0.1188 - val_outmap_loss: 0.1114 - val_outbin_loss: 0.7349 - val_outmap_dice_coef: 0.0052 - val_outbin_acc: 0.4821
# Epoch 3/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0386 - outmap_loss: 0.0333 - outbin_loss: 0.5271 - outmap_dice_coef: 0.1986 - outbin_acc: 0.7527Epoch 00002: val_loss improved from 0.11369 to 0.06757, saving model to weights.hdf5
# 9030/9030 [==============================] - 118s - loss: 0.0386 - outmap_loss: 0.0333 - outbin_loss: 0.5270 - outmap_dice_coef: 0.1986 - outbin_acc: 0.7527 - val_loss: 0.0676 - val_outmap_loss: 0.0611 - val_outbin_loss: 0.6471 - val_outmap_dice_coef: 0.1178 - val_outbin_acc: 0.6138
# Epoch 4/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0332 - outmap_loss: 0.0286 - outbin_loss: 0.4661 - outmap_dice_coef: 0.2802 - outbin_acc: 0.7959Epoch 00003: val_loss improved from 0.06757 to 0.04629, saving model to weights.hdf5
# 9030/9030 [==============================] - 118s - loss: 0.0332 - outmap_loss: 0.0285 - outbin_loss: 0.4659 - outmap_dice_coef: 0.2800 - outbin_acc: 0.7959 - val_loss: 0.0463 - val_outmap_loss: 0.0415 - val_outbin_loss: 0.4814 - val_outmap_dice_coef: 0.2901 - val_outbin_acc: 0.7812
# Epoch 5/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0302 - outmap_loss: 0.0259 - outbin_loss: 0.4228 - outmap_dice_coef: 0.3287 - outbin_acc: 0.8166Epoch 00004: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0302 - outmap_loss: 0.0259 - outbin_loss: 0.4228 - outmap_dice_coef: 0.3286 - outbin_acc: 0.8165 - val_loss: 0.0480 - val_outmap_loss: 0.0427 - val_outbin_loss: 0.5357 - val_outmap_dice_coef: 0.2841 - val_outbin_acc: 0.7478
# Epoch 6/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0281 - outmap_loss: 0.0241 - outbin_loss: 0.4064 - outmap_dice_coef: 0.3672 - outbin_acc: 0.8241Epoch 00005: val_loss improved from 0.04629 to 0.03754, saving model to weights.hdf5
# 9030/9030 [==============================] - 119s - loss: 0.0281 - outmap_loss: 0.0241 - outbin_loss: 0.4065 - outmap_dice_coef: 0.3673 - outbin_acc: 0.8240 - val_loss: 0.0375 - val_outmap_loss: 0.0341 - val_outbin_loss: 0.3452 - val_outmap_dice_coef: 0.4877 - val_outbin_acc: 0.8571
# Epoch 7/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0263 - outmap_loss: 0.0225 - outbin_loss: 0.3790 - outmap_dice_coef: 0.4023 - outbin_acc: 0.8416Epoch 00006: val_loss did not improve
# 9030/9030 [==============================] - 118s - loss: 0.0263 - outmap_loss: 0.0225 - outbin_loss: 0.3791 - outmap_dice_coef: 0.4024 - outbin_acc: 0.8416 - val_loss: 0.0379 - val_outmap_loss: 0.0331 - val_outbin_loss: 0.4850 - val_outmap_dice_coef: 0.4393 - val_outbin_acc: 0.7679
# Epoch 8/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0260 - outmap_loss: 0.0224 - outbin_loss: 0.3639 - outmap_dice_coef: 0.4035 - outbin_acc: 0.8518Epoch 00007: val_loss improved from 0.03754 to 0.03461, saving model to weights.hdf5
# 9030/9030 [==============================] - 118s - loss: 0.0261 - outmap_loss: 0.0224 - outbin_loss: 0.3639 - outmap_dice_coef: 0.4035 - outbin_acc: 0.8518 - val_loss: 0.0346 - val_outmap_loss: 0.0310 - val_outbin_loss: 0.3618 - val_outmap_dice_coef: 0.5324 - val_outbin_acc: 0.8460
# Epoch 9/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0246 - outmap_loss: 0.0211 - outbin_loss: 0.3488 - outmap_dice_coef: 0.4283 - outbin_acc: 0.8551Epoch 00008: val_loss did not improve
# 9030/9030 [==============================] - 118s - loss: 0.0246 - outmap_loss: 0.0211 - outbin_loss: 0.3491 - outmap_dice_coef: 0.4284 - outbin_acc: 0.8549 - val_loss: 0.0399 - val_outmap_loss: 0.0363 - val_outbin_loss: 0.3632 - val_outmap_dice_coef: 0.5441 - val_outbin_acc: 0.8315
# Epoch 10/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0243 - outmap_loss: 0.0208 - outbin_loss: 0.3520 - outmap_dice_coef: 0.4356 - outbin_acc: 0.8539Epoch 00009: val_loss improved from 0.03461 to 0.03182, saving model to weights.hdf5
# 9030/9030 [==============================] - 121s - loss: 0.0243 - outmap_loss: 0.0208 - outbin_loss: 0.3520 - outmap_dice_coef: 0.4357 - outbin_acc: 0.8539 - val_loss: 0.0318 - val_outmap_loss: 0.0276 - val_outbin_loss: 0.4259 - val_outmap_dice_coef: 0.5673 - val_outbin_acc: 0.8002
# Epoch 11/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0236 - outmap_loss: 0.0203 - outbin_loss: 0.3351 - outmap_dice_coef: 0.4476 - outbin_acc: 0.8640Epoch 00010: val_loss did not improve
# 9030/9030 [==============================] - 118s - loss: 0.0236 - outmap_loss: 0.0203 - outbin_loss: 0.3351 - outmap_dice_coef: 0.4476 - outbin_acc: 0.8640 - val_loss: 0.0323 - val_outmap_loss: 0.0287 - val_outbin_loss: 0.3637 - val_outmap_dice_coef: 0.5100 - val_outbin_acc: 0.8203
# Epoch 12/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0228 - outmap_loss: 0.0195 - outbin_loss: 0.3256 - outmap_dice_coef: 0.4619 - outbin_acc: 0.8625Epoch 00011: val_loss improved from 0.03182 to 0.03028, saving model to weights.hdf5
# 9030/9030 [==============================] - 118s - loss: 0.0228 - outmap_loss: 0.0195 - outbin_loss: 0.3260 - outmap_dice_coef: 0.4616 - outbin_acc: 0.8625 - val_loss: 0.0303 - val_outmap_loss: 0.0269 - val_outbin_loss: 0.3370 - val_outmap_dice_coef: 0.5236 - val_outbin_acc: 0.8404
# Epoch 13/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0230 - outmap_loss: 0.0197 - outbin_loss: 0.3309 - outmap_dice_coef: 0.4515 - outbin_acc: 0.8592Epoch 00012: val_loss did not improve
# 9030/9030 [==============================] - 120s - loss: 0.0230 - outmap_loss: 0.0197 - outbin_loss: 0.3314 - outmap_dice_coef: 0.4514 - outbin_acc: 0.8590 - val_loss: 0.0334 - val_outmap_loss: 0.0300 - val_outbin_loss: 0.3470 - val_outmap_dice_coef: 0.5021 - val_outbin_acc: 0.8571
# Epoch 14/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0228 - outmap_loss: 0.0194 - outbin_loss: 0.3314 - outmap_dice_coef: 0.4567 - outbin_acc: 0.8679Epoch 00013: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0228 - outmap_loss: 0.0194 - outbin_loss: 0.3312 - outmap_dice_coef: 0.4568 - outbin_acc: 0.8680 - val_loss: 0.0314 - val_outmap_loss: 0.0277 - val_outbin_loss: 0.3695 - val_outmap_dice_coef: 0.5603 - val_outbin_acc: 0.8136
# Epoch 15/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0220 - outmap_loss: 0.0188 - outbin_loss: 0.3183 - outmap_dice_coef: 0.4734 - outbin_acc: 0.8711Epoch 00014: val_loss improved from 0.03028 to 0.02911, saving model to weights.hdf5
# 9030/9030 [==============================] - 119s - loss: 0.0220 - outmap_loss: 0.0188 - outbin_loss: 0.3185 - outmap_dice_coef: 0.4735 - outbin_acc: 0.8709 - val_loss: 0.0291 - val_outmap_loss: 0.0258 - val_outbin_loss: 0.3278 - val_outmap_dice_coef: 0.5732 - val_outbin_acc: 0.8382
# Epoch 16/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0215 - outmap_loss: 0.0184 - outbin_loss: 0.3110 - outmap_dice_coef: 0.4777 - outbin_acc: 0.8739Epoch 00015: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0215 - outmap_loss: 0.0184 - outbin_loss: 0.3109 - outmap_dice_coef: 0.4774 - outbin_acc: 0.8740 - val_loss: 0.0294 - val_outmap_loss: 0.0263 - val_outbin_loss: 0.3117 - val_outmap_dice_coef: 0.5872 - val_outbin_acc: 0.8694
# Epoch 17/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0216 - outmap_loss: 0.0185 - outbin_loss: 0.3121 - outmap_dice_coef: 0.4767 - outbin_acc: 0.8754Epoch 00016: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0216 - outmap_loss: 0.0185 - outbin_loss: 0.3120 - outmap_dice_coef: 0.4764 - outbin_acc: 0.8755 - val_loss: 0.0321 - val_outmap_loss: 0.0279 - val_outbin_loss: 0.4268 - val_outmap_dice_coef: 0.5167 - val_outbin_acc: 0.7980
# Epoch 18/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0211 - outmap_loss: 0.0181 - outbin_loss: 0.3052 - outmap_dice_coef: 0.4881 - outbin_acc: 0.8732Epoch 00017: val_loss did not improve
# 9030/9030 [==============================] - 122s - loss: 0.0211 - outmap_loss: 0.0181 - outbin_loss: 0.3051 - outmap_dice_coef: 0.4881 - outbin_acc: 0.8733 - val_loss: 0.0327 - val_outmap_loss: 0.0290 - val_outbin_loss: 0.3633 - val_outmap_dice_coef: 0.4812 - val_outbin_acc: 0.8326
# Epoch 19/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0212 - outmap_loss: 0.0181 - outbin_loss: 0.3079 - outmap_dice_coef: 0.4852 - outbin_acc: 0.8734Epoch 00018: val_loss did not improve
# 9030/9030 [==============================] - 123s - loss: 0.0212 - outmap_loss: 0.0181 - outbin_loss: 0.3081 - outmap_dice_coef: 0.4851 - outbin_acc: 0.8733 - val_loss: 0.0321 - val_outmap_loss: 0.0285 - val_outbin_loss: 0.3663 - val_outmap_dice_coef: 0.4811 - val_outbin_acc: 0.8304
# Epoch 20/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0207 - outmap_loss: 0.0177 - outbin_loss: 0.2938 - outmap_dice_coef: 0.4877 - outbin_acc: 0.8823Epoch 00019: val_loss did not improve
# 9030/9030 [==============================] - 121s - loss: 0.0206 - outmap_loss: 0.0177 - outbin_loss: 0.2937 - outmap_dice_coef: 0.4878 - outbin_acc: 0.8823 - val_loss: 0.0317 - val_outmap_loss: 0.0273 - val_outbin_loss: 0.4428 - val_outmap_dice_coef: 0.5654 - val_outbin_acc: 0.8382
# Epoch 21/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0205 - outmap_loss: 0.0175 - outbin_loss: 0.2972 - outmap_dice_coef: 0.4960 - outbin_acc: 0.8791Epoch 00020: val_loss did not improve
# 9030/9030 [==============================] - 120s - loss: 0.0205 - outmap_loss: 0.0175 - outbin_loss: 0.2970 - outmap_dice_coef: 0.4960 - outbin_acc: 0.8792 - val_loss: 0.0296 - val_outmap_loss: 0.0255 - val_outbin_loss: 0.4073 - val_outmap_dice_coef: 0.5828 - val_outbin_acc: 0.8214
# Epoch 22/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0203 - outmap_loss: 0.0174 - outbin_loss: 0.2929 - outmap_dice_coef: 0.5044 - outbin_acc: 0.8784Epoch 00021: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0203 - outmap_loss: 0.0174 - outbin_loss: 0.2928 - outmap_dice_coef: 0.5044 - outbin_acc: 0.8785 - val_loss: 0.0334 - val_outmap_loss: 0.0294 - val_outbin_loss: 0.3943 - val_outmap_dice_coef: 0.5488 - val_outbin_acc: 0.8114
# Epoch 23/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0201 - outmap_loss: 0.0173 - outbin_loss: 0.2841 - outmap_dice_coef: 0.5010 - outbin_acc: 0.8832Epoch 00022: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0201 - outmap_loss: 0.0173 - outbin_loss: 0.2840 - outmap_dice_coef: 0.5011 - outbin_acc: 0.8832 - val_loss: 0.0317 - val_outmap_loss: 0.0273 - val_outbin_loss: 0.4435 - val_outmap_dice_coef: 0.5178 - val_outbin_acc: 0.8281
# Epoch 24/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0197 - outmap_loss: 0.0169 - outbin_loss: 0.2807 - outmap_dice_coef: 0.5115 - outbin_acc: 0.8874Epoch 00023: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0197 - outmap_loss: 0.0169 - outbin_loss: 0.2808 - outmap_dice_coef: 0.5115 - outbin_acc: 0.8874 - val_loss: 0.0300 - val_outmap_loss: 0.0264 - val_outbin_loss: 0.3537 - val_outmap_dice_coef: 0.5647 - val_outbin_acc: 0.8292
# Epoch 25/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0197 - outmap_loss: 0.0169 - outbin_loss: 0.2839 - outmap_dice_coef: 0.5152 - outbin_acc: 0.8866Epoch 00024: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0197 - outmap_loss: 0.0169 - outbin_loss: 0.2838 - outmap_dice_coef: 0.5153 - outbin_acc: 0.8866 - val_loss: 0.0305 - val_outmap_loss: 0.0269 - val_outbin_loss: 0.3634 - val_outmap_dice_coef: 0.5444 - val_outbin_acc: 0.8471
# Epoch 26/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0198 - outmap_loss: 0.0170 - outbin_loss: 0.2840 - outmap_dice_coef: 0.5093 - outbin_acc: 0.8862Epoch 00025: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0199 - outmap_loss: 0.0170 - outbin_loss: 0.2845 - outmap_dice_coef: 0.5092 - outbin_acc: 0.8860 - val_loss: 0.0306 - val_outmap_loss: 0.0269 - val_outbin_loss: 0.3614 - val_outmap_dice_coef: 0.5186 - val_outbin_acc: 0.8304
# Epoch 27/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0193 - outmap_loss: 0.0165 - outbin_loss: 0.2795 - outmap_dice_coef: 0.5227 - outbin_acc: 0.8864Epoch 00026: val_loss did not improve
# 9030/9030 [==============================] - 124s - loss: 0.0193 - outmap_loss: 0.0166 - outbin_loss: 0.2795 - outmap_dice_coef: 0.5225 - outbin_acc: 0.8864 - val_loss: 0.0325 - val_outmap_loss: 0.0286 - val_outbin_loss: 0.3910 - val_outmap_dice_coef: 0.4882 - val_outbin_acc: 0.8237
# Epoch 28/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0191 - outmap_loss: 0.0164 - outbin_loss: 0.2699 - outmap_dice_coef: 0.5258 - outbin_acc: 0.8894Epoch 00027: val_loss did not improve
# 9030/9030 [==============================] - 124s - loss: 0.0191 - outmap_loss: 0.0164 - outbin_loss: 0.2699 - outmap_dice_coef: 0.5258 - outbin_acc: 0.8894 - val_loss: 0.0316 - val_outmap_loss: 0.0275 - val_outbin_loss: 0.4067 - val_outmap_dice_coef: 0.5411 - val_outbin_acc: 0.8281
# Epoch 29/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0190 - outmap_loss: 0.0164 - outbin_loss: 0.2637 - outmap_dice_coef: 0.5237 - outbin_acc: 0.8931Epoch 00028: val_loss did not improve
# 9030/9030 [==============================] - 124s - loss: 0.0190 - outmap_loss: 0.0164 - outbin_loss: 0.2636 - outmap_dice_coef: 0.5238 - outbin_acc: 0.8931 - val_loss: 0.0323 - val_outmap_loss: 0.0279 - val_outbin_loss: 0.4435 - val_outmap_dice_coef: 0.5187 - val_outbin_acc: 0.8237
# Epoch 30/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0191 - outmap_loss: 0.0164 - outbin_loss: 0.2658 - outmap_dice_coef: 0.5245 - outbin_acc: 0.8936Epoch 00029: val_loss did not improve
# 9030/9030 [==============================] - 124s - loss: 0.0191 - outmap_loss: 0.0164 - outbin_loss: 0.2658 - outmap_dice_coef: 0.5243 - outbin_acc: 0.8937 - val_loss: 0.0377 - val_outmap_loss: 0.0315 - val_outbin_loss: 0.6252 - val_outmap_dice_coef: 0.4637 - val_outbin_acc: 0.7489
# Epoch 31/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0187 - outmap_loss: 0.0161 - outbin_loss: 0.2667 - outmap_dice_coef: 0.5322 - outbin_acc: 0.8942Epoch 00030: val_loss did not improve
# 9030/9030 [==============================] - 124s - loss: 0.0187 - outmap_loss: 0.0161 - outbin_loss: 0.2667 - outmap_dice_coef: 0.5319 - outbin_acc: 0.8941 - val_loss: 0.0309 - val_outmap_loss: 0.0265 - val_outbin_loss: 0.4375 - val_outmap_dice_coef: 0.5919 - val_outbin_acc: 0.8069
# Epoch 32/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0181 - outmap_loss: 0.0156 - outbin_loss: 0.2499 - outmap_dice_coef: 0.5406 - outbin_acc: 0.8969Epoch 00031: val_loss did not improve
# 9030/9030 [==============================] - 120s - loss: 0.0182 - outmap_loss: 0.0157 - outbin_loss: 0.2502 - outmap_dice_coef: 0.5404 - outbin_acc: 0.8968 - val_loss: 0.0322 - val_outmap_loss: 0.0266 - val_outbin_loss: 0.5597 - val_outmap_dice_coef: 0.5692 - val_outbin_acc: 0.8504
# Epoch 33/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0189 - outmap_loss: 0.0160 - outbin_loss: 0.2917 - outmap_dice_coef: 0.5323 - outbin_acc: 0.8816Epoch 00032: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0189 - outmap_loss: 0.0160 - outbin_loss: 0.2918 - outmap_dice_coef: 0.5321 - outbin_acc: 0.8815 - val_loss: 0.0295 - val_outmap_loss: 0.0257 - val_outbin_loss: 0.3815 - val_outmap_dice_coef: 0.5702 - val_outbin_acc: 0.8225
# Epoch 34/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0180 - outmap_loss: 0.0155 - outbin_loss: 0.2490 - outmap_dice_coef: 0.5457 - outbin_acc: 0.8992Epoch 00033: val_loss did not improve
# 9030/9030 [==============================] - 118s - loss: 0.0180 - outmap_loss: 0.0155 - outbin_loss: 0.2489 - outmap_dice_coef: 0.5459 - outbin_acc: 0.8992 - val_loss: 0.0356 - val_outmap_loss: 0.0297 - val_outbin_loss: 0.5897 - val_outmap_dice_coef: 0.5523 - val_outbin_acc: 0.7411
# Epoch 35/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0178 - outmap_loss: 0.0154 - outbin_loss: 0.2379 - outmap_dice_coef: 0.5468 - outbin_acc: 0.9060Epoch 00034: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0178 - outmap_loss: 0.0154 - outbin_loss: 0.2378 - outmap_dice_coef: 0.5464 - outbin_acc: 0.9061 - val_loss: 0.0307 - val_outmap_loss: 0.0266 - val_outbin_loss: 0.4080 - val_outmap_dice_coef: 0.5637 - val_outbin_acc: 0.8292
# Epoch 36/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0173 - outmap_loss: 0.0150 - outbin_loss: 0.2306 - outmap_dice_coef: 0.5563 - outbin_acc: 0.9066Epoch 00035: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0173 - outmap_loss: 0.0150 - outbin_loss: 0.2311 - outmap_dice_coef: 0.5563 - outbin_acc: 0.9064 - val_loss: 0.0303 - val_outmap_loss: 0.0266 - val_outbin_loss: 0.3699 - val_outmap_dice_coef: 0.5539 - val_outbin_acc: 0.8471
# Epoch 37/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0173 - outmap_loss: 0.0148 - outbin_loss: 0.2479 - outmap_dice_coef: 0.5603 - outbin_acc: 0.9014Epoch 00036: val_loss did not improve
# 9030/9030 [==============================] - 122s - loss: 0.0173 - outmap_loss: 0.0148 - outbin_loss: 0.2480 - outmap_dice_coef: 0.5604 - outbin_acc: 0.9013 - val_loss: 0.0323 - val_outmap_loss: 0.0274 - val_outbin_loss: 0.4860 - val_outmap_dice_coef: 0.5485 - val_outbin_acc: 0.7946
# Epoch 38/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0172 - outmap_loss: 0.0149 - outbin_loss: 0.2348 - outmap_dice_coef: 0.5596 - outbin_acc: 0.9062Epoch 00037: val_loss did not improve
# 9030/9030 [==============================] - 124s - loss: 0.0173 - outmap_loss: 0.0149 - outbin_loss: 0.2348 - outmap_dice_coef: 0.5596 - outbin_acc: 0.9061 - val_loss: 0.0318 - val_outmap_loss: 0.0279 - val_outbin_loss: 0.3876 - val_outmap_dice_coef: 0.5353 - val_outbin_acc: 0.8047
# Epoch 39/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0171 - outmap_loss: 0.0148 - outbin_loss: 0.2335 - outmap_dice_coef: 0.5639 - outbin_acc: 0.9059Epoch 00038: val_loss did not improve
# 9030/9030 [==============================] - 124s - loss: 0.0171 - outmap_loss: 0.0148 - outbin_loss: 0.2334 - outmap_dice_coef: 0.5638 - outbin_acc: 0.9059 - val_loss: 0.0312 - val_outmap_loss: 0.0268 - val_outbin_loss: 0.4400 - val_outmap_dice_coef: 0.5548 - val_outbin_acc: 0.8460
# Epoch 40/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0167 - outmap_loss: 0.0145 - outbin_loss: 0.2207 - outmap_dice_coef: 0.5712 - outbin_acc: 0.9116Epoch 00039: val_loss did not improve
# 9030/9030 [==============================] - 121s - loss: 0.0167 - outmap_loss: 0.0145 - outbin_loss: 0.2207 - outmap_dice_coef: 0.5712 - outbin_acc: 0.9116 - val_loss: 0.0303 - val_outmap_loss: 0.0263 - val_outbin_loss: 0.4054 - val_outmap_dice_coef: 0.5712 - val_outbin_acc: 0.8047
# Epoch 41/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0171 - outmap_loss: 0.0148 - outbin_loss: 0.2343 - outmap_dice_coef: 0.5642 - outbin_acc: 0.9060Epoch 00040: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0171 - outmap_loss: 0.0148 - outbin_loss: 0.2342 - outmap_dice_coef: 0.5643 - outbin_acc: 0.9061 - val_loss: 0.0331 - val_outmap_loss: 0.0269 - val_outbin_loss: 0.6189 - val_outmap_dice_coef: 0.5207 - val_outbin_acc: 0.7835
# Epoch 42/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0168 - outmap_loss: 0.0146 - outbin_loss: 0.2253 - outmap_dice_coef: 0.5694 - outbin_acc: 0.9117Epoch 00041: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0168 - outmap_loss: 0.0146 - outbin_loss: 0.2252 - outmap_dice_coef: 0.5694 - outbin_acc: 0.9117 - val_loss: 0.0331 - val_outmap_loss: 0.0285 - val_outbin_loss: 0.4616 - val_outmap_dice_coef: 0.5130 - val_outbin_acc: 0.7935
# Epoch 43/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0163 - outmap_loss: 0.0141 - outbin_loss: 0.2134 - outmap_dice_coef: 0.5791 - outbin_acc: 0.9164Epoch 00042: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0163 - outmap_loss: 0.0141 - outbin_loss: 0.2135 - outmap_dice_coef: 0.5791 - outbin_acc: 0.9164 - val_loss: 0.0317 - val_outmap_loss: 0.0272 - val_outbin_loss: 0.4522 - val_outmap_dice_coef: 0.5425 - val_outbin_acc: 0.8036
# Epoch 44/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0185 - outmap_loss: 0.0148 - outbin_loss: 0.3726 - outmap_dice_coef: 0.5669 - outbin_acc: 0.8831Epoch 00043: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0185 - outmap_loss: 0.0148 - outbin_loss: 0.3724 - outmap_dice_coef: 0.5665 - outbin_acc: 0.8832 - val_loss: 0.0341 - val_outmap_loss: 0.0285 - val_outbin_loss: 0.5643 - val_outmap_dice_coef: 0.4740 - val_outbin_acc: 0.7165
# Epoch 45/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0165 - outmap_loss: 0.0142 - outbin_loss: 0.2311 - outmap_dice_coef: 0.5774 - outbin_acc: 0.9077Epoch 00044: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0165 - outmap_loss: 0.0142 - outbin_loss: 0.2311 - outmap_dice_coef: 0.5775 - outbin_acc: 0.9078 - val_loss: 0.0355 - val_outmap_loss: 0.0308 - val_outbin_loss: 0.4665 - val_outmap_dice_coef: 0.5489 - val_outbin_acc: 0.8114
# Epoch 46/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0162 - outmap_loss: 0.0141 - outbin_loss: 0.2130 - outmap_dice_coef: 0.5781 - outbin_acc: 0.9151Epoch 00045: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0162 - outmap_loss: 0.0141 - outbin_loss: 0.2132 - outmap_dice_coef: 0.5782 - outbin_acc: 0.9151 - val_loss: 0.0320 - val_outmap_loss: 0.0274 - val_outbin_loss: 0.4511 - val_outmap_dice_coef: 0.5518 - val_outbin_acc: 0.8013
# Epoch 47/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0163 - outmap_loss: 0.0141 - outbin_loss: 0.2155 - outmap_dice_coef: 0.5824 - outbin_acc: 0.9098Epoch 00046: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0163 - outmap_loss: 0.0141 - outbin_loss: 0.2154 - outmap_dice_coef: 0.5824 - outbin_acc: 0.9097 - val_loss: 0.0314 - val_outmap_loss: 0.0275 - val_outbin_loss: 0.3958 - val_outmap_dice_coef: 0.5591 - val_outbin_acc: 0.8192
# Epoch 48/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0156 - outmap_loss: 0.0136 - outbin_loss: 0.1950 - outmap_dice_coef: 0.5952 - outbin_acc: 0.9219Epoch 00047: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0156 - outmap_loss: 0.0136 - outbin_loss: 0.1950 - outmap_dice_coef: 0.5952 - outbin_acc: 0.9218 - val_loss: 0.0320 - val_outmap_loss: 0.0276 - val_outbin_loss: 0.4384 - val_outmap_dice_coef: 0.5584 - val_outbin_acc: 0.8203
# Epoch 49/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0159 - outmap_loss: 0.0139 - outbin_loss: 0.1958 - outmap_dice_coef: 0.5866 - outbin_acc: 0.9253Epoch 00048: val_loss did not improve
# 9030/9030 [==============================] - 119s - loss: 0.0159 - outmap_loss: 0.0139 - outbin_loss: 0.1957 - outmap_dice_coef: 0.5866 - outbin_acc: 0.9254 - val_loss: 0.0315 - val_outmap_loss: 0.0275 - val_outbin_loss: 0.3980 - val_outmap_dice_coef: 0.5821 - val_outbin_acc: 0.8270
# Epoch 50/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0152 - outmap_loss: 0.0134 - outbin_loss: 0.1769 - outmap_dice_coef: 0.6020 - outbin_acc: 0.9305Epoch 00049: val_loss did not improve
# 9030/9030 [==============================] - 121s - loss: 0.0152 - outmap_loss: 0.0134 - outbin_loss: 0.1768 - outmap_dice_coef: 0.6020 - outbin_acc: 0.9306 - val_loss: 0.0327 - val_outmap_loss: 0.0283 - val_outbin_loss: 0.4433 - val_outmap_dice_coef: 0.6143 - val_outbin_acc: 0.8237
# Epoch 51/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0155 - outmap_loss: 0.0135 - outbin_loss: 0.1950 - outmap_dice_coef: 0.5992 - outbin_acc: 0.9234Epoch 00050: val_loss did not improve
# 9030/9030 [==============================] - 123s - loss: 0.0155 - outmap_loss: 0.0135 - outbin_loss: 0.1949 - outmap_dice_coef: 0.5988 - outbin_acc: 0.9235 - val_loss: 0.0333 - val_outmap_loss: 0.0289 - val_outbin_loss: 0.4411 - val_outmap_dice_coef: 0.5840 - val_outbin_acc: 0.8214
# Epoch 52/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0155 - outmap_loss: 0.0135 - outbin_loss: 0.1941 - outmap_dice_coef: 0.5969 - outbin_acc: 0.9242Epoch 00051: val_loss did not improve
# 9030/9030 [==============================] - 123s - loss: 0.0155 - outmap_loss: 0.0135 - outbin_loss: 0.1941 - outmap_dice_coef: 0.5968 - outbin_acc: 0.9241 - val_loss: 0.0306 - val_outmap_loss: 0.0266 - val_outbin_loss: 0.4053 - val_outmap_dice_coef: 0.5600 - val_outbin_acc: 0.8348
# Epoch 53/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0153 - outmap_loss: 0.0134 - outbin_loss: 0.1903 - outmap_dice_coef: 0.5981 - outbin_acc: 0.9250Epoch 00052: val_loss did not improve
# 9030/9030 [==============================] - 123s - loss: 0.0153 - outmap_loss: 0.0134 - outbin_loss: 0.1904 - outmap_dice_coef: 0.5981 - outbin_acc: 0.9249 - val_loss: 0.0321 - val_outmap_loss: 0.0274 - val_outbin_loss: 0.4687 - val_outmap_dice_coef: 0.5568 - val_outbin_acc: 0.8237
# Epoch 54/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0148 - outmap_loss: 0.0129 - outbin_loss: 0.1823 - outmap_dice_coef: 0.6111 - outbin_acc: 0.9296Epoch 00053: val_loss did not improve
# 9030/9030 [==============================] - 123s - loss: 0.0148 - outmap_loss: 0.0129 - outbin_loss: 0.1824 - outmap_dice_coef: 0.6112 - outbin_acc: 0.9296 - val_loss: 0.0327 - val_outmap_loss: 0.0283 - val_outbin_loss: 0.4381 - val_outmap_dice_coef: 0.5452 - val_outbin_acc: 0.8237
# Epoch 55/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0150 - outmap_loss: 0.0132 - outbin_loss: 0.1809 - outmap_dice_coef: 0.6059 - outbin_acc: 0.9294Epoch 00054: val_loss did not improve
# 9030/9030 [==============================] - 123s - loss: 0.0150 - outmap_loss: 0.0132 - outbin_loss: 0.1808 - outmap_dice_coef: 0.6055 - outbin_acc: 0.9295 - val_loss: 0.0378 - val_outmap_loss: 0.0318 - val_outbin_loss: 0.6089 - val_outmap_dice_coef: 0.5316 - val_outbin_acc: 0.7913
# Epoch 56/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0152 - outmap_loss: 0.0132 - outbin_loss: 0.1954 - outmap_dice_coef: 0.6036 - outbin_acc: 0.9224Epoch 00055: val_loss did not improve
# 9030/9030 [==============================] - 123s - loss: 0.0152 - outmap_loss: 0.0132 - outbin_loss: 0.1954 - outmap_dice_coef: 0.6036 - outbin_acc: 0.9224 - val_loss: 0.0342 - val_outmap_loss: 0.0296 - val_outbin_loss: 0.4655 - val_outmap_dice_coef: 0.5731 - val_outbin_acc: 0.8192
# Epoch 57/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0150 - outmap_loss: 0.0130 - outbin_loss: 0.1931 - outmap_dice_coef: 0.6083 - outbin_acc: 0.9253Epoch 00056: val_loss did not improve
# 9030/9030 [==============================] - 123s - loss: 0.0150 - outmap_loss: 0.0130 - outbin_loss: 0.1931 - outmap_dice_coef: 0.6083 - outbin_acc: 0.9254 - val_loss: 0.0324 - val_outmap_loss: 0.0273 - val_outbin_loss: 0.5076 - val_outmap_dice_coef: 0.5832 - val_outbin_acc: 0.8125
# Epoch 58/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0148 - outmap_loss: 0.0130 - outbin_loss: 0.1780 - outmap_dice_coef: 0.6090 - outbin_acc: 0.9292Epoch 00057: val_loss did not improve
# 9030/9030 [==============================] - 123s - loss: 0.0148 - outmap_loss: 0.0130 - outbin_loss: 0.1781 - outmap_dice_coef: 0.6089 - outbin_acc: 0.9291 - val_loss: 0.0322 - val_outmap_loss: 0.0276 - val_outbin_loss: 0.4594 - val_outmap_dice_coef: 0.5684 - val_outbin_acc: 0.8248
# Epoch 59/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0153 - outmap_loss: 0.0134 - outbin_loss: 0.1940 - outmap_dice_coef: 0.6022 - outbin_acc: 0.9248Epoch 00058: val_loss did not improve
# 9030/9030 [==============================] - 123s - loss: 0.0153 - outmap_loss: 0.0134 - outbin_loss: 0.1939 - outmap_dice_coef: 0.6023 - outbin_acc: 0.9248 - val_loss: 0.0313 - val_outmap_loss: 0.0267 - val_outbin_loss: 0.4618 - val_outmap_dice_coef: 0.5483 - val_outbin_acc: 0.8259
# Epoch 60/60
# 9024/9030 [============================>.] - ETA: 0s - loss: 0.0143 - outmap_loss: 0.0126 - outbin_loss: 0.1658 - outmap_dice_coef: 0.6222 - outbin_acc: 0.9355Epoch 00059: val_loss did not improve
# 9030/9030 [==============================] - 123s - loss: 0.0143 - outmap_loss: 0.0126 - outbin_loss: 0.1658 - outmap_dice_coef: 0.6221 - outbin_acc: 0.9355 - val_loss: 0.0329 - val_outmap_loss: 0.0280 - val_outbin_loss: 0.4904 - val_outmap_dice_coef: 0.5646 - val_outbin_acc: 0.8125

# %%
if True:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture_final.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights_final.hdf5'))

# %%
conv1 = model.layers[1].output
_f = K.function([K.learning_phase(), input_img], [conv1])
_convout = _f([0, X_test[:1]])[0]
print _convout.shape

maxout1 = model.layers[3].output
_f = K.function([K.learning_phase(), input_img], [maxout1])
_maxout = _f([0, X_test[:1]])[0]
print _maxout.shape

pl.figure()
pl.imshow(_convout[0, 0], interpolation='nearest')
pl.colorbar()
pl.figure()
pl.imshow(_maxout[0, 0], interpolation='nearest')
pl.colorbar()
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/backend/theano_backend.py:514: UserWarning: theano.function was asked to create a function computing outputs given certain inputs, but the provided input variable at index 0 is not part of the computational graph needed to compute the outputs: keras_learning_phase.
# To make this warning into an error, you can pass the parameter on_unused_input='raise' to theano.function. To disable it completely, use on_unused_input='ignore'.
#   **kwargs)
# (1, 32, 128, 128)
# (1, 32, 128, 128)
# <matplotlib.colorbar.Colorbar instance at 0x7fa268e7d5f0>
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
def compute_scores_map(X, Y):
    Y_pred, Y_pred_binary = model.predict(X)
    
    map_threshs = np.linspace(0, 1, num=21)
    bin_threshs = np.linspace(0, 1, num=21)
    
    scores = np.zeros((len(map_threshs), len(bin_threshs)))
    for i in range(len(map_threshs)):
        for j in range(len(bin_threshs)):
            _Y_pred = Y_pred > map_threshs[i]
            
            for k in range(_Y_pred.shape[0]):
                # Clear prediction where we detect to little pixels
                if np.sum(_Y_pred[k]) < 150 or Y_pred_binary[k] < bin_threshs[j]:
                    _Y_pred[k,:] = 0
            
            scores[i, j] = utils.average_dice_coefficient(_Y_pred, Y)
    
    pl.imshow(scores, interpolation='nearest')
    pl.yticks(np.arange(len(map_threshs)) + 0.5, ['%.2f' % v for v in map_threshs])
    pl.xticks(np.arange(len(bin_threshs)) + 0.5, ['%.2f' % v for v in bin_threshs], rotation=90)
    pl.ylabel('map thresh')
    pl.xlabel('bin thresh')
    pl.colorbar()
    
    best_i, best_j = np.unravel_index(np.argmax(scores.ravel()), scores.shape)
    best_map_thresh = map_threshs[best_i]
    best_bin_thresh = bin_threshs[best_j]
    return best_map_thresh, best_bin_thresh

map_thresh, bin_thresh = compute_scores_map(X_test, Y_test)
print 'Best map_thresh=%f, bin_thresh=%f' % (map_thresh, bin_thresh)
# Out:
# Best map_thresh=0.350000, bin_thresh=0.150000

# %%
def predict(X, map_thresh, bin_thresh):
    Y_pred, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > map_thresh
    for i in range(Y_pred.shape[0]):
        if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < bin_thresh:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test, map_thresh, bin_thresh)
Y_full_pred, Y_full_pred_proba, Y_full_pred_binary = predict(X_full, map_thresh, bin_thresh)

print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "avg test set score : ", utils.average_dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
print "avg full set score : ", utils.average_dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.661861055017
# avg test set score :  0.722436991116
# full set score :  0.653342189428
# avg full set score :  0.760887304996

# %%
_ = pl.hist(Y_pred_binary)

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[310:315]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.2
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(30):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 15
img, pred_map = dream_output(Y_full[i])
pl.figure(figsize=(12, 4))
pl.subplot(141)
pl.imshow(X_full[i].squeeze(), cmap=cm.gray)
pl.subplot(142)
pl.imshow(Y_full[i].squeeze())
pl.subplot(143)
pl.imshow(img, cmap=cm.gray)
pl.subplot(144)
pl.imshow(pred_map.squeeze())

# %%
# Dream for the binary output
def dream_binoutput(output):
    
    layer_output = layer_dict['outbin'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output - layer_output[:, 0]))
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    
    step = 0.1
    for i in range(40):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    _, model_pred = model.predict(img[None,None,:,:])
    return img, model_pred

img, model_pred = dream_binoutput(1)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
img, model_pred = dream_binoutput(0)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
def dream_layer_filter(layer_name, filter_index):

    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(4):
        pl.subplot(1, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
if True:
    import cv2
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(50,50))
    
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    test_fnames = _d['test_fnames']
    # bin_thresh
    Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:], map_thresh, 0.5)
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
        #imre = cv2.morphologyEx(imre, cv2.MORPH_CLOSE, kernel)
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
        
        if i % 10 == 0:
            print '\r%d / %d' % (i, len(test_fnames)),
            sys.stdout.flush()
# Out:
# 5500 / 5508

# %% [markdown]
# ## Stats on predicted masks

# %%
# on Y_full
nbp_pixels = np.sum(np.sum(np.sum(Y_full, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
