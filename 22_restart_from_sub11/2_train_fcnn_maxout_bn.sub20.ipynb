# %% [markdown]
# without per-patient CV - sub20 scored 0.63599

# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']
X_pids = _d['pids']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
# Out:
# (3906, 128, 128)
# (3906, 128, 128)

# %%
# Split patients in train/test
train_pids, test_pids = train_test_split(np.unique(X_pids), test_size=0.04)
print train_pids
print test_pids
# Out:
# [45 41 20 15 31 14 33 18 34  1 36  8  2 22 40 30 12  9 24 19 42 28 21 44 29
#  27 11  7 10  6 39 17 46 32 16 26 25 47 37 43 23  3 38 13  4]
# [ 5 35]

# %%
if False:
    train_indices = np.flatnonzero(np.in1d(X_pids, train_pids))
    test_indices = np.flatnonzero(np.in1d(X_pids, test_pids))
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]
else:
    nsamples = X.shape[0]

    #train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]

# %%
print X_train.shape
print Y_train.shape
print X_test.shape
print X_train.min(), X_train.max()
# Out:
# (3515, 1, 128, 128)
# (3515, 1, 128, 128)
# (391, 1, 128, 128)
# 0.0 1.0

# %%
#pl.imshow(X_train[0].squeeze())
pl.imshow(Y_train[0].squeeze())
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float32'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense
from keras.layers import LeakyReLU, BatchNormalization
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
from keras.layers import Layer, InputSpec
import keras.initializations
import keras.backend as K

class Maxout2D(Layer):
    def __init__(self, output_dim, cardinality, init='glorot_uniform', **kwargs):
        super(Maxout2D, self).__init__(**kwargs)
        # the k of the maxout paper
        self.cardinality = cardinality
        # the m of the maxout paper
        self.output_dim = output_dim
        self.init = keras.initializations.get(init)
    
    def build(self, input_shape):
        self.input_dim = input_shape[1]
        self.input_spec = [InputSpec(dtype=K.floatx(),
                                     shape=(None, input_shape[1], input_shape[2], input_shape[3]))]
        self.W = self.init((self.input_dim, self.output_dim, self.cardinality),
                           name='{}_W'.format(self.name))
        self.b = K.zeros((self.output_dim, self.cardinality))
        self.trainable_weights = [self.W, self.b]
              
    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        # flatten the spatial dimensions
        flat_x = K.reshape(x, (-1, input_shape[1], input_shape[2] * input_shape[3]))
        output = K.dot(
            K.permute_dimensions(flat_x, (0, 2, 1)),
            K.permute_dimensions(self.W, (1, 0, 2))
        )
        output += K.reshape(self.b, (1, 1, self.output_dim, self.cardinality))
        output = K.max(output, axis=3)
        output = output.transpose(0, 2, 1)
        output = K.reshape(output, (-1, self.output_dim, input_shape[2], input_shape[3]))
        return output
    
    def get_output_shape_for(self, input_shape):
        return (input_shape[0], self.output_dim, input_shape[2], input_shape[3])
    
    def get_config(self):
        config = {
            'output_dim': self.output_dim,
            'cardinality': self.cardinality
        }
        base_config = super(Maxout2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))
    
input_img = Input(shape=(3, 16, 16))
x = Convolution2D(16, 3, 3, border_mode='same')(input_img)
x = Maxout2D(5, 7)(x)

model = Model(input=input_img, output=x)
model.compile(optimizer='adam', loss='mse')
print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)               (None, 3, 16, 16)   0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)    (None, 16, 16, 16)  448         input_1[0][0]
# ____________________________________________________________________________________________________
# maxout2d_1 (Maxout2D)              (None, 5, 16, 16)   595         convolution2d_1[0][0]
# ====================================================================================================
# Total params: 1043
# ____________________________________________________________________________________________________

# %%
# https://www.kaggle.com/c/ultrasound-nerve-segmentation/forums/t/21358/0-57-deep-learning-keras-tutorial
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def dice_coef_batchwise(y_true, y_pred):
    y_true_f = K.batch_flatten(y_true)
    y_pred_f = K.batch_flatten(y_pred)
    intersection = 2. * K.sum(y_true_f * y_pred_f, axis=1, keepdims=True) + smooth
    union = K.sum(y_true_f, axis=1, keepdims=True) + \
            K.sum(y_pred_f, axis=1, keepdims=True) + \
            smooth
    return K.mean(intersection / union)

def dice_coef_loss_batchwise(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
input_img = Input(shape=input_shape, name='input_img')
x = Convolution2D(16, 3, 3, border_mode='same')(input_img)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(16, 2)(x)
pool1 = x = MaxPooling2D((2, 2), name='pool1')(x)

x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(16, 2)(x)
pool2 = x = MaxPooling2D((2, 2), name='pool2')(x)

x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Dropout(0.1)(x)
x = Maxout2D(16, 2)(x)
pool3 = x = MaxPooling2D((2, 2), name='pool3')(x)

# -- binary presence part
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.1)(x)
x = Maxout2D(16, 2)(x)
pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.1)(x)
x = Maxout2D(16, 2)(x)
pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(x)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# -- location map
x = Convolution2D(8, 3, 3, border_mode='same')(pool3)
x = Convolution2D(4, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = Maxout2D(1, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(4, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = Maxout2D(1, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(4, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = Maxout2D(1, 2)(x)
x = UpSampling2D((2, 2))(x)

x = Convolution2D(4, 3, 3, border_mode='same')(x)
x = Convolution2D(2, 3, 3, border_mode='same')(x)
outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
#loss='binary_crossentropy'
loss=[dice_coef_loss_batchwise, 'binary_crossentropy']
metrics={'outmap': dice_coef, 'outbin': 'accuracy'}
model.compile(optimizer='adam',
              loss=loss,
              loss_weights=[1., 0.01],
              metrics=metrics)

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)    (None, 16, 128, 128)160         input_img[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)    (None, 16, 128, 128)2320        convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)                (None, 16, 128, 128)0           convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# maxout2d_2 (Maxout2D)              (None, 16, 128, 128)544         dropout_1[0][0]
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)               (None, 16, 64, 64)  0           maxout2d_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)    (None, 16, 64, 64)  2320        pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)    (None, 16, 64, 64)  2320        convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)                (None, 16, 64, 64)  0           convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# maxout2d_3 (Maxout2D)              (None, 16, 64, 64)  544         dropout_2[0][0]
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)               (None, 16, 32, 32)  0           maxout2d_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_6 (Convolution2D)    (None, 32, 32, 32)  4640        pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_7 (Convolution2D)    (None, 32, 32, 32)  9248        convolution2d_6[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)                (None, 32, 32, 32)  0           convolution2d_7[0][0]
# ____________________________________________________________________________________________________
# maxout2d_4 (Maxout2D)              (None, 16, 32, 32)  1056        dropout_3[0][0]
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)               (None, 16, 16, 16)  0           maxout2d_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_12 (Convolution2D)   (None, 8, 16, 16)   1160        pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_13 (Convolution2D)   (None, 4, 16, 16)   292         convolution2d_12[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_1 (BatchNormaliz(None, 4, 16, 16)   32          convolution2d_13[0][0]
# ____________________________________________________________________________________________________
# maxout2d_7 (Maxout2D)              (None, 1, 16, 16)   10          batchnormalization_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8 (Convolution2D)    (None, 16, 16, 16)  2320        pool3[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_1 (UpSampling2D)      (None, 1, 32, 32)   0           maxout2d_7[0][0]
# ____________________________________________________________________________________________________
# convolution2d_9 (Convolution2D)    (None, 16, 16, 16)  2320        convolution2d_8[0][0]
# ____________________________________________________________________________________________________
# merge_1 (Merge)                    (None, 17, 32, 32)  0           upsampling2d_1[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_14 (Convolution2D)   (None, 8, 32, 32)   1232        merge_1[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)                (None, 16, 16, 16)  0           convolution2d_9[0][0]
# ____________________________________________________________________________________________________
# convolution2d_15 (Convolution2D)   (None, 4, 32, 32)   292         convolution2d_14[0][0]
# ____________________________________________________________________________________________________
# maxout2d_5 (Maxout2D)              (None, 16, 16, 16)  544         dropout_4[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_2 (BatchNormaliz(None, 4, 32, 32)   64          convolution2d_15[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)               (None, 16, 8, 8)    0           maxout2d_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_10 (Convolution2D)   (None, 16, 8, 8)    2320        pool4[0][0]
# ____________________________________________________________________________________________________
# maxout2d_8 (Maxout2D)              (None, 1, 32, 32)   10          batchnormalization_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_11 (Convolution2D)   (None, 16, 8, 8)    2320        convolution2d_10[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_2 (UpSampling2D)      (None, 1, 64, 64)   0           maxout2d_8[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)                (None, 16, 8, 8)    0           convolution2d_11[0][0]
# ____________________________________________________________________________________________________
# merge_2 (Merge)                    (None, 17, 64, 64)  0           upsampling2d_2[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_16 (Convolution2D)   (None, 8, 64, 64)   1232        merge_2[0][0]
# ____________________________________________________________________________________________________
# maxout2d_6 (Maxout2D)              (None, 16, 8, 8)    544         dropout_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_17 (Convolution2D)   (None, 4, 64, 64)   292         convolution2d_16[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)               (None, 16, 4, 4)    0           maxout2d_6[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_3 (BatchNormaliz(None, 4, 64, 64)   128         convolution2d_17[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)                (None, 256)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                    (None, 32)          8224        flatten_1[0][0]
# ____________________________________________________________________________________________________
# maxout2d_9 (Maxout2D)              (None, 1, 64, 64)   10          batchnormalization_3[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_1 (LeakyReLU)            (None, 32)          0           dense_1[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_3 (UpSampling2D)      (None, 1, 128, 128) 0           maxout2d_9[0][0]
# ____________________________________________________________________________________________________
# convolution2d_18 (Convolution2D)   (None, 4, 128, 128) 40          upsampling2d_3[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                    (None, 16)          528         leakyrelu_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_19 (Convolution2D)   (None, 2, 128, 128) 74          convolution2d_18[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_2 (LeakyReLU)            (None, 16)          0           dense_2[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_2[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 19          convolution2d_19[0][0]
# ====================================================================================================
# Total params: 47176
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {'outmap': Y_train, 'outbin': Y_train_binary},
        batch_size=64,
        validation_data=(X_test, {'outmap': Y_test, 'outbin': Y_test_binary}),
        nb_epoch=60,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    pl.plot(history.history['loss'], label='train loss')
    pl.plot(history.history['val_loss'], c='g', label='val loss')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
        custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.01])
    
    print_summary(model.layers)
# Out:
# Train on 3515 samples, validate on 391 samples
# Epoch 1/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.0608 - outmap_loss: -0.0685 - outbin_loss: 0.7637 - outmap_dice_coef: 0.0685 - outbin_acc: 0.6001Epoch 00000: val_loss improved from inf to -0.09396, saving model to weights.hdf5
# 3515/3515 [==============================] - 42s - loss: -0.0642 - outmap_loss: -0.0718 - outbin_loss: 0.7610 - outmap_dice_coef: 0.0718 - outbin_acc: 0.6014 - val_loss: -0.0940 - val_outmap_loss: -0.1005 - val_outbin_loss: 0.6543 - val_outmap_dice_coef: 0.1005 - val_outbin_acc: 0.6061
# Epoch 2/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.4157 - outmap_loss: -0.4222 - outbin_loss: 0.6439 - outmap_dice_coef: 0.4222 - outbin_acc: 0.6464Epoch 00001: val_loss improved from -0.09396 to -0.44120, saving model to weights.hdf5
# 3515/3515 [==============================] - 41s - loss: -0.4174 - outmap_loss: -0.4238 - outbin_loss: 0.6430 - outmap_dice_coef: 0.4238 - outbin_acc: 0.6475 - val_loss: -0.4412 - val_outmap_loss: -0.4470 - val_outbin_loss: 0.5834 - val_outmap_dice_coef: 0.4470 - val_outbin_acc: 0.7161
# Epoch 3/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.4991 - outmap_loss: -0.5045 - outbin_loss: 0.5355 - outmap_dice_coef: 0.5045 - outbin_acc: 0.7402Epoch 00002: val_loss improved from -0.44120 to -0.44866, saving model to weights.hdf5
# 3515/3515 [==============================] - 44s - loss: -0.4990 - outmap_loss: -0.5043 - outbin_loss: 0.5341 - outmap_dice_coef: 0.5043 - outbin_acc: 0.7408 - val_loss: -0.4487 - val_outmap_loss: -0.4533 - val_outbin_loss: 0.4591 - val_outmap_dice_coef: 0.4533 - val_outbin_acc: 0.7877
# Epoch 4/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.5317 - outmap_loss: -0.5366 - outbin_loss: 0.4890 - outmap_dice_coef: 0.5366 - outbin_acc: 0.7775Epoch 00003: val_loss did not improve
# 3515/3515 [==============================] - 44s - loss: -0.5314 - outmap_loss: -0.5362 - outbin_loss: 0.4857 - outmap_dice_coef: 0.5362 - outbin_acc: 0.7792 - val_loss: -0.3543 - val_outmap_loss: -0.3594 - val_outbin_loss: 0.5063 - val_outmap_dice_coef: 0.3594 - val_outbin_acc: 0.7647
# Epoch 5/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.5540 - outmap_loss: -0.5588 - outbin_loss: 0.4828 - outmap_dice_coef: 0.5588 - outbin_acc: 0.7781Epoch 00004: val_loss did not improve
# 3515/3515 [==============================] - 43s - loss: -0.5540 - outmap_loss: -0.5588 - outbin_loss: 0.4816 - outmap_dice_coef: 0.5588 - outbin_acc: 0.7778 - val_loss: -0.4387 - val_outmap_loss: -0.4429 - val_outbin_loss: 0.4256 - val_outmap_dice_coef: 0.4429 - val_outbin_acc: 0.7928
# Epoch 6/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.5671 - outmap_loss: -0.5715 - outbin_loss: 0.4413 - outmap_dice_coef: 0.5715 - outbin_acc: 0.8041Epoch 00005: val_loss improved from -0.44866 to -0.44876, saving model to weights.hdf5
# 3515/3515 [==============================] - 43s - loss: -0.5675 - outmap_loss: -0.5719 - outbin_loss: 0.4422 - outmap_dice_coef: 0.5719 - outbin_acc: 0.8040 - val_loss: -0.4488 - val_outmap_loss: -0.4529 - val_outbin_loss: 0.4098 - val_outmap_dice_coef: 0.4529 - val_outbin_acc: 0.8133
# Epoch 7/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.5731 - outmap_loss: -0.5774 - outbin_loss: 0.4289 - outmap_dice_coef: 0.5774 - outbin_acc: 0.8163Epoch 00006: val_loss improved from -0.44876 to -0.60945, saving model to weights.hdf5
# 3515/3515 [==============================] - 42s - loss: -0.5733 - outmap_loss: -0.5776 - outbin_loss: 0.4293 - outmap_dice_coef: 0.5776 - outbin_acc: 0.8159 - val_loss: -0.6094 - val_outmap_loss: -0.6133 - val_outbin_loss: 0.3830 - val_outmap_dice_coef: 0.6133 - val_outbin_acc: 0.8261
# Epoch 8/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.5865 - outmap_loss: -0.5906 - outbin_loss: 0.4066 - outmap_dice_coef: 0.5906 - outbin_acc: 0.8255Epoch 00007: val_loss improved from -0.60945 to -0.62921, saving model to weights.hdf5
# 3515/3515 [==============================] - 43s - loss: -0.5870 - outmap_loss: -0.5910 - outbin_loss: 0.4057 - outmap_dice_coef: 0.5910 - outbin_acc: 0.8259 - val_loss: -0.6292 - val_outmap_loss: -0.6330 - val_outbin_loss: 0.3764 - val_outmap_dice_coef: 0.6330 - val_outbin_acc: 0.8312
# Epoch 9/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6007 - outmap_loss: -0.6045 - outbin_loss: 0.3847 - outmap_dice_coef: 0.6045 - outbin_acc: 0.8374Epoch 00008: val_loss did not improve
# 3515/3515 [==============================] - 43s - loss: -0.6007 - outmap_loss: -0.6046 - outbin_loss: 0.3861 - outmap_dice_coef: 0.6046 - outbin_acc: 0.8370 - val_loss: -0.5763 - val_outmap_loss: -0.5800 - val_outbin_loss: 0.3660 - val_outmap_dice_coef: 0.5800 - val_outbin_acc: 0.8517
# Epoch 10/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6173 - outmap_loss: -0.6210 - outbin_loss: 0.3670 - outmap_dice_coef: 0.6210 - outbin_acc: 0.8504Epoch 00009: val_loss improved from -0.62921 to -0.64588, saving model to weights.hdf5
# 3515/3515 [==============================] - 42s - loss: -0.6166 - outmap_loss: -0.6202 - outbin_loss: 0.3665 - outmap_dice_coef: 0.6202 - outbin_acc: 0.8512 - val_loss: -0.6459 - val_outmap_loss: -0.6498 - val_outbin_loss: 0.3871 - val_outmap_dice_coef: 0.6498 - val_outbin_acc: 0.8440
# Epoch 11/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6156 - outmap_loss: -0.6193 - outbin_loss: 0.3711 - outmap_dice_coef: 0.6193 - outbin_acc: 0.8409Epoch 00010: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6151 - outmap_loss: -0.6189 - outbin_loss: 0.3714 - outmap_dice_coef: 0.6189 - outbin_acc: 0.8401 - val_loss: -0.6359 - val_outmap_loss: -0.6396 - val_outbin_loss: 0.3706 - val_outmap_dice_coef: 0.6396 - val_outbin_acc: 0.8542
# Epoch 12/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6235 - outmap_loss: -0.6271 - outbin_loss: 0.3590 - outmap_dice_coef: 0.6271 - outbin_acc: 0.8516Epoch 00011: val_loss improved from -0.64588 to -0.66669, saving model to weights.hdf5
# 3515/3515 [==============================] - 43s - loss: -0.6233 - outmap_loss: -0.6269 - outbin_loss: 0.3595 - outmap_dice_coef: 0.6269 - outbin_acc: 0.8515 - val_loss: -0.6667 - val_outmap_loss: -0.6707 - val_outbin_loss: 0.3989 - val_outmap_dice_coef: 0.6707 - val_outbin_acc: 0.8312
# Epoch 13/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6295 - outmap_loss: -0.6329 - outbin_loss: 0.3465 - outmap_dice_coef: 0.6329 - outbin_acc: 0.8556Epoch 00012: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6288 - outmap_loss: -0.6323 - outbin_loss: 0.3463 - outmap_dice_coef: 0.6323 - outbin_acc: 0.8563 - val_loss: -0.6463 - val_outmap_loss: -0.6496 - val_outbin_loss: 0.3282 - val_outmap_dice_coef: 0.6496 - val_outbin_acc: 0.8696
# Epoch 14/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6372 - outmap_loss: -0.6405 - outbin_loss: 0.3312 - outmap_dice_coef: 0.6405 - outbin_acc: 0.8686Epoch 00013: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6378 - outmap_loss: -0.6411 - outbin_loss: 0.3308 - outmap_dice_coef: 0.6411 - outbin_acc: 0.8686 - val_loss: -0.6621 - val_outmap_loss: -0.6654 - val_outbin_loss: 0.3306 - val_outmap_dice_coef: 0.6654 - val_outbin_acc: 0.8645
# Epoch 15/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6360 - outmap_loss: -0.6393 - outbin_loss: 0.3285 - outmap_dice_coef: 0.6393 - outbin_acc: 0.8692Epoch 00014: val_loss improved from -0.66669 to -0.67447, saving model to weights.hdf5
# 3515/3515 [==============================] - 42s - loss: -0.6370 - outmap_loss: -0.6402 - outbin_loss: 0.3277 - outmap_dice_coef: 0.6402 - outbin_acc: 0.8694 - val_loss: -0.6745 - val_outmap_loss: -0.6779 - val_outbin_loss: 0.3436 - val_outmap_dice_coef: 0.6779 - val_outbin_acc: 0.8517
# Epoch 16/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6467 - outmap_loss: -0.6498 - outbin_loss: 0.3094 - outmap_dice_coef: 0.6498 - outbin_acc: 0.8747Epoch 00015: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6467 - outmap_loss: -0.6498 - outbin_loss: 0.3140 - outmap_dice_coef: 0.6498 - outbin_acc: 0.8731 - val_loss: -0.6702 - val_outmap_loss: -0.6733 - val_outbin_loss: 0.3168 - val_outmap_dice_coef: 0.6733 - val_outbin_acc: 0.8645
# Epoch 17/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6488 - outmap_loss: -0.6519 - outbin_loss: 0.3157 - outmap_dice_coef: 0.6519 - outbin_acc: 0.8689Epoch 00016: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6479 - outmap_loss: -0.6510 - outbin_loss: 0.3159 - outmap_dice_coef: 0.6510 - outbin_acc: 0.8691 - val_loss: -0.6451 - val_outmap_loss: -0.6482 - val_outbin_loss: 0.3149 - val_outmap_dice_coef: 0.6482 - val_outbin_acc: 0.8696
# Epoch 18/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6468 - outmap_loss: -0.6500 - outbin_loss: 0.3221 - outmap_dice_coef: 0.6500 - outbin_acc: 0.8704Epoch 00017: val_loss improved from -0.67447 to -0.67868, saving model to weights.hdf5
# 3515/3515 [==============================] - 42s - loss: -0.6468 - outmap_loss: -0.6500 - outbin_loss: 0.3216 - outmap_dice_coef: 0.6500 - outbin_acc: 0.8706 - val_loss: -0.6787 - val_outmap_loss: -0.6820 - val_outbin_loss: 0.3309 - val_outmap_dice_coef: 0.6820 - val_outbin_acc: 0.8465
# Epoch 19/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6591 - outmap_loss: -0.6622 - outbin_loss: 0.3062 - outmap_dice_coef: 0.6622 - outbin_acc: 0.8756Epoch 00018: val_loss did not improve
# 3515/3515 [==============================] - 43s - loss: -0.6589 - outmap_loss: -0.6619 - outbin_loss: 0.3059 - outmap_dice_coef: 0.6619 - outbin_acc: 0.8768 - val_loss: -0.6702 - val_outmap_loss: -0.6735 - val_outbin_loss: 0.3273 - val_outmap_dice_coef: 0.6735 - val_outbin_acc: 0.8696
# Epoch 20/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6569 - outmap_loss: -0.6599 - outbin_loss: 0.3083 - outmap_dice_coef: 0.6599 - outbin_acc: 0.8727Epoch 00019: val_loss improved from -0.67868 to -0.68797, saving model to weights.hdf5
# 3515/3515 [==============================] - 42s - loss: -0.6570 - outmap_loss: -0.6601 - outbin_loss: 0.3100 - outmap_dice_coef: 0.6601 - outbin_acc: 0.8725 - val_loss: -0.6880 - val_outmap_loss: -0.6911 - val_outbin_loss: 0.3175 - val_outmap_dice_coef: 0.6911 - val_outbin_acc: 0.8696
# Epoch 21/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6646 - outmap_loss: -0.6676 - outbin_loss: 0.2980 - outmap_dice_coef: 0.6676 - outbin_acc: 0.8782Epoch 00020: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6648 - outmap_loss: -0.6678 - outbin_loss: 0.2981 - outmap_dice_coef: 0.6678 - outbin_acc: 0.8785 - val_loss: -0.6721 - val_outmap_loss: -0.6754 - val_outbin_loss: 0.3345 - val_outmap_dice_coef: 0.6754 - val_outbin_acc: 0.8670
# Epoch 22/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6606 - outmap_loss: -0.6637 - outbin_loss: 0.3071 - outmap_dice_coef: 0.6637 - outbin_acc: 0.8750Epoch 00021: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6612 - outmap_loss: -0.6642 - outbin_loss: 0.3064 - outmap_dice_coef: 0.6642 - outbin_acc: 0.8754 - val_loss: -0.6645 - val_outmap_loss: -0.6679 - val_outbin_loss: 0.3451 - val_outmap_dice_coef: 0.6679 - val_outbin_acc: 0.8696
# Epoch 23/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6603 - outmap_loss: -0.6632 - outbin_loss: 0.2847 - outmap_dice_coef: 0.6632 - outbin_acc: 0.8828Epoch 00022: val_loss did not improve
# 3515/3515 [==============================] - 43s - loss: -0.6616 - outmap_loss: -0.6644 - outbin_loss: 0.2838 - outmap_dice_coef: 0.6644 - outbin_acc: 0.8831 - val_loss: -0.6807 - val_outmap_loss: -0.6840 - val_outbin_loss: 0.3295 - val_outmap_dice_coef: 0.6840 - val_outbin_acc: 0.8798
# Epoch 24/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6764 - outmap_loss: -0.6793 - outbin_loss: 0.2934 - outmap_dice_coef: 0.6793 - outbin_acc: 0.8782Epoch 00023: val_loss improved from -0.68797 to -0.70030, saving model to weights.hdf5
# 3515/3515 [==============================] - 42s - loss: -0.6773 - outmap_loss: -0.6802 - outbin_loss: 0.2920 - outmap_dice_coef: 0.6802 - outbin_acc: 0.8788 - val_loss: -0.7003 - val_outmap_loss: -0.7036 - val_outbin_loss: 0.3332 - val_outmap_dice_coef: 0.7036 - val_outbin_acc: 0.8593
# Epoch 25/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6738 - outmap_loss: -0.6766 - outbin_loss: 0.2824 - outmap_dice_coef: 0.6766 - outbin_acc: 0.8863Epoch 00024: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6741 - outmap_loss: -0.6769 - outbin_loss: 0.2824 - outmap_dice_coef: 0.6769 - outbin_acc: 0.8868 - val_loss: -0.6895 - val_outmap_loss: -0.6929 - val_outbin_loss: 0.3388 - val_outmap_dice_coef: 0.6929 - val_outbin_acc: 0.8645
# Epoch 26/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6795 - outmap_loss: -0.6822 - outbin_loss: 0.2663 - outmap_dice_coef: 0.6822 - outbin_acc: 0.8921Epoch 00025: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6794 - outmap_loss: -0.6820 - outbin_loss: 0.2662 - outmap_dice_coef: 0.6820 - outbin_acc: 0.8916 - val_loss: -0.6824 - val_outmap_loss: -0.6864 - val_outbin_loss: 0.3923 - val_outmap_dice_coef: 0.6864 - val_outbin_acc: 0.8440
# Epoch 27/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6792 - outmap_loss: -0.6820 - outbin_loss: 0.2822 - outmap_dice_coef: 0.6820 - outbin_acc: 0.8924Epoch 00026: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6798 - outmap_loss: -0.6826 - outbin_loss: 0.2803 - outmap_dice_coef: 0.6826 - outbin_acc: 0.8933 - val_loss: -0.6988 - val_outmap_loss: -0.7022 - val_outbin_loss: 0.3310 - val_outmap_dice_coef: 0.7022 - val_outbin_acc: 0.8721
# Epoch 28/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6746 - outmap_loss: -0.6773 - outbin_loss: 0.2710 - outmap_dice_coef: 0.6773 - outbin_acc: 0.8927Epoch 00027: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6745 - outmap_loss: -0.6773 - outbin_loss: 0.2718 - outmap_dice_coef: 0.6773 - outbin_acc: 0.8919 - val_loss: -0.6870 - val_outmap_loss: -0.6910 - val_outbin_loss: 0.3951 - val_outmap_dice_coef: 0.6910 - val_outbin_acc: 0.8465
# Epoch 29/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6807 - outmap_loss: -0.6835 - outbin_loss: 0.2782 - outmap_dice_coef: 0.6835 - outbin_acc: 0.8874Epoch 00028: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6804 - outmap_loss: -0.6832 - outbin_loss: 0.2785 - outmap_dice_coef: 0.6832 - outbin_acc: 0.8868 - val_loss: -0.6974 - val_outmap_loss: -0.7007 - val_outbin_loss: 0.3297 - val_outmap_dice_coef: 0.7007 - val_outbin_acc: 0.8670
# Epoch 30/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6851 - outmap_loss: -0.6876 - outbin_loss: 0.2588 - outmap_dice_coef: 0.6876 - outbin_acc: 0.8932Epoch 00029: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6838 - outmap_loss: -0.6864 - outbin_loss: 0.2599 - outmap_dice_coef: 0.6864 - outbin_acc: 0.8930 - val_loss: -0.6623 - val_outmap_loss: -0.6654 - val_outbin_loss: 0.3163 - val_outmap_dice_coef: 0.6654 - val_outbin_acc: 0.8772
# Epoch 31/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6880 - outmap_loss: -0.6905 - outbin_loss: 0.2495 - outmap_dice_coef: 0.6905 - outbin_acc: 0.9031Epoch 00030: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6853 - outmap_loss: -0.6878 - outbin_loss: 0.2507 - outmap_dice_coef: 0.6878 - outbin_acc: 0.9030 - val_loss: -0.6988 - val_outmap_loss: -0.7020 - val_outbin_loss: 0.3169 - val_outmap_dice_coef: 0.7020 - val_outbin_acc: 0.8721
# Epoch 32/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6883 - outmap_loss: -0.6910 - outbin_loss: 0.2646 - outmap_dice_coef: 0.6910 - outbin_acc: 0.8970Epoch 00031: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6882 - outmap_loss: -0.6908 - outbin_loss: 0.2642 - outmap_dice_coef: 0.6908 - outbin_acc: 0.8976 - val_loss: -0.6925 - val_outmap_loss: -0.6958 - val_outbin_loss: 0.3274 - val_outmap_dice_coef: 0.6958 - val_outbin_acc: 0.8619
# Epoch 33/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6787 - outmap_loss: -0.6814 - outbin_loss: 0.2735 - outmap_dice_coef: 0.6814 - outbin_acc: 0.8915Epoch 00032: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6794 - outmap_loss: -0.6821 - outbin_loss: 0.2725 - outmap_dice_coef: 0.6821 - outbin_acc: 0.8916 - val_loss: -0.6884 - val_outmap_loss: -0.6934 - val_outbin_loss: 0.4983 - val_outmap_dice_coef: 0.6934 - val_outbin_acc: 0.8107
# Epoch 34/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6898 - outmap_loss: -0.6924 - outbin_loss: 0.2569 - outmap_dice_coef: 0.6924 - outbin_acc: 0.8967Epoch 00033: val_loss improved from -0.70030 to -0.70540, saving model to weights.hdf5
# 3515/3515 [==============================] - 42s - loss: -0.6896 - outmap_loss: -0.6922 - outbin_loss: 0.2583 - outmap_dice_coef: 0.6922 - outbin_acc: 0.8953 - val_loss: -0.7054 - val_outmap_loss: -0.7093 - val_outbin_loss: 0.3892 - val_outmap_dice_coef: 0.7093 - val_outbin_acc: 0.8619
# Epoch 35/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6900 - outmap_loss: -0.6924 - outbin_loss: 0.2468 - outmap_dice_coef: 0.6924 - outbin_acc: 0.8990Epoch 00034: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6897 - outmap_loss: -0.6922 - outbin_loss: 0.2491 - outmap_dice_coef: 0.6922 - outbin_acc: 0.8984 - val_loss: -0.6749 - val_outmap_loss: -0.6781 - val_outbin_loss: 0.3246 - val_outmap_dice_coef: 0.6781 - val_outbin_acc: 0.8593
# Epoch 36/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6902 - outmap_loss: -0.6927 - outbin_loss: 0.2509 - outmap_dice_coef: 0.6927 - outbin_acc: 0.8996Epoch 00035: val_loss did not improve
# 3515/3515 [==============================] - 43s - loss: -0.6905 - outmap_loss: -0.6930 - outbin_loss: 0.2512 - outmap_dice_coef: 0.6930 - outbin_acc: 0.8984 - val_loss: -0.7051 - val_outmap_loss: -0.7096 - val_outbin_loss: 0.4542 - val_outmap_dice_coef: 0.7096 - val_outbin_acc: 0.8312
# Epoch 37/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7023 - outmap_loss: -0.7048 - outbin_loss: 0.2482 - outmap_dice_coef: 0.7048 - outbin_acc: 0.9062Epoch 00036: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6999 - outmap_loss: -0.7024 - outbin_loss: 0.2494 - outmap_dice_coef: 0.7024 - outbin_acc: 0.9047 - val_loss: -0.6871 - val_outmap_loss: -0.6909 - val_outbin_loss: 0.3756 - val_outmap_dice_coef: 0.6909 - val_outbin_acc: 0.8593
# Epoch 38/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6988 - outmap_loss: -0.7012 - outbin_loss: 0.2405 - outmap_dice_coef: 0.7012 - outbin_acc: 0.9060Epoch 00037: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6990 - outmap_loss: -0.7014 - outbin_loss: 0.2400 - outmap_dice_coef: 0.7014 - outbin_acc: 0.9061 - val_loss: -0.7010 - val_outmap_loss: -0.7047 - val_outbin_loss: 0.3759 - val_outmap_dice_coef: 0.7047 - val_outbin_acc: 0.8491
# Epoch 39/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6992 - outmap_loss: -0.7016 - outbin_loss: 0.2449 - outmap_dice_coef: 0.7016 - outbin_acc: 0.9016Epoch 00038: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.6993 - outmap_loss: -0.7018 - outbin_loss: 0.2439 - outmap_dice_coef: 0.7018 - outbin_acc: 0.9021 - val_loss: -0.7018 - val_outmap_loss: -0.7053 - val_outbin_loss: 0.3558 - val_outmap_dice_coef: 0.7053 - val_outbin_acc: 0.8670
# Epoch 40/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6987 - outmap_loss: -0.7010 - outbin_loss: 0.2316 - outmap_dice_coef: 0.7010 - outbin_acc: 0.9045Epoch 00039: val_loss improved from -0.70540 to -0.70790, saving model to weights.hdf5
# 3515/3515 [==============================] - 42s - loss: -0.6986 - outmap_loss: -0.7010 - outbin_loss: 0.2325 - outmap_dice_coef: 0.7010 - outbin_acc: 0.9041 - val_loss: -0.7079 - val_outmap_loss: -0.7115 - val_outbin_loss: 0.3574 - val_outmap_dice_coef: 0.7115 - val_outbin_acc: 0.8593
# Epoch 41/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7078 - outmap_loss: -0.7101 - outbin_loss: 0.2227 - outmap_dice_coef: 0.7101 - outbin_acc: 0.9141Epoch 00040: val_loss did not improve
# 3515/3515 [==============================] - 41s - loss: -0.7070 - outmap_loss: -0.7092 - outbin_loss: 0.2228 - outmap_dice_coef: 0.7092 - outbin_acc: 0.9141 - val_loss: -0.6944 - val_outmap_loss: -0.6982 - val_outbin_loss: 0.3729 - val_outmap_dice_coef: 0.6982 - val_outbin_acc: 0.8491
# Epoch 42/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7012 - outmap_loss: -0.7034 - outbin_loss: 0.2268 - outmap_dice_coef: 0.7034 - outbin_acc: 0.9126Epoch 00041: val_loss did not improve
# 3515/3515 [==============================] - 41s - loss: -0.7008 - outmap_loss: -0.7030 - outbin_loss: 0.2265 - outmap_dice_coef: 0.7030 - outbin_acc: 0.9132 - val_loss: -0.7054 - val_outmap_loss: -0.7091 - val_outbin_loss: 0.3654 - val_outmap_dice_coef: 0.7091 - val_outbin_acc: 0.8619
# Epoch 43/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7035 - outmap_loss: -0.7058 - outbin_loss: 0.2290 - outmap_dice_coef: 0.7058 - outbin_acc: 0.9086Epoch 00042: val_loss did not improve
# 3515/3515 [==============================] - 41s - loss: -0.7037 - outmap_loss: -0.7060 - outbin_loss: 0.2275 - outmap_dice_coef: 0.7060 - outbin_acc: 0.9090 - val_loss: -0.7043 - val_outmap_loss: -0.7080 - val_outbin_loss: 0.3690 - val_outmap_dice_coef: 0.7080 - val_outbin_acc: 0.8517
# Epoch 44/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.6995 - outmap_loss: -0.7019 - outbin_loss: 0.2365 - outmap_dice_coef: 0.7019 - outbin_acc: 0.9034Epoch 00043: val_loss did not improve
# 3515/3515 [==============================] - 41s - loss: -0.6993 - outmap_loss: -0.7017 - outbin_loss: 0.2362 - outmap_dice_coef: 0.7017 - outbin_acc: 0.9030 - val_loss: -0.6941 - val_outmap_loss: -0.6973 - val_outbin_loss: 0.3232 - val_outmap_dice_coef: 0.6973 - val_outbin_acc: 0.8696
# Epoch 45/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7053 - outmap_loss: -0.7075 - outbin_loss: 0.2182 - outmap_dice_coef: 0.7075 - outbin_acc: 0.9187Epoch 00044: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.7043 - outmap_loss: -0.7065 - outbin_loss: 0.2196 - outmap_dice_coef: 0.7065 - outbin_acc: 0.9181 - val_loss: -0.7041 - val_outmap_loss: -0.7075 - val_outbin_loss: 0.3410 - val_outmap_dice_coef: 0.7075 - val_outbin_acc: 0.8696
# Epoch 46/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7105 - outmap_loss: -0.7126 - outbin_loss: 0.2129 - outmap_dice_coef: 0.7126 - outbin_acc: 0.9158Epoch 00045: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.7105 - outmap_loss: -0.7126 - outbin_loss: 0.2112 - outmap_dice_coef: 0.7126 - outbin_acc: 0.9164 - val_loss: -0.7076 - val_outmap_loss: -0.7110 - val_outbin_loss: 0.3406 - val_outmap_dice_coef: 0.7110 - val_outbin_acc: 0.8645
# Epoch 47/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7037 - outmap_loss: -0.7059 - outbin_loss: 0.2194 - outmap_dice_coef: 0.7059 - outbin_acc: 0.9161Epoch 00046: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.7041 - outmap_loss: -0.7063 - outbin_loss: 0.2188 - outmap_dice_coef: 0.7063 - outbin_acc: 0.9164 - val_loss: -0.7006 - val_outmap_loss: -0.7052 - val_outbin_loss: 0.4553 - val_outmap_dice_coef: 0.7052 - val_outbin_acc: 0.8312
# Epoch 48/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7091 - outmap_loss: -0.7111 - outbin_loss: 0.2033 - outmap_dice_coef: 0.7111 - outbin_acc: 0.9225Epoch 00047: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.7082 - outmap_loss: -0.7103 - outbin_loss: 0.2083 - outmap_dice_coef: 0.7103 - outbin_acc: 0.9209 - val_loss: -0.6860 - val_outmap_loss: -0.6898 - val_outbin_loss: 0.3801 - val_outmap_dice_coef: 0.6898 - val_outbin_acc: 0.8747
# Epoch 49/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7057 - outmap_loss: -0.7079 - outbin_loss: 0.2197 - outmap_dice_coef: 0.7079 - outbin_acc: 0.9109Epoch 00048: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.7059 - outmap_loss: -0.7081 - outbin_loss: 0.2194 - outmap_dice_coef: 0.7081 - outbin_acc: 0.9107 - val_loss: -0.6674 - val_outmap_loss: -0.6707 - val_outbin_loss: 0.3331 - val_outmap_dice_coef: 0.6707 - val_outbin_acc: 0.8645
# Epoch 50/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7164 - outmap_loss: -0.7186 - outbin_loss: 0.2199 - outmap_dice_coef: 0.7186 - outbin_acc: 0.9158Epoch 00049: val_loss improved from -0.70790 to -0.70964, saving model to weights.hdf5
# 3515/3515 [==============================] - 43s - loss: -0.7149 - outmap_loss: -0.7172 - outbin_loss: 0.2203 - outmap_dice_coef: 0.7172 - outbin_acc: 0.9155 - val_loss: -0.7096 - val_outmap_loss: -0.7131 - val_outbin_loss: 0.3440 - val_outmap_dice_coef: 0.7131 - val_outbin_acc: 0.8593
# Epoch 51/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7191 - outmap_loss: -0.7212 - outbin_loss: 0.2150 - outmap_dice_coef: 0.7212 - outbin_acc: 0.9146Epoch 00050: val_loss did not improve
# 3515/3515 [==============================] - 43s - loss: -0.7193 - outmap_loss: -0.7214 - outbin_loss: 0.2134 - outmap_dice_coef: 0.7214 - outbin_acc: 0.9155 - val_loss: -0.6921 - val_outmap_loss: -0.6959 - val_outbin_loss: 0.3820 - val_outmap_dice_coef: 0.6959 - val_outbin_acc: 0.8414
# Epoch 52/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7130 - outmap_loss: -0.7151 - outbin_loss: 0.2124 - outmap_dice_coef: 0.7151 - outbin_acc: 0.9190Epoch 00051: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.7133 - outmap_loss: -0.7154 - outbin_loss: 0.2117 - outmap_dice_coef: 0.7154 - outbin_acc: 0.9192 - val_loss: -0.6920 - val_outmap_loss: -0.6952 - val_outbin_loss: 0.3246 - val_outmap_dice_coef: 0.6952 - val_outbin_acc: 0.8670
# Epoch 53/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7167 - outmap_loss: -0.7188 - outbin_loss: 0.2014 - outmap_dice_coef: 0.7188 - outbin_acc: 0.9242Epoch 00052: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.7166 - outmap_loss: -0.7186 - outbin_loss: 0.2013 - outmap_dice_coef: 0.7186 - outbin_acc: 0.9238 - val_loss: -0.6930 - val_outmap_loss: -0.6966 - val_outbin_loss: 0.3626 - val_outmap_dice_coef: 0.6966 - val_outbin_acc: 0.8696
# Epoch 54/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7176 - outmap_loss: -0.7195 - outbin_loss: 0.1897 - outmap_dice_coef: 0.7195 - outbin_acc: 0.9294Epoch 00053: val_loss did not improve
# 3515/3515 [==============================] - 43s - loss: -0.7173 - outmap_loss: -0.7192 - outbin_loss: 0.1901 - outmap_dice_coef: 0.7192 - outbin_acc: 0.9286 - val_loss: -0.7081 - val_outmap_loss: -0.7117 - val_outbin_loss: 0.3580 - val_outmap_dice_coef: 0.7117 - val_outbin_acc: 0.8517
# Epoch 55/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7120 - outmap_loss: -0.7141 - outbin_loss: 0.2159 - outmap_dice_coef: 0.7141 - outbin_acc: 0.9115Epoch 00054: val_loss did not improve
# 3515/3515 [==============================] - 43s - loss: -0.7126 - outmap_loss: -0.7147 - outbin_loss: 0.2155 - outmap_dice_coef: 0.7147 - outbin_acc: 0.9115 - val_loss: -0.6969 - val_outmap_loss: -0.7009 - val_outbin_loss: 0.4016 - val_outmap_dice_coef: 0.7009 - val_outbin_acc: 0.8542
# Epoch 56/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7133 - outmap_loss: -0.7154 - outbin_loss: 0.2090 - outmap_dice_coef: 0.7154 - outbin_acc: 0.9193Epoch 00055: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.7131 - outmap_loss: -0.7152 - outbin_loss: 0.2090 - outmap_dice_coef: 0.7152 - outbin_acc: 0.9189 - val_loss: -0.7018 - val_outmap_loss: -0.7056 - val_outbin_loss: 0.3825 - val_outmap_dice_coef: 0.7056 - val_outbin_acc: 0.8440
# Epoch 57/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7150 - outmap_loss: -0.7172 - outbin_loss: 0.2160 - outmap_dice_coef: 0.7172 - outbin_acc: 0.9164Epoch 00056: val_loss improved from -0.70964 to -0.70993, saving model to weights.hdf5
# 3515/3515 [==============================] - 43s - loss: -0.7145 - outmap_loss: -0.7166 - outbin_loss: 0.2157 - outmap_dice_coef: 0.7166 - outbin_acc: 0.9166 - val_loss: -0.7099 - val_outmap_loss: -0.7136 - val_outbin_loss: 0.3669 - val_outmap_dice_coef: 0.7136 - val_outbin_acc: 0.8542
# Epoch 58/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7202 - outmap_loss: -0.7222 - outbin_loss: 0.2028 - outmap_dice_coef: 0.7222 - outbin_acc: 0.9207Epoch 00057: val_loss did not improve
# 3515/3515 [==============================] - 43s - loss: -0.7193 - outmap_loss: -0.7213 - outbin_loss: 0.2028 - outmap_dice_coef: 0.7213 - outbin_acc: 0.9203 - val_loss: -0.6984 - val_outmap_loss: -0.7017 - val_outbin_loss: 0.3312 - val_outmap_dice_coef: 0.7017 - val_outbin_acc: 0.8645
# Epoch 59/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7221 - outmap_loss: -0.7240 - outbin_loss: 0.1887 - outmap_dice_coef: 0.7240 - outbin_acc: 0.9268Epoch 00058: val_loss improved from -0.70993 to -0.71033, saving model to weights.hdf5
# 3515/3515 [==============================] - 42s - loss: -0.7222 - outmap_loss: -0.7241 - outbin_loss: 0.1888 - outmap_dice_coef: 0.7241 - outbin_acc: 0.9263 - val_loss: -0.7103 - val_outmap_loss: -0.7138 - val_outbin_loss: 0.3476 - val_outmap_dice_coef: 0.7138 - val_outbin_acc: 0.8517
# Epoch 60/60
# 3456/3515 [============================>.] - ETA: 0s - loss: -0.7165 - outmap_loss: -0.7183 - outbin_loss: 0.1811 - outmap_dice_coef: 0.7183 - outbin_acc: 0.9303Epoch 00059: val_loss did not improve
# 3515/3515 [==============================] - 42s - loss: -0.7178 - outmap_loss: -0.7196 - outbin_loss: 0.1823 - outmap_dice_coef: 0.7196 - outbin_acc: 0.9303 - val_loss: -0.7031 - val_outmap_loss: -0.7072 - val_outbin_loss: 0.4092 - val_outmap_dice_coef: 0.7072 - val_outbin_acc: 0.8465

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights.hdf5'))

# %%
conv1 = model.layers[1].output
_f = K.function([K.learning_phase(), input_img], [conv1])
_convout = _f([0, X_test[:1]])[0]
print _convout.shape

maxout1 = model.layers[3].output
_f = K.function([K.learning_phase(), input_img], [maxout1])
_maxout = _f([0, X_test[:1]])[0]
print _maxout.shape

pl.figure()
pl.imshow(_convout[0, 0], interpolation='nearest')
pl.colorbar()
pl.figure()
pl.imshow(_maxout[0, 0], interpolation='nearest')
pl.colorbar()
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/backend/theano_backend.py:514: UserWarning: theano.function was asked to create a function computing outputs given certain inputs, but the provided input variable at index 0 is not part of the computational graph needed to compute the outputs: keras_learning_phase.
# To make this warning into an error, you can pass the parameter on_unused_input='raise' to theano.function. To disable it completely, use on_unused_input='ignore'.
#   **kwargs)
# (1, 16, 128, 128)
# (1, 16, 128, 128)
# <matplotlib.colorbar.Colorbar instance at 0x7f8bad8c6f38>
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
def predict(X):
    Y_pred, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > 0.3
    for i in range(Y_pred.shape[0]):
        # Clear prediction where we detect to little pixels
        # Figure it out by
        # pl.hist(np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1))
        #if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < 0.2:
        if np.sum(Y_pred[i]) < 150:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test)
Y_full_pred, Y_full_pred_proba, Y_full_pred_binary = predict(X_full)

print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "avg test set score : ", utils.average_dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
print "avg full set score : ", utils.average_dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.708020819763
# avg test set score :  0.78837157697
# full set score :  0.65699990614
# avg full set score :  0.747385437207

# %%
_ = pl.hist(Y_pred_binary)

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[55:60]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 0
img, pred_map = dream_output(Y_full[i])
pl.figure(figsize=(12, 4))
pl.subplot(131)
pl.imshow(Y_full[i].squeeze())
pl.subplot(132)
pl.imshow(img, cmap=cm.gray)
pl.subplot(133)
pl.imshow(pred_map.squeeze())

# %%
# Dream for the binary output
def dream_binoutput(output):
    
    layer_output = layer_dict['outbin'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output - layer_output[:, 0]))
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    
    step = 0.1
    for i in range(40):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    _, model_pred = model.predict(img[None,None,:,:])
    return img, model_pred

img, model_pred = dream_binoutput(1)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
img, model_pred = dream_binoutput(0)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
def dream_layer_filter(layer_name, filter_index):

    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(8):
        pl.subplot(2, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
if True:
    import cv2
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(50,50))
    
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    test_fnames = _d['test_fnames']
    Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:])
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
        imre = cv2.morphologyEx(imre, cv2.MORPH_CLOSE, kernel)
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
        
        if i % 10 == 0:
            print '\r%d / %d' % (i, len(test_fnames)),
            sys.stdout.flush()
# Out:
# 5500 / 5508

# %% [markdown]
# ## Stats on predicted masks

# %%
# on Y_full
nbp_pixels = np.sum(np.sum(np.sum(Y_full, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
