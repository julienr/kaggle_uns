# %% [markdown]
# without per-patient CV

# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']
X_pids = _d['pids']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
# Out:
# (3906, 128, 128)
# (3906, 128, 128)

# %%
# Split patients in train/test
train_pids, test_pids = train_test_split(np.unique(X_pids), test_size=0.04)
print train_pids
print test_pids
# Out:
# [33  7 17 29 21 15 25 35 40 47 14 32 13 19  2 12 41 37 16 31 46 27 18 28  1
#  22 23 39  8 34  6  4 44  5 38  3 10 45 30 42 24 11 43  9 36]
# [26 20]

# %%
if False:
    train_indices = np.flatnonzero(np.in1d(X_pids, train_pids))
    test_indices = np.flatnonzero(np.in1d(X_pids, test_pids))
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]
else:
    nsamples = X.shape[0]

    #train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]

# %%
print X_train.shape
print Y_train.shape
print X_test.shape
print X_train.min(), X_train.max()
# Out:
# (3515, 1, 128, 128)
# (3515, 1, 128, 128)
# (391, 1, 128, 128)
# 0.0 1.0

# %%
#pl.imshow(X_train[0].squeeze())
pl.imshow(Y_train[0].squeeze())
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float32'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense
from keras.layers import LeakyReLU, BatchNormalization
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
from keras.layers import Layer, InputSpec
import keras.initializations
import keras.backend as K

class Maxout2D(Layer):
    def __init__(self, output_dim, cardinality, init='glorot_uniform', **kwargs):
        super(Maxout2D, self).__init__(**kwargs)
        # the k of the maxout paper
        self.cardinality = cardinality
        # the m of the maxout paper
        self.output_dim = output_dim
        self.init = keras.initializations.get(init)
    
    def build(self, input_shape):
        self.input_dim = input_shape[1]
        self.input_spec = [InputSpec(dtype=K.floatx(),
                                     shape=(None, input_shape[1], input_shape[2], input_shape[3]))]
        self.W = self.init((self.input_dim, self.output_dim, self.cardinality),
                           name='{}_W'.format(self.name))
        self.b = K.zeros((self.output_dim, self.cardinality))
        self.trainable_weights = [self.W, self.b]
              
    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        # flatten the spatial dimensions
        flat_x = K.reshape(x, (-1, input_shape[1], input_shape[2] * input_shape[3]))
        output = K.dot(
            K.permute_dimensions(flat_x, (0, 2, 1)),
            K.permute_dimensions(self.W, (1, 0, 2))
        )
        output += K.reshape(self.b, (1, 1, self.output_dim, self.cardinality))
        output = K.max(output, axis=3)
        output = output.transpose(0, 2, 1)
        output = K.reshape(output, (-1, self.output_dim, input_shape[2], input_shape[3]))
        return output
    
    def get_output_shape_for(self, input_shape):
        return (input_shape[0], self.output_dim, input_shape[2], input_shape[3])
    
    def get_config(self):
        config = {
            'output_dim': self.output_dim,
            'cardinality': self.cardinality
        }
        base_config = super(Maxout2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))
    
input_img = Input(shape=(3, 16, 16))
x = Convolution2D(16, 3, 3, border_mode='same')(input_img)
x = Maxout2D(5, 7)(x)

model = Model(input=input_img, output=x)
model.compile(optimizer='adam', loss='mse')
print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)               (None, 3, 16, 16)   0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)    (None, 16, 16, 16)  448         input_1[0][0]
# ____________________________________________________________________________________________________
# maxout2d_1 (Maxout2D)              (None, 5, 16, 16)   595         convolution2d_1[0][0]
# ====================================================================================================
# Total params: 1043
# ____________________________________________________________________________________________________

# %%
# https://www.kaggle.com/c/ultrasound-nerve-segmentation/forums/t/21358/0-57-deep-learning-keras-tutorial
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def dice_coef_batchwise(y_true, y_pred):
    y_true_f = K.batch_flatten(y_true)
    y_pred_f = K.batch_flatten(y_pred)
    intersection = 2. * K.sum(y_true_f * y_pred_f, axis=1, keepdims=True) + smooth
    union = K.sum(y_true_f, axis=1, keepdims=True) + \
            K.sum(y_pred_f, axis=1, keepdims=True) + \
            smooth
    return K.mean(intersection / union)

def dice_coef_loss_batchwise(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
input_img = Input(shape=input_shape, name='input_img')
x = Convolution2D(32, 3, 3, border_mode='same')(input_img)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(16, 2)(x)
pool1 = x = MaxPooling2D((2, 2), name='pool1')(x)

x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(16, 2)(x)
pool2 = x = MaxPooling2D((2, 2), name='pool2')(x)

x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Dropout(0.1)(x)
x = Maxout2D(16, 2)(x)
pool3 = x = MaxPooling2D((2, 2), name='pool3')(x)

# -- binary presence part
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.1)(x)
x = Maxout2D(16, 2)(x)
pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.1)(x)
x = Maxout2D(16, 2)(x)
#x = BatchNormalization()(x)
pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(x)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# -- location map
x = Convolution2D(8, 3, 3, border_mode='same')(pool3)
x = Convolution2D(4, 3, 3, border_mode='same')(x)
x = Maxout2D(1, 2)(x)
#x = BatchNormalization()(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(4, 3, 3, border_mode='same')(x)
x = Maxout2D(1, 2)(x)
#x = BatchNormalization()(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(4, 3, 3, border_mode='same')(x)
x = Maxout2D(1, 2)(x)
#x = BatchNormalization()(x)
x = UpSampling2D((2, 2))(x)

x = Convolution2D(4, 3, 3, border_mode='same')(x)
x = Convolution2D(4, 3, 3, border_mode='same')(x)
outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
loss='binary_crossentropy'
#loss=[dice_coef_loss_batchwise, 'binary_crossentropy']
metrics={'outmap': dice_coef, 'outbin': 'accuracy'}
model.compile(optimizer='adam',
              loss=loss,
              loss_weights=[1., 0.01],
              metrics=metrics)

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_20 (Convolution2D)   (None, 32, 128, 128)320         input_img[0][0]
# ____________________________________________________________________________________________________
# convolution2d_21 (Convolution2D)   (None, 32, 128, 128)9248        convolution2d_20[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)                (None, 32, 128, 128)0           convolution2d_21[0][0]
# ____________________________________________________________________________________________________
# maxout2d_10 (Maxout2D)             (None, 16, 128, 128)1056        dropout_6[0][0]
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)               (None, 16, 64, 64)  0           maxout2d_10[0][0]
# ____________________________________________________________________________________________________
# convolution2d_22 (Convolution2D)   (None, 32, 64, 64)  4640        pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_23 (Convolution2D)   (None, 32, 64, 64)  9248        convolution2d_22[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)                (None, 32, 64, 64)  0           convolution2d_23[0][0]
# ____________________________________________________________________________________________________
# maxout2d_11 (Maxout2D)             (None, 16, 64, 64)  1056        dropout_7[0][0]
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)               (None, 16, 32, 32)  0           maxout2d_11[0][0]
# ____________________________________________________________________________________________________
# convolution2d_24 (Convolution2D)   (None, 32, 32, 32)  4640        pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_25 (Convolution2D)   (None, 32, 32, 32)  9248        convolution2d_24[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)                (None, 32, 32, 32)  0           convolution2d_25[0][0]
# ____________________________________________________________________________________________________
# maxout2d_12 (Maxout2D)             (None, 16, 32, 32)  1056        dropout_8[0][0]
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)               (None, 16, 16, 16)  0           maxout2d_12[0][0]
# ____________________________________________________________________________________________________
# convolution2d_30 (Convolution2D)   (None, 8, 16, 16)   1160        pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_26 (Convolution2D)   (None, 16, 16, 16)  2320        pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_31 (Convolution2D)   (None, 4, 16, 16)   292         convolution2d_30[0][0]
# ____________________________________________________________________________________________________
# convolution2d_27 (Convolution2D)   (None, 16, 16, 16)  2320        convolution2d_26[0][0]
# ____________________________________________________________________________________________________
# maxout2d_15 (Maxout2D)             (None, 1, 16, 16)   10          convolution2d_31[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)                (None, 16, 16, 16)  0           convolution2d_27[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_4 (UpSampling2D)      (None, 1, 32, 32)   0           maxout2d_15[0][0]
# ____________________________________________________________________________________________________
# maxout2d_13 (Maxout2D)             (None, 16, 16, 16)  544         dropout_9[0][0]
# ____________________________________________________________________________________________________
# merge_3 (Merge)                    (None, 17, 32, 32)  0           upsampling2d_4[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_32 (Convolution2D)   (None, 8, 32, 32)   1232        merge_3[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)               (None, 16, 8, 8)    0           maxout2d_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_28 (Convolution2D)   (None, 16, 8, 8)    2320        pool4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_33 (Convolution2D)   (None, 4, 32, 32)   292         convolution2d_32[0][0]
# ____________________________________________________________________________________________________
# convolution2d_29 (Convolution2D)   (None, 16, 8, 8)    2320        convolution2d_28[0][0]
# ____________________________________________________________________________________________________
# maxout2d_16 (Maxout2D)             (None, 1, 32, 32)   10          convolution2d_33[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)               (None, 16, 8, 8)    0           convolution2d_29[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_5 (UpSampling2D)      (None, 1, 64, 64)   0           maxout2d_16[0][0]
# ____________________________________________________________________________________________________
# maxout2d_14 (Maxout2D)             (None, 16, 8, 8)    544         dropout_10[0][0]
# ____________________________________________________________________________________________________
# merge_4 (Merge)                    (None, 17, 64, 64)  0           upsampling2d_5[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_34 (Convolution2D)   (None, 8, 64, 64)   1232        merge_4[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)               (None, 16, 4, 4)    0           maxout2d_14[0][0]
# ____________________________________________________________________________________________________
# convolution2d_35 (Convolution2D)   (None, 4, 64, 64)   292         convolution2d_34[0][0]
# ____________________________________________________________________________________________________
# flatten_2 (Flatten)                (None, 256)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# dense_3 (Dense)                    (None, 32)          8224        flatten_2[0][0]
# ____________________________________________________________________________________________________
# maxout2d_17 (Maxout2D)             (None, 1, 64, 64)   10          convolution2d_35[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_3 (LeakyReLU)            (None, 32)          0           dense_3[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_6 (UpSampling2D)      (None, 1, 128, 128) 0           maxout2d_17[0][0]
# ____________________________________________________________________________________________________
# convolution2d_36 (Convolution2D)   (None, 4, 128, 128) 40          upsampling2d_6[0][0]
# ____________________________________________________________________________________________________
# dense_4 (Dense)                    (None, 16)          528         leakyrelu_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_37 (Convolution2D)   (None, 4, 128, 128) 148         convolution2d_36[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_4 (LeakyReLU)            (None, 16)          0           dense_4[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_4[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 37          convolution2d_37[0][0]
# ====================================================================================================
# Total params: 64404
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {'outmap': Y_train, 'outbin': Y_train_binary},
        batch_size=64,
        validation_data=(X_test, {'outmap': Y_test, 'outbin': Y_test_binary}),
        nb_epoch=100,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    pl.plot(history.history['loss'], label='train loss')
    pl.plot(history.history['val_loss'], c='g', label='val loss')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
        custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.01])
    
    print_summary(model.layers)
# Out:
# Train on 3515 samples, validate on 391 samples
# Epoch 1/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0910 - outmap_loss: 0.0823 - outbin_loss: 0.8769 - outmap_dice_coef: 0.0088 - outbin_acc: 0.5697Epoch 00000: val_loss improved from inf to 0.08217, saving model to weights.hdf5
# 3515/3515 [==============================] - 37s - loss: 0.0905 - outmap_loss: 0.0818 - outbin_loss: 0.8726 - outmap_dice_coef: 0.0091 - outbin_acc: 0.5713 - val_loss: 0.0822 - val_outmap_loss: 0.0754 - val_outbin_loss: 0.6803 - val_outmap_dice_coef: 0.0312 - val_outbin_acc: 0.5882
# Epoch 2/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0618 - outmap_loss: 0.0552 - outbin_loss: 0.6588 - outmap_dice_coef: 0.0276 - outbin_acc: 0.6175Epoch 00001: val_loss improved from 0.08217 to 0.07513, saving model to weights.hdf5
# 3515/3515 [==============================] - 37s - loss: 0.0620 - outmap_loss: 0.0554 - outbin_loss: 0.6605 - outmap_dice_coef: 0.0281 - outbin_acc: 0.6148 - val_loss: 0.0751 - val_outmap_loss: 0.0688 - val_outbin_loss: 0.6279 - val_outmap_dice_coef: 0.0495 - val_outbin_acc: 0.6266
# Epoch 3/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0540 - outmap_loss: 0.0480 - outbin_loss: 0.5972 - outmap_dice_coef: 0.0557 - outbin_acc: 0.6791Epoch 00002: val_loss improved from 0.07513 to 0.04657, saving model to weights.hdf5
# 3515/3515 [==============================] - 38s - loss: 0.0539 - outmap_loss: 0.0479 - outbin_loss: 0.5980 - outmap_dice_coef: 0.0565 - outbin_acc: 0.6788 - val_loss: 0.0466 - val_outmap_loss: 0.0411 - val_outbin_loss: 0.5456 - val_outmap_dice_coef: 0.1008 - val_outbin_acc: 0.7366
# Epoch 4/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0453 - outmap_loss: 0.0398 - outbin_loss: 0.5492 - outmap_dice_coef: 0.1345 - outbin_acc: 0.7384Epoch 00003: val_loss improved from 0.04657 to 0.04107, saving model to weights.hdf5
# 3515/3515 [==============================] - 37s - loss: 0.0451 - outmap_loss: 0.0397 - outbin_loss: 0.5478 - outmap_dice_coef: 0.1356 - outbin_acc: 0.7403 - val_loss: 0.0411 - val_outmap_loss: 0.0358 - val_outbin_loss: 0.5255 - val_outmap_dice_coef: 0.1784 - val_outbin_acc: 0.7468
# Epoch 5/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0391 - outmap_loss: 0.0342 - outbin_loss: 0.4887 - outmap_dice_coef: 0.2132 - outbin_acc: 0.7746Epoch 00004: val_loss improved from 0.04107 to 0.03635, saving model to weights.hdf5
# 3515/3515 [==============================] - 36s - loss: 0.0392 - outmap_loss: 0.0343 - outbin_loss: 0.4892 - outmap_dice_coef: 0.2138 - outbin_acc: 0.7744 - val_loss: 0.0364 - val_outmap_loss: 0.0316 - val_outbin_loss: 0.4768 - val_outmap_dice_coef: 0.2592 - val_outbin_acc: 0.7826
# Epoch 6/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0370 - outmap_loss: 0.0324 - outbin_loss: 0.4648 - outmap_dice_coef: 0.2535 - outbin_acc: 0.7917Epoch 00005: val_loss improved from 0.03635 to 0.03424, saving model to weights.hdf5
# 3515/3515 [==============================] - 36s - loss: 0.0369 - outmap_loss: 0.0323 - outbin_loss: 0.4622 - outmap_dice_coef: 0.2550 - outbin_acc: 0.7935 - val_loss: 0.0342 - val_outmap_loss: 0.0297 - val_outbin_loss: 0.4554 - val_outmap_dice_coef: 0.2973 - val_outbin_acc: 0.7775
# Epoch 7/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0338 - outmap_loss: 0.0294 - outbin_loss: 0.4372 - outmap_dice_coef: 0.3141 - outbin_acc: 0.8099Epoch 00006: val_loss improved from 0.03424 to 0.03403, saving model to weights.hdf5
# 3515/3515 [==============================] - 36s - loss: 0.0337 - outmap_loss: 0.0293 - outbin_loss: 0.4369 - outmap_dice_coef: 0.3149 - outbin_acc: 0.8097 - val_loss: 0.0340 - val_outmap_loss: 0.0295 - val_outbin_loss: 0.4495 - val_outmap_dice_coef: 0.3097 - val_outbin_acc: 0.7903
# Epoch 8/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0326 - outmap_loss: 0.0285 - outbin_loss: 0.4098 - outmap_dice_coef: 0.3311 - outbin_acc: 0.8200Epoch 00007: val_loss improved from 0.03403 to 0.03210, saving model to weights.hdf5
# 3515/3515 [==============================] - 37s - loss: 0.0325 - outmap_loss: 0.0284 - outbin_loss: 0.4094 - outmap_dice_coef: 0.3313 - outbin_acc: 0.8208 - val_loss: 0.0321 - val_outmap_loss: 0.0278 - val_outbin_loss: 0.4266 - val_outmap_dice_coef: 0.3307 - val_outbin_acc: 0.8082
# Epoch 9/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0311 - outmap_loss: 0.0273 - outbin_loss: 0.3875 - outmap_dice_coef: 0.3549 - outbin_acc: 0.8383Epoch 00008: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0314 - outmap_loss: 0.0275 - outbin_loss: 0.3885 - outmap_dice_coef: 0.3532 - outbin_acc: 0.8367 - val_loss: 0.0345 - val_outmap_loss: 0.0303 - val_outbin_loss: 0.4245 - val_outmap_dice_coef: 0.3472 - val_outbin_acc: 0.8056
# Epoch 10/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0308 - outmap_loss: 0.0269 - outbin_loss: 0.3883 - outmap_dice_coef: 0.3665 - outbin_acc: 0.8296Epoch 00009: val_loss improved from 0.03210 to 0.03066, saving model to weights.hdf5
# 3515/3515 [==============================] - 36s - loss: 0.0308 - outmap_loss: 0.0270 - outbin_loss: 0.3881 - outmap_dice_coef: 0.3659 - outbin_acc: 0.8304 - val_loss: 0.0307 - val_outmap_loss: 0.0266 - val_outbin_loss: 0.4047 - val_outmap_dice_coef: 0.3625 - val_outbin_acc: 0.8286
# Epoch 11/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0300 - outmap_loss: 0.0262 - outbin_loss: 0.3806 - outmap_dice_coef: 0.3740 - outbin_acc: 0.8348Epoch 00010: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0301 - outmap_loss: 0.0263 - outbin_loss: 0.3802 - outmap_dice_coef: 0.3750 - outbin_acc: 0.8353 - val_loss: 0.0318 - val_outmap_loss: 0.0282 - val_outbin_loss: 0.3645 - val_outmap_dice_coef: 0.3711 - val_outbin_acc: 0.8235
# Epoch 12/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0293 - outmap_loss: 0.0256 - outbin_loss: 0.3699 - outmap_dice_coef: 0.3903 - outbin_acc: 0.8388Epoch 00011: val_loss improved from 0.03066 to 0.02886, saving model to weights.hdf5
# 3515/3515 [==============================] - 37s - loss: 0.0294 - outmap_loss: 0.0256 - outbin_loss: 0.3714 - outmap_dice_coef: 0.3906 - outbin_acc: 0.8370 - val_loss: 0.0289 - val_outmap_loss: 0.0252 - val_outbin_loss: 0.3708 - val_outmap_dice_coef: 0.4168 - val_outbin_acc: 0.8133
# Epoch 13/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0289 - outmap_loss: 0.0253 - outbin_loss: 0.3576 - outmap_dice_coef: 0.3991 - outbin_acc: 0.8484Epoch 00012: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0290 - outmap_loss: 0.0254 - outbin_loss: 0.3587 - outmap_dice_coef: 0.3996 - outbin_acc: 0.8486 - val_loss: 0.0290 - val_outmap_loss: 0.0253 - val_outbin_loss: 0.3621 - val_outmap_dice_coef: 0.4074 - val_outbin_acc: 0.8517
# Epoch 14/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0282 - outmap_loss: 0.0247 - outbin_loss: 0.3498 - outmap_dice_coef: 0.4110 - outbin_acc: 0.8553Epoch 00013: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0281 - outmap_loss: 0.0246 - outbin_loss: 0.3488 - outmap_dice_coef: 0.4114 - outbin_acc: 0.8558 - val_loss: 0.0294 - val_outmap_loss: 0.0258 - val_outbin_loss: 0.3566 - val_outmap_dice_coef: 0.3915 - val_outbin_acc: 0.8338
# Epoch 15/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0279 - outmap_loss: 0.0244 - outbin_loss: 0.3520 - outmap_dice_coef: 0.4169 - outbin_acc: 0.8484Epoch 00014: val_loss improved from 0.02886 to 0.02726, saving model to weights.hdf5
# 3515/3515 [==============================] - 36s - loss: 0.0278 - outmap_loss: 0.0243 - outbin_loss: 0.3502 - outmap_dice_coef: 0.4181 - outbin_acc: 0.8492 - val_loss: 0.0273 - val_outmap_loss: 0.0235 - val_outbin_loss: 0.3749 - val_outmap_dice_coef: 0.4220 - val_outbin_acc: 0.8159
# Epoch 16/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0269 - outmap_loss: 0.0235 - outbin_loss: 0.3397 - outmap_dice_coef: 0.4332 - outbin_acc: 0.8637Epoch 00015: val_loss did not improve
# 3515/3515 [==============================] - 37s - loss: 0.0272 - outmap_loss: 0.0237 - outbin_loss: 0.3452 - outmap_dice_coef: 0.4325 - outbin_acc: 0.8609 - val_loss: 0.0283 - val_outmap_loss: 0.0247 - val_outbin_loss: 0.3643 - val_outmap_dice_coef: 0.4126 - val_outbin_acc: 0.8286
# Epoch 17/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0275 - outmap_loss: 0.0241 - outbin_loss: 0.3371 - outmap_dice_coef: 0.4242 - outbin_acc: 0.8628Epoch 00016: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0276 - outmap_loss: 0.0242 - outbin_loss: 0.3364 - outmap_dice_coef: 0.4244 - outbin_acc: 0.8620 - val_loss: 0.0282 - val_outmap_loss: 0.0245 - val_outbin_loss: 0.3704 - val_outmap_dice_coef: 0.4165 - val_outbin_acc: 0.8465
# Epoch 18/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0264 - outmap_loss: 0.0231 - outbin_loss: 0.3381 - outmap_dice_coef: 0.4411 - outbin_acc: 0.8605Epoch 00017: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0265 - outmap_loss: 0.0232 - outbin_loss: 0.3391 - outmap_dice_coef: 0.4412 - outbin_acc: 0.8597 - val_loss: 0.0275 - val_outmap_loss: 0.0234 - val_outbin_loss: 0.4146 - val_outmap_dice_coef: 0.4503 - val_outbin_acc: 0.8184
# Epoch 19/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0263 - outmap_loss: 0.0231 - outbin_loss: 0.3206 - outmap_dice_coef: 0.4466 - outbin_acc: 0.8657Epoch 00018: val_loss improved from 0.02726 to 0.02639, saving model to weights.hdf5
# 3515/3515 [==============================] - 36s - loss: 0.0262 - outmap_loss: 0.0230 - outbin_loss: 0.3195 - outmap_dice_coef: 0.4473 - outbin_acc: 0.8663 - val_loss: 0.0264 - val_outmap_loss: 0.0227 - val_outbin_loss: 0.3686 - val_outmap_dice_coef: 0.4506 - val_outbin_acc: 0.8338
# Epoch 20/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0256 - outmap_loss: 0.0224 - outbin_loss: 0.3270 - outmap_dice_coef: 0.4599 - outbin_acc: 0.8634Epoch 00019: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0257 - outmap_loss: 0.0224 - outbin_loss: 0.3266 - outmap_dice_coef: 0.4599 - outbin_acc: 0.8632 - val_loss: 0.0289 - val_outmap_loss: 0.0254 - val_outbin_loss: 0.3486 - val_outmap_dice_coef: 0.4200 - val_outbin_acc: 0.8593
# Epoch 21/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0262 - outmap_loss: 0.0230 - outbin_loss: 0.3241 - outmap_dice_coef: 0.4505 - outbin_acc: 0.8568Epoch 00020: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0262 - outmap_loss: 0.0230 - outbin_loss: 0.3232 - outmap_dice_coef: 0.4509 - outbin_acc: 0.8575 - val_loss: 0.0266 - val_outmap_loss: 0.0231 - val_outbin_loss: 0.3416 - val_outmap_dice_coef: 0.4498 - val_outbin_acc: 0.8593
# Epoch 22/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0257 - outmap_loss: 0.0226 - outbin_loss: 0.3104 - outmap_dice_coef: 0.4586 - outbin_acc: 0.8718Epoch 00021: val_loss improved from 0.02639 to 0.02622, saving model to weights.hdf5
# 3515/3515 [==============================] - 37s - loss: 0.0256 - outmap_loss: 0.0225 - outbin_loss: 0.3095 - outmap_dice_coef: 0.4586 - outbin_acc: 0.8723 - val_loss: 0.0262 - val_outmap_loss: 0.0227 - val_outbin_loss: 0.3470 - val_outmap_dice_coef: 0.4658 - val_outbin_acc: 0.8517
# Epoch 23/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0253 - outmap_loss: 0.0222 - outbin_loss: 0.3068 - outmap_dice_coef: 0.4673 - outbin_acc: 0.8753Epoch 00022: val_loss improved from 0.02622 to 0.02489, saving model to weights.hdf5
# 3515/3515 [==============================] - 36s - loss: 0.0251 - outmap_loss: 0.0221 - outbin_loss: 0.3045 - outmap_dice_coef: 0.4662 - outbin_acc: 0.8765 - val_loss: 0.0249 - val_outmap_loss: 0.0215 - val_outbin_loss: 0.3393 - val_outmap_dice_coef: 0.4847 - val_outbin_acc: 0.8645
# Epoch 24/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0254 - outmap_loss: 0.0222 - outbin_loss: 0.3192 - outmap_dice_coef: 0.4676 - outbin_acc: 0.8646Epoch 00023: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0255 - outmap_loss: 0.0223 - outbin_loss: 0.3202 - outmap_dice_coef: 0.4684 - outbin_acc: 0.8643 - val_loss: 0.0271 - val_outmap_loss: 0.0236 - val_outbin_loss: 0.3510 - val_outmap_dice_coef: 0.4587 - val_outbin_acc: 0.8542
# Epoch 25/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0237 - outmap_loss: 0.0208 - outbin_loss: 0.2903 - outmap_dice_coef: 0.4980 - outbin_acc: 0.8874Epoch 00024: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0237 - outmap_loss: 0.0208 - outbin_loss: 0.2904 - outmap_dice_coef: 0.4978 - outbin_acc: 0.8873 - val_loss: 0.0255 - val_outmap_loss: 0.0217 - val_outbin_loss: 0.3767 - val_outmap_dice_coef: 0.4863 - val_outbin_acc: 0.8363
# Epoch 26/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0234 - outmap_loss: 0.0205 - outbin_loss: 0.2863 - outmap_dice_coef: 0.4985 - outbin_acc: 0.8793Epoch 00025: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0235 - outmap_loss: 0.0207 - outbin_loss: 0.2868 - outmap_dice_coef: 0.4980 - outbin_acc: 0.8788 - val_loss: 0.0255 - val_outmap_loss: 0.0219 - val_outbin_loss: 0.3556 - val_outmap_dice_coef: 0.4692 - val_outbin_acc: 0.8491
# Epoch 27/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0235 - outmap_loss: 0.0206 - outbin_loss: 0.2917 - outmap_dice_coef: 0.4980 - outbin_acc: 0.8851Epoch 00026: val_loss improved from 0.02489 to 0.02382, saving model to weights.hdf5
# 3515/3515 [==============================] - 36s - loss: 0.0236 - outmap_loss: 0.0207 - outbin_loss: 0.2901 - outmap_dice_coef: 0.4981 - outbin_acc: 0.8859 - val_loss: 0.0238 - val_outmap_loss: 0.0207 - val_outbin_loss: 0.3087 - val_outmap_dice_coef: 0.5063 - val_outbin_acc: 0.8696
# Epoch 28/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0233 - outmap_loss: 0.0205 - outbin_loss: 0.2851 - outmap_dice_coef: 0.5048 - outbin_acc: 0.8872Epoch 00027: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0233 - outmap_loss: 0.0204 - outbin_loss: 0.2844 - outmap_dice_coef: 0.5046 - outbin_acc: 0.8879 - val_loss: 0.0239 - val_outmap_loss: 0.0205 - val_outbin_loss: 0.3394 - val_outmap_dice_coef: 0.5120 - val_outbin_acc: 0.8517
# Epoch 29/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0231 - outmap_loss: 0.0203 - outbin_loss: 0.2786 - outmap_dice_coef: 0.5082 - outbin_acc: 0.8877Epoch 00028: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0231 - outmap_loss: 0.0203 - outbin_loss: 0.2797 - outmap_dice_coef: 0.5086 - outbin_acc: 0.8868 - val_loss: 0.0244 - val_outmap_loss: 0.0212 - val_outbin_loss: 0.3184 - val_outmap_dice_coef: 0.5073 - val_outbin_acc: 0.8568
# Epoch 30/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0225 - outmap_loss: 0.0198 - outbin_loss: 0.2758 - outmap_dice_coef: 0.5197 - outbin_acc: 0.8918Epoch 00029: val_loss improved from 0.02382 to 0.02363, saving model to weights.hdf5
# 3515/3515 [==============================] - 36s - loss: 0.0225 - outmap_loss: 0.0198 - outbin_loss: 0.2743 - outmap_dice_coef: 0.5197 - outbin_acc: 0.8919 - val_loss: 0.0236 - val_outmap_loss: 0.0205 - val_outbin_loss: 0.3161 - val_outmap_dice_coef: 0.5243 - val_outbin_acc: 0.8696
# Epoch 31/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0227 - outmap_loss: 0.0200 - outbin_loss: 0.2749 - outmap_dice_coef: 0.5191 - outbin_acc: 0.8872Epoch 00030: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0227 - outmap_loss: 0.0199 - outbin_loss: 0.2738 - outmap_dice_coef: 0.5192 - outbin_acc: 0.8882 - val_loss: 0.0242 - val_outmap_loss: 0.0205 - val_outbin_loss: 0.3650 - val_outmap_dice_coef: 0.5179 - val_outbin_acc: 0.8568
# Epoch 32/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0229 - outmap_loss: 0.0200 - outbin_loss: 0.2846 - outmap_dice_coef: 0.5184 - outbin_acc: 0.8880Epoch 00031: val_loss did not improve
# 3515/3515 [==============================] - 37s - loss: 0.0229 - outmap_loss: 0.0201 - outbin_loss: 0.2844 - outmap_dice_coef: 0.5177 - outbin_acc: 0.8885 - val_loss: 0.0253 - val_outmap_loss: 0.0220 - val_outbin_loss: 0.3336 - val_outmap_dice_coef: 0.4781 - val_outbin_acc: 0.8517
# Epoch 33/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0229 - outmap_loss: 0.0203 - outbin_loss: 0.2663 - outmap_dice_coef: 0.5091 - outbin_acc: 0.8924Epoch 00032: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0229 - outmap_loss: 0.0202 - outbin_loss: 0.2668 - outmap_dice_coef: 0.5092 - outbin_acc: 0.8919 - val_loss: 0.0240 - val_outmap_loss: 0.0202 - val_outbin_loss: 0.3753 - val_outmap_dice_coef: 0.5140 - val_outbin_acc: 0.8517
# Epoch 34/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0227 - outmap_loss: 0.0200 - outbin_loss: 0.2695 - outmap_dice_coef: 0.5137 - outbin_acc: 0.8927Epoch 00033: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0227 - outmap_loss: 0.0200 - outbin_loss: 0.2695 - outmap_dice_coef: 0.5148 - outbin_acc: 0.8922 - val_loss: 0.0237 - val_outmap_loss: 0.0204 - val_outbin_loss: 0.3283 - val_outmap_dice_coef: 0.5340 - val_outbin_acc: 0.8593
# Epoch 35/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0222 - outmap_loss: 0.0196 - outbin_loss: 0.2634 - outmap_dice_coef: 0.5280 - outbin_acc: 0.8912Epoch 00034: val_loss improved from 0.02363 to 0.02332, saving model to weights.hdf5
# 3515/3515 [==============================] - 38s - loss: 0.0222 - outmap_loss: 0.0196 - outbin_loss: 0.2625 - outmap_dice_coef: 0.5286 - outbin_acc: 0.8913 - val_loss: 0.0233 - val_outmap_loss: 0.0200 - val_outbin_loss: 0.3308 - val_outmap_dice_coef: 0.5367 - val_outbin_acc: 0.8542
# Epoch 36/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0215 - outmap_loss: 0.0189 - outbin_loss: 0.2601 - outmap_dice_coef: 0.5404 - outbin_acc: 0.8927Epoch 00035: val_loss improved from 0.02332 to 0.02325, saving model to weights.hdf5
# 3515/3515 [==============================] - 38s - loss: 0.0214 - outmap_loss: 0.0188 - outbin_loss: 0.2578 - outmap_dice_coef: 0.5413 - outbin_acc: 0.8939 - val_loss: 0.0233 - val_outmap_loss: 0.0199 - val_outbin_loss: 0.3398 - val_outmap_dice_coef: 0.5410 - val_outbin_acc: 0.8593
# Epoch 37/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0220 - outmap_loss: 0.0194 - outbin_loss: 0.2563 - outmap_dice_coef: 0.5305 - outbin_acc: 0.8981Epoch 00036: val_loss improved from 0.02325 to 0.02292, saving model to weights.hdf5
# 3515/3515 [==============================] - 38s - loss: 0.0218 - outmap_loss: 0.0193 - outbin_loss: 0.2549 - outmap_dice_coef: 0.5310 - outbin_acc: 0.8987 - val_loss: 0.0229 - val_outmap_loss: 0.0199 - val_outbin_loss: 0.3049 - val_outmap_dice_coef: 0.5301 - val_outbin_acc: 0.8593
# Epoch 38/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0217 - outmap_loss: 0.0192 - outbin_loss: 0.2550 - outmap_dice_coef: 0.5357 - outbin_acc: 0.8938Epoch 00037: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0217 - outmap_loss: 0.0192 - outbin_loss: 0.2540 - outmap_dice_coef: 0.5365 - outbin_acc: 0.8945 - val_loss: 0.0265 - val_outmap_loss: 0.0230 - val_outbin_loss: 0.3482 - val_outmap_dice_coef: 0.4885 - val_outbin_acc: 0.8414
# Epoch 39/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0215 - outmap_loss: 0.0191 - outbin_loss: 0.2421 - outmap_dice_coef: 0.5344 - outbin_acc: 0.8961Epoch 00038: val_loss improved from 0.02292 to 0.02256, saving model to weights.hdf5
# 3515/3515 [==============================] - 38s - loss: 0.0214 - outmap_loss: 0.0190 - outbin_loss: 0.2415 - outmap_dice_coef: 0.5355 - outbin_acc: 0.8962 - val_loss: 0.0226 - val_outmap_loss: 0.0192 - val_outbin_loss: 0.3359 - val_outmap_dice_coef: 0.5526 - val_outbin_acc: 0.8619
# Epoch 40/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0209 - outmap_loss: 0.0185 - outbin_loss: 0.2447 - outmap_dice_coef: 0.5481 - outbin_acc: 0.9036Epoch 00039: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0209 - outmap_loss: 0.0184 - outbin_loss: 0.2432 - outmap_dice_coef: 0.5490 - outbin_acc: 0.9041 - val_loss: 0.0230 - val_outmap_loss: 0.0195 - val_outbin_loss: 0.3446 - val_outmap_dice_coef: 0.5611 - val_outbin_acc: 0.8593
# Epoch 41/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0206 - outmap_loss: 0.0183 - outbin_loss: 0.2303 - outmap_dice_coef: 0.5543 - outbin_acc: 0.9080Epoch 00040: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0207 - outmap_loss: 0.0184 - outbin_loss: 0.2298 - outmap_dice_coef: 0.5530 - outbin_acc: 0.9084 - val_loss: 0.0230 - val_outmap_loss: 0.0196 - val_outbin_loss: 0.3482 - val_outmap_dice_coef: 0.5457 - val_outbin_acc: 0.8696
# Epoch 42/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0209 - outmap_loss: 0.0185 - outbin_loss: 0.2367 - outmap_dice_coef: 0.5419 - outbin_acc: 0.9057Epoch 00041: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0210 - outmap_loss: 0.0186 - outbin_loss: 0.2362 - outmap_dice_coef: 0.5418 - outbin_acc: 0.9058 - val_loss: 0.0233 - val_outmap_loss: 0.0202 - val_outbin_loss: 0.3162 - val_outmap_dice_coef: 0.5370 - val_outbin_acc: 0.8593
# Epoch 43/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0203 - outmap_loss: 0.0181 - outbin_loss: 0.2247 - outmap_dice_coef: 0.5599 - outbin_acc: 0.9109Epoch 00042: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0203 - outmap_loss: 0.0180 - outbin_loss: 0.2230 - outmap_dice_coef: 0.5595 - outbin_acc: 0.9121 - val_loss: 0.0231 - val_outmap_loss: 0.0199 - val_outbin_loss: 0.3195 - val_outmap_dice_coef: 0.5289 - val_outbin_acc: 0.8542
# Epoch 44/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0203 - outmap_loss: 0.0181 - outbin_loss: 0.2255 - outmap_dice_coef: 0.5569 - outbin_acc: 0.9074Epoch 00043: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0203 - outmap_loss: 0.0181 - outbin_loss: 0.2249 - outmap_dice_coef: 0.5563 - outbin_acc: 0.9078 - val_loss: 0.0234 - val_outmap_loss: 0.0203 - val_outbin_loss: 0.3093 - val_outmap_dice_coef: 0.5323 - val_outbin_acc: 0.8645
# Epoch 45/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0211 - outmap_loss: 0.0189 - outbin_loss: 0.2213 - outmap_dice_coef: 0.5419 - outbin_acc: 0.9144Epoch 00044: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0211 - outmap_loss: 0.0189 - outbin_loss: 0.2210 - outmap_dice_coef: 0.5411 - outbin_acc: 0.9144 - val_loss: 0.0246 - val_outmap_loss: 0.0209 - val_outbin_loss: 0.3670 - val_outmap_dice_coef: 0.5145 - val_outbin_acc: 0.8414
# Epoch 46/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0211 - outmap_loss: 0.0188 - outbin_loss: 0.2302 - outmap_dice_coef: 0.5419 - outbin_acc: 0.9089Epoch 00045: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0211 - outmap_loss: 0.0188 - outbin_loss: 0.2308 - outmap_dice_coef: 0.5416 - outbin_acc: 0.9087 - val_loss: 0.0233 - val_outmap_loss: 0.0198 - val_outbin_loss: 0.3502 - val_outmap_dice_coef: 0.5537 - val_outbin_acc: 0.8542
# Epoch 47/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0206 - outmap_loss: 0.0184 - outbin_loss: 0.2156 - outmap_dice_coef: 0.5514 - outbin_acc: 0.9135Epoch 00046: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0205 - outmap_loss: 0.0183 - outbin_loss: 0.2140 - outmap_dice_coef: 0.5521 - outbin_acc: 0.9138 - val_loss: 0.0229 - val_outmap_loss: 0.0196 - val_outbin_loss: 0.3375 - val_outmap_dice_coef: 0.5712 - val_outbin_acc: 0.8619
# Epoch 48/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0203 - outmap_loss: 0.0182 - outbin_loss: 0.2036 - outmap_dice_coef: 0.5524 - outbin_acc: 0.9175Epoch 00047: val_loss improved from 0.02256 to 0.02254, saving model to weights.hdf5
# 3515/3515 [==============================] - 38s - loss: 0.0203 - outmap_loss: 0.0183 - outbin_loss: 0.2037 - outmap_dice_coef: 0.5521 - outbin_acc: 0.9178 - val_loss: 0.0225 - val_outmap_loss: 0.0194 - val_outbin_loss: 0.3148 - val_outmap_dice_coef: 0.5575 - val_outbin_acc: 0.8772
# Epoch 49/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0208 - outmap_loss: 0.0185 - outbin_loss: 0.2371 - outmap_dice_coef: 0.5497 - outbin_acc: 0.9045Epoch 00048: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0208 - outmap_loss: 0.0184 - outbin_loss: 0.2363 - outmap_dice_coef: 0.5491 - outbin_acc: 0.9044 - val_loss: 0.0233 - val_outmap_loss: 0.0197 - val_outbin_loss: 0.3562 - val_outmap_dice_coef: 0.5700 - val_outbin_acc: 0.8721
# Epoch 50/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0197 - outmap_loss: 0.0177 - outbin_loss: 0.2066 - outmap_dice_coef: 0.5644 - outbin_acc: 0.9138Epoch 00049: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0197 - outmap_loss: 0.0177 - outbin_loss: 0.2059 - outmap_dice_coef: 0.5636 - outbin_acc: 0.9138 - val_loss: 0.0227 - val_outmap_loss: 0.0193 - val_outbin_loss: 0.3400 - val_outmap_dice_coef: 0.5719 - val_outbin_acc: 0.8772
# Epoch 51/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0201 - outmap_loss: 0.0180 - outbin_loss: 0.2120 - outmap_dice_coef: 0.5660 - outbin_acc: 0.9144Epoch 00050: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0200 - outmap_loss: 0.0179 - outbin_loss: 0.2102 - outmap_dice_coef: 0.5657 - outbin_acc: 0.9152 - val_loss: 0.0232 - val_outmap_loss: 0.0201 - val_outbin_loss: 0.3083 - val_outmap_dice_coef: 0.5184 - val_outbin_acc: 0.8875
# Epoch 52/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0199 - outmap_loss: 0.0178 - outbin_loss: 0.2047 - outmap_dice_coef: 0.5617 - outbin_acc: 0.9198Epoch 00051: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0199 - outmap_loss: 0.0179 - outbin_loss: 0.2053 - outmap_dice_coef: 0.5614 - outbin_acc: 0.9195 - val_loss: 0.0234 - val_outmap_loss: 0.0198 - val_outbin_loss: 0.3602 - val_outmap_dice_coef: 0.5796 - val_outbin_acc: 0.8772
# Epoch 53/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0197 - outmap_loss: 0.0177 - outbin_loss: 0.1997 - outmap_dice_coef: 0.5665 - outbin_acc: 0.9210Epoch 00052: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0197 - outmap_loss: 0.0177 - outbin_loss: 0.2003 - outmap_dice_coef: 0.5664 - outbin_acc: 0.9206 - val_loss: 0.0276 - val_outmap_loss: 0.0243 - val_outbin_loss: 0.3259 - val_outmap_dice_coef: 0.4652 - val_outbin_acc: 0.8849
# Epoch 54/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0196 - outmap_loss: 0.0176 - outbin_loss: 0.2030 - outmap_dice_coef: 0.5675 - outbin_acc: 0.9225Epoch 00053: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0197 - outmap_loss: 0.0176 - outbin_loss: 0.2039 - outmap_dice_coef: 0.5677 - outbin_acc: 0.9226 - val_loss: 0.0257 - val_outmap_loss: 0.0222 - val_outbin_loss: 0.3452 - val_outmap_dice_coef: 0.5131 - val_outbin_acc: 0.8696
# Epoch 55/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0192 - outmap_loss: 0.0173 - outbin_loss: 0.1903 - outmap_dice_coef: 0.5739 - outbin_acc: 0.9245Epoch 00054: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0193 - outmap_loss: 0.0174 - outbin_loss: 0.1902 - outmap_dice_coef: 0.5742 - outbin_acc: 0.9249 - val_loss: 0.0228 - val_outmap_loss: 0.0192 - val_outbin_loss: 0.3569 - val_outmap_dice_coef: 0.5840 - val_outbin_acc: 0.8798
# Epoch 56/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0193 - outmap_loss: 0.0173 - outbin_loss: 0.2010 - outmap_dice_coef: 0.5729 - outbin_acc: 0.9225Epoch 00055: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0193 - outmap_loss: 0.0173 - outbin_loss: 0.2005 - outmap_dice_coef: 0.5738 - outbin_acc: 0.9226 - val_loss: 0.0230 - val_outmap_loss: 0.0197 - val_outbin_loss: 0.3261 - val_outmap_dice_coef: 0.5856 - val_outbin_acc: 0.8772
# Epoch 57/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0192 - outmap_loss: 0.0173 - outbin_loss: 0.1950 - outmap_dice_coef: 0.5756 - outbin_acc: 0.9216Epoch 00056: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0192 - outmap_loss: 0.0172 - outbin_loss: 0.1951 - outmap_dice_coef: 0.5757 - outbin_acc: 0.9215 - val_loss: 0.0228 - val_outmap_loss: 0.0196 - val_outbin_loss: 0.3263 - val_outmap_dice_coef: 0.5767 - val_outbin_acc: 0.8619
# Epoch 58/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0195 - outmap_loss: 0.0175 - outbin_loss: 0.1965 - outmap_dice_coef: 0.5710 - outbin_acc: 0.9201Epoch 00057: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0195 - outmap_loss: 0.0175 - outbin_loss: 0.1957 - outmap_dice_coef: 0.5709 - outbin_acc: 0.9206 - val_loss: 0.0247 - val_outmap_loss: 0.0210 - val_outbin_loss: 0.3684 - val_outmap_dice_coef: 0.5626 - val_outbin_acc: 0.8645
# Epoch 59/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0189 - outmap_loss: 0.0170 - outbin_loss: 0.1830 - outmap_dice_coef: 0.5806 - outbin_acc: 0.9251Epoch 00058: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0188 - outmap_loss: 0.0170 - outbin_loss: 0.1824 - outmap_dice_coef: 0.5818 - outbin_acc: 0.9249 - val_loss: 0.0234 - val_outmap_loss: 0.0199 - val_outbin_loss: 0.3513 - val_outmap_dice_coef: 0.5713 - val_outbin_acc: 0.8619
# Epoch 60/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0188 - outmap_loss: 0.0171 - outbin_loss: 0.1681 - outmap_dice_coef: 0.5775 - outbin_acc: 0.9334Epoch 00059: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0188 - outmap_loss: 0.0171 - outbin_loss: 0.1662 - outmap_dice_coef: 0.5776 - outbin_acc: 0.9346 - val_loss: 0.0230 - val_outmap_loss: 0.0196 - val_outbin_loss: 0.3434 - val_outmap_dice_coef: 0.5408 - val_outbin_acc: 0.8747
# Epoch 61/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0192 - outmap_loss: 0.0173 - outbin_loss: 0.1914 - outmap_dice_coef: 0.5753 - outbin_acc: 0.9227Epoch 00060: val_loss improved from 0.02254 to 0.02175, saving model to weights.hdf5
# 3515/3515 [==============================] - 38s - loss: 0.0193 - outmap_loss: 0.0173 - outbin_loss: 0.1918 - outmap_dice_coef: 0.5751 - outbin_acc: 0.9223 - val_loss: 0.0218 - val_outmap_loss: 0.0186 - val_outbin_loss: 0.3114 - val_outmap_dice_coef: 0.5809 - val_outbin_acc: 0.8875
# Epoch 62/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0184 - outmap_loss: 0.0167 - outbin_loss: 0.1729 - outmap_dice_coef: 0.5862 - outbin_acc: 0.9291Epoch 00061: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0184 - outmap_loss: 0.0167 - outbin_loss: 0.1721 - outmap_dice_coef: 0.5867 - outbin_acc: 0.9294 - val_loss: 0.0221 - val_outmap_loss: 0.0189 - val_outbin_loss: 0.3251 - val_outmap_dice_coef: 0.5615 - val_outbin_acc: 0.8696
# Epoch 63/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0182 - outmap_loss: 0.0165 - outbin_loss: 0.1705 - outmap_dice_coef: 0.5875 - outbin_acc: 0.9314Epoch 00062: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0182 - outmap_loss: 0.0165 - outbin_loss: 0.1701 - outmap_dice_coef: 0.5870 - outbin_acc: 0.9314 - val_loss: 0.0233 - val_outmap_loss: 0.0198 - val_outbin_loss: 0.3577 - val_outmap_dice_coef: 0.5707 - val_outbin_acc: 0.8849
# Epoch 64/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0185 - outmap_loss: 0.0167 - outbin_loss: 0.1805 - outmap_dice_coef: 0.5909 - outbin_acc: 0.9300Epoch 00063: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0185 - outmap_loss: 0.0167 - outbin_loss: 0.1804 - outmap_dice_coef: 0.5909 - outbin_acc: 0.9297 - val_loss: 0.0233 - val_outmap_loss: 0.0198 - val_outbin_loss: 0.3485 - val_outmap_dice_coef: 0.5728 - val_outbin_acc: 0.8798
# Epoch 65/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0178 - outmap_loss: 0.0161 - outbin_loss: 0.1674 - outmap_dice_coef: 0.5954 - outbin_acc: 0.9361Epoch 00064: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0179 - outmap_loss: 0.0162 - outbin_loss: 0.1664 - outmap_dice_coef: 0.5962 - outbin_acc: 0.9366 - val_loss: 0.0240 - val_outmap_loss: 0.0201 - val_outbin_loss: 0.3895 - val_outmap_dice_coef: 0.5547 - val_outbin_acc: 0.8747
# Epoch 66/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0185 - outmap_loss: 0.0168 - outbin_loss: 0.1721 - outmap_dice_coef: 0.5863 - outbin_acc: 0.9303Epoch 00065: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0186 - outmap_loss: 0.0169 - outbin_loss: 0.1741 - outmap_dice_coef: 0.5855 - outbin_acc: 0.9292 - val_loss: 0.0232 - val_outmap_loss: 0.0195 - val_outbin_loss: 0.3707 - val_outmap_dice_coef: 0.5571 - val_outbin_acc: 0.8824
# Epoch 67/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0178 - outmap_loss: 0.0162 - outbin_loss: 0.1586 - outmap_dice_coef: 0.5935 - outbin_acc: 0.9352Epoch 00066: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0179 - outmap_loss: 0.0163 - outbin_loss: 0.1591 - outmap_dice_coef: 0.5932 - outbin_acc: 0.9346 - val_loss: 0.0234 - val_outmap_loss: 0.0196 - val_outbin_loss: 0.3773 - val_outmap_dice_coef: 0.5779 - val_outbin_acc: 0.8900
# Epoch 68/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0181 - outmap_loss: 0.0165 - outbin_loss: 0.1653 - outmap_dice_coef: 0.5915 - outbin_acc: 0.9306Epoch 00067: val_loss did not improve
# 3515/3515 [==============================] - 37s - loss: 0.0181 - outmap_loss: 0.0164 - outbin_loss: 0.1647 - outmap_dice_coef: 0.5920 - outbin_acc: 0.9309 - val_loss: 0.0229 - val_outmap_loss: 0.0190 - val_outbin_loss: 0.3899 - val_outmap_dice_coef: 0.5682 - val_outbin_acc: 0.8798
# Epoch 69/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0180 - outmap_loss: 0.0164 - outbin_loss: 0.1586 - outmap_dice_coef: 0.5934 - outbin_acc: 0.9349Epoch 00068: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0180 - outmap_loss: 0.0164 - outbin_loss: 0.1573 - outmap_dice_coef: 0.5934 - outbin_acc: 0.9357 - val_loss: 0.0228 - val_outmap_loss: 0.0190 - val_outbin_loss: 0.3739 - val_outmap_dice_coef: 0.5638 - val_outbin_acc: 0.8798
# Epoch 70/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0182 - outmap_loss: 0.0167 - outbin_loss: 0.1500 - outmap_dice_coef: 0.5891 - outbin_acc: 0.9372Epoch 00069: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0182 - outmap_loss: 0.0167 - outbin_loss: 0.1501 - outmap_dice_coef: 0.5885 - outbin_acc: 0.9371 - val_loss: 0.0234 - val_outmap_loss: 0.0195 - val_outbin_loss: 0.3925 - val_outmap_dice_coef: 0.5462 - val_outbin_acc: 0.8772
# Epoch 71/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0186 - outmap_loss: 0.0168 - outbin_loss: 0.1845 - outmap_dice_coef: 0.5845 - outbin_acc: 0.9297Epoch 00070: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0186 - outmap_loss: 0.0168 - outbin_loss: 0.1828 - outmap_dice_coef: 0.5854 - outbin_acc: 0.9306 - val_loss: 0.0226 - val_outmap_loss: 0.0195 - val_outbin_loss: 0.3129 - val_outmap_dice_coef: 0.5588 - val_outbin_acc: 0.8798
# Epoch 72/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0180 - outmap_loss: 0.0166 - outbin_loss: 0.1410 - outmap_dice_coef: 0.5858 - outbin_acc: 0.9416Epoch 00071: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0182 - outmap_loss: 0.0168 - outbin_loss: 0.1424 - outmap_dice_coef: 0.5856 - outbin_acc: 0.9411 - val_loss: 0.0237 - val_outmap_loss: 0.0197 - val_outbin_loss: 0.4026 - val_outmap_dice_coef: 0.5829 - val_outbin_acc: 0.8696
# Epoch 73/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0181 - outmap_loss: 0.0164 - outbin_loss: 0.1617 - outmap_dice_coef: 0.5873 - outbin_acc: 0.9332Epoch 00072: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0181 - outmap_loss: 0.0164 - outbin_loss: 0.1610 - outmap_dice_coef: 0.5886 - outbin_acc: 0.9329 - val_loss: 0.0234 - val_outmap_loss: 0.0199 - val_outbin_loss: 0.3560 - val_outmap_dice_coef: 0.5714 - val_outbin_acc: 0.8798
# Epoch 74/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0177 - outmap_loss: 0.0161 - outbin_loss: 0.1582 - outmap_dice_coef: 0.6009 - outbin_acc: 0.9323Epoch 00073: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0177 - outmap_loss: 0.0161 - outbin_loss: 0.1581 - outmap_dice_coef: 0.6015 - outbin_acc: 0.9323 - val_loss: 0.0224 - val_outmap_loss: 0.0189 - val_outbin_loss: 0.3520 - val_outmap_dice_coef: 0.5783 - val_outbin_acc: 0.8951
# Epoch 75/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0171 - outmap_loss: 0.0157 - outbin_loss: 0.1362 - outmap_dice_coef: 0.6077 - outbin_acc: 0.9442Epoch 00074: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0172 - outmap_loss: 0.0158 - outbin_loss: 0.1387 - outmap_dice_coef: 0.6074 - outbin_acc: 0.9437 - val_loss: 0.0230 - val_outmap_loss: 0.0192 - val_outbin_loss: 0.3798 - val_outmap_dice_coef: 0.5433 - val_outbin_acc: 0.8798
# Epoch 76/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0174 - outmap_loss: 0.0160 - outbin_loss: 0.1407 - outmap_dice_coef: 0.6053 - outbin_acc: 0.9424Epoch 00075: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0174 - outmap_loss: 0.0160 - outbin_loss: 0.1412 - outmap_dice_coef: 0.6044 - outbin_acc: 0.9417 - val_loss: 0.0232 - val_outmap_loss: 0.0194 - val_outbin_loss: 0.3792 - val_outmap_dice_coef: 0.5416 - val_outbin_acc: 0.8772
# Epoch 77/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0176 - outmap_loss: 0.0162 - outbin_loss: 0.1479 - outmap_dice_coef: 0.5959 - outbin_acc: 0.9372Epoch 00076: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0177 - outmap_loss: 0.0162 - outbin_loss: 0.1501 - outmap_dice_coef: 0.5965 - outbin_acc: 0.9368 - val_loss: 0.0245 - val_outmap_loss: 0.0196 - val_outbin_loss: 0.4922 - val_outmap_dice_coef: 0.5965 - val_outbin_acc: 0.8670
# Epoch 78/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0172 - outmap_loss: 0.0158 - outbin_loss: 0.1437 - outmap_dice_coef: 0.6083 - outbin_acc: 0.9424Epoch 00077: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0172 - outmap_loss: 0.0157 - outbin_loss: 0.1453 - outmap_dice_coef: 0.6085 - outbin_acc: 0.9417 - val_loss: 0.0235 - val_outmap_loss: 0.0195 - val_outbin_loss: 0.4027 - val_outmap_dice_coef: 0.5865 - val_outbin_acc: 0.8977
# Epoch 79/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0172 - outmap_loss: 0.0158 - outbin_loss: 0.1403 - outmap_dice_coef: 0.6039 - outbin_acc: 0.9453Epoch 00078: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0173 - outmap_loss: 0.0159 - outbin_loss: 0.1400 - outmap_dice_coef: 0.6041 - outbin_acc: 0.9457 - val_loss: 0.0240 - val_outmap_loss: 0.0192 - val_outbin_loss: 0.4811 - val_outmap_dice_coef: 0.5787 - val_outbin_acc: 0.8772
# Epoch 80/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0171 - outmap_loss: 0.0157 - outbin_loss: 0.1405 - outmap_dice_coef: 0.6083 - outbin_acc: 0.9439Epoch 00079: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0172 - outmap_loss: 0.0158 - outbin_loss: 0.1415 - outmap_dice_coef: 0.6077 - outbin_acc: 0.9431 - val_loss: 0.0232 - val_outmap_loss: 0.0194 - val_outbin_loss: 0.3825 - val_outmap_dice_coef: 0.5609 - val_outbin_acc: 0.8849
# Epoch 81/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0176 - outmap_loss: 0.0162 - outbin_loss: 0.1440 - outmap_dice_coef: 0.6003 - outbin_acc: 0.9410Epoch 00080: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0176 - outmap_loss: 0.0161 - outbin_loss: 0.1438 - outmap_dice_coef: 0.6003 - outbin_acc: 0.9414 - val_loss: 0.0237 - val_outmap_loss: 0.0197 - val_outbin_loss: 0.3953 - val_outmap_dice_coef: 0.5538 - val_outbin_acc: 0.8517
# Epoch 82/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0173 - outmap_loss: 0.0158 - outbin_loss: 0.1485 - outmap_dice_coef: 0.6017 - outbin_acc: 0.9421Epoch 00081: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0174 - outmap_loss: 0.0159 - outbin_loss: 0.1472 - outmap_dice_coef: 0.6028 - outbin_acc: 0.9422 - val_loss: 0.0230 - val_outmap_loss: 0.0193 - val_outbin_loss: 0.3662 - val_outmap_dice_coef: 0.5931 - val_outbin_acc: 0.8824
# Epoch 83/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0171 - outmap_loss: 0.0157 - outbin_loss: 0.1403 - outmap_dice_coef: 0.6045 - outbin_acc: 0.9442Epoch 00082: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0172 - outmap_loss: 0.0158 - outbin_loss: 0.1393 - outmap_dice_coef: 0.6057 - outbin_acc: 0.9445 - val_loss: 0.0242 - val_outmap_loss: 0.0202 - val_outbin_loss: 0.3984 - val_outmap_dice_coef: 0.5547 - val_outbin_acc: 0.8721
# Epoch 84/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0172 - outmap_loss: 0.0158 - outbin_loss: 0.1401 - outmap_dice_coef: 0.6015 - outbin_acc: 0.9395Epoch 00083: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0172 - outmap_loss: 0.0158 - outbin_loss: 0.1395 - outmap_dice_coef: 0.6020 - outbin_acc: 0.9403 - val_loss: 0.0251 - val_outmap_loss: 0.0209 - val_outbin_loss: 0.4171 - val_outmap_dice_coef: 0.5561 - val_outbin_acc: 0.8619
# Epoch 85/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0175 - outmap_loss: 0.0160 - outbin_loss: 0.1449 - outmap_dice_coef: 0.6044 - outbin_acc: 0.9442Epoch 00084: val_loss did not improve
# 3515/3515 [==============================] - 37s - loss: 0.0175 - outmap_loss: 0.0160 - outbin_loss: 0.1437 - outmap_dice_coef: 0.6047 - outbin_acc: 0.9448 - val_loss: 0.0229 - val_outmap_loss: 0.0189 - val_outbin_loss: 0.4048 - val_outmap_dice_coef: 0.5508 - val_outbin_acc: 0.8772
# Epoch 86/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0173 - outmap_loss: 0.0159 - outbin_loss: 0.1442 - outmap_dice_coef: 0.6050 - outbin_acc: 0.9433Epoch 00085: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0173 - outmap_loss: 0.0159 - outbin_loss: 0.1441 - outmap_dice_coef: 0.6048 - outbin_acc: 0.9434 - val_loss: 0.0233 - val_outmap_loss: 0.0190 - val_outbin_loss: 0.4294 - val_outmap_dice_coef: 0.5790 - val_outbin_acc: 0.8696
# Epoch 87/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0164 - outmap_loss: 0.0153 - outbin_loss: 0.1152 - outmap_dice_coef: 0.6146 - outbin_acc: 0.9537Epoch 00086: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0165 - outmap_loss: 0.0154 - outbin_loss: 0.1150 - outmap_dice_coef: 0.6143 - outbin_acc: 0.9539 - val_loss: 0.0226 - val_outmap_loss: 0.0187 - val_outbin_loss: 0.3880 - val_outmap_dice_coef: 0.5830 - val_outbin_acc: 0.8798
# Epoch 88/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0166 - outmap_loss: 0.0155 - outbin_loss: 0.1101 - outmap_dice_coef: 0.6143 - outbin_acc: 0.9572Epoch 00087: val_loss did not improve
# 3515/3515 [==============================] - 38s - loss: 0.0166 - outmap_loss: 0.0155 - outbin_loss: 0.1113 - outmap_dice_coef: 0.6141 - outbin_acc: 0.9568 - val_loss: 0.0238 - val_outmap_loss: 0.0195 - val_outbin_loss: 0.4380 - val_outmap_dice_coef: 0.5782 - val_outbin_acc: 0.8747
# Epoch 89/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0166 - outmap_loss: 0.0153 - outbin_loss: 0.1279 - outmap_dice_coef: 0.6147 - outbin_acc: 0.9505Epoch 00088: val_loss did not improve
# 3515/3515 [==============================] - 37s - loss: 0.0166 - outmap_loss: 0.0153 - outbin_loss: 0.1281 - outmap_dice_coef: 0.6141 - outbin_acc: 0.9508 - val_loss: 0.0222 - val_outmap_loss: 0.0184 - val_outbin_loss: 0.3746 - val_outmap_dice_coef: 0.5612 - val_outbin_acc: 0.8747
# Epoch 90/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0165 - outmap_loss: 0.0153 - outbin_loss: 0.1170 - outmap_dice_coef: 0.6152 - outbin_acc: 0.9523Epoch 00089: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0165 - outmap_loss: 0.0153 - outbin_loss: 0.1162 - outmap_dice_coef: 0.6153 - outbin_acc: 0.9528 - val_loss: 0.0244 - val_outmap_loss: 0.0198 - val_outbin_loss: 0.4659 - val_outmap_dice_coef: 0.5833 - val_outbin_acc: 0.8670
# Epoch 91/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0166 - outmap_loss: 0.0153 - outbin_loss: 0.1235 - outmap_dice_coef: 0.6184 - outbin_acc: 0.9497Epoch 00090: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0165 - outmap_loss: 0.0153 - outbin_loss: 0.1233 - outmap_dice_coef: 0.6188 - outbin_acc: 0.9496 - val_loss: 0.0226 - val_outmap_loss: 0.0186 - val_outbin_loss: 0.4041 - val_outmap_dice_coef: 0.5833 - val_outbin_acc: 0.8875
# Epoch 92/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0161 - outmap_loss: 0.0148 - outbin_loss: 0.1234 - outmap_dice_coef: 0.6258 - outbin_acc: 0.9479Epoch 00091: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0161 - outmap_loss: 0.0149 - outbin_loss: 0.1249 - outmap_dice_coef: 0.6247 - outbin_acc: 0.9474 - val_loss: 0.0236 - val_outmap_loss: 0.0191 - val_outbin_loss: 0.4510 - val_outmap_dice_coef: 0.5683 - val_outbin_acc: 0.8772
# Epoch 93/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0161 - outmap_loss: 0.0149 - outbin_loss: 0.1175 - outmap_dice_coef: 0.6262 - outbin_acc: 0.9520Epoch 00092: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0160 - outmap_loss: 0.0149 - outbin_loss: 0.1164 - outmap_dice_coef: 0.6266 - outbin_acc: 0.9522 - val_loss: 0.0238 - val_outmap_loss: 0.0190 - val_outbin_loss: 0.4730 - val_outmap_dice_coef: 0.5756 - val_outbin_acc: 0.8772
# Epoch 94/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0168 - outmap_loss: 0.0155 - outbin_loss: 0.1280 - outmap_dice_coef: 0.6121 - outbin_acc: 0.9534Epoch 00093: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0168 - outmap_loss: 0.0155 - outbin_loss: 0.1265 - outmap_dice_coef: 0.6122 - outbin_acc: 0.9539 - val_loss: 0.0232 - val_outmap_loss: 0.0185 - val_outbin_loss: 0.4639 - val_outmap_dice_coef: 0.5821 - val_outbin_acc: 0.8696
# Epoch 95/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0165 - outmap_loss: 0.0152 - outbin_loss: 0.1317 - outmap_dice_coef: 0.6202 - outbin_acc: 0.9499Epoch 00094: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0165 - outmap_loss: 0.0152 - outbin_loss: 0.1305 - outmap_dice_coef: 0.6204 - outbin_acc: 0.9505 - val_loss: 0.0226 - val_outmap_loss: 0.0184 - val_outbin_loss: 0.4162 - val_outmap_dice_coef: 0.5771 - val_outbin_acc: 0.8772
# Epoch 96/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0169 - outmap_loss: 0.0157 - outbin_loss: 0.1196 - outmap_dice_coef: 0.6106 - outbin_acc: 0.9537Epoch 00095: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0168 - outmap_loss: 0.0157 - outbin_loss: 0.1189 - outmap_dice_coef: 0.6108 - outbin_acc: 0.9539 - val_loss: 0.0232 - val_outmap_loss: 0.0190 - val_outbin_loss: 0.4184 - val_outmap_dice_coef: 0.5828 - val_outbin_acc: 0.8798
# Epoch 97/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0164 - outmap_loss: 0.0153 - outbin_loss: 0.1034 - outmap_dice_coef: 0.6127 - outbin_acc: 0.9580Epoch 00096: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0163 - outmap_loss: 0.0153 - outbin_loss: 0.1032 - outmap_dice_coef: 0.6132 - outbin_acc: 0.9582 - val_loss: 0.0234 - val_outmap_loss: 0.0188 - val_outbin_loss: 0.4658 - val_outmap_dice_coef: 0.5930 - val_outbin_acc: 0.8696
# Epoch 98/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0165 - outmap_loss: 0.0151 - outbin_loss: 0.1421 - outmap_dice_coef: 0.6172 - outbin_acc: 0.9442Epoch 00097: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0166 - outmap_loss: 0.0152 - outbin_loss: 0.1419 - outmap_dice_coef: 0.6161 - outbin_acc: 0.9442 - val_loss: 0.0263 - val_outmap_loss: 0.0221 - val_outbin_loss: 0.4171 - val_outmap_dice_coef: 0.5143 - val_outbin_acc: 0.8696
# Epoch 99/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0166 - outmap_loss: 0.0153 - outbin_loss: 0.1260 - outmap_dice_coef: 0.6143 - outbin_acc: 0.9540Epoch 00098: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0166 - outmap_loss: 0.0153 - outbin_loss: 0.1260 - outmap_dice_coef: 0.6134 - outbin_acc: 0.9539 - val_loss: 0.0227 - val_outmap_loss: 0.0190 - val_outbin_loss: 0.3725 - val_outmap_dice_coef: 0.5631 - val_outbin_acc: 0.8900
# Epoch 100/100
# 3456/3515 [============================>.] - ETA: 0s - loss: 0.0161 - outmap_loss: 0.0151 - outbin_loss: 0.1029 - outmap_dice_coef: 0.6246 - outbin_acc: 0.9598Epoch 00099: val_loss did not improve
# 3515/3515 [==============================] - 36s - loss: 0.0161 - outmap_loss: 0.0151 - outbin_loss: 0.1029 - outmap_dice_coef: 0.6246 - outbin_acc: 0.9602 - val_loss: 0.0241 - val_outmap_loss: 0.0193 - val_outbin_loss: 0.4846 - val_outmap_dice_coef: 0.5524 - val_outbin_acc: 0.8721

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights.hdf5'))

# %%
conv1 = model.layers[1].output
_f = K.function([K.learning_phase(), input_img], [conv1])
_convout = _f([0, X_test[:1]])[0]
print _convout.shape

maxout1 = model.layers[3].output
_f = K.function([K.learning_phase(), input_img], [maxout1])
_maxout = _f([0, X_test[:1]])[0]
print _maxout.shape

pl.figure()
pl.imshow(_convout[0, 0], interpolation='nearest')
pl.colorbar()
pl.figure()
pl.imshow(_maxout[0, 0], interpolation='nearest')
pl.colorbar()
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/backend/theano_backend.py:514: UserWarning: theano.function was asked to create a function computing outputs given certain inputs, but the provided input variable at index 0 is not part of the computational graph needed to compute the outputs: keras_learning_phase.
# To make this warning into an error, you can pass the parameter on_unused_input='raise' to theano.function. To disable it completely, use on_unused_input='ignore'.
#   **kwargs)
# (1, 32, 128, 128)
# (1, 32, 128, 128)
# <matplotlib.colorbar.Colorbar instance at 0x7f299524a6c8>
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
def compute_scores_map(X, Y):
    Y_pred, Y_pred_binary = model.predict(X)
    
    map_threshs = np.linspace(0, 1, num=21)
    bin_threshs = np.linspace(0, 1, num=21)
    
    scores = np.zeros((len(map_threshs), len(bin_threshs)))
    for i in range(len(map_threshs)):
        for j in range(len(bin_threshs)):
            _Y_pred = Y_pred > map_threshs[i]
            
            for k in range(_Y_pred.shape[0]):
                # Clear prediction where we detect to little pixels
                if np.sum(_Y_pred[k]) < 150 or Y_pred_binary[k] < bin_threshs[j]:
                    _Y_pred[k,:] = 0
            
            scores[i, j] = utils.average_dice_coefficient(_Y_pred, Y)
    
    pl.imshow(scores, interpolation='nearest')
    pl.yticks(np.arange(len(map_threshs)) + 0.5, ['%.2f' % v for v in map_threshs])
    pl.xticks(np.arange(len(bin_threshs)) + 0.5, ['%.2f' % v for v in bin_threshs], rotation=90)
    pl.ylabel('map thresh')
    pl.xlabel('bin thresh')
    pl.colorbar()
    
    best_i, best_j = np.unravel_index(np.argmax(scores.ravel()), scores.shape)
    best_map_thresh = map_threshs[best_i]
    best_bin_thresh = bin_threshs[best_j]
    return best_map_thresh, best_bin_thresh

map_thresh, bin_thresh = compute_scores_map(X_test, Y_test)
print 'Best map_thresh=%f, bin_thresh=%f' % (map_thresh, bin_thresh)
# Out:
# Best map_thresh=0.450000, bin_thresh=0.950000

# %%
def predict(X, map_thresh, bin_thresh):
    Y_pred, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > map_thresh
    for i in range(Y_pred.shape[0]):
        if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < bin_thresh:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test, map_thresh, bin_thresh)
Y_full_pred, Y_full_pred_proba, Y_full_pred_binary = predict(X_full, map_thresh, bin_thresh)

print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "avg test set score : ", utils.average_dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
print "avg full set score : ", utils.average_dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.690144605117
# avg test set score :  0.829376791955
# full set score :  0.668319898515
# avg full set score :  0.794863693807

# %%
_ = pl.hist(Y_pred_binary)

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[45:50]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 0
img, pred_map = dream_output(Y_full[i])
pl.figure(figsize=(12, 4))
pl.subplot(131)
pl.imshow(Y_full[i].squeeze())
pl.subplot(132)
pl.imshow(img, cmap=cm.gray)
pl.subplot(133)
pl.imshow(pred_map.squeeze())

# %%
# Dream for the binary output
def dream_binoutput(output):
    
    layer_output = layer_dict['outbin'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output - layer_output[:, 0]))
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    
    step = 0.1
    for i in range(40):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    _, model_pred = model.predict(img[None,None,:,:])
    return img, model_pred

img, model_pred = dream_binoutput(1)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
img, model_pred = dream_binoutput(0)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
def dream_layer_filter(layer_name, filter_index):

    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(8):
        pl.subplot(2, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
if True:
    import cv2
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(50,50))
    
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    test_fnames = _d['test_fnames']
    # bin_thresh
    Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:], map_thresh, 0.5)
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
        #imre = cv2.morphologyEx(imre, cv2.MORPH_CLOSE, kernel)
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
        
        if i % 10 == 0:
            print '\r%d / %d' % (i, len(test_fnames)),
            sys.stdout.flush()
# Out:
# 5500 / 5508

# %% [markdown]
# ## Stats on predicted masks

# %%
# on Y_full
nbp_pixels = np.sum(np.sum(np.sum(Y_full, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
