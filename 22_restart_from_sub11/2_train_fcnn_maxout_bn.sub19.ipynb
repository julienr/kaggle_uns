# %% [markdown]
# submission 19 - 0.65681

# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']
X_pids = _d['pids']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
# Out:
# (3906, 128, 128)
# (3906, 128, 128)

# %%
# Split patients in train/test
train_pids, test_pids = train_test_split(np.unique(X_pids), test_size=0.1)
print train_pids
print test_pids
# Out:
# [22  1 34 38 45  2 12  7 37 15 40 44 25 13  5  6 33 18 11 14 19 29 43 32  3
#  35  8 20 24 16 39  9 21 23 27 26 47 30 10 17  4 31]
# [46 36 42 41 28]

# %%
train_indices = np.flatnonzero(np.in1d(X_pids, train_pids))
test_indices = np.flatnonzero(np.in1d(X_pids, test_pids))
X_train = X[train_indices][:,None,:,:]
Y_train_binary = Y_binary[train_indices][:,None]
Y_train = Y[train_indices][:,None,:,:]
X_test = X[test_indices][:,None,:,:]
Y_test_binary = Y_binary[test_indices][:,None]
Y_test = Y[test_indices][:,None,:,:]

# %%
print X_train.shape
print Y_train.shape
print X_test.shape
print X_train.min(), X_train.max()
# Out:
# (3498, 1, 128, 128)
# (3498, 1, 128, 128)
# (408, 1, 128, 128)
# 0.0 1.0

# %%
#pl.imshow(X_train[0].squeeze())
pl.imshow(Y_train[0].squeeze())
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float32'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense
from keras.layers import LeakyReLU, BatchNormalization
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
from keras.layers import Layer, InputSpec
import keras.initializations
import keras.backend as K

class Maxout2D(Layer):
    def __init__(self, output_dim, cardinality, init='glorot_uniform', **kwargs):
        super(Maxout2D, self).__init__(**kwargs)
        # the k of the maxout paper
        self.cardinality = cardinality
        # the m of the maxout paper
        self.output_dim = output_dim
        self.init = keras.initializations.get(init)
    
    def build(self, input_shape):
        self.input_dim = input_shape[1]
        self.input_spec = [InputSpec(dtype=K.floatx(),
                                     shape=(None, input_shape[1], input_shape[2], input_shape[3]))]
        self.W = self.init((self.input_dim, self.output_dim, self.cardinality),
                           name='{}_W'.format(self.name))
        self.b = K.zeros((self.output_dim, self.cardinality))
        self.trainable_weights = [self.W, self.b]
              
    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        # flatten the spatial dimensions
        flat_x = K.reshape(x, (-1, input_shape[1], input_shape[2] * input_shape[3]))
        output = K.dot(
            K.permute_dimensions(flat_x, (0, 2, 1)),
            K.permute_dimensions(self.W, (1, 0, 2))
        )
        output += K.reshape(self.b, (1, 1, self.output_dim, self.cardinality))
        output = K.max(output, axis=3)
        output = output.transpose(0, 2, 1)
        output = K.reshape(output, (-1, self.output_dim, input_shape[2], input_shape[3]))
        return output
    
    def get_output_shape_for(self, input_shape):
        return (input_shape[0], self.output_dim, input_shape[2], input_shape[3])
    
    def get_config(self):
        config = {
            'output_dim': self.output_dim,
            'cardinality': self.cardinality
        }
        base_config = super(Maxout2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))
    
input_img = Input(shape=(3, 16, 16))
x = Convolution2D(16, 3, 3, border_mode='same')(input_img)
x = Maxout2D(5, 7)(x)

model = Model(input=input_img, output=x)
model.compile(optimizer='adam', loss='mse')
print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)               (None, 3, 16, 16)   0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)    (None, 16, 16, 16)  448         input_1[0][0]
# ____________________________________________________________________________________________________
# maxout2d_1 (Maxout2D)              (None, 5, 16, 16)   595         convolution2d_1[0][0]
# ====================================================================================================
# Total params: 1043
# ____________________________________________________________________________________________________

# %%
# https://www.kaggle.com/c/ultrasound-nerve-segmentation/forums/t/21358/0-57-deep-learning-keras-tutorial
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def dice_coef_batchwise(y_true, y_pred):
    y_true_f = K.batch_flatten(y_true)
    y_pred_f = K.batch_flatten(y_pred)
    intersection = 2. * K.sum(y_true_f * y_pred_f, axis=1, keepdims=True) + smooth
    union = K.sum(y_true_f, axis=1, keepdims=True) + \
            K.sum(y_pred_f, axis=1, keepdims=True) + \
            smooth
    return K.mean(intersection / union)

def dice_coef_loss_batchwise(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
input_img = Input(shape=input_shape, name='input_img')
x = Convolution2D(16, 3, 3, border_mode='same')(input_img)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(16, 2)(x)
pool1 = x = MaxPooling2D((2, 2), name='pool1')(x)

x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.25)(x)
x = Maxout2D(16, 2)(x)
pool2 = x = MaxPooling2D((2, 2), name='pool2')(x)

x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Convolution2D(32, 3, 3, border_mode='same')(x)
x = Dropout(0.1)(x)
x = Maxout2D(16, 2)(x)
pool3 = x = MaxPooling2D((2, 2), name='pool3')(x)

# -- binary presence part
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.1)(x)
x = Maxout2D(16, 2)(x)
pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Convolution2D(16, 3, 3, border_mode='same')(x)
x = Dropout(0.1)(x)
x = Maxout2D(16, 2)(x)
pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Flatten()(x)
x = Dense(32)(x)
x = LeakyReLU()(x)
x = Dense(16)(x)
x = LeakyReLU()(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# -- location map
x = Convolution2D(8, 3, 3, border_mode='same')(pool3)
x = Convolution2D(4, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = Maxout2D(1, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(4, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = Maxout2D(1, 2)(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same')(x)
x = Convolution2D(4, 3, 3, border_mode='same')(x)
x = BatchNormalization()(x)
x = Maxout2D(1, 2)(x)
x = UpSampling2D((2, 2))(x)

x = Convolution2D(4, 3, 3, border_mode='same')(x)
x = Convolution2D(2, 3, 3, border_mode='same')(x)
outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
#loss='binary_crossentropy'
loss=[dice_coef_loss_batchwise, 'binary_crossentropy']
metrics={'outmap': dice_coef, 'outbin': 'accuracy'}
model.compile(optimizer='adam',
              loss=loss,
              loss_weights=[1., 0.01],
              metrics=metrics)

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# convolution2d_14 (Convolution2D)   (None, 16, 128, 128)160         input_img[0][0]
# ____________________________________________________________________________________________________
# convolution2d_15 (Convolution2D)   (None, 16, 128, 128)2320        convolution2d_14[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)                (None, 16, 128, 128)0           convolution2d_15[0][0]
# ____________________________________________________________________________________________________
# maxout2d_7 (Maxout2D)              (None, 16, 128, 128)544         dropout_6[0][0]
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)               (None, 16, 64, 64)  0           maxout2d_7[0][0]
# ____________________________________________________________________________________________________
# convolution2d_16 (Convolution2D)   (None, 16, 64, 64)  2320        pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_17 (Convolution2D)   (None, 16, 64, 64)  2320        convolution2d_16[0][0]
# ____________________________________________________________________________________________________
# dropout_7 (Dropout)                (None, 16, 64, 64)  0           convolution2d_17[0][0]
# ____________________________________________________________________________________________________
# maxout2d_8 (Maxout2D)              (None, 16, 64, 64)  544         dropout_7[0][0]
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)               (None, 16, 32, 32)  0           maxout2d_8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_18 (Convolution2D)   (None, 32, 32, 32)  4640        pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_19 (Convolution2D)   (None, 32, 32, 32)  9248        convolution2d_18[0][0]
# ____________________________________________________________________________________________________
# dropout_8 (Dropout)                (None, 32, 32, 32)  0           convolution2d_19[0][0]
# ____________________________________________________________________________________________________
# maxout2d_9 (Maxout2D)              (None, 16, 32, 32)  1056        dropout_8[0][0]
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)               (None, 16, 16, 16)  0           maxout2d_9[0][0]
# ____________________________________________________________________________________________________
# convolution2d_24 (Convolution2D)   (None, 8, 16, 16)   1160        pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_25 (Convolution2D)   (None, 4, 16, 16)   292         convolution2d_24[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_1 (BatchNormaliz(None, 4, 16, 16)   32          convolution2d_25[0][0]
# ____________________________________________________________________________________________________
# maxout2d_12 (Maxout2D)             (None, 1, 16, 16)   10          batchnormalization_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_20 (Convolution2D)   (None, 16, 16, 16)  2320        pool3[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_1 (UpSampling2D)      (None, 1, 32, 32)   0           maxout2d_12[0][0]
# ____________________________________________________________________________________________________
# convolution2d_21 (Convolution2D)   (None, 16, 16, 16)  2320        convolution2d_20[0][0]
# ____________________________________________________________________________________________________
# merge_1 (Merge)                    (None, 17, 32, 32)  0           upsampling2d_1[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_26 (Convolution2D)   (None, 8, 32, 32)   1232        merge_1[0][0]
# ____________________________________________________________________________________________________
# dropout_9 (Dropout)                (None, 16, 16, 16)  0           convolution2d_21[0][0]
# ____________________________________________________________________________________________________
# convolution2d_27 (Convolution2D)   (None, 4, 32, 32)   292         convolution2d_26[0][0]
# ____________________________________________________________________________________________________
# maxout2d_10 (Maxout2D)             (None, 16, 16, 16)  544         dropout_9[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_2 (BatchNormaliz(None, 4, 32, 32)   64          convolution2d_27[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)               (None, 16, 8, 8)    0           maxout2d_10[0][0]
# ____________________________________________________________________________________________________
# convolution2d_22 (Convolution2D)   (None, 16, 8, 8)    2320        pool4[0][0]
# ____________________________________________________________________________________________________
# maxout2d_13 (Maxout2D)             (None, 1, 32, 32)   10          batchnormalization_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_23 (Convolution2D)   (None, 16, 8, 8)    2320        convolution2d_22[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_2 (UpSampling2D)      (None, 1, 64, 64)   0           maxout2d_13[0][0]
# ____________________________________________________________________________________________________
# dropout_10 (Dropout)               (None, 16, 8, 8)    0           convolution2d_23[0][0]
# ____________________________________________________________________________________________________
# merge_2 (Merge)                    (None, 17, 64, 64)  0           upsampling2d_2[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_28 (Convolution2D)   (None, 8, 64, 64)   1232        merge_2[0][0]
# ____________________________________________________________________________________________________
# maxout2d_11 (Maxout2D)             (None, 16, 8, 8)    544         dropout_10[0][0]
# ____________________________________________________________________________________________________
# convolution2d_29 (Convolution2D)   (None, 4, 64, 64)   292         convolution2d_28[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)               (None, 16, 4, 4)    0           maxout2d_11[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_3 (BatchNormaliz(None, 4, 64, 64)   128         convolution2d_29[0][0]
# ____________________________________________________________________________________________________
# flatten_2 (Flatten)                (None, 256)         0           pool5[0][0]
# ____________________________________________________________________________________________________
# dense_3 (Dense)                    (None, 32)          8224        flatten_2[0][0]
# ____________________________________________________________________________________________________
# maxout2d_14 (Maxout2D)             (None, 1, 64, 64)   10          batchnormalization_3[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_3 (LeakyReLU)            (None, 32)          0           dense_3[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_3 (UpSampling2D)      (None, 1, 128, 128) 0           maxout2d_14[0][0]
# ____________________________________________________________________________________________________
# convolution2d_30 (Convolution2D)   (None, 4, 128, 128) 40          upsampling2d_3[0][0]
# ____________________________________________________________________________________________________
# dense_4 (Dense)                    (None, 16)          528         leakyrelu_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_31 (Convolution2D)   (None, 2, 128, 128) 74          convolution2d_30[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_4 (LeakyReLU)            (None, 16)          0           dense_4[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          leakyrelu_4[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 19          convolution2d_31[0][0]
# ====================================================================================================
# Total params: 47176
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {'outmap': Y_train, 'outbin': Y_train_binary},
        batch_size=64,
        validation_data=(X_test, {'outmap': Y_test, 'outbin': Y_test_binary}),
        nb_epoch=60,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    pl.plot(history.history['loss'], label='train loss')
    pl.plot(history.history['val_loss'], c='g', label='val loss')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
        custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.01])
    
    print_summary(model.layers)
# Out:
# Train on 3498 samples, validate on 408 samples
# Epoch 1/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.0528 - outmap_loss: -0.0603 - outbin_loss: 0.7452 - outmap_dice_coef: 0.0603 - outbin_acc: 0.6126Epoch 00000: val_loss improved from inf to -0.20718, saving model to weights.hdf5
# 3498/3498 [==============================] - 42s - loss: -0.0548 - outmap_loss: -0.0622 - outbin_loss: 0.7437 - outmap_dice_coef: 0.0622 - outbin_acc: 0.6138 - val_loss: -0.2072 - val_outmap_loss: -0.2147 - val_outbin_loss: 0.7471 - val_outmap_dice_coef: 0.2147 - val_outbin_acc: 0.4044
# Epoch 2/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.3086 - outmap_loss: -0.3150 - outbin_loss: 0.6401 - outmap_dice_coef: 0.3150 - outbin_acc: 0.6519Epoch 00001: val_loss improved from -0.20718 to -0.49539, saving model to weights.hdf5
# 3498/3498 [==============================] - 41s - loss: -0.3103 - outmap_loss: -0.3167 - outbin_loss: 0.6413 - outmap_dice_coef: 0.3167 - outbin_acc: 0.6501 - val_loss: -0.4954 - val_outmap_loss: -0.5028 - val_outbin_loss: 0.7399 - val_outmap_dice_coef: 0.5028 - val_outbin_acc: 0.4461
# Epoch 3/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.4191 - outmap_loss: -0.4248 - outbin_loss: 0.5708 - outmap_dice_coef: 0.4248 - outbin_acc: 0.7176Epoch 00002: val_loss improved from -0.49539 to -0.52040, saving model to weights.hdf5
# 3498/3498 [==============================] - 41s - loss: -0.4198 - outmap_loss: -0.4255 - outbin_loss: 0.5705 - outmap_dice_coef: 0.4255 - outbin_acc: 0.7173 - val_loss: -0.5204 - val_outmap_loss: -0.5282 - val_outbin_loss: 0.7813 - val_outmap_dice_coef: 0.5282 - val_outbin_acc: 0.5049
# Epoch 4/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.4540 - outmap_loss: -0.4594 - outbin_loss: 0.5362 - outmap_dice_coef: 0.4594 - outbin_acc: 0.7381Epoch 00003: val_loss improved from -0.52040 to -0.54643, saving model to weights.hdf5
# 3498/3498 [==============================] - 41s - loss: -0.4545 - outmap_loss: -0.4599 - outbin_loss: 0.5361 - outmap_dice_coef: 0.4599 - outbin_acc: 0.7384 - val_loss: -0.5464 - val_outmap_loss: -0.5532 - val_outbin_loss: 0.6797 - val_outmap_dice_coef: 0.5532 - val_outbin_acc: 0.6225
# Epoch 5/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.4876 - outmap_loss: -0.4926 - outbin_loss: 0.4922 - outmap_dice_coef: 0.4926 - outbin_acc: 0.7685Epoch 00004: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.4888 - outmap_loss: -0.4937 - outbin_loss: 0.4924 - outmap_dice_coef: 0.4937 - outbin_acc: 0.7679 - val_loss: -0.4382 - val_outmap_loss: -0.4506 - val_outbin_loss: 1.2437 - val_outmap_dice_coef: 0.4506 - val_outbin_acc: 0.4706
# Epoch 6/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.5244 - outmap_loss: -0.5291 - outbin_loss: 0.4680 - outmap_dice_coef: 0.5291 - outbin_acc: 0.7870Epoch 00005: val_loss improved from -0.54643 to -0.61087, saving model to weights.hdf5
# 3498/3498 [==============================] - 41s - loss: -0.5259 - outmap_loss: -0.5306 - outbin_loss: 0.4678 - outmap_dice_coef: 0.5306 - outbin_acc: 0.7870 - val_loss: -0.6109 - val_outmap_loss: -0.6162 - val_outbin_loss: 0.5331 - val_outmap_dice_coef: 0.6162 - val_outbin_acc: 0.7892
# Epoch 7/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.5362 - outmap_loss: -0.5409 - outbin_loss: 0.4745 - outmap_dice_coef: 0.5409 - outbin_acc: 0.7839Epoch 00006: val_loss improved from -0.61087 to -0.61307, saving model to weights.hdf5
# 3498/3498 [==============================] - 41s - loss: -0.5379 - outmap_loss: -0.5427 - outbin_loss: 0.4737 - outmap_dice_coef: 0.5427 - outbin_acc: 0.7842 - val_loss: -0.6131 - val_outmap_loss: -0.6192 - val_outbin_loss: 0.6130 - val_outmap_dice_coef: 0.6192 - val_outbin_acc: 0.7034
# Epoch 8/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.5502 - outmap_loss: -0.5545 - outbin_loss: 0.4312 - outmap_dice_coef: 0.5545 - outbin_acc: 0.8111Epoch 00007: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.5511 - outmap_loss: -0.5554 - outbin_loss: 0.4293 - outmap_dice_coef: 0.5554 - outbin_acc: 0.8119 - val_loss: -0.5452 - val_outmap_loss: -0.5524 - val_outbin_loss: 0.7169 - val_outmap_dice_coef: 0.5524 - val_outbin_acc: 0.6373
# Epoch 9/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.5611 - outmap_loss: -0.5653 - outbin_loss: 0.4154 - outmap_dice_coef: 0.5653 - outbin_acc: 0.8139Epoch 00008: val_loss improved from -0.61307 to -0.64753, saving model to weights.hdf5
# 3498/3498 [==============================] - 41s - loss: -0.5614 - outmap_loss: -0.5655 - outbin_loss: 0.4150 - outmap_dice_coef: 0.5655 - outbin_acc: 0.8139 - val_loss: -0.6475 - val_outmap_loss: -0.6543 - val_outbin_loss: 0.6765 - val_outmap_dice_coef: 0.6543 - val_outbin_acc: 0.6667
# Epoch 10/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.5775 - outmap_loss: -0.5816 - outbin_loss: 0.4103 - outmap_dice_coef: 0.5816 - outbin_acc: 0.8166Epoch 00009: val_loss did not improve
# 3498/3498 [==============================] - 42s - loss: -0.5775 - outmap_loss: -0.5816 - outbin_loss: 0.4096 - outmap_dice_coef: 0.5816 - outbin_acc: 0.8170 - val_loss: -0.6474 - val_outmap_loss: -0.6515 - val_outbin_loss: 0.4106 - val_outmap_dice_coef: 0.6515 - val_outbin_acc: 0.8431
# Epoch 11/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.5898 - outmap_loss: -0.5937 - outbin_loss: 0.3947 - outmap_dice_coef: 0.5937 - outbin_acc: 0.8261Epoch 00010: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.5897 - outmap_loss: -0.5937 - outbin_loss: 0.3983 - outmap_dice_coef: 0.5937 - outbin_acc: 0.8242 - val_loss: -0.6441 - val_outmap_loss: -0.6497 - val_outbin_loss: 0.5575 - val_outmap_dice_coef: 0.6497 - val_outbin_acc: 0.7745
# Epoch 12/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.5973 - outmap_loss: -0.6014 - outbin_loss: 0.4079 - outmap_dice_coef: 0.6014 - outbin_acc: 0.8232Epoch 00011: val_loss improved from -0.64753 to -0.65214, saving model to weights.hdf5
# 3498/3498 [==============================] - 41s - loss: -0.5957 - outmap_loss: -0.5997 - outbin_loss: 0.4070 - outmap_dice_coef: 0.5997 - outbin_acc: 0.8239 - val_loss: -0.6521 - val_outmap_loss: -0.6563 - val_outbin_loss: 0.4189 - val_outmap_dice_coef: 0.6563 - val_outbin_acc: 0.8431
# Epoch 13/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6031 - outmap_loss: -0.6067 - outbin_loss: 0.3590 - outmap_dice_coef: 0.6067 - outbin_acc: 0.8478Epoch 00012: val_loss improved from -0.65214 to -0.66007, saving model to weights.hdf5
# 3498/3498 [==============================] - 41s - loss: -0.6037 - outmap_loss: -0.6073 - outbin_loss: 0.3589 - outmap_dice_coef: 0.6073 - outbin_acc: 0.8479 - val_loss: -0.6601 - val_outmap_loss: -0.6642 - val_outbin_loss: 0.4112 - val_outmap_dice_coef: 0.6642 - val_outbin_acc: 0.8333
# Epoch 14/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6103 - outmap_loss: -0.6140 - outbin_loss: 0.3607 - outmap_dice_coef: 0.6140 - outbin_acc: 0.8438Epoch 00013: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6099 - outmap_loss: -0.6136 - outbin_loss: 0.3636 - outmap_dice_coef: 0.6136 - outbin_acc: 0.8431 - val_loss: -0.6442 - val_outmap_loss: -0.6488 - val_outbin_loss: 0.4601 - val_outmap_dice_coef: 0.6488 - val_outbin_acc: 0.8015
# Epoch 15/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6068 - outmap_loss: -0.6104 - outbin_loss: 0.3524 - outmap_dice_coef: 0.6104 - outbin_acc: 0.8513Epoch 00014: val_loss improved from -0.66007 to -0.67248, saving model to weights.hdf5
# 3498/3498 [==============================] - 41s - loss: -0.6068 - outmap_loss: -0.6103 - outbin_loss: 0.3527 - outmap_dice_coef: 0.6103 - outbin_acc: 0.8508 - val_loss: -0.6725 - val_outmap_loss: -0.6780 - val_outbin_loss: 0.5499 - val_outmap_dice_coef: 0.6780 - val_outbin_acc: 0.7206
# Epoch 16/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6219 - outmap_loss: -0.6253 - outbin_loss: 0.3413 - outmap_dice_coef: 0.6253 - outbin_acc: 0.8571Epoch 00015: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6224 - outmap_loss: -0.6259 - outbin_loss: 0.3406 - outmap_dice_coef: 0.6259 - outbin_acc: 0.8573 - val_loss: -0.6398 - val_outmap_loss: -0.6432 - val_outbin_loss: 0.3435 - val_outmap_dice_coef: 0.6432 - val_outbin_acc: 0.8750
# Epoch 17/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6183 - outmap_loss: -0.6217 - outbin_loss: 0.3378 - outmap_dice_coef: 0.6217 - outbin_acc: 0.8530Epoch 00016: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6175 - outmap_loss: -0.6209 - outbin_loss: 0.3395 - outmap_dice_coef: 0.6209 - outbin_acc: 0.8525 - val_loss: -0.6540 - val_outmap_loss: -0.6587 - val_outbin_loss: 0.4769 - val_outmap_dice_coef: 0.6587 - val_outbin_acc: 0.7672
# Epoch 18/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6200 - outmap_loss: -0.6234 - outbin_loss: 0.3366 - outmap_dice_coef: 0.6234 - outbin_acc: 0.8611Epoch 00017: val_loss improved from -0.67248 to -0.68162, saving model to weights.hdf5
# 3498/3498 [==============================] - 41s - loss: -0.6203 - outmap_loss: -0.6236 - outbin_loss: 0.3374 - outmap_dice_coef: 0.6236 - outbin_acc: 0.8608 - val_loss: -0.6816 - val_outmap_loss: -0.6852 - val_outbin_loss: 0.3555 - val_outmap_dice_coef: 0.6852 - val_outbin_acc: 0.8701
# Epoch 19/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6248 - outmap_loss: -0.6284 - outbin_loss: 0.3618 - outmap_dice_coef: 0.6284 - outbin_acc: 0.8504Epoch 00018: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6243 - outmap_loss: -0.6279 - outbin_loss: 0.3602 - outmap_dice_coef: 0.6279 - outbin_acc: 0.8516 - val_loss: -0.6760 - val_outmap_loss: -0.6800 - val_outbin_loss: 0.4027 - val_outmap_dice_coef: 0.6800 - val_outbin_acc: 0.8505
# Epoch 20/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6272 - outmap_loss: -0.6306 - outbin_loss: 0.3395 - outmap_dice_coef: 0.6306 - outbin_acc: 0.8608Epoch 00019: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6267 - outmap_loss: -0.6301 - outbin_loss: 0.3386 - outmap_dice_coef: 0.6301 - outbin_acc: 0.8608 - val_loss: -0.6654 - val_outmap_loss: -0.6686 - val_outbin_loss: 0.3118 - val_outmap_dice_coef: 0.6686 - val_outbin_acc: 0.8848
# Epoch 21/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6389 - outmap_loss: -0.6423 - outbin_loss: 0.3389 - outmap_dice_coef: 0.6423 - outbin_acc: 0.8571Epoch 00020: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6397 - outmap_loss: -0.6431 - outbin_loss: 0.3399 - outmap_dice_coef: 0.6431 - outbin_acc: 0.8568 - val_loss: -0.6731 - val_outmap_loss: -0.6771 - val_outbin_loss: 0.4003 - val_outmap_dice_coef: 0.6771 - val_outbin_acc: 0.8358
# Epoch 22/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6450 - outmap_loss: -0.6480 - outbin_loss: 0.3068 - outmap_dice_coef: 0.6480 - outbin_acc: 0.8744Epoch 00021: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6455 - outmap_loss: -0.6486 - outbin_loss: 0.3061 - outmap_dice_coef: 0.6486 - outbin_acc: 0.8745 - val_loss: -0.6660 - val_outmap_loss: -0.6696 - val_outbin_loss: 0.3654 - val_outmap_dice_coef: 0.6696 - val_outbin_acc: 0.8775
# Epoch 23/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6438 - outmap_loss: -0.6468 - outbin_loss: 0.2983 - outmap_dice_coef: 0.6468 - outbin_acc: 0.8785Epoch 00022: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6434 - outmap_loss: -0.6464 - outbin_loss: 0.3009 - outmap_dice_coef: 0.6464 - outbin_acc: 0.8774 - val_loss: -0.6766 - val_outmap_loss: -0.6799 - val_outbin_loss: 0.3244 - val_outmap_dice_coef: 0.6799 - val_outbin_acc: 0.8578
# Epoch 24/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6414 - outmap_loss: -0.6445 - outbin_loss: 0.3112 - outmap_dice_coef: 0.6445 - outbin_acc: 0.8733Epoch 00023: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6420 - outmap_loss: -0.6451 - outbin_loss: 0.3102 - outmap_dice_coef: 0.6451 - outbin_acc: 0.8736 - val_loss: -0.6675 - val_outmap_loss: -0.6709 - val_outbin_loss: 0.3435 - val_outmap_dice_coef: 0.6709 - val_outbin_acc: 0.8897
# Epoch 25/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6503 - outmap_loss: -0.6534 - outbin_loss: 0.3073 - outmap_dice_coef: 0.6534 - outbin_acc: 0.8724Epoch 00024: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6493 - outmap_loss: -0.6524 - outbin_loss: 0.3071 - outmap_dice_coef: 0.6524 - outbin_acc: 0.8722 - val_loss: -0.6732 - val_outmap_loss: -0.6767 - val_outbin_loss: 0.3495 - val_outmap_dice_coef: 0.6767 - val_outbin_acc: 0.8529
# Epoch 26/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6463 - outmap_loss: -0.6494 - outbin_loss: 0.3032 - outmap_dice_coef: 0.6494 - outbin_acc: 0.8762Epoch 00025: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6462 - outmap_loss: -0.6492 - outbin_loss: 0.3026 - outmap_dice_coef: 0.6492 - outbin_acc: 0.8768 - val_loss: -0.6633 - val_outmap_loss: -0.6671 - val_outbin_loss: 0.3783 - val_outmap_dice_coef: 0.6671 - val_outbin_acc: 0.8505
# Epoch 27/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6562 - outmap_loss: -0.6590 - outbin_loss: 0.2853 - outmap_dice_coef: 0.6590 - outbin_acc: 0.8796Epoch 00026: val_loss did not improve
# 3498/3498 [==============================] - 42s - loss: -0.6563 - outmap_loss: -0.6592 - outbin_loss: 0.2869 - outmap_dice_coef: 0.6592 - outbin_acc: 0.8788 - val_loss: -0.6650 - val_outmap_loss: -0.6685 - val_outbin_loss: 0.3469 - val_outmap_dice_coef: 0.6685 - val_outbin_acc: 0.8480
# Epoch 28/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6546 - outmap_loss: -0.6575 - outbin_loss: 0.2883 - outmap_dice_coef: 0.6575 - outbin_acc: 0.8837Epoch 00027: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6529 - outmap_loss: -0.6558 - outbin_loss: 0.2901 - outmap_dice_coef: 0.6558 - outbin_acc: 0.8831 - val_loss: -0.6644 - val_outmap_loss: -0.6686 - val_outbin_loss: 0.4152 - val_outmap_dice_coef: 0.6686 - val_outbin_acc: 0.8260
# Epoch 29/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6600 - outmap_loss: -0.6629 - outbin_loss: 0.2865 - outmap_dice_coef: 0.6629 - outbin_acc: 0.8843Epoch 00028: val_loss improved from -0.68162 to -0.70656, saving model to weights.hdf5
# 3498/3498 [==============================] - 41s - loss: -0.6610 - outmap_loss: -0.6639 - outbin_loss: 0.2851 - outmap_dice_coef: 0.6639 - outbin_acc: 0.8848 - val_loss: -0.7066 - val_outmap_loss: -0.7096 - val_outbin_loss: 0.3054 - val_outmap_dice_coef: 0.7096 - val_outbin_acc: 0.8799
# Epoch 30/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6613 - outmap_loss: -0.6641 - outbin_loss: 0.2799 - outmap_dice_coef: 0.6641 - outbin_acc: 0.8903Epoch 00029: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6608 - outmap_loss: -0.6636 - outbin_loss: 0.2792 - outmap_dice_coef: 0.6636 - outbin_acc: 0.8908 - val_loss: -0.6968 - val_outmap_loss: -0.6998 - val_outbin_loss: 0.3037 - val_outmap_dice_coef: 0.6998 - val_outbin_acc: 0.8775
# Epoch 31/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6693 - outmap_loss: -0.6720 - outbin_loss: 0.2726 - outmap_dice_coef: 0.6720 - outbin_acc: 0.8909Epoch 00030: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6704 - outmap_loss: -0.6731 - outbin_loss: 0.2707 - outmap_dice_coef: 0.6731 - outbin_acc: 0.8922 - val_loss: -0.6912 - val_outmap_loss: -0.6945 - val_outbin_loss: 0.3244 - val_outmap_dice_coef: 0.6945 - val_outbin_acc: 0.8775
# Epoch 32/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6640 - outmap_loss: -0.6668 - outbin_loss: 0.2819 - outmap_dice_coef: 0.6668 - outbin_acc: 0.8866Epoch 00031: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6638 - outmap_loss: -0.6666 - outbin_loss: 0.2823 - outmap_dice_coef: 0.6666 - outbin_acc: 0.8856 - val_loss: -0.6714 - val_outmap_loss: -0.6749 - val_outbin_loss: 0.3464 - val_outmap_dice_coef: 0.6749 - val_outbin_acc: 0.8456
# Epoch 33/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6718 - outmap_loss: -0.6748 - outbin_loss: 0.2981 - outmap_dice_coef: 0.6748 - outbin_acc: 0.8802Epoch 00032: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6711 - outmap_loss: -0.6741 - outbin_loss: 0.2978 - outmap_dice_coef: 0.6741 - outbin_acc: 0.8802 - val_loss: -0.6861 - val_outmap_loss: -0.6889 - val_outbin_loss: 0.2886 - val_outmap_dice_coef: 0.6889 - val_outbin_acc: 0.8701
# Epoch 34/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6680 - outmap_loss: -0.6707 - outbin_loss: 0.2696 - outmap_dice_coef: 0.6707 - outbin_acc: 0.8924Epoch 00033: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6689 - outmap_loss: -0.6716 - outbin_loss: 0.2682 - outmap_dice_coef: 0.6716 - outbin_acc: 0.8931 - val_loss: -0.6901 - val_outmap_loss: -0.6934 - val_outbin_loss: 0.3262 - val_outmap_dice_coef: 0.6934 - val_outbin_acc: 0.8578
# Epoch 35/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6693 - outmap_loss: -0.6720 - outbin_loss: 0.2702 - outmap_dice_coef: 0.6720 - outbin_acc: 0.8944Epoch 00034: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6694 - outmap_loss: -0.6721 - outbin_loss: 0.2700 - outmap_dice_coef: 0.6721 - outbin_acc: 0.8945 - val_loss: -0.6839 - val_outmap_loss: -0.6871 - val_outbin_loss: 0.3186 - val_outmap_dice_coef: 0.6871 - val_outbin_acc: 0.8676
# Epoch 36/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6672 - outmap_loss: -0.6698 - outbin_loss: 0.2588 - outmap_dice_coef: 0.6698 - outbin_acc: 0.8935Epoch 00035: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6676 - outmap_loss: -0.6702 - outbin_loss: 0.2598 - outmap_dice_coef: 0.6702 - outbin_acc: 0.8939 - val_loss: -0.6656 - val_outmap_loss: -0.6695 - val_outbin_loss: 0.3925 - val_outmap_dice_coef: 0.6695 - val_outbin_acc: 0.8627
# Epoch 37/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6745 - outmap_loss: -0.6771 - outbin_loss: 0.2594 - outmap_dice_coef: 0.6771 - outbin_acc: 0.8947Epoch 00036: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6747 - outmap_loss: -0.6773 - outbin_loss: 0.2594 - outmap_dice_coef: 0.6773 - outbin_acc: 0.8948 - val_loss: -0.6821 - val_outmap_loss: -0.6862 - val_outbin_loss: 0.4091 - val_outmap_dice_coef: 0.6862 - val_outbin_acc: 0.8309
# Epoch 38/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6774 - outmap_loss: -0.6799 - outbin_loss: 0.2458 - outmap_dice_coef: 0.6799 - outbin_acc: 0.9057Epoch 00037: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6781 - outmap_loss: -0.6806 - outbin_loss: 0.2461 - outmap_dice_coef: 0.6806 - outbin_acc: 0.9065 - val_loss: -0.6830 - val_outmap_loss: -0.6862 - val_outbin_loss: 0.3177 - val_outmap_dice_coef: 0.6862 - val_outbin_acc: 0.8529
# Epoch 39/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6818 - outmap_loss: -0.6843 - outbin_loss: 0.2510 - outmap_dice_coef: 0.6843 - outbin_acc: 0.8990Epoch 00038: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6828 - outmap_loss: -0.6853 - outbin_loss: 0.2492 - outmap_dice_coef: 0.6853 - outbin_acc: 0.8999 - val_loss: -0.6905 - val_outmap_loss: -0.6938 - val_outbin_loss: 0.3298 - val_outmap_dice_coef: 0.6938 - val_outbin_acc: 0.8554
# Epoch 40/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6686 - outmap_loss: -0.6712 - outbin_loss: 0.2639 - outmap_dice_coef: 0.6712 - outbin_acc: 0.8979Epoch 00039: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6672 - outmap_loss: -0.6699 - outbin_loss: 0.2648 - outmap_dice_coef: 0.6699 - outbin_acc: 0.8977 - val_loss: -0.6419 - val_outmap_loss: -0.6460 - val_outbin_loss: 0.4193 - val_outmap_dice_coef: 0.6460 - val_outbin_acc: 0.8431
# Epoch 41/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6630 - outmap_loss: -0.6657 - outbin_loss: 0.2749 - outmap_dice_coef: 0.6657 - outbin_acc: 0.8892Epoch 00040: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6639 - outmap_loss: -0.6666 - outbin_loss: 0.2770 - outmap_dice_coef: 0.6666 - outbin_acc: 0.8882 - val_loss: -0.6516 - val_outmap_loss: -0.6552 - val_outbin_loss: 0.3566 - val_outmap_dice_coef: 0.6552 - val_outbin_acc: 0.8480
# Epoch 42/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6737 - outmap_loss: -0.6762 - outbin_loss: 0.2450 - outmap_dice_coef: 0.6762 - outbin_acc: 0.9013Epoch 00041: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6740 - outmap_loss: -0.6764 - outbin_loss: 0.2453 - outmap_dice_coef: 0.6764 - outbin_acc: 0.9011 - val_loss: -0.6859 - val_outmap_loss: -0.6893 - val_outbin_loss: 0.3419 - val_outmap_dice_coef: 0.6893 - val_outbin_acc: 0.8456
# Epoch 43/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6833 - outmap_loss: -0.6856 - outbin_loss: 0.2288 - outmap_dice_coef: 0.6856 - outbin_acc: 0.9146Epoch 00042: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6839 - outmap_loss: -0.6862 - outbin_loss: 0.2282 - outmap_dice_coef: 0.6862 - outbin_acc: 0.9148 - val_loss: -0.6514 - val_outmap_loss: -0.6553 - val_outbin_loss: 0.3903 - val_outmap_dice_coef: 0.6553 - val_outbin_acc: 0.8382
# Epoch 44/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6787 - outmap_loss: -0.6812 - outbin_loss: 0.2509 - outmap_dice_coef: 0.6812 - outbin_acc: 0.8993Epoch 00043: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6795 - outmap_loss: -0.6820 - outbin_loss: 0.2504 - outmap_dice_coef: 0.6820 - outbin_acc: 0.8997 - val_loss: -0.6997 - val_outmap_loss: -0.7029 - val_outbin_loss: 0.3148 - val_outmap_dice_coef: 0.7029 - val_outbin_acc: 0.8652
# Epoch 45/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6867 - outmap_loss: -0.6890 - outbin_loss: 0.2272 - outmap_dice_coef: 0.6890 - outbin_acc: 0.9117Epoch 00044: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6871 - outmap_loss: -0.6894 - outbin_loss: 0.2278 - outmap_dice_coef: 0.6894 - outbin_acc: 0.9114 - val_loss: -0.6999 - val_outmap_loss: -0.7033 - val_outbin_loss: 0.3416 - val_outmap_dice_coef: 0.7033 - val_outbin_acc: 0.8529
# Epoch 46/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6849 - outmap_loss: -0.6871 - outbin_loss: 0.2216 - outmap_dice_coef: 0.6871 - outbin_acc: 0.9161Epoch 00045: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6856 - outmap_loss: -0.6878 - outbin_loss: 0.2222 - outmap_dice_coef: 0.6878 - outbin_acc: 0.9162 - val_loss: -0.6941 - val_outmap_loss: -0.6979 - val_outbin_loss: 0.3764 - val_outmap_dice_coef: 0.6979 - val_outbin_acc: 0.8333
# Epoch 47/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6918 - outmap_loss: -0.6940 - outbin_loss: 0.2211 - outmap_dice_coef: 0.6940 - outbin_acc: 0.9172Epoch 00046: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6916 - outmap_loss: -0.6938 - outbin_loss: 0.2210 - outmap_dice_coef: 0.6938 - outbin_acc: 0.9174 - val_loss: -0.6988 - val_outmap_loss: -0.7021 - val_outbin_loss: 0.3297 - val_outmap_dice_coef: 0.7021 - val_outbin_acc: 0.8676
# Epoch 48/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6858 - outmap_loss: -0.6881 - outbin_loss: 0.2300 - outmap_dice_coef: 0.6881 - outbin_acc: 0.9077Epoch 00047: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6869 - outmap_loss: -0.6892 - outbin_loss: 0.2296 - outmap_dice_coef: 0.6892 - outbin_acc: 0.9077 - val_loss: -0.6918 - val_outmap_loss: -0.6953 - val_outbin_loss: 0.3484 - val_outmap_dice_coef: 0.6953 - val_outbin_acc: 0.8480
# Epoch 49/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6846 - outmap_loss: -0.6870 - outbin_loss: 0.2367 - outmap_dice_coef: 0.6870 - outbin_acc: 0.9028Epoch 00048: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6849 - outmap_loss: -0.6873 - outbin_loss: 0.2356 - outmap_dice_coef: 0.6873 - outbin_acc: 0.9031 - val_loss: -0.6915 - val_outmap_loss: -0.6950 - val_outbin_loss: 0.3512 - val_outmap_dice_coef: 0.6950 - val_outbin_acc: 0.8382
# Epoch 50/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6955 - outmap_loss: -0.6978 - outbin_loss: 0.2339 - outmap_dice_coef: 0.6978 - outbin_acc: 0.9083Epoch 00049: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6953 - outmap_loss: -0.6976 - outbin_loss: 0.2347 - outmap_dice_coef: 0.6976 - outbin_acc: 0.9074 - val_loss: -0.6909 - val_outmap_loss: -0.6953 - val_outbin_loss: 0.4425 - val_outmap_dice_coef: 0.6953 - val_outbin_acc: 0.8284
# Epoch 51/60
# 3456/3498 [============================>.] - ETA: 0s - loss: -0.6875 - outmap_loss: -0.6900 - outbin_loss: 0.2479 - outmap_dice_coef: 0.6900 - outbin_acc: 0.9016Epoch 00050: val_loss did not improve
# 3498/3498 [==============================] - 41s - loss: -0.6867 - outmap_loss: -0.6892 - outbin_loss: 0.2497 - outmap_dice_coef: 0.6892 - outbin_acc: 0.8999 - val_loss: -0.6813 - val_outmap_loss: -0.6849 - val_outbin_loss: 0.3597 - val_outmap_dice_coef: 0.6849 - val_outbin_acc: 0.8284
# Epoch 52/60
# 3328/3498 [===========================>..] - ETA: 1s - loss: -0.6921 - outmap_loss: -0.6943 - outbin_loss: 0.2144 - outmap_dice_coef: 0.6943 - outbin_acc: 0.9126
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-b9f675be66b3> in <module>()
#      13         verbose=1,
#      14         shuffle=True,
# ---> 15         callbacks=[model_checkpoint]
#      16     )
#      17     pl.plot(history.history['loss'], label='train loss')
#
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight)
#    1050                               verbose=verbose, callbacks=callbacks,
#    1051                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
# -> 1052                               callback_metrics=callback_metrics)
#    1053
#    1054     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, nb_epoch, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics)
#     788                 batch_logs['size'] = len(batch_ids)
#     789                 callbacks.on_batch_begin(batch_index, batch_logs)
# --> 790                 outs = f(ins_batch)
#     791                 if type(outs) != list:
#     792                     outs = [outs]
#
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/backend/theano_backend.pyc in __call__(self, inputs)
#     516     def __call__(self, inputs):
#     517         assert type(inputs) in {list, tuple}
# --> 518         return self.function(*inputs)
#     519
#     520
#
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/theano/gof/op.pyc in rval(p, i, o, n)
#     909         if params is graph.NoParams:
#     910             # default arguments are stored in the closure of `rval`
# --> 911             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
#     912                 r = p(n, [x[0] for x in i], o)
#     913                 for o in node.outputs:
#
# KeyboardInterrupt:

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights.hdf5'))

# %%
conv1 = model.layers[1].output
_f = K.function([K.learning_phase(), input_img], [conv1])
_convout = _f([0, X_test[:1]])[0]
print _convout.shape

maxout1 = model.layers[3].output
_f = K.function([K.learning_phase(), input_img], [maxout1])
_maxout = _f([0, X_test[:1]])[0]
print _maxout.shape

pl.figure()
pl.imshow(_convout[0, 0], interpolation='nearest')
pl.colorbar()
pl.figure()
pl.imshow(_maxout[0, 0], interpolation='nearest')
pl.colorbar()
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/keras/backend/theano_backend.py:514: UserWarning: theano.function was asked to create a function computing outputs given certain inputs, but the provided input variable at index 0 is not part of the computational graph needed to compute the outputs: keras_learning_phase.
# To make this warning into an error, you can pass the parameter on_unused_input='raise' to theano.function. To disable it completely, use on_unused_input='ignore'.
#   **kwargs)
# (1, 16, 128, 128)
# (1, 16, 128, 128)
# <matplotlib.colorbar.Colorbar instance at 0x7f57a9d0ecb0>
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
def predict(X):
    Y_pred, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > 0.3
    for i in range(Y_pred.shape[0]):
        # Clear prediction where we detect to little pixels
        # Figure it out by
        # pl.hist(np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1))
        #if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < 0.2:
        if np.sum(Y_pred[i]) < 150:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test)
Y_full_pred, Y_full_pred_proba, Y_full_pred_binary = predict(X_full)

print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "avg test set score : ", utils.average_dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
print "avg full set score : ", utils.average_dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.705237872343
# avg test set score :  0.761570682657
# full set score :  0.616878390778
# avg full set score :  0.74594058961

# %%
_ = pl.hist(Y_pred_binary)

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[150:155]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 0
img, pred_map = dream_output(Y_full[i])
pl.figure(figsize=(12, 4))
pl.subplot(131)
pl.imshow(Y_full[i].squeeze())
pl.subplot(132)
pl.imshow(img, cmap=cm.gray)
pl.subplot(133)
pl.imshow(pred_map.squeeze())

# %%
# Dream for the binary output
def dream_binoutput(output):
    
    layer_output = layer_dict['outbin'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output - layer_output[:, 0]))
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    
    step = 0.1
    for i in range(40):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    _, model_pred = model.predict(img[None,None,:,:])
    return img, model_pred

img, model_pred = dream_binoutput(1)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
img, model_pred = dream_binoutput(0)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
def dream_layer_filter(layer_name, filter_index):

    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(8):
        pl.subplot(2, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
if True:
    import cv2
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(50,50))
    
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    test_fnames = _d['test_fnames']
    Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:])
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
        imre = cv2.morphologyEx(imre, cv2.MORPH_CLOSE, kernel)
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
        
        if i % 10 == 0:
            print '\r%d / %d' % (i, len(test_fnames)),
            sys.stdout.flush()
# Out:
# 5500 / 5508

# %% [markdown]
# ## Stats on predicted masks

# %%
# on Y_full
nbp_pixels = np.sum(np.sum(np.sum(Y_full, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
