# %% [markdown]
# validation fails to converge

# %%
import sys
sys.path.append('../notebooks')
import utils
import os
import numpy as np
import glob
import cv2
import utils
import pylab as pl
import shutil
import matplotlib.cm as cm
from sklearn.cross_validation import train_test_split
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning, module='.*/ipykernel/.*')
# %matplotlib inline
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):

# %%
_d = np.load('../data/data_clean_128_train.npz')
X = _d['X']
Y = _d['Y']
X_pids = _d['pids']

# Turn labels into boolean present/missing
Y_binary = np.sum(np.sum(Y, axis=2), axis=1) > 0
Y_binary = Y_binary.astype(np.float32)

# %%
# Also load the non-filtered data for evaluation
_d = np.load('../data/data_128_train.npz')
X_full = _d['X'][:,None,:,:]
Y_full = _d['Y'][:,None,:,:]

# %%
print X.shape
print Y.shape
print X.dtype
print Y.dtype
# Out:
# (3906, 128, 128)
# (3906, 128, 128)
# float32
# float32

# %%
if False:
    # Split patients in train/test
    train_pids, test_pids = train_test_split(np.unique(X_pids), test_size=0.2)
    print train_pids
    print test_pids
    
    train_indices = np.flatnonzero(np.in1d(X_pids, train_pids))
    test_indices = np.flatnonzero(np.in1d(X_pids, test_pids))
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]
else:
    nsamples = X.shape[0]

    #train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.1)
    train_indices, test_indices = train_test_split(np.arange(nsamples), test_size=0.2)
    X_train = X[train_indices][:,None,:,:]
    Y_train_binary = Y_binary[train_indices][:,None]
    Y_train = Y[train_indices][:,None,:,:]
    X_test = X[test_indices][:,None,:,:]
    Y_test_binary = Y_binary[test_indices][:,None]
    Y_test = Y[test_indices][:,None,:,:]

# %%
import skimage.transform as sktransf

def rand_float(rng):
    return rng[0] + np.random.random() * (rng[1] - rng[0])

def generate_image(X_img, Y_img, angle_range=None, zoom_range=None, shear_range=None, horiz_shift_range=None,
                   vert_shift_range=None):
    """
    Randomly shift an image by resizing and then random croping
    the resized image
    """
    if angle_range is None:
        angle_range = (-5, 5)
    if zoom_range is None:
        zoom_range = (0.8, 1.2)
    if shear_range is None:
        shear_range = (-5, 5) # shear angle in degrees
    if horiz_shift_range is None:
        horiz_shift_range = (-5, 5)
    if vert_shift_range is None:
        vert_shift_range = (-5, 5)
    inshape = X_img.shape
    
    X2 = X_img.copy()
    Y2 = Y_img.copy()
    
    # -- random rotation
    angle = np.deg2rad(rand_float(angle_range))
    zoom = rand_float(zoom_range)
    shear = np.deg2rad(rand_float(shear_range))
    horiz_shift = rand_float(horiz_shift_range)
    vert_shift = rand_float(vert_shift_range)
    
    tform = sktransf.AffineTransform(
        scale=(zoom, zoom),
        rotation=angle,
        shear=shear,
        translation=(horiz_shift, vert_shift)
    )
    X2 = sktransf.warp(X2, tform, order=5, mode='edge')
    Y2 = sktransf.warp(Y2, tform, order=1)

    # gaussian noise
    #noise_scale = rand_float((0, 0.1))
    #X2 += np.random.normal(scale=noise_scale, size=X2.shape)
    Y2 = Y2 > 0.5
    return X2[None,:,:].astype(np.float32), Y2[None,:,:].astype(np.float32)

X_train_augmented = []
Y_train_augmented = []
for i in range(X_train.shape[0]):
    if i % 10 == 0:
        print '\r%d / %d' % (i, X_train.shape[0]),
        sys.stdout.flush()
    X_train_augmented.append(X_train[i])
    Y_train_augmented.append(Y_train[i])
    for j in range(2):
        X2, Y2 = generate_image(X_train[i].squeeze(), Y_train[i].squeeze())
        X_train_augmented.append(X2)
        Y_train_augmented.append(Y2)
# Out:
# 3120 / 3124

# %%
X_train = np.array(X_train_augmented, dtype=np.float32)
Y_train = np.array(Y_train_augmented, dtype=np.float32)

Y_train_binary = np.sum(np.sum(Y_train.squeeze(), axis=2), axis=1) > 0
Y_train_binary = Y_train_binary.astype(np.float32)
Y_train_binary = Y_train_binary[:,None]

# %%
print X_train.shape
print Y_train.shape
print X_test.shape
print X_train.min(), X_train.max()
# Out:
# (9372, 1, 128, 128)
# (9372, 1, 128, 128)
# (782, 1, 128, 128)
# 0.0 1.0

# %%
import cv2
def _resize(Y, outshape):
    return cv2.resize(Y.squeeze(), outshape, interpolation=cv2.INTER_AREA)[None, :, :]
Y_train_88 = np.array([_resize(img, (8, 8)) for img in Y_train])
Y_test_88 = np.array([_resize(img, (8, 8)) for img in Y_test])
Y_train_44 = np.array([_resize(img, (4, 4)) for img in Y_train])
Y_test_44 = np.array([_resize(img, (4, 4)) for img in Y_test])

# %%
with_bp = np.flatnonzero(np.sum(np.sum(np.sum(Y_train, axis=1), axis=1), axis=1))

# %%
for bpi in range(11, 14):
    i = with_bp[bpi]
    pl.figure(figsize=(16, 4))
    pl.subplot(141)
    pl.imshow(X_train[i].squeeze())
    pl.subplot(142)
    pl.imshow(Y_train[i].squeeze())
    pl.subplot(143)
    pl.imshow(Y_train_88[i].squeeze(), interpolation='nearest')
    pl.colorbar()
    pl.subplot(144)
    pl.imshow(Y_train_44[i].squeeze(), interpolation='nearest')
    pl.colorbar()
# Out:
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/julien/kaggle/venv/local/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %% [markdown]
# # Keras model

# %%
# channels first in keras
input_shape = X_train[0].shape
print input_shape
# Out:
# (1, 128, 128)

# %%
os.environ['KERAS_BACKEND'] = 'theano'
# TODO: Use float16 ?
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu0,floatX=float32'
import keras
from keras.layers import Input, Dense, Dropout, Activation, Flatten, merge, RepeatVector, Permute, Reshape
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D, MaxoutDense
from keras.layers import LeakyReLU, BatchNormalization
from keras.models import Model
from keras.optimizers import SGD, RMSprop
from keras.utils.layer_utils import print_summary
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
import keras.backend as K
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 960 (CNMeM is disabled, cuDNN 4007)

# %%
import theano
print theano.config.device
# Out:
# gpu0

# %%
from keras.layers import Layer, InputSpec
import keras.initializations
import keras.backend as K

class Maxout2D(Layer):
    def __init__(self, output_dim, cardinality, init='glorot_uniform', **kwargs):
        super(Maxout2D, self).__init__(**kwargs)
        # the k of the maxout paper
        self.cardinality = cardinality
        # the m of the maxout paper
        self.output_dim = output_dim
        self.init = keras.initializations.get(init)
    
    def build(self, input_shape):
        self.input_dim = input_shape[1]
        self.input_spec = [InputSpec(dtype=K.floatx(),
                                     shape=(None, input_shape[1], input_shape[2], input_shape[3]))]
        self.W = self.init((self.input_dim, self.output_dim, self.cardinality),
                           name='{}_W'.format(self.name))
        self.b = K.zeros((self.output_dim, self.cardinality))
        self.trainable_weights = [self.W, self.b]
              
    def call(self, x, mask=None):
        input_shape = self.input_spec[0].shape
        # flatten the spatial dimensions
        flat_x = K.reshape(x, (-1, input_shape[1], input_shape[2] * input_shape[3]))
        output = K.dot(
            K.permute_dimensions(flat_x, (0, 2, 1)),
            K.permute_dimensions(self.W, (1, 0, 2))
        )
        output += K.reshape(self.b, (1, 1, self.output_dim, self.cardinality))
        output = K.max(output, axis=3)
        output = output.transpose(0, 2, 1)
        output = K.reshape(output, (-1, self.output_dim, input_shape[2], input_shape[3]))
        return output
    
    def get_output_shape_for(self, input_shape):
        return (input_shape[0], self.output_dim, input_shape[2], input_shape[3])
    
    def get_config(self):
        config = {
            'output_dim': self.output_dim,
            'cardinality': self.cardinality
        }
        base_config = super(Maxout2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
# https://www.kaggle.com/c/ultrasound-nerve-segmentation/forums/t/21358/0-57-deep-learning-keras-tutorial
smooth = 1.

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def dice_coef_batchwise(y_true, y_pred):
    y_true_f = K.batch_flatten(y_true)
    y_pred_f = K.batch_flatten(y_pred)
    intersection = 2. * K.sum(y_true_f * y_pred_f, axis=1, keepdims=True) + smooth
    union = K.sum(y_true_f, axis=1, keepdims=True) + \
            K.sum(y_pred_f, axis=1, keepdims=True) + \
            smooth
    return K.mean(intersection / union)

def dice_coef_loss_batchwise(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %% [markdown]
# http://torch.ch/blog/2015/07/30/cifar.html

# %%
def Inception5(x, name):
    """
    Inception-v2 module as described in Figure 5. of
    "Revisiting the inception architecture for computer vision"
    """
    x1 = Convolution2D(8, 1, 1, border_mode='same', activation='relu')(x)
    x1 = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x1)
    x1 = Convolution2D(16, 3, 3, border_mode='same', activation='relu')(x1)
    x1 = Convolution2D(16, 3, 3, border_mode='same', activation='relu', subsample=(2, 2))(x1)
    
    x2 = Convolution2D(8, 1, 1, border_mode='same', activation='relu')(x)
    x2 = Convolution2D(16, 3, 3, border_mode='same', activation='relu', subsample=(2, 2))(x2)
    
    x3 = MaxPooling2D((2, 2))(x)
    x3 = Convolution2D(16, 1, 1, border_mode='same', activation='relu')(x3)
    
    x4 = Convolution2D(16, 1, 1, border_mode='same', subsample=(2, 2))(x)
    
    x = merge([x1, x2, x3, x4], mode='concat', concat_axis=1, name=name)
    return x

# %%
input_img = x = Input(shape=input_shape, name='input_img')
x = Dropout(0.25)(x)
pool1 = x = Inception5(x, name='pool1')
x = Dropout(0.25)(x)
pool2 = x = Inception5(x, name='pool2')
x = Dropout(0.25)(x)
pool3 = x = Inception5(x, name='pool3')
x = Dropout(0.25)(x)
pool4 = x = Inception5(x, name='pool4')
x = Dropout(0.25)(x)
pool5 = x = Inception5(x, name='pool5')

#x = Convolution2D(32, 3, 3, border_mode='same', activation='relu')(input_img)
#x = Convolution2D(32, 3, 3, border_mode='same', activation='relu')(x)
#x = Convolution2D(32, 3, 3, border_mode='same', activation='relu')(x)
#pool1 = x = MaxPooling2D((2, 2), name='pool1')(x)

#x = Dropout(0.25)(x)
#x = Convolution2D(64, 3, 3, border_mode='same', activation='relu')(x)
#x = Convolution2D(64, 3, 3, border_mode='same', activation='relu')(x)
#x = Convolution2D(64, 3, 3, border_mode='same', activation='relu')(x)
#pool2 = x = MaxPooling2D((2, 2), name='pool2')(x)

#x = Dropout(0.25)(x)
#x = Convolution2D(64, 3, 3, border_mode='same', activation='relu')(x)
#x = Convolution2D(64, 3, 3, border_mode='same', activation='relu')(x)
#x = Convolution2D(64, 3, 3, border_mode='same', activation='relu')(x)
#pool3 = x = MaxPooling2D((2, 2), name='pool3')(x)

# -- binary presence part
#x = Dropout(0.25)(x)
#x = Convolution2D(32, 3, 3, border_mode='same', activation='relu')(x)
#x = Convolution2D(32, 3, 3, border_mode='same', activation='relu')(x)
#pool4 = x = MaxPooling2D((2, 2), name='pool4')(x)

#x = Dropout(0.25)(x)
#x = Convolution2D(32, 3, 3, border_mode='same', activation='relu')(x)
#x = Convolution2D(32, 3, 3, border_mode='same', activation='relu')(x)
#pool5 = x = MaxPooling2D((2, 2), name='pool5')(x)

# Since some images have not mask, the hope is that the innermost units capture this
x = Convolution2D(16, 1, 1, border_mode='same', activation='relu')(x)
x = Flatten()(x)
x = Dense(32, activation='relu')(x)
x = Dense(16, activation='relu')(x)
outbin = Dense(1, activation='sigmoid', name='outbin')(x)

# turn pool4 and 5 into classification map
outmap4 = Convolution2D(1, 3, 3, border_mode='same', activation='sigmoid', name='outmap4')(pool4)
outmap5 = Convolution2D(1, 3, 3, border_mode='same', activation='sigmoid', name='outmap5')(pool5)

# upsample the classif map
x = merge([
        UpSampling2D((2, 2))(outmap4),
        UpSampling2D((4, 4))(outmap5),
        pool3
    ], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(pool3)
x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool2], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(x)
x = UpSampling2D((2, 2))(x)

x = merge([x, pool1], mode='concat', concat_axis=1)
x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(x)
x = UpSampling2D((2, 2))(x)

x = Dropout(0.25)(x)
x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(8, 3, 3, border_mode='same', activation='relu')(x)
x = Convolution2D(1, 3, 3, border_mode='same')(x)
outmap = Convolution2D(1, 3, 3, activation='sigmoid', border_mode='same', name='outmap')(x)

model = Model(
    input=input_img,
    output=[outmap, outmap4, outmap5, outbin]
)

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(optimizer=sgd, loss='binary_crossentropy')
#rmsprop = RMSprop(lr=0.001, rho=0.9, epsilon=1e-08)
#model.compile(optimizer=rmsprop, loss='binary_crossentropy')
metrics={'outbin': 'accuracy'}
model.compile(optimizer='adam', loss='binary_crossentropy',
              loss_weights=[1., 0.2, 0.05, 0.01], metrics=metrics)

print_summary(model.layers)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                       Output Shape        Param #     Connected to
# ====================================================================================================
# input_img (InputLayer)             (None, 1, 128, 128) 0
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)                (None, 1, 128, 128) 0           input_img[0][0]
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)    (None, 8, 128, 128) 16          dropout_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)    (None, 16, 128, 128)1168        convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)    (None, 16, 128, 128)2320        convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5 (Convolution2D)    (None, 8, 128, 128) 16          dropout_1[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_1 (MaxPooling2D)      (None, 1, 64, 64)   0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)    (None, 16, 64, 64)  2320        convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_6 (Convolution2D)    (None, 16, 64, 64)  1168        convolution2d_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_7 (Convolution2D)    (None, 16, 64, 64)  32          maxpooling2d_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8 (Convolution2D)    (None, 16, 64, 64)  32          dropout_1[0][0]
# ____________________________________________________________________________________________________
# pool1 (Merge)                      (None, 64, 64, 64)  0           convolution2d_4[0][0]
#                                                                    convolution2d_6[0][0]
#                                                                    convolution2d_7[0][0]
#                                                                    convolution2d_8[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)                (None, 64, 64, 64)  0           pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_9 (Convolution2D)    (None, 8, 64, 64)   520         dropout_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_10 (Convolution2D)   (None, 16, 64, 64)  1168        convolution2d_9[0][0]
# ____________________________________________________________________________________________________
# convolution2d_11 (Convolution2D)   (None, 16, 64, 64)  2320        convolution2d_10[0][0]
# ____________________________________________________________________________________________________
# convolution2d_13 (Convolution2D)   (None, 8, 64, 64)   520         dropout_2[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_2 (MaxPooling2D)      (None, 64, 32, 32)  0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_12 (Convolution2D)   (None, 16, 32, 32)  2320        convolution2d_11[0][0]
# ____________________________________________________________________________________________________
# convolution2d_14 (Convolution2D)   (None, 16, 32, 32)  1168        convolution2d_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_15 (Convolution2D)   (None, 16, 32, 32)  1040        maxpooling2d_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_16 (Convolution2D)   (None, 16, 32, 32)  1040        dropout_2[0][0]
# ____________________________________________________________________________________________________
# pool2 (Merge)                      (None, 64, 32, 32)  0           convolution2d_12[0][0]
#                                                                    convolution2d_14[0][0]
#                                                                    convolution2d_15[0][0]
#                                                                    convolution2d_16[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)                (None, 64, 32, 32)  0           pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_17 (Convolution2D)   (None, 8, 32, 32)   520         dropout_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_18 (Convolution2D)   (None, 16, 32, 32)  1168        convolution2d_17[0][0]
# ____________________________________________________________________________________________________
# convolution2d_19 (Convolution2D)   (None, 16, 32, 32)  2320        convolution2d_18[0][0]
# ____________________________________________________________________________________________________
# convolution2d_21 (Convolution2D)   (None, 8, 32, 32)   520         dropout_3[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_3 (MaxPooling2D)      (None, 64, 16, 16)  0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_20 (Convolution2D)   (None, 16, 16, 16)  2320        convolution2d_19[0][0]
# ____________________________________________________________________________________________________
# convolution2d_22 (Convolution2D)   (None, 16, 16, 16)  1168        convolution2d_21[0][0]
# ____________________________________________________________________________________________________
# convolution2d_23 (Convolution2D)   (None, 16, 16, 16)  1040        maxpooling2d_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_24 (Convolution2D)   (None, 16, 16, 16)  1040        dropout_3[0][0]
# ____________________________________________________________________________________________________
# pool3 (Merge)                      (None, 64, 16, 16)  0           convolution2d_20[0][0]
#                                                                    convolution2d_22[0][0]
#                                                                    convolution2d_23[0][0]
#                                                                    convolution2d_24[0][0]
# ____________________________________________________________________________________________________
# convolution2d_41 (Convolution2D)   (None, 8, 16, 16)   4616        pool3[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)                (None, 64, 16, 16)  0           pool3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_25 (Convolution2D)   (None, 8, 16, 16)   520         dropout_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_42 (Convolution2D)   (None, 8, 16, 16)   584         convolution2d_41[0][0]
# ____________________________________________________________________________________________________
# convolution2d_26 (Convolution2D)   (None, 16, 16, 16)  1168        convolution2d_25[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_3 (UpSampling2D)      (None, 8, 32, 32)   0           convolution2d_42[0][0]
# ____________________________________________________________________________________________________
# convolution2d_27 (Convolution2D)   (None, 16, 16, 16)  2320        convolution2d_26[0][0]
# ____________________________________________________________________________________________________
# convolution2d_29 (Convolution2D)   (None, 8, 16, 16)   520         dropout_4[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_4 (MaxPooling2D)      (None, 64, 8, 8)    0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# merge_2 (Merge)                    (None, 72, 32, 32)  0           upsampling2d_3[0][0]
#                                                                    pool2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_28 (Convolution2D)   (None, 16, 8, 8)    2320        convolution2d_27[0][0]
# ____________________________________________________________________________________________________
# convolution2d_30 (Convolution2D)   (None, 16, 8, 8)    1168        convolution2d_29[0][0]
# ____________________________________________________________________________________________________
# convolution2d_31 (Convolution2D)   (None, 16, 8, 8)    1040        maxpooling2d_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_32 (Convolution2D)   (None, 16, 8, 8)    1040        dropout_4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_43 (Convolution2D)   (None, 8, 32, 32)   5192        merge_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_44 (Convolution2D)   (None, 8, 32, 32)   584         convolution2d_43[0][0]
# ____________________________________________________________________________________________________
# pool4 (Merge)                      (None, 64, 8, 8)    0           convolution2d_28[0][0]
#                                                                    convolution2d_30[0][0]
#                                                                    convolution2d_31[0][0]
#                                                                    convolution2d_32[0][0]
# ____________________________________________________________________________________________________
# dropout_5 (Dropout)                (None, 64, 8, 8)    0           pool4[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_4 (UpSampling2D)      (None, 8, 64, 64)   0           convolution2d_44[0][0]
# ____________________________________________________________________________________________________
# convolution2d_33 (Convolution2D)   (None, 8, 8, 8)     520         dropout_5[0][0]
# ____________________________________________________________________________________________________
# merge_3 (Merge)                    (None, 72, 64, 64)  0           upsampling2d_4[0][0]
#                                                                    pool1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_34 (Convolution2D)   (None, 16, 8, 8)    1168        convolution2d_33[0][0]
# ____________________________________________________________________________________________________
# convolution2d_45 (Convolution2D)   (None, 8, 64, 64)   5192        merge_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_35 (Convolution2D)   (None, 16, 8, 8)    2320        convolution2d_34[0][0]
# ____________________________________________________________________________________________________
# convolution2d_37 (Convolution2D)   (None, 8, 8, 8)     520         dropout_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_46 (Convolution2D)   (None, 8, 64, 64)   584         convolution2d_45[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_5 (MaxPooling2D)      (None, 64, 4, 4)    0           dropout_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_36 (Convolution2D)   (None, 16, 4, 4)    2320        convolution2d_35[0][0]
# ____________________________________________________________________________________________________
# convolution2d_38 (Convolution2D)   (None, 16, 4, 4)    1168        convolution2d_37[0][0]
# ____________________________________________________________________________________________________
# convolution2d_39 (Convolution2D)   (None, 16, 4, 4)    1040        maxpooling2d_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_40 (Convolution2D)   (None, 16, 4, 4)    1040        dropout_5[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_5 (UpSampling2D)      (None, 8, 128, 128) 0           convolution2d_46[0][0]
# ____________________________________________________________________________________________________
# dropout_6 (Dropout)                (None, 8, 128, 128) 0           upsampling2d_5[0][0]
# ____________________________________________________________________________________________________
# pool5 (Merge)                      (None, 64, 4, 4)    0           convolution2d_36[0][0]
#                                                                    convolution2d_38[0][0]
#                                                                    convolution2d_39[0][0]
#                                                                    convolution2d_40[0][0]
# ____________________________________________________________________________________________________
# convolution2d_47 (Convolution2D)   (None, 8, 128, 128) 584         dropout_6[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)                (None, 1024)        0           pool5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_48 (Convolution2D)   (None, 8, 128, 128) 584         convolution2d_47[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                    (None, 32)          32800       flatten_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_49 (Convolution2D)   (None, 1, 128, 128) 73          convolution2d_48[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                    (None, 16)          528         dense_1[0][0]
# ____________________________________________________________________________________________________
# outbin (Dense)                     (None, 1)           17          dense_2[0][0]
# ____________________________________________________________________________________________________
# outmap (Convolution2D)             (None, 1, 128, 128) 10          convolution2d_49[0][0]
# ____________________________________________________________________________________________________
# outmap4 (Convolution2D)            (None, 1, 8, 8)     577         pool4[0][0]
# ____________________________________________________________________________________________________
# outmap5 (Convolution2D)            (None, 1, 4, 4)     577         pool5[0][0]
# ====================================================================================================
# Total params: 99958
# ____________________________________________________________________________________________________

# %%
#from IPython.display import SVG
#from keras.utils.visualize_util import model_to_dot
#SVG(model_to_dot(model).create(prog='dot', format='svg'))

#from keras.utils.visualize_util import plot
#plot(model, to_file='model.png')

# %%
if True:
    json_string = model.to_json()
    open('architecture.json', 'w').write(json_string)
    
    model_checkpoint = ModelCheckpoint('weights.hdf5', monitor='val_loss', save_best_only=True, verbose=True)
    
    history = model.fit(
        X_train,
        {
            'outmap': Y_train,
            'outmap4' : Y_train_88,
            'outmap5' : Y_train_44,
            'outbin': Y_train_binary
        },
        batch_size=64,
        validation_data=(X_test, {
                'outmap': Y_test,
                'outmap4' : Y_test_88,
                'outmap5' : Y_test_44,
                'outbin': Y_test_binary
        }),
        nb_epoch=60,# 40 + 10 + 10 + 5 + 5
        verbose=1,
        shuffle=True,
        callbacks=[model_checkpoint]
    )
    
    pl.figure()
    pl.plot(history.history['outmap_loss'], label='train loss')
    pl.plot(history.history['val_outmap_loss'], c='g', label='val loss')
    pl.legend()

    pl.figure()
    pl.plot(history.history['outbin_acc'], label='train acc')
    pl.plot(history.history['val_outbin_acc'], c='g', label='val acc')
    pl.legend()
else:
    model_dir = '.'
    model = model_from_json(
        open(os.path.join(model_dir, 'architecture.json')).read(),
                custom_objects={'Maxout2D' : Maxout2D}
    )
    model.load_weights(os.path.join(model_dir, 'weights.hdf5'))
    model.compile(optimizer='adam', loss='binary_crossentropy',
                  loss_weights=[1., 0.01])
    
    print_summary(model.layers)
# Out:
# Train on 9372 samples, validate on 782 samples
# Epoch 1/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.1394 - outmap_loss: 0.1082 - outmap4_loss: 0.0985 - outmap5_loss: 0.0941 - outbin_loss: 0.6711 - outbin_acc: 0.6189Epoch 00000: val_loss improved from inf to 0.08591, saving model to weights.hdf5
# 9372/9372 [==============================] - 87s - loss: 0.1391 - outmap_loss: 0.1081 - outmap4_loss: 0.0984 - outmap5_loss: 0.0939 - outbin_loss: 0.6709 - outbin_acc: 0.6192 - val_loss: 0.0859 - val_outmap_loss: 0.0612 - val_outmap4_loss: 0.0648 - val_outmap5_loss: 0.1028 - val_outbin_loss: 0.6626 - val_outbin_acc: 0.6304
# Epoch 2/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0692 - outmap_loss: 0.0504 - outmap4_loss: 0.0482 - outmap5_loss: 0.0503 - outbin_loss: 0.6614 - outbin_acc: 0.6269Epoch 00001: val_loss improved from 0.08591 to 0.07793, saving model to weights.hdf5
# 9372/9372 [==============================] - 88s - loss: 0.0691 - outmap_loss: 0.0504 - outmap4_loss: 0.0482 - outmap5_loss: 0.0503 - outbin_loss: 0.6613 - outbin_acc: 0.6271 - val_loss: 0.0779 - val_outmap_loss: 0.0596 - val_outmap4_loss: 0.0428 - val_outmap5_loss: 0.0635 - val_outbin_loss: 0.6594 - val_outbin_acc: 0.6304
# Epoch 3/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0607 - outmap_loss: 0.0432 - outmap4_loss: 0.0432 - outmap5_loss: 0.0486 - outbin_loss: 0.6467 - outbin_acc: 0.6302Epoch 00002: val_loss did not improve
# 9372/9372 [==============================] - 88s - loss: 0.0607 - outmap_loss: 0.0432 - outmap4_loss: 0.0432 - outmap5_loss: 0.0486 - outbin_loss: 0.6465 - outbin_acc: 0.6306 - val_loss: 0.0978 - val_outmap_loss: 0.0769 - val_outmap4_loss: 0.0583 - val_outmap5_loss: 0.0468 - val_outbin_loss: 0.6930 - val_outbin_acc: 0.6304
# Epoch 4/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0552 - outmap_loss: 0.0388 - outmap4_loss: 0.0401 - outmap5_loss: 0.0463 - outbin_loss: 0.6071 - outbin_acc: 0.6713Epoch 00003: val_loss improved from 0.07793 to 0.06620, saving model to weights.hdf5
# 9372/9372 [==============================] - 88s - loss: 0.0552 - outmap_loss: 0.0388 - outmap4_loss: 0.0401 - outmap5_loss: 0.0463 - outbin_loss: 0.6071 - outbin_acc: 0.6715 - val_loss: 0.0662 - val_outmap_loss: 0.0505 - val_outmap4_loss: 0.0388 - val_outmap5_loss: 0.0433 - val_outbin_loss: 0.5790 - val_outbin_acc: 0.6982
# Epoch 5/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0492 - outmap_loss: 0.0339 - outmap4_loss: 0.0367 - outmap5_loss: 0.0445 - outbin_loss: 0.5766 - outbin_acc: 0.7090Epoch 00004: val_loss improved from 0.06620 to 0.05214, saving model to weights.hdf5
# 9372/9372 [==============================] - 88s - loss: 0.0493 - outmap_loss: 0.0339 - outmap4_loss: 0.0367 - outmap5_loss: 0.0445 - outbin_loss: 0.5768 - outbin_acc: 0.7089 - val_loss: 0.0521 - val_outmap_loss: 0.0380 - val_outmap4_loss: 0.0339 - val_outmap5_loss: 0.0404 - val_outbin_loss: 0.5300 - val_outbin_acc: 0.7174
# Epoch 6/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0445 - outmap_loss: 0.0303 - outmap4_loss: 0.0342 - outmap5_loss: 0.0427 - outbin_loss: 0.5183 - outbin_acc: 0.7589Epoch 00005: val_loss improved from 0.05214 to 0.04883, saving model to weights.hdf5
# 9372/9372 [==============================] - 91s - loss: 0.0445 - outmap_loss: 0.0303 - outmap4_loss: 0.0343 - outmap5_loss: 0.0427 - outbin_loss: 0.5187 - outbin_acc: 0.7584 - val_loss: 0.0488 - val_outmap_loss: 0.0349 - val_outmap4_loss: 0.0329 - val_outmap5_loss: 0.0412 - val_outbin_loss: 0.5262 - val_outbin_acc: 0.7302
# Epoch 7/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0418 - outmap_loss: 0.0284 - outmap4_loss: 0.0331 - outmap5_loss: 0.0415 - outbin_loss: 0.4703 - outbin_acc: 0.7893Epoch 00006: val_loss improved from 0.04883 to 0.04548, saving model to weights.hdf5
# 9372/9372 [==============================] - 92s - loss: 0.0418 - outmap_loss: 0.0284 - outmap4_loss: 0.0332 - outmap5_loss: 0.0416 - outbin_loss: 0.4707 - outbin_acc: 0.7889 - val_loss: 0.0455 - val_outmap_loss: 0.0327 - val_outmap4_loss: 0.0321 - val_outmap5_loss: 0.0423 - val_outbin_loss: 0.4251 - val_outbin_acc: 0.8018
# Epoch 8/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0401 - outmap_loss: 0.0271 - outmap4_loss: 0.0323 - outmap5_loss: 0.0405 - outbin_loss: 0.4460 - outbin_acc: 0.7985Epoch 00007: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0401 - outmap_loss: 0.0272 - outmap4_loss: 0.0323 - outmap5_loss: 0.0405 - outbin_loss: 0.4463 - outbin_acc: 0.7985 - val_loss: 0.0556 - val_outmap_loss: 0.0410 - val_outmap4_loss: 0.0334 - val_outmap5_loss: 0.0412 - val_outbin_loss: 0.5889 - val_outbin_acc: 0.7059
# Epoch 9/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0386 - outmap_loss: 0.0261 - outmap4_loss: 0.0316 - outmap5_loss: 0.0399 - outbin_loss: 0.4258 - outbin_acc: 0.8139Epoch 00008: val_loss improved from 0.04548 to 0.04228, saving model to weights.hdf5
# 9372/9372 [==============================] - 92s - loss: 0.0386 - outmap_loss: 0.0260 - outmap4_loss: 0.0316 - outmap5_loss: 0.0398 - outbin_loss: 0.4257 - outbin_acc: 0.8140 - val_loss: 0.0423 - val_outmap_loss: 0.0283 - val_outmap4_loss: 0.0330 - val_outmap5_loss: 0.0411 - val_outbin_loss: 0.5344 - val_outbin_acc: 0.7174
# Epoch 10/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0374 - outmap_loss: 0.0252 - outmap4_loss: 0.0310 - outmap5_loss: 0.0390 - outbin_loss: 0.4092 - outbin_acc: 0.8237Epoch 00009: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0374 - outmap_loss: 0.0252 - outmap4_loss: 0.0310 - outmap5_loss: 0.0390 - outbin_loss: 0.4090 - outbin_acc: 0.8239 - val_loss: 0.0436 - val_outmap_loss: 0.0289 - val_outmap4_loss: 0.0331 - val_outmap5_loss: 0.0428 - val_outbin_loss: 0.5891 - val_outbin_acc: 0.6957
# Epoch 11/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0363 - outmap_loss: 0.0242 - outmap4_loss: 0.0308 - outmap5_loss: 0.0388 - outbin_loss: 0.4022 - outbin_acc: 0.8264Epoch 00010: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0363 - outmap_loss: 0.0242 - outmap4_loss: 0.0308 - outmap5_loss: 0.0388 - outbin_loss: 0.4020 - outbin_acc: 0.8267 - val_loss: 0.0457 - val_outmap_loss: 0.0306 - val_outmap4_loss: 0.0323 - val_outmap5_loss: 0.0407 - val_outbin_loss: 0.6632 - val_outbin_acc: 0.6841
# Epoch 12/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0355 - outmap_loss: 0.0235 - outmap4_loss: 0.0306 - outmap5_loss: 0.0387 - outbin_loss: 0.3917 - outbin_acc: 0.8379Epoch 00011: val_loss improved from 0.04228 to 0.03890, saving model to weights.hdf5
# 9372/9372 [==============================] - 92s - loss: 0.0355 - outmap_loss: 0.0235 - outmap4_loss: 0.0307 - outmap5_loss: 0.0388 - outbin_loss: 0.3919 - outbin_acc: 0.8377 - val_loss: 0.0389 - val_outmap_loss: 0.0257 - val_outmap4_loss: 0.0306 - val_outmap5_loss: 0.0394 - val_outbin_loss: 0.5142 - val_outbin_acc: 0.7340
# Epoch 13/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0347 - outmap_loss: 0.0230 - outmap4_loss: 0.0303 - outmap5_loss: 0.0382 - outbin_loss: 0.3773 - outbin_acc: 0.8396Epoch 00012: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0347 - outmap_loss: 0.0230 - outmap4_loss: 0.0303 - outmap5_loss: 0.0382 - outbin_loss: 0.3773 - outbin_acc: 0.8396 - val_loss: 0.0439 - val_outmap_loss: 0.0305 - val_outmap4_loss: 0.0308 - val_outmap5_loss: 0.0395 - val_outbin_loss: 0.5324 - val_outbin_acc: 0.7276
# Epoch 14/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0342 - outmap_loss: 0.0225 - outmap4_loss: 0.0303 - outmap5_loss: 0.0385 - outbin_loss: 0.3763 - outbin_acc: 0.8391Epoch 00013: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0342 - outmap_loss: 0.0225 - outmap4_loss: 0.0302 - outmap5_loss: 0.0384 - outbin_loss: 0.3761 - outbin_acc: 0.8393 - val_loss: 0.0515 - val_outmap_loss: 0.0351 - val_outmap4_loss: 0.0337 - val_outmap5_loss: 0.0422 - val_outbin_loss: 0.7639 - val_outbin_acc: 0.6688
# Epoch 15/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0332 - outmap_loss: 0.0217 - outmap4_loss: 0.0297 - outmap5_loss: 0.0377 - outbin_loss: 0.3614 - outbin_acc: 0.8488Epoch 00014: val_loss improved from 0.03890 to 0.03849, saving model to weights.hdf5
# 9372/9372 [==============================] - 92s - loss: 0.0332 - outmap_loss: 0.0217 - outmap4_loss: 0.0297 - outmap5_loss: 0.0377 - outbin_loss: 0.3620 - outbin_acc: 0.8487 - val_loss: 0.0385 - val_outmap_loss: 0.0253 - val_outmap4_loss: 0.0318 - val_outmap5_loss: 0.0407 - val_outbin_loss: 0.4833 - val_outbin_acc: 0.7711
# Epoch 16/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0330 - outmap_loss: 0.0216 - outmap4_loss: 0.0297 - outmap5_loss: 0.0379 - outbin_loss: 0.3568 - outbin_acc: 0.8519Epoch 00015: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0331 - outmap_loss: 0.0216 - outmap4_loss: 0.0297 - outmap5_loss: 0.0379 - outbin_loss: 0.3573 - outbin_acc: 0.8516 - val_loss: 0.0442 - val_outmap_loss: 0.0295 - val_outmap4_loss: 0.0312 - val_outmap5_loss: 0.0391 - val_outbin_loss: 0.6502 - val_outbin_acc: 0.6867
# Epoch 17/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0322 - outmap_loss: 0.0210 - outmap4_loss: 0.0293 - outmap5_loss: 0.0374 - outbin_loss: 0.3494 - outbin_acc: 0.8537Epoch 00016: val_loss did not improve
# 9372/9372 [==============================] - 91s - loss: 0.0322 - outmap_loss: 0.0210 - outmap4_loss: 0.0293 - outmap5_loss: 0.0374 - outbin_loss: 0.3495 - outbin_acc: 0.8533 - val_loss: 0.0438 - val_outmap_loss: 0.0285 - val_outmap4_loss: 0.0326 - val_outmap5_loss: 0.0391 - val_outbin_loss: 0.6854 - val_outbin_acc: 0.6854
# Epoch 18/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0323 - outmap_loss: 0.0211 - outmap4_loss: 0.0293 - outmap5_loss: 0.0378 - outbin_loss: 0.3474 - outbin_acc: 0.8556Epoch 00017: val_loss did not improve
# 9372/9372 [==============================] - 89s - loss: 0.0323 - outmap_loss: 0.0211 - outmap4_loss: 0.0293 - outmap5_loss: 0.0377 - outbin_loss: 0.3476 - outbin_acc: 0.8555 - val_loss: 0.0446 - val_outmap_loss: 0.0308 - val_outmap4_loss: 0.0325 - val_outmap5_loss: 0.0391 - val_outbin_loss: 0.5376 - val_outbin_acc: 0.7327
# Epoch 19/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0314 - outmap_loss: 0.0204 - outmap4_loss: 0.0290 - outmap5_loss: 0.0370 - outbin_loss: 0.3301 - outbin_acc: 0.8668Epoch 00018: val_loss did not improve
# 9372/9372 [==============================] - 88s - loss: 0.0314 - outmap_loss: 0.0204 - outmap4_loss: 0.0290 - outmap5_loss: 0.0371 - outbin_loss: 0.3305 - outbin_acc: 0.8668 - val_loss: 0.0429 - val_outmap_loss: 0.0272 - val_outmap4_loss: 0.0327 - val_outmap5_loss: 0.0409 - val_outbin_loss: 0.7125 - val_outbin_acc: 0.6867
# Epoch 20/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0308 - outmap_loss: 0.0200 - outmap4_loss: 0.0287 - outmap5_loss: 0.0368 - outbin_loss: 0.3277 - outbin_acc: 0.8665Epoch 00019: val_loss did not improve
# 9372/9372 [==============================] - 87s - loss: 0.0308 - outmap_loss: 0.0199 - outmap4_loss: 0.0287 - outmap5_loss: 0.0368 - outbin_loss: 0.3278 - outbin_acc: 0.8664 - val_loss: 0.0470 - val_outmap_loss: 0.0299 - val_outmap4_loss: 0.0359 - val_outmap5_loss: 0.0418 - val_outbin_loss: 0.7753 - val_outbin_acc: 0.6650
# Epoch 21/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0308 - outmap_loss: 0.0200 - outmap4_loss: 0.0285 - outmap5_loss: 0.0368 - outbin_loss: 0.3250 - outbin_acc: 0.8655Epoch 00020: val_loss did not improve
# 9372/9372 [==============================] - 87s - loss: 0.0308 - outmap_loss: 0.0200 - outmap4_loss: 0.0285 - outmap5_loss: 0.0369 - outbin_loss: 0.3248 - outbin_acc: 0.8656 - val_loss: 0.0393 - val_outmap_loss: 0.0255 - val_outmap4_loss: 0.0307 - val_outmap5_loss: 0.0379 - val_outbin_loss: 0.5768 - val_outbin_acc: 0.7404
# Epoch 22/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0301 - outmap_loss: 0.0195 - outmap4_loss: 0.0282 - outmap5_loss: 0.0363 - outbin_loss: 0.3147 - outbin_acc: 0.8738Epoch 00021: val_loss did not improve
# 9372/9372 [==============================] - 87s - loss: 0.0301 - outmap_loss: 0.0195 - outmap4_loss: 0.0281 - outmap5_loss: 0.0363 - outbin_loss: 0.3145 - outbin_acc: 0.8738 - val_loss: 0.0405 - val_outmap_loss: 0.0264 - val_outmap4_loss: 0.0321 - val_outmap5_loss: 0.0388 - val_outbin_loss: 0.5815 - val_outbin_acc: 0.7404
# Epoch 23/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0297 - outmap_loss: 0.0193 - outmap4_loss: 0.0280 - outmap5_loss: 0.0360 - outbin_loss: 0.3021 - outbin_acc: 0.8791Epoch 00022: val_loss did not improve
# 9372/9372 [==============================] - 87s - loss: 0.0297 - outmap_loss: 0.0193 - outmap4_loss: 0.0280 - outmap5_loss: 0.0360 - outbin_loss: 0.3022 - outbin_acc: 0.8792 - val_loss: 0.0412 - val_outmap_loss: 0.0253 - val_outmap4_loss: 0.0318 - val_outmap5_loss: 0.0399 - val_outbin_loss: 0.7553 - val_outbin_acc: 0.6829
# Epoch 24/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0292 - outmap_loss: 0.0188 - outmap4_loss: 0.0278 - outmap5_loss: 0.0359 - outbin_loss: 0.3013 - outbin_acc: 0.8711Epoch 00023: val_loss did not improve
# 9372/9372 [==============================] - 87s - loss: 0.0292 - outmap_loss: 0.0188 - outmap4_loss: 0.0278 - outmap5_loss: 0.0359 - outbin_loss: 0.3009 - outbin_acc: 0.8713 - val_loss: 0.0463 - val_outmap_loss: 0.0300 - val_outmap4_loss: 0.0353 - val_outmap5_loss: 0.0420 - val_outbin_loss: 0.7142 - val_outbin_acc: 0.7008
# Epoch 25/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0288 - outmap_loss: 0.0186 - outmap4_loss: 0.0276 - outmap5_loss: 0.0358 - outbin_loss: 0.2918 - outbin_acc: 0.8807Epoch 00024: val_loss improved from 0.03849 to 0.03641, saving model to weights.hdf5
# 9372/9372 [==============================] - 89s - loss: 0.0288 - outmap_loss: 0.0186 - outmap4_loss: 0.0276 - outmap5_loss: 0.0358 - outbin_loss: 0.2916 - outbin_acc: 0.8808 - val_loss: 0.0364 - val_outmap_loss: 0.0239 - val_outmap4_loss: 0.0289 - val_outmap5_loss: 0.0371 - val_outbin_loss: 0.4885 - val_outbin_acc: 0.7941
# Epoch 26/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0287 - outmap_loss: 0.0185 - outmap4_loss: 0.0275 - outmap5_loss: 0.0358 - outbin_loss: 0.2941 - outbin_acc: 0.8807Epoch 00025: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0287 - outmap_loss: 0.0185 - outmap4_loss: 0.0275 - outmap5_loss: 0.0358 - outbin_loss: 0.2942 - outbin_acc: 0.8805 - val_loss: 0.0496 - val_outmap_loss: 0.0310 - val_outmap4_loss: 0.0358 - val_outmap5_loss: 0.0461 - val_outbin_loss: 0.9132 - val_outbin_acc: 0.6650
# Epoch 27/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0285 - outmap_loss: 0.0183 - outmap4_loss: 0.0275 - outmap5_loss: 0.0357 - outbin_loss: 0.2894 - outbin_acc: 0.8821Epoch 00026: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0285 - outmap_loss: 0.0183 - outmap4_loss: 0.0275 - outmap5_loss: 0.0358 - outbin_loss: 0.2893 - outbin_acc: 0.8821 - val_loss: 0.0454 - val_outmap_loss: 0.0293 - val_outmap4_loss: 0.0327 - val_outmap5_loss: 0.0407 - val_outbin_loss: 0.7555 - val_outbin_acc: 0.7072
# Epoch 28/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0284 - outmap_loss: 0.0182 - outmap4_loss: 0.0275 - outmap5_loss: 0.0355 - outbin_loss: 0.2841 - outbin_acc: 0.8853Epoch 00027: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0283 - outmap_loss: 0.0182 - outmap4_loss: 0.0275 - outmap5_loss: 0.0355 - outbin_loss: 0.2838 - outbin_acc: 0.8855 - val_loss: 0.0476 - val_outmap_loss: 0.0302 - val_outmap4_loss: 0.0343 - val_outmap5_loss: 0.0467 - val_outbin_loss: 0.8164 - val_outbin_acc: 0.6777
# Epoch 29/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0283 - outmap_loss: 0.0183 - outmap4_loss: 0.0273 - outmap5_loss: 0.0357 - outbin_loss: 0.2806 - outbin_acc: 0.8854Epoch 00028: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0283 - outmap_loss: 0.0183 - outmap4_loss: 0.0273 - outmap5_loss: 0.0357 - outbin_loss: 0.2810 - outbin_acc: 0.8852 - val_loss: 0.0523 - val_outmap_loss: 0.0336 - val_outmap4_loss: 0.0374 - val_outmap5_loss: 0.0448 - val_outbin_loss: 0.8986 - val_outbin_acc: 0.6714
# Epoch 30/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0277 - outmap_loss: 0.0178 - outmap4_loss: 0.0272 - outmap5_loss: 0.0352 - outbin_loss: 0.2711 - outbin_acc: 0.8911Epoch 00029: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0277 - outmap_loss: 0.0178 - outmap4_loss: 0.0272 - outmap5_loss: 0.0352 - outbin_loss: 0.2713 - outbin_acc: 0.8907 - val_loss: 0.0428 - val_outmap_loss: 0.0266 - val_outmap4_loss: 0.0323 - val_outmap5_loss: 0.0407 - val_outbin_loss: 0.7761 - val_outbin_acc: 0.7033
# Epoch 31/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0274 - outmap_loss: 0.0176 - outmap4_loss: 0.0269 - outmap5_loss: 0.0351 - outbin_loss: 0.2681 - outbin_acc: 0.8932Epoch 00030: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0274 - outmap_loss: 0.0176 - outmap4_loss: 0.0269 - outmap5_loss: 0.0351 - outbin_loss: 0.2681 - outbin_acc: 0.8931 - val_loss: 0.0426 - val_outmap_loss: 0.0262 - val_outmap4_loss: 0.0328 - val_outmap5_loss: 0.0420 - val_outbin_loss: 0.7649 - val_outbin_acc: 0.7020
# Epoch 32/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0273 - outmap_loss: 0.0175 - outmap4_loss: 0.0269 - outmap5_loss: 0.0353 - outbin_loss: 0.2699 - outbin_acc: 0.8875Epoch 00031: val_loss improved from 0.03641 to 0.03413, saving model to weights.hdf5
# 9372/9372 [==============================] - 92s - loss: 0.0274 - outmap_loss: 0.0175 - outmap4_loss: 0.0269 - outmap5_loss: 0.0353 - outbin_loss: 0.2703 - outbin_acc: 0.8872 - val_loss: 0.0341 - val_outmap_loss: 0.0213 - val_outmap4_loss: 0.0302 - val_outmap5_loss: 0.0364 - val_outbin_loss: 0.4928 - val_outbin_acc: 0.7916
# Epoch 33/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0270 - outmap_loss: 0.0172 - outmap4_loss: 0.0268 - outmap5_loss: 0.0351 - outbin_loss: 0.2662 - outbin_acc: 0.8913Epoch 00032: val_loss improved from 0.03413 to 0.03220, saving model to weights.hdf5
# 9372/9372 [==============================] - 92s - loss: 0.0270 - outmap_loss: 0.0172 - outmap4_loss: 0.0268 - outmap5_loss: 0.0351 - outbin_loss: 0.2660 - outbin_acc: 0.8913 - val_loss: 0.0322 - val_outmap_loss: 0.0207 - val_outmap4_loss: 0.0288 - val_outmap5_loss: 0.0363 - val_outbin_loss: 0.3922 - val_outbin_acc: 0.8312
# Epoch 34/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0269 - outmap_loss: 0.0172 - outmap4_loss: 0.0266 - outmap5_loss: 0.0351 - outbin_loss: 0.2562 - outbin_acc: 0.8970Epoch 00033: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0269 - outmap_loss: 0.0172 - outmap4_loss: 0.0266 - outmap5_loss: 0.0351 - outbin_loss: 0.2563 - outbin_acc: 0.8969 - val_loss: 0.0467 - val_outmap_loss: 0.0311 - val_outmap4_loss: 0.0344 - val_outmap5_loss: 0.0414 - val_outbin_loss: 0.6583 - val_outbin_acc: 0.7263
# Epoch 35/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0265 - outmap_loss: 0.0169 - outmap4_loss: 0.0266 - outmap5_loss: 0.0349 - outbin_loss: 0.2507 - outbin_acc: 0.8967Epoch 00034: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0265 - outmap_loss: 0.0169 - outmap4_loss: 0.0266 - outmap5_loss: 0.0349 - outbin_loss: 0.2506 - outbin_acc: 0.8967 - val_loss: 0.0659 - val_outmap_loss: 0.0430 - val_outmap4_loss: 0.0484 - val_outmap5_loss: 0.0502 - val_outbin_loss: 1.0772 - val_outbin_acc: 0.6598
# Epoch 36/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0263 - outmap_loss: 0.0168 - outmap4_loss: 0.0264 - outmap5_loss: 0.0348 - outbin_loss: 0.2422 - outbin_acc: 0.9034Epoch 00035: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0263 - outmap_loss: 0.0168 - outmap4_loss: 0.0264 - outmap5_loss: 0.0348 - outbin_loss: 0.2420 - outbin_acc: 0.9033 - val_loss: 0.0457 - val_outmap_loss: 0.0295 - val_outmap4_loss: 0.0364 - val_outmap5_loss: 0.0427 - val_outbin_loss: 0.6718 - val_outbin_acc: 0.7442
# Epoch 37/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0259 - outmap_loss: 0.0165 - outmap4_loss: 0.0262 - outmap5_loss: 0.0347 - outbin_loss: 0.2400 - outbin_acc: 0.9057Epoch 00036: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0259 - outmap_loss: 0.0165 - outmap4_loss: 0.0263 - outmap5_loss: 0.0347 - outbin_loss: 0.2405 - outbin_acc: 0.9055 - val_loss: 0.0415 - val_outmap_loss: 0.0259 - val_outmap4_loss: 0.0320 - val_outmap5_loss: 0.0393 - val_outbin_loss: 0.7218 - val_outbin_acc: 0.7545
# Epoch 38/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0257 - outmap_loss: 0.0165 - outmap4_loss: 0.0262 - outmap5_loss: 0.0345 - outbin_loss: 0.2307 - outbin_acc: 0.9085Epoch 00037: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0258 - outmap_loss: 0.0165 - outmap4_loss: 0.0262 - outmap5_loss: 0.0345 - outbin_loss: 0.2309 - outbin_acc: 0.9085 - val_loss: 0.0406 - val_outmap_loss: 0.0257 - val_outmap4_loss: 0.0300 - val_outmap5_loss: 0.0391 - val_outbin_loss: 0.6982 - val_outbin_acc: 0.7442
# Epoch 39/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0256 - outmap_loss: 0.0162 - outmap4_loss: 0.0262 - outmap5_loss: 0.0346 - outbin_loss: 0.2357 - outbin_acc: 0.9037Epoch 00038: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0256 - outmap_loss: 0.0162 - outmap4_loss: 0.0261 - outmap5_loss: 0.0346 - outbin_loss: 0.2359 - outbin_acc: 0.9036 - val_loss: 0.0398 - val_outmap_loss: 0.0257 - val_outmap4_loss: 0.0316 - val_outmap5_loss: 0.0372 - val_outbin_loss: 0.5948 - val_outbin_acc: 0.7685
# Epoch 40/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0254 - outmap_loss: 0.0162 - outmap4_loss: 0.0261 - outmap5_loss: 0.0344 - outbin_loss: 0.2260 - outbin_acc: 0.9062Epoch 00039: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0253 - outmap_loss: 0.0161 - outmap4_loss: 0.0261 - outmap5_loss: 0.0344 - outbin_loss: 0.2260 - outbin_acc: 0.9062 - val_loss: 0.0437 - val_outmap_loss: 0.0288 - val_outmap4_loss: 0.0349 - val_outmap5_loss: 0.0377 - val_outbin_loss: 0.6029 - val_outbin_acc: 0.7621
# Epoch 41/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0255 - outmap_loss: 0.0163 - outmap4_loss: 0.0260 - outmap5_loss: 0.0344 - outbin_loss: 0.2272 - outbin_acc: 0.9106Epoch 00040: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0255 - outmap_loss: 0.0163 - outmap4_loss: 0.0261 - outmap5_loss: 0.0344 - outbin_loss: 0.2271 - outbin_acc: 0.9106 - val_loss: 0.0419 - val_outmap_loss: 0.0257 - val_outmap4_loss: 0.0343 - val_outmap5_loss: 0.0381 - val_outbin_loss: 0.7366 - val_outbin_acc: 0.6957
# Epoch 42/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0250 - outmap_loss: 0.0159 - outmap4_loss: 0.0259 - outmap5_loss: 0.0343 - outbin_loss: 0.2240 - outbin_acc: 0.9088Epoch 00041: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0250 - outmap_loss: 0.0159 - outmap4_loss: 0.0260 - outmap5_loss: 0.0343 - outbin_loss: 0.2241 - outbin_acc: 0.9088 - val_loss: 0.0357 - val_outmap_loss: 0.0228 - val_outmap4_loss: 0.0309 - val_outmap5_loss: 0.0362 - val_outbin_loss: 0.4940 - val_outbin_acc: 0.7992
# Epoch 43/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0248 - outmap_loss: 0.0157 - outmap4_loss: 0.0259 - outmap5_loss: 0.0342 - outbin_loss: 0.2146 - outbin_acc: 0.9152Epoch 00042: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0248 - outmap_loss: 0.0157 - outmap4_loss: 0.0260 - outmap5_loss: 0.0342 - outbin_loss: 0.2153 - outbin_acc: 0.9146 - val_loss: 0.0379 - val_outmap_loss: 0.0262 - val_outmap4_loss: 0.0282 - val_outmap5_loss: 0.0349 - val_outbin_loss: 0.4316 - val_outbin_acc: 0.8274
# Epoch 44/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0244 - outmap_loss: 0.0154 - outmap4_loss: 0.0257 - outmap5_loss: 0.0341 - outbin_loss: 0.2117 - outbin_acc: 0.9149Epoch 00043: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0244 - outmap_loss: 0.0155 - outmap4_loss: 0.0257 - outmap5_loss: 0.0341 - outbin_loss: 0.2119 - outbin_acc: 0.9149 - val_loss: 0.0369 - val_outmap_loss: 0.0257 - val_outmap4_loss: 0.0284 - val_outmap5_loss: 0.0353 - val_outbin_loss: 0.3750 - val_outbin_acc: 0.8555
# Epoch 45/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0247 - outmap_loss: 0.0157 - outmap4_loss: 0.0258 - outmap5_loss: 0.0342 - outbin_loss: 0.2135 - outbin_acc: 0.9150Epoch 00044: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0247 - outmap_loss: 0.0157 - outmap4_loss: 0.0258 - outmap5_loss: 0.0342 - outbin_loss: 0.2130 - outbin_acc: 0.9153 - val_loss: 0.0484 - val_outmap_loss: 0.0319 - val_outmap4_loss: 0.0337 - val_outmap5_loss: 0.0389 - val_outbin_loss: 0.7794 - val_outbin_acc: 0.7161
# Epoch 46/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0242 - outmap_loss: 0.0153 - outmap4_loss: 0.0256 - outmap5_loss: 0.0340 - outbin_loss: 0.2052 - outbin_acc: 0.9196Epoch 00045: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0242 - outmap_loss: 0.0153 - outmap4_loss: 0.0256 - outmap5_loss: 0.0341 - outbin_loss: 0.2052 - outbin_acc: 0.9198 - val_loss: 0.0449 - val_outmap_loss: 0.0275 - val_outmap4_loss: 0.0334 - val_outmap5_loss: 0.0434 - val_outbin_loss: 0.8471 - val_outbin_acc: 0.7315
# Epoch 47/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0241 - outmap_loss: 0.0152 - outmap4_loss: 0.0256 - outmap5_loss: 0.0341 - outbin_loss: 0.2106 - outbin_acc: 0.9173Epoch 00046: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0241 - outmap_loss: 0.0152 - outmap4_loss: 0.0256 - outmap5_loss: 0.0340 - outbin_loss: 0.2108 - outbin_acc: 0.9172 - val_loss: 0.0486 - val_outmap_loss: 0.0329 - val_outmap4_loss: 0.0344 - val_outmap5_loss: 0.0385 - val_outbin_loss: 0.6845 - val_outbin_acc: 0.7519
# Epoch 48/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0244 - outmap_loss: 0.0155 - outmap4_loss: 0.0258 - outmap5_loss: 0.0341 - outbin_loss: 0.2039 - outbin_acc: 0.9176Epoch 00047: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0244 - outmap_loss: 0.0155 - outmap4_loss: 0.0257 - outmap5_loss: 0.0340 - outbin_loss: 0.2042 - outbin_acc: 0.9174 - val_loss: 0.0489 - val_outmap_loss: 0.0344 - val_outmap4_loss: 0.0332 - val_outmap5_loss: 0.0396 - val_outbin_loss: 0.5896 - val_outbin_acc: 0.7698
# Epoch 49/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0239 - outmap_loss: 0.0152 - outmap4_loss: 0.0255 - outmap5_loss: 0.0339 - outbin_loss: 0.1927 - outbin_acc: 0.9237Epoch 00048: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0239 - outmap_loss: 0.0152 - outmap4_loss: 0.0255 - outmap5_loss: 0.0338 - outbin_loss: 0.1924 - outbin_acc: 0.9237 - val_loss: 0.0443 - val_outmap_loss: 0.0280 - val_outmap4_loss: 0.0329 - val_outmap5_loss: 0.0392 - val_outbin_loss: 0.7703 - val_outbin_acc: 0.7379
# Epoch 50/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0239 - outmap_loss: 0.0150 - outmap4_loss: 0.0255 - outmap5_loss: 0.0340 - outbin_loss: 0.2018 - outbin_acc: 0.9210Epoch 00049: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0239 - outmap_loss: 0.0150 - outmap4_loss: 0.0255 - outmap5_loss: 0.0340 - outbin_loss: 0.2018 - outbin_acc: 0.9210 - val_loss: 0.0475 - val_outmap_loss: 0.0302 - val_outmap4_loss: 0.0373 - val_outmap5_loss: 0.0441 - val_outbin_loss: 0.7615 - val_outbin_acc: 0.7353
# Epoch 51/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0236 - outmap_loss: 0.0148 - outmap4_loss: 0.0254 - outmap5_loss: 0.0340 - outbin_loss: 0.1961 - outbin_acc: 0.9205Epoch 00050: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0236 - outmap_loss: 0.0148 - outmap4_loss: 0.0254 - outmap5_loss: 0.0340 - outbin_loss: 0.1969 - outbin_acc: 0.9202 - val_loss: 0.0388 - val_outmap_loss: 0.0243 - val_outmap4_loss: 0.0345 - val_outmap5_loss: 0.0383 - val_outbin_loss: 0.5763 - val_outbin_acc: 0.7980
# Epoch 52/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0231 - outmap_loss: 0.0146 - outmap4_loss: 0.0252 - outmap5_loss: 0.0337 - outbin_loss: 0.1845 - outbin_acc: 0.9275Epoch 00051: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0231 - outmap_loss: 0.0146 - outmap4_loss: 0.0252 - outmap5_loss: 0.0337 - outbin_loss: 0.1842 - outbin_acc: 0.9277 - val_loss: 0.0512 - val_outmap_loss: 0.0322 - val_outmap4_loss: 0.0378 - val_outmap5_loss: 0.0429 - val_outbin_loss: 0.9324 - val_outbin_acc: 0.6982
# Epoch 53/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0231 - outmap_loss: 0.0146 - outmap4_loss: 0.0252 - outmap5_loss: 0.0336 - outbin_loss: 0.1815 - outbin_acc: 0.9277Epoch 00052: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0231 - outmap_loss: 0.0146 - outmap4_loss: 0.0252 - outmap5_loss: 0.0337 - outbin_loss: 0.1816 - outbin_acc: 0.9276 - val_loss: 0.0535 - val_outmap_loss: 0.0293 - val_outmap4_loss: 0.0393 - val_outmap5_loss: 0.0483 - val_outbin_loss: 1.3963 - val_outbin_acc: 0.6509
# Epoch 54/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0233 - outmap_loss: 0.0146 - outmap4_loss: 0.0254 - outmap5_loss: 0.0339 - outbin_loss: 0.1894 - outbin_acc: 0.9235Epoch 00053: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0233 - outmap_loss: 0.0146 - outmap4_loss: 0.0254 - outmap5_loss: 0.0339 - outbin_loss: 0.1895 - outbin_acc: 0.9236 - val_loss: 0.0372 - val_outmap_loss: 0.0247 - val_outmap4_loss: 0.0295 - val_outmap5_loss: 0.0367 - val_outbin_loss: 0.4811 - val_outbin_acc: 0.8338
# Epoch 55/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0227 - outmap_loss: 0.0142 - outmap4_loss: 0.0250 - outmap5_loss: 0.0336 - outbin_loss: 0.1761 - outbin_acc: 0.9289Epoch 00054: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0227 - outmap_loss: 0.0142 - outmap4_loss: 0.0250 - outmap5_loss: 0.0336 - outbin_loss: 0.1761 - outbin_acc: 0.9289 - val_loss: 0.0458 - val_outmap_loss: 0.0311 - val_outmap4_loss: 0.0314 - val_outmap5_loss: 0.0378 - val_outbin_loss: 0.6493 - val_outbin_acc: 0.7698
# Epoch 56/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0227 - outmap_loss: 0.0142 - outmap4_loss: 0.0251 - outmap5_loss: 0.0337 - outbin_loss: 0.1765 - outbin_acc: 0.9294Epoch 00055: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0227 - outmap_loss: 0.0142 - outmap4_loss: 0.0251 - outmap5_loss: 0.0337 - outbin_loss: 0.1762 - outbin_acc: 0.9295 - val_loss: 0.0386 - val_outmap_loss: 0.0241 - val_outmap4_loss: 0.0325 - val_outmap5_loss: 0.0391 - val_outbin_loss: 0.6036 - val_outbin_acc: 0.8095
# Epoch 57/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0227 - outmap_loss: 0.0142 - outmap4_loss: 0.0251 - outmap5_loss: 0.0339 - outbin_loss: 0.1768 - outbin_acc: 0.9329Epoch 00056: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0227 - outmap_loss: 0.0142 - outmap4_loss: 0.0251 - outmap5_loss: 0.0339 - outbin_loss: 0.1769 - outbin_acc: 0.9328 - val_loss: 0.0410 - val_outmap_loss: 0.0283 - val_outmap4_loss: 0.0286 - val_outmap5_loss: 0.0393 - val_outbin_loss: 0.4926 - val_outbin_acc: 0.8338
# Epoch 58/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0222 - outmap_loss: 0.0139 - outmap4_loss: 0.0249 - outmap5_loss: 0.0335 - outbin_loss: 0.1638 - outbin_acc: 0.9345Epoch 00057: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0222 - outmap_loss: 0.0139 - outmap4_loss: 0.0249 - outmap5_loss: 0.0335 - outbin_loss: 0.1644 - outbin_acc: 0.9345 - val_loss: 0.0428 - val_outmap_loss: 0.0292 - val_outmap4_loss: 0.0315 - val_outmap5_loss: 0.0384 - val_outbin_loss: 0.5402 - val_outbin_acc: 0.8299
# Epoch 59/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0227 - outmap_loss: 0.0141 - outmap4_loss: 0.0252 - outmap5_loss: 0.0339 - outbin_loss: 0.1787 - outbin_acc: 0.9273Epoch 00058: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0226 - outmap_loss: 0.0141 - outmap4_loss: 0.0252 - outmap5_loss: 0.0339 - outbin_loss: 0.1787 - outbin_acc: 0.9274 - val_loss: 0.0455 - val_outmap_loss: 0.0286 - val_outmap4_loss: 0.0355 - val_outmap5_loss: 0.0412 - val_outbin_loss: 0.7803 - val_outbin_acc: 0.7506
# Epoch 60/60
# 9344/9372 [============================>.] - ETA: 0s - loss: 0.0219 - outmap_loss: 0.0137 - outmap4_loss: 0.0247 - outmap5_loss: 0.0333 - outbin_loss: 0.1596 - outbin_acc: 0.9386Epoch 00059: val_loss did not improve
# 9372/9372 [==============================] - 92s - loss: 0.0220 - outmap_loss: 0.0137 - outmap4_loss: 0.0247 - outmap5_loss: 0.0333 - outbin_loss: 0.1597 - outbin_acc: 0.9385 - val_loss: 0.0476 - val_outmap_loss: 0.0294 - val_outmap4_loss: 0.0369 - val_outmap5_loss: 0.0441 - val_outbin_loss: 0.8604 - val_outbin_acc: 0.7379

# %%
if False:
    model_dir = '.'
    json_string = model.to_json()
    open(os.path.join(model_dir, 'architecture_final.json'), 'w').write(json_string)
    model.save_weights(os.path.join(model_dir, 'weights_final.hdf5'))

# %%
def compute_scores_map(X, Y):
    Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X)
    
    map_threshs = np.linspace(0, 1, num=21)
    bin_threshs = np.linspace(0, 1, num=21)
    
    scores = np.zeros((len(map_threshs), len(bin_threshs)))
    for i in range(len(map_threshs)):
        for j in range(len(bin_threshs)):
            _Y_pred = Y_pred > map_threshs[i]
            
            for k in range(_Y_pred.shape[0]):
                # Clear prediction where we detect to little pixels
                if np.sum(_Y_pred[k]) < 150 or Y_pred_binary[k] < bin_threshs[j]:
                    _Y_pred[k,:] = 0
            
            scores[i, j] = utils.average_dice_coefficient(_Y_pred, Y)
    
    pl.imshow(scores, interpolation='nearest')
    pl.yticks(np.arange(len(map_threshs)) + 0.5, ['%.2f' % v for v in map_threshs])
    pl.xticks(np.arange(len(bin_threshs)) + 0.5, ['%.2f' % v for v in bin_threshs], rotation=90)
    pl.ylabel('map thresh')
    pl.xlabel('bin thresh')
    pl.colorbar()
    
    best_i, best_j = np.unravel_index(np.argmax(scores.ravel()), scores.shape)
    best_map_thresh = map_threshs[best_i]
    best_bin_thresh = bin_threshs[best_j]
    return best_map_thresh, best_bin_thresh

map_thresh, bin_thresh = compute_scores_map(X_test, Y_test)
print 'Best map_thresh=%f, bin_thresh=%f' % (map_thresh, bin_thresh)
# Out:
# Best map_thresh=0.150000, bin_thresh=0.000000

# %%
map_thresh = 0.45
bin_thresh = 0.4

# %%
def predict(X, map_thresh, bin_thresh):
    Y_pred, Y_pred_88, Y_pred_44, Y_pred_binary = model.predict(X)
    Y_pred_binary = Y_pred_binary.squeeze()
    Y_pred_proba = Y_pred
    Y_pred = Y_pred > map_thresh
    for i in range(Y_pred.shape[0]):
        if np.sum(Y_pred[i]) < 150 or Y_pred_binary[i] < bin_thresh:
            Y_pred[i,:] = 0
        pass
    return Y_pred, Y_pred_proba, Y_pred_binary

Y_pred, Y_pred_proba, Y_pred_binary = predict(X_test, map_thresh, bin_thresh)
Y_full_pred, Y_full_pred_proba, Y_full_pred_binary = predict(X_full, map_thresh, bin_thresh)

print "test set score : ", utils.dice_coefficient(Y_pred, Y_test)
print "avg test set score : ", utils.average_dice_coefficient(Y_pred, Y_test)
print "full set score : ", utils.dice_coefficient(Y_full_pred, Y_full)
print "avg full set score : ", utils.average_dice_coefficient(Y_full_pred, Y_full)
# Out:
# test set score :  0.334760872903
# avg test set score :  0.714665229201
# full set score :  0.264944871054
# avg full set score :  0.652231592655

# %%
_ = pl.hist(Y_pred_binary)

# %%
# Find the images with lowest scores
dice_scores = []
for i in range(Y_pred.shape[0]):
    dice_scores.append(utils.dice_coefficient(Y_pred[i], Y_test[i]))
dice_scores = np.array(dice_scores)
lowest = np.argsort(dice_scores)

# %%
pl.plot(dice_scores[lowest])
#pl.plot(Y_pred_binary[lowest], c='r')

# %%
#i = 50
#i = 47

#for i in lowest[380:385]:
for i in lowest[80:85]:
    pl.figure(figsize=(12, 3))
    pl.suptitle('dice score %f' % utils.dice_coefficient(Y_pred[i], Y_test[i]))
    pl.subplot(141)
    pl.title('input')
    pl.imshow(X_test[i].squeeze())
    pl.subplot(142)
    pl.title('expected')
    pl.imshow(Y_test[i].squeeze())
    pl.subplot(143)
    pl.title('predicted')
    pl.imshow(Y_pred[i].squeeze(), vmin=0, vmax=1)
    pl.subplot(144)
    #print np.sum(Y_pred[i].squeeze())
    pl.title('prediction proba %f' % Y_pred_binary[i])
    pl.imshow(Y_pred_proba[i].squeeze(), vmin=0, vmax=1)

# %% [markdown]
# # Filters visualization

# %%
# get the symbolic outputs of each "key" layer (we gave them unique names).
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
import keras.backend as K

# %%
# Dream for the classifmap output
def dream_output(output):
    layer_output = layer_dict['outmap'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output[None,:,:,:] - layer_output))

    # compute the gradient of the input picture wrt this loss
    input_img = layer_dict['input_img'].input
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.2
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()
    
    step = 0.1
    for i in range(30):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    pred_map, pred44, pred88, binary_pred = model.predict(img[None,None,:,:])
    return img, pred_map

i = 15
img, pred_map = dream_output(Y_full[i])
pl.figure(figsize=(12, 4))
pl.subplot(141)
pl.imshow(X_full[i].squeeze(), cmap=cm.gray)
pl.subplot(142)
pl.imshow(Y_full[i].squeeze())
pl.subplot(143)
pl.imshow(img, cmap=cm.gray)
pl.subplot(144)
pl.imshow(pred_map.squeeze())

# %%
# Dream for the binary output
def dream_binoutput(output):
    
    layer_output = layer_dict['outbin'].output
    # minimize difference between requested output and actual
    loss = K.mean(K.square(output - layer_output[:, 0]))
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    
    step = 0.1
    for i in range(40):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data -= grads_value * step
        
        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    # run the image through the model to get prediction
    _, _, _, model_pred = model.predict(img[None,None,:,:])
    return img, model_pred

img, model_pred = dream_binoutput(1)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
img, model_pred = dream_binoutput(0)
pl.title('pred : %f' % model_pred)
pl.imshow(img, cmap=cm.gray)

# %%
def dream_layer_filter(layer_name, filter_index):

    # build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    loss = K.mean(layer_output[:, filter_index, :, :])
    
    input_img = layer_dict['input_img'].input

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([K.learning_phase(), input_img], [loss, grads])

    # we start from a gray image with some noise
    input_img_data = np.random.random((1, input_shape[0], input_shape[1], input_shape[2])) * 0.2 + 0.5
    input_img_data = input_img_data.astype(np.float32)

    orig_img = input_img_data.copy()

    # run gradient ascent for 20 steps
    step = 0.1
    for i in range(20):
        # 0 is to disable training_phase
        loss_value, grads_value = iterate([0, input_img_data])
        input_img_data += grads_value * step

        # normalize to 0-1
        #input_img_data = (input_img_data - input_img_data.min()) / (input_img_data.max() - input_img_data.min())

    img = input_img_data[0].squeeze()
    return img
    #img = deprocess_image(img)
    
    
for layer_name in ['pool2', 'pool3', 'pool4', 'pool5']:
    pl.figure(figsize=(16, 8))
    for i in range(4):
        pl.subplot(1, 4, i + 1)
        pl.title('%s:%d' % (layer_name, i))
        img = dream_layer_filter(layer_name, i)
        pl.imshow(img, cmap=cm.gray)

# %% [markdown]
# # Run the model on kaggle'7 test set

# %%
if True:
    import cv2
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(50,50))
    
    _d = np.load('../data/data_128_test.npz')
    X_submit = _d['X']
    test_fnames = _d['test_fnames']
    # bin_thresh
    Y_pred, Y_pred_proba, Y_pred_binary = predict(X_submit[:,None,:,:],
                                                  map_thresh, bin_thresh)
    
    OUTDIR='../../preds'
    if os.path.exists(OUTDIR):
        shutil.rmtree(OUTDIR)
    utils.mkdir_p(OUTDIR)

    for i in range(Y_pred.shape[0]):
        imre = cv2.resize((Y_pred[i].squeeze() * 255).astype(np.uint8), (580, 420))
        #imre = cv2.morphologyEx(imre, cv2.MORPH_CLOSE, kernel)
        basename = os.path.splitext(test_fnames[i])[0]
        cv2.imwrite(os.path.join(OUTDIR, basename + '.png'), imre)
        
        if i % 10 == 0:
            print '\r%d / %d' % (i, len(test_fnames)),
            sys.stdout.flush()
# Out:
# 5500 / 5508

# %% [markdown]
# ## Stats on predicted masks

# %%
# on Y_full
nbp_pixels = np.sum(np.sum(np.sum(Y_full, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
pl.xlim((0, 1200))
# Out:
# (0, 1200)

# %%
# on pred
nbp_pixels = np.sum(np.sum(np.sum(Y_pred, axis=1), axis=1), axis=1)
bpvisible = nbp_pixels > 0

pl.figure()
pl.title('Number of mask pixels in images with brachial plexus visible')
_ = pl.hist(nbp_pixels[bpvisible], bins=50)
pl.xlim((0, 1200))
# Out:
# (0, 1200)
